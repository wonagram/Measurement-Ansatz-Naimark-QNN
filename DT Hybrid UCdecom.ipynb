# %%
# 0,1: 00 for psi_1, 01 for psi_2 ...
# 2,3: For states
# 4,5: Ancillary qubits

# %%
from qiskit import QuantumCircuit
from numpy import sqrt

def circuit_init():
    qc = QuantumCircuit(6)
    return qc

def PREP(qc):
    desired_vector = [
        1/sqrt(3), 0, 0, 0, 
        1/(4*sqrt(3)), 1/4, 1/4, sqrt(3)/4, 
        1/(4*sqrt(3)), -1/4, -1/4, sqrt(3)/4, 
        0, 0, 0, 0
    ]
    qc.initialize(desired_vector, [3,2,1,0])
    return qc

# %%
from qiskit.circuit.library.standard_gates import RXGate,RYGate, RZGate
from qiskit.circuit.library import MCXGate
from qiskit.circuit.library.standard_gates import XGate
from pennylane.templates.state_preparations.mottonen import compute_theta, gray_code
from numpy import array, log2

def RR_X(qc, wires, params):
    qc.append(RXGate(params[0]),[wires[0]])
    qc.append(RXGate(params[1]),[wires[1]])

def RR_Z(qc, wires, params):
    qc.append(RZGate(params[0]),[wires[0]])
    qc.append(RZGate(params[1]),[wires[1]])


def CRR_X(qc, wires, state, params):
    qc.append(RXGate(params[0]).control(1,ctrl_state = state[::-1]), [wires[0], wires[1]])  # Control: wires[0] Target: wires[1]
    qc.append(RXGate(params[1]).control(1,ctrl_state = state[::-1]), [wires[0], wires[2]])  # Control: wires[0] Target: wires[2]
    return qc

def CRR_Z(qc, wires, state, params):
    qc.append(RZGate(params[0]).control(1,ctrl_state = state[::-1]), [wires[0], wires[1]])  # Control: wires[0] Target: wires[1]
    qc.append(RZGate(params[1]).control(1,ctrl_state = state[::-1]), [wires[0], wires[2]])  # Control: wires[0] Target: wires[2]
    return qc

def CCRR_X(qc, wires, state, params):
    qc.append(RXGate(params[0]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[2]])  # Control: wires[0] wires[1]
    qc.append(RXGate(params[1]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[3]])  # Control: wires[0] wires[1]
    return qc

def CCRR_Z(qc, wires, state, params):
    qc.append(RZGate(params[0]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[2]])  # Control: wires[0] wires[1]
    qc.append(RZGate(params[1]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[3]])  # Control: wires[0] wires[1]
    return qc

def U_CCR(qc, wires, params):
    qc.append(RYGate(params[0]).control(2, ctrl_state = '00'), [wires[0], wires[1],wires[2]])
    qc.append(RYGate(params[1]).control(2, ctrl_state = '10'), [wires[0], wires[1],wires[2]])
    qc.append(RYGate(params[2]).control(2, ctrl_state = '01'), [wires[0], wires[1],wires[2]])
    qc.append(RYGate(params[3]).control(2, ctrl_state = '11'), [wires[0], wires[1],wires[2]])

def U_CCcR(qc,wires, params):
    qc.append(RYGate(params[0]).control(3, ctrl_state = '001'[::-1]), [wires[0], wires[1],wires[2],wires[3]])
    qc.append(RYGate(params[1]).control(3, ctrl_state = '011'[::-1]), [wires[0], wires[1],wires[2],wires[3]])
    qc.append(RYGate(params[2]).control(3, ctrl_state = '101'[::-1]), [wires[0], wires[1],wires[2],wires[3]])
    qc.append(RYGate(params[3]).control(3, ctrl_state = '111'[::-1]), [wires[0], wires[1],wires[2],wires[3]])

def U_CCR_decom(qc,wires,params):
    # Make sure that control qubits should be increasing order
    params = array(params)
    params = compute_theta(params) #can be on/off

    num_Ucontrols = len(wires)-1
    code = gray_code(2)
    n_selections = len(code)
    control_order = [int(log2(int(code[i], 2) ^ int(code[(i + 1) % n_selections], 2))) for i in range(n_selections)]

    for i in range(n_selections):
        qc.ry(params[i],wires[2])
        qc.cx(wires[num_Ucontrols-1 - control_order[i]],wires[2])
    
    return qc

def U_CCcR_decom(qc,wires,params):
    # Make sure that control qubits should be increasing order
    params = array(params)
    params = compute_theta(params) #can be on/off

    num_Ucontrols = len(wires)-2
    code = gray_code(2)
    n_selections = len(code)
    control_order = [int(log2(int(code[i], 2) ^ int(code[(i + 1) % n_selections], 2))) for i in range(n_selections)]

    for i in range(n_selections):
        qc.cry(params[i],wires[2],wires[3])
        CCX(qc,[wires[num_Ucontrols-1 - control_order[i]],wires[2],wires[3]],'11')
    
    return qc

def CCX(qc, wires, state):
    mcx_gate = MCXGate(num_ctrl_qubits=2,ctrl_state=state[::-1])
    qc.append(mcx_gate, [wires[0], wires[1],wires[2]])
    return qc

def CCCX(qc, wires, state):
    mcx_gate = MCXGate(num_ctrl_qubits=3,ctrl_state=state[::-1])
    qc.append(mcx_gate, [wires[0], wires[1],wires[2], wires[3]])
    return qc

def CX01(qc, wires):
    qc.append(XGate().control(1, ctrl_state='1'),[wires[0], wires[1]])
    return qc

# %%
from qiskit.circuit.library.standard_gates import RYGate
from qiskit.circuit.library import U2Gate
from numpy import pi

# U2Gate 
def Ansatz(qc, wires, params):


    #Big made by HEA 
    RR_X(qc,wires[0:2],params[0:2])
    RR_Z(qc,wires[0:2],params[2:4])
    qc.cx(wires[0],wires[1])
    
    #Module 1
    U_CCR_decom(qc,wires[0:3],params[4:8])
    CRR_X(qc,[wires[2],wires[0],wires[1]],'0',params[8:10])
    CRR_Z(qc,[wires[2],wires[0],wires[1]],'0',params[10:12])
    CCX(qc,[wires[0],wires[2], wires[1]],'10')
    CRR_X(qc,[wires[2],wires[0],wires[1]],'1',params[12:14])
    CRR_Z(qc,[wires[2],wires[0],wires[1]],'1',params[14:16])
    CCX(qc,[wires[0],wires[2], wires[1]],'11')

    #Module 2
    U_CCcR_decom(qc, wires[0:4],params[16:20])
    CCRR_X(qc,[wires[2],wires[3],wires[0],wires[1]],'10',params[20:22])
    CCRR_Z(qc,[wires[2],wires[3],wires[0],wires[1]],'10',params[22:24])
    CCCX(qc,[wires[0],wires[2],wires[3],wires[1]],'110')
    CCRR_X(qc,[wires[2],wires[3],wires[0],wires[1]],'11',params[24:26])
    CCRR_Z(qc,[wires[2],wires[3],wires[0],wires[1]],'11',params[26:28])
    CCCX(qc,[wires[0],wires[2],wires[3],wires[1]],'111')
    
    CX01(qc, [wires[3],wires[2]])
    qc.measure_all()
    return qc

# %%
from numpy.random import rand
num_params=28
params = list(range(num_params))
qc = QuantumCircuit(4)
#PREP(qc)
Ansatz(qc, [0,1,2,3] , params)
qc.draw(output='mpl', style = 'clifford')

# %%
from qiskit_aer import AerSimulator
from qiskit import transpile
from scipy.optimize import minimize

import numpy as np
import os
import time


# ============================================================
# Simulator
# ============================================================

aersim = AerSimulator()


# ============================================================
# Settings
# ============================================================

num_times = 30
num_shots = 10000

optimizer_name = "COBYLA"
tol_value = 1e-8
maxiter = 1000

BASE_SEED = 150

report_filename = (
    "DT_Hybrid_report.txt"
)


# ============================================================
# High-Shot Evaluation Settings
# ============================================================

evaluation_num_times = 20
evaluation_num_shots = 100000

EVALUATION_BASE_SEED = 10000

evaluation_seeds = np.array(
    [
        EVALUATION_BASE_SEED + i
        for i in range(evaluation_num_times)
    ],
    dtype=int
)


# ============================================================
# Storage
# ============================================================

final_optimized_values = []

initial_params_all_runs = []
optimal_params_all_runs = []

optimization_success_all_runs = []
optimization_status_all_runs = []
optimization_message_all_runs = []
optimization_nfev_all_runs = []
reached_maxiter_all_runs = []
optimization_wall_times = []


# ------------------------------------------------------------
# High-Shot Evaluation Storage
# ------------------------------------------------------------

evaluation_values_all_runs = []

evaluation_mean_all_runs = []
evaluation_std_all_runs = []
evaluation_min_all_runs = []
evaluation_max_all_runs = []


# ============================================================
# Objective Function
# ============================================================

def objective_function(
    params,
    run_seed,
    shots=None,
    print_result=True
):

    if shots is None:
        shots = num_shots


    # --------------------------------------------------------
    # Construct circuit
    # --------------------------------------------------------

    qc = circuit_init()

    PREP(qc)

    Ansatz(
        qc,
        [2, 3, 4, 5],
        params
    )


    qc_reverse = qc.reverse_bits()


    # --------------------------------------------------------
    # Transpile
    # --------------------------------------------------------

    t_qc = transpile(
        qc_reverse,
        aersim,
        seed_transpiler=run_seed
    )


    # --------------------------------------------------------
    # Run simulation
    # --------------------------------------------------------

    job = aersim.run(
        t_qc,
        shots=shots,
        seed_simulator=run_seed
    )


    result = job.result()

    counts = result.get_counts()


    # --------------------------------------------------------
    # Target counts
    # --------------------------------------------------------

    tar_00 = 0
    tar_01 = 0
    tar_10 = 0


    for outcome, count in counts.items():

        if outcome[0:2] == "00":

            if outcome[4:6] == "00":

                tar_00 += count


        if outcome[0:2] == "01":

            if outcome[4:6] == "01":

                tar_01 += count


        if outcome[0:2] == "10":

            if outcome[4:6] == "10":

                tar_10 += count


    # --------------------------------------------------------
    # Success probability
    # --------------------------------------------------------

    p_suc = (
        tar_00
        + tar_01
        + tar_10
    ) / shots


    if print_result:

        print(
            f"success_probability = "
            f"{p_suc:.8f}"
        )


    # --------------------------------------------------------
    # Avoid division by zero
    # --------------------------------------------------------

    if p_suc == 0:

        return 1e10


    # --------------------------------------------------------
    # COBYLA minimizes.
    #
    # Minimizing 1 / p_suc maximizes p_suc.
    # --------------------------------------------------------

    return 1.0 / p_suc


# ============================================================
# Run Optimization
# ============================================================

# Total wall-clock timer for the full computational workflow
# (all optimization runs + all high-shot evaluations).
total_wall_start = time.perf_counter()

for run in range(num_times):


    # ========================================================
    # Optimization Seed
    # ========================================================

    run_seed = (
        BASE_SEED + run
    )


    rng = np.random.default_rng(
        run_seed
    )


    print(
        "\n"
        + "=" * 80
    )


    print(
        f"Optimization Run "
        f"{run + 1}/{num_times}"
    )


    print(
        f"Optimization Seed : "
        f"{run_seed}"
    )


    print(
        "=" * 80
    )


    # ========================================================
    # Generate Random Initial Parameters
    # ========================================================

    initial_params = rng.random(
        num_params
    )


    initial_params_all_runs.append(
        initial_params.copy()
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    # ========================================================
    # Run COBYLA Optimization
    # ========================================================

    print(
        "\nStarting COBYLA optimization..."
    )


    # Measure only the COBYLA optimization time for this run.
    optimization_wall_start = time.perf_counter()

    result = minimize(

        fun=lambda params: objective_function(
            params,
            run_seed,
            shots=num_shots,
            print_result=True
        ),

        x0=initial_params,

        method=optimizer_name,

        options={
            "maxiter": maxiter,
            "disp": True,
            "tol": tol_value
        }
    )

    optimization_wall_end = time.perf_counter()
    optimization_wall_time = (
        optimization_wall_end
        - optimization_wall_start
    )

    optimization_wall_times.append(
        optimization_wall_time
    )

    print(
        f"Optimization Wall-Clock Time : "
        f"{optimization_wall_time:.6f} s"
    )


    # ========================================================
    # Optimization Status
    # ========================================================

    optimization_success = bool(
        result.success
    )


    optimization_status = getattr(
        result,
        "status",
        None
    )


    optimization_message = str(
        getattr(
            result,
            "message",
            "No message returned"
        )
    )


    optimization_nfev = getattr(
        result,
        "nfev",
        None
    )


    # ========================================================
    # Detect Maximum Function Evaluations
    # ========================================================

    message_lower = (
        optimization_message.lower()
    )


    reached_maxiter = (

        "maximum number"
        in message_lower

        or "maximum function"
        in message_lower

        or "maxiter"
        in message_lower

        or "maxfun"
        in message_lower

        or "maximum iterations"
        in message_lower

        or "maximum evaluations"
        in message_lower
    )


    if optimization_nfev is not None:

        if optimization_nfev >= maxiter:

            reached_maxiter = True


    # ========================================================
    # Store Optimization Status
    # ========================================================

    optimization_success_all_runs.append(
        optimization_success
    )


    optimization_status_all_runs.append(
        optimization_status
    )


    optimization_message_all_runs.append(
        optimization_message
    )


    optimization_nfev_all_runs.append(
        optimization_nfev
    )


    reached_maxiter_all_runs.append(
        reached_maxiter
    )


    # ========================================================
    # Optimal Parameters
    # ========================================================

    optimal_params = (
        result.x.copy()
    )


    optimal_params_all_runs.append(
        optimal_params.copy()
    )


    # ========================================================
    # Final Optimization-Shot Evaluation
    # ========================================================

    final_objective = objective_function(
        optimal_params,
        run_seed,
        shots=num_shots,
        print_result=False
    )


    if final_objective >= 1e10:

        final_value = 0.0

    else:

        final_value = (
            1.0 / final_objective
        )


    final_optimized_values.append(
        final_value
    )


    # ========================================================
    # High-Shot Evaluation
    # ========================================================

    print(
        "\n"
        + "-" * 80
    )


    print(
        "HIGH-SHOT EVALUATION OF "
        "OPTIMIZED PARAMETERS"
    )


    print(
        "-" * 80
    )


    print(
        f"Optimization Shots     : "
        f"{num_shots}"
    )


    print(
        f"Evaluation Shots       : "
        f"{evaluation_num_shots}"
    )


    print(
        f"Number of Evaluations : "
        f"{evaluation_num_times}"
    )


    print(
        "\nEvaluation Results:"
    )


    evaluation_values = []


    for eval_index, eval_seed in enumerate(
        evaluation_seeds
    ):


        eval_objective = objective_function(
            optimal_params,
            int(eval_seed),
            shots=evaluation_num_shots,
            print_result=False
        )


        if eval_objective >= 1e10:

            eval_value = 0.0

        else:

            eval_value = (
                1.0 / eval_objective
            )


        evaluation_values.append(
            eval_value
        )


        print(
            f"Evaluation "
            f"{eval_index + 1:2d}/"
            f"{evaluation_num_times:2d}"
            f" | Value = "
            f"{eval_value:.8f}"
        )


    # ========================================================
    # Evaluation Statistics
    # ========================================================

    evaluation_values = np.array(
        evaluation_values,
        dtype=float
    )


    evaluation_mean = np.mean(
        evaluation_values
    )


    evaluation_std = np.std(
        evaluation_values
    )


    evaluation_min = np.min(
        evaluation_values
    )


    evaluation_max = np.max(
        evaluation_values
    )


    # ========================================================
    # Store Evaluation Results
    # ========================================================

    evaluation_values_all_runs.append(
        evaluation_values.copy()
    )


    evaluation_mean_all_runs.append(
        evaluation_mean
    )


    evaluation_std_all_runs.append(
        evaluation_std
    )


    evaluation_min_all_runs.append(
        evaluation_min
    )


    evaluation_max_all_runs.append(
        evaluation_max
    )


    # ========================================================
    # Individual Run Report
    # ========================================================

    print(
        "\n"
        + "=" * 80
    )


    print(
        f"RUN {run + 1} RESULT"
    )


    print(
        "=" * 80
    )


    print(
        f"Optimization Success : "
        f"{optimization_success}"
    )


    print(
        f"Reached MaxIter      : "
        f"{reached_maxiter}"
    )


    print(
        f"Status               : "
        f"{optimization_status}"
    )


    print(
        f"Message              : "
        f"{optimization_message}"
    )


    print(
        f"Optimization Time    : "
        f"{optimization_wall_time:.6f} s"
    )


    print(
        f"Function Evaluations : "
        f"{optimization_nfev}"
    )


    print(
        f"Final Objective Value: "
        f"{result.fun}"
    )


    print(
        "\n"
        + "-" * 80
    )


    print(
        "OPTIMIZED AND HIGH-SHOT "
        "EVALUATED VALUES"
    )


    print(
        "-" * 80
    )


    print(
        f"Final Optimized Value : "
        f"{final_value:.8f}"
    )


    print(
        f"Evaluated Mean        : "
        f"{evaluation_mean:.8f}"
    )


    print(
        f"Evaluated Std         : "
        f"{evaluation_std:.8f}"
    )


    print(
        f"Evaluated Min         : "
        f"{evaluation_min:.8f}"
    )


    print(
        f"Evaluated Max         : "
        f"{evaluation_max:.8f}"
    )


    print(
        "\nAll Evaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values,
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "=" * 80
    )


# ============================================================
# Wall-Clock Runtime Statistics
# ============================================================

total_wall_end = time.perf_counter()

total_wall_time = (
    total_wall_end
    - total_wall_start
)

optimization_wall_times = np.array(
    optimization_wall_times,
    dtype=float
)

total_optimization_wall_time = np.sum(
    optimization_wall_times
)

mean_optimization_wall_time = np.mean(
    optimization_wall_times
)

std_optimization_wall_time = np.std(
    optimization_wall_times
)


# ============================================================
# Convert Results to NumPy Arrays
# ============================================================

final_optimized_values = np.array(
    final_optimized_values,
    dtype=float
)


initial_params_all_runs = np.array(
    initial_params_all_runs
)


optimal_params_all_runs = np.array(
    optimal_params_all_runs
)


evaluation_values_all_runs = np.array(
    evaluation_values_all_runs,
    dtype=float
)


evaluation_mean_all_runs = np.array(
    evaluation_mean_all_runs,
    dtype=float
)


evaluation_std_all_runs = np.array(
    evaluation_std_all_runs,
    dtype=float
)


evaluation_min_all_runs = np.array(
    evaluation_min_all_runs,
    dtype=float
)


evaluation_max_all_runs = np.array(
    evaluation_max_all_runs,
    dtype=float
)


# ============================================================
# Original Optimization Statistics
# ============================================================

maximum_value = np.max(
    final_optimized_values
)


mean_value = np.mean(
    final_optimized_values
)


std_value = np.std(
    final_optimized_values
)


maximum_run_index = np.argmax(
    final_optimized_values
)


maximum_run = (
    maximum_run_index + 1
)


# ============================================================
# High-Shot Evaluation Statistics
# ============================================================

maximum_evaluated_mean = np.max(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run_index = np.argmax(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run = (
    maximum_evaluated_mean_run_index
    + 1
)


mean_of_evaluated_means = np.mean(
    evaluation_mean_all_runs
)


std_of_evaluated_means = np.std(
    evaluation_mean_all_runs
)


# ============================================================
# Function Evaluation Statistics
# ============================================================

nfev_values = np.array(
    [
        nfev
        for nfev
        in optimization_nfev_all_runs
        if nfev is not None
    ],
    dtype=float
)


if len(nfev_values) > 0:

    mean_nfev = np.mean(
        nfev_values
    )


    std_nfev = np.std(
        nfev_values
    )

else:

    mean_nfev = np.nan
    std_nfev = np.nan


# ============================================================
# Optimization Success Statistics
# ============================================================

num_successful_runs = sum(
    optimization_success_all_runs
)


num_failed_runs = (
    num_times
    - num_successful_runs
)


num_reached_maxiter = sum(
    reached_maxiter_all_runs
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

best_initial_params = (
    initial_params_all_runs[
        maximum_run_index
    ]
)


best_optimal_params = (
    optimal_params_all_runs[
        maximum_run_index
    ]
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

best_evaluated_initial_params = (
    initial_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_optimal_params = (
    optimal_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_values = (
    evaluation_values_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


# ============================================================
# Print Final Report
# ============================================================

print("\n")


print(
    "=" * 100
)


print(
    "FINAL OPTIMIZATION AND "
    "HIGH-SHOT EVALUATION REPORT"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Settings
# ------------------------------------------------------------

print(
    f"Optimizer               : "
    f"{optimizer_name}"
)


print(
    f"Tolerance               : "
    f"{tol_value}"
)


print(
    f"Max Iteration           : "
    f"{maxiter}"
)


print(
    f"Number of Runs          : "
    f"{num_times}"
)


print(
    f"Optimization Shots      : "
    f"{num_shots}"
)


print(
    f"Optimization Base Seed  : "
    f"{BASE_SEED}"
)


print(
    f"Evaluation Shots        : "
    f"{evaluation_num_shots}"
)


print(
    f"Evaluations Per Run     : "
    f"{evaluation_num_times}"
)


print(
    f"Evaluation Base Seed    : "
    f"{EVALUATION_BASE_SEED}"
)


# Evaluation seeds are printed only once.
print(
    "Evaluation Seeds        : "
    + np.array2string(
        evaluation_seeds,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Results for Every Run
# ============================================================

for i in range(num_times):


    print(
        f"\nRun {i + 1:2d}"
    )


    print(
        "-" * 100
    )


    print(
        f"Optimization Seed : "
        f"{BASE_SEED + i}"
    )


    print(
        f"Optimized Value   : "
        f"{final_optimized_values[i]:.8f}"
    )


    print(
        f"Evaluated Mean    : "
        f"{evaluation_mean_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Std     : "
        f"{evaluation_std_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Min     : "
        f"{evaluation_min_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Max     : "
        f"{evaluation_max_all_runs[i]:.8f}"
    )


    print(
        f"Success           : "
        f"{optimization_success_all_runs[i]}"
    )


    print(
        f"Reached MaxIter   : "
        f"{reached_maxiter_all_runs[i]}"
    )


    print(
        f"Status            : "
        f"{optimization_status_all_runs[i]}"
    )


    print(
        f"Message           : "
        f"{optimization_message_all_runs[i]}"
    )


    print(
        f"Function Evals    : "
        f"{optimization_nfev_all_runs[i]}"
    )


    print(
        f"Optimization Time : "
        f"{optimization_wall_times[i]:.6f} s"
    )


    print(
        "\nEvaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values_all_runs[i],
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "-" * 100
    )


# ============================================================
# Summary
# ============================================================

print(
    "\nSUMMARY"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Original Optimization Results
# ------------------------------------------------------------

print(
    "\nOriginal Optimization-Shot Results:"
)


print(
    f"Maximum Optimized Value : "
    f"{maximum_value:.8f}"
)


print(
    f"Maximum Run             : "
    f"{maximum_run}"
)


print(
    f"Mean Optimized Value    : "
    f"{mean_value:.8f}"
)


print(
    f"Std Optimized Value     : "
    f"{std_value:.8f}"
)


# ------------------------------------------------------------
# High-Shot Evaluation Results
# ------------------------------------------------------------

print(
    "\nHigh-Shot Evaluation Results:"
)


print(
    f"Best Evaluated Mean     : "
    f"{maximum_evaluated_mean:.8f}"
)


print(
    f"Best Evaluated Mean Run : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Mean of Evaluated Means : "
    f"{mean_of_evaluated_means:.8f}"
)


print(
    f"Std of Evaluated Means  : "
    f"{std_of_evaluated_means:.8f}"
)


# ------------------------------------------------------------
# Optimizer Statistics
# ------------------------------------------------------------

print(
    "\nOptimizer Statistics:"
)


print(
    f"Mean Function Evals     : "
    f"{mean_nfev:.2f}"
)


print(
    f"Std Function Evals      : "
    f"{std_nfev:.2f}"
)


print(
    f"Successful Runs         : "
    f"{num_successful_runs}/"
    f"{num_times}"
)


print(
    f"Failed Runs             : "
    f"{num_failed_runs}/"
    f"{num_times}"
)


print(
    f"Reached MaxIter         : "
    f"{num_reached_maxiter}/"
    f"{num_times}"
)


# ------------------------------------------------------------
# Computational Runtime Statistics
# ------------------------------------------------------------

print(
    "\nComputational Runtime Statistics:"
)

print(
    f"Total Wall-Clock Time          : "
    f"{total_wall_time:.6f} s"
)

print(
    f"Total Optimization Time        : "
    f"{total_optimization_wall_time:.6f} s"
)

print(
    f"Time per Complete Opt. Run     : "
    f"{mean_optimization_wall_time:.6f} s"
)

print(
    f"Std Optimization Time per Run  : "
    f"{std_optimization_wall_time:.6f} s"
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "ORIGINAL OPTIMIZED VALUE"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        evaluation_values_all_runs[
            maximum_run_index
        ],
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_optimal_params,
        precision=10,
        separator=", "
    )
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "HIGH-SHOT EVALUATED MEAN"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        best_evaluated_values,
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_evaluated_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_evaluated_optimal_params,
        precision=10,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Save Report to TXT
# ============================================================

with open(
    report_filename,
    "w"
) as f:


    # ========================================================
    # Header
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "FINAL OPTIMIZATION AND "
        "HIGH-SHOT EVALUATION REPORT\n"
    )


    f.write(
        "=" * 100
        + "\n\n"
    )


    # ========================================================
    # Settings
    # ========================================================

    f.write(
        f"Optimizer               : "
        f"{optimizer_name}\n"
    )


    f.write(
        f"Tolerance               : "
        f"{tol_value}\n"
    )


    f.write(
        f"Max Iteration           : "
        f"{maxiter}\n"
    )


    f.write(
        f"Number of Runs          : "
        f"{num_times}\n"
    )


    f.write(
        f"Optimization Shots      : "
        f"{num_shots}\n"
    )


    f.write(
        f"Optimization Base Seed  : "
        f"{BASE_SEED}\n"
    )


    f.write(
        f"Evaluation Shots        : "
        f"{evaluation_num_shots}\n"
    )


    f.write(
        f"Evaluations Per Run     : "
        f"{evaluation_num_times}\n"
    )


    f.write(
        f"Evaluation Base Seed    : "
        f"{EVALUATION_BASE_SEED}\n"
    )


    # Evaluation seeds are saved only once.
    f.write(
        "Evaluation Seeds        : "
    )


    f.write(
        np.array2string(
            evaluation_seeds,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    # ========================================================
    # Results for Every Run
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "RESULTS FOR EACH RUN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    for i in range(num_times):


        f.write(
            f"\nRun {i + 1:2d}\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


        f.write(
            f"Optimization Seed : "
            f"{BASE_SEED + i}\n"
        )


        f.write(
            f"Optimized Value   : "
            f"{final_optimized_values[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Mean    : "
            f"{evaluation_mean_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Std     : "
            f"{evaluation_std_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Min     : "
            f"{evaluation_min_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Max     : "
            f"{evaluation_max_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Success           : "
            f"{optimization_success_all_runs[i]}\n"
        )


        f.write(
            f"Reached MaxIter   : "
            f"{reached_maxiter_all_runs[i]}\n"
        )


        f.write(
            f"Status            : "
            f"{optimization_status_all_runs[i]}\n"
        )


        f.write(
            f"Message           : "
            f"{optimization_message_all_runs[i]}\n"
        )


        f.write(
            f"Function Evals    : "
            f"{optimization_nfev_all_runs[i]}\n"
        )


        f.write(
            f"Optimization Time : "
            f"{optimization_wall_times[i]:.6f} s\n"
        )


        f.write(
            "\nEvaluated Values:\n"
        )


        f.write(
            np.array2string(
                evaluation_values_all_runs[i],
                precision=8,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nInitial Parameters:\n"
        )


        f.write(
            np.array2string(
                initial_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nOptimal Parameters:\n"
        )


        f.write(
            np.array2string(
                optimal_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


    # ========================================================
    # Summary
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "SUMMARY\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    # --------------------------------------------------------
    # Original Optimization Results
    # --------------------------------------------------------

    f.write(
        "\nOriginal Optimization-Shot Results:\n"
    )


    f.write(
        f"Maximum Optimized Value : "
        f"{maximum_value:.8f}\n"
    )


    f.write(
        f"Maximum Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Mean Optimized Value    : "
        f"{mean_value:.8f}\n"
    )


    f.write(
        f"Std Optimized Value     : "
        f"{std_value:.8f}\n"
    )


    # --------------------------------------------------------
    # High-Shot Evaluation Results
    # --------------------------------------------------------

    f.write(
        "\nHigh-Shot Evaluation Results:\n"
    )


    f.write(
        f"Best Evaluated Mean     : "
        f"{maximum_evaluated_mean:.8f}\n"
    )


    f.write(
        f"Best Evaluated Mean Run : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Mean of Evaluated Means : "
        f"{mean_of_evaluated_means:.8f}\n"
    )


    f.write(
        f"Std of Evaluated Means  : "
        f"{std_of_evaluated_means:.8f}\n"
    )


    # --------------------------------------------------------
    # Optimizer Statistics
    # --------------------------------------------------------

    f.write(
        "\nOptimizer Statistics:\n"
    )


    f.write(
        f"Mean Function Evals     : "
        f"{mean_nfev:.2f}\n"
    )


    f.write(
        f"Std Function Evals      : "
        f"{std_nfev:.2f}\n"
    )


    f.write(
        f"Successful Runs         : "
        f"{num_successful_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Failed Runs             : "
        f"{num_failed_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Reached MaxIter         : "
        f"{num_reached_maxiter}/"
        f"{num_times}\n"
    )


    # --------------------------------------------------------
    # Computational Runtime Statistics
    # --------------------------------------------------------

    f.write(
        "\nComputational Runtime Statistics:\n"
    )

    f.write(
        f"Total Wall-Clock Time          : "
        f"{total_wall_time:.6f} s\n"
    )

    f.write(
        f"Total Optimization Time        : "
        f"{total_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Time per Complete Opt. Run     : "
        f"{mean_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Std Optimization Time per Run  : "
        f"{std_optimization_wall_time:.6f} s\n"
    )


    # ========================================================
    # Best Run According to Original Optimized Value
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "ORIGINAL OPTIMIZED VALUE\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            evaluation_values_all_runs[
                maximum_run_index
            ],
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    # ========================================================
    # Best Run According to High-Shot Evaluated Mean
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "HIGH-SHOT EVALUATED MEAN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_values,
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


# ============================================================
# Report Location
# ============================================================

print(
    "\nReport saved to:"
)


print(
    os.path.abspath(
        report_filename
    )
)
# Out:
# ================================================================================
# Optimization Run 1/30
# Optimization Seed : 150
# ================================================================================
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566, 0.6883896757,
#  0.5848087428, 0.2739643248, 0.8377858251, 0.3022293541, 0.1728462164,
#  0.8017433668, 0.3441099205, 0.4375847094]
#
# Starting COBYLA optimization...
# success_probability = 0.33170000
# success_probability = 0.34440000
# success_probability = 0.33190000
# success_probability = 0.34670000
# success_probability = 0.34800000
# success_probability = 0.27280000
# success_probability = 0.35880000
# success_probability = 0.41540000
# success_probability = 0.42060000
# success_probability = 0.41730000
# success_probability = 0.41540000
# success_probability = 0.42060000
# success_probability = 0.42060000
# success_probability = 0.41780000
# success_probability = 0.42300000
# success_probability = 0.42460000
# success_probability = 0.42450000
# success_probability = 0.42150000
# success_probability = 0.41800000
# success_probability = 0.45120000
# success_probability = 0.43820000
# success_probability = 0.45340000
# success_probability = 0.44830000
# success_probability = 0.45340000
# success_probability = 0.45340000
# success_probability = 0.45370000
# success_probability = 0.45350000
# success_probability = 0.45370000
# success_probability = 0.45370000
# success_probability = 0.50080000
# success_probability = 0.53700000
# success_probability = 0.49360000
# success_probability = 0.59660000
# success_probability = 0.67500000
# success_probability = 0.64240000
# success_probability = 0.65460000
# success_probability = 0.70170000
# success_probability = 0.68090000
# success_probability = 0.73690000
# success_probability = 0.64070000
# success_probability = 0.73700000
# success_probability = 0.72870000
# success_probability = 0.73010000
# success_probability = 0.72380000
# success_probability = 0.73700000
# success_probability = 0.71460000
# success_probability = 0.73840000
# success_probability = 0.72310000
# success_probability = 0.73820000
# success_probability = 0.73670000
# success_probability = 0.73810000
# success_probability = 0.69100000
# success_probability = 0.73890000
# success_probability = 0.76080000
# success_probability = 0.76080000
# success_probability = 0.76090000
# success_probability = 0.76020000
# success_probability = 0.74800000
# success_probability = 0.76090000
# success_probability = 0.70830000
# success_probability = 0.74830000
# success_probability = 0.84630000
# success_probability = 0.77130000
# success_probability = 0.85160000
# success_probability = 0.82570000
# success_probability = 0.83570000
# success_probability = 0.82510000
# success_probability = 0.81070000
# success_probability = 0.86520000
# success_probability = 0.86170000
# success_probability = 0.83440000
# success_probability = 0.86200000
# success_probability = 0.77000000
# success_probability = 0.86520000
# success_probability = 0.86650000
# success_probability = 0.86540000
# success_probability = 0.77410000
# success_probability = 0.86080000
# success_probability = 0.83160000
# success_probability = 0.86650000
# success_probability = 0.87130000
# success_probability = 0.86450000
# success_probability = 0.81860000
# success_probability = 0.86860000
# success_probability = 0.85660000
# success_probability = 0.87130000
# success_probability = 0.84660000
# success_probability = 0.86940000
# success_probability = 0.85720000
# success_probability = 0.87140000
# success_probability = 0.79640000
# success_probability = 0.87960000
# success_probability = 0.86340000
# success_probability = 0.85410000
# success_probability = 0.86490000
# success_probability = 0.87710000
# success_probability = 0.84500000
# success_probability = 0.86480000
# success_probability = 0.84160000
# success_probability = 0.86540000
# success_probability = 0.82410000
# success_probability = 0.86960000
# success_probability = 0.87260000
# success_probability = 0.89110000
# success_probability = 0.89190000
# success_probability = 0.88670000
# success_probability = 0.88880000
# success_probability = 0.88070000
# success_probability = 0.89470000
# success_probability = 0.88570000
# success_probability = 0.89260000
# success_probability = 0.89050000
# success_probability = 0.89430000
# success_probability = 0.89380000
# success_probability = 0.89400000
# success_probability = 0.87950000
# success_probability = 0.89450000
# success_probability = 0.86980000
# success_probability = 0.89100000
# success_probability = 0.88210000
# success_probability = 0.89030000
# success_probability = 0.89280000
# success_probability = 0.89390000
# success_probability = 0.87890000
# success_probability = 0.89510000
# success_probability = 0.88040000
# success_probability = 0.89490000
# success_probability = 0.88490000
# success_probability = 0.89200000
# success_probability = 0.88950000
# success_probability = 0.89620000
# success_probability = 0.89880000
# success_probability = 0.89620000
# success_probability = 0.88820000
# success_probability = 0.89540000
# success_probability = 0.89810000
# success_probability = 0.89580000
# success_probability = 0.89970000
# success_probability = 0.89200000
# success_probability = 0.89620000
# success_probability = 0.89550000
# success_probability = 0.90000000
# success_probability = 0.89840000
# success_probability = 0.90000000
# success_probability = 0.90390000
# success_probability = 0.89970000
# success_probability = 0.90380000
# success_probability = 0.90450000
# success_probability = 0.90680000
# success_probability = 0.90620000
# success_probability = 0.90400000
# success_probability = 0.90840000
# success_probability = 0.90440000
# success_probability = 0.90810000
# success_probability = 0.90800000
# success_probability = 0.90780000
# success_probability = 0.90440000
# success_probability = 0.90650000
# success_probability = 0.90820000
# success_probability = 0.90720000
# success_probability = 0.90560000
# success_probability = 0.90650000
# success_probability = 0.90770000
# success_probability = 0.90620000
# success_probability = 0.90650000
# success_probability = 0.91010000
# success_probability = 0.90810000
# success_probability = 0.90900000
# success_probability = 0.90830000
# success_probability = 0.90980000
# success_probability = 0.90900000
# success_probability = 0.90920000
# success_probability = 0.91020000
# success_probability = 0.90670000
# success_probability = 0.90880000
# success_probability = 0.90880000
# success_probability = 0.90950000
# success_probability = 0.90910000
# success_probability = 0.90980000
# success_probability = 0.90970000
# success_probability = 0.91000000
# success_probability = 0.90930000
# success_probability = 0.91030000
# success_probability = 0.90910000
# success_probability = 0.90980000
# success_probability = 0.90840000
# success_probability = 0.90970000
# success_probability = 0.91050000
# success_probability = 0.91050000
# success_probability = 0.91070000
# success_probability = 0.91020000
# success_probability = 0.91050000
# success_probability = 0.91040000
# success_probability = 0.90900000
# success_probability = 0.91070000
# success_probability = 0.91060000
# success_probability = 0.91020000
# success_probability = 0.91070000
# success_probability = 0.90950000
# success_probability = 0.91030000
# success_probability = 0.91030000
# success_probability = 0.91140000
# success_probability = 0.91150000
# success_probability = 0.91130000
# success_probability = 0.91240000
# success_probability = 0.91250000
# success_probability = 0.91250000
# success_probability = 0.91210000
# success_probability = 0.91230000
# success_probability = 0.91230000
# success_probability = 0.91250000
# success_probability = 0.91180000
# success_probability = 0.91260000
# success_probability = 0.91200000
# success_probability = 0.91290000
# success_probability = 0.91250000
# success_probability = 0.91270000
# success_probability = 0.91280000
# success_probability = 0.91220000
# success_probability = 0.91260000
# success_probability = 0.91240000
# success_probability = 0.91230000
# success_probability = 0.91220000
# success_probability = 0.91200000
# success_probability = 0.91260000
# success_probability = 0.91200000
# success_probability = 0.91260000
# success_probability = 0.91190000
# success_probability = 0.91300000
# success_probability = 0.91270000
# success_probability = 0.91270000
# success_probability = 0.91180000
# success_probability = 0.91230000
# success_probability = 0.91250000
# success_probability = 0.91260000
# success_probability = 0.91260000
# success_probability = 0.91250000
# success_probability = 0.91280000
# success_probability = 0.91250000
# success_probability = 0.91290000
# success_probability = 0.91260000
# success_probability = 0.91270000
# success_probability = 0.91250000
# success_probability = 0.91250000
# success_probability = 0.91210000
# success_probability = 0.91280000
# success_probability = 0.91250000
# success_probability = 0.91270000
# success_probability = 0.91280000
# success_probability = 0.91260000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91300000
# success_probability = 0.91290000
# success_probability = 0.91300000
# success_probability = 0.91270000
# success_probability = 0.91300000
# success_probability = 0.91300000
# success_probability = 0.91300000
# success_probability = 0.91250000
# success_probability = 0.91290000
# success_probability = 0.91290000
# success_probability = 0.91300000
# success_probability = 0.91310000
# success_probability = 0.91290000
# success_probability = 0.91300000
# success_probability = 0.91300000
# success_probability = 0.91300000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91300000
# success_probability = 0.91300000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91280000
# success_probability = 0.91300000
# success_probability = 0.91300000
# success_probability = 0.91290000
# success_probability = 0.91280000
# success_probability = 0.91290000
# success_probability = 0.91310000
# success_probability = 0.91300000
# success_probability = 0.91300000
# success_probability = 0.91300000
# success_probability = 0.91310000
# success_probability = 0.91300000
# success_probability = 0.91300000
# success_probability = 0.91310000
# success_probability = 0.91300000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91300000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91300000
# success_probability = 0.91300000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91300000
# success_probability = 0.91310000
# success_probability = 0.91300000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# success_probability = 0.91310000
# Optimization Wall-Clock Time : 138.091792 s
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  477   F = 1.095170E+00    MAXCV = 0.000000E+00
#    X = 3.695770E-03  -2.191498E-02  -1.823395E-02   1.606469E+00  -1.142712E-01
#        2.987842E+00   3.169304E+00   2.981420E+00   1.225657E-02  -1.975104E-01
#        3.779966E-01   1.509714E+00   9.440928E-01   1.550820E+00   1.556045E+00
#        7.180480E-01   5.845154E-01   2.179705E-01   3.118587E+00   4.440945E-02
#        1.304753E+00  -1.301572E+00   4.784850E-01   4.972655E-02   9.320186E-01
#        5.458688E-02  -2.450499E-01   6.584013E-01
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.90743000
# Evaluation  2/20 | Value = 0.90743000
# Evaluation  3/20 | Value = 0.90744000
# Evaluation  4/20 | Value = 0.90744000
# Evaluation  5/20 | Value = 0.90744000
# Evaluation  6/20 | Value = 0.90744000
# Evaluation  7/20 | Value = 0.90744000
# Evaluation  8/20 | Value = 0.90744000
# Evaluation  9/20 | Value = 0.90744000
# Evaluation 10/20 | Value = 0.90744000
# Evaluation 11/20 | Value = 0.90744000
# Evaluation 12/20 | Value = 0.90744000
# Evaluation 13/20 | Value = 0.90744000
# Evaluation 14/20 | Value = 0.90744000
# Evaluation 15/20 | Value = 0.90744000
# Evaluation 16/20 | Value = 0.90744000
# Evaluation 17/20 | Value = 0.90744000
# Evaluation 18/20 | Value = 0.90744000
# Evaluation 19/20 | Value = 0.90744000
# Evaluation 20/20 | Value = 0.90744000
#
# ================================================================================
# RUN 1 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 1
# Message              : Optimization terminated successfully.
# Optimization Time    : 138.091792 s
# Function Evaluations : 477
# Final Objective Value: 1.0951702989814915
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.91310000
# Evaluated Mean        : 0.90743900
# Evaluated Std         : 0.00000300
# Evaluated Min         : 0.90743000
# Evaluated Max         : 0.90744000
#
# All Evaluated Values:
# [0.90743, 0.90743, 0.90744, 0.90744, 0.90744, 0.90744, 0.90744, 0.90744,
#  0.90744, 0.90744, 0.90744, 0.90744, 0.90744, 0.90744, 0.90744, 0.90744,
#  0.90744, 0.90744, 0.90744, 0.90744]
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566, 0.6883896757,
#  0.5848087428, 0.2739643248, 0.8377858251, 0.3022293541, 0.1728462164,
#  0.8017433668, 0.3441099205, 0.4375847094]
#
# Optimal Parameters:
# [ 0.0036957704, -0.0219149765, -0.0182339519,  1.6064690412, -0.114271161 ,
#   2.9878423405,  3.1693037601,  2.9814199093,  0.0122565659, -0.1975103832,
#   0.377996574 ,  1.5097141252,  0.9440928312,  1.5508198798,  1.5560453136,
#   0.7180480357,  0.5845154456,  0.2179705479,  3.118586939 ,  0.0444094538,
#   1.304753185 , -1.3015717007,  0.4784850445,  0.0497265451,  0.9320186297,
#   0.0545868783, -0.2450499283,  0.6584012726]
# ================================================================================
#
# ================================================================================
# Optimization Run 2/30
# Optimization Seed : 151
# ================================================================================
#
# Initial Parameters:
# [0.4917938425, 0.3601415032, 0.7094100488, 0.6895107167, 0.4723817514,
#  0.4790485592, 0.0068635273, 0.9044398512, 0.4337399476, 0.4736042839,
#  0.034330777 , 0.9496323674, 0.5907905652, 0.4241785512, 0.1868628067,
#  0.9840929216, 0.690221156 , 0.9039467044, 0.0207568308, 0.9969449281,
#  0.3143005034, 0.2098620446, 0.0173606056, 0.1892781313, 0.2905169378,
#  0.2743264362, 0.6422361978, 0.0963913748]
#
# Starting COBYLA optimization...
# success_probability = 0.34040000
# success_probability = 0.32190000
# success_probability = 0.34550000
# success_probability = 0.34400000
# success_probability = 0.34650000
# success_probability = 0.28730000
# success_probability = 0.31500000
# success_probability = 0.37080000
# success_probability = 0.41050000
# success_probability = 0.41480000
# success_probability = 0.42290000
# success_probability = 0.42290000
# success_probability = 0.42290000
# success_probability = 0.42760000
# success_probability = 0.42700000
# success_probability = 0.42790000
# success_probability = 0.42800000
# success_probability = 0.41530000
# success_probability = 0.43240000
# success_probability = 0.43380000
# success_probability = 0.43070000
# success_probability = 0.43380000
# success_probability = 0.43290000
# success_probability = 0.43380000
# success_probability = 0.43380000
# success_probability = 0.43450000
# success_probability = 0.43460000
# success_probability = 0.43460000
# success_probability = 0.43460000
# success_probability = 0.48570000
# success_probability = 0.54470000
# success_probability = 0.51410000
# success_probability = 0.55730000
# success_probability = 0.53990000
# success_probability = 0.55290000
# success_probability = 0.50120000
# success_probability = 0.54350000
# success_probability = 0.50520000
# success_probability = 0.55630000
# success_probability = 0.57070000
# success_probability = 0.57070000
# success_probability = 0.57730000
# success_probability = 0.57730000
# success_probability = 0.55690000
# success_probability = 0.53900000
# success_probability = 0.57090000
# success_probability = 0.57980000
# success_probability = 0.58650000
# success_probability = 0.58460000
# success_probability = 0.55690000
# success_probability = 0.59050000
# success_probability = 0.58170000
# success_probability = 0.59000000
# success_probability = 0.58710000
# success_probability = 0.59050000
# success_probability = 0.59540000
# success_probability = 0.59560000
# success_probability = 0.61410000
# success_probability = 0.61860000
# success_probability = 0.66160000
# success_probability = 0.63310000
# success_probability = 0.65150000
# success_probability = 0.72250000
# success_probability = 0.74590000
# success_probability = 0.74860000
# success_probability = 0.64330000
# success_probability = 0.72520000
# success_probability = 0.71560000
# success_probability = 0.75130000
# success_probability = 0.75910000
# success_probability = 0.75440000
# success_probability = 0.67720000
# success_probability = 0.75910000
# success_probability = 0.77960000
# success_probability = 0.77790000
# success_probability = 0.76990000
# success_probability = 0.77960000
# success_probability = 0.78130000
# success_probability = 0.77620000
# success_probability = 0.79110000
# success_probability = 0.78880000
# success_probability = 0.79060000
# success_probability = 0.78960000
# success_probability = 0.79480000
# success_probability = 0.79480000
# success_probability = 0.78730000
# success_probability = 0.79520000
# success_probability = 0.77050000
# success_probability = 0.75180000
# success_probability = 0.71960000
# success_probability = 0.83190000
# success_probability = 0.80980000
# success_probability = 0.78970000
# success_probability = 0.82070000
# success_probability = 0.84230000
# success_probability = 0.77300000
# success_probability = 0.80180000
# success_probability = 0.79650000
# success_probability = 0.83790000
# success_probability = 0.81140000
# success_probability = 0.79960000
# success_probability = 0.84330000
# success_probability = 0.84330000
# success_probability = 0.84980000
# success_probability = 0.83610000
# success_probability = 0.81330000
# success_probability = 0.84130000
# success_probability = 0.83590000
# success_probability = 0.84980000
# success_probability = 0.84500000
# success_probability = 0.85240000
# success_probability = 0.84630000
# success_probability = 0.85260000
# success_probability = 0.83590000
# success_probability = 0.85280000
# success_probability = 0.82110000
# success_probability = 0.86290000
# success_probability = 0.81570000
# success_probability = 0.86410000
# success_probability = 0.80930000
# success_probability = 0.84080000
# success_probability = 0.81350000
# success_probability = 0.85710000
# success_probability = 0.78930000
# success_probability = 0.83410000
# success_probability = 0.86410000
# success_probability = 0.86490000
# success_probability = 0.86520000
# success_probability = 0.85750000
# success_probability = 0.86170000
# success_probability = 0.86100000
# success_probability = 0.86190000
# success_probability = 0.87140000
# success_probability = 0.87140000
# success_probability = 0.86990000
# success_probability = 0.87070000
# success_probability = 0.86960000
# success_probability = 0.87130000
# success_probability = 0.87870000
# success_probability = 0.88220000
# success_probability = 0.88420000
# success_probability = 0.88440000
# success_probability = 0.87770000
# success_probability = 0.88790000
# success_probability = 0.89130000
# success_probability = 0.88940000
# success_probability = 0.89310000
# success_probability = 0.89350000
# success_probability = 0.87910000
# success_probability = 0.89360000
# success_probability = 0.88890000
# success_probability = 0.88580000
# success_probability = 0.87860000
# success_probability = 0.89350000
# success_probability = 0.90140000
# success_probability = 0.90140000
# success_probability = 0.88750000
# success_probability = 0.89020000
# success_probability = 0.87370000
# success_probability = 0.89930000
# success_probability = 0.88670000
# success_probability = 0.90460000
# success_probability = 0.89950000
# success_probability = 0.90950000
# success_probability = 0.89330000
# success_probability = 0.91090000
# success_probability = 0.91540000
# success_probability = 0.91540000
# success_probability = 0.90130000
# success_probability = 0.91060000
# success_probability = 0.90420000
# success_probability = 0.91470000
# success_probability = 0.90460000
# success_probability = 0.91180000
# success_probability = 0.91720000
# success_probability = 0.91240000
# success_probability = 0.90940000
# success_probability = 0.91510000
# success_probability = 0.90810000
# success_probability = 0.91610000
# success_probability = 0.89460000
# success_probability = 0.91310000
# success_probability = 0.90880000
# success_probability = 0.90740000
# success_probability = 0.91810000
# success_probability = 0.92360000
# success_probability = 0.92420000
# success_probability = 0.92560000
# success_probability = 0.92680000
# success_probability = 0.92490000
# success_probability = 0.92480000
# success_probability = 0.92500000
# success_probability = 0.92690000
# success_probability = 0.92600000
# success_probability = 0.92760000
# success_probability = 0.92450000
# success_probability = 0.92590000
# success_probability = 0.92280000
# success_probability = 0.92700000
# success_probability = 0.92230000
# success_probability = 0.92690000
# success_probability = 0.92650000
# success_probability = 0.92740000
# success_probability = 0.92850000
# success_probability = 0.92740000
# success_probability = 0.92770000
# success_probability = 0.92810000
# success_probability = 0.92930000
# success_probability = 0.92910000
# success_probability = 0.92560000
# success_probability = 0.93000000
# success_probability = 0.93410000
# success_probability = 0.93360000
# success_probability = 0.92800000
# success_probability = 0.93370000
# success_probability = 0.92870000
# success_probability = 0.93050000
# success_probability = 0.93350000
# success_probability = 0.93100000
# success_probability = 0.92950000
# success_probability = 0.93420000
# success_probability = 0.92840000
# success_probability = 0.93340000
# success_probability = 0.92830000
# success_probability = 0.93500000
# success_probability = 0.93140000
# success_probability = 0.93530000
# success_probability = 0.93370000
# success_probability = 0.93410000
# success_probability = 0.93130000
# success_probability = 0.93520000
# success_probability = 0.93320000
# success_probability = 0.93450000
# success_probability = 0.93750000
# success_probability = 0.93470000
# success_probability = 0.93370000
# success_probability = 0.93600000
# success_probability = 0.93650000
# success_probability = 0.93700000
# success_probability = 0.93450000
# success_probability = 0.93640000
# success_probability = 0.93670000
# success_probability = 0.93760000
# success_probability = 0.93450000
# success_probability = 0.93610000
# success_probability = 0.93140000
# success_probability = 0.93920000
# success_probability = 0.93870000
# success_probability = 0.93830000
# success_probability = 0.93830000
# success_probability = 0.93920000
# success_probability = 0.93810000
# success_probability = 0.93670000
# success_probability = 0.93830000
# success_probability = 0.93810000
# success_probability = 0.93800000
# success_probability = 0.93940000
# success_probability = 0.93850000
# success_probability = 0.93930000
# success_probability = 0.93810000
# success_probability = 0.93900000
# success_probability = 0.93950000
# success_probability = 0.93910000
# success_probability = 0.93890000
# success_probability = 0.93900000
# success_probability = 0.94170000
# success_probability = 0.94000000
# success_probability = 0.94080000
# success_probability = 0.94090000
# success_probability = 0.94070000
# success_probability = 0.94050000
# success_probability = 0.93950000
# success_probability = 0.94100000
# success_probability = 0.94030000
# success_probability = 0.94110000
# success_probability = 0.94260000
# success_probability = 0.94170000
# success_probability = 0.94060000
# success_probability = 0.94140000
# success_probability = 0.94260000
# success_probability = 0.94100000
# success_probability = 0.94230000
# success_probability = 0.94110000
# success_probability = 0.94240000
# success_probability = 0.94280000
# success_probability = 0.94390000
# success_probability = 0.94330000
# success_probability = 0.94400000
# success_probability = 0.94240000
# success_probability = 0.94430000
# success_probability = 0.94220000
# success_probability = 0.94310000
# success_probability = 0.94190000
# success_probability = 0.94300000
# success_probability = 0.94230000
# success_probability = 0.94360000
# success_probability = 0.94180000
# success_probability = 0.94340000
# success_probability = 0.94340000
# success_probability = 0.94410000
# success_probability = 0.94310000
# success_probability = 0.94460000
# success_probability = 0.94390000
# success_probability = 0.94340000
# success_probability = 0.94440000
# success_probability = 0.94350000
# success_probability = 0.94430000
# success_probability = 0.94410000
# success_probability = 0.94390000
# success_probability = 0.94270000
# success_probability = 0.94420000
# success_probability = 0.94340000
# success_probability = 0.94380000
# success_probability = 0.94490000
# success_probability = 0.94490000
# success_probability = 0.94420000
# success_probability = 0.94470000
# success_probability = 0.94400000
# success_probability = 0.94460000
# success_probability = 0.94470000
# success_probability = 0.94460000
# success_probability = 0.94510000
# success_probability = 0.94460000
# success_probability = 0.94490000
# success_probability = 0.94520000
# success_probability = 0.94560000
# success_probability = 0.94510000
# success_probability = 0.94500000
# success_probability = 0.94560000
# success_probability = 0.94550000
# success_probability = 0.94530000
# success_probability = 0.94510000
# success_probability = 0.94560000
# success_probability = 0.94500000
# success_probability = 0.94570000
# success_probability = 0.94570000
# success_probability = 0.94550000
# success_probability = 0.94500000
# success_probability = 0.94500000
# success_probability = 0.94520000
# success_probability = 0.94610000
# success_probability = 0.94620000
# success_probability = 0.94620000
# success_probability = 0.94460000
# success_probability = 0.94640000
# success_probability = 0.94610000
# success_probability = 0.94620000
# success_probability = 0.94520000
# success_probability = 0.94620000
# success_probability = 0.94530000
# success_probability = 0.94650000
# success_probability = 0.94610000
# success_probability = 0.94640000
# success_probability = 0.94560000
# success_probability = 0.94630000
# success_probability = 0.94630000
# success_probability = 0.94630000
# success_probability = 0.94640000
# success_probability = 0.94630000
# success_probability = 0.94650000
# success_probability = 0.94660000
# success_probability = 0.94680000
# success_probability = 0.94660000
# success_probability = 0.94680000
# success_probability = 0.94650000
# success_probability = 0.94670000
# success_probability = 0.94630000
# success_probability = 0.94660000
# success_probability = 0.94660000
# success_probability = 0.94680000
# success_probability = 0.94660000
# success_probability = 0.94670000
# success_probability = 0.94600000
# success_probability = 0.94660000
# success_probability = 0.94670000
# success_probability = 0.94680000
# success_probability = 0.94660000
# success_probability = 0.94700000
# success_probability = 0.94670000
# success_probability = 0.94690000
# success_probability = 0.94630000
# success_probability = 0.94680000
# success_probability = 0.94680000
# success_probability = 0.94700000
# success_probability = 0.94700000
# success_probability = 0.94650000
# success_probability = 0.94690000
# success_probability = 0.94690000
# success_probability = 0.94700000
# success_probability = 0.94720000
# success_probability = 0.94710000
# success_probability = 0.94610000
# success_probability = 0.94710000
# success_probability = 0.94700000
# success_probability = 0.94700000
# success_probability = 0.94690000
# success_probability = 0.94680000
# success_probability = 0.94680000
# success_probability = 0.94700000
# success_probability = 0.94680000
# success_probability = 0.94710000
# success_probability = 0.94690000
# success_probability = 0.94690000
# success_probability = 0.94690000
# success_probability = 0.94700000
# success_probability = 0.94700000
# success_probability = 0.94700000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94700000
# success_probability = 0.94700000
# success_probability = 0.94700000
# success_probability = 0.94710000
# success_probability = 0.94720000
# success_probability = 0.94710000
# success_probability = 0.94710000
# success_probability = 0.94720000
# success_probability = 0.94710000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94710000
# success_probability = 0.94710000
# success_probability = 0.94710000
# success_probability = 0.94710000
# success_probability = 0.94710000
# success_probability = 0.94720000
# success_probability = 0.94710000
# success_probability = 0.94710000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94710000
# success_probability = 0.94710000
# success_probability = 0.94710000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94710000
# success_probability = 0.94720000
# success_probability = 0.94710000
# success_probability = 0.94710000
# success_probability = 0.94720000
# success_probability = 0.94710000
# success_probability = 0.94720000
# success_probability = 0.94710000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94710000
# success_probability = 0.94720000
# success_probability = 0.94710000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94710000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94710000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# success_probability = 0.94720000
# Optimization Wall-Clock Time : 112.506936 s
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  625   F = 1.055743E+00    MAXCV = 0.000000E+00
#    X = 1.873113E-02   3.138188E+00   2.796628E-02   1.561969E+00   3.200940E+00
#       -5.323961E-02   3.140174E+00   3.174461E+00   6.550539E-01   5.296767E-01
#        1.784444E-01   9.938765E-01   2.343239E+00   1.537030E+00   5.593707E-01
#        7.524275E-01  -5.928949E-02   3.127762E+00   4.089212E-02   2.363807E+00
#        1.452080E+00   1.533603E-01  -2.624921E-02  -2.525052E-01   3.225866E-01
#        1.242678E+00  -1.531953E+00  -5.184937E-01
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.94478000
# Evaluation  2/20 | Value = 0.94478000
# Evaluation  3/20 | Value = 0.94478000
# Evaluation  4/20 | Value = 0.94478000
# Evaluation  5/20 | Value = 0.94479000
# Evaluation  6/20 | Value = 0.94479000
# Evaluation  7/20 | Value = 0.94479000
# Evaluation  8/20 | Value = 0.94479000
# Evaluation  9/20 | Value = 0.94479000
# Evaluation 10/20 | Value = 0.94479000
# Evaluation 11/20 | Value = 0.94479000
# Evaluation 12/20 | Value = 0.94479000
# Evaluation 13/20 | Value = 0.94479000
# Evaluation 14/20 | Value = 0.94479000
# Evaluation 15/20 | Value = 0.94479000
# Evaluation 16/20 | Value = 0.94479000
# Evaluation 17/20 | Value = 0.94479000
# Evaluation 18/20 | Value = 0.94479000
# Evaluation 19/20 | Value = 0.94479000
# Evaluation 20/20 | Value = 0.94479000
#
# ================================================================================
# RUN 2 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 1
# Message              : Optimization terminated successfully.
# Optimization Time    : 112.506936 s
# Function Evaluations : 625
# Final Objective Value: 1.0557432432432432
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.94720000
# Evaluated Mean        : 0.94478800
# Evaluated Std         : 0.00000400
# Evaluated Min         : 0.94478000
# Evaluated Max         : 0.94479000
#
# All Evaluated Values:
# [0.94478, 0.94478, 0.94478, 0.94478, 0.94479, 0.94479, 0.94479, 0.94479,
#  0.94479, 0.94479, 0.94479, 0.94479, 0.94479, 0.94479, 0.94479, 0.94479,
#  0.94479, 0.94479, 0.94479, 0.94479]
#
# Initial Parameters:
# [0.4917938425, 0.3601415032, 0.7094100488, 0.6895107167, 0.4723817514,
#  0.4790485592, 0.0068635273, 0.9044398512, 0.4337399476, 0.4736042839,
#  0.034330777 , 0.9496323674, 0.5907905652, 0.4241785512, 0.1868628067,
#  0.9840929216, 0.690221156 , 0.9039467044, 0.0207568308, 0.9969449281,
#  0.3143005034, 0.2098620446, 0.0173606056, 0.1892781313, 0.2905169378,
#  0.2743264362, 0.6422361978, 0.0963913748]
#
# Optimal Parameters:
# [ 0.0187311252,  3.1381880366,  0.0279662808,  1.5619692905,  3.2009395098,
#  -0.0532396053,  3.1401736782,  3.1744612255,  0.6550538544,  0.5296767176,
#   0.1784443719,  0.9938764942,  2.3432386421,  1.5370299899,  0.5593706574,
#   0.7524274842, -0.0592894898,  3.1277619239,  0.0408921228,  2.3638072637,
#   1.4520802549,  0.1533603059, -0.0262492117, -0.2525052305,  0.3225865953,
#   1.2426781008, -1.5319534333, -0.518493699 ]
# ================================================================================
#
# ================================================================================
# Optimization Run 3/30
# Optimization Seed : 152
# ================================================================================
#
# Initial Parameters:
# [0.2185327016, 0.2605845547, 0.0494520073, 0.5385992113, 0.5420706407,
#  0.7890536718, 0.9123372133, 0.3722628249, 0.3257754726, 0.6556609124,
#  0.8969863307, 0.6516960973, 0.7833870606, 0.8742393722, 0.1922236761,
#  0.610154332 , 0.9457183359, 0.8193944158, 0.2252887854, 0.5455987355,
#  0.8717491352, 0.8014303248, 0.0339990148, 0.0928109212, 0.7620745294,
#  0.7686826107, 0.119207887 , 0.1127172009]
#
# Starting COBYLA optimization...
# success_probability = 0.35840000
# success_probability = 0.37170000
# success_probability = 0.35120000
# success_probability = 0.37310000
# success_probability = 0.36840000
# success_probability = 0.28840000
# success_probability = 0.41540000
# success_probability = 0.48240000
# success_probability = 0.45950000
# success_probability = 0.48310000
# success_probability = 0.48130000
# success_probability = 0.48310000
# success_probability = 0.48310000
# success_probability = 0.48480000
# success_probability = 0.48290000
# success_probability = 0.48680000
# success_probability = 0.48290000
# success_probability = 0.49580000
# success_probability = 0.49200000
# success_probability = 0.50340000
# success_probability = 0.49360000
# success_probability = 0.50320000
# success_probability = 0.50170000
# success_probability = 0.50340000
# success_probability = 0.50340000
# success_probability = 0.50440000
# success_probability = 0.50230000
# success_probability = 0.50440000
# success_probability = 0.50440000
# success_probability = 0.56180000
# success_probability = 0.61130000
# success_probability = 0.57540000
# success_probability = 0.60980000
# success_probability = 0.60960000
# success_probability = 0.57750000
# success_probability = 0.56450000
# success_probability = 0.60630000
# success_probability = 0.58730000
# success_probability = 0.61530000
# success_probability = 0.61900000
# success_probability = 0.61530000
# success_probability = 0.60710000
# success_probability = 0.61900000
# success_probability = 0.61820000
# success_probability = 0.61900000
# success_probability = 0.63280000
# success_probability = 0.63460000
# success_probability = 0.61980000
# success_probability = 0.63410000
# success_probability = 0.59830000
# success_probability = 0.63210000
# success_probability = 0.61500000
# success_probability = 0.63450000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63470000
# success_probability = 0.63750000
# success_probability = 0.62760000
# success_probability = 0.62380000
# success_probability = 0.61140000
# success_probability = 0.57510000
# success_probability = 0.65890000
# success_probability = 0.64930000
# success_probability = 0.68340000
# success_probability = 0.67200000
# success_probability = 0.53300000
# success_probability = 0.67900000
# success_probability = 0.62200000
# success_probability = 0.67680000
# success_probability = 0.66190000
# success_probability = 0.68510000
# success_probability = 0.68080000
# ...
# Evaluated Mean    : 0.79515300
# Evaluated Std     : 0.00000781
# Evaluated Min     : 0.79513000
# Evaluated Max     : 0.79516000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 602
# Optimization Time : 127.885626 s
#
# Evaluated Values:
# [0.79515, 0.79515, 0.79515, 0.79515, 0.79516, 0.79515, 0.79515, 0.79515,
#  0.79516, 0.79516, 0.79516, 0.79516, 0.79516, 0.79516, 0.79516, 0.79516,
#  0.79515, 0.79515, 0.79514, 0.79513]
#
# Initial Parameters:
# [0.0683064102, 0.5061877572, 0.2800764934, 0.4917358842, 0.3376481488,
#  0.6337766115, 0.7941202296, 0.2237709719, 0.8893153608, 0.9462072178,
#  0.9270749557, 0.8979372613, 0.8865232604, 0.1112901922, 0.4404611446,
#  0.6571269562, 0.6018173982, 0.0668305069, 0.5031888045, 0.7100940384,
#  0.3646853666, 0.6647653187, 0.3408936761, 0.3312253256, 0.7714370826,
#  0.2269448353, 0.0303235797, 0.6383902153]
#
# Optimal Parameters:
# [ 1.9099867287,  0.0145341898,  0.0064192825,  0.7404818293,  0.3289070026,
#   3.1442724153,  3.2239542067, -0.0330915557,  2.3790773996,  2.7907008604,
#   0.8740293032,  0.8038562757,  1.582008557 ,  1.5291192038,  1.5688055257,
#   0.2468631932,  3.1493048809, -0.0420827853,  2.934182482 , -0.0481450765,
#   1.4101942837,  1.3207977902, -0.0777349833, -0.5820475622,  1.8927634579,
#  -0.1213810194,  0.5226077702,  0.5007658658]
# ----------------------------------------------------------------------------------------------------
#
# Run 25
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 174
# Optimized Value   : 0.91480000
# Evaluated Mean    : 0.90997350
# Evaluated Std     : 0.00000726
# Evaluated Min     : 0.90996000
# Evaluated Max     : 0.90998000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 532
# Optimization Time : 118.841101 s
#
# Evaluated Values:
# [0.90998, 0.90998, 0.90998, 0.90998, 0.90998, 0.90998, 0.90998, 0.90998,
#  0.90998, 0.90998, 0.90997, 0.90997, 0.90997, 0.90997, 0.90997, 0.90997,
#  0.90997, 0.90996, 0.90996, 0.90996]
#
# Initial Parameters:
# [0.920751175 , 0.8324481628, 0.9226421153, 0.4120178702, 0.112899878 ,
#  0.539662511 , 0.9690640438, 0.8958288503, 0.8463732302, 0.6837088366,
#  0.0134777936, 0.9213092468, 0.0585796685, 0.528523907 , 0.4212992395,
#  0.8064657524, 0.2081509804, 0.1492170041, 0.0586840123, 0.6381376407,
#  0.7175421339, 0.7259671078, 0.0347409726, 0.8317209152, 0.1893140181,
#  0.5873066532, 0.6508822385, 0.1541344136]
#
# Optimal Parameters:
# [-0.0373559596, -0.0076406729,  0.0380092041,  1.5344635172, -0.0951574869,
#   3.0846570511,  3.0732097524,  3.1827330465,  3.1048866891,  0.3888392888,
#   0.1671654997,  1.1784404552,  0.8175600795,  1.6065555848, -0.7521518176,
#   1.5419928958,  0.5359551229, -0.0451404258,  3.1524780605, -0.0081242764,
#   0.2647752111,  0.2697782636,  0.4145234446,  0.4914664938,  2.0245565438,
#   1.924447235 , -0.4498679755,  0.2312672483]
# ----------------------------------------------------------------------------------------------------
#
# Run 26
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 175
# Optimized Value   : 0.94970000
# Evaluated Mean    : 0.94513800
# Evaluated Std     : 0.00000400
# Evaluated Min     : 0.94513000
# Evaluated Max     : 0.94514000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 492
# Optimization Time : 95.368527 s
#
# Evaluated Values:
# [0.94513, 0.94513, 0.94513, 0.94513, 0.94514, 0.94514, 0.94514, 0.94514,
#  0.94514, 0.94514, 0.94514, 0.94514, 0.94514, 0.94514, 0.94514, 0.94514,
#  0.94514, 0.94514, 0.94514, 0.94514]
#
# Initial Parameters:
# [0.5632800098, 0.5263460088, 0.074383608 , 0.0432472297, 0.1116614549,
#  0.3149336925, 0.8051899849, 0.2265811498, 0.2507577735, 0.3247400132,
#  0.7132637608, 0.7744654451, 0.9295185054, 0.8709503245, 0.9380278462,
#  0.6231528096, 0.2419077457, 0.8799737511, 0.1804762542, 0.8020908004,
#  0.3363522676, 0.2884964572, 0.5552697615, 0.8113197998, 0.1117050081,
#  0.04623727  , 0.2558624663, 0.3513980154]
#
# Optimal Parameters:
# [ 1.7359056287e-03, -3.4210809605e-02, -2.6486109450e-02,
#   1.5334741284e+00,  5.0432823957e-02,  3.2968122255e+00,
#   3.1926252446e+00,  3.0971317027e+00,  5.2358424629e-01,
#  -1.1718188597e+00,  1.4085797793e+00,  7.7465382407e-01,
#   7.2586897807e-01,  1.6165844597e+00,  1.1765516543e+00,
#  -1.1608189813e+00,  2.6521416947e+00,  3.9198036479e-01,
#   3.1162801320e+00,  1.0479166885e-02,  4.5307522416e-01,
#  -2.7598296360e-01,  2.3433540320e-01, -7.0334769469e-01,
#   9.3893188016e-02, -1.4417233033e-01,  7.6068928827e-01,
#   5.2033887637e-01]
# ----------------------------------------------------------------------------------------------------
#
# Run 27
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 176
# Optimized Value   : 0.95420000
# Evaluated Mean    : 0.95088800
# Evaluated Std     : 0.00000400
# Evaluated Min     : 0.95088000
# Evaluated Max     : 0.95089000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 505
# Optimization Time : 96.109218 s
#
# Evaluated Values:
# [0.95088, 0.95088, 0.95088, 0.95088, 0.95089, 0.95089, 0.95089, 0.95089,
#  0.95089, 0.95089, 0.95089, 0.95089, 0.95089, 0.95089, 0.95089, 0.95089,
#  0.95089, 0.95089, 0.95089, 0.95089]
#
# Initial Parameters:
# [0.908796571 , 0.1480812304, 0.9316217524, 0.8690627692, 0.8218723273,
#  0.3598173853, 0.8198721198, 0.1817033926, 0.2126209616, 0.6959983996,
#  0.3659168242, 0.6449720995, 0.1945739112, 0.1231941489, 0.9608135811,
#  0.9693122607, 0.6994862206, 0.3285305578, 0.5308429614, 0.0713595069,
#  0.6124682681, 0.0173357401, 0.2291752338, 0.1716368198, 0.7904109494,
#  0.6764072798, 0.8677348266, 0.5559777189]
#
# Optimal Parameters:
# [ 3.1807115524e+00, -3.8132930503e-02,  3.5356089616e-02,
#   1.5572817653e+00,  3.1455458370e+00,  3.1768345392e+00,
#   3.2325289009e+00,  1.3509825044e-02,  1.5108331308e+00,
#   4.4207557085e-01,  1.0825267938e+00,  4.0448949435e-01,
#   7.7289011723e-01,  1.5579752468e+00,  5.1151626209e-01,
#   1.2823600766e+00,  3.1332098408e+00,  1.1224811965e-04,
#   3.1150567376e+00, -5.9647728995e-02,  2.2847196429e+00,
#   1.6487803630e+00,  2.4156639690e-01, -1.7292916614e-01,
#   1.0850155508e+00,  3.2479140653e-01,  6.6764080182e-01,
#  -9.8528885264e-01]
# ----------------------------------------------------------------------------------------------------
#
# Run 28
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 177
# Optimized Value   : 0.81350000
# Evaluated Mean    : 0.79707900
# Evaluated Std     : 0.00001136
# Evaluated Min     : 0.79706000
# Evaluated Max     : 0.79709000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 494
# Optimization Time : 103.033357 s
#
# Evaluated Values:
# [0.79706, 0.79706, 0.79706, 0.79706, 0.79707, 0.79707, 0.79708, 0.79708,
#  0.79709, 0.79709, 0.79709, 0.79709, 0.79709, 0.79709, 0.79709, 0.79709,
#  0.79708, 0.79708, 0.79708, 0.79708]
#
# Initial Parameters:
# [0.4859979492, 0.3134855983, 0.5928545916, 0.5388495959, 0.8208222388,
#  0.1681699936, 0.7886708539, 0.9073399324, 0.1513191786, 0.6385598502,
#  0.0204482374, 0.441729694 , 0.1062169866, 0.3316953766, 0.9856944419,
#  0.4606017013, 0.291802071 , 0.5311775661, 0.6869978953, 0.085870002 ,
#  0.70379701  , 0.7732596263, 0.358077326 , 0.7448635381, 0.5398799816,
#  0.6518199474, 0.496504845 , 0.729372615 ]
#
# Optimal Parameters:
# [ 0.027240171 ,  0.8452546009,  0.2448022991,  1.5566733645, -0.0485715764,
#  -0.2765267987,  3.0520164637,  3.0391611312,  0.9481783239,  0.2218634009,
#   0.0857824185,  0.0632972174, -0.0276638364,  1.5385292424,  1.4120977404,
#   0.1182688491,  0.3284933408,  1.4029247869,  3.1158156923,  0.0047219203,
#   1.229434372 ,  0.0857160811, -0.4179458096,  0.7564209393,  0.2922937158,
#  -0.1283812404, -0.0777352145,  0.6793577657]
# ----------------------------------------------------------------------------------------------------
#
# Run 29
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 178
# Optimized Value   : 0.95050000
# Evaluated Mean    : 0.94670800
# Evaluated Std     : 0.00000400
# Evaluated Min     : 0.94670000
# Evaluated Max     : 0.94671000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 516
# Optimization Time : 102.150289 s
#
# Evaluated Values:
# [0.9467 , 0.9467 , 0.9467 , 0.9467 , 0.94671, 0.94671, 0.94671, 0.94671,
#  0.94671, 0.94671, 0.94671, 0.94671, 0.94671, 0.94671, 0.94671, 0.94671,
#  0.94671, 0.94671, 0.94671, 0.94671]
#
# Initial Parameters:
# [0.7608275692, 0.0464101376, 0.0032708871, 0.7605003536, 0.2769531808,
#  0.5945503444, 0.8036218146, 0.7402677744, 0.1239034672, 0.2438968692,
#  0.748428843 , 0.9205783868, 0.2357355697, 0.9391032789, 0.4081091944,
#  0.4620759117, 0.7294079941, 0.5779372506, 0.3477807167, 0.9240071009,
#  0.4847679255, 0.9369591861, 0.6895419866, 0.4903610315, 0.1782447546,
#  0.0915727898, 0.6053767128, 0.8164664622]
#
# Optimal Parameters:
# [ 1.0269988787e-02, -1.5553863350e-02,  1.8360704349e-03,
#   1.6075216211e+00, -7.5467226982e-03,  3.1484342586e+00,
#   3.2904178510e+00,  3.0778489979e+00,  1.4322848234e+00,
#  -9.7133641112e-01,  8.6187965354e-01,  1.1842455341e+00,
#   8.1191131418e-01,  1.6286126634e+00,  3.9357216208e-01,
#  -5.7311709563e-01,  2.7565290095e+00,  3.4506629577e-01,
#   3.1785990695e+00, -1.8026910448e-02, -3.3529947291e-01,
#  -2.1479016018e-01,  1.0152313580e+00,  1.6393091191e+00,
#   1.7898286747e+00, -4.1201300715e-03, -2.4724105459e-01,
#   5.7654170265e-01]
# ----------------------------------------------------------------------------------------------------
#
# Run 30
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 179
# Optimized Value   : 0.81400000
# Evaluated Mean    : 0.79688350
# Evaluated Std     : 0.00001195
# Evaluated Min     : 0.79686000
# Evaluated Max     : 0.79690000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 532
# Optimization Time : 100.966060 s
#
# Evaluated Values:
# [0.79687, 0.79687, 0.79687, 0.79687, 0.79688, 0.79688, 0.79689, 0.79689,
#  0.7969 , 0.7969 , 0.7969 , 0.7969 , 0.79689, 0.79689, 0.79689, 0.79689,
#  0.79688, 0.79688, 0.79687, 0.79686]
#
# Initial Parameters:
# [0.9180695286, 0.9403935557, 0.9611445873, 0.1282735573, 0.7343854482,
#  0.1418537547, 0.3206870255, 0.8783134777, 0.3925501756, 0.9542827898,
#  0.4333144504, 0.0052152104, 0.5921889116, 0.318609756 , 0.9316370681,
#  0.6026668473, 0.0078690534, 0.7991305598, 0.851774691 , 0.06652901  ,
#  0.7310172927, 0.1064287992, 0.0810809173, 0.7115609048, 0.7069595409,
#  0.496652521 , 0.9897356485, 0.1231137075]
#
# Optimal Parameters:
# [-0.032563272 ,  3.6920617448,  1.310375148 ,  1.5646813246,  0.0305821642,
#  -0.0340670903,  3.0962925127,  3.0711334744,  1.2514854556,  2.7321053455,
#   0.4217864693,  0.0316009896, -0.0059860756,  1.5081333214,  1.7547765378,
#  -0.2673861219,  0.9788035622,  0.4803487721,  3.093128598 , -0.0685697105,
#   0.9557272494,  0.7839480157, -0.534518944 ,  1.7128615289,  0.2483404338,
#   0.4206521239,  0.0942748388, -0.7246880081]
# ----------------------------------------------------------------------------------------------------
#
# SUMMARY
# ====================================================================================================
#
# Original Optimization-Shot Results:
# Maximum Optimized Value : 0.95420000
# Maximum Run             : 27
# Mean Optimized Value    : 0.89849333
# Std Optimized Value     : 0.07884073
#
# High-Shot Evaluation Results:
# Best Evaluated Mean     : 0.95088800
# Best Evaluated Mean Run : 27
# Mean of Evaluated Means : 0.89143593
# Std of Evaluated Means  : 0.08311332
#
# Optimizer Statistics:
# Mean Function Evals     : 560.07
# Std Function Evals      : 54.23
# Successful Runs         : 30/30
# Failed Runs             : 0/30
# Reached MaxIter         : 0/30
#
# Computational Runtime Statistics:
# Total Wall-Clock Time          : 3552.893883 s
# Total Optimization Time        : 2959.383873 s
# Time per Complete Opt. Run     : 98.646129 s
# Std Optimization Time per Run  : 15.665061 s
#
# ====================================================================================================
# BEST RUN ACCORDING TO ORIGINAL OPTIMIZED VALUE
# ====================================================================================================
# Run             : 27
# Optimized Value : 0.95420000
# Evaluated Mean  : 0.95088800
# Evaluated Std   : 0.00000400
# Evaluated Min   : 0.95088000
# Evaluated Max   : 0.95089000
#
# Evaluated Values:
# [0.95088, 0.95088, 0.95088, 0.95088, 0.95089, 0.95089, 0.95089, 0.95089,
#  0.95089, 0.95089, 0.95089, 0.95089, 0.95089, 0.95089, 0.95089, 0.95089,
#  0.95089, 0.95089, 0.95089, 0.95089]
#
# Initial Parameters:
# [0.908796571 , 0.1480812304, 0.9316217524, 0.8690627692, 0.8218723273,
#  0.3598173853, 0.8198721198, 0.1817033926, 0.2126209616, 0.6959983996,
#  0.3659168242, 0.6449720995, 0.1945739112, 0.1231941489, 0.9608135811,
#  0.9693122607, 0.6994862206, 0.3285305578, 0.5308429614, 0.0713595069,
#  0.6124682681, 0.0173357401, 0.2291752338, 0.1716368198, 0.7904109494,
#  0.6764072798, 0.8677348266, 0.5559777189]
#
# Optimal Parameters:
# [ 3.1807115524e+00, -3.8132930503e-02,  3.5356089616e-02,
#   1.5572817653e+00,  3.1455458370e+00,  3.1768345392e+00,
#   3.2325289009e+00,  1.3509825044e-02,  1.5108331308e+00,
#   4.4207557085e-01,  1.0825267938e+00,  4.0448949435e-01,
#   7.7289011723e-01,  1.5579752468e+00,  5.1151626209e-01,
#   1.2823600766e+00,  3.1332098408e+00,  1.1224811965e-04,
#   3.1150567376e+00, -5.9647728995e-02,  2.2847196429e+00,
#   1.6487803630e+00,  2.4156639690e-01, -1.7292916614e-01,
#   1.0850155508e+00,  3.2479140653e-01,  6.6764080182e-01,
#  -9.8528885264e-01]
#
# ====================================================================================================
# BEST RUN ACCORDING TO HIGH-SHOT EVALUATED MEAN
# ====================================================================================================
# Run             : 27
# Optimized Value : 0.95420000
# Evaluated Mean  : 0.95088800
# Evaluated Std   : 0.00000400
# Evaluated Min   : 0.95088000
# Evaluated Max   : 0.95089000
#
# Evaluated Values:
# [0.95088, 0.95088, 0.95088, 0.95088, 0.95089, 0.95089, 0.95089, 0.95089,
#  0.95089, 0.95089, 0.95089, 0.95089, 0.95089, 0.95089, 0.95089, 0.95089,
#  0.95089, 0.95089, 0.95089, 0.95089]
#
# Initial Parameters:
# [0.908796571 , 0.1480812304, 0.9316217524, 0.8690627692, 0.8218723273,
#  0.3598173853, 0.8198721198, 0.1817033926, 0.2126209616, 0.6959983996,
#  0.3659168242, 0.6449720995, 0.1945739112, 0.1231941489, 0.9608135811,
#  0.9693122607, 0.6994862206, 0.3285305578, 0.5308429614, 0.0713595069,
#  0.6124682681, 0.0173357401, 0.2291752338, 0.1716368198, 0.7904109494,
#  0.6764072798, 0.8677348266, 0.5559777189]
#
# Optimal Parameters:
# [ 3.1807115524e+00, -3.8132930503e-02,  3.5356089616e-02,
#   1.5572817653e+00,  3.1455458370e+00,  3.1768345392e+00,
#   3.2325289009e+00,  1.3509825044e-02,  1.5108331308e+00,
#   4.4207557085e-01,  1.0825267938e+00,  4.0448949435e-01,
#   7.7289011723e-01,  1.5579752468e+00,  5.1151626209e-01,
#   1.2823600766e+00,  3.1332098408e+00,  1.1224811965e-04,
#   3.1150567376e+00, -5.9647728995e-02,  2.2847196429e+00,
#   1.6487803630e+00,  2.4156639690e-01, -1.7292916614e-01,
#   1.0850155508e+00,  3.2479140653e-01,  6.6764080182e-01,
#  -9.8528885264e-01]
# ====================================================================================================
#
# Report saved to:
# /Users/sungwonyun/Documents/Qiskit/Minimum Error Discrimination/Simulator Seed 150 ReRe /DT_Hybrid_report.txt
