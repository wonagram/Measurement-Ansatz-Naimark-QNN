# %%
# 0,1: 00 for psi_1, 01 for psi_2 ...
# 2: For states
# 3,4: Ancillary qubits

# when theta = 32.56... 
# psi_1 = |0> 
# psi_2 = sqrt(2/3)|0> + sqrt(1/3)|1>
# psi_3 = sqrt(2/3)|0> - sqrt(1/3)|1>

# %%
from qiskit import QuantumCircuit, ClassicalRegister
from numpy import sqrt, array
from numpy.linalg import norm

def circuit_init():
    qc = QuantumCircuit(5)
    return qc

def PREP(qc):
    desired_vector = [sqrt(1/3), 0, sqrt(2)/3, 1/3, sqrt(2)/3, -1/3, 0, 0]
    qc.initialize(desired_vector, [2,1,0])
    return qc

def Ansatz(qc, wires, num_layers, params):
    for i in range(num_layers):
        qc.barrier()
        offset = 6 * i
        qc.rx(params[offset + 0], wires[0])
        qc.rz(params[offset + 1], wires[0])
        qc.rx(params[offset + 2], wires[1])
        qc.rz(params[offset + 3], wires[1])
        qc.rx(params[offset + 4], wires[2])
        qc.rz(params[offset + 5], wires[2])
        qc.cx(wires[0], wires[1])
        qc.cx(wires[1], wires[2])
        qc.cx(wires[2], wires[0])
    qc.measure_all()

    return qc

# %%
from numpy.random import rand
num_layers=4
num_params= 6*num_layers
params = list(range(num_params))
num_shots=10000

qc = circuit_init()
qc = PREP(qc)
Ansatz(qc, [2,3,4] , num_layers, params)

qc.draw(output='mpl', style = 'clifford') 
#qc_reversed=qc.reverse_bits()
#qc_reversed.draw(output='mpl',style = 'clifford')

# %%
from qiskit_aer import AerSimulator
from qiskit import transpile
from scipy.optimize import minimize

import numpy as np
import os
import time


# ============================================================
# Simulator
# ============================================================

aersim = AerSimulator()


# ============================================================
# Settings
# ============================================================

num_times = 30
num_shots = 10000

optimizer_name = "COBYLA"
tol_value = 1e-8
maxiter = 1000

BASE_SEED = 150

num_layers = 3

report_filename = (
    "Sym_QNN_CB_report.txt"
)


# ============================================================
# High-Shot Evaluation Settings
# ============================================================

evaluation_num_times = 20
evaluation_num_shots = 100000

EVALUATION_BASE_SEED = 10000

evaluation_seeds = np.array(
    [
        EVALUATION_BASE_SEED + i
        for i in range(evaluation_num_times)
    ],
    dtype=int
)


# ============================================================
# Storage
# ============================================================

final_optimized_values = []

initial_params_all_runs = []
optimal_params_all_runs = []

optimization_success_all_runs = []
optimization_status_all_runs = []
optimization_message_all_runs = []
optimization_nfev_all_runs = []
reached_maxiter_all_runs = []

# ------------------------------------------------------------
# Runtime Storage
# ------------------------------------------------------------

optimization_wall_times = []


# ------------------------------------------------------------
# High-Shot Evaluation Storage
# ------------------------------------------------------------

evaluation_values_all_runs = []

evaluation_mean_all_runs = []
evaluation_std_all_runs = []
evaluation_sem_all_runs = []

evaluation_min_all_runs = []
evaluation_max_all_runs = []


# ============================================================
# Objective Function
# ============================================================

def objective_function(
    params,
    run_seed,
    shots=None,
    print_result=True
):

    if shots is None:
        shots = num_shots


    # --------------------------------------------------------
    # Construct circuit
    # --------------------------------------------------------

    qc = circuit_init()

    PREP(qc)

    Ansatz(
        qc,
        wires=[2, 3, 4],
        num_layers=num_layers,
        params=params
    )


    qc_reverse = qc.reverse_bits()


    # --------------------------------------------------------
    # Transpile
    # --------------------------------------------------------

    t_qc = transpile(
        qc_reverse,
        aersim,
        seed_transpiler=run_seed
    )


    # --------------------------------------------------------
    # Run simulator
    # --------------------------------------------------------

    job = aersim.run(
        t_qc,
        shots=shots,
        seed_simulator=run_seed
    )


    result = job.result()

    counts = result.get_counts()


    # --------------------------------------------------------
    # Target counts
    # --------------------------------------------------------

    tar_00 = 0
    tar_01 = 0
    tar_10 = 0


    for outcome, count in counts.items():

        if outcome[0:2] == "00":

            if outcome[3:5] == "00":

                tar_00 += count


        if outcome[0:2] == "01":

            if outcome[3:5] == "01":

                tar_01 += count


        if outcome[0:2] == "10":

            if outcome[3:5] == "10":

                tar_10 += count


    # --------------------------------------------------------
    # Success probability
    # --------------------------------------------------------

    p_suc = (
        tar_00
        + tar_01
        + tar_10
    ) / shots


    if print_result:

        print(
            f"success_probability = "
            f"{p_suc:.8f}"
        )


    # --------------------------------------------------------
    # Avoid division by zero
    # --------------------------------------------------------

    if p_suc == 0:

        return 1e10


    # --------------------------------------------------------
    # COBYLA minimizes.
    #
    # Minimizing 1 / p_suc maximizes p_suc.
    # --------------------------------------------------------

    return 1.0 / p_suc


# ============================================================
# Run Optimization
# ============================================================

# Total wall-clock time for the complete workflow:
# optimization + final evaluations + high-shot evaluations + overhead.
total_wall_start = time.perf_counter()

for run in range(num_times):


    # ========================================================
    # Optimization Seed
    # ========================================================

    run_seed = (
        BASE_SEED + run
    )


    rng = np.random.default_rng(
        run_seed
    )


    print(
        "\n"
        + "=" * 80
    )


    print(
        f"Optimization Run "
        f"{run + 1}/{num_times}"
    )


    print(
        f"Optimization Seed : "
        f"{run_seed}"
    )


    print(
        "=" * 80
    )


    # ========================================================
    # Generate Random Initial Parameters
    # ========================================================

    initial_params = rng.random(
        num_params
    )


    initial_params_all_runs.append(
        initial_params.copy()
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    # ========================================================
    # Run COBYLA Optimization
    # ========================================================

    print(
        "\nStarting COBYLA optimization..."
    )


    optimization_start = time.perf_counter()

    result = minimize(

        fun=lambda params: objective_function(
            params,
            run_seed,
            shots=num_shots,
            print_result=True
        ),

        x0=initial_params,

        method=optimizer_name,

        options={
            "maxiter": maxiter,
            "disp": True,
            "tol": tol_value
        }
    )

    optimization_end = time.perf_counter()

    run_optimization_wall_time = (
        optimization_end
        - optimization_start
    )

    optimization_wall_times.append(
        run_optimization_wall_time
    )


    # ========================================================
    # Optimization Status
    # ========================================================

    optimization_success = bool(
        result.success
    )


    optimization_status = getattr(
        result,
        "status",
        None
    )


    optimization_message = str(
        getattr(
            result,
            "message",
            "No message returned"
        )
    )


    optimization_nfev = getattr(
        result,
        "nfev",
        None
    )


    # ========================================================
    # Detect Whether Maximum Evaluations Was Reached
    # ========================================================

    message_lower = (
        optimization_message.lower()
    )


    reached_maxiter = (

        "maximum number"
        in message_lower

        or "maximum function"
        in message_lower

        or "maxiter"
        in message_lower

        or "maxfun"
        in message_lower

        or "maximum iterations"
        in message_lower

        or "maximum evaluations"
        in message_lower
    )


    if optimization_nfev is not None:

        if optimization_nfev >= maxiter:

            reached_maxiter = True


    # ========================================================
    # Store Optimization Status
    # ========================================================

    optimization_success_all_runs.append(
        optimization_success
    )


    optimization_status_all_runs.append(
        optimization_status
    )


    optimization_message_all_runs.append(
        optimization_message
    )


    optimization_nfev_all_runs.append(
        optimization_nfev
    )


    reached_maxiter_all_runs.append(
        reached_maxiter
    )


    # ========================================================
    # Optimal Parameters
    # ========================================================

    optimal_params = (
        result.x.copy()
    )


    optimal_params_all_runs.append(
        optimal_params.copy()
    )


    # ========================================================
    # Final Optimization-Shot Evaluation
    # ========================================================

    final_objective = objective_function(
        optimal_params,
        run_seed,
        shots=num_shots,
        print_result=False
    )


    if final_objective >= 1e10:

        final_value = 0.0

    else:

        final_value = (
            1.0 / final_objective
        )


    final_optimized_values.append(
        final_value
    )


    # ========================================================
    # High-Shot Evaluation
    # ========================================================

    print(
        "\n"
        + "-" * 80
    )


    print(
        "HIGH-SHOT EVALUATION OF "
        "OPTIMIZED PARAMETERS"
    )


    print(
        "-" * 80
    )


    print(
        f"Optimization Shots     : "
        f"{num_shots}"
    )


    print(
        f"Evaluation Shots       : "
        f"{evaluation_num_shots}"
    )


    print(
        f"Number of Evaluations : "
        f"{evaluation_num_times}"
    )


    print(
        "\nEvaluation Results:"
    )


    evaluation_values = []


    # --------------------------------------------------------
    # Same evaluation seeds are used for every optimized
    # parameter set.
    # --------------------------------------------------------

    for eval_index, eval_seed in enumerate(
        evaluation_seeds
    ):


        eval_objective = objective_function(
            optimal_params,
            int(eval_seed),
            shots=evaluation_num_shots,
            print_result=False
        )


        if eval_objective >= 1e10:

            eval_value = 0.0

        else:

            eval_value = (
                1.0 / eval_objective
            )


        evaluation_values.append(
            eval_value
        )


        # Seed is intentionally not printed here.
        print(
            f"Evaluation "
            f"{eval_index + 1:2d}/"
            f"{evaluation_num_times:2d}"
            f" | Value = "
            f"{eval_value:.8f}"
        )


    # ========================================================
    # Evaluation Statistics
    # ========================================================

    evaluation_values = np.array(
        evaluation_values,
        dtype=float
    )


    evaluation_mean = np.mean(
        evaluation_values
    )


    evaluation_std = np.std(
        evaluation_values
    )


    evaluation_sem = (
        evaluation_std
        / np.sqrt(evaluation_num_times)
    )


    evaluation_min = np.min(
        evaluation_values
    )


    evaluation_max = np.max(
        evaluation_values
    )


    # ========================================================
    # Store Evaluation Results
    # ========================================================

    evaluation_values_all_runs.append(
        evaluation_values.copy()
    )


    evaluation_mean_all_runs.append(
        evaluation_mean
    )


    evaluation_std_all_runs.append(
        evaluation_std
    )


    evaluation_sem_all_runs.append(
        evaluation_sem
    )


    evaluation_min_all_runs.append(
        evaluation_min
    )


    evaluation_max_all_runs.append(
        evaluation_max
    )


    # ========================================================
    # Individual Run Report
    # ========================================================

    print(
        "\n"
        + "=" * 80
    )


    print(
        f"RUN {run + 1} RESULT"
    )


    print(
        "=" * 80
    )


    print(
        f"Optimization Success : "
        f"{optimization_success}"
    )


    print(
        f"Reached MaxIter      : "
        f"{reached_maxiter}"
    )


    print(
        f"Status               : "
        f"{optimization_status}"
    )


    print(
        f"Message              : "
        f"{optimization_message}"
    )


    print(
        f"Function Evaluations : "
        f"{optimization_nfev}"
    )


    print(
        f"Optimization Time    : "
        f"{run_optimization_wall_time:.6f} s"
    )


    print(
        f"Final Objective Value: "
        f"{result.fun}"
    )


    print(
        "\n"
        + "-" * 80
    )


    print(
        "OPTIMIZED AND HIGH-SHOT "
        "EVALUATED VALUES"
    )


    print(
        "-" * 80
    )


    print(
        f"Final Optimized Value : "
        f"{final_value:.8f}"
    )


    print(
        f"Evaluated Mean        : "
        f"{evaluation_mean:.8f}"
    )


    print(
        f"Evaluated Std         : "
        f"{evaluation_std:.8f}"
    )


    print(
        f"Evaluated SEM         : "
        f"{evaluation_sem:.8f}"
    )


    print(
        f"Evaluated Min         : "
        f"{evaluation_min:.8f}"
    )


    print(
        f"Evaluated Max         : "
        f"{evaluation_max:.8f}"
    )


    print(
        "\nAll Evaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values,
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "=" * 80
    )


# ============================================================
# Runtime Statistics
# ============================================================

total_wall_end = time.perf_counter()

total_wall_time = (
    total_wall_end
    - total_wall_start
)

optimization_wall_times = np.array(
    optimization_wall_times,
    dtype=float
)

total_optimization_wall_time = np.sum(
    optimization_wall_times
)

mean_optimization_wall_time = np.mean(
    optimization_wall_times
)

std_optimization_wall_time = np.std(
    optimization_wall_times
)


# ============================================================
# Convert Results to NumPy Arrays
# ============================================================

final_optimized_values = np.array(
    final_optimized_values,
    dtype=float
)


initial_params_all_runs = np.array(
    initial_params_all_runs
)


optimal_params_all_runs = np.array(
    optimal_params_all_runs
)


evaluation_values_all_runs = np.array(
    evaluation_values_all_runs,
    dtype=float
)


evaluation_mean_all_runs = np.array(
    evaluation_mean_all_runs,
    dtype=float
)


evaluation_std_all_runs = np.array(
    evaluation_std_all_runs,
    dtype=float
)


evaluation_sem_all_runs = np.array(
    evaluation_sem_all_runs,
    dtype=float
)


evaluation_min_all_runs = np.array(
    evaluation_min_all_runs,
    dtype=float
)


evaluation_max_all_runs = np.array(
    evaluation_max_all_runs,
    dtype=float
)


# ============================================================
# Original Optimization Statistics
# ============================================================

maximum_value = np.max(
    final_optimized_values
)


mean_value = np.mean(
    final_optimized_values
)


std_value = np.std(
    final_optimized_values
)


maximum_run_index = np.argmax(
    final_optimized_values
)


maximum_run = (
    maximum_run_index + 1
)


# ============================================================
# High-Shot Evaluation Statistics
# ============================================================

maximum_evaluated_mean = np.max(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run_index = np.argmax(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run = (
    maximum_evaluated_mean_run_index
    + 1
)


mean_of_evaluated_means = np.mean(
    evaluation_mean_all_runs
)


std_of_evaluated_means = np.std(
    evaluation_mean_all_runs
)


# ============================================================
# Function Evaluation Statistics
# ============================================================

nfev_values = np.array(
    [
        nfev
        for nfev
        in optimization_nfev_all_runs
        if nfev is not None
    ],
    dtype=float
)


if len(nfev_values) > 0:

    mean_nfev = np.mean(
        nfev_values
    )


    std_nfev = np.std(
        nfev_values
    )

else:

    mean_nfev = np.nan
    std_nfev = np.nan


# ============================================================
# Optimization Success Statistics
# ============================================================

num_successful_runs = sum(
    optimization_success_all_runs
)


num_failed_runs = (
    num_times
    - num_successful_runs
)


num_reached_maxiter = sum(
    reached_maxiter_all_runs
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

best_initial_params = (
    initial_params_all_runs[
        maximum_run_index
    ]
)


best_optimal_params = (
    optimal_params_all_runs[
        maximum_run_index
    ]
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

best_evaluated_initial_params = (
    initial_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_optimal_params = (
    optimal_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_values = (
    evaluation_values_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


# ============================================================
# Print Final Report
# ============================================================

print("\n")


print(
    "=" * 100
)


print(
    "FINAL OPTIMIZATION AND "
    "HIGH-SHOT EVALUATION REPORT"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Settings
# ------------------------------------------------------------

print(
    f"Optimizer               : "
    f"{optimizer_name}"
)


print(
    f"Tolerance               : "
    f"{tol_value}"
)


print(
    f"Max Iteration           : "
    f"{maxiter}"
)


print(
    f"Number of Runs          : "
    f"{num_times}"
)


print(
    f"Number of Layers        : "
    f"{num_layers}"
)


print(
    f"Optimization Shots      : "
    f"{num_shots}"
)


print(
    f"Optimization Base Seed  : "
    f"{BASE_SEED}"
)


print(
    f"Evaluation Shots        : "
    f"{evaluation_num_shots}"
)


print(
    f"Evaluations Per Run     : "
    f"{evaluation_num_times}"
)


print(
    f"Evaluation Base Seed    : "
    f"{EVALUATION_BASE_SEED}"
)


# Evaluation seeds are printed ONCE here only.
print(
    "Evaluation Seeds        : "
    + np.array2string(
        evaluation_seeds,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Results for Every Run
# ============================================================

for i in range(num_times):


    print(
        f"\nRun {i + 1:2d}"
    )


    print(
        "-" * 100
    )


    print(
        f"Optimization Seed : "
        f"{BASE_SEED + i}"
    )


    print(
        f"Optimized Value   : "
        f"{final_optimized_values[i]:.8f}"
    )


    print(
        f"Evaluated Mean    : "
        f"{evaluation_mean_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Std     : "
        f"{evaluation_std_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated SEM     : "
        f"{evaluation_sem_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Min     : "
        f"{evaluation_min_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Max     : "
        f"{evaluation_max_all_runs[i]:.8f}"
    )


    print(
        f"Success           : "
        f"{optimization_success_all_runs[i]}"
    )


    print(
        f"Reached MaxIter   : "
        f"{reached_maxiter_all_runs[i]}"
    )


    print(
        f"Status            : "
        f"{optimization_status_all_runs[i]}"
    )


    print(
        f"Message           : "
        f"{optimization_message_all_runs[i]}"
    )


    print(
        f"Function Evals    : "
        f"{optimization_nfev_all_runs[i]}"
    )


    print(
        f"Optimization Time : "
        f"{optimization_wall_times[i]:.6f} s"
    )


    print(
        "\nEvaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values_all_runs[i],
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "-" * 100
    )


# ============================================================
# Summary
# ============================================================

print(
    "\nSUMMARY"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Original Optimization Results
# ------------------------------------------------------------

print(
    "\nOriginal Optimization-Shot Results:"
)


print(
    f"Maximum Optimized Value : "
    f"{maximum_value:.8f}"
)


print(
    f"Maximum Run             : "
    f"{maximum_run}"
)


print(
    f"Mean Optimized Value    : "
    f"{mean_value:.8f}"
)


print(
    f"Std Optimized Value     : "
    f"{std_value:.8f}"
)


# ------------------------------------------------------------
# High-Shot Evaluation Results
# ------------------------------------------------------------

print(
    "\nHigh-Shot Evaluation Results:"
)


print(
    f"Best Evaluated Mean     : "
    f"{maximum_evaluated_mean:.8f}"
)


print(
    f"Best Evaluated Mean Run : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Mean of Evaluated Means : "
    f"{mean_of_evaluated_means:.8f}"
)


print(
    f"Std of Evaluated Means  : "
    f"{std_of_evaluated_means:.8f}"
)


# ------------------------------------------------------------
# Optimizer Statistics
# ------------------------------------------------------------

print(
    "\nOptimizer Statistics:"
)


print(
    f"Mean Function Evals     : "
    f"{mean_nfev:.2f}"
)


print(
    f"Std Function Evals      : "
    f"{std_nfev:.2f}"
)


print(
    f"Successful Runs         : "
    f"{num_successful_runs}/"
    f"{num_times}"
)


print(
    f"Failed Runs             : "
    f"{num_failed_runs}/"
    f"{num_times}"
)


print(
    f"Reached MaxIter         : "
    f"{num_reached_maxiter}/"
    f"{num_times}"
)


# ------------------------------------------------------------
# Computational Runtime Statistics
# ------------------------------------------------------------

print(
    "\nComputational Runtime Statistics:"
)

print(
    f"Total Wall-Clock Time          : "
    f"{total_wall_time:.6f} s"
)

print(
    f"Total Optimization Time        : "
    f"{total_optimization_wall_time:.6f} s"
)

print(
    f"Time per Complete Opt. Run     : "
    f"{mean_optimization_wall_time:.6f} s"
)

print(
    f"Std Optimization Time per Run  : "
    f"{std_optimization_wall_time:.6f} s"
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "ORIGINAL OPTIMIZED VALUE"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated SEM   : "
    f"{evaluation_sem_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        evaluation_values_all_runs[
            maximum_run_index
        ],
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_optimal_params,
        precision=10,
        separator=", "
    )
)


# ============================================================
# Best Run According to High-Shot Evaluation
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "HIGH-SHOT EVALUATED MEAN"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated SEM   : "
    f"{evaluation_sem_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        best_evaluated_values,
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_evaluated_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_evaluated_optimal_params,
        precision=10,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Save Report to TXT
# ============================================================

with open(
    report_filename,
    "w"
) as f:


    # ========================================================
    # Header
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "FINAL OPTIMIZATION AND "
        "HIGH-SHOT EVALUATION REPORT\n"
    )


    f.write(
        "=" * 100
        + "\n\n"
    )


    # ========================================================
    # Settings
    # ========================================================

    f.write(
        f"Optimizer               : "
        f"{optimizer_name}\n"
    )


    f.write(
        f"Tolerance               : "
        f"{tol_value}\n"
    )


    f.write(
        f"Max Iteration           : "
        f"{maxiter}\n"
    )


    f.write(
        f"Number of Runs          : "
        f"{num_times}\n"
    )


    f.write(
        f"Number of Layers        : "
        f"{num_layers}\n"
    )


    f.write(
        f"Optimization Shots      : "
        f"{num_shots}\n"
    )


    f.write(
        f"Optimization Base Seed  : "
        f"{BASE_SEED}\n"
    )


    f.write(
        f"Evaluation Shots        : "
        f"{evaluation_num_shots}\n"
    )


    f.write(
        f"Evaluations Per Run     : "
        f"{evaluation_num_times}\n"
    )


    f.write(
        f"Evaluation Base Seed    : "
        f"{EVALUATION_BASE_SEED}\n"
    )


    # Evaluation seeds are saved ONCE here only.
    f.write(
        "Evaluation Seeds        : "
    )


    f.write(
        np.array2string(
            evaluation_seeds,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    # ========================================================
    # Results for Every Run
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "RESULTS FOR EACH RUN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    for i in range(num_times):


        f.write(
            f"\nRun {i + 1:2d}\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


        f.write(
            f"Optimization Seed : "
            f"{BASE_SEED + i}\n"
        )


        f.write(
            f"Optimized Value   : "
            f"{final_optimized_values[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Mean    : "
            f"{evaluation_mean_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Std     : "
            f"{evaluation_std_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated SEM     : "
            f"{evaluation_sem_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Min     : "
            f"{evaluation_min_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Max     : "
            f"{evaluation_max_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Success           : "
            f"{optimization_success_all_runs[i]}\n"
        )


        f.write(
            f"Reached MaxIter   : "
            f"{reached_maxiter_all_runs[i]}\n"
        )


        f.write(
            f"Status            : "
            f"{optimization_status_all_runs[i]}\n"
        )


        f.write(
            f"Message           : "
            f"{optimization_message_all_runs[i]}\n"
        )


        f.write(
            f"Function Evals    : "
            f"{optimization_nfev_all_runs[i]}\n"
        )


        f.write(
            f"Optimization Time : "
            f"{optimization_wall_times[i]:.6f} s\n"
        )


        f.write(
            "\nEvaluated Values:\n"
        )


        f.write(
            np.array2string(
                evaluation_values_all_runs[i],
                precision=8,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nInitial Parameters:\n"
        )


        f.write(
            np.array2string(
                initial_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nOptimal Parameters:\n"
        )


        f.write(
            np.array2string(
                optimal_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


    # ========================================================
    # Summary
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "SUMMARY\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    # --------------------------------------------------------
    # Original Optimization Results
    # --------------------------------------------------------

    f.write(
        "\nOriginal Optimization-Shot Results:\n"
    )


    f.write(
        f"Maximum Optimized Value : "
        f"{maximum_value:.8f}\n"
    )


    f.write(
        f"Maximum Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Mean Optimized Value    : "
        f"{mean_value:.8f}\n"
    )


    f.write(
        f"Std Optimized Value     : "
        f"{std_value:.8f}\n"
    )


    # --------------------------------------------------------
    # High-Shot Evaluation Results
    # --------------------------------------------------------

    f.write(
        "\nHigh-Shot Evaluation Results:\n"
    )


    f.write(
        f"Best Evaluated Mean     : "
        f"{maximum_evaluated_mean:.8f}\n"
    )


    f.write(
        f"Best Evaluated Mean Run : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Mean of Evaluated Means : "
        f"{mean_of_evaluated_means:.8f}\n"
    )


    f.write(
        f"Std of Evaluated Means  : "
        f"{std_of_evaluated_means:.8f}\n"
    )


    # --------------------------------------------------------
    # Optimizer Statistics
    # --------------------------------------------------------

    f.write(
        "\nOptimizer Statistics:\n"
    )


    f.write(
        f"Mean Function Evals     : "
        f"{mean_nfev:.2f}\n"
    )


    f.write(
        f"Std Function Evals      : "
        f"{std_nfev:.2f}\n"
    )


    f.write(
        f"Successful Runs         : "
        f"{num_successful_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Failed Runs             : "
        f"{num_failed_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Reached MaxIter         : "
        f"{num_reached_maxiter}/"
        f"{num_times}\n"
    )


    # --------------------------------------------------------
    # Computational Runtime Statistics
    # --------------------------------------------------------

    f.write(
        "\nComputational Runtime Statistics:\n"
    )

    f.write(
        f"Total Wall-Clock Time          : "
        f"{total_wall_time:.6f} s\n"
    )

    f.write(
        f"Total Optimization Time        : "
        f"{total_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Time per Complete Opt. Run     : "
        f"{mean_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Std Optimization Time per Run  : "
        f"{std_optimization_wall_time:.6f} s\n"
    )


    # ========================================================
    # Best Run According to Original Optimized Value
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "ORIGINAL OPTIMIZED VALUE\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated SEM   : "
        f"{evaluation_sem_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            evaluation_values_all_runs[
                maximum_run_index
            ],
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    # ========================================================
    # Best Run According to High-Shot Evaluated Mean
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "HIGH-SHOT EVALUATED MEAN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated SEM   : "
        f"{evaluation_sem_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_values,
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


# ============================================================
# Report Location
# ============================================================

print(
    "\nReport saved to:"
)


print(
    os.path.abspath(
        report_filename
    )
)
# Out:
# ================================================================================
# Optimization Run 1/30
# Optimization Seed : 150
# ================================================================================
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566, 0.6883896757,
#  0.5848087428, 0.2739643248, 0.8377858251, 0.3022293541]
#
# Starting COBYLA optimization...
# success_probability = 0.22520000
# success_probability = 0.21170000
# success_probability = 0.23440000
# success_probability = 0.28550000
# success_probability = 0.26500000
# success_probability = 0.31420000
# success_probability = 0.36650000
# success_probability = 0.17180000
# success_probability = 0.37950000
# success_probability = 0.35790000
# success_probability = 0.36100000
# success_probability = 0.23820000
# success_probability = 0.35470000
# success_probability = 0.34800000
# success_probability = 0.37950000
# success_probability = 0.36070000
# success_probability = 0.37950000
# success_probability = 0.41350000
# success_probability = 0.41350000
# success_probability = 0.41350000
# success_probability = 0.41350000
# success_probability = 0.41350000
# success_probability = 0.41350000
# success_probability = 0.41350000
# success_probability = 0.41350000
# success_probability = 0.51170000
# success_probability = 0.43680000
# success_probability = 0.50600000
# success_probability = 0.42170000
# success_probability = 0.47810000
# success_probability = 0.46190000
# success_probability = 0.49170000
# success_probability = 0.43910000
# success_probability = 0.43920000
# success_probability = 0.48920000
# success_probability = 0.52720000
# success_probability = 0.48240000
# success_probability = 0.54140000
# success_probability = 0.53750000
# success_probability = 0.54140000
# success_probability = 0.56420000
# success_probability = 0.56420000
# success_probability = 0.59980000
# success_probability = 0.59980000
# success_probability = 0.59930000
# success_probability = 0.59980000
# success_probability = 0.60120000
# success_probability = 0.60120000
# success_probability = 0.59220000
# success_probability = 0.60120000
# success_probability = 0.56190000
# success_probability = 0.59380000
# success_probability = 0.58620000
# success_probability = 0.59830000
# success_probability = 0.60040000
# success_probability = 0.60930000
# success_probability = 0.54420000
# success_probability = 0.62070000
# success_probability = 0.58110000
# success_probability = 0.61900000
# success_probability = 0.59740000
# success_probability = 0.60580000
# success_probability = 0.62760000
# success_probability = 0.62760000
# success_probability = 0.59940000
# success_probability = 0.61860000
# success_probability = 0.58890000
# success_probability = 0.61930000
# success_probability = 0.62430000
# success_probability = 0.61880000
# success_probability = 0.57450000
# success_probability = 0.63430000
# success_probability = 0.63570000
# success_probability = 0.63670000
# success_probability = 0.63670000
# success_probability = 0.63430000
# success_probability = 0.63670000
# success_probability = 0.63310000
# success_probability = 0.63600000
# success_probability = 0.61510000
# success_probability = 0.63490000
# success_probability = 0.62980000
# success_probability = 0.63480000
# success_probability = 0.63510000
# success_probability = 0.63670000
# success_probability = 0.63440000
# success_probability = 0.63500000
# success_probability = 0.63270000
# success_probability = 0.63770000
# success_probability = 0.63790000
# success_probability = 0.63320000
# success_probability = 0.62450000
# success_probability = 0.63210000
# success_probability = 0.62550000
# success_probability = 0.63790000
# success_probability = 0.63630000
# success_probability = 0.63030000
# success_probability = 0.63270000
# success_probability = 0.63400000
# success_probability = 0.63570000
# success_probability = 0.63900000
# success_probability = 0.64050000
# success_probability = 0.63680000
# success_probability = 0.63810000
# success_probability = 0.63990000
# success_probability = 0.63940000
# success_probability = 0.63870000
# success_probability = 0.64040000
# success_probability = 0.63650000
# success_probability = 0.64150000
# success_probability = 0.63560000
# success_probability = 0.63990000
# success_probability = 0.63970000
# success_probability = 0.63960000
# success_probability = 0.63500000
# success_probability = 0.63880000
# success_probability = 0.63810000
# success_probability = 0.63850000
# success_probability = 0.64120000
# success_probability = 0.63910000
# success_probability = 0.64080000
# success_probability = 0.63600000
# success_probability = 0.63820000
# success_probability = 0.64170000
# success_probability = 0.64100000
# success_probability = 0.64110000
# success_probability = 0.64120000
# success_probability = 0.63890000
# success_probability = 0.64110000
# success_probability = 0.63870000
# success_probability = 0.64140000
# success_probability = 0.63930000
# success_probability = 0.64070000
# success_probability = 0.64080000
# success_probability = 0.64030000
# success_probability = 0.64170000
# success_probability = 0.64120000
# success_probability = 0.64100000
# success_probability = 0.64150000
# success_probability = 0.64050000
# success_probability = 0.64130000
# success_probability = 0.64090000
# success_probability = 0.64020000
# success_probability = 0.64160000
# success_probability = 0.64070000
# success_probability = 0.64050000
# success_probability = 0.64200000
# success_probability = 0.64190000
# success_probability = 0.64110000
# success_probability = 0.64080000
# success_probability = 0.64180000
# success_probability = 0.64150000
# success_probability = 0.64060000
# success_probability = 0.64100000
# success_probability = 0.64070000
# success_probability = 0.64150000
# success_probability = 0.64210000
# success_probability = 0.64120000
# success_probability = 0.64200000
# success_probability = 0.64140000
# success_probability = 0.64180000
# success_probability = 0.64170000
# success_probability = 0.64260000
# success_probability = 0.64160000
# success_probability = 0.64110000
# success_probability = 0.64190000
# success_probability = 0.64210000
# success_probability = 0.64200000
# success_probability = 0.64220000
# success_probability = 0.64290000
# success_probability = 0.64240000
# success_probability = 0.64230000
# success_probability = 0.64270000
# success_probability = 0.64170000
# success_probability = 0.64280000
# success_probability = 0.64220000
# success_probability = 0.64280000
# success_probability = 0.64130000
# success_probability = 0.64250000
# success_probability = 0.64190000
# success_probability = 0.64280000
# success_probability = 0.64170000
# success_probability = 0.64340000
# success_probability = 0.64250000
# success_probability = 0.64250000
# success_probability = 0.64230000
# success_probability = 0.64240000
# success_probability = 0.64320000
# success_probability = 0.64270000
# success_probability = 0.64320000
# success_probability = 0.64290000
# success_probability = 0.64290000
# success_probability = 0.64300000
# success_probability = 0.64330000
# success_probability = 0.64310000
# success_probability = 0.64310000
# success_probability = 0.64240000
# success_probability = 0.64310000
# success_probability = 0.64300000
# success_probability = 0.64340000
# success_probability = 0.64180000
# success_probability = 0.64260000
# success_probability = 0.64310000
# success_probability = 0.64350000
# success_probability = 0.64350000
# success_probability = 0.64350000
# success_probability = 0.64320000
# success_probability = 0.64350000
# success_probability = 0.64330000
# success_probability = 0.64360000
# success_probability = 0.64320000
# success_probability = 0.64360000
# success_probability = 0.64300000
# success_probability = 0.64330000
# success_probability = 0.64280000
# success_probability = 0.64330000
# success_probability = 0.64270000
# success_probability = 0.64330000
# success_probability = 0.64270000
# success_probability = 0.64340000
# success_probability = 0.64300000
# success_probability = 0.64310000
# success_probability = 0.64290000
# success_probability = 0.64300000
# success_probability = 0.64350000
# success_probability = 0.64350000
# success_probability = 0.64320000
# success_probability = 0.64340000
# success_probability = 0.64340000
# success_probability = 0.64340000
# success_probability = 0.64350000
# success_probability = 0.64350000
# success_probability = 0.64350000
# success_probability = 0.64340000
# success_probability = 0.64340000
# success_probability = 0.64300000
# success_probability = 0.64350000
# success_probability = 0.64330000
# success_probability = 0.64360000
# success_probability = 0.64330000
# success_probability = 0.64360000
# success_probability = 0.64350000
# success_probability = 0.64360000
# success_probability = 0.64350000
# success_probability = 0.64350000
# success_probability = 0.64320000
# success_probability = 0.64350000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64350000
# success_probability = 0.64350000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64350000
# success_probability = 0.64360000
# success_probability = 0.64350000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64350000
# success_probability = 0.64360000
# success_probability = 0.64340000
# success_probability = 0.64360000
# success_probability = 0.64340000
# success_probability = 0.64350000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
# success_probability = 0.64360000
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  392   F = 1.553760E+00    MAXCV = 0.000000E+00
#    X =-2.134742E-02   1.582263E+00   1.776768E+00  -1.629502E-02   1.623529E+00
#        1.868951E+00  -3.944389E-02   5.059039E-01   4.723747E-01  -9.616064E-03
#        1.171678E-02   3.288237E-01   7.717326E-01   7.275319E-01   7.748080E-01
#        7.713750E-01   7.763197E-01   5.665717E-01   1.289537E+00   9.764382E-01
#        4.059631E-01   1.468765E-01   8.688552E-01   3.630889E-01
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.63040000
# Evaluation  2/20 | Value = 0.63133000
# Evaluation  3/20 | Value = 0.62920000
# Evaluation  4/20 | Value = 0.63090000
# Evaluation  5/20 | Value = 0.62728000
# Evaluation  6/20 | Value = 0.62572000
# Evaluation  7/20 | Value = 0.62846000
# Evaluation  8/20 | Value = 0.63160000
# Evaluation  9/20 | Value = 0.63275000
# Evaluation 10/20 | Value = 0.63107000
# Evaluation 11/20 | Value = 0.63037000
# Evaluation 12/20 | Value = 0.62864000
# Evaluation 13/20 | Value = 0.62981000
# Evaluation 14/20 | Value = 0.62960000
# Evaluation 15/20 | Value = 0.62888000
# Evaluation 16/20 | Value = 0.62864000
# Evaluation 17/20 | Value = 0.62922000
# Evaluation 18/20 | Value = 0.62903000
# Evaluation 19/20 | Value = 0.62889000
# Evaluation 20/20 | Value = 0.63010000
#
# ================================================================================
# RUN 1 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 1
# Message              : Optimization terminated successfully.
# Function Evaluations : 392
# Optimization Time    : 24.203889 s
# Final Objective Value: 1.5537600994406464
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.64360000
# Evaluated Mean        : 0.62959450
# Evaluated Std         : 0.00154149
# Evaluated SEM         : 0.00034469
# Evaluated Min         : 0.62572000
# Evaluated Max         : 0.63275000
#
# All Evaluated Values:
# [0.6304 , 0.63133, 0.6292 , 0.6309 , 0.62728, 0.62572, 0.62846, 0.6316 ,
#  0.63275, 0.63107, 0.63037, 0.62864, 0.62981, 0.6296 , 0.62888, 0.62864,
#  0.62922, 0.62903, 0.62889, 0.6301 ]
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566, 0.6883896757,
#  0.5848087428, 0.2739643248, 0.8377858251, 0.3022293541]
#
# Optimal Parameters:
# [-0.0213474176,  1.5822626037,  1.7767680278, -0.0162950189,  1.6235294311,
#   1.8689508296, -0.0394438858,  0.5059038712,  0.4723747078, -0.009616064 ,
#   0.011716784 ,  0.328823727 ,  0.7717326479,  0.7275318907,  0.7748079983,
#   0.7713750067,  0.7763197108,  0.5665717065,  1.2895372438,  0.9764381982,
#   0.4059630959,  0.14687648  ,  0.8688551945,  0.3630888525]
# ================================================================================
#
# ================================================================================
# Optimization Run 2/30
# Optimization Seed : 151
# ================================================================================
#
# Initial Parameters:
# [0.4917938425, 0.3601415032, 0.7094100488, 0.6895107167, 0.4723817514,
#  0.4790485592, 0.0068635273, 0.9044398512, 0.4337399476, 0.4736042839,
#  0.034330777 , 0.9496323674, 0.5907905652, 0.4241785512, 0.1868628067,
#  0.9840929216, 0.690221156 , 0.9039467044, 0.0207568308, 0.9969449281,
#  0.3143005034, 0.2098620446, 0.0173606056, 0.1892781313]
#
# Starting COBYLA optimization...
# success_probability = 0.34960000
# success_probability = 0.26620000
# success_probability = 0.36340000
# success_probability = 0.36540000
# success_probability = 0.30320000
# success_probability = 0.36940000
# success_probability = 0.44530000
# success_probability = 0.41690000
# success_probability = 0.35170000
# success_probability = 0.40450000
# success_probability = 0.36670000
# success_probability = 0.41520000
# success_probability = 0.38210000
# success_probability = 0.43260000
# success_probability = 0.44530000
# success_probability = 0.45990000
# success_probability = 0.45990000
# success_probability = 0.45130000
# success_probability = 0.45990000
# success_probability = 0.45990000
# success_probability = 0.45990000
# success_probability = 0.45990000
# success_probability = 0.45990000
# success_probability = 0.45990000
# success_probability = 0.45990000
# success_probability = 0.55870000
# success_probability = 0.54880000
# success_probability = 0.55480000
# success_probability = 0.50070000
# success_probability = 0.57020000
# success_probability = 0.54420000
# success_probability = 0.58150000
# success_probability = 0.50550000
# success_probability = 0.57990000
# success_probability = 0.51280000
# success_probability = 0.56450000
# success_probability = 0.57790000
# success_probability = 0.59000000
# success_probability = 0.58780000
# success_probability = 0.59000000
# success_probability = 0.56230000
# success_probability = 0.59000000
# success_probability = 0.56780000
# success_probability = 0.59000000
# success_probability = 0.60710000
# success_probability = 0.60710000
# success_probability = 0.61020000
# success_probability = 0.61020000
# success_probability = 0.61050000
# success_probability = 0.61050000
# success_probability = 0.60520000
# success_probability = 0.60150000
# success_probability = 0.61260000
# success_probability = 0.60550000
# success_probability = 0.59820000
# success_probability = 0.60220000
# success_probability = 0.56840000
# success_probability = 0.60050000
# success_probability = 0.58570000
# success_probability = 0.60160000
# success_probability = 0.55960000
# success_probability = 0.61440000
# success_probability = 0.57950000
# success_probability = 0.61340000
# success_probability = 0.61580000
# success_probability = 0.61580000
# success_probability = 0.57670000
# success_probability = 0.61580000
# success_probability = 0.61010000
# success_probability = 0.61580000
# success_probability = 0.60090000
# success_probability = 0.61900000
# success_probability = 0.58860000
# success_probability = 0.61850000
# success_probability = 0.61630000
# success_probability = 0.61700000
# success_probability = 0.59120000
# success_probability = 0.61800000
# success_probability = 0.59770000
# success_probability = 0.61960000
# success_probability = 0.61960000
# success_probability = 0.60410000
# success_probability = 0.62020000
# success_probability = 0.62220000
# success_probability = 0.62220000
# success_probability = 0.62230000
# success_probability = 0.61920000
# success_probability = 0.61620000
# success_probability = 0.62400000
# success_probability = 0.62060000
# success_probability = 0.62370000
# success_probability = 0.62310000
# success_probability = 0.62420000
# success_probability = 0.62190000
# success_probability = 0.62090000
# success_probability = 0.59920000
# success_probability = 0.62510000
# success_probability = 0.63900000
# success_probability = 0.63670000
# success_probability = 0.63780000
# success_probability = 0.62690000
# success_probability = 0.63890000
# success_probability = 0.63570000
# success_probability = 0.63730000
# success_probability = 0.63680000
# success_probability = 0.63810000
# success_probability = 0.63050000
# success_probability = 0.63140000
# success_probability = 0.63940000
# success_probability = 0.63940000
# success_probability = 0.63530000
# success_probability = 0.63920000
# success_probability = 0.63770000
# success_probability = 0.63880000
# success_probability = 0.64120000
# success_probability = 0.63730000
# success_probability = 0.64120000
# success_probability = 0.63900000
# success_probability = 0.64040000
# success_probability = 0.64030000
# success_probability = 0.63930000
# success_probability = 0.63960000
# success_probability = 0.63910000
# success_probability = 0.63270000
# success_probability = 0.63810000
# success_probability = 0.64150000
# success_probability = 0.64250000
# success_probability = 0.64170000
# success_probability = 0.64190000
# success_probability = 0.64090000
# success_probability = 0.64140000
# success_probability = 0.64110000
# success_probability = 0.64250000
# success_probability = 0.64230000
# success_probability = 0.63980000
# success_probability = 0.63960000
# success_probability = 0.64160000
# success_probability = 0.64000000
# success_probability = 0.64250000
# success_probability = 0.64260000
# success_probability = 0.64070000
# success_probability = 0.64330000
# success_probability = 0.64290000
# success_probability = 0.64370000
# success_probability = 0.64250000
# success_probability = 0.64300000
# success_probability = 0.64300000
# success_probability = 0.64070000
# success_probability = 0.64210000
# success_probability = 0.64050000
# success_probability = 0.64200000
# success_probability = 0.64200000
# success_probability = 0.64390000
# success_probability = 0.64270000
# success_probability = 0.64220000
# success_probability = 0.64100000
# success_probability = 0.64230000
# success_probability = 0.64170000
# success_probability = 0.64420000
# success_probability = 0.64270000
# success_probability = 0.64350000
# success_probability = 0.64460000
# success_probability = 0.64430000
# success_probability = 0.64410000
# success_probability = 0.64410000
# success_probability = 0.64210000
# success_probability = 0.64450000
# success_probability = 0.64300000
# success_probability = 0.64370000
# success_probability = 0.64470000
# success_probability = 0.64620000
# success_probability = 0.64400000
# success_probability = 0.64660000
# success_probability = 0.64440000
# success_probability = 0.64460000
# success_probability = 0.64400000
# success_probability = 0.64510000
# success_probability = 0.64410000
# success_probability = 0.64460000
# success_probability = 0.64450000
# success_probability = 0.64430000
# success_probability = 0.64530000
# success_probability = 0.64490000
# success_probability = 0.64310000
# success_probability = 0.64440000
# success_probability = 0.64430000
# success_probability = 0.64600000
# success_probability = 0.64360000
# success_probability = 0.64590000
# success_probability = 0.64550000
# success_probability = 0.64500000
# success_probability = 0.64620000
# success_probability = 0.64520000
# success_probability = 0.64560000
# success_probability = 0.64450000
# success_probability = 0.64600000
# success_probability = 0.64580000
# success_probability = 0.64640000
# success_probability = 0.64610000
# success_probability = 0.64590000
# success_probability = 0.64640000
# success_probability = 0.64640000
# success_probability = 0.64600000
# success_probability = 0.64560000
# success_probability = 0.64610000
# success_probability = 0.64650000
# success_probability = 0.64640000
# success_probability = 0.64600000
# success_probability = 0.64580000
# success_probability = 0.64550000
# success_probability = 0.64610000
# success_probability = 0.64630000
# success_probability = 0.64630000
# success_probability = 0.64640000
# success_probability = 0.64640000
# success_probability = 0.64590000
# success_probability = 0.64650000
# success_probability = 0.64560000
# success_probability = 0.64630000
# success_probability = 0.64590000
# success_probability = 0.64640000
# success_probability = 0.64570000
# success_probability = 0.64630000
# success_probability = 0.64610000
# success_probability = 0.64640000
# success_probability = 0.64630000
# success_probability = 0.64600000
# success_probability = 0.64620000
# success_probability = 0.64630000
# success_probability = 0.64620000
# success_probability = 0.64650000
# success_probability = 0.64630000
# success_probability = 0.64650000
# success_probability = 0.64640000
# success_probability = 0.64630000
# success_probability = 0.64630000
# success_probability = 0.64640000
# success_probability = 0.64610000
# success_probability = 0.64630000
# success_probability = 0.64640000
# success_probability = 0.64630000
# success_probability = 0.64610000
# success_probability = 0.64640000
# success_probability = 0.64660000
# success_probability = 0.64650000
# success_probability = 0.64640000
# success_probability = 0.64630000
# success_probability = 0.64630000
# success_probability = 0.64630000
# success_probability = 0.64650000
# success_probability = 0.64660000
# success_probability = 0.64630000
# success_probability = 0.64650000
# success_probability = 0.64630000
# success_probability = 0.64650000
# success_probability = 0.64630000
# success_probability = 0.64650000
# success_probability = 0.64650000
# success_probability = 0.64630000
# success_probability = 0.64640000
# success_probability = 0.64650000
# success_probability = 0.64650000
# success_probability = 0.64650000
# success_probability = 0.64650000
# success_probability = 0.64650000
# success_probability = 0.64660000
# success_probability = 0.64640000
# success_probability = 0.64660000
# success_probability = 0.64630000
# success_probability = 0.64640000
# success_probability = 0.64640000
# success_probability = 0.64650000
# success_probability = 0.64630000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64650000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64650000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64650000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
# success_probability = 0.64660000
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  403   F = 1.546551E+00    MAXCV = 0.000000E+00
#    X = 5.774073E-01   1.167232E+00   2.833728E+00   5.708672E-01   2.035526E+00
#        1.577838E+00   7.111766E-02   7.545332E-01   2.481708E-01  -3.769596E-01
#       -6.297802E-02   1.396777E-02  -1.520565E-02   3.004957E-01   1.584722E+00
#        1.025132E+00   6.989316E-02   9.944836E-01  -1.504647E-01   1.198396E+00
#        4.286201E-01   4.430886E-02  -2.707502E-01  -3.588313E-02
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.64213000
# Evaluation  2/20 | Value = 0.64378000
# Evaluation  3/20 | Value = 0.64251000
# Evaluation  4/20 | Value = 0.64277000
# Evaluation  5/20 | Value = 0.64149000
# Evaluation  6/20 | Value = 0.63855000
# Evaluation  7/20 | Value = 0.64020000
# Evaluation  8/20 | Value = 0.64472000
# Evaluation  9/20 | Value = 0.64476000
# Evaluation 10/20 | Value = 0.64344000
# Evaluation 11/20 | Value = 0.64356000
# Evaluation 12/20 | Value = 0.64230000
# Evaluation 13/20 | Value = 0.64245000
# Evaluation 14/20 | Value = 0.64326000
# Evaluation 15/20 | Value = 0.64060000
# Evaluation 16/20 | Value = 0.64247000
# Evaluation 17/20 | Value = 0.64027000
# Evaluation 18/20 | Value = 0.64262000
# Evaluation 19/20 | Value = 0.64073000
# Evaluation 20/20 | Value = 0.64382000
#
# ================================================================================
# RUN 2 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 1
# Message              : Optimization terminated successfully.
# Function Evaluations : 403
# Optimization Time    : 27.750453 s
# Final Objective Value: 1.5465511908444172
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.64660000
# Evaluated Mean        : 0.64232150
# Evaluated Std         : 0.00156940
# Evaluated SEM         : 0.00035093
# Evaluated Min         : 0.63855000
# Evaluated Max         : 0.64476000
#
# All Evaluated Values:
# [0.64213, 0.64378, 0.64251, 0.64277, 0.64149, 0.63855, 0.6402 , 0.64472,
#  0.64476, 0.64344, 0.64356, 0.6423 , 0.64245, 0.64326, 0.6406 , 0.64247,
#  0.64027, 0.64262, 0.64073, 0.64382]
#
# Initial Parameters:
# [0.4917938425, 0.3601415032, 0.7094100488, 0.6895107167, 0.4723817514,
#  0.4790485592, 0.0068635273, 0.9044398512, 0.4337399476, 0.4736042839,
#  0.034330777 , 0.9496323674, 0.5907905652, 0.4241785512, 0.1868628067,
#  0.9840929216, 0.690221156 , 0.9039467044, 0.0207568308, 0.9969449281,
#  0.3143005034, 0.2098620446, 0.0173606056, 0.1892781313]
#
# Optimal Parameters:
# [ 0.5774072517,  1.1672316958,  2.8337283556,  0.5708672056,  2.0355255256,
#   1.5778378808,  0.0711176594,  0.7545332038,  0.2481708285, -0.3769596255,
#  -0.0629780168,  0.0139677684, -0.015205647 ,  0.3004957308,  1.5847219345,
#   1.0251316778,  0.0698931602,  0.9944836188, -0.1504646891,  1.1983960802,
#   0.4286200593,  0.0443088585, -0.2707501552, -0.0358831286]
# ================================================================================
#
# ================================================================================
# Optimization Run 3/30
# Optimization Seed : 152
# ================================================================================
#
# Initial Parameters:
# [0.2185327016, 0.2605845547, 0.0494520073, 0.5385992113, 0.5420706407,
#  0.7890536718, 0.9123372133, 0.3722628249, 0.3257754726, 0.6556609124,
#  0.8969863307, 0.6516960973, 0.7833870606, 0.8742393722, 0.1922236761,
#  0.610154332 , 0.9457183359, 0.8193944158, 0.2252887854, 0.5455987355,
#  0.8717491352, 0.8014303248, 0.0339990148, 0.0928109212]
#
# Starting COBYLA optimization...
# success_probability = 0.18540000
# success_probability = 0.16060000
# success_probability = 0.18480000
# success_probability = 0.20600000
# success_probability = 0.24870000
# success_probability = 0.23350000
# success_probability = 0.21860000
# success_probability = 0.22990000
# success_probability = 0.26590000
# success_probability = 0.30700000
# success_probability = 0.36400000
# success_probability = 0.20400000
# success_probability = 0.43060000
# success_probability = 0.41130000
# success_probability = 0.43060000
# success_probability = 0.37450000
# success_probability = 0.43060000
# success_probability = 0.45740000
# success_probability = 0.45740000
# success_probability = 0.45740000
# success_probability = 0.45740000
# success_probability = 0.45740000
# success_probability = 0.45740000
# success_probability = 0.45740000
# success_probability = 0.45740000
# success_probability = 0.53080000
# success_probability = 0.51230000
# success_probability = 0.46260000
# success_probability = 0.43970000
# success_probability = 0.53230000
# success_probability = 0.46360000
# success_probability = 0.54340000
# success_probability = 0.51670000
# success_probability = 0.50660000
# success_probability = 0.45450000
# success_probability = 0.48880000
# success_probability = 0.55460000
# success_probability = 0.55810000
# success_probability = 0.54170000
# success_probability = 0.56050000
# success_probability = 0.56050000
# success_probability = 0.54810000
# success_probability = 0.56050000
# success_probability = 0.55220000
# success_probability = 0.56050000
# success_probability = 0.57980000
# success_probability = 0.57980000
# success_probability = 0.57450000
# success_probability = 0.57980000
# success_probability = 0.57790000
# success_probability = 0.57980000
# success_probability = 0.57190000
# success_probability = 0.57850000
# success_probability = 0.55320000
# success_probability = 0.58530000
# success_probability = 0.55560000
# success_probability = 0.56290000
# success_probability = 0.55350000
# success_probability = 0.59420000
# success_probability = 0.58370000
# success_probability = 0.56720000
# success_probability = 0.57250000
# success_probability = 0.59160000
# success_probability = 0.59450000
# success_probability = 0.59230000
# success_probability = 0.58430000
# success_probability = 0.59550000
# success_probability = 0.58910000
# success_probability = 0.59100000
# success_probability = 0.59550000
# success_probability = 0.60600000
# success_probability = 0.60600000
# success_probability = 0.61040000
# success_probability = 0.61040000
# success_probability = 0.61870000
# success_probability = 0.61260000
# success_probability = 0.62080000
# success_probability = 0.62100000
# success_probability = 0.62770000
# success_probability = 0.62630000
# success_probability = 0.63130000
# success_probability = 0.63470000
# success_probability = 0.62960000
# success_probability = 0.63230000
# success_probability = 0.62760000
# success_probability = 0.63510000
# success_probability = 0.62790000
# success_probability = 0.63510000
# success_probability = 0.63290000
# success_probability = 0.63470000
# success_probability = 0.63390000
# success_probability = 0.63640000
# success_probability = 0.62890000
# success_probability = 0.63290000
# success_probability = 0.64070000
# success_probability = 0.64070000
# success_probability = 0.63450000
# success_probability = 0.64070000
# success_probability = 0.62990000
# success_probability = 0.63890000
# success_probability = 0.64260000
# success_probability = 0.64400000
# success_probability = 0.64310000
# success_probability = 0.64340000
# success_probability = 0.63850000
# success_probability = 0.64360000
# success_probability = 0.64170000
# success_probability = 0.64250000
# success_probability = 0.64110000
# success_probability = 0.64260000
# success_probability = 0.63640000
# success_probability = 0.64500000
# success_probability = 0.64120000
# success_probability = 0.64600000
# success_probability = 0.64480000
# success_probability = 0.64160000
# success_probability = 0.64330000
# success_probability = 0.64540000
# success_probability = 0.64370000
# success_probability = 0.64400000
# success_probability = 0.64660000
# success_probability = 0.64670000
# success_probability = 0.64470000
# success_probability = 0.64200000
# success_probability = 0.64760000
# success_probability = 0.64630000
# success_probability = 0.64740000
# success_probability = 0.64800000
# success_probability = 0.64800000
# success_probability = 0.64730000
# success_probability = 0.64780000
# success_probability = 0.64670000
# success_probability = 0.64820000
# success_probability = 0.64640000
# success_probability = 0.64750000
# success_probability = 0.64740000
# success_probability = 0.64650000
# success_probability = 0.64550000
# success_probability = 0.64720000
# success_probability = 0.64780000
# success_probability = 0.64730000
# success_probability = 0.64730000
# success_probability = 0.64640000
# success_probability = 0.64670000
# success_probability = 0.64790000
# success_probability = 0.64580000
# success_probability = 0.64700000
# success_probability = 0.64690000
# success_probability = 0.64740000
# success_probability = 0.64540000
# success_probability = 0.64850000
# success_probability = 0.64760000
# success_probability = 0.64800000
# success_probability = 0.64780000
# success_probability = 0.64790000
# success_probability = 0.64860000
# success_probability = 0.64780000
# success_probability = 0.64920000
# success_probability = 0.64820000
# success_probability = 0.64870000
# success_probability = 0.64770000
# success_probability = 0.64840000
# success_probability = 0.64710000
# success_probability = 0.64830000
# success_probability = 0.64820000
# success_probability = 0.64850000
# success_probability = 0.64780000
# success_probability = 0.64870000
# success_probability = 0.64820000
# success_probability = 0.64810000
# success_probability = 0.64850000
# success_probability = 0.64890000
# success_probability = 0.64830000
# success_probability = 0.64860000
# success_probability = 0.64850000
# success_probability = 0.64840000
# success_probability = 0.64730000
# success_probability = 0.64890000
# success_probability = 0.64830000
# success_probability = 0.64840000
# success_probability = 0.64800000
# success_probability = 0.64890000
# success_probability = 0.64840000
# success_probability = 0.64890000
# success_probability = 0.64910000
# success_probability = 0.64860000
# success_probability = 0.64890000
# success_probability = 0.64900000
# success_probability = 0.64900000
# success_probability = 0.64860000
# success_probability = 0.64890000
# success_probability = 0.64880000
# success_probability = 0.64860000
# success_probability = 0.64900000
# success_probability = 0.64920000
# success_probability = 0.64910000
# success_probability = 0.64860000
# success_probability = 0.64900000
# success_probability = 0.64920000
# success_probability = 0.64910000
# success_probability = 0.64900000
# success_probability = 0.64920000
# success_probability = 0.64910000
# success_probability = 0.64920000
# success_probability = 0.64850000
# success_probability = 0.64940000
# success_probability = 0.64860000
# success_probability = 0.64920000
# success_probability = 0.64930000
# success_probability = 0.64890000
# success_probability = 0.64930000
# success_probability = 0.64910000
# success_probability = 0.64940000
# success_probability = 0.64910000
# success_probability = 0.64930000
# success_probability = 0.64920000
# success_probability = 0.64920000
# success_probability = 0.64920000
# success_probability = 0.64920000
# success_probability = 0.64900000
# success_probability = 0.64930000
# success_probability = 0.64920000
# success_probability = 0.64920000
# success_probability = 0.64900000
# success_probability = 0.64940000
# success_probability = 0.64920000
# success_probability = 0.64930000
# success_probability = 0.64920000
# success_probability = 0.64920000
# success_probability = 0.64930000
# success_probability = 0.64940000
# success_probability = 0.64930000
# success_probability = 0.64900000
# success_probability = 0.64940000
# success_probability = 0.64930000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64920000
# success_probability = 0.64920000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64930000
# success_probability = 0.64940000
# success_probability = 0.64930000
# success_probability = 0.64930000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64930000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64930000
# success_probability = 0.64930000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64930000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64930000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64930000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  387   F = 1.539883E+00    MAXCV = 0.000000E+00
#    X =-7.973241E-02   5.585686E-01   1.502301E+00   1.553565E+00   3.736815E-02
#       -5.919949E-01   1.535635E+00   1.561192E+00   1.592349E+00   1.592531E+00
# ...
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 445
# Optimization Time : 27.540988 s
#
# Evaluated Values:
# [0.64023, 0.64278, 0.64176, 0.64095, 0.63886, 0.63651, 0.63877, 0.64268,
#  0.64373, 0.64292, 0.64185, 0.64158, 0.64007, 0.64099, 0.63907, 0.64155,
#  0.63849, 0.64062, 0.63934, 0.64247]
#
# Initial Parameters:
# [0.1702293838, 0.9230877777, 0.5877290957, 0.306458957 , 0.4751153524,
#  0.3697992575, 0.4214819696, 0.5618192319, 0.161492304 , 0.8493918532,
#  0.0143050224, 0.3930636181, 0.7191759106, 0.2969669963, 0.7611493365,
#  0.0896341489, 0.847170193 , 0.8567125443, 0.2548602455, 0.9788032124,
#  0.9030627866, 0.6739628526, 0.5013960951, 0.6787189362]
#
# Optimal Parameters:
# [-0.5230753628,  1.4793143745,  1.6255002322,  0.0384888409,  1.3909000667,
#   1.6332191235,  0.062722503 ,  0.1858884149,  0.845648092 , -0.0975807418,
#  -0.1106542937,  0.1259833834,  0.796565225 ,  0.1989891068,  0.782860306 ,
#   0.0072110157,  0.6173486023,  0.431489135 ,  0.0117148869,  0.9323921216,
#   0.7983882354,  0.4775935878,  0.3945101077,  0.4343695651]
# ----------------------------------------------------------------------------------------------------
#
# Run 24
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 173
# Optimized Value   : 0.64800000
# Evaluated Mean    : 0.64642300
# Evaluated Std     : 0.00182714
# Evaluated SEM     : 0.00040856
# Evaluated Min     : 0.64180000
# Evaluated Max     : 0.64952000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 424
# Optimization Time : 26.172105 s
#
# Evaluated Values:
# [0.64637, 0.64866, 0.64652, 0.64645, 0.64492, 0.6418 , 0.64475, 0.64899,
#  0.64952, 0.64773, 0.64781, 0.64646, 0.64638, 0.6466 , 0.64453, 0.64665,
#  0.64411, 0.64736, 0.64475, 0.6481 ]
#
# Initial Parameters:
# [0.0683064102, 0.5061877572, 0.2800764934, 0.4917358842, 0.3376481488,
#  0.6337766115, 0.7941202296, 0.2237709719, 0.8893153608, 0.9462072178,
#  0.9270749557, 0.8979372613, 0.8865232604, 0.1112901922, 0.4404611446,
#  0.6571269562, 0.6018173982, 0.0668305069, 0.5031888045, 0.7100940384,
#  0.3646853666, 0.6647653187, 0.3408936761, 0.3312253256]
#
# Optimal Parameters:
# [ 0.8226076141,  1.6026673405,  1.6031892506,  1.5241363524,  1.6669369492,
#   1.8090757244,  0.2018137699,  1.6039461166,  2.0475089605,  1.5842068216,
#   1.3632671341,  1.5878770031, -0.0430205397,  0.0086777576, -0.2256232061,
#   0.1640481564,  1.5730024674,  0.0837553134,  0.5217766598,  0.7238915725,
#   0.3785192681,  0.6782594858, -0.0642155107, -0.0409232979]
# ----------------------------------------------------------------------------------------------------
#
# Run 25
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 174
# Optimized Value   : 0.64660000
# Evaluated Mean    : 0.64245350
# Evaluated Std     : 0.00158841
# Evaluated SEM     : 0.00035518
# Evaluated Min     : 0.63906000
# Evaluated Max     : 0.64493000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 373
# Optimization Time : 22.845377 s
#
# Evaluated Values:
# [0.64156, 0.64426, 0.64325, 0.64274, 0.64055, 0.63906, 0.64053, 0.64493,
#  0.64493, 0.64281, 0.64328, 0.64297, 0.64194, 0.64352, 0.64049, 0.64294,
#  0.64087, 0.64319, 0.64106, 0.64419]
#
# Initial Parameters:
# [0.920751175 , 0.8324481628, 0.9226421153, 0.4120178702, 0.112899878 ,
#  0.539662511 , 0.9690640438, 0.8958288503, 0.8463732302, 0.6837088366,
#  0.0134777936, 0.9213092468, 0.0585796685, 0.528523907 , 0.4212992395,
#  0.8064657524, 0.2081509804, 0.1492170041, 0.0586840123, 0.6381376407,
#  0.7175421339, 0.7259671078, 0.0347409726, 0.8317209152]
#
# Optimal Parameters:
# [ 1.586814647 ,  1.4487305797,  1.4884537246,  1.5469839839,  0.4230508269,
#  -0.4259992133,  1.2760303645,  1.5599189675,  2.4801305224,  1.389442901 ,
#  -0.0273876031,  1.3077017728,  0.0534031012,  0.5273209784,  0.3083442883,
#   0.7884423234,  1.4910724667,  0.1574022678,  0.0586840123,  0.6839255896,
#   0.4980810501,  0.8030847277,  0.0590178529,  0.7269788596]
# ----------------------------------------------------------------------------------------------------
#
# Run 26
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 175
# Optimized Value   : 0.64810000
# Evaluated Mean    : 0.64401250
# Evaluated Std     : 0.00153585
# Evaluated SEM     : 0.00034343
# Evaluated Min     : 0.64049000
# Evaluated Max     : 0.64628000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 392
# Optimization Time : 24.265546 s
#
# Evaluated Values:
# [0.64359, 0.64628, 0.64422, 0.644  , 0.64293, 0.64049, 0.64226, 0.64606,
#  0.64604, 0.64548, 0.6453 , 0.64368, 0.64369, 0.64444, 0.64244, 0.6442 ,
#  0.64201, 0.644  , 0.64291, 0.64623]
#
# Initial Parameters:
# [0.5632800098, 0.5263460088, 0.074383608 , 0.0432472297, 0.1116614549,
#  0.3149336925, 0.8051899849, 0.2265811498, 0.2507577735, 0.3247400132,
#  0.7132637608, 0.7744654451, 0.9295185054, 0.8709503245, 0.9380278462,
#  0.6231528096, 0.2419077457, 0.8799737511, 0.1804762542, 0.8020908004,
#  0.3363522676, 0.2884964572, 0.5552697615, 0.8113197998]
#
# Optimal Parameters:
# [-0.5371033526,  1.660150788 , -0.0776431975,  0.5695529628,  1.5578195952,
#   2.1677985561, -0.0863275139, -0.7168006393,  1.4965296604, -0.0379098188,
#   0.1568309936, -0.0949202448,  0.6470174803,  0.874917657 ,  0.922985706 ,
#   0.6363370111,  1.7532320244,  0.9113817441,  0.1696483801,  0.7853973871,
#   0.3307685245,  0.0794713167,  0.3964701669,  0.7925218315]
# ----------------------------------------------------------------------------------------------------
#
# Run 27
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 176
# Optimized Value   : 0.64370000
# Evaluated Mean    : 0.64511800
# Evaluated Std     : 0.00161687
# Evaluated SEM     : 0.00036154
# Evaluated Min     : 0.64086000
# Evaluated Max     : 0.64775000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 398
# Optimization Time : 25.261065 s
#
# Evaluated Values:
# [0.64468, 0.6467 , 0.6448 , 0.64611, 0.64367, 0.64086, 0.6436 , 0.64713,
#  0.64775, 0.64608, 0.64638, 0.64583, 0.64493, 0.64546, 0.64324, 0.64544,
#  0.64322, 0.64523, 0.6442 , 0.64705]
#
# Initial Parameters:
# [0.908796571 , 0.1480812304, 0.9316217524, 0.8690627692, 0.8218723273,
#  0.3598173853, 0.8198721198, 0.1817033926, 0.2126209616, 0.6959983996,
#  0.3659168242, 0.6449720995, 0.1945739112, 0.1231941489, 0.9608135811,
#  0.9693122607, 0.6994862206, 0.3285305578, 0.5308429614, 0.0713595069,
#  0.6124682681, 0.0173357401, 0.2291752338, 0.1716368198]
#
# Optimal Parameters:
# [ 0.5595914264,  1.5757986887,  1.396427374 ,  1.2712893824,  1.8446302989,
#   0.0312449439,  0.1325403397,  1.479373144 ,  1.2465618653,  0.0679733991,
#  -0.0691309031,  0.1050403805,  0.0081908855,  0.1783054656,  1.4261311187,
#   1.3567243763,  1.5211763794,  0.4973330678,  0.5908747793,  0.3013323153,
#   0.7816162877,  0.1918392704,  0.2325809979, -0.0651926787]
# ----------------------------------------------------------------------------------------------------
#
# Run 28
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 177
# Optimized Value   : 0.64110000
# Evaluated Mean    : 0.64534900
# Evaluated Std     : 0.00165027
# Evaluated SEM     : 0.00036901
# Evaluated Min     : 0.64131000
# Evaluated Max     : 0.64819000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 402
# Optimization Time : 25.596096 s
#
# Evaluated Values:
# [0.64518, 0.64703, 0.64611, 0.64561, 0.64377, 0.64131, 0.64386, 0.64768,
#  0.64819, 0.64594, 0.64593, 0.64577, 0.64513, 0.64601, 0.64313, 0.64562,
#  0.64304, 0.64611, 0.6444 , 0.64716]
#
# Initial Parameters:
# [0.4859979492, 0.3134855983, 0.5928545916, 0.5388495959, 0.8208222388,
#  0.1681699936, 0.7886708539, 0.9073399324, 0.1513191786, 0.6385598502,
#  0.0204482374, 0.441729694 , 0.1062169866, 0.3316953766, 0.9856944419,
#  0.4606017013, 0.291802071 , 0.5311775661, 0.6869978953, 0.085870002 ,
#  0.70379701  , 0.7732596263, 0.358077326 , 0.7448635381]
#
# Optimal Parameters:
# [-0.2764438385,  1.55169577  ,  1.7605251374,  1.5843836234,  1.8187587031,
#   0.0421767207,  1.2795324252,  1.6372439267,  1.2924984201,  0.22002296  ,
#  -0.0269345399,  0.2962578984, -0.1987680816,  0.5041588237,  0.3219186833,
#  -0.1305868544,  1.5239045543,  0.4932193746,  0.6368960586,  0.0653811014,
#   0.694763713 ,  0.7935752795,  0.3684975861,  0.7322174015]
# ----------------------------------------------------------------------------------------------------
#
# Run 29
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 178
# Optimized Value   : 0.64630000
# Evaluated Mean    : 0.64532600
# Evaluated Std     : 0.00154852
# Evaluated SEM     : 0.00034626
# Evaluated Min     : 0.64155000
# Evaluated Max     : 0.64761000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 410
# Optimization Time : 26.185772 s
#
# Evaluated Values:
# [0.64488, 0.64747, 0.64616, 0.6456 , 0.64409, 0.64155, 0.64345, 0.64761,
#  0.64711, 0.64668, 0.64614, 0.64588, 0.64499, 0.6457 , 0.64331, 0.64527,
#  0.64387, 0.64583, 0.64386, 0.64707]
#
# Initial Parameters:
# [0.7608275692, 0.0464101376, 0.0032708871, 0.7605003536, 0.2769531808,
#  0.5945503444, 0.8036218146, 0.7402677744, 0.1239034672, 0.2438968692,
#  0.748428843 , 0.9205783868, 0.2357355697, 0.9391032789, 0.4081091944,
#  0.4620759117, 0.7294079941, 0.5779372506, 0.3477807167, 0.9240071009,
#  0.4847679255, 0.9369591861, 0.6895419866, 0.4903610315]
#
# Optimal Parameters:
# [ 0.1655256457,  1.6017905585,  1.6438896403,  1.5270200818,  1.2945246855,
#   1.6096894988,  1.272236851 ,  1.5870409328,  1.4361180073,  1.5683418776,
#   0.3068616707,  1.5774938379,  0.0053269208,  0.9793024253, -0.0433920791,
#   0.4139616642,  1.5636388329,  0.5683351118,  0.430972368 ,  0.8957264994,
#   0.5221572718,  0.786810467 ,  0.5433990095,  0.0986451069]
# ----------------------------------------------------------------------------------------------------
#
# Run 30
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 179
# Optimized Value   : 0.65170000
# Evaluated Mean    : 0.64399150
# Evaluated Std     : 0.00154841
# Evaluated SEM     : 0.00034623
# Evaluated Min     : 0.64038000
# Evaluated Max     : 0.64683000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 417
# Optimization Time : 26.323307 s
#
# Evaluated Values:
# [0.64382, 0.64581, 0.64438, 0.64471, 0.64389, 0.64038, 0.6424 , 0.64565,
#  0.64683, 0.64492, 0.64496, 0.6434 , 0.64384, 0.64476, 0.64258, 0.6433 ,
#  0.64131, 0.64447, 0.64266, 0.64576]
#
# Initial Parameters:
# [0.9180695286, 0.9403935557, 0.9611445873, 0.1282735573, 0.7343854482,
#  0.1418537547, 0.3206870255, 0.8783134777, 0.3925501756, 0.9542827898,
#  0.4333144504, 0.0052152104, 0.5921889116, 0.318609756 , 0.9316370681,
#  0.6026668473, 0.0078690534, 0.7991305598, 0.851774691 , 0.06652901  ,
#  0.7310172927, 0.1064287992, 0.0810809173, 0.7115609048]
#
# Optimal Parameters:
# [ 0.8497435481,  2.1061280833,  2.8380186229,  0.5629793168,  1.8486420814,
#   1.657953254 ,  0.1768314341,  0.6139044559,  0.2146727031,  0.5256483867,
#  -0.2247169662, -0.0063442792, -0.0107757398, -0.0458301757,  1.5929014237,
#   0.4681405241,  0.0877648456,  0.6417372592,  0.8190640515,  0.1070482592,
#   0.8747145579, -0.1403373191,  0.0916096641,  0.3014043499]
# ----------------------------------------------------------------------------------------------------
#
# SUMMARY
# ====================================================================================================
#
# Original Optimization-Shot Results:
# Maximum Optimized Value : 0.65820000
# Maximum Run             : 21
# Mean Optimized Value    : 0.64627000
# Std Optimized Value     : 0.00591660
#
# High-Shot Evaluation Results:
# Best Evaluated Mean     : 0.64642300
# Best Evaluated Mean Run : 24
# Mean of Evaluated Means : 0.64221832
# Std of Evaluated Means  : 0.00349421
#
# Optimizer Statistics:
# Mean Function Evals     : 403.93
# Std Function Evals      : 28.39
# Successful Runs         : 30/30
# Failed Runs             : 0/30
# Reached MaxIter         : 0/30
#
# Computational Runtime Statistics:
# Total Wall-Clock Time          : 799.030112 s
# Total Optimization Time        : 747.646149 s
# Time per Complete Opt. Run     : 24.921538 s
# Std Optimization Time per Run  : 1.888846 s
#
# ====================================================================================================
# BEST RUN ACCORDING TO ORIGINAL OPTIMIZED VALUE
# ====================================================================================================
# Run             : 21
# Optimized Value : 0.65820000
# Evaluated Mean  : 0.64477800
# Evaluated Std   : 0.00161566
# Evaluated SEM   : 0.00036127
# Evaluated Min   : 0.64096000
# Evaluated Max   : 0.64734000
#
# Evaluated Values:
# [0.64449, 0.64717, 0.64509, 0.64545, 0.6436 , 0.64096, 0.64326, 0.64701,
#  0.64734, 0.64616, 0.64575, 0.64454, 0.64351, 0.64509, 0.64267, 0.64474,
#  0.6437 , 0.64474, 0.64348, 0.64681]
#
# Initial Parameters:
# [0.7874185021, 0.9584562682, 0.8591507262, 0.9645583872, 0.1861908476,
#  0.9733637291, 0.0280706788, 0.0552851721, 0.6590788677, 0.6741578349,
#  0.8616838769, 0.8939815973, 0.0797041007, 0.3456415486, 0.4524772268,
#  0.042159618 , 0.4282577349, 0.1251842981, 0.1376304707, 0.815588407 ,
#  0.0915335873, 0.590188672 , 0.8152434753, 0.271484639 ]
#
# Optimal Parameters:
# [ 0.5140565715,  1.5689428033,  1.5314905764,  1.5229092337,  1.5634125897,
#   1.8614259028,  0.9944535236,  1.6298306053,  1.3360567784,  1.6398062923,
#   0.5875501981,  1.5283169235,  0.0091807276,  0.0374152976, -0.1320051509,
#  -0.3367672933,  1.6543919764,  0.2230791565, -0.1003076708,  0.3056960788,
#  -0.1512741259,  0.4044585702,  0.4449720243,  0.3894601932]
#
# ====================================================================================================
# BEST RUN ACCORDING TO HIGH-SHOT EVALUATED MEAN
# ====================================================================================================
# Run             : 24
# Optimized Value : 0.64800000
# Evaluated Mean  : 0.64642300
# Evaluated Std   : 0.00182714
# Evaluated SEM   : 0.00040856
# Evaluated Min   : 0.64180000
# Evaluated Max   : 0.64952000
#
# Evaluated Values:
# [0.64637, 0.64866, 0.64652, 0.64645, 0.64492, 0.6418 , 0.64475, 0.64899,
#  0.64952, 0.64773, 0.64781, 0.64646, 0.64638, 0.6466 , 0.64453, 0.64665,
#  0.64411, 0.64736, 0.64475, 0.6481 ]
#
# Initial Parameters:
# [0.0683064102, 0.5061877572, 0.2800764934, 0.4917358842, 0.3376481488,
#  0.6337766115, 0.7941202296, 0.2237709719, 0.8893153608, 0.9462072178,
#  0.9270749557, 0.8979372613, 0.8865232604, 0.1112901922, 0.4404611446,
#  0.6571269562, 0.6018173982, 0.0668305069, 0.5031888045, 0.7100940384,
#  0.3646853666, 0.6647653187, 0.3408936761, 0.3312253256]
#
# Optimal Parameters:
# [ 0.8226076141,  1.6026673405,  1.6031892506,  1.5241363524,  1.6669369492,
#   1.8090757244,  0.2018137699,  1.6039461166,  2.0475089605,  1.5842068216,
#   1.3632671341,  1.5878770031, -0.0430205397,  0.0086777576, -0.2256232061,
#   0.1640481564,  1.5730024674,  0.0837553134,  0.5217766598,  0.7238915725,
#   0.3785192681,  0.6782594858, -0.0642155107, -0.0409232979]
# ====================================================================================================
#
# Report saved to:
# /Users/sungwonyun/Documents/Qiskit/Minimum Error Discrimination/Simulator Seed 150 ReRe /Sym_QNN_CB_report.txt
