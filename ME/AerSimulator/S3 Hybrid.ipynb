# %%
# 0,1: 00 for psi_1, 01 for psi_2 ...
# 2,3,4: For states
# 5,6: Ancillary qubits

# %%
from qiskit import QuantumCircuit
from numpy import sqrt

def circuit_init():
    qc = QuantumCircuit(7)
    return qc

def PREP(qc):

    desired_vector = [
        1 / sqrt(3), 0, 0, 0, 0, 0, 0, 0,
        -1 / (8 * sqrt(3)), -1 / 8, -1 / 8, -sqrt(3) / 8,
        -1 / 8, -sqrt(3) / 8, -sqrt(3) / 8, -3 / 8,
        -1 / (8 * sqrt(3)), 1 / 8, 1 / 8, -sqrt(3) / 8,
        1 / 8, -sqrt(3) / 8, -sqrt(3) / 8, 3 / 8,
        0, 0, 0, 0, 0, 0, 0, 0
    ]
    
    qc.initialize(desired_vector, [4, 3, 2, 1, 0])
    return qc

# %%
from pennylane.templates.state_preparations.mottonen import compute_theta, gray_code
from qiskit.circuit.library.standard_gates import RXGate,RYGate, RZGate
from qiskit.circuit.library import MCXGate
from qiskit.circuit.library.standard_gates import XGate
from numpy import array, log2

def RRR_X(qc, wires, params):
    qc.append(RXGate(params[0]),[wires[0]])
    qc.append(RXGate(params[1]),[wires[1]])
    qc.append(RXGate(params[2]),[wires[2]])
    
def RRR_Z(qc, wires, params):
    qc.append(RZGate(params[0]),[wires[0]])
    qc.append(RZGate(params[1]),[wires[1]])
    qc.append(RZGate(params[2]),[wires[2]])


def U_CCCR_decom(qc,wires,params):
    # Make sure that control qubits should be increasing order
    params = array(params)
    params = compute_theta(params) #can be on/off

    num_Ucontrols = len(wires)-1
    code = gray_code(3)
    n_selections = len(code)
    control_order = [int(log2(int(code[i], 2) ^ int(code[(i + 1) % n_selections], 2))) for i in range(n_selections)]

    for i in range(n_selections):
        qc.ry(params[i],wires[3])
        qc.cx(wires[num_Ucontrols-1 - control_order[i]],wires[3])   
    return qc


def CRRR_X(qc, wires, state, params):
    qc.append(RXGate(params[0]).control(1,ctrl_state = state[::-1]), [wires[0], wires[1]])  # Control: wires[0] Target: wires[1]
    qc.append(RXGate(params[1]).control(1,ctrl_state = state[::-1]), [wires[0], wires[2]])  # Control: wires[0] Target: wires[2]
    qc.append(RXGate(params[2]).control(1,ctrl_state = state[::-1]), [wires[0], wires[3]])  # Control: wires[0] Target: wires[3]
    return qc

def CRRR_Z(qc, wires, state, params):
    qc.append(RZGate(params[0]).control(1,ctrl_state = state[::-1]), [wires[0], wires[1]])  # Control: wires[0] Target: wires[1]
    qc.append(RZGate(params[1]).control(1,ctrl_state = state[::-1]), [wires[0], wires[2]])  # Control: wires[0] Target: wires[2]
    qc.append(RZGate(params[2]).control(1,ctrl_state = state[::-1]), [wires[0], wires[3]])  # Control: wires[0] Target: wires[2]
    return qc

def U_CCCcR_decom(qc,wires,params):
    # Make sure that control qubits should be increasing order
    params = array(params)
    params = compute_theta(params) #can be on/off

    num_Ucontrols = len(wires)-2
    code = gray_code(3)
    n_selections = len(code)
    control_order = [int(log2(int(code[i], 2) ^ int(code[(i + 1) % n_selections], 2))) for i in range(n_selections)]

    for i in range(n_selections):
        qc.cry(params[i],wires[3],wires[4])
        CCX(qc,[wires[num_Ucontrols-1 - control_order[i]],wires[3],wires[4]],'11')
    
    return qc

def CCRRR_X(qc, wires, state, params):
    qc.append(RXGate(params[0]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[2]])  # Control: wires[0] wires[1]
    qc.append(RXGate(params[1]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[3]])  # Control: wires[0] wires[1]
    qc.append(RXGate(params[2]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[4]])  # Control: wires[0] wires[1]
    return qc

def CCRRR_Z(qc, wires, state, params):
    qc.append(RZGate(params[0]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[2]])  # Control: wires[0] wires[1]
    qc.append(RZGate(params[1]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[3]])  # Control: wires[0] wires[1]
    qc.append(RZGate(params[2]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[4]])  # Control: wires[0] wires[1]
    return qc

def CCX(qc, wires, state):
    mcx_gate = MCXGate(num_ctrl_qubits=2,ctrl_state=state[::-1])
    qc.append(mcx_gate, [wires[0], wires[1],wires[2]])
    return qc

def CCCX(qc, wires, state):
    mcx_gate = MCXGate(num_ctrl_qubits=3,ctrl_state=state[::-1])
    qc.append(mcx_gate, [wires[0], wires[1],wires[2], wires[3]])
    return qc


def CX01(qc, wires):
    qc.append(XGate().control(1, ctrl_state='1'),[wires[0], wires[1]])
    return qc

# %%
def Ansatz(qc, wires, params):


    #Big made by HEA 
    RRR_X(qc,wires[0:3],params[0:3])
    RRR_Z(qc,wires[0:3],params[3:6])
    qc.cx(wires[0],wires[1])
    qc.cx(wires[1],wires[2])

    #Module 1
    U_CCCR_decom(qc,wires[0:4],params[6:14])
    CRRR_X(qc,[wires[3],wires[0],wires[1],wires[2]],'0',params[14:17])
    CRRR_Z(qc,[wires[3],wires[0],wires[1],wires[2]],'0',params[17:20])
    CCX(qc,[wires[0],wires[3], wires[1]],'10')
    CCX(qc,[wires[1],wires[3], wires[2]],'10')

    CRRR_X(qc,[wires[3],wires[0],wires[1],wires[2]],'1',params[20:23])
    CRRR_Z(qc,[wires[3],wires[0],wires[1],wires[2]],'1',params[23:26])
    CCX(qc,[wires[0],wires[3], wires[1]],'11')
    CCX(qc,[wires[1],wires[3], wires[2]],'11')

    #Module 2
    U_CCCcR_decom(qc, wires[0:5],params[26:34])
    CCRRR_X(qc,[wires[3],wires[4],wires[0],wires[1],wires[2]],'10',params[34:37])
    CCRRR_Z(qc,[wires[3],wires[4],wires[0],wires[1],wires[2]],'10',params[37:40])
    CCCX(qc,[wires[0],wires[3],wires[4],wires[1]],'110')
    CCCX(qc,[wires[1],wires[3],wires[4],wires[2]],'110')
    CCRRR_X(qc,[wires[3],wires[4],wires[0],wires[1],wires[2]],'11',params[40:43])
    CCRRR_Z(qc,[wires[3],wires[4],wires[0],wires[1],wires[2]],'11',params[43:46])
    CCCX(qc,[wires[0],wires[3],wires[4],wires[1]],'111')
    CCCX(qc,[wires[1],wires[3],wires[4],wires[2]],'111')    
    
    CX01(qc, [wires[4],wires[3]])
    qc.measure_all()
    return qc

# %%
from numpy.random import rand
num_params=46
#params = rand(num_params)
params = list(range(num_params))
qc = QuantumCircuit(5)
#PREP(qc)
Ansatz(qc, [0,1,2,3,4] , params)
qc.draw(output='mpl', style = 'clifford')

# %%
from numpy.random import rand
num_shots=10000
num_params=46
params = list(range(num_params))
qc = circuit_init()
PREP(qc)
Ansatz(qc, [2,3,4,5,6], params)
qc.draw(output='mpl', style = 'clifford')

# %%
from qiskit_aer import AerSimulator
from qiskit import transpile
from scipy.optimize import minimize

import numpy as np
import os
import time


# ============================================================
# Simulator
# ============================================================

aersim = AerSimulator()


# ============================================================
# Settings
# ============================================================

num_times = 30
num_shots = 10000

optimizer_name = "COBYLA"
tol_value = 1e-8
maxiter = 3000

BASE_SEED = 150

report_filename = (
    "TT_Hybrid_report.txt"
)


# ============================================================
# High-Shot Evaluation Settings
# ============================================================

evaluation_num_times = 20
evaluation_num_shots = 100000

EVALUATION_BASE_SEED = 10000

evaluation_seeds = np.array(
    [
        EVALUATION_BASE_SEED + i
        for i in range(evaluation_num_times)
    ],
    dtype=int
)


# ============================================================
# Storage
# ============================================================

final_optimized_values = []

initial_params_all_runs = []
optimal_params_all_runs = []

optimization_success_all_runs = []
optimization_status_all_runs = []
optimization_message_all_runs = []
optimization_nfev_all_runs = []
reached_maxiter_all_runs = []

# ------------------------------------------------------------
# Runtime Storage
# ------------------------------------------------------------

optimization_wall_times = []


# ------------------------------------------------------------
# High-Shot Evaluation Storage
# ------------------------------------------------------------

evaluation_values_all_runs = []

evaluation_mean_all_runs = []
evaluation_std_all_runs = []
evaluation_min_all_runs = []
evaluation_max_all_runs = []


# ============================================================
# Objective Function
# ============================================================

def objective_function(
    params,
    run_seed,
    shots=None,
    print_result=True
):

    if shots is None:
        shots = num_shots


    # --------------------------------------------------------
    # Construct circuit
    # --------------------------------------------------------

    qc = circuit_init()

    PREP(qc)

    Ansatz(
        qc,
        wires=[2, 3, 4, 5, 6],
        params=params
    )


    qc_reverse = qc.reverse_bits()


    # --------------------------------------------------------
    # Transpile
    # --------------------------------------------------------

    t_qc = transpile(
        qc_reverse,
        aersim,
        seed_transpiler=run_seed
    )


    # --------------------------------------------------------
    # Run simulator
    # --------------------------------------------------------

    job = aersim.run(
        t_qc,
        shots=shots,
        seed_simulator=run_seed
    )


    result = job.result()

    counts = result.get_counts()


    # --------------------------------------------------------
    # Target counts
    # --------------------------------------------------------

    tar_00 = 0
    tar_01 = 0
    tar_10 = 0


    for outcome, count in counts.items():

        if outcome[0:2] == "00":

            if outcome[5:7] == "00":

                tar_00 += count


        if outcome[0:2] == "01":

            if outcome[5:7] == "01":

                tar_01 += count


        if outcome[0:2] == "10":

            if outcome[5:7] == "10":

                tar_10 += count


    # --------------------------------------------------------
    # Success probability
    # --------------------------------------------------------

    p_suc = (
        tar_00
        + tar_01
        + tar_10
    ) / shots


    if print_result:

        print(
            f"success_probability = "
            f"{p_suc:.8f}"
        )


    # --------------------------------------------------------
    # Avoid division by zero
    # --------------------------------------------------------

    if p_suc == 0:

        return 1e10


    # --------------------------------------------------------
    # COBYLA minimizes.
    #
    # Minimizing 1 / p_suc maximizes p_suc.
    # --------------------------------------------------------

    return 1.0 / p_suc


# ============================================================
# Run Optimization
# ============================================================

# Measures the complete workflow:
# optimization + final evaluations + high-shot evaluations + overhead.
total_wall_start = time.perf_counter()

for run in range(num_times):


    # ========================================================
    # Optimization Seed
    # ========================================================

    run_seed = (
        BASE_SEED + run
    )


    rng = np.random.default_rng(
        run_seed
    )


    print(
        "\n"
        + "=" * 80
    )


    print(
        f"Optimization Run "
        f"{run + 1}/{num_times}"
    )


    print(
        f"Optimization Seed : "
        f"{run_seed}"
    )


    print(
        "=" * 80
    )


    # ========================================================
    # Generate Random Initial Parameters
    # ========================================================

    initial_params = rng.random(
        num_params
    )


    initial_params_all_runs.append(
        initial_params.copy()
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    # ========================================================
    # Run COBYLA Optimization
    # ========================================================

    print(
        "\nStarting COBYLA optimization..."
    )


    optimization_start = time.perf_counter()

    result = minimize(

        fun=lambda params: objective_function(
            params,
            run_seed,
            shots=num_shots,
            print_result=True
        ),

        x0=initial_params,

        method=optimizer_name,

        options={
            "maxiter": maxiter,
            "disp": True,
            "tol": tol_value
        }
    )

    optimization_end = time.perf_counter()

    run_optimization_wall_time = (
        optimization_end
        - optimization_start
    )

    optimization_wall_times.append(
        run_optimization_wall_time
    )

    print(
        f"Optimization Wall-Clock Time : "
        f"{run_optimization_wall_time:.6f} s"
    )


    # ========================================================
    # Optimization Status
    # ========================================================

    optimization_success = bool(
        result.success
    )


    optimization_status = getattr(
        result,
        "status",
        None
    )


    optimization_message = str(
        getattr(
            result,
            "message",
            "No message returned"
        )
    )


    optimization_nfev = getattr(
        result,
        "nfev",
        None
    )


    # ========================================================
    # Detect Maximum Function Evaluations
    # ========================================================

    message_lower = (
        optimization_message.lower()
    )


    reached_maxiter = (

        "maximum number"
        in message_lower

        or "maximum function"
        in message_lower

        or "maxiter"
        in message_lower

        or "maxfun"
        in message_lower

        or "maximum iterations"
        in message_lower

        or "maximum evaluations"
        in message_lower
    )


    if optimization_nfev is not None:

        if optimization_nfev >= maxiter:

            reached_maxiter = True


    # ========================================================
    # Store Optimization Status
    # ========================================================

    optimization_success_all_runs.append(
        optimization_success
    )


    optimization_status_all_runs.append(
        optimization_status
    )


    optimization_message_all_runs.append(
        optimization_message
    )


    optimization_nfev_all_runs.append(
        optimization_nfev
    )


    reached_maxiter_all_runs.append(
        reached_maxiter
    )


    # ========================================================
    # Optimal Parameters
    # ========================================================

    optimal_params = (
        result.x.copy()
    )


    optimal_params_all_runs.append(
        optimal_params.copy()
    )


    # ========================================================
    # Final Optimization-Shot Evaluation
    # ========================================================

    final_objective = objective_function(
        optimal_params,
        run_seed,
        shots=num_shots,
        print_result=False
    )


    if final_objective >= 1e10:

        final_value = 0.0

    else:

        final_value = (
            1.0 / final_objective
        )


    final_optimized_values.append(
        final_value
    )


    # ========================================================
    # High-Shot Evaluation
    # ========================================================

    print(
        "\n"
        + "-" * 80
    )


    print(
        "HIGH-SHOT EVALUATION OF "
        "OPTIMIZED PARAMETERS"
    )


    print(
        "-" * 80
    )


    print(
        f"Optimization Shots     : "
        f"{num_shots}"
    )


    print(
        f"Evaluation Shots       : "
        f"{evaluation_num_shots}"
    )


    print(
        f"Number of Evaluations : "
        f"{evaluation_num_times}"
    )


    print(
        "\nEvaluation Results:"
    )


    evaluation_values = []


    for eval_index, eval_seed in enumerate(
        evaluation_seeds
    ):


        eval_objective = objective_function(
            optimal_params,
            int(eval_seed),
            shots=evaluation_num_shots,
            print_result=False
        )


        if eval_objective >= 1e10:

            eval_value = 0.0

        else:

            eval_value = (
                1.0 / eval_objective
            )


        evaluation_values.append(
            eval_value
        )


        print(
            f"Evaluation "
            f"{eval_index + 1:2d}/"
            f"{evaluation_num_times:2d}"
            f" | Value = "
            f"{eval_value:.8f}"
        )


    # ========================================================
    # Evaluation Statistics
    # ========================================================

    evaluation_values = np.array(
        evaluation_values,
        dtype=float
    )


    evaluation_mean = np.mean(
        evaluation_values
    )


    evaluation_std = np.std(
        evaluation_values
    )


    evaluation_min = np.min(
        evaluation_values
    )


    evaluation_max = np.max(
        evaluation_values
    )


    # ========================================================
    # Store Evaluation Results
    # ========================================================

    evaluation_values_all_runs.append(
        evaluation_values.copy()
    )


    evaluation_mean_all_runs.append(
        evaluation_mean
    )


    evaluation_std_all_runs.append(
        evaluation_std
    )


    evaluation_min_all_runs.append(
        evaluation_min
    )


    evaluation_max_all_runs.append(
        evaluation_max
    )


    # ========================================================
    # Individual Run Report
    # ========================================================

    print(
        "\n"
        + "=" * 80
    )


    print(
        f"RUN {run + 1} RESULT"
    )


    print(
        "=" * 80
    )


    print(
        f"Optimization Success : "
        f"{optimization_success}"
    )


    print(
        f"Reached MaxIter      : "
        f"{reached_maxiter}"
    )


    print(
        f"Status               : "
        f"{optimization_status}"
    )


    print(
        f"Message              : "
        f"{optimization_message}"
    )


    print(
        f"Function Evaluations : "
        f"{optimization_nfev}"
    )


    print(
        f"Optimization Time    : "
        f"{run_optimization_wall_time:.6f} s"
    )


    print(
        f"Final Objective Value: "
        f"{result.fun}"
    )


    print(
        "\n"
        + "-" * 80
    )


    print(
        "OPTIMIZED AND HIGH-SHOT "
        "EVALUATED VALUES"
    )


    print(
        "-" * 80
    )


    print(
        f"Final Optimized Value : "
        f"{final_value:.8f}"
    )


    print(
        f"Evaluated Mean        : "
        f"{evaluation_mean:.8f}"
    )


    print(
        f"Evaluated Std         : "
        f"{evaluation_std:.8f}"
    )


    print(
        f"Evaluated Min         : "
        f"{evaluation_min:.8f}"
    )


    print(
        f"Evaluated Max         : "
        f"{evaluation_max:.8f}"
    )


    print(
        "\nAll Evaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values,
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "=" * 80
    )


# ============================================================
# Runtime Statistics
# ============================================================

total_wall_end = time.perf_counter()

total_wall_time = (
    total_wall_end
    - total_wall_start
)

optimization_wall_times = np.array(
    optimization_wall_times,
    dtype=float
)

total_optimization_wall_time = np.sum(
    optimization_wall_times
)

mean_optimization_wall_time = np.mean(
    optimization_wall_times
)

std_optimization_wall_time = np.std(
    optimization_wall_times
)


# ============================================================
# Convert Results to NumPy Arrays
# ============================================================

final_optimized_values = np.array(
    final_optimized_values,
    dtype=float
)


initial_params_all_runs = np.array(
    initial_params_all_runs
)


optimal_params_all_runs = np.array(
    optimal_params_all_runs
)


evaluation_values_all_runs = np.array(
    evaluation_values_all_runs,
    dtype=float
)


evaluation_mean_all_runs = np.array(
    evaluation_mean_all_runs,
    dtype=float
)


evaluation_std_all_runs = np.array(
    evaluation_std_all_runs,
    dtype=float
)


evaluation_min_all_runs = np.array(
    evaluation_min_all_runs,
    dtype=float
)


evaluation_max_all_runs = np.array(
    evaluation_max_all_runs,
    dtype=float
)


# ============================================================
# Original Optimization Statistics
# ============================================================

maximum_value = np.max(
    final_optimized_values
)


mean_value = np.mean(
    final_optimized_values
)


std_value = np.std(
    final_optimized_values
)


maximum_run_index = np.argmax(
    final_optimized_values
)


maximum_run = (
    maximum_run_index + 1
)


# ============================================================
# High-Shot Evaluation Statistics
# ============================================================

maximum_evaluated_mean = np.max(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run_index = np.argmax(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run = (
    maximum_evaluated_mean_run_index
    + 1
)


mean_of_evaluated_means = np.mean(
    evaluation_mean_all_runs
)


std_of_evaluated_means = np.std(
    evaluation_mean_all_runs
)


# ============================================================
# Function Evaluation Statistics
# ============================================================

nfev_values = np.array(
    [
        nfev
        for nfev
        in optimization_nfev_all_runs
        if nfev is not None
    ],
    dtype=float
)


if len(nfev_values) > 0:

    mean_nfev = np.mean(
        nfev_values
    )


    std_nfev = np.std(
        nfev_values
    )

else:

    mean_nfev = np.nan
    std_nfev = np.nan


# ============================================================
# Optimization Success Statistics
# ============================================================

num_successful_runs = sum(
    optimization_success_all_runs
)


num_failed_runs = (
    num_times
    - num_successful_runs
)


num_reached_maxiter = sum(
    reached_maxiter_all_runs
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

best_initial_params = (
    initial_params_all_runs[
        maximum_run_index
    ]
)


best_optimal_params = (
    optimal_params_all_runs[
        maximum_run_index
    ]
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

best_evaluated_initial_params = (
    initial_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_optimal_params = (
    optimal_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_values = (
    evaluation_values_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


# ============================================================
# Print Final Report
# ============================================================

print("\n")


print(
    "=" * 100
)


print(
    "FINAL OPTIMIZATION AND "
    "HIGH-SHOT EVALUATION REPORT"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Settings
# ------------------------------------------------------------

print(
    f"Optimizer               : "
    f"{optimizer_name}"
)


print(
    f"Tolerance               : "
    f"{tol_value}"
)


print(
    f"Max Iteration           : "
    f"{maxiter}"
)


print(
    f"Number of Runs          : "
    f"{num_times}"
)


print(
    f"Optimization Shots      : "
    f"{num_shots}"
)


print(
    f"Optimization Base Seed  : "
    f"{BASE_SEED}"
)


print(
    f"Evaluation Shots        : "
    f"{evaluation_num_shots}"
)


print(
    f"Evaluations Per Run     : "
    f"{evaluation_num_times}"
)


print(
    f"Evaluation Base Seed    : "
    f"{EVALUATION_BASE_SEED}"
)


# Evaluation seeds are printed only once.
print(
    "Evaluation Seeds        : "
    + np.array2string(
        evaluation_seeds,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Results for Every Run
# ============================================================

for i in range(num_times):


    print(
        f"\nRun {i + 1:2d}"
    )


    print(
        "-" * 100
    )


    print(
        f"Optimization Seed : "
        f"{BASE_SEED + i}"
    )


    print(
        f"Optimized Value   : "
        f"{final_optimized_values[i]:.8f}"
    )


    print(
        f"Evaluated Mean    : "
        f"{evaluation_mean_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Std     : "
        f"{evaluation_std_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Min     : "
        f"{evaluation_min_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Max     : "
        f"{evaluation_max_all_runs[i]:.8f}"
    )


    print(
        f"Success           : "
        f"{optimization_success_all_runs[i]}"
    )


    print(
        f"Reached MaxIter   : "
        f"{reached_maxiter_all_runs[i]}"
    )


    print(
        f"Status            : "
        f"{optimization_status_all_runs[i]}"
    )


    print(
        f"Message           : "
        f"{optimization_message_all_runs[i]}"
    )


    print(
        f"Function Evals    : "
        f"{optimization_nfev_all_runs[i]}"
    )


    print(
        f"Optimization Time : "
        f"{optimization_wall_times[i]:.6f} s"
    )


    print(
        "\nEvaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values_all_runs[i],
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "-" * 100
    )


# ============================================================
# Summary
# ============================================================

print(
    "\nSUMMARY"
)


print(
    "=" * 100
)


print(
    "\nOriginal Optimization-Shot Results:"
)


print(
    f"Maximum Optimized Value : "
    f"{maximum_value:.8f}"
)


print(
    f"Maximum Run             : "
    f"{maximum_run}"
)


print(
    f"Mean Optimized Value    : "
    f"{mean_value:.8f}"
)


print(
    f"Std Optimized Value     : "
    f"{std_value:.8f}"
)


print(
    "\nHigh-Shot Evaluation Results:"
)


print(
    f"Best Evaluated Mean     : "
    f"{maximum_evaluated_mean:.8f}"
)


print(
    f"Best Evaluated Mean Run : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Mean of Evaluated Means : "
    f"{mean_of_evaluated_means:.8f}"
)


print(
    f"Std of Evaluated Means  : "
    f"{std_of_evaluated_means:.8f}"
)


print(
    "\nOptimizer Statistics:"
)


print(
    f"Mean Function Evals     : "
    f"{mean_nfev:.2f}"
)


print(
    f"Std Function Evals      : "
    f"{std_nfev:.2f}"
)


print(
    f"Successful Runs         : "
    f"{num_successful_runs}/"
    f"{num_times}"
)


print(
    f"Failed Runs             : "
    f"{num_failed_runs}/"
    f"{num_times}"
)


print(
    f"Reached MaxIter         : "
    f"{num_reached_maxiter}/"
    f"{num_times}"
)


# ------------------------------------------------------------
# Computational Runtime Statistics
# ------------------------------------------------------------

print(
    "\nComputational Runtime Statistics:"
)

print(
    f"Total Wall-Clock Time          : "
    f"{total_wall_time:.6f} s"
)

print(
    f"Total Optimization Time        : "
    f"{total_optimization_wall_time:.6f} s"
)

print(
    f"Time per Complete Opt. Run     : "
    f"{mean_optimization_wall_time:.6f} s"
)

print(
    f"Std Optimization Time per Run  : "
    f"{std_optimization_wall_time:.6f} s"
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "ORIGINAL OPTIMIZED VALUE"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        evaluation_values_all_runs[
            maximum_run_index
        ],
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_optimal_params,
        precision=10,
        separator=", "
    )
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "HIGH-SHOT EVALUATED MEAN"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        best_evaluated_values,
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_evaluated_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_evaluated_optimal_params,
        precision=10,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Save Report to TXT
# ============================================================

with open(
    report_filename,
    "w"
) as f:


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "FINAL OPTIMIZATION AND "
        "HIGH-SHOT EVALUATION REPORT\n"
    )


    f.write(
        "=" * 100
        + "\n\n"
    )


    # ========================================================
    # Settings
    # ========================================================

    f.write(
        f"Optimizer               : "
        f"{optimizer_name}\n"
    )


    f.write(
        f"Tolerance               : "
        f"{tol_value}\n"
    )


    f.write(
        f"Max Iteration           : "
        f"{maxiter}\n"
    )


    f.write(
        f"Number of Runs          : "
        f"{num_times}\n"
    )


    f.write(
        f"Optimization Shots      : "
        f"{num_shots}\n"
    )


    f.write(
        f"Optimization Base Seed  : "
        f"{BASE_SEED}\n"
    )


    f.write(
        f"Evaluation Shots        : "
        f"{evaluation_num_shots}\n"
    )


    f.write(
        f"Evaluations Per Run     : "
        f"{evaluation_num_times}\n"
    )


    f.write(
        f"Evaluation Base Seed    : "
        f"{EVALUATION_BASE_SEED}\n"
    )


    # Evaluation seeds are saved only once.
    f.write(
        "Evaluation Seeds        : "
    )


    f.write(
        np.array2string(
            evaluation_seeds,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    # ========================================================
    # Results for Every Run
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "RESULTS FOR EACH RUN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    for i in range(num_times):


        f.write(
            f"\nRun {i + 1:2d}\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


        f.write(
            f"Optimization Seed : "
            f"{BASE_SEED + i}\n"
        )


        f.write(
            f"Optimized Value   : "
            f"{final_optimized_values[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Mean    : "
            f"{evaluation_mean_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Std     : "
            f"{evaluation_std_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Min     : "
            f"{evaluation_min_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Max     : "
            f"{evaluation_max_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Success           : "
            f"{optimization_success_all_runs[i]}\n"
        )


        f.write(
            f"Reached MaxIter   : "
            f"{reached_maxiter_all_runs[i]}\n"
        )


        f.write(
            f"Status            : "
            f"{optimization_status_all_runs[i]}\n"
        )


        f.write(
            f"Message           : "
            f"{optimization_message_all_runs[i]}\n"
        )


        f.write(
            f"Function Evals    : "
            f"{optimization_nfev_all_runs[i]}\n"
        )


        f.write(
            f"Optimization Time : "
            f"{optimization_wall_times[i]:.6f} s\n"
        )


        f.write(
            "\nEvaluated Values:\n"
        )


        f.write(
            np.array2string(
                evaluation_values_all_runs[i],
                precision=8,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nInitial Parameters:\n"
        )


        f.write(
            np.array2string(
                initial_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nOptimal Parameters:\n"
        )


        f.write(
            np.array2string(
                optimal_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


    # ========================================================
    # Summary
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "SUMMARY\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "\nOriginal Optimization-Shot Results:\n"
    )


    f.write(
        f"Maximum Optimized Value : "
        f"{maximum_value:.8f}\n"
    )


    f.write(
        f"Maximum Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Mean Optimized Value    : "
        f"{mean_value:.8f}\n"
    )


    f.write(
        f"Std Optimized Value     : "
        f"{std_value:.8f}\n"
    )


    f.write(
        "\nHigh-Shot Evaluation Results:\n"
    )


    f.write(
        f"Best Evaluated Mean     : "
        f"{maximum_evaluated_mean:.8f}\n"
    )


    f.write(
        f"Best Evaluated Mean Run : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Mean of Evaluated Means : "
        f"{mean_of_evaluated_means:.8f}\n"
    )


    f.write(
        f"Std of Evaluated Means  : "
        f"{std_of_evaluated_means:.8f}\n"
    )


    f.write(
        "\nOptimizer Statistics:\n"
    )


    f.write(
        f"Mean Function Evals     : "
        f"{mean_nfev:.2f}\n"
    )


    f.write(
        f"Std Function Evals      : "
        f"{std_nfev:.2f}\n"
    )


    f.write(
        f"Successful Runs         : "
        f"{num_successful_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Failed Runs             : "
        f"{num_failed_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Reached MaxIter         : "
        f"{num_reached_maxiter}/"
        f"{num_times}\n"
    )


    # --------------------------------------------------------
    # Computational Runtime Statistics
    # --------------------------------------------------------

    f.write(
        "\nComputational Runtime Statistics:\n"
    )

    f.write(
        f"Total Wall-Clock Time          : "
        f"{total_wall_time:.6f} s\n"
    )

    f.write(
        f"Total Optimization Time        : "
        f"{total_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Time per Complete Opt. Run     : "
        f"{mean_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Std Optimization Time per Run  : "
        f"{std_optimization_wall_time:.6f} s\n"
    )


    # ========================================================
    # Best Original Optimization Run
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "ORIGINAL OPTIMIZED VALUE\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            evaluation_values_all_runs[
                maximum_run_index
            ],
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    # ========================================================
    # Best High-Shot Evaluated Run
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "HIGH-SHOT EVALUATED MEAN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_values,
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


# ============================================================
# Report Location
# ============================================================

print(
    "\nReport saved to:"
)


print(
    os.path.abspath(
        report_filename
    )
)
# Out:
# ================================================================================
# Optimization Run 1/30
# Optimization Seed : 150
# ================================================================================
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566, 0.6883896757,
#  0.5848087428, 0.2739643248, 0.8377858251, 0.3022293541, 0.1728462164,
#  0.8017433668, 0.3441099205, 0.4375847094, 0.152681156 , 0.2761357842,
#  0.5638672039, 0.8646746614, 0.0827886029, 0.9748236223, 0.9228236344,
#  0.4073736921, 0.7807688858, 0.6465955762, 0.2254609107, 0.8244806881,
#  0.3453562772, 0.5685671364, 0.6863696968, 0.2470087963, 0.8753744063,
#  0.1559330851]
#
# Starting COBYLA optimization...
# success_probability = 0.32870000
# success_probability = 0.32670000
# success_probability = 0.35700000
# success_probability = 0.36120000
# success_probability = 0.36150000
# success_probability = 0.35900000
# success_probability = 0.36250000
# success_probability = 0.35570000
# success_probability = 0.35220000
# success_probability = 0.32060000
# success_probability = 0.33980000
# success_probability = 0.39360000
# success_probability = 0.41940000
# success_probability = 0.45010000
# success_probability = 0.49020000
# success_probability = 0.48460000
# success_probability = 0.48970000
# success_probability = 0.48720000
# success_probability = 0.49020000
# success_probability = 0.49020000
# success_probability = 0.49020000
# success_probability = 0.48440000
# success_probability = 0.48080000
# success_probability = 0.49540000
# success_probability = 0.49390000
# success_probability = 0.49500000
# success_probability = 0.49450000
# success_probability = 0.49520000
# success_probability = 0.49130000
# success_probability = 0.49590000
# success_probability = 0.49210000
# success_probability = 0.47060000
# success_probability = 0.52640000
# success_probability = 0.51710000
# success_probability = 0.54460000
# success_probability = 0.54520000
# success_probability = 0.54520000
# success_probability = 0.54320000
# success_probability = 0.54520000
# success_probability = 0.54520000
# success_probability = 0.54520000
# success_probability = 0.54570000
# success_probability = 0.54690000
# success_probability = 0.54590000
# success_probability = 0.54690000
# success_probability = 0.54690000
# success_probability = 0.54690000
# success_probability = 0.61520000
# success_probability = 0.67140000
# success_probability = 0.62210000
# success_probability = 0.66280000
# success_probability = 0.64070000
# success_probability = 0.66940000
# success_probability = 0.69550000
# success_probability = 0.69610000
# success_probability = 0.71560000
# success_probability = 0.68590000
# success_probability = 0.73590000
# success_probability = 0.73540000
# success_probability = 0.72600000
# success_probability = 0.72980000
# success_probability = 0.69780000
# success_probability = 0.72830000
# success_probability = 0.69990000
# success_probability = 0.74280000
# success_probability = 0.71310000
# success_probability = 0.74450000
# success_probability = 0.74370000
# success_probability = 0.74180000
# success_probability = 0.75100000
# success_probability = 0.75100000
# success_probability = 0.72640000
# success_probability = 0.74150000
# success_probability = 0.72880000
# success_probability = 0.75210000
# success_probability = 0.75280000
# success_probability = 0.75410000
# success_probability = 0.73840000
# success_probability = 0.75360000
# success_probability = 0.72340000
# success_probability = 0.75630000
# success_probability = 0.74240000
# success_probability = 0.75670000
# success_probability = 0.73980000
# success_probability = 0.75670000
# success_probability = 0.75510000
# success_probability = 0.75310000
# success_probability = 0.75720000
# success_probability = 0.75720000
# success_probability = 0.75570000
# success_probability = 0.75770000
# success_probability = 0.74690000
# success_probability = 0.75770000
# success_probability = 0.73310000
# success_probability = 0.74100000
# success_probability = 0.71440000
# success_probability = 0.71690000
# success_probability = 0.79260000
# success_probability = 0.78760000
# success_probability = 0.79170000
# success_probability = 0.76180000
# success_probability = 0.79230000
# success_probability = 0.77600000
# success_probability = 0.78780000
# success_probability = 0.75950000
# success_probability = 0.80150000
# success_probability = 0.75480000
# success_probability = 0.78800000
# success_probability = 0.76750000
# success_probability = 0.79910000
# success_probability = 0.74560000
# success_probability = 0.79190000
# success_probability = 0.76450000
# success_probability = 0.80330000
# success_probability = 0.76920000
# success_probability = 0.80500000
# success_probability = 0.77930000
# success_probability = 0.79620000
# success_probability = 0.78630000
# success_probability = 0.80500000
# success_probability = 0.77880000
# success_probability = 0.80330000
# success_probability = 0.76440000
# success_probability = 0.80240000
# success_probability = 0.78450000
# success_probability = 0.79520000
# success_probability = 0.76270000
# success_probability = 0.79950000
# success_probability = 0.76550000
# success_probability = 0.76590000
# success_probability = 0.77980000
# success_probability = 0.78810000
# success_probability = 0.80460000
# success_probability = 0.80110000
# success_probability = 0.80290000
# success_probability = 0.80430000
# success_probability = 0.80510000
# success_probability = 0.80320000
# success_probability = 0.80370000
# success_probability = 0.80410000
# success_probability = 0.80420000
# success_probability = 0.80230000
# success_probability = 0.80410000
# success_probability = 0.80800000
# success_probability = 0.80800000
# success_probability = 0.80370000
# success_probability = 0.80830000
# success_probability = 0.78810000
# success_probability = 0.81000000
# success_probability = 0.79090000
# success_probability = 0.80860000
# success_probability = 0.80990000
# success_probability = 0.80350000
# success_probability = 0.80160000
# success_probability = 0.80670000
# success_probability = 0.79350000
# success_probability = 0.80810000
# success_probability = 0.79720000
# success_probability = 0.80270000
# success_probability = 0.79920000
# success_probability = 0.80690000
# success_probability = 0.80730000
# success_probability = 0.80700000
# success_probability = 0.80570000
# success_probability = 0.80840000
# success_probability = 0.80200000
# success_probability = 0.80870000
# success_probability = 0.79920000
# success_probability = 0.80540000
# success_probability = 0.80370000
# success_probability = 0.80550000
# success_probability = 0.79890000
# success_probability = 0.81380000
# success_probability = 0.79340000
# success_probability = 0.81040000
# success_probability = 0.80970000
# success_probability = 0.81460000
# success_probability = 0.81530000
# success_probability = 0.81270000
# success_probability = 0.81420000
# success_probability = 0.81140000
# success_probability = 0.81390000
# success_probability = 0.81370000
# success_probability = 0.81490000
# success_probability = 0.81440000
# success_probability = 0.81430000
# success_probability = 0.81550000
# success_probability = 0.81460000
# success_probability = 0.81480000
# success_probability = 0.81520000
# success_probability = 0.81430000
# success_probability = 0.81150000
# success_probability = 0.82140000
# success_probability = 0.81980000
# success_probability = 0.81690000
# success_probability = 0.82090000
# success_probability = 0.82190000
# success_probability = 0.82080000
# success_probability = 0.82020000
# success_probability = 0.81930000
# success_probability = 0.82260000
# success_probability = 0.82190000
# success_probability = 0.82110000
# success_probability = 0.82360000
# success_probability = 0.82730000
# success_probability = 0.82740000
# success_probability = 0.82260000
# success_probability = 0.81070000
# success_probability = 0.82740000
# success_probability = 0.82760000
# success_probability = 0.82710000
# success_probability = 0.82750000
# success_probability = 0.82750000
# success_probability = 0.82620000
# success_probability = 0.82480000
# success_probability = 0.83070000
# success_probability = 0.83060000
# success_probability = 0.83080000
# success_probability = 0.83210000
# success_probability = 0.83170000
# success_probability = 0.83210000
# success_probability = 0.82710000
# success_probability = 0.83170000
# success_probability = 0.83110000
# success_probability = 0.83240000
# success_probability = 0.83310000
# success_probability = 0.83270000
# success_probability = 0.83170000
# success_probability = 0.83340000
# success_probability = 0.83420000
# success_probability = 0.83450000
# success_probability = 0.83400000
# success_probability = 0.83450000
# success_probability = 0.83510000
# success_probability = 0.83370000
# success_probability = 0.83410000
# success_probability = 0.83380000
# success_probability = 0.83720000
# success_probability = 0.83830000
# success_probability = 0.83720000
# success_probability = 0.83580000
# success_probability = 0.83600000
# success_probability = 0.83600000
# success_probability = 0.83620000
# success_probability = 0.83610000
# success_probability = 0.83080000
# success_probability = 0.83860000
# success_probability = 0.83970000
# success_probability = 0.83870000
# success_probability = 0.83660000
# success_probability = 0.84000000
# success_probability = 0.83950000
# success_probability = 0.83710000
# success_probability = 0.83640000
# success_probability = 0.84000000
# success_probability = 0.83650000
# success_probability = 0.83890000
# success_probability = 0.83950000
# success_probability = 0.83760000
# success_probability = 0.83740000
# success_probability = 0.83730000
# success_probability = 0.83960000
# success_probability = 0.83750000
# success_probability = 0.83990000
# success_probability = 0.84130000
# success_probability = 0.83850000
# success_probability = 0.84020000
# success_probability = 0.83900000
# success_probability = 0.84030000
# success_probability = 0.84460000
# success_probability = 0.84390000
# success_probability = 0.84800000
# success_probability = 0.84560000
# success_probability = 0.84560000
# success_probability = 0.84700000
# success_probability = 0.84930000
# success_probability = 0.84840000
# success_probability = 0.84720000
# success_probability = 0.84870000
# success_probability = 0.84870000
# success_probability = 0.84840000
# success_probability = 0.84730000
# success_probability = 0.85020000
# success_probability = 0.84810000
# success_probability = 0.84680000
# success_probability = 0.84680000
# success_probability = 0.84860000
# success_probability = 0.84710000
# success_probability = 0.84980000
# success_probability = 0.84690000
# success_probability = 0.85050000
# success_probability = 0.84930000
# success_probability = 0.84930000
# success_probability = 0.84660000
# success_probability = 0.85140000
# success_probability = 0.84420000
# success_probability = 0.85080000
# success_probability = 0.84990000
# success_probability = 0.84540000
# success_probability = 0.84540000
# success_probability = 0.85110000
# success_probability = 0.84710000
# success_probability = 0.85160000
# success_probability = 0.84510000
# success_probability = 0.84910000
# success_probability = 0.85030000
# success_probability = 0.84940000
# success_probability = 0.84680000
# success_probability = 0.85030000
# success_probability = 0.85000000
# success_probability = 0.84980000
# success_probability = 0.84830000
# success_probability = 0.85160000
# success_probability = 0.84800000
# success_probability = 0.85040000
# success_probability = 0.84770000
# success_probability = 0.84980000
# success_probability = 0.84710000
# success_probability = 0.84990000
# success_probability = 0.85300000
# success_probability = 0.84990000
# success_probability = 0.84910000
# success_probability = 0.85100000
# success_probability = 0.85460000
# success_probability = 0.85330000
# success_probability = 0.84960000
# success_probability = 0.85130000
# success_probability = 0.85620000
# success_probability = 0.85530000
# success_probability = 0.85490000
# success_probability = 0.85740000
# success_probability = 0.85560000
# success_probability = 0.85720000
# success_probability = 0.85870000
# success_probability = 0.85710000
# success_probability = 0.85570000
# success_probability = 0.85450000
# success_probability = 0.85540000
# success_probability = 0.85690000
# success_probability = 0.85980000
# success_probability = 0.85900000
# success_probability = 0.85950000
# success_probability = 0.86030000
# success_probability = 0.85860000
# success_probability = 0.85940000
# success_probability = 0.85840000
# success_probability = 0.86140000
# success_probability = 0.85810000
# success_probability = 0.86070000
# success_probability = 0.85830000
# success_probability = 0.86000000
# success_probability = 0.86030000
# success_probability = 0.86210000
# success_probability = 0.86040000
# success_probability = 0.86090000
# success_probability = 0.85720000
# success_probability = 0.85950000
# success_probability = 0.86080000
# success_probability = 0.86150000
# success_probability = 0.85680000
# success_probability = 0.86110000
# success_probability = 0.85820000
# success_probability = 0.86000000
# success_probability = 0.86000000
# success_probability = 0.86260000
# success_probability = 0.85940000
# success_probability = 0.86310000
# success_probability = 0.85750000
# success_probability = 0.86210000
# success_probability = 0.86030000
# success_probability = 0.86120000
# success_probability = 0.86300000
# success_probability = 0.86050000
# success_probability = 0.85920000
# success_probability = 0.86230000
# success_probability = 0.86240000
# success_probability = 0.86190000
# success_probability = 0.86200000
# success_probability = 0.86210000
# success_probability = 0.86020000
# success_probability = 0.86270000
# success_probability = 0.86070000
# success_probability = 0.85810000
# success_probability = 0.86270000
# success_probability = 0.86220000
# success_probability = 0.86250000
# success_probability = 0.86150000
# success_probability = 0.86390000
# success_probability = 0.86370000
# success_probability = 0.86280000
# success_probability = 0.86210000
# success_probability = 0.86300000
# success_probability = 0.86160000
# success_probability = 0.86120000
# success_probability = 0.86270000
# success_probability = 0.86410000
# success_probability = 0.86220000
# success_probability = 0.86200000
# success_probability = 0.86540000
# success_probability = 0.86430000
# success_probability = 0.86380000
# success_probability = 0.86450000
# success_probability = 0.86540000
# success_probability = 0.86510000
# success_probability = 0.86450000
# success_probability = 0.86450000
# success_probability = 0.86370000
# success_probability = 0.86490000
# success_probability = 0.86310000
# success_probability = 0.86370000
# success_probability = 0.86500000
# success_probability = 0.86460000
# success_probability = 0.86480000
# success_probability = 0.86440000
# success_probability = 0.86390000
# success_probability = 0.86400000
# success_probability = 0.86530000
# success_probability = 0.86420000
# success_probability = 0.86130000
# success_probability = 0.86470000
# success_probability = 0.86440000
# success_probability = 0.86410000
# success_probability = 0.86430000
# success_probability = 0.86320000
# success_probability = 0.86430000
# success_probability = 0.86310000
# success_probability = 0.86370000
# success_probability = 0.86440000
# success_probability = 0.86430000
# success_probability = 0.86530000
# success_probability = 0.86460000
# success_probability = 0.86540000
# success_probability = 0.86410000
# success_probability = 0.86460000
# success_probability = 0.86500000
# success_probability = 0.86530000
# success_probability = 0.86520000
# success_probability = 0.86490000
# success_probability = 0.86480000
# success_probability = 0.86380000
# success_probability = 0.86490000
# success_probability = 0.86490000
# success_probability = 0.86450000
# success_probability = 0.86400000
# success_probability = 0.86450000
# success_probability = 0.86490000
# success_probability = 0.86510000
# success_probability = 0.86500000
# success_probability = 0.86510000
# success_probability = 0.86510000
# success_probability = 0.86600000
# success_probability = 0.86560000
# success_probability = 0.86540000
# success_probability = 0.86520000
# success_probability = 0.86510000
# success_probability = 0.86540000
# success_probability = 0.86470000
# success_probability = 0.86490000
# success_probability = 0.86420000
# success_probability = 0.86540000
# success_probability = 0.86540000
# success_probability = 0.86520000
# success_probability = 0.86480000
# success_probability = 0.86520000
# success_probability = 0.86540000
# success_probability = 0.86540000
# success_probability = 0.86550000
# success_probability = 0.86540000
# success_probability = 0.86460000
# success_probability = 0.86510000
# success_probability = 0.86590000
# success_probability = 0.86480000
# success_probability = 0.86530000
# success_probability = 0.86490000
# success_probability = 0.86560000
# success_probability = 0.86510000
# success_probability = 0.86570000
# success_probability = 0.86530000
# success_probability = 0.86500000
# success_probability = 0.86580000
# success_probability = 0.86590000
# success_probability = 0.86520000
# success_probability = 0.86580000
# success_probability = 0.86540000
# success_probability = 0.86510000
# success_probability = 0.86570000
# success_probability = 0.86560000
# success_probability = 0.86520000
# success_probability = 0.86580000
# success_probability = 0.86540000
# success_probability = 0.86550000
# success_probability = 0.86570000
# success_probability = 0.86590000
# success_probability = 0.86520000
# success_probability = 0.86580000
# success_probability = 0.86560000
# success_probability = 0.86570000
# success_probability = 0.86630000
# success_probability = 0.86580000
# success_probability = 0.86540000
# success_probability = 0.86590000
# success_probability = 0.86600000
# success_probability = 0.86550000
# success_probability = 0.86540000
# success_probability = 0.86570000
# success_probability = 0.86540000
# success_probability = 0.86590000
# success_probability = 0.86540000
# success_probability = 0.86530000
# success_probability = 0.86610000
# success_probability = 0.86550000
# success_probability = 0.86540000
# success_probability = 0.86550000
# success_probability = 0.86590000
# success_probability = 0.86610000
# success_probability = 0.86570000
# success_probability = 0.86590000
# success_probability = 0.86580000
# success_probability = 0.86560000
# success_probability = 0.86600000
# success_probability = 0.86590000
# success_probability = 0.86580000
# success_probability = 0.86560000
# success_probability = 0.86600000
# success_probability = 0.86540000
# success_probability = 0.86590000
# success_probability = 0.86560000
# success_probability = 0.86590000
# success_probability = 0.86580000
# success_probability = 0.86610000
# success_probability = 0.86590000
# success_probability = 0.86600000
# success_probability = 0.86580000
# success_probability = 0.86600000
# success_probability = 0.86550000
# success_probability = 0.86590000
# success_probability = 0.86580000
# success_probability = 0.86570000
# success_probability = 0.86600000
# success_probability = 0.86620000
# success_probability = 0.86560000
# success_probability = 0.86610000
# success_probability = 0.86580000
# success_probability = 0.86580000
# success_probability = 0.86590000
# success_probability = 0.86600000
# success_probability = 0.86610000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86610000
# success_probability = 0.86610000
# success_probability = 0.86610000
# success_probability = 0.86630000
# success_probability = 0.86630000
# success_probability = 0.86610000
# success_probability = 0.86590000
# success_probability = 0.86620000
# success_probability = 0.86630000
# success_probability = 0.86640000
# success_probability = 0.86600000
# success_probability = 0.86610000
# success_probability = 0.86600000
# success_probability = 0.86610000
# success_probability = 0.86600000
# success_probability = 0.86630000
# success_probability = 0.86620000
# success_probability = 0.86640000
# success_probability = 0.86620000
# success_probability = 0.86600000
# success_probability = 0.86620000
# success_probability = 0.86640000
# success_probability = 0.86590000
# success_probability = 0.86630000
# success_probability = 0.86610000
# success_probability = 0.86630000
# success_probability = 0.86620000
# success_probability = 0.86630000
# success_probability = 0.86610000
# success_probability = 0.86640000
# success_probability = 0.86630000
# success_probability = 0.86610000
# success_probability = 0.86630000
# success_probability = 0.86630000
# success_probability = 0.86630000
# success_probability = 0.86630000
# success_probability = 0.86630000
# success_probability = 0.86620000
# success_probability = 0.86610000
# success_probability = 0.86610000
# success_probability = 0.86640000
# success_probability = 0.86630000
# success_probability = 0.86640000
# success_probability = 0.86620000
# success_probability = 0.86640000
# success_probability = 0.86620000
# success_probability = 0.86630000
# success_probability = 0.86640000
# success_probability = 0.86630000
# success_probability = 0.86630000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86630000
# success_probability = 0.86640000
# success_probability = 0.86630000
# success_probability = 0.86640000
# success_probability = 0.86630000
# success_probability = 0.86630000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86630000
# success_probability = 0.86630000
# success_probability = 0.86630000
# success_probability = 0.86640000
# success_probability = 0.86630000
# success_probability = 0.86640000
# success_probability = 0.86630000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86630000
# success_probability = 0.86630000
# success_probability = 0.86640000
# success_probability = 0.86630000
# success_probability = 0.86630000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86630000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# success_probability = 0.86640000
# Optimization Wall-Clock Time : 193.766244 s
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  895   F = 1.154201E+00    MAXCV = 0.000000E+00
#    X =-2.784693E-02   3.354047E+00   2.132132E+00   1.684945E+00   7.309309E-01
#        1.462792E+00   2.336447E+00   1.257351E+00  -6.160027E-02   1.472826E-01
#        3.122753E+00   3.225643E+00   3.212458E+00   3.172450E+00   8.782395E-01
#        1.254002E+00  -5.216269E-01  -7.238009E-02   2.530432E-01  -5.094521E-01
#       -3.210525E-01  -1.706646E-01   1.579144E+00   1.294180E+00  -2.664764E-01
#        5.939344E-01   9.101459E-01   1.301503E-01   1.372336E+00  -5.664685E-02
#        4.124390E-02   3.230548E+00  -3.027418E-02   3.133492E+00   1.665224E+00
#        6.044501E-01   3.530675E-01   2.657521E-02  -2.832036E-01   6.234506E-01
#        1.032637E+00   1.401449E+00   3.501052E-01  -1.284743E-01   1.130126E+00
#        4.817188E-01
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.85283000
# Evaluation  2/20 | Value = 0.85282000
# Evaluation  3/20 | Value = 0.85282000
# Evaluation  4/20 | Value = 0.85282000
# Evaluation  5/20 | Value = 0.85283000
# Evaluation  6/20 | Value = 0.85283000
# Evaluation  7/20 | Value = 0.85283000
# Evaluation  8/20 | Value = 0.85283000
# Evaluation  9/20 | Value = 0.85283000
# Evaluation 10/20 | Value = 0.85283000
# Evaluation 11/20 | Value = 0.85283000
# Evaluation 12/20 | Value = 0.85283000
# Evaluation 13/20 | Value = 0.85283000
# Evaluation 14/20 | Value = 0.85283000
# Evaluation 15/20 | Value = 0.85283000
# Evaluation 16/20 | Value = 0.85283000
# Evaluation 17/20 | Value = 0.85282000
# Evaluation 18/20 | Value = 0.85282000
# Evaluation 19/20 | Value = 0.85281000
# Evaluation 20/20 | Value = 0.85280000
#
# ================================================================================
# RUN 1 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 1
# Message              : Optimization terminated successfully.
# Function Evaluations : 895
# Optimization Time    : 193.766244 s
# Final Objective Value: 1.154201292705448
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.86640000
# Evaluated Mean        : 0.85282500
# Evaluated Std         : 0.00000806
# Evaluated Min         : 0.85280000
# Evaluated Max         : 0.85283000
#
# All Evaluated Values:
# [0.85283, 0.85282, 0.85282, 0.85282, 0.85283, 0.85283, 0.85283, 0.85283,
#  0.85283, 0.85283, 0.85283, 0.85283, 0.85283, 0.85283, 0.85283, 0.85283,
#  0.85282, 0.85282, 0.85281, 0.8528 ]
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566, 0.6883896757,
#  0.5848087428, 0.2739643248, 0.8377858251, 0.3022293541, 0.1728462164,
#  0.8017433668, 0.3441099205, 0.4375847094, 0.152681156 , 0.2761357842,
#  0.5638672039, 0.8646746614, 0.0827886029, 0.9748236223, 0.9228236344,
#  0.4073736921, 0.7807688858, 0.6465955762, 0.2254609107, 0.8244806881,
#  0.3453562772, 0.5685671364, 0.6863696968, 0.2470087963, 0.8753744063,
#  0.1559330851]
#
# Optimal Parameters:
# [-0.0278469328,  3.3540471694,  2.1321319726,  1.6849449602,  0.7309308594,
#   1.462792341 ,  2.3364471593,  1.2573507202, -0.0616002652,  0.1472826187,
#   3.1227526855,  3.2256430069,  3.2124576744,  3.1724502746,  0.8782394728,
#   1.2540015442, -0.5216269337, -0.0723800914,  0.2530431936, -0.5094521106,
#  -0.3210525257, -0.1706645734,  1.5791436016,  1.294179671 , -0.266476355 ,
#   0.5939343907,  0.9101458887,  0.130150312 ,  1.3723364653, -0.0566468523,
#   0.0412439021,  3.2305475968, -0.0302741799,  3.1334923717,  1.6652242883,
#   0.6044500884,  0.353067538 ,  0.0265752092, -0.2832035734,  0.6234506474,
#   1.0326372531,  1.401449202 ,  0.3501051596, -0.1284742843,  1.1301256496,
#   0.4817188069]
# ================================================================================
#
# ================================================================================
# Optimization Run 2/30
# Optimization Seed : 151
# ================================================================================
#
# Initial Parameters:
# [0.4917938425, 0.3601415032, 0.7094100488, 0.6895107167, 0.4723817514,
#  0.4790485592, 0.0068635273, 0.9044398512, 0.4337399476, 0.4736042839,
#  0.034330777 , 0.9496323674, 0.5907905652, 0.4241785512, 0.1868628067,
#  0.9840929216, 0.690221156 , 0.9039467044, 0.0207568308, 0.9969449281,
#  0.3143005034, 0.2098620446, 0.0173606056, 0.1892781313, 0.2905169378,
#  0.2743264362, 0.6422361978, 0.0963913748, 0.0696866112, 0.767331954 ,
#  0.8795830504, 0.1374186715, 0.8099241505, 0.8542614782, 0.2971560221,
#  0.9414299034, 0.5424735984, 0.1876331615, 0.6995902047, 0.9645506228,
#  0.6243252615, 0.7598983102, 0.5310856425, 0.9411633223, 0.0506727127,
#  0.1954788481]
#
# Starting COBYLA optimization...
# success_probability = 0.36230000
# success_probability = 0.35490000
# success_probability = 0.36210000
# success_probability = 0.32480000
# success_probability = 0.36220000
# success_probability = 0.36470000
# success_probability = 0.36270000
# success_probability = 0.30580000
# success_probability = 0.35290000
# success_probability = 0.38460000
# success_probability = 0.38650000
# success_probability = 0.40100000
# success_probability = 0.46680000
# success_probability = 0.48030000
# success_probability = 0.48100000
# success_probability = 0.47840000
# success_probability = 0.48070000
# success_probability = 0.47950000
# success_probability = 0.48100000
# success_probability = 0.48100000
# success_probability = 0.48100000
# success_probability = 0.48200000
# success_probability = 0.48880000
# success_probability = 0.48800000
# success_probability = 0.49090000
# success_probability = 0.48930000
# success_probability = 0.48810000
# success_probability = 0.48990000
# success_probability = 0.48530000
# success_probability = 0.49050000
# success_probability = 0.49020000
# success_probability = 0.48460000
# success_probability = 0.48330000
# success_probability = 0.49910000
# success_probability = 0.49910000
# success_probability = 0.49840000
# success_probability = 0.49490000
# success_probability = 0.49820000
# success_probability = 0.49910000
# success_probability = 0.49910000
# success_probability = 0.49910000
# success_probability = 0.50000000
# success_probability = 0.50000000
# success_probability = 0.50050000
# success_probability = 0.50050000
# success_probability = 0.50050000
# success_probability = 0.50050000
# success_probability = 0.50780000
# success_probability = 0.47740000
# success_probability = 0.57760000
# success_probability = 0.59570000
# success_probability = 0.59620000
# success_probability = 0.54220000
# success_probability = 0.59620000
# success_probability = 0.59710000
# success_probability = 0.59150000
# success_probability = 0.58060000
# success_probability = 0.59860000
# success_probability = 0.55470000
# success_probability = 0.60820000
# success_probability = 0.55930000
# success_probability = 0.60690000
# success_probability = 0.62560000
# success_probability = 0.62510000
# success_probability = 0.59450000
# success_probability = 0.62880000
# success_probability = 0.62100000
# success_probability = 0.62370000
# success_probability = 0.62380000
# success_probability = 0.62880000
# success_probability = 0.62130000
# success_probability = 0.62880000
# success_probability = 0.62810000
# success_probability = 0.62390000
# success_probability = 0.62540000
# success_probability = 0.62510000
# success_probability = 0.62440000
# success_probability = 0.62660000
# success_probability = 0.62810000
# success_probability = 0.62770000
# success_probability = 0.63050000
# success_probability = 0.63070000
# success_probability = 0.62640000
# success_probability = 0.62800000
# success_probability = 0.62480000
# success_probability = 0.63240000
# success_probability = 0.62750000
# success_probability = 0.62920000
# success_probability = 0.62680000
# success_probability = 0.63230000
# success_probability = 0.63000000
# success_probability = 0.63240000
# success_probability = 0.62900000
# success_probability = 0.63130000
# success_probability = 0.62510000
# success_probability = 0.63240000
# success_probability = 0.59690000
# success_probability = 0.63370000
# success_probability = 0.59530000
# success_probability = 0.59840000
# success_probability = 0.60480000
# success_probability = 0.63680000
# success_probability = 0.61000000
# success_probability = 0.62500000
# success_probability = 0.60300000
# success_probability = 0.64660000
# success_probability = 0.61200000
# success_probability = 0.64520000
# success_probability = 0.61810000
# success_probability = 0.64560000
# success_probability = 0.63610000
# success_probability = 0.64110000
# success_probability = 0.64340000
# success_probability = 0.64430000
# success_probability = 0.64740000
# success_probability = 0.63880000
# success_probability = 0.64670000
# success_probability = 0.64420000
# success_probability = 0.64590000
# success_probability = 0.64630000
# success_probability = 0.64590000
# success_probability = 0.65270000
# success_probability = 0.65030000
# success_probability = 0.65050000
# success_probability = 0.65040000
# success_probability = 0.65240000
# success_probability = 0.64970000
# success_probability = 0.64710000
# success_probability = 0.65160000
# success_probability = 0.64580000
# success_probability = 0.65270000
# success_probability = 0.65110000
# success_probability = 0.65020000
# success_probability = 0.65120000
# success_probability = 0.64970000
# success_probability = 0.64920000
# success_probability = 0.65220000
# success_probability = 0.65080000
# success_probability = 0.65280000
# success_probability = 0.65250000
# success_probability = 0.65230000
# success_probability = 0.64840000
# success_probability = 0.65070000
# success_probability = 0.64190000
# success_probability = 0.65110000
# success_probability = 0.65240000
# success_probability = 0.65030000
# success_probability = 0.64580000
# success_probability = 0.65080000
# success_probability = 0.64670000
# success_probability = 0.65290000
# success_probability = 0.65050000
# success_probability = 0.65290000
# success_probability = 0.65170000
# success_probability = 0.65160000
# success_probability = 0.64050000
# success_probability = 0.65110000
# success_probability = 0.64640000
# success_probability = 0.64860000
# success_probability = 0.65170000
# success_probability = 0.65000000
# success_probability = 0.64620000
# success_probability = 0.65240000
# success_probability = 0.65140000
# success_probability = 0.65070000
# success_probability = 0.65210000
# success_probability = 0.65200000
# success_probability = 0.65180000
# success_probability = 0.65240000
# success_probability = 0.65280000
# success_probability = 0.65170000
# success_probability = 0.65100000
# success_probability = 0.64960000
# success_probability = 0.65260000
# success_probability = 0.65000000
# success_probability = 0.65240000
# success_probability = 0.65200000
# success_probability = 0.65330000
# success_probability = 0.64920000
# success_probability = 0.65400000
# success_probability = 0.65260000
# success_probability = 0.65570000
# success_probability = 0.64980000
# success_probability = 0.65820000
# success_probability = 0.65550000
# success_probability = 0.65910000
# success_probability = 0.65690000
# success_probability = 0.65820000
# success_probability = 0.65640000
# success_probability = 0.65940000
# success_probability = 0.65650000
# success_probability = 0.65810000
# success_probability = 0.65890000
# success_probability = 0.65890000
# success_probability = 0.65780000
# success_probability = 0.65730000
# success_probability = 0.65730000
# success_probability = 0.65980000
# success_probability = 0.65840000
# success_probability = 0.65970000
# success_probability = 0.66220000
# success_probability = 0.66130000
# success_probability = 0.65760000
# success_probability = 0.66180000
# success_probability = 0.66180000
# success_probability = 0.66130000
# success_probability = 0.66000000
# success_probability = 0.66200000
# success_probability = 0.66070000
# success_probability = 0.66130000
# success_probability = 0.65940000
# success_probability = 0.66360000
# success_probability = 0.65950000
# success_probability = 0.66190000
# success_probability = 0.66170000
# success_probability = 0.66150000
# success_probability = 0.66350000
# success_probability = 0.66080000
# success_probability = 0.66060000
# success_probability = 0.66200000
# success_probability = 0.66310000
# success_probability = 0.66080000
# success_probability = 0.66250000
# success_probability = 0.66270000
# success_probability = 0.66400000
# success_probability = 0.66250000
# success_probability = 0.66460000
# success_probability = 0.66420000
# success_probability = 0.66520000
# success_probability = 0.66390000
# success_probability = 0.66470000
# success_probability = 0.66250000
# success_probability = 0.66380000
# success_probability = 0.66560000
# success_probability = 0.66540000
# success_probability = 0.66200000
# success_probability = 0.66520000
# success_probability = 0.66440000
# success_probability = 0.66650000
# success_probability = 0.66580000
# success_probability = 0.66720000
# success_probability = 0.66580000
# success_probability = 0.66490000
# success_probability = 0.66590000
# success_probability = 0.66670000
# success_probability = 0.66510000
# success_probability = 0.66680000
# success_probability = 0.66560000
# success_probability = 0.66570000
# success_probability = 0.66590000
# success_probability = 0.66640000
# success_probability = 0.66510000
# success_probability = 0.66700000
# success_probability = 0.66520000
# success_probability = 0.66670000
# success_probability = 0.66670000
# success_probability = 0.66720000
# success_probability = 0.66590000
# success_probability = 0.66640000
# success_probability = 0.66560000
# success_probability = 0.66710000
# success_probability = 0.66590000
# success_probability = 0.66780000
# success_probability = 0.66540000
# success_probability = 0.66370000
# success_probability = 0.66340000
# success_probability = 0.66730000
# success_probability = 0.66460000
# success_probability = 0.66510000
# success_probability = 0.66670000
# success_probability = 0.66530000
# success_probability = 0.66620000
# success_probability = 0.66670000
# success_probability = 0.66830000
# success_probability = 0.66810000
# success_probability = 0.66890000
# success_probability = 0.66820000
# success_probability = 0.66830000
# success_probability = 0.66910000
# success_probability = 0.66830000
# success_probability = 0.66930000
# success_probability = 0.67110000
# success_probability = 0.66980000
# success_probability = 0.67170000
# success_probability = 0.67270000
# success_probability = 0.67140000
# success_probability = 0.67220000
# success_probability = 0.67030000
# success_probability = 0.67200000
# success_probability = 0.67140000
# success_probability = 0.67220000
# success_probability = 0.67200000
# success_probability = 0.67350000
# success_probability = 0.67170000
# success_probability = 0.67240000
# success_probability = 0.67270000
# success_probability = 0.67240000
# success_probability = 0.67280000
# success_probability = 0.67300000
# success_probability = 0.67150000
# success_probability = 0.67240000
# success_probability = 0.67230000
# success_probability = 0.67430000
# success_probability = 0.67240000
# success_probability = 0.67310000
# success_probability = 0.67390000
# success_probability = 0.67330000
# success_probability = 0.67090000
# success_probability = 0.67220000
# success_probability = 0.67310000
# success_probability = 0.67400000
# success_probability = 0.67310000
# success_probability = 0.67450000
# success_probability = 0.67230000
# success_probability = 0.67370000
# success_probability = 0.67170000
# success_probability = 0.67480000
# success_probability = 0.67340000
# success_probability = 0.67360000
# success_probability = 0.67260000
# success_probability = 0.67440000
# success_probability = 0.67330000
# success_probability = 0.67350000
# success_probability = 0.67270000
# success_probability = 0.67380000
# success_probability = 0.67140000
# success_probability = 0.67380000
# success_probability = 0.67400000
# success_probability = 0.67370000
# success_probability = 0.67470000
# success_probability = 0.67380000
# success_probability = 0.67310000
# success_probability = 0.67420000
# success_probability = 0.67390000
# success_probability = 0.67320000
# success_probability = 0.67400000
# success_probability = 0.67340000
# success_probability = 0.67390000
# success_probability = 0.67320000
# success_probability = 0.67500000
# success_probability = 0.67390000
# success_probability = 0.67470000
# success_probability = 0.67410000
# success_probability = 0.67490000
# success_probability = 0.67510000
# success_probability = 0.67480000
# success_probability = 0.67400000
# success_probability = 0.67480000
# success_probability = 0.67300000
# success_probability = 0.67500000
# success_probability = 0.67400000
# success_probability = 0.67510000
# success_probability = 0.67510000
# success_probability = 0.67480000
# success_probability = 0.67450000
# success_probability = 0.67460000
# success_probability = 0.67490000
# success_probability = 0.67540000
# success_probability = 0.67400000
# success_probability = 0.67540000
# success_probability = 0.67440000
# success_probability = 0.67450000
# success_probability = 0.67530000
# success_probability = 0.67540000
# success_probability = 0.67430000
# success_probability = 0.67430000
# success_probability = 0.67500000
# success_probability = 0.67520000
# success_probability = 0.67470000
# ...
# success_probability = 0.96970000
# success_probability = 0.96960000
# success_probability = 0.96970000
# success_probability = 0.96960000
# success_probability = 0.96960000
# success_probability = 0.96970000
# success_probability = 0.96960000
# success_probability = 0.96950000
# success_probability = 0.96960000
# success_probability = 0.96960000
# success_probability = 0.96960000
# success_probability = 0.96970000
# success_probability = 0.96960000
# success_probability = 0.96940000
# success_probability = 0.96960000
# success_probability = 0.96950000
# success_probability = 0.96970000
# success_probability = 0.96960000
# success_probability = 0.96950000
# success_probability = 0.96970000
# success_probability = 0.96960000
# success_probability = 0.96960000
# success_probability = 0.96960000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96960000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96960000
# success_probability = 0.96960000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96960000
# success_probability = 0.96960000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# success_probability = 0.96970000
# Optimization Wall-Clock Time : 229.841724 s
#
#    Normal return from subroutine COBYLA
#
#    NFVALS = 1113   F = 1.031247E+00    MAXCV = 0.000000E+00
#    X = 3.199635E+00   4.198511E-02   1.105923E-02  -9.745287E-02   3.042688E-02
#        1.522824E+00   2.671743E+00   3.155862E+00   3.093353E+00   2.960986E+00
#        2.430586E+00   2.883206E+00   2.804498E+00  -1.465892E-02   1.791326E+00
#        8.544469E-01   3.391332E-02   2.483092E-01   9.154344E-01   5.539489E-01
#       -6.518735E-02   5.022082E-01   1.564319E+00   9.756173E-01  -7.460356E-01
#        5.652072E-01   3.035185E+00  -6.108231E-02   3.046259E+00  -2.811249E-02
#       -4.543484E-02   2.131627E+00   3.710661E-02  -3.029540E+00   4.273202E-02
#        1.220770E-01   1.478428E+00   1.336161E-01  -1.025639E+00  -2.204836E-01
#        7.172923E-01   1.145489E+00  -1.101436E+00   7.631791E-03  -1.008247E-01
#        4.013121E-01
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.96349000
# Evaluation  2/20 | Value = 0.96348000
# Evaluation  3/20 | Value = 0.96348000
# Evaluation  4/20 | Value = 0.96348000
# Evaluation  5/20 | Value = 0.96348000
# Evaluation  6/20 | Value = 0.96348000
# Evaluation  7/20 | Value = 0.96348000
# Evaluation  8/20 | Value = 0.96348000
# Evaluation  9/20 | Value = 0.96348000
# Evaluation 10/20 | Value = 0.96348000
# Evaluation 11/20 | Value = 0.96348000
# Evaluation 12/20 | Value = 0.96348000
# Evaluation 13/20 | Value = 0.96348000
# Evaluation 14/20 | Value = 0.96348000
# Evaluation 15/20 | Value = 0.96348000
# Evaluation 16/20 | Value = 0.96348000
# Evaluation 17/20 | Value = 0.96348000
# Evaluation 18/20 | Value = 0.96347000
# Evaluation 19/20 | Value = 0.96347000
# Evaluation 20/20 | Value = 0.96347000
#
# ================================================================================
# RUN 30 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 1
# Message              : Optimization terminated successfully.
# Function Evaluations : 1113
# Optimization Time    : 229.841724 s
# Final Objective Value: 1.0312467773538208
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.96970000
# Evaluated Mean        : 0.96347900
# Evaluated Std         : 0.00000436
# Evaluated Min         : 0.96347000
# Evaluated Max         : 0.96349000
#
# All Evaluated Values:
# [0.96349, 0.96348, 0.96348, 0.96348, 0.96348, 0.96348, 0.96348, 0.96348,
#  0.96348, 0.96348, 0.96348, 0.96348, 0.96348, 0.96348, 0.96348, 0.96348,
#  0.96348, 0.96347, 0.96347, 0.96347]
#
# Initial Parameters:
# [0.9180695286, 0.9403935557, 0.9611445873, 0.1282735573, 0.7343854482,
#  0.1418537547, 0.3206870255, 0.8783134777, 0.3925501756, 0.9542827898,
#  0.4333144504, 0.0052152104, 0.5921889116, 0.318609756 , 0.9316370681,
#  0.6026668473, 0.0078690534, 0.7991305598, 0.851774691 , 0.06652901  ,
#  0.7310172927, 0.1064287992, 0.0810809173, 0.7115609048, 0.7069595409,
#  0.496652521 , 0.9897356485, 0.1231137075, 0.6818954479, 0.6829684311,
#  0.6297061464, 0.4286822178, 0.2197024243, 0.0834353681, 0.9077417659,
#  0.0972222206, 0.061382995 , 0.8279569226, 0.1578310648, 0.0841288554,
#  0.4172996827, 0.7066178285, 0.6364755314, 0.8297559874, 0.3496650027,
#  0.8342151076]
#
# Optimal Parameters:
# [ 3.199635252 ,  0.0419851128,  0.0110592301, -0.0974528745,  0.0304268799,
#   1.5228239634,  2.671742865 ,  3.1558623845,  3.0933526588,  2.9609857865,
#   2.4305858577,  2.8832064928,  2.8044983072, -0.0146589211,  1.791326244 ,
#   0.8544468654,  0.0339133229,  0.2483092404,  0.9154344424,  0.5539489363,
#  -0.0651873529,  0.5022082152,  1.5643194394,  0.9756172692, -0.7460356443,
#   0.5652072132,  3.0351853597, -0.0610823099,  3.0462589024, -0.0281124879,
#  -0.045434836 ,  2.1316270806,  0.0371066082, -3.0295398182,  0.0427320242,
#   0.1220770231,  1.4784284443,  0.1336160576, -1.0256390823, -0.2204835656,
#   0.7172923241,  1.1454885514, -1.1014355461,  0.0076317912, -0.1008247406,
#   0.4013120618]
# ================================================================================
#
#
# ====================================================================================================
# FINAL OPTIMIZATION AND HIGH-SHOT EVALUATION REPORT
# ====================================================================================================
# Optimizer               : COBYLA
# Tolerance               : 1e-08
# Max Iteration           : 3000
# Number of Runs          : 30
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1067
#    1053 print(
#    1054     f"Max Iteration           : "
#    1055     f"{maxiter}"
#    1056 )
#    1059 print(
#    1060     f"Number of Runs          : "
#    1061     f"{num_times}"
#    1062 )
#    1065 print(
#    1066     f"Number of Layers        : "
# -> 1067     f"{num_layers}"
#    1068 )
#    1071 print(
#    1072     f"Optimization Shots      : "
#    1073     f"{num_shots}"
#    1074 )
#    1077 print(
#    1078     f"Optimization Base Seed  : "
#    1079     f"{BASE_SEED}"
#    1080 )
#
# NameError: name 'num_layers' is not defined
