# %%
# 0,1: 00 for psi_1, 01 for psi_2 ...
# 2: For states
# 3,4: Ancillary qubits

# when theta = 32.56... 
# psi_1 = |0> 
# psi_2 = sqrt(2/3)|0> + sqrt(1/3)|1>
# psi_3 = sqrt(2/3)|0> - sqrt(1/3)|1>

# %%
from qiskit import QuantumCircuit, ClassicalRegister
from numpy import sqrt, array
from numpy.linalg import norm

def circuit_init():
    qc = QuantumCircuit(5)
    return qc

def PREP(qc):
    desired_vector = [sqrt(1/3), 0, sqrt(2)/3, 1/3, sqrt(2)/3, -1/3, 0, 0]
    qc.initialize(desired_vector, [2,1,0])
    return qc

def Ansatz(qc, wires, num_layers, params):
    for i in range(num_layers):
        qc.barrier()
        offset = 6 * i
        qc.rx(params[offset + 0], wires[0])
        qc.rz(params[offset + 1], wires[0])
        qc.rx(params[offset + 2], wires[1])
        qc.rz(params[offset + 3], wires[1])
        qc.rx(params[offset + 4], wires[2])
        qc.rz(params[offset + 5], wires[2])
        qc.cx(wires[0], wires[1])
        qc.cx(wires[1], wires[2])
        qc.cx(wires[2], wires[0])
    qc.measure_all()

    return qc

# %%
from numpy.random import rand
num_layers=3
num_params= 6*num_layers
params = list(range(num_params))
num_shots=10000

qc = circuit_init()
qc = PREP(qc)
Ansatz(qc, [2,3,4] , num_layers, params)

qc.draw(output='mpl', style = 'clifford') 
#qc_reversed=qc.reverse_bits()
#qc_reversed.draw(output='mpl',style = 'clifford')

# %%
from qiskit_aer import AerSimulator
from qiskit import transpile
from scipy.optimize import minimize

import numpy as np
import os
import time


# ============================================================
# Simulator
# ============================================================

aersim = AerSimulator()


# ============================================================
# Settings
# ============================================================

num_times = 30
num_shots = 10000

optimizer_name = "COBYLA"
tol_value = 1e-8
maxiter = 1000

BASE_SEED = 150

num_layers = 3

report_filename = (
    "Sym_QNN_CB_report.txt"
)


# ============================================================
# High-Shot Evaluation Settings
# ============================================================

evaluation_num_times = 20
evaluation_num_shots = 100000

EVALUATION_BASE_SEED = 10000

evaluation_seeds = np.array(
    [
        EVALUATION_BASE_SEED + i
        for i in range(evaluation_num_times)
    ],
    dtype=int
)


# ============================================================
# Storage
# ============================================================

final_optimized_values = []

initial_params_all_runs = []
optimal_params_all_runs = []

optimization_success_all_runs = []
optimization_status_all_runs = []
optimization_message_all_runs = []
optimization_nfev_all_runs = []
reached_maxiter_all_runs = []

# ------------------------------------------------------------
# Runtime Storage
# ------------------------------------------------------------

optimization_wall_times = []


# ------------------------------------------------------------
# High-Shot Evaluation Storage
# ------------------------------------------------------------

evaluation_values_all_runs = []

evaluation_mean_all_runs = []
evaluation_std_all_runs = []
evaluation_sem_all_runs = []

evaluation_min_all_runs = []
evaluation_max_all_runs = []


# ============================================================
# Objective Function
# ============================================================

def objective_function(
    params,
    run_seed,
    shots=None,
    print_result=True
):

    if shots is None:
        shots = num_shots


    # --------------------------------------------------------
    # Construct circuit
    # --------------------------------------------------------

    qc = circuit_init()

    PREP(qc)

    Ansatz(
        qc,
        wires=[2, 3, 4],
        num_layers=num_layers,
        params=params
    )


    qc_reverse = qc.reverse_bits()


    # --------------------------------------------------------
    # Transpile
    # --------------------------------------------------------

    t_qc = transpile(
        qc_reverse,
        aersim,
        seed_transpiler=run_seed
    )


    # --------------------------------------------------------
    # Run simulator
    # --------------------------------------------------------

    job = aersim.run(
        t_qc,
        shots=shots,
        seed_simulator=run_seed
    )


    result = job.result()

    counts = result.get_counts()


    # --------------------------------------------------------
    # Target counts
    # --------------------------------------------------------

    tar_00 = 0
    tar_01 = 0
    tar_10 = 0


    for outcome, count in counts.items():

        if outcome[0:2] == "00":

            if outcome[3:5] == "00":

                tar_00 += count


        if outcome[0:2] == "01":

            if outcome[3:5] == "01":

                tar_01 += count


        if outcome[0:2] == "10":

            if outcome[3:5] == "10":

                tar_10 += count


    # --------------------------------------------------------
    # Success probability
    # --------------------------------------------------------

    p_suc = (
        tar_00
        + tar_01
        + tar_10
    ) / shots


    if print_result:

        print(
            f"success_probability = "
            f"{p_suc:.8f}"
        )


    # --------------------------------------------------------
    # Avoid division by zero
    # --------------------------------------------------------

    if p_suc == 0:

        return 1e10


    # --------------------------------------------------------
    # COBYLA minimizes.
    #
    # Minimizing 1 / p_suc maximizes p_suc.
    # --------------------------------------------------------

    return 1.0 / p_suc


# ============================================================
# Run Optimization
# ============================================================

# Total wall-clock time for the complete workflow:
# optimization + final evaluations + high-shot evaluations + overhead.
total_wall_start = time.perf_counter()

for run in range(num_times):


    # ========================================================
    # Optimization Seed
    # ========================================================

    run_seed = (
        BASE_SEED + run
    )


    rng = np.random.default_rng(
        run_seed
    )


    print(
        "\n"
        + "=" * 80
    )


    print(
        f"Optimization Run "
        f"{run + 1}/{num_times}"
    )


    print(
        f"Optimization Seed : "
        f"{run_seed}"
    )


    print(
        "=" * 80
    )


    # ========================================================
    # Generate Random Initial Parameters
    # ========================================================

    initial_params = rng.random(
        num_params
    )


    initial_params_all_runs.append(
        initial_params.copy()
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    # ========================================================
    # Run COBYLA Optimization
    # ========================================================

    print(
        "\nStarting COBYLA optimization..."
    )


    optimization_start = time.perf_counter()

    result = minimize(

        fun=lambda params: objective_function(
            params,
            run_seed,
            shots=num_shots,
            print_result=True
        ),

        x0=initial_params,

        method=optimizer_name,

        options={
            "maxiter": maxiter,
            "disp": True,
            "tol": tol_value
        }
    )

    optimization_end = time.perf_counter()

    run_optimization_wall_time = (
        optimization_end
        - optimization_start
    )

    optimization_wall_times.append(
        run_optimization_wall_time
    )


    # ========================================================
    # Optimization Status
    # ========================================================

    optimization_success = bool(
        result.success
    )


    optimization_status = getattr(
        result,
        "status",
        None
    )


    optimization_message = str(
        getattr(
            result,
            "message",
            "No message returned"
        )
    )


    optimization_nfev = getattr(
        result,
        "nfev",
        None
    )


    # ========================================================
    # Detect Whether Maximum Evaluations Was Reached
    # ========================================================

    message_lower = (
        optimization_message.lower()
    )


    reached_maxiter = (

        "maximum number"
        in message_lower

        or "maximum function"
        in message_lower

        or "maxiter"
        in message_lower

        or "maxfun"
        in message_lower

        or "maximum iterations"
        in message_lower

        or "maximum evaluations"
        in message_lower
    )


    if optimization_nfev is not None:

        if optimization_nfev >= maxiter:

            reached_maxiter = True


    # ========================================================
    # Store Optimization Status
    # ========================================================

    optimization_success_all_runs.append(
        optimization_success
    )


    optimization_status_all_runs.append(
        optimization_status
    )


    optimization_message_all_runs.append(
        optimization_message
    )


    optimization_nfev_all_runs.append(
        optimization_nfev
    )


    reached_maxiter_all_runs.append(
        reached_maxiter
    )


    # ========================================================
    # Optimal Parameters
    # ========================================================

    optimal_params = (
        result.x.copy()
    )


    optimal_params_all_runs.append(
        optimal_params.copy()
    )


    # ========================================================
    # Final Optimization-Shot Evaluation
    # ========================================================

    final_objective = objective_function(
        optimal_params,
        run_seed,
        shots=num_shots,
        print_result=False
    )


    if final_objective >= 1e10:

        final_value = 0.0

    else:

        final_value = (
            1.0 / final_objective
        )


    final_optimized_values.append(
        final_value
    )


    # ========================================================
    # High-Shot Evaluation
    # ========================================================

    print(
        "\n"
        + "-" * 80
    )


    print(
        "HIGH-SHOT EVALUATION OF "
        "OPTIMIZED PARAMETERS"
    )


    print(
        "-" * 80
    )


    print(
        f"Optimization Shots     : "
        f"{num_shots}"
    )


    print(
        f"Evaluation Shots       : "
        f"{evaluation_num_shots}"
    )


    print(
        f"Number of Evaluations : "
        f"{evaluation_num_times}"
    )


    print(
        "\nEvaluation Results:"
    )


    evaluation_values = []


    # --------------------------------------------------------
    # Same evaluation seeds are used for every optimized
    # parameter set.
    # --------------------------------------------------------

    for eval_index, eval_seed in enumerate(
        evaluation_seeds
    ):


        eval_objective = objective_function(
            optimal_params,
            int(eval_seed),
            shots=evaluation_num_shots,
            print_result=False
        )


        if eval_objective >= 1e10:

            eval_value = 0.0

        else:

            eval_value = (
                1.0 / eval_objective
            )


        evaluation_values.append(
            eval_value
        )


        # Seed is intentionally not printed here.
        print(
            f"Evaluation "
            f"{eval_index + 1:2d}/"
            f"{evaluation_num_times:2d}"
            f" | Value = "
            f"{eval_value:.8f}"
        )


    # ========================================================
    # Evaluation Statistics
    # ========================================================

    evaluation_values = np.array(
        evaluation_values,
        dtype=float
    )


    evaluation_mean = np.mean(
        evaluation_values
    )


    evaluation_std = np.std(
        evaluation_values
    )


    evaluation_sem = (
        evaluation_std
        / np.sqrt(evaluation_num_times)
    )


    evaluation_min = np.min(
        evaluation_values
    )


    evaluation_max = np.max(
        evaluation_values
    )


    # ========================================================
    # Store Evaluation Results
    # ========================================================

    evaluation_values_all_runs.append(
        evaluation_values.copy()
    )


    evaluation_mean_all_runs.append(
        evaluation_mean
    )


    evaluation_std_all_runs.append(
        evaluation_std
    )


    evaluation_sem_all_runs.append(
        evaluation_sem
    )


    evaluation_min_all_runs.append(
        evaluation_min
    )


    evaluation_max_all_runs.append(
        evaluation_max
    )


    # ========================================================
    # Individual Run Report
    # ========================================================

    print(
        "\n"
        + "=" * 80
    )


    print(
        f"RUN {run + 1} RESULT"
    )


    print(
        "=" * 80
    )


    print(
        f"Optimization Success : "
        f"{optimization_success}"
    )


    print(
        f"Reached MaxIter      : "
        f"{reached_maxiter}"
    )


    print(
        f"Status               : "
        f"{optimization_status}"
    )


    print(
        f"Message              : "
        f"{optimization_message}"
    )


    print(
        f"Function Evaluations : "
        f"{optimization_nfev}"
    )


    print(
        f"Optimization Time    : "
        f"{run_optimization_wall_time:.6f} s"
    )


    print(
        f"Final Objective Value: "
        f"{result.fun}"
    )


    print(
        "\n"
        + "-" * 80
    )


    print(
        "OPTIMIZED AND HIGH-SHOT "
        "EVALUATED VALUES"
    )


    print(
        "-" * 80
    )


    print(
        f"Final Optimized Value : "
        f"{final_value:.8f}"
    )


    print(
        f"Evaluated Mean        : "
        f"{evaluation_mean:.8f}"
    )


    print(
        f"Evaluated Std         : "
        f"{evaluation_std:.8f}"
    )


    print(
        f"Evaluated SEM         : "
        f"{evaluation_sem:.8f}"
    )


    print(
        f"Evaluated Min         : "
        f"{evaluation_min:.8f}"
    )


    print(
        f"Evaluated Max         : "
        f"{evaluation_max:.8f}"
    )


    print(
        "\nAll Evaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values,
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "=" * 80
    )


# ============================================================
# Runtime Statistics
# ============================================================

total_wall_end = time.perf_counter()

total_wall_time = (
    total_wall_end
    - total_wall_start
)

optimization_wall_times = np.array(
    optimization_wall_times,
    dtype=float
)

total_optimization_wall_time = np.sum(
    optimization_wall_times
)

mean_optimization_wall_time = np.mean(
    optimization_wall_times
)

std_optimization_wall_time = np.std(
    optimization_wall_times
)


# ============================================================
# Convert Results to NumPy Arrays
# ============================================================

final_optimized_values = np.array(
    final_optimized_values,
    dtype=float
)


initial_params_all_runs = np.array(
    initial_params_all_runs
)


optimal_params_all_runs = np.array(
    optimal_params_all_runs
)


evaluation_values_all_runs = np.array(
    evaluation_values_all_runs,
    dtype=float
)


evaluation_mean_all_runs = np.array(
    evaluation_mean_all_runs,
    dtype=float
)


evaluation_std_all_runs = np.array(
    evaluation_std_all_runs,
    dtype=float
)


evaluation_sem_all_runs = np.array(
    evaluation_sem_all_runs,
    dtype=float
)


evaluation_min_all_runs = np.array(
    evaluation_min_all_runs,
    dtype=float
)


evaluation_max_all_runs = np.array(
    evaluation_max_all_runs,
    dtype=float
)


# ============================================================
# Original Optimization Statistics
# ============================================================

maximum_value = np.max(
    final_optimized_values
)


mean_value = np.mean(
    final_optimized_values
)


std_value = np.std(
    final_optimized_values
)


maximum_run_index = np.argmax(
    final_optimized_values
)


maximum_run = (
    maximum_run_index + 1
)


# ============================================================
# High-Shot Evaluation Statistics
# ============================================================

maximum_evaluated_mean = np.max(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run_index = np.argmax(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run = (
    maximum_evaluated_mean_run_index
    + 1
)


mean_of_evaluated_means = np.mean(
    evaluation_mean_all_runs
)


std_of_evaluated_means = np.std(
    evaluation_mean_all_runs
)


# ============================================================
# Function Evaluation Statistics
# ============================================================

nfev_values = np.array(
    [
        nfev
        for nfev
        in optimization_nfev_all_runs
        if nfev is not None
    ],
    dtype=float
)


if len(nfev_values) > 0:

    mean_nfev = np.mean(
        nfev_values
    )


    std_nfev = np.std(
        nfev_values
    )

else:

    mean_nfev = np.nan
    std_nfev = np.nan


# ============================================================
# Optimization Success Statistics
# ============================================================

num_successful_runs = sum(
    optimization_success_all_runs
)


num_failed_runs = (
    num_times
    - num_successful_runs
)


num_reached_maxiter = sum(
    reached_maxiter_all_runs
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

best_initial_params = (
    initial_params_all_runs[
        maximum_run_index
    ]
)


best_optimal_params = (
    optimal_params_all_runs[
        maximum_run_index
    ]
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

best_evaluated_initial_params = (
    initial_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_optimal_params = (
    optimal_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_values = (
    evaluation_values_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


# ============================================================
# Print Final Report
# ============================================================

print("\n")


print(
    "=" * 100
)


print(
    "FINAL OPTIMIZATION AND "
    "HIGH-SHOT EVALUATION REPORT"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Settings
# ------------------------------------------------------------

print(
    f"Optimizer               : "
    f"{optimizer_name}"
)


print(
    f"Tolerance               : "
    f"{tol_value}"
)


print(
    f"Max Iteration           : "
    f"{maxiter}"
)


print(
    f"Number of Runs          : "
    f"{num_times}"
)


print(
    f"Number of Layers        : "
    f"{num_layers}"
)


print(
    f"Optimization Shots      : "
    f"{num_shots}"
)


print(
    f"Optimization Base Seed  : "
    f"{BASE_SEED}"
)


print(
    f"Evaluation Shots        : "
    f"{evaluation_num_shots}"
)


print(
    f"Evaluations Per Run     : "
    f"{evaluation_num_times}"
)


print(
    f"Evaluation Base Seed    : "
    f"{EVALUATION_BASE_SEED}"
)


# Evaluation seeds are printed ONCE here only.
print(
    "Evaluation Seeds        : "
    + np.array2string(
        evaluation_seeds,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Results for Every Run
# ============================================================

for i in range(num_times):


    print(
        f"\nRun {i + 1:2d}"
    )


    print(
        "-" * 100
    )


    print(
        f"Optimization Seed : "
        f"{BASE_SEED + i}"
    )


    print(
        f"Optimized Value   : "
        f"{final_optimized_values[i]:.8f}"
    )


    print(
        f"Evaluated Mean    : "
        f"{evaluation_mean_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Std     : "
        f"{evaluation_std_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated SEM     : "
        f"{evaluation_sem_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Min     : "
        f"{evaluation_min_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Max     : "
        f"{evaluation_max_all_runs[i]:.8f}"
    )


    print(
        f"Success           : "
        f"{optimization_success_all_runs[i]}"
    )


    print(
        f"Reached MaxIter   : "
        f"{reached_maxiter_all_runs[i]}"
    )


    print(
        f"Status            : "
        f"{optimization_status_all_runs[i]}"
    )


    print(
        f"Message           : "
        f"{optimization_message_all_runs[i]}"
    )


    print(
        f"Function Evals    : "
        f"{optimization_nfev_all_runs[i]}"
    )


    print(
        f"Optimization Time : "
        f"{optimization_wall_times[i]:.6f} s"
    )


    print(
        "\nEvaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values_all_runs[i],
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "-" * 100
    )


# ============================================================
# Summary
# ============================================================

print(
    "\nSUMMARY"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Original Optimization Results
# ------------------------------------------------------------

print(
    "\nOriginal Optimization-Shot Results:"
)


print(
    f"Maximum Optimized Value : "
    f"{maximum_value:.8f}"
)


print(
    f"Maximum Run             : "
    f"{maximum_run}"
)


print(
    f"Mean Optimized Value    : "
    f"{mean_value:.8f}"
)


print(
    f"Std Optimized Value     : "
    f"{std_value:.8f}"
)


# ------------------------------------------------------------
# High-Shot Evaluation Results
# ------------------------------------------------------------

print(
    "\nHigh-Shot Evaluation Results:"
)


print(
    f"Best Evaluated Mean     : "
    f"{maximum_evaluated_mean:.8f}"
)


print(
    f"Best Evaluated Mean Run : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Mean of Evaluated Means : "
    f"{mean_of_evaluated_means:.8f}"
)


print(
    f"Std of Evaluated Means  : "
    f"{std_of_evaluated_means:.8f}"
)


# ------------------------------------------------------------
# Optimizer Statistics
# ------------------------------------------------------------

print(
    "\nOptimizer Statistics:"
)


print(
    f"Mean Function Evals     : "
    f"{mean_nfev:.2f}"
)


print(
    f"Std Function Evals      : "
    f"{std_nfev:.2f}"
)


print(
    f"Successful Runs         : "
    f"{num_successful_runs}/"
    f"{num_times}"
)


print(
    f"Failed Runs             : "
    f"{num_failed_runs}/"
    f"{num_times}"
)


print(
    f"Reached MaxIter         : "
    f"{num_reached_maxiter}/"
    f"{num_times}"
)


# ------------------------------------------------------------
# Computational Runtime Statistics
# ------------------------------------------------------------

print(
    "\nComputational Runtime Statistics:"
)

print(
    f"Total Wall-Clock Time          : "
    f"{total_wall_time:.6f} s"
)

print(
    f"Total Optimization Time        : "
    f"{total_optimization_wall_time:.6f} s"
)

print(
    f"Time per Complete Opt. Run     : "
    f"{mean_optimization_wall_time:.6f} s"
)

print(
    f"Std Optimization Time per Run  : "
    f"{std_optimization_wall_time:.6f} s"
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "ORIGINAL OPTIMIZED VALUE"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated SEM   : "
    f"{evaluation_sem_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        evaluation_values_all_runs[
            maximum_run_index
        ],
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_optimal_params,
        precision=10,
        separator=", "
    )
)


# ============================================================
# Best Run According to High-Shot Evaluation
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "HIGH-SHOT EVALUATED MEAN"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated SEM   : "
    f"{evaluation_sem_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        best_evaluated_values,
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_evaluated_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_evaluated_optimal_params,
        precision=10,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Save Report to TXT
# ============================================================

with open(
    report_filename,
    "w"
) as f:


    # ========================================================
    # Header
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "FINAL OPTIMIZATION AND "
        "HIGH-SHOT EVALUATION REPORT\n"
    )


    f.write(
        "=" * 100
        + "\n\n"
    )


    # ========================================================
    # Settings
    # ========================================================

    f.write(
        f"Optimizer               : "
        f"{optimizer_name}\n"
    )


    f.write(
        f"Tolerance               : "
        f"{tol_value}\n"
    )


    f.write(
        f"Max Iteration           : "
        f"{maxiter}\n"
    )


    f.write(
        f"Number of Runs          : "
        f"{num_times}\n"
    )


    f.write(
        f"Number of Layers        : "
        f"{num_layers}\n"
    )


    f.write(
        f"Optimization Shots      : "
        f"{num_shots}\n"
    )


    f.write(
        f"Optimization Base Seed  : "
        f"{BASE_SEED}\n"
    )


    f.write(
        f"Evaluation Shots        : "
        f"{evaluation_num_shots}\n"
    )


    f.write(
        f"Evaluations Per Run     : "
        f"{evaluation_num_times}\n"
    )


    f.write(
        f"Evaluation Base Seed    : "
        f"{EVALUATION_BASE_SEED}\n"
    )


    # Evaluation seeds are saved ONCE here only.
    f.write(
        "Evaluation Seeds        : "
    )


    f.write(
        np.array2string(
            evaluation_seeds,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    # ========================================================
    # Results for Every Run
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "RESULTS FOR EACH RUN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    for i in range(num_times):


        f.write(
            f"\nRun {i + 1:2d}\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


        f.write(
            f"Optimization Seed : "
            f"{BASE_SEED + i}\n"
        )


        f.write(
            f"Optimized Value   : "
            f"{final_optimized_values[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Mean    : "
            f"{evaluation_mean_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Std     : "
            f"{evaluation_std_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated SEM     : "
            f"{evaluation_sem_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Min     : "
            f"{evaluation_min_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Max     : "
            f"{evaluation_max_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Success           : "
            f"{optimization_success_all_runs[i]}\n"
        )


        f.write(
            f"Reached MaxIter   : "
            f"{reached_maxiter_all_runs[i]}\n"
        )


        f.write(
            f"Status            : "
            f"{optimization_status_all_runs[i]}\n"
        )


        f.write(
            f"Message           : "
            f"{optimization_message_all_runs[i]}\n"
        )


        f.write(
            f"Function Evals    : "
            f"{optimization_nfev_all_runs[i]}\n"
        )


        f.write(
            f"Optimization Time : "
            f"{optimization_wall_times[i]:.6f} s\n"
        )


        f.write(
            "\nEvaluated Values:\n"
        )


        f.write(
            np.array2string(
                evaluation_values_all_runs[i],
                precision=8,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nInitial Parameters:\n"
        )


        f.write(
            np.array2string(
                initial_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nOptimal Parameters:\n"
        )


        f.write(
            np.array2string(
                optimal_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


    # ========================================================
    # Summary
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "SUMMARY\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    # --------------------------------------------------------
    # Original Optimization Results
    # --------------------------------------------------------

    f.write(
        "\nOriginal Optimization-Shot Results:\n"
    )


    f.write(
        f"Maximum Optimized Value : "
        f"{maximum_value:.8f}\n"
    )


    f.write(
        f"Maximum Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Mean Optimized Value    : "
        f"{mean_value:.8f}\n"
    )


    f.write(
        f"Std Optimized Value     : "
        f"{std_value:.8f}\n"
    )


    # --------------------------------------------------------
    # High-Shot Evaluation Results
    # --------------------------------------------------------

    f.write(
        "\nHigh-Shot Evaluation Results:\n"
    )


    f.write(
        f"Best Evaluated Mean     : "
        f"{maximum_evaluated_mean:.8f}\n"
    )


    f.write(
        f"Best Evaluated Mean Run : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Mean of Evaluated Means : "
        f"{mean_of_evaluated_means:.8f}\n"
    )


    f.write(
        f"Std of Evaluated Means  : "
        f"{std_of_evaluated_means:.8f}\n"
    )


    # --------------------------------------------------------
    # Optimizer Statistics
    # --------------------------------------------------------

    f.write(
        "\nOptimizer Statistics:\n"
    )


    f.write(
        f"Mean Function Evals     : "
        f"{mean_nfev:.2f}\n"
    )


    f.write(
        f"Std Function Evals      : "
        f"{std_nfev:.2f}\n"
    )


    f.write(
        f"Successful Runs         : "
        f"{num_successful_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Failed Runs             : "
        f"{num_failed_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Reached MaxIter         : "
        f"{num_reached_maxiter}/"
        f"{num_times}\n"
    )


    # --------------------------------------------------------
    # Computational Runtime Statistics
    # --------------------------------------------------------

    f.write(
        "\nComputational Runtime Statistics:\n"
    )

    f.write(
        f"Total Wall-Clock Time          : "
        f"{total_wall_time:.6f} s\n"
    )

    f.write(
        f"Total Optimization Time        : "
        f"{total_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Time per Complete Opt. Run     : "
        f"{mean_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Std Optimization Time per Run  : "
        f"{std_optimization_wall_time:.6f} s\n"
    )


    # ========================================================
    # Best Run According to Original Optimized Value
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "ORIGINAL OPTIMIZED VALUE\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated SEM   : "
        f"{evaluation_sem_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            evaluation_values_all_runs[
                maximum_run_index
            ],
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    # ========================================================
    # Best Run According to High-Shot Evaluated Mean
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "HIGH-SHOT EVALUATED MEAN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated SEM   : "
        f"{evaluation_sem_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_values,
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


# ============================================================
# Report Location
# ============================================================

print(
    "\nReport saved to:"
)


print(
    os.path.abspath(
        report_filename
    )
)
# Out:
# ================================================================================
# Optimization Run 1/30
# Optimization Seed : 150
# ================================================================================
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075]
#
# Starting COBYLA optimization...
# success_probability = 0.22520000
# success_probability = 0.21170000
# success_probability = 0.23440000
# success_probability = 0.28550000
# success_probability = 0.26500000
# success_probability = 0.31420000
# success_probability = 0.36650000
# success_probability = 0.17180000
# success_probability = 0.37950000
# success_probability = 0.35790000
# success_probability = 0.36100000
# success_probability = 0.23820000
# success_probability = 0.35470000
# success_probability = 0.34800000
# success_probability = 0.37950000
# success_probability = 0.36070000
# success_probability = 0.37950000
# success_probability = 0.41350000
# success_probability = 0.41350000
# success_probability = 0.51170000
# success_probability = 0.43680000
# success_probability = 0.50600000
# success_probability = 0.42170000
# success_probability = 0.47810000
# success_probability = 0.46190000
# success_probability = 0.49170000
# success_probability = 0.43910000
# success_probability = 0.43920000
# success_probability = 0.48920000
# success_probability = 0.52720000
# success_probability = 0.48240000
# success_probability = 0.54140000
# success_probability = 0.53750000
# success_probability = 0.54140000
# success_probability = 0.56420000
# success_probability = 0.56420000
# success_probability = 0.59980000
# success_probability = 0.59980000
# success_probability = 0.56770000
# success_probability = 0.59900000
# success_probability = 0.58130000
# success_probability = 0.59550000
# success_probability = 0.59510000
# success_probability = 0.56730000
# success_probability = 0.57310000
# success_probability = 0.60360000
# success_probability = 0.59770000
# success_probability = 0.60250000
# success_probability = 0.59390000
# success_probability = 0.59680000
# success_probability = 0.61380000
# success_probability = 0.61380000
# success_probability = 0.62000000
# success_probability = 0.62000000
# success_probability = 0.60480000
# success_probability = 0.61000000
# success_probability = 0.61800000
# success_probability = 0.62050000
# success_probability = 0.62430000
# success_probability = 0.61800000
# success_probability = 0.62090000
# success_probability = 0.62370000
# success_probability = 0.62200000
# success_probability = 0.62650000
# success_probability = 0.62370000
# success_probability = 0.62650000
# success_probability = 0.62280000
# success_probability = 0.62050000
# success_probability = 0.62180000
# success_probability = 0.62260000
# success_probability = 0.62030000
# success_probability = 0.62750000
# success_probability = 0.62760000
# success_probability = 0.62250000
# success_probability = 0.62760000
# success_probability = 0.62580000
# success_probability = 0.62840000
# success_probability = 0.63350000
# success_probability = 0.63510000
# success_probability = 0.63540000
# success_probability = 0.63480000
# success_probability = 0.63380000
# success_probability = 0.63460000
# success_probability = 0.63380000
# success_probability = 0.63380000
# success_probability = 0.62920000
# success_probability = 0.63390000
# success_probability = 0.63290000
# success_probability = 0.63540000
# success_probability = 0.63410000
# success_probability = 0.63210000
# success_probability = 0.63430000
# success_probability = 0.63470000
# success_probability = 0.63250000
# success_probability = 0.63540000
# success_probability = 0.63410000
# success_probability = 0.63350000
# success_probability = 0.63480000
# success_probability = 0.63610000
# success_probability = 0.63470000
# success_probability = 0.63370000
# success_probability = 0.63490000
# success_probability = 0.63570000
# success_probability = 0.63410000
# success_probability = 0.63470000
# success_probability = 0.63440000
# success_probability = 0.63420000
# success_probability = 0.63490000
# success_probability = 0.63420000
# success_probability = 0.63430000
# success_probability = 0.63590000
# success_probability = 0.63490000
# success_probability = 0.63520000
# success_probability = 0.63610000
# success_probability = 0.63330000
# success_probability = 0.63650000
# success_probability = 0.63650000
# success_probability = 0.63370000
# success_probability = 0.63620000
# success_probability = 0.63510000
# success_probability = 0.63600000
# success_probability = 0.63580000
# success_probability = 0.63630000
# success_probability = 0.63600000
# success_probability = 0.63610000
# success_probability = 0.63600000
# success_probability = 0.63570000
# success_probability = 0.63560000
# success_probability = 0.63610000
# success_probability = 0.63580000
# success_probability = 0.63580000
# success_probability = 0.63660000
# success_probability = 0.63620000
# success_probability = 0.63660000
# success_probability = 0.63590000
# success_probability = 0.63650000
# success_probability = 0.63560000
# success_probability = 0.63660000
# success_probability = 0.63620000
# success_probability = 0.63610000
# success_probability = 0.63660000
# success_probability = 0.63620000
# success_probability = 0.63660000
# success_probability = 0.63590000
# success_probability = 0.63660000
# success_probability = 0.63620000
# success_probability = 0.63650000
# success_probability = 0.63610000
# success_probability = 0.63640000
# success_probability = 0.63610000
# success_probability = 0.63640000
# success_probability = 0.63660000
# success_probability = 0.63630000
# success_probability = 0.63650000
# success_probability = 0.63660000
# success_probability = 0.63660000
# success_probability = 0.63660000
# success_probability = 0.63660000
# success_probability = 0.63670000
# success_probability = 0.63640000
# success_probability = 0.63660000
# success_probability = 0.63660000
# success_probability = 0.63660000
# success_probability = 0.63670000
# success_probability = 0.63640000
# success_probability = 0.63660000
# success_probability = 0.63660000
# success_probability = 0.63650000
# success_probability = 0.63660000
# success_probability = 0.63670000
# success_probability = 0.63640000
# success_probability = 0.63660000
# success_probability = 0.63640000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63670000
# success_probability = 0.63670000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63670000
# success_probability = 0.63680000
# success_probability = 0.63670000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63670000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
# success_probability = 0.63680000
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  288   F = 1.570352E+00    MAXCV = 0.000000E+00
#    X =-3.108749E-02   1.784034E+00   1.937098E+00   7.945511E-02   1.639116E+00
#        1.830938E+00  -5.656255E-02   4.767203E-01   1.864163E-01   2.419670E-01
#       -1.445524E-02   4.682709E-01   9.526471E-01   7.388265E-01   6.009883E-01
#        8.871886E-01   9.772871E-01   5.789722E-01
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.62830000
# Evaluation  2/20 | Value = 0.62930000
# Evaluation  3/20 | Value = 0.62648000
# Evaluation  4/20 | Value = 0.62845000
# Evaluation  5/20 | Value = 0.62679000
# Evaluation  6/20 | Value = 0.62587000
# Evaluation  7/20 | Value = 0.62644000
# Evaluation  8/20 | Value = 0.62762000
# Evaluation  9/20 | Value = 0.63049000
# Evaluation 10/20 | Value = 0.63114000
# Evaluation 11/20 | Value = 0.62861000
# Evaluation 12/20 | Value = 0.62774000
# Evaluation 13/20 | Value = 0.62817000
# Evaluation 14/20 | Value = 0.62647000
# Evaluation 15/20 | Value = 0.62678000
# Evaluation 16/20 | Value = 0.62729000
# Evaluation 17/20 | Value = 0.62604000
# Evaluation 18/20 | Value = 0.62796000
# Evaluation 19/20 | Value = 0.62608000
# Evaluation 20/20 | Value = 0.62951000
#
# ================================================================================
# RUN 1 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 1
# Message              : Optimization terminated successfully.
# Function Evaluations : 288
# Optimization Time    : 16.283806 s
# Final Objective Value: 1.5703517587939697
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.63680000
# Evaluated Mean        : 0.62777650
# Evaluated Std         : 0.00145850
# Evaluated SEM         : 0.00032613
# Evaluated Min         : 0.62587000
# Evaluated Max         : 0.63114000
#
# All Evaluated Values:
# [0.6283 , 0.6293 , 0.62648, 0.62845, 0.62679, 0.62587, 0.62644, 0.62762,
#  0.63049, 0.63114, 0.62861, 0.62774, 0.62817, 0.62647, 0.62678, 0.62729,
#  0.62604, 0.62796, 0.62608, 0.62951]
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075]
#
# Optimal Parameters:
# [-0.0310874896,  1.7840336782,  1.9370981521,  0.0794551054,  1.6391160047,
#   1.8309383674, -0.0565625535,  0.4767202616,  0.1864163037,  0.2419670237,
#  -0.0144552423,  0.4682708714,  0.9526470577,  0.7388264953,  0.6009882733,
#   0.8871886152,  0.9772870817,  0.5789721824]
# ================================================================================
#
# ================================================================================
# Optimization Run 2/30
# Optimization Seed : 151
# ================================================================================
#
# Initial Parameters:
# [0.4917938425, 0.3601415032, 0.7094100488, 0.6895107167, 0.4723817514,
#  0.4790485592, 0.0068635273, 0.9044398512, 0.4337399476, 0.4736042839,
#  0.034330777 , 0.9496323674, 0.5907905652, 0.4241785512, 0.1868628067,
#  0.9840929216, 0.690221156 , 0.9039467044]
#
# Starting COBYLA optimization...
# success_probability = 0.34960000
# success_probability = 0.26620000
# success_probability = 0.36340000
# success_probability = 0.36540000
# success_probability = 0.30320000
# success_probability = 0.36940000
# success_probability = 0.44530000
# success_probability = 0.41690000
# success_probability = 0.35170000
# success_probability = 0.40450000
# success_probability = 0.36670000
# success_probability = 0.41520000
# success_probability = 0.38210000
# success_probability = 0.43260000
# success_probability = 0.44530000
# success_probability = 0.45990000
# success_probability = 0.45990000
# success_probability = 0.45130000
# success_probability = 0.45990000
# success_probability = 0.55870000
# success_probability = 0.54880000
# success_probability = 0.55480000
# success_probability = 0.50070000
# success_probability = 0.57020000
# success_probability = 0.54420000
# success_probability = 0.58150000
# success_probability = 0.50550000
# success_probability = 0.57990000
# success_probability = 0.51280000
# success_probability = 0.56450000
# success_probability = 0.57790000
# success_probability = 0.59000000
# success_probability = 0.58780000
# success_probability = 0.59000000
# success_probability = 0.56230000
# success_probability = 0.59000000
# success_probability = 0.56780000
# success_probability = 0.59000000
# success_probability = 0.60710000
# success_probability = 0.59970000
# success_probability = 0.61290000
# success_probability = 0.60770000
# success_probability = 0.60960000
# success_probability = 0.60260000
# success_probability = 0.57300000
# success_probability = 0.60670000
# success_probability = 0.58770000
# success_probability = 0.59370000
# success_probability = 0.61340000
# success_probability = 0.61350000
# success_probability = 0.59210000
# success_probability = 0.59740000
# success_probability = 0.58820000
# success_probability = 0.59390000
# success_probability = 0.61140000
# success_probability = 0.61700000
# success_probability = 0.60670000
# success_probability = 0.62020000
# success_probability = 0.60490000
# success_probability = 0.62020000
# success_probability = 0.60680000
# success_probability = 0.62020000
# success_probability = 0.57390000
# success_probability = 0.62020000
# success_probability = 0.60480000
# success_probability = 0.61820000
# success_probability = 0.58660000
# success_probability = 0.61580000
# success_probability = 0.61770000
# success_probability = 0.61910000
# success_probability = 0.61600000
# success_probability = 0.62590000
# success_probability = 0.62500000
# success_probability = 0.62960000
# success_probability = 0.62070000
# success_probability = 0.63420000
# success_probability = 0.63370000
# success_probability = 0.63550000
# success_probability = 0.63530000
# success_probability = 0.62640000
# success_probability = 0.63590000
# success_probability = 0.63310000
# success_probability = 0.62920000
# success_probability = 0.63240000
# success_probability = 0.62040000
# success_probability = 0.63590000
# success_probability = 0.63190000
# success_probability = 0.63590000
# success_probability = 0.63480000
# success_probability = 0.63590000
# success_probability = 0.63080000
# success_probability = 0.63130000
# success_probability = 0.63340000
# success_probability = 0.64150000
# success_probability = 0.62980000
# success_probability = 0.64140000
# success_probability = 0.63700000
# success_probability = 0.64200000
# success_probability = 0.64150000
# success_probability = 0.63920000
# success_probability = 0.63800000
# success_probability = 0.64510000
# success_probability = 0.64300000
# success_probability = 0.64430000
# success_probability = 0.64600000
# success_probability = 0.64600000
# success_probability = 0.64520000
# success_probability = 0.64580000
# success_probability = 0.64450000
# success_probability = 0.64600000
# success_probability = 0.64680000
# success_probability = 0.64620000
# success_probability = 0.64860000
# success_probability = 0.64860000
# success_probability = 0.64610000
# success_probability = 0.64700000
# success_probability = 0.64280000
# success_probability = 0.64650000
# success_probability = 0.64570000
# success_probability = 0.64770000
# success_probability = 0.64680000
# success_probability = 0.64650000
# success_probability = 0.64590000
# success_probability = 0.64690000
# success_probability = 0.64820000
# success_probability = 0.64850000
# success_probability = 0.64790000
# success_probability = 0.64740000
# success_probability = 0.64810000
# success_probability = 0.64790000
# success_probability = 0.64780000
# success_probability = 0.64880000
# success_probability = 0.64850000
# success_probability = 0.64780000
# success_probability = 0.64840000
# success_probability = 0.64780000
# success_probability = 0.64800000
# success_probability = 0.64760000
# success_probability = 0.64810000
# success_probability = 0.64680000
# success_probability = 0.64830000
# success_probability = 0.64810000
# success_probability = 0.64820000
# success_probability = 0.64900000
# success_probability = 0.64860000
# success_probability = 0.64930000
# success_probability = 0.64930000
# success_probability = 0.64790000
# success_probability = 0.64800000
# success_probability = 0.64850000
# success_probability = 0.64800000
# success_probability = 0.64870000
# success_probability = 0.64880000
# success_probability = 0.64850000
# success_probability = 0.64860000
# success_probability = 0.64870000
# success_probability = 0.64870000
# success_probability = 0.64890000
# success_probability = 0.64870000
# success_probability = 0.64920000
# success_probability = 0.64840000
# success_probability = 0.64880000
# success_probability = 0.64890000
# success_probability = 0.64860000
# success_probability = 0.64890000
# success_probability = 0.64910000
# success_probability = 0.64870000
# success_probability = 0.64920000
# success_probability = 0.64930000
# success_probability = 0.64940000
# success_probability = 0.64880000
# success_probability = 0.64890000
# success_probability = 0.64940000
# success_probability = 0.64850000
# success_probability = 0.64930000
# success_probability = 0.64900000
# success_probability = 0.64940000
# success_probability = 0.64880000
# success_probability = 0.64910000
# success_probability = 0.64900000
# success_probability = 0.64880000
# success_probability = 0.64920000
# success_probability = 0.64910000
# success_probability = 0.64930000
# success_probability = 0.64930000
# success_probability = 0.64910000
# success_probability = 0.64930000
# success_probability = 0.64890000
# success_probability = 0.64870000
# success_probability = 0.64940000
# success_probability = 0.64930000
# success_probability = 0.64930000
# success_probability = 0.64920000
# success_probability = 0.64920000
# success_probability = 0.64920000
# success_probability = 0.64910000
# success_probability = 0.64930000
# success_probability = 0.64930000
# success_probability = 0.64940000
# success_probability = 0.64920000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64930000
# success_probability = 0.64930000
# success_probability = 0.64910000
# success_probability = 0.64940000
# success_probability = 0.64930000
# success_probability = 0.64930000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64930000
# success_probability = 0.64930000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64930000
# success_probability = 0.64930000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64950000
# success_probability = 0.64940000
# success_probability = 0.64950000
# success_probability = 0.64930000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64940000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64950000
# success_probability = 0.64940000
# success_probability = 0.64940000
# success_probability = 0.64950000
# success_probability = 0.64940000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64940000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
# success_probability = 0.64950000
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  321   F = 1.539646E+00    MAXCV = 0.000000E+00
#    X = 7.713142E-01   1.531017E+00   2.591341E+00   6.498337E-02   1.585096E+00
#        1.634769E+00   4.032887E-01   2.119376E-01   2.537557E-01  -1.828747E-02
#       -4.616000E-01   2.176776E-02   1.857281E-01   3.683821E-01   1.342015E+00
#        1.025538E+00   3.041850E-01   9.453919E-01
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.64541000
# Evaluation  2/20 | Value = 0.64792000
# Evaluation  3/20 | Value = 0.64607000
# Evaluation  4/20 | Value = 0.64600000
# Evaluation  5/20 | Value = 0.64424000
# Evaluation  6/20 | Value = 0.64194000
# Evaluation  7/20 | Value = 0.64343000
# Evaluation  8/20 | Value = 0.64800000
# Evaluation  9/20 | Value = 0.64802000
# Evaluation 10/20 | Value = 0.64669000
# Evaluation 11/20 | Value = 0.64702000
# Evaluation 12/20 | Value = 0.64550000
# Evaluation 13/20 | Value = 0.64537000
# Evaluation 14/20 | Value = 0.64652000
# Evaluation 15/20 | Value = 0.64405000
# Evaluation 16/20 | Value = 0.64566000
# Evaluation 17/20 | Value = 0.64446000
# Evaluation 18/20 | Value = 0.64633000
# Evaluation 19/20 | Value = 0.64424000
# Evaluation 20/20 | Value = 0.64769000
#
# ================================================================================
# RUN 2 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 1
# Message              : Optimization terminated successfully.
# Function Evaluations : 321
# Optimization Time    : 17.677880 s
# Final Objective Value: 1.539645881447267
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.64950000
# Evaluated Mean        : 0.64572800
# Evaluated Std         : 0.00160643
# Evaluated SEM         : 0.00035921
# Evaluated Min         : 0.64194000
# Evaluated Max         : 0.64802000
#
# All Evaluated Values:
# [0.64541, 0.64792, 0.64607, 0.646  , 0.64424, 0.64194, 0.64343, 0.648  ,
#  0.64802, 0.64669, 0.64702, 0.6455 , 0.64537, 0.64652, 0.64405, 0.64566,
#  0.64446, 0.64633, 0.64424, 0.64769]
#
# Initial Parameters:
# [0.4917938425, 0.3601415032, 0.7094100488, 0.6895107167, 0.4723817514,
#  0.4790485592, 0.0068635273, 0.9044398512, 0.4337399476, 0.4736042839,
#  0.034330777 , 0.9496323674, 0.5907905652, 0.4241785512, 0.1868628067,
#  0.9840929216, 0.690221156 , 0.9039467044]
#
# Optimal Parameters:
# [ 0.7713141873,  1.5310174271,  2.5913405846,  0.0649833716,  1.5850955056,
#   1.6347689256,  0.4032886736,  0.2119375688,  0.2537556647, -0.0182874669,
#  -0.4616000034,  0.0217677586,  0.1857280577,  0.3683821218,  1.3420146446,
#   1.025538157 ,  0.3041849598,  0.9453919399]
# ================================================================================
#
# ================================================================================
# Optimization Run 3/30
# Optimization Seed : 152
# ================================================================================
#
# Initial Parameters:
# [0.2185327016, 0.2605845547, 0.0494520073, 0.5385992113, 0.5420706407,
#  0.7890536718, 0.9123372133, 0.3722628249, 0.3257754726, 0.6556609124,
#  0.8969863307, 0.6516960973, 0.7833870606, 0.8742393722, 0.1922236761,
#  0.610154332 , 0.9457183359, 0.8193944158]
#
# Starting COBYLA optimization...
# success_probability = 0.18540000
# success_probability = 0.16060000
# success_probability = 0.18480000
# success_probability = 0.20600000
# success_probability = 0.24870000
# success_probability = 0.23350000
# success_probability = 0.21860000
# success_probability = 0.22990000
# success_probability = 0.26590000
# success_probability = 0.30700000
# success_probability = 0.36400000
# success_probability = 0.20400000
# success_probability = 0.43060000
# success_probability = 0.41130000
# success_probability = 0.43060000
# success_probability = 0.37450000
# success_probability = 0.43060000
# success_probability = 0.45740000
# success_probability = 0.45740000
# success_probability = 0.53080000
# success_probability = 0.51230000
# success_probability = 0.46260000
# success_probability = 0.43970000
# success_probability = 0.53230000
# success_probability = 0.46360000
# success_probability = 0.54340000
# success_probability = 0.51670000
# success_probability = 0.50660000
# success_probability = 0.45450000
# success_probability = 0.48880000
# success_probability = 0.55460000
# success_probability = 0.55810000
# success_probability = 0.54170000
# success_probability = 0.56050000
# success_probability = 0.56050000
# success_probability = 0.54810000
# success_probability = 0.56050000
# success_probability = 0.51900000
# success_probability = 0.57330000
# success_probability = 0.56810000
# success_probability = 0.57140000
# success_probability = 0.55700000
# success_probability = 0.57370000
# success_probability = 0.54760000
# success_probability = 0.55600000
# success_probability = 0.54010000
# success_probability = 0.58150000
# success_probability = 0.58090000
# success_probability = 0.55530000
# success_probability = 0.56520000
# success_probability = 0.58310000
# success_probability = 0.58380000
# success_probability = 0.57270000
# success_probability = 0.57310000
# success_probability = 0.58150000
# success_probability = 0.55740000
# success_probability = 0.58280000
# success_probability = 0.57150000
# success_probability = 0.58730000
# success_probability = 0.59190000
# success_probability = 0.59490000
# success_probability = 0.59490000
# success_probability = 0.60350000
# success_probability = 0.60350000
# success_probability = 0.61450000
# success_probability = 0.61980000
# success_probability = 0.61300000
# success_probability = 0.62090000
# success_probability = 0.61900000
# success_probability = 0.61360000
# success_probability = 0.61960000
# success_probability = 0.61570000
# success_probability = 0.61970000
# success_probability = 0.61720000
# success_probability = 0.62340000
# success_probability = 0.61920000
# success_probability = 0.61730000
# success_probability = 0.62090000
# success_probability = 0.61870000
# success_probability = 0.62340000
# success_probability = 0.61820000
# success_probability = 0.62070000
# success_probability = 0.62470000
# success_probability = 0.62510000
# success_probability = 0.62400000
# success_probability = 0.62430000
# success_probability = 0.62550000
# success_probability = 0.62430000
# success_probability = 0.62920000
# success_probability = 0.62640000
# success_probability = 0.63210000
# success_probability = 0.63090000
# success_probability = 0.62880000
# success_probability = 0.63610000
# success_probability = 0.63870000
# success_probability = 0.63620000
# success_probability = 0.64120000
# success_probability = 0.64030000
# success_probability = 0.63730000
# success_probability = 0.64120000
# success_probability = 0.63990000
# success_probability = 0.64020000
# success_probability = 0.64230000
# success_probability = 0.64150000
# success_probability = 0.64230000
# success_probability = 0.64160000
# success_probability = 0.64330000
# success_probability = 0.64370000
# success_probability = 0.64080000
# success_probability = 0.64290000
# success_probability = 0.64270000
# success_probability = 0.64320000
# success_probability = 0.64450000
# success_probability = 0.64470000
# success_probability = 0.64240000
# success_probability = 0.64500000
# success_probability = 0.64170000
# success_probability = 0.64560000
# success_probability = 0.64340000
# success_probability = 0.64560000
# success_probability = 0.64110000
# success_probability = 0.64470000
# success_probability = 0.64510000
# success_probability = 0.64520000
# success_probability = 0.64440000
# success_probability = 0.64490000
# success_probability = 0.64520000
# success_probability = 0.64340000
# success_probability = 0.64410000
# success_probability = 0.64450000
# success_probability = 0.64370000
# success_probability = 0.64370000
# success_probability = 0.64510000
# success_probability = 0.64520000
# success_probability = 0.64480000
# success_probability = 0.64510000
# success_probability = 0.64510000
# success_probability = 0.64540000
# success_probability = 0.64420000
# success_probability = 0.64490000
# success_probability = 0.64590000
# success_probability = 0.64590000
# success_probability = 0.64580000
# success_probability = 0.64630000
# success_probability = 0.64650000
# success_probability = 0.64660000
# success_probability = 0.64640000
# success_probability = 0.64600000
# success_probability = 0.64660000
# success_probability = 0.64630000
# success_probability = 0.64640000
# success_probability = 0.64660000
# success_probability = 0.64630000
# success_probability = 0.64660000
# success_probability = 0.64620000
# success_probability = 0.64560000
# success_probability = 0.64640000
# success_probability = 0.64590000
# success_probability = 0.64640000
# success_probability = 0.64600000
# success_probability = 0.64690000
# success_probability = 0.64600000
# success_probability = 0.64650000
# success_probability = 0.64640000
# success_probability = 0.64660000
# success_probability = 0.64650000
# success_probability = 0.64690000
# success_probability = 0.64680000
# success_probability = 0.64670000
# success_probability = 0.64670000
# success_probability = 0.64640000
# success_probability = 0.64650000
# success_probability = 0.64650000
# success_probability = 0.64680000
# success_probability = 0.64620000
# success_probability = 0.64710000
# success_probability = 0.64690000
# success_probability = 0.64630000
# success_probability = 0.64680000
# success_probability = 0.64690000
# success_probability = 0.64710000
# success_probability = 0.64670000
# success_probability = 0.64680000
# success_probability = 0.64680000
# success_probability = 0.64710000
# success_probability = 0.64680000
# success_probability = 0.64670000
# success_probability = 0.64660000
# success_probability = 0.64710000
# success_probability = 0.64620000
# success_probability = 0.64690000
# success_probability = 0.64710000
# success_probability = 0.64710000
# success_probability = 0.64680000
# success_probability = 0.64720000
# success_probability = 0.64680000
# success_probability = 0.64720000
# success_probability = 0.64680000
# success_probability = 0.64710000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64710000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64710000
# success_probability = 0.64720000
# success_probability = 0.64680000
# success_probability = 0.64720000
# success_probability = 0.64690000
# success_probability = 0.64720000
# success_probability = 0.64680000
# success_probability = 0.64720000
# success_probability = 0.64680000
# success_probability = 0.64710000
# success_probability = 0.64700000
# success_probability = 0.64710000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64710000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
# success_probability = 0.64720000
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  321   F = 1.545117E+00    MAXCV = 0.000000E+00
#    X =-3.267268E-01   4.237728E-01   1.545161E+00   1.634349E+00  -7.340119E-02
#       -4.972665E-01   1.339637E+00   1.544392E+00   1.690011E+00   1.601873E+00
#        8.764559E-02   1.623813E+00   1.150094E+00   8.749445E-01  -1.973252E-02
#        5.170525E-01   1.492083E+00   7.577691E-01
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.64199000
# Evaluation  2/20 | Value = 0.64524000
# Evaluation  3/20 | Value = 0.64323000
# Evaluation  4/20 | Value = 0.64364000
# Evaluation  5/20 | Value = 0.64144000
# Evaluation  6/20 | Value = 0.63887000
# Evaluation  7/20 | Value = 0.64076000
# Evaluation  8/20 | Value = 0.64522000
# Evaluation  9/20 | Value = 0.64529000
# Evaluation 10/20 | Value = 0.64379000
# Evaluation 11/20 | Value = 0.64368000
# Evaluation 12/20 | Value = 0.64157000
# Evaluation 13/20 | Value = 0.64250000
# Evaluation 14/20 | Value = 0.64373000
# Evaluation 15/20 | Value = 0.64161000
# Evaluation 16/20 | Value = 0.64235000
# Evaluation 17/20 | Value = 0.64082000
# Evaluation 18/20 | Value = 0.64337000
# Evaluation 19/20 | Value = 0.64209000
# Evaluation 20/20 | Value = 0.64378000
#
# ================================================================================
# RUN 3 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 1
# Message              : Optimization terminated successfully.
# Function Evaluations : 321
# Optimization Time    : 17.733920 s
# Final Objective Value: 1.5451174289245984
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.64720000
# Evaluated Mean        : 0.64274850
# Evaluated Std         : 0.00162035
# Evaluated SEM         : 0.00036232
# Evaluated Min         : 0.63887000
# Evaluated Max         : 0.64529000
#
# All Evaluated Values:
# [0.64199, 0.64524, 0.64323, 0.64364, 0.64144, 0.63887, 0.64076, 0.64522,
#  0.64529, 0.64379, 0.64368, 0.64157, 0.6425 , 0.64373, 0.64161, 0.64235,
#  0.64082, 0.64337, 0.64209, 0.64378]
#
# Initial Parameters:
# [0.2185327016, 0.2605845547, 0.0494520073, 0.5385992113, 0.5420706407,
#  0.7890536718, 0.9123372133, 0.3722628249, 0.3257754726, 0.6556609124,
#  0.8969863307, 0.6516960973, 0.7833870606, 0.8742393722, 0.1922236761,
#  0.610154332 , 0.9457183359, 0.8193944158]
#
# Optimal Parameters:
# [-0.3267267806,  0.4237727724,  1.5451612799,  1.634348734 , -0.073401189 ,
#  -0.4972664592,  1.339637327 ,  1.5443915696,  1.6900109725,  1.601872637 ,
#   0.0876455939,  1.6238126232,  1.1500944055,  0.8749444575, -0.0197325169,
#   0.5170525179,  1.4920827326,  0.7577690761]
# ================================================================================
#
# ================================================================================
# Optimization Run 4/30
# Optimization Seed : 153
# ================================================================================
#
# Initial Parameters:
# [0.9351787748, 0.5440484715, 0.1109812758, 0.8565970763, 0.3821572142,
#  0.9499039298, 0.3855507108, 0.5811580834, 0.920415456 , 0.0082027188,
#  0.9726734037, 0.2335279912, 0.0796605772, 0.8396870049, 0.3792427994,
#  0.8424622263, 0.3825950036, 0.0886091157]
#
# Starting COBYLA optimization...
# success_probability = 0.23830000
# success_probability = 0.17430000
# success_probability = 0.24880000
# success_probability = 0.30070000
# success_probability = 0.29220000
# success_probability = 0.35550000
# success_probability = 0.34300000
# success_probability = 0.22360000
# success_probability = 0.34400000
# success_probability = 0.38490000
# success_probability = 0.39790000
# success_probability = 0.25810000
# success_probability = 0.38160000
# success_probability = 0.35550000
# success_probability = 0.39790000
# success_probability = 0.39000000
# success_probability = 0.39790000
# success_probability = 0.42170000
# success_probability = 0.42170000
# success_probability = 0.42540000
# success_probability = 0.43320000
# success_probability = 0.28150000
# success_probability = 0.39490000
# success_probability = 0.40810000
# success_probability = 0.41930000
# success_probability = 0.48110000
# success_probability = 0.48380000
# success_probability = 0.43720000
# success_probability = 0.45560000
# success_probability = 0.46800000
# success_probability = 0.48520000
# success_probability = 0.49000000
# success_probability = 0.43330000
# success_probability = 0.47010000
# success_probability = 0.49000000
# success_probability = 0.47460000
# success_probability = 0.49000000
# success_probability = 0.47450000
# success_probability = 0.47370000
# success_probability = 0.47010000
# success_probability = 0.45620000
# success_probability = 0.47080000
# success_probability = 0.45790000
# success_probability = 0.47810000
# success_probability = 0.49760000
# success_probability = 0.49040000
# success_probability = 0.49440000
# success_probability = 0.49730000
# success_probability = 0.48750000
# success_probability = 0.48980000
# success_probability = 0.53660000
# success_probability = 0.54820000
# success_probability = 0.51360000
# success_probability = 0.55240000
# success_probability = 0.56850000
# success_probability = 0.55560000
# success_probability = 0.57090000
# success_probability = 0.56500000
# success_probability = 0.57960000
# success_probability = 0.55220000
# success_probability = 0.61190000
# success_probability = 0.58460000
# success_probability = 0.61190000
# success_probability = 0.52720000
# success_probability = 0.61190000
# success_probability = 0.59930000
# success_probability = 0.60390000
# success_probability = 0.58750000
# success_probability = 0.59830000
# success_probability = 0.61560000
# success_probability = 0.62020000
# success_probability = 0.63160000
# success_probability = 0.63480000
# success_probability = 0.61720000
# success_probability = 0.62540000
# success_probability = 0.63320000
# success_probability = 0.62970000
# success_probability = 0.61060000
# success_probability = 0.63840000
# success_probability = 0.60690000
# success_probability = 0.64080000
# success_probability = 0.61370000
# success_probability = 0.63290000
# success_probability = 0.63860000
# success_probability = 0.64180000
# success_probability = 0.61340000
# success_probability = 0.63360000
# success_probability = 0.61920000
# success_probability = 0.64390000
# success_probability = 0.61480000
# success_probability = 0.63010000
# success_probability = 0.61410000
# success_probability = 0.64190000
# success_probability = 0.64390000
# success_probability = 0.63680000
# success_probability = 0.64430000
# success_probability = 0.64330000
# success_probability = 0.64390000
# success_probability = 0.64270000
# success_probability = 0.64780000
# success_probability = 0.63710000
# success_probability = 0.64630000
# success_probability = 0.64760000
# success_probability = 0.64380000
# success_probability = 0.64330000
# success_probability = 0.64110000
# success_probability = 0.64150000
# success_probability = 0.64830000
# success_probability = 0.64640000
# success_probability = 0.65000000
# success_probability = 0.64930000
# success_probability = 0.64960000
# success_probability = 0.65130000
# success_probability = 0.64790000
# success_probability = 0.64980000
# success_probability = 0.64800000
# success_probability = 0.65010000
# success_probability = 0.65100000
# success_probability = 0.65010000
# success_probability = 0.65130000
# success_probability = 0.65060000
# success_probability = 0.65100000
# success_probability = 0.64810000
# success_probability = 0.65130000
# success_probability = 0.65100000
# success_probability = 0.64880000
# success_probability = 0.65140000
# success_probability = 0.64890000
# success_probability = 0.65150000
# success_probability = 0.65150000
# success_probability = 0.65170000
# success_probability = 0.65210000
# success_probability = 0.65080000
# success_probability = 0.65190000
# success_probability = 0.65190000
# success_probability = 0.65200000
# success_probability = 0.65070000
# success_probability = 0.65210000
# success_probability = 0.65240000
# success_probability = 0.65010000
# success_probability = 0.65140000
# success_probability = 0.65080000
# success_probability = 0.65100000
# success_probability = 0.64990000
# success_probability = 0.65250000
# success_probability = 0.65200000
# success_probability = 0.65080000
# success_probability = 0.65180000
# success_probability = 0.65050000
# success_probability = 0.65200000
# success_probability = 0.65100000
# success_probability = 0.65180000
# success_probability = 0.65110000
# success_probability = 0.65290000
# success_probability = 0.65120000
# success_probability = 0.65190000
# success_probability = 0.65190000
# success_probability = 0.65250000
# success_probability = 0.65230000
# success_probability = 0.65220000
# success_probability = 0.65200000
# success_probability = 0.65190000
# success_probability = 0.65150000
# success_probability = 0.65290000
# success_probability = 0.65220000
# success_probability = 0.65250000
# success_probability = 0.65210000
# success_probability = 0.65270000
# success_probability = 0.65120000
# success_probability = 0.65140000
# success_probability = 0.65230000
# success_probability = 0.65150000
# success_probability = 0.65240000
# ...
#
# Run 22
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 171
# Optimized Value   : 0.63610000
# Evaluated Mean    : 0.63555800
# Evaluated Std     : 0.00164997
# Evaluated SEM     : 0.00036894
# Evaluated Min     : 0.63151000
# Evaluated Max     : 0.63852000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 323
# Optimization Time : 18.351996 s
#
# Evaluated Values:
# [0.63585, 0.63654, 0.63546, 0.63616, 0.63445, 0.63151, 0.6347 , 0.63617,
#  0.6382 , 0.63852, 0.63634, 0.63682, 0.63564, 0.6353 , 0.63456, 0.63484,
#  0.63301, 0.63607, 0.63351, 0.63751]
#
# Initial Parameters:
# [0.1024943338, 0.7590156346, 0.5423988438, 0.2717202027, 0.821423202 ,
#  0.5490770792, 0.3929539844, 0.4443998034, 0.8931920339, 0.6002576055,
#  0.2288338735, 0.7955796738, 0.5437449364, 0.3068613245, 0.2044913485,
#  0.8968288433, 0.6989656495, 0.9796459926]
#
# Optimal Parameters:
# [ 0.1248857316,  1.581905951 ,  0.3874666235,  0.405648979 ,  1.5388501463,
#   1.5145089496,  0.0053572353,  0.4077072106,  1.1556338258,  0.1058667075,
#  -0.1821984338,  0.3494121571,  0.977806325 ,  0.2495267348,  0.6211013696,
#   0.7841243175,  1.5744104662,  1.0103028955]
# ----------------------------------------------------------------------------------------------------
#
# Run 23
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 172
# Optimized Value   : 0.62570000
# Evaluated Mean    : 0.63526000
# Evaluated Std     : 0.00166193
# Evaluated SEM     : 0.00037162
# Evaluated Min     : 0.63068000
# Evaluated Max     : 0.63813000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 274
# Optimization Time : 15.496160 s
#
# Evaluated Values:
# [0.63483, 0.63702, 0.63544, 0.63572, 0.63512, 0.63068, 0.63334, 0.63813,
#  0.63686, 0.63678, 0.63654, 0.63451, 0.63482, 0.6367 , 0.63349, 0.63539,
#  0.63313, 0.63521, 0.63494, 0.63655]
#
# Initial Parameters:
# [0.1702293838, 0.9230877777, 0.5877290957, 0.306458957 , 0.4751153524,
#  0.3697992575, 0.4214819696, 0.5618192319, 0.161492304 , 0.8493918532,
#  0.0143050224, 0.3930636181, 0.7191759106, 0.2969669963, 0.7611493365,
#  0.0896341489, 0.847170193 , 0.8567125443]
#
# Optimal Parameters:
# [-0.4226953375,  1.6221619022,  2.2185719892,  0.3197516813,  1.5886578945,
#   1.348874585 ,  0.198212953 , -0.2400250782,  0.6745055959, -0.0053427524,
#  -0.3360524467, -0.2388247751,  1.2368353044,  0.7163768786,  0.3479045268,
#   0.1072498393,  0.2143172192,  0.7277614014]
# ----------------------------------------------------------------------------------------------------
#
# Run 24
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 173
# Optimized Value   : 0.64700000
# Evaluated Mean    : 0.64600550
# Evaluated Std     : 0.00154896
# Evaluated SEM     : 0.00034636
# Evaluated Min     : 0.64220000
# Evaluated Max     : 0.64847000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 294
# Optimization Time : 16.689003 s
#
# Evaluated Values:
# [0.64563, 0.64826, 0.64645, 0.64626, 0.64419, 0.6422 , 0.64462, 0.64807,
#  0.64847, 0.64702, 0.64698, 0.64615, 0.6456 , 0.64648, 0.64412, 0.64552,
#  0.64485, 0.6465 , 0.64488, 0.64786]
#
# Initial Parameters:
# [0.0683064102, 0.5061877572, 0.2800764934, 0.4917358842, 0.3376481488,
#  0.6337766115, 0.7941202296, 0.2237709719, 0.8893153608, 0.9462072178,
#  0.9270749557, 0.8979372613, 0.8865232604, 0.1112901922, 0.4404611446,
#  0.6571269562, 0.6018173982, 0.0668305069]
#
# Optimal Parameters:
# [ 0.8999847811,  1.5788756205,  1.576044088 ,  1.555303946 ,  1.5723048494,
#   1.5393933875,  0.2520735384,  1.6248453085,  2.4881502765,  1.6400176189,
#   1.2788096427,  1.5778631225, -0.0126407547,  0.0311528567,  0.0028763151,
#   0.2131717688,  1.609351473 ,  0.1232050374]
# ----------------------------------------------------------------------------------------------------
#
# Run 25
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 174
# Optimized Value   : 0.64800000
# Evaluated Mean    : 0.64242750
# Evaluated Std     : 0.00164915
# Evaluated SEM     : 0.00036876
# Evaluated Min     : 0.63799000
# Evaluated Max     : 0.64497000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 312
# Optimization Time : 17.631289 s
#
# Evaluated Values:
# [0.64158, 0.64439, 0.64243, 0.64295, 0.64129, 0.63799, 0.6407 , 0.64459,
#  0.64497, 0.64368, 0.64345, 0.64256, 0.64251, 0.64353, 0.64159, 0.64236,
#  0.6405 , 0.64279, 0.64061, 0.64408]
#
# Initial Parameters:
# [0.920751175 , 0.8324481628, 0.9226421153, 0.4120178702, 0.112899878 ,
#  0.539662511 , 0.9690640438, 0.8958288503, 0.8463732302, 0.6837088366,
#  0.0134777936, 0.9213092468, 0.0585796685, 0.528523907 , 0.4212992395,
#  0.8064657524, 0.2081509804, 0.1492170041]
#
# Optimal Parameters:
# [ 1.6058959432,  1.7207563979,  1.5338274273,  1.5492755151,  0.1800661557,
#  -0.0866360126,  1.5513424123,  1.5370652376,  2.0047796865,  1.4097393606,
#  -0.0332554657,  1.3622026522, -0.0768742051,  0.6435896262,  0.0034171534,
#   0.7943664817,  1.5996100642,  0.1491692   ]
# ----------------------------------------------------------------------------------------------------
#
# Run 26
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 175
# Optimized Value   : 0.64810000
# Evaluated Mean    : 0.64427850
# Evaluated Std     : 0.00176013
# Evaluated SEM     : 0.00039358
# Evaluated Min     : 0.64002000
# Evaluated Max     : 0.64772000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 295
# Optimization Time : 16.603705 s
#
# Evaluated Values:
# [0.64408, 0.6468 , 0.64477, 0.64469, 0.64273, 0.64002, 0.64209, 0.64661,
#  0.64772, 0.64576, 0.64511, 0.64363, 0.64358, 0.64478, 0.64253, 0.64456,
#  0.6428 , 0.64429, 0.64327, 0.64575]
#
# Initial Parameters:
# [0.5632800098, 0.5263460088, 0.074383608 , 0.0432472297, 0.1116614549,
#  0.3149336925, 0.8051899849, 0.2265811498, 0.2507577735, 0.3247400132,
#  0.7132637608, 0.7744654451, 0.9295185054, 0.8709503245, 0.9380278462,
#  0.6231528096, 0.2419077457, 0.8799737511]
#
# Optimal Parameters:
# [-0.3538035925,  1.5246104776,  0.1180581841,  0.5862370924,  1.4757043275,
#   2.1002431951, -0.1629890303, -0.5554965924,  1.1137890503,  0.0325618672,
#   0.1213911946, -0.0696262155,  0.2973760873,  0.8624248279,  1.2842961039,
#   0.6294206365,  1.9625729271,  0.4324297659]
# ----------------------------------------------------------------------------------------------------
#
# Run 27
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 176
# Optimized Value   : 0.64180000
# Evaluated Mean    : 0.64380400
# Evaluated Std     : 0.00158390
# Evaluated SEM     : 0.00035417
# Evaluated Min     : 0.64018000
# Evaluated Max     : 0.64652000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 324
# Optimization Time : 18.291648 s
#
# Evaluated Values:
# [0.64308, 0.64545, 0.64435, 0.64439, 0.64213, 0.64018, 0.64229, 0.64624,
#  0.64652, 0.64435, 0.64442, 0.64401, 0.64349, 0.64458, 0.64182, 0.6441 ,
#  0.64169, 0.64465, 0.64278, 0.64556]
#
# Initial Parameters:
# [0.908796571 , 0.1480812304, 0.9316217524, 0.8690627692, 0.8218723273,
#  0.3598173853, 0.8198721198, 0.1817033926, 0.2126209616, 0.6959983996,
#  0.3659168242, 0.6449720995, 0.1945739112, 0.1231941489, 0.9608135811,
#  0.9693122607, 0.6994862206, 0.3285305578]
#
# Optimal Parameters:
# [0.184811624 , 1.5358874415, 1.2001855758, 1.5036652778, 2.1350949261,
#  0.0444238761, 0.1538544567, 1.508567168 , 0.9798567549, 0.4611007634,
#  0.0336962233, 0.4614287715, 0.0365225663, 0.2503044838, 1.4513963323,
#  0.2903023303, 1.7348579019, 0.0604650064]
# ----------------------------------------------------------------------------------------------------
#
# Run 28
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 177
# Optimized Value   : 0.63920000
# Evaluated Mean    : 0.64438250
# Evaluated Std     : 0.00162241
# Evaluated SEM     : 0.00036278
# Evaluated Min     : 0.64037000
# Evaluated Max     : 0.64710000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 274
# Optimization Time : 15.511274 s
#
# Evaluated Values:
# [0.64377, 0.6461 , 0.64471, 0.6449 , 0.64301, 0.64037, 0.6429 , 0.64664,
#  0.6471 , 0.64519, 0.6451 , 0.64471, 0.64413, 0.64511, 0.64236, 0.64482,
#  0.64212, 0.64519, 0.64327, 0.64615]
#
# Initial Parameters:
# [0.4859979492, 0.3134855983, 0.5928545916, 0.5388495959, 0.8208222388,
#  0.1681699936, 0.7886708539, 0.9073399324, 0.1513191786, 0.6385598502,
#  0.0204482374, 0.441729694 , 0.1062169866, 0.3316953766, 0.9856944419,
#  0.4606017013, 0.291802071 , 0.5311775661]
#
# Optimal Parameters:
# [-0.316618593 ,  1.5602480992,  1.8431540396,  1.5437419117,  1.7954436793,
#  -0.0127243711,  1.3874471727,  1.6012777676,  1.3774990086,  0.3541068716,
#   0.0852834216,  0.3619346892, -0.2559729973,  0.3472941868,  0.2494565809,
#   0.4419235558,  1.6243682863,  0.5119599931]
# ----------------------------------------------------------------------------------------------------
#
# Run 29
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 178
# Optimized Value   : 0.64630000
# Evaluated Mean    : 0.64533150
# Evaluated Std     : 0.00176440
# Evaluated SEM     : 0.00039453
# Evaluated Min     : 0.64112000
# Evaluated Max     : 0.64813000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 317
# Optimization Time : 17.832173 s
#
# Evaluated Values:
# [0.64498, 0.64722, 0.64527, 0.64585, 0.64484, 0.64112, 0.64356, 0.64761,
#  0.64813, 0.64634, 0.64708, 0.6451 , 0.64536, 0.64634, 0.64309, 0.64524,
#  0.64291, 0.64596, 0.64335, 0.64728]
#
# Initial Parameters:
# [0.7608275692, 0.0464101376, 0.0032708871, 0.7605003536, 0.2769531808,
#  0.5945503444, 0.8036218146, 0.7402677744, 0.1239034672, 0.2438968692,
#  0.748428843 , 0.9205783868, 0.2357355697, 0.9391032789, 0.4081091944,
#  0.4620759117, 0.7294079941, 0.5779372506]
#
# Optimal Parameters:
# [-0.2837913402,  1.5625916601,  1.6220266743,  1.6249360301,  1.6347120768,
#   1.4806335389,  1.1736787238,  1.6182676508,  1.6576501879,  1.6482813683,
#   0.3487545344,  1.6102308142,  0.0280853219,  0.9832071699,  0.038105786 ,
#   0.5034846956,  1.5205097459,  0.5932727432]
# ----------------------------------------------------------------------------------------------------
#
# Run 30
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 179
# Optimized Value   : 0.65060000
# Evaluated Mean    : 0.64441400
# Evaluated Std     : 0.00176871
# Evaluated SEM     : 0.00039549
# Evaluated Min     : 0.64021000
# Evaluated Max     : 0.64726000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 287
# Optimization Time : 16.214837 s
#
# Evaluated Values:
# [0.64396, 0.64695, 0.64468, 0.64416, 0.64315, 0.64021, 0.64211, 0.64726,
#  0.64665, 0.64599, 0.64556, 0.6439 , 0.64413, 0.64501, 0.64283, 0.64527,
#  0.64212, 0.64429, 0.64355, 0.6465 ]
#
# Initial Parameters:
# [0.9180695286, 0.9403935557, 0.9611445873, 0.1282735573, 0.7343854482,
#  0.1418537547, 0.3206870255, 0.8783134777, 0.3925501756, 0.9542827898,
#  0.4333144504, 0.0052152104, 0.5921889116, 0.318609756 , 0.9316370681,
#  0.6026668473, 0.0078690534, 0.7991305598]
#
# Optimal Parameters:
# [ 0.4616259553,  2.4396284541,  2.5035454684,  0.1592401093,  1.6235032502,
#   1.6975525535, -0.2011298242,  0.5890331149,  0.6707641695,  0.901536279 ,
#   0.2206229151, -0.0365059878, -0.1366269129, -0.1058966753,  1.7090132277,
#   0.4683136454,  0.0036291775,  0.3121401889]
# ----------------------------------------------------------------------------------------------------
#
# SUMMARY
# ====================================================================================================
#
# Original Optimization-Shot Results:
# Maximum Optimized Value : 0.66010000
# Maximum Run             : 6
# Mean Optimized Value    : 0.64587333
# Std Optimized Value     : 0.00733375
#
# High-Shot Evaluation Results:
# Best Evaluated Mean     : 0.64613800
# Best Evaluated Mean Run : 21
# Mean of Evaluated Means : 0.64201840
# Std of Evaluated Means  : 0.00450959
#
# Optimizer Statistics:
# Mean Function Evals     : 304.07
# Std Function Evals      : 21.74
# Successful Runs         : 30/30
# Failed Runs             : 0/30
# Reached MaxIter         : 0/30
#
# Computational Runtime Statistics:
# Total Wall-Clock Time          : 560.992007 s
# Total Optimization Time        : 514.419892 s
# Time per Complete Opt. Run     : 17.147330 s
# Std Optimization Time per Run  : 1.214832 s
#
# ====================================================================================================
# BEST RUN ACCORDING TO ORIGINAL OPTIMIZED VALUE
# ====================================================================================================
# Run             : 6
# Optimized Value : 0.66010000
# Evaluated Mean  : 0.64525750
# Evaluated Std   : 0.00164909
# Evaluated SEM   : 0.00036875
# Evaluated Min   : 0.64118000
# Evaluated Max   : 0.64783000
#
# Evaluated Values:
# [0.64436, 0.64734, 0.64568, 0.64571, 0.64418, 0.64118, 0.64328, 0.64783,
#  0.64752, 0.6472 , 0.64603, 0.64534, 0.64472, 0.64534, 0.64346, 0.64551,
#  0.64376, 0.64577, 0.64391, 0.64703]
#
# Initial Parameters:
# [0.3114798279, 0.8305870248, 0.3618952412, 0.6435388083, 0.2472304492,
#  0.7245005345, 0.2110327772, 0.8652346895, 0.3502640216, 0.3240004707,
#  0.4085586437, 0.7775305865, 0.0813795236, 0.1716318327, 0.4096552724,
#  0.2097527797, 0.9685092354, 0.9113196559]
#
# Optimal Parameters:
# [ 0.1038674891,  1.6042196291,  1.6895377508,  0.0041238574,  1.4901663624,
#   1.5113338099, -0.1149571016, -0.0221361624,  0.4490873449, -0.0091853194,
#   0.1740480289, -0.0243189323,  0.3200094578,  0.3203401844,  1.2012931418,
#   0.4480687036,  0.925466504 ,  1.0343191075]
#
# ====================================================================================================
# BEST RUN ACCORDING TO HIGH-SHOT EVALUATED MEAN
# ====================================================================================================
# Run             : 21
# Optimized Value : 0.65830000
# Evaluated Mean  : 0.64613800
# Evaluated Std   : 0.00170316
# Evaluated SEM   : 0.00038084
# Evaluated Min   : 0.64163000
# Evaluated Max   : 0.64882000
#
# Evaluated Values:
# [0.64602, 0.64805, 0.64614, 0.6464 , 0.64485, 0.64163, 0.64487, 0.64882,
#  0.64882, 0.64697, 0.64771, 0.6461 , 0.64593, 0.64629, 0.64445, 0.64592,
#  0.64456, 0.64687, 0.64429, 0.64807]
#
# Initial Parameters:
# [0.7874185021, 0.9584562682, 0.8591507262, 0.9645583872, 0.1861908476,
#  0.9733637291, 0.0280706788, 0.0552851721, 0.6590788677, 0.6741578349,
#  0.8616838769, 0.8939815973, 0.0797041007, 0.3456415486, 0.4524772268,
#  0.042159618 , 0.4282577349, 0.1251842981]
#
# Optimal Parameters:
# [ 0.2852483257,  1.5669427833,  1.5563958663,  1.5369548683,  1.4877356314,
#   1.4503721165,  0.9057217019,  1.6146804247,  1.7499334449,  1.6112073805,
#   0.6854128522,  1.6195585799,  0.0350254858,  0.3089816257,  0.0500279604,
#  -0.0234792144,  1.5988576221,  0.3294466487]
# ====================================================================================================
#
# Report saved to:
# /Users/sungwonyun/Documents/Qiskit/Minimum Error Discrimination/Simulator Seed 150/Sym_QNN_CB_report.txt
