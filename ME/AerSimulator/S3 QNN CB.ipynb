# %%
# 0,1: 00 for psi_1, 01 for psi_2 ...
# 2,3,4: For states
# 5,6: Ancillary qubits

# %%
from qiskit import QuantumCircuit
from numpy import sqrt, array


def circuit_init():
    qc = QuantumCircuit(7)
    return qc
    
def PREP(qc):

    desired_vector = [
        1 / sqrt(3), 0, 0, 0, 0, 0, 0, 0,
        -1 / (8 * sqrt(3)), -1 / 8, -1 / 8, -sqrt(3) / 8,
        -1 / 8, -sqrt(3) / 8, -sqrt(3) / 8, -3 / 8,
        -1 / (8 * sqrt(3)), 1 / 8, 1 / 8, -sqrt(3) / 8,
        1 / 8, -sqrt(3) / 8, -sqrt(3) / 8, 3 / 8,
        0, 0, 0, 0, 0, 0, 0, 0
    ]
    
    qc.initialize(desired_vector, [4, 3, 2, 1, 0])
    return qc

# %%
def Ansatz(qc, wires, num_layers, params):

    for i in range(num_layers):
        qc.barrier()

        offset = 10 * i
        qc.rx(params[offset + 0], wires[0])
        qc.rz(params[offset + 1], wires[0])

        qc.rx(params[offset + 2], wires[1])
        qc.rz(params[offset + 3], wires[1])

        qc.rx(params[offset + 4], wires[2])
        qc.rz(params[offset + 5], wires[2])

        qc.rx(params[offset + 6], wires[3])
        qc.rz(params[offset + 7], wires[3])

        qc.rx(params[offset + 8], wires[4])
        qc.rz(params[offset + 9], wires[4])

        qc.cx(wires[0], wires[1])
        qc.cx(wires[1], wires[2])
        qc.cx(wires[2], wires[3])
        qc.cx(wires[3], wires[4])
        qc.cx(wires[4], wires[0])
    qc.measure_all()
    return qc

# %%
from numpy.random import rand
num_layers=3
num_params= 10*num_layers
params = list(range(num_params))
num_shots=10000

qc = circuit_init()
qc = PREP(qc)
Ansatz(qc, [2,3,4,5,6] , num_layers, params)

qc.draw(output='mpl', style = 'clifford') 
#qc_reversed=qc.reverse_bits()
#qc_reversed.draw(output='mpl',style = 'clifford')

# %%
# q_00: priori probability of psi_00
# p_00: Tr[M_00 psi_00]
# p_suc = q_00 p_00 + q_01 p_01 + q_10 p_10 = sum_i (tot_i/num_shots)(tar_i/tot_i) = 1/num_shots sum_i tar_i

# %%
from qiskit_aer import AerSimulator
from qiskit import transpile
from scipy.optimize import minimize

import numpy as np
import os
import time


# ============================================================
# Simulator
# ============================================================

aersim = AerSimulator()


# ============================================================
# Settings
# ============================================================

num_times = 30
num_shots = 10000

optimizer_name = "COBYLA"
tol_value = 1e-8
maxiter = 2000

BASE_SEED = 150
num_layers = 3

report_filename = (
    "TT_QNN_CB_report.txt"
)


# ============================================================
# High-Shot Evaluation Settings
# ============================================================

evaluation_num_times = 20
evaluation_num_shots = 100000

EVALUATION_BASE_SEED = 10000

evaluation_seeds = np.array(
    [
        EVALUATION_BASE_SEED + i
        for i in range(evaluation_num_times)
    ],
    dtype=int
)


# ============================================================
# Storage
# ============================================================

final_optimized_values = []

initial_params_all_runs = []
optimal_params_all_runs = []

optimization_success_all_runs = []
optimization_status_all_runs = []
optimization_message_all_runs = []
optimization_nfev_all_runs = []
reached_maxiter_all_runs = []

# ------------------------------------------------------------
# Runtime Storage
# ------------------------------------------------------------

optimization_wall_times = []


# ------------------------------------------------------------
# High-Shot Evaluation Storage
# ------------------------------------------------------------

evaluation_values_all_runs = []

evaluation_mean_all_runs = []
evaluation_std_all_runs = []
evaluation_min_all_runs = []
evaluation_max_all_runs = []


# ============================================================
# Objective Function
# ============================================================

def objective_function(
    params,
    run_seed,
    shots=None,
    print_result=True
):

    if shots is None:
        shots = num_shots


    # --------------------------------------------------------
    # Construct circuit
    # --------------------------------------------------------

    qc = circuit_init()

    PREP(qc)

    Ansatz(
        qc,
        [2, 3, 4, 5, 6],
        num_layers,
        params
    )


    qc_reverse = qc.reverse_bits()


    # --------------------------------------------------------
    # Transpile
    # --------------------------------------------------------

    t_qc = transpile(
        qc_reverse,
        aersim,
        seed_transpiler=run_seed
    )


    # --------------------------------------------------------
    # Run simulation
    # --------------------------------------------------------

    job = aersim.run(
        t_qc,
        shots=shots,
        seed_simulator=run_seed
    )


    result = job.result()

    counts = result.get_counts()


    # --------------------------------------------------------
    # Target counts
    # --------------------------------------------------------

    tar_00 = 0
    tar_01 = 0
    tar_10 = 0


    for outcome, count in counts.items():

        if outcome[0:2] == "00":

            if outcome[5:7] == "00":

                tar_00 += count


        if outcome[0:2] == "01":

            if outcome[5:7] == "01":

                tar_01 += count


        if outcome[0:2] == "10":

            if outcome[5:7] == "10":

                tar_10 += count


    # --------------------------------------------------------
    # Success probability
    # --------------------------------------------------------

    p_suc = (
        tar_00
        + tar_01
        + tar_10
    ) / shots


    if print_result:

        print(
            f"success_probability = "
            f"{p_suc:.8f}"
        )


    # --------------------------------------------------------
    # Avoid division by zero
    # --------------------------------------------------------

    if p_suc == 0:

        return 1e10


    # --------------------------------------------------------
    # COBYLA minimizes.
    #
    # Minimizing 1 / p_suc maximizes p_suc.
    # --------------------------------------------------------

    return 1.0 / p_suc


# ============================================================
# Run Optimization
# ============================================================

# Measures the complete workflow:
# optimization + final evaluations + high-shot evaluations + overhead.
total_wall_start = time.perf_counter()

for run in range(num_times):


    # ========================================================
    # Optimization Seed
    # ========================================================

    run_seed = (
        BASE_SEED + run
    )


    rng = np.random.default_rng(
        run_seed
    )


    print(
        "\n"
        + "=" * 80
    )


    print(
        f"Optimization Run "
        f"{run + 1}/{num_times}"
    )


    print(
        f"Optimization Seed : "
        f"{run_seed}"
    )


    print(
        "=" * 80
    )


    # ========================================================
    # Generate Random Initial Parameters
    # ========================================================

    initial_params = rng.random(
        num_params
    )


    initial_params_all_runs.append(
        initial_params.copy()
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    # ========================================================
    # Run COBYLA Optimization
    # ========================================================

    print(
        "\nStarting COBYLA optimization..."
    )


    optimization_start = time.perf_counter()

    result = minimize(

        fun=lambda params: objective_function(
            params,
            run_seed,
            shots=num_shots,
            print_result=True
        ),

        x0=initial_params,

        method=optimizer_name,

        options={
            "maxiter": maxiter,
            "disp": True,
            "tol": tol_value
        }
    )

    optimization_end = time.perf_counter()

    run_optimization_wall_time = (
        optimization_end
        - optimization_start
    )

    optimization_wall_times.append(
        run_optimization_wall_time
    )

    print(
        f"Optimization Wall-Clock Time : "
        f"{run_optimization_wall_time:.6f} s"
    )


    # ========================================================
    # Optimization Status
    # ========================================================

    optimization_success = bool(
        result.success
    )


    optimization_status = getattr(
        result,
        "status",
        None
    )


    optimization_message = str(
        getattr(
            result,
            "message",
            "No message returned"
        )
    )


    optimization_nfev = getattr(
        result,
        "nfev",
        None
    )


    # ========================================================
    # Detect Maximum Function Evaluations
    # ========================================================

    message_lower = (
        optimization_message.lower()
    )


    reached_maxiter = (

        "maximum number"
        in message_lower

        or "maximum function"
        in message_lower

        or "maxiter"
        in message_lower

        or "maxfun"
        in message_lower

        or "maximum iterations"
        in message_lower

        or "maximum evaluations"
        in message_lower
    )


    if optimization_nfev is not None:

        if optimization_nfev >= maxiter:

            reached_maxiter = True


    # ========================================================
    # Store Optimization Status
    # ========================================================

    optimization_success_all_runs.append(
        optimization_success
    )


    optimization_status_all_runs.append(
        optimization_status
    )


    optimization_message_all_runs.append(
        optimization_message
    )


    optimization_nfev_all_runs.append(
        optimization_nfev
    )


    reached_maxiter_all_runs.append(
        reached_maxiter
    )


    # ========================================================
    # Optimal Parameters
    # ========================================================

    optimal_params = (
        result.x.copy()
    )


    optimal_params_all_runs.append(
        optimal_params.copy()
    )


    # ========================================================
    # Final Optimization-Shot Evaluation
    # ========================================================

    final_objective = objective_function(
        optimal_params,
        run_seed,
        shots=num_shots,
        print_result=False
    )


    if final_objective >= 1e10:

        final_value = 0.0

    else:

        final_value = (
            1.0 / final_objective
        )


    final_optimized_values.append(
        final_value
    )


    # ========================================================
    # High-Shot Evaluation
    # ========================================================

    print(
        "\n"
        + "-" * 80
    )


    print(
        "HIGH-SHOT EVALUATION OF "
        "OPTIMIZED PARAMETERS"
    )


    print(
        "-" * 80
    )


    print(
        f"Optimization Shots     : "
        f"{num_shots}"
    )


    print(
        f"Evaluation Shots       : "
        f"{evaluation_num_shots}"
    )


    print(
        f"Number of Evaluations : "
        f"{evaluation_num_times}"
    )


    print(
        "\nEvaluation Results:"
    )


    evaluation_values = []


    for eval_index, eval_seed in enumerate(
        evaluation_seeds
    ):


        eval_objective = objective_function(
            optimal_params,
            int(eval_seed),
            shots=evaluation_num_shots,
            print_result=False
        )


        if eval_objective >= 1e10:

            eval_value = 0.0

        else:

            eval_value = (
                1.0 / eval_objective
            )


        evaluation_values.append(
            eval_value
        )


        print(
            f"Evaluation "
            f"{eval_index + 1:2d}/"
            f"{evaluation_num_times:2d}"
            f" | Value = "
            f"{eval_value:.8f}"
        )


    # ========================================================
    # Evaluation Statistics
    # ========================================================

    evaluation_values = np.array(
        evaluation_values,
        dtype=float
    )


    evaluation_mean = np.mean(
        evaluation_values
    )


    evaluation_std = np.std(
        evaluation_values
    )


    evaluation_min = np.min(
        evaluation_values
    )


    evaluation_max = np.max(
        evaluation_values
    )


    # ========================================================
    # Store Evaluation Results
    # ========================================================

    evaluation_values_all_runs.append(
        evaluation_values.copy()
    )


    evaluation_mean_all_runs.append(
        evaluation_mean
    )


    evaluation_std_all_runs.append(
        evaluation_std
    )


    evaluation_min_all_runs.append(
        evaluation_min
    )


    evaluation_max_all_runs.append(
        evaluation_max
    )


    # ========================================================
    # Individual Run Report
    # ========================================================

    print(
        "\n"
        + "=" * 80
    )


    print(
        f"RUN {run + 1} RESULT"
    )


    print(
        "=" * 80
    )


    print(
        f"Optimization Success : "
        f"{optimization_success}"
    )


    print(
        f"Reached MaxIter      : "
        f"{reached_maxiter}"
    )


    print(
        f"Status               : "
        f"{optimization_status}"
    )


    print(
        f"Message              : "
        f"{optimization_message}"
    )


    print(
        f"Function Evaluations : "
        f"{optimization_nfev}"
    )


    print(
        f"Optimization Time    : "
        f"{run_optimization_wall_time:.6f} s"
    )


    print(
        f"Final Objective Value: "
        f"{result.fun}"
    )


    print(
        "\n"
        + "-" * 80
    )


    print(
        "OPTIMIZED AND HIGH-SHOT "
        "EVALUATED VALUES"
    )


    print(
        "-" * 80
    )


    print(
        f"Final Optimized Value : "
        f"{final_value:.8f}"
    )


    print(
        f"Evaluated Mean        : "
        f"{evaluation_mean:.8f}"
    )


    print(
        f"Evaluated Std         : "
        f"{evaluation_std:.8f}"
    )


    print(
        f"Evaluated Min         : "
        f"{evaluation_min:.8f}"
    )


    print(
        f"Evaluated Max         : "
        f"{evaluation_max:.8f}"
    )


    print(
        "\nAll Evaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values,
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "=" * 80
    )


# ============================================================
# Runtime Statistics
# ============================================================

total_wall_end = time.perf_counter()

total_wall_time = (
    total_wall_end
    - total_wall_start
)

optimization_wall_times = np.array(
    optimization_wall_times,
    dtype=float
)

total_optimization_wall_time = np.sum(
    optimization_wall_times
)

mean_optimization_wall_time = np.mean(
    optimization_wall_times
)

std_optimization_wall_time = np.std(
    optimization_wall_times
)


# ============================================================
# Convert Results to NumPy Arrays
# ============================================================

final_optimized_values = np.array(
    final_optimized_values,
    dtype=float
)


initial_params_all_runs = np.array(
    initial_params_all_runs
)


optimal_params_all_runs = np.array(
    optimal_params_all_runs
)


evaluation_values_all_runs = np.array(
    evaluation_values_all_runs,
    dtype=float
)


evaluation_mean_all_runs = np.array(
    evaluation_mean_all_runs,
    dtype=float
)


evaluation_std_all_runs = np.array(
    evaluation_std_all_runs,
    dtype=float
)


evaluation_min_all_runs = np.array(
    evaluation_min_all_runs,
    dtype=float
)


evaluation_max_all_runs = np.array(
    evaluation_max_all_runs,
    dtype=float
)


# ============================================================
# Original Optimization Statistics
# ============================================================

maximum_value = np.max(
    final_optimized_values
)


mean_value = np.mean(
    final_optimized_values
)


std_value = np.std(
    final_optimized_values
)


maximum_run_index = np.argmax(
    final_optimized_values
)


maximum_run = (
    maximum_run_index + 1
)


# ============================================================
# High-Shot Evaluation Statistics
# ============================================================

maximum_evaluated_mean = np.max(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run_index = np.argmax(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run = (
    maximum_evaluated_mean_run_index
    + 1
)


mean_of_evaluated_means = np.mean(
    evaluation_mean_all_runs
)


std_of_evaluated_means = np.std(
    evaluation_mean_all_runs
)


# ============================================================
# Function Evaluation Statistics
# ============================================================

nfev_values = np.array(
    [
        nfev
        for nfev
        in optimization_nfev_all_runs
        if nfev is not None
    ],
    dtype=float
)


if len(nfev_values) > 0:

    mean_nfev = np.mean(
        nfev_values
    )


    std_nfev = np.std(
        nfev_values
    )

else:

    mean_nfev = np.nan
    std_nfev = np.nan


# ============================================================
# Optimization Success Statistics
# ============================================================

num_successful_runs = sum(
    optimization_success_all_runs
)


num_failed_runs = (
    num_times
    - num_successful_runs
)


num_reached_maxiter = sum(
    reached_maxiter_all_runs
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

best_initial_params = (
    initial_params_all_runs[
        maximum_run_index
    ]
)


best_optimal_params = (
    optimal_params_all_runs[
        maximum_run_index
    ]
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

best_evaluated_initial_params = (
    initial_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_optimal_params = (
    optimal_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_values = (
    evaluation_values_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


# ============================================================
# Print Final Report
# ============================================================

print("\n")


print(
    "=" * 100
)


print(
    "FINAL OPTIMIZATION AND "
    "HIGH-SHOT EVALUATION REPORT"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Settings
# ------------------------------------------------------------

print(
    f"Optimizer               : "
    f"{optimizer_name}"
)


print(
    f"Tolerance               : "
    f"{tol_value}"
)


print(
    f"Max Iteration           : "
    f"{maxiter}"
)


print(
    f"Number of Runs          : "
    f"{num_times}"
)


print(
    f"Optimization Shots      : "
    f"{num_shots}"
)


print(
    f"Optimization Base Seed  : "
    f"{BASE_SEED}"
)


print(
    f"Evaluation Shots        : "
    f"{evaluation_num_shots}"
)


print(
    f"Evaluations Per Run     : "
    f"{evaluation_num_times}"
)


print(
    f"Evaluation Base Seed    : "
    f"{EVALUATION_BASE_SEED}"
)


# Evaluation seeds are printed only once.
print(
    "Evaluation Seeds        : "
    + np.array2string(
        evaluation_seeds,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Results for Every Run
# ============================================================

for i in range(num_times):


    print(
        f"\nRun {i + 1:2d}"
    )


    print(
        "-" * 100
    )


    print(
        f"Optimization Seed : "
        f"{BASE_SEED + i}"
    )


    print(
        f"Optimized Value   : "
        f"{final_optimized_values[i]:.8f}"
    )


    print(
        f"Evaluated Mean    : "
        f"{evaluation_mean_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Std     : "
        f"{evaluation_std_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Min     : "
        f"{evaluation_min_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Max     : "
        f"{evaluation_max_all_runs[i]:.8f}"
    )


    print(
        f"Success           : "
        f"{optimization_success_all_runs[i]}"
    )


    print(
        f"Reached MaxIter   : "
        f"{reached_maxiter_all_runs[i]}"
    )


    print(
        f"Status            : "
        f"{optimization_status_all_runs[i]}"
    )


    print(
        f"Message           : "
        f"{optimization_message_all_runs[i]}"
    )


    print(
        f"Function Evals    : "
        f"{optimization_nfev_all_runs[i]}"
    )


    print(
        f"Optimization Time : "
        f"{optimization_wall_times[i]:.6f} s"
    )


    print(
        "\nEvaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values_all_runs[i],
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "-" * 100
    )


# ============================================================
# Summary
# ============================================================

print(
    "\nSUMMARY"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Original Optimization Results
# ------------------------------------------------------------

print(
    "\nOriginal Optimization-Shot Results:"
)


print(
    f"Maximum Optimized Value : "
    f"{maximum_value:.8f}"
)


print(
    f"Maximum Run             : "
    f"{maximum_run}"
)


print(
    f"Mean Optimized Value    : "
    f"{mean_value:.8f}"
)


print(
    f"Std Optimized Value     : "
    f"{std_value:.8f}"
)


# ------------------------------------------------------------
# High-Shot Evaluation Results
# ------------------------------------------------------------

print(
    "\nHigh-Shot Evaluation Results:"
)


print(
    f"Best Evaluated Mean     : "
    f"{maximum_evaluated_mean:.8f}"
)


print(
    f"Best Evaluated Mean Run : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Mean of Evaluated Means : "
    f"{mean_of_evaluated_means:.8f}"
)


print(
    f"Std of Evaluated Means  : "
    f"{std_of_evaluated_means:.8f}"
)


# ------------------------------------------------------------
# Optimizer Statistics
# ------------------------------------------------------------

print(
    "\nOptimizer Statistics:"
)


print(
    f"Mean Function Evals     : "
    f"{mean_nfev:.2f}"
)


print(
    f"Std Function Evals      : "
    f"{std_nfev:.2f}"
)


print(
    f"Successful Runs         : "
    f"{num_successful_runs}/"
    f"{num_times}"
)


print(
    f"Failed Runs             : "
    f"{num_failed_runs}/"
    f"{num_times}"
)


print(
    f"Reached MaxIter         : "
    f"{num_reached_maxiter}/"
    f"{num_times}"
)


# ------------------------------------------------------------
# Computational Runtime Statistics
# ------------------------------------------------------------

print(
    "\nComputational Runtime Statistics:"
)

print(
    f"Total Wall-Clock Time          : "
    f"{total_wall_time:.6f} s"
)

print(
    f"Total Optimization Time        : "
    f"{total_optimization_wall_time:.6f} s"
)

print(
    f"Time per Complete Opt. Run     : "
    f"{mean_optimization_wall_time:.6f} s"
)

print(
    f"Std Optimization Time per Run  : "
    f"{std_optimization_wall_time:.6f} s"
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "ORIGINAL OPTIMIZED VALUE"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        evaluation_values_all_runs[
            maximum_run_index
        ],
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_optimal_params,
        precision=10,
        separator=", "
    )
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "HIGH-SHOT EVALUATED MEAN"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        best_evaluated_values,
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_evaluated_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_evaluated_optimal_params,
        precision=10,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Save Report to TXT
# ============================================================

with open(
    report_filename,
    "w"
) as f:


    # ========================================================
    # Header
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "FINAL OPTIMIZATION AND "
        "HIGH-SHOT EVALUATION REPORT\n"
    )


    f.write(
        "=" * 100
        + "\n\n"
    )


    # ========================================================
    # Settings
    # ========================================================

    f.write(
        f"Optimizer               : "
        f"{optimizer_name}\n"
    )


    f.write(
        f"Tolerance               : "
        f"{tol_value}\n"
    )


    f.write(
        f"Max Iteration           : "
        f"{maxiter}\n"
    )


    f.write(
        f"Number of Runs          : "
        f"{num_times}\n"
    )


    f.write(
        f"Optimization Shots      : "
        f"{num_shots}\n"
    )


    f.write(
        f"Optimization Base Seed  : "
        f"{BASE_SEED}\n"
    )


    f.write(
        f"Evaluation Shots        : "
        f"{evaluation_num_shots}\n"
    )


    f.write(
        f"Evaluations Per Run     : "
        f"{evaluation_num_times}\n"
    )


    f.write(
        f"Evaluation Base Seed    : "
        f"{EVALUATION_BASE_SEED}\n"
    )


    # Evaluation seeds are saved only once.
    f.write(
        "Evaluation Seeds        : "
    )


    f.write(
        np.array2string(
            evaluation_seeds,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    # ========================================================
    # Results for Every Run
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "RESULTS FOR EACH RUN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    for i in range(num_times):


        f.write(
            f"\nRun {i + 1:2d}\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


        f.write(
            f"Optimization Seed : "
            f"{BASE_SEED + i}\n"
        )


        f.write(
            f"Optimized Value   : "
            f"{final_optimized_values[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Mean    : "
            f"{evaluation_mean_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Std     : "
            f"{evaluation_std_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Min     : "
            f"{evaluation_min_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Max     : "
            f"{evaluation_max_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Success           : "
            f"{optimization_success_all_runs[i]}\n"
        )


        f.write(
            f"Reached MaxIter   : "
            f"{reached_maxiter_all_runs[i]}\n"
        )


        f.write(
            f"Status            : "
            f"{optimization_status_all_runs[i]}\n"
        )


        f.write(
            f"Message           : "
            f"{optimization_message_all_runs[i]}\n"
        )


        f.write(
            f"Function Evals    : "
            f"{optimization_nfev_all_runs[i]}\n"
        )


        f.write(
            f"Optimization Time : "
            f"{optimization_wall_times[i]:.6f} s\n"
        )


        f.write(
            "\nEvaluated Values:\n"
        )


        f.write(
            np.array2string(
                evaluation_values_all_runs[i],
                precision=8,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nInitial Parameters:\n"
        )


        f.write(
            np.array2string(
                initial_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nOptimal Parameters:\n"
        )


        f.write(
            np.array2string(
                optimal_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


    # ========================================================
    # Summary
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "SUMMARY\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    # --------------------------------------------------------
    # Original Optimization Results
    # --------------------------------------------------------

    f.write(
        "\nOriginal Optimization-Shot Results:\n"
    )


    f.write(
        f"Maximum Optimized Value : "
        f"{maximum_value:.8f}\n"
    )


    f.write(
        f"Maximum Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Mean Optimized Value    : "
        f"{mean_value:.8f}\n"
    )


    f.write(
        f"Std Optimized Value     : "
        f"{std_value:.8f}\n"
    )


    # --------------------------------------------------------
    # High-Shot Evaluation Results
    # --------------------------------------------------------

    f.write(
        "\nHigh-Shot Evaluation Results:\n"
    )


    f.write(
        f"Best Evaluated Mean     : "
        f"{maximum_evaluated_mean:.8f}\n"
    )


    f.write(
        f"Best Evaluated Mean Run : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Mean of Evaluated Means : "
        f"{mean_of_evaluated_means:.8f}\n"
    )


    f.write(
        f"Std of Evaluated Means  : "
        f"{std_of_evaluated_means:.8f}\n"
    )


    # --------------------------------------------------------
    # Optimizer Statistics
    # --------------------------------------------------------

    f.write(
        "\nOptimizer Statistics:\n"
    )


    f.write(
        f"Mean Function Evals     : "
        f"{mean_nfev:.2f}\n"
    )


    f.write(
        f"Std Function Evals      : "
        f"{std_nfev:.2f}\n"
    )


    f.write(
        f"Successful Runs         : "
        f"{num_successful_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Failed Runs             : "
        f"{num_failed_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Reached MaxIter         : "
        f"{num_reached_maxiter}/"
        f"{num_times}\n"
    )


    # --------------------------------------------------------
    # Computational Runtime Statistics
    # --------------------------------------------------------

    f.write(
        "\nComputational Runtime Statistics:\n"
    )

    f.write(
        f"Total Wall-Clock Time          : "
        f"{total_wall_time:.6f} s\n"
    )

    f.write(
        f"Total Optimization Time        : "
        f"{total_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Time per Complete Opt. Run     : "
        f"{mean_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Std Optimization Time per Run  : "
        f"{std_optimization_wall_time:.6f} s\n"
    )


    # ========================================================
    # Best Run According to Original Optimized Value
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "ORIGINAL OPTIMIZED VALUE\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            evaluation_values_all_runs[
                maximum_run_index
            ],
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    # ========================================================
    # Best Run According to High-Shot Evaluated Mean
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "HIGH-SHOT EVALUATED MEAN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_values,
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


# ============================================================
# Report Location
# ============================================================

print(
    "\nReport saved to:"
)


print(
    os.path.abspath(
        report_filename
    )
)
# Out:
# ================================================================================
# Optimization Run 1/30
# Optimization Seed : 150
# ================================================================================
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566, 0.6883896757,
#  0.5848087428, 0.2739643248, 0.8377858251, 0.3022293541, 0.1728462164,
#  0.8017433668, 0.3441099205, 0.4375847094, 0.152681156 , 0.2761357842]
#
# Starting COBYLA optimization...
# success_probability = 0.25760000
# success_probability = 0.28570000
# success_probability = 0.29130000
# success_probability = 0.25940000
# success_probability = 0.30300000
# success_probability = 0.30020000
# success_probability = 0.35370000
# success_probability = 0.27920000
# success_probability = 0.33730000
# success_probability = 0.35030000
# success_probability = 0.34030000
# success_probability = 0.30710000
# success_probability = 0.35970000
# success_probability = 0.29000000
# success_probability = 0.31670000
# success_probability = 0.33010000
# success_probability = 0.31680000
# success_probability = 0.31080000
# success_probability = 0.33210000
# success_probability = 0.31360000
# success_probability = 0.33530000
# success_probability = 0.29240000
# success_probability = 0.35970000
# success_probability = 0.32210000
# success_probability = 0.35970000
# success_probability = 0.37380000
# success_probability = 0.37380000
# success_probability = 0.35080000
# success_probability = 0.37380000
# success_probability = 0.29980000
# success_probability = 0.37380000
# success_probability = 0.39540000
# success_probability = 0.39300000
# success_probability = 0.33930000
# success_probability = 0.38070000
# success_probability = 0.31440000
# success_probability = 0.39520000
# success_probability = 0.34030000
# success_probability = 0.38370000
# success_probability = 0.34960000
# success_probability = 0.38880000
# success_probability = 0.33800000
# success_probability = 0.42200000
# success_probability = 0.42570000
# success_probability = 0.41610000
# success_probability = 0.41080000
# success_probability = 0.41910000
# success_probability = 0.40450000
# success_probability = 0.40140000
# success_probability = 0.42530000
# success_probability = 0.44330000
# success_probability = 0.43470000
# success_probability = 0.45140000
# success_probability = 0.43840000
# success_probability = 0.45960000
# success_probability = 0.45290000
# success_probability = 0.50270000
# success_probability = 0.55990000
# success_probability = 0.55990000
# success_probability = 0.59120000
# success_probability = 0.59120000
# success_probability = 0.58410000
# success_probability = 0.59120000
# success_probability = 0.56560000
# success_probability = 0.58740000
# success_probability = 0.58430000
# success_probability = 0.60920000
# success_probability = 0.59630000
# success_probability = 0.60690000
# success_probability = 0.60890000
# success_probability = 0.62140000
# success_probability = 0.60930000
# success_probability = 0.61350000
# success_probability = 0.63190000
# success_probability = 0.63280000
# success_probability = 0.64030000
# success_probability = 0.61890000
# success_probability = 0.61400000
# success_probability = 0.64190000
# success_probability = 0.65590000
# success_probability = 0.67530000
# success_probability = 0.63090000
# success_probability = 0.65940000
# success_probability = 0.64150000
# success_probability = 0.67360000
# success_probability = 0.67680000
# success_probability = 0.66040000
# success_probability = 0.70260000
# success_probability = 0.70260000
# success_probability = 0.63560000
# success_probability = 0.68490000
# success_probability = 0.67840000
# success_probability = 0.69720000
# success_probability = 0.70640000
# success_probability = 0.70960000
# success_probability = 0.71030000
# success_probability = 0.71030000
# success_probability = 0.72380000
# success_probability = 0.68030000
# success_probability = 0.70870000
# success_probability = 0.69510000
# success_probability = 0.73240000
# success_probability = 0.73530000
# success_probability = 0.73770000
# success_probability = 0.70000000
# success_probability = 0.71950000
# success_probability = 0.73360000
# success_probability = 0.75900000
# success_probability = 0.73300000
# success_probability = 0.79790000
# success_probability = 0.79850000
# success_probability = 0.76550000
# success_probability = 0.78970000
# success_probability = 0.72920000
# success_probability = 0.78430000
# success_probability = 0.77580000
# success_probability = 0.80070000
# success_probability = 0.79740000
# success_probability = 0.79210000
# success_probability = 0.78900000
# success_probability = 0.80060000
# success_probability = 0.79430000
# success_probability = 0.78010000
# success_probability = 0.77550000
# success_probability = 0.80070000
# success_probability = 0.76440000
# success_probability = 0.77570000
# success_probability = 0.74910000
# success_probability = 0.79110000
# success_probability = 0.79480000
# success_probability = 0.76230000
# success_probability = 0.78440000
# success_probability = 0.80070000
# success_probability = 0.75750000
# success_probability = 0.79250000
# success_probability = 0.79320000
# success_probability = 0.80280000
# success_probability = 0.81620000
# success_probability = 0.81510000
# success_probability = 0.78020000
# success_probability = 0.81310000
# success_probability = 0.79260000
# success_probability = 0.80980000
# success_probability = 0.80820000
# success_probability = 0.82340000
# success_probability = 0.82550000
# success_probability = 0.82300000
# success_probability = 0.82710000
# success_probability = 0.81600000
# success_probability = 0.81930000
# success_probability = 0.82720000
# success_probability = 0.81980000
# success_probability = 0.82200000
# success_probability = 0.81930000
# success_probability = 0.82370000
# success_probability = 0.81790000
# success_probability = 0.79300000
# success_probability = 0.82900000
# success_probability = 0.82670000
# success_probability = 0.82770000
# success_probability = 0.82490000
# success_probability = 0.82910000
# success_probability = 0.82610000
# success_probability = 0.82610000
# success_probability = 0.82630000
# success_probability = 0.82630000
# success_probability = 0.82640000
# success_probability = 0.82640000
# success_probability = 0.83440000
# success_probability = 0.83270000
# success_probability = 0.84210000
# success_probability = 0.83560000
# success_probability = 0.84580000
# success_probability = 0.84710000
# success_probability = 0.84590000
# success_probability = 0.84660000
# success_probability = 0.83450000
# success_probability = 0.84650000
# success_probability = 0.83010000
# success_probability = 0.84790000
# success_probability = 0.84760000
# success_probability = 0.84050000
# success_probability = 0.85150000
# success_probability = 0.84430000
# success_probability = 0.85160000
# success_probability = 0.84310000
# success_probability = 0.84660000
# success_probability = 0.84580000
# success_probability = 0.84860000
# success_probability = 0.84600000
# success_probability = 0.85280000
# success_probability = 0.84900000
# success_probability = 0.84470000
# success_probability = 0.84890000
# success_probability = 0.84570000
# success_probability = 0.85030000
# success_probability = 0.84280000
# success_probability = 0.84950000
# success_probability = 0.84630000
# success_probability = 0.85580000
# success_probability = 0.84700000
# success_probability = 0.85060000
# success_probability = 0.84720000
# success_probability = 0.85380000
# success_probability = 0.84720000
# success_probability = 0.85550000
# success_probability = 0.85330000
# success_probability = 0.85270000
# success_probability = 0.85320000
# success_probability = 0.84860000
# success_probability = 0.84660000
# success_probability = 0.84950000
# success_probability = 0.84230000
# success_probability = 0.85340000
# success_probability = 0.85270000
# success_probability = 0.85870000
# success_probability = 0.86050000
# success_probability = 0.85880000
# success_probability = 0.86010000
# success_probability = 0.85570000
# success_probability = 0.86100000
# success_probability = 0.85410000
# success_probability = 0.86140000
# success_probability = 0.85920000
# success_probability = 0.86080000
# success_probability = 0.86170000
# success_probability = 0.86170000
# success_probability = 0.86050000
# success_probability = 0.86160000
# success_probability = 0.86260000
# success_probability = 0.86150000
# success_probability = 0.86790000
# success_probability = 0.87070000
# success_probability = 0.87520000
# success_probability = 0.87220000
# success_probability = 0.87620000
# success_probability = 0.87360000
# success_probability = 0.87670000
# success_probability = 0.86970000
# success_probability = 0.87300000
# success_probability = 0.87320000
# success_probability = 0.87560000
# success_probability = 0.87250000
# success_probability = 0.87550000
# success_probability = 0.87240000
# success_probability = 0.87140000
# success_probability = 0.87740000
# success_probability = 0.87580000
# success_probability = 0.87430000
# success_probability = 0.87780000
# success_probability = 0.87210000
# success_probability = 0.87640000
# success_probability = 0.87240000
# success_probability = 0.87480000
# success_probability = 0.87360000
# success_probability = 0.87290000
# success_probability = 0.86900000
# success_probability = 0.87630000
# success_probability = 0.87490000
# success_probability = 0.87590000
# success_probability = 0.86950000
# success_probability = 0.87700000
# success_probability = 0.87270000
# success_probability = 0.87620000
# success_probability = 0.87680000
# success_probability = 0.87800000
# success_probability = 0.87790000
# success_probability = 0.87630000
# success_probability = 0.87620000
# success_probability = 0.87610000
# success_probability = 0.87660000
# success_probability = 0.87490000
# success_probability = 0.87840000
# success_probability = 0.87550000
# success_probability = 0.87630000
# success_probability = 0.87700000
# success_probability = 0.87750000
# success_probability = 0.87740000
# success_probability = 0.87830000
# success_probability = 0.87560000
# success_probability = 0.87660000
# success_probability = 0.87430000
# success_probability = 0.87690000
# success_probability = 0.87690000
# success_probability = 0.87810000
# success_probability = 0.87760000
# success_probability = 0.87800000
# success_probability = 0.87830000
# success_probability = 0.87730000
# success_probability = 0.87600000
# success_probability = 0.87630000
# success_probability = 0.87900000
# success_probability = 0.87810000
# success_probability = 0.87820000
# success_probability = 0.87790000
# success_probability = 0.87890000
# success_probability = 0.87730000
# success_probability = 0.87850000
# success_probability = 0.87780000
# success_probability = 0.87780000
# success_probability = 0.87770000
# success_probability = 0.87820000
# success_probability = 0.87650000
# success_probability = 0.87870000
# success_probability = 0.87830000
# success_probability = 0.87660000
# success_probability = 0.87880000
# success_probability = 0.87740000
# success_probability = 0.87890000
# success_probability = 0.87790000
# success_probability = 0.87830000
# success_probability = 0.87630000
# success_probability = 0.87870000
# success_probability = 0.87710000
# success_probability = 0.87840000
# success_probability = 0.87750000
# success_probability = 0.87840000
# success_probability = 0.87760000
# success_probability = 0.87850000
# success_probability = 0.87740000
# success_probability = 0.87860000
# success_probability = 0.87840000
# success_probability = 0.87870000
# success_probability = 0.87610000
# success_probability = 0.87900000
# success_probability = 0.87890000
# success_probability = 0.87850000
# success_probability = 0.87830000
# success_probability = 0.87840000
# success_probability = 0.87840000
# success_probability = 0.87850000
# success_probability = 0.87810000
# success_probability = 0.87860000
# success_probability = 0.87900000
# success_probability = 0.87820000
# success_probability = 0.87900000
# success_probability = 0.87880000
# success_probability = 0.87850000
# success_probability = 0.87900000
# success_probability = 0.87890000
# success_probability = 0.87870000
# success_probability = 0.87920000
# success_probability = 0.87900000
# success_probability = 0.87890000
# success_probability = 0.87880000
# success_probability = 0.87900000
# success_probability = 0.87850000
# success_probability = 0.87890000
# success_probability = 0.87880000
# success_probability = 0.87860000
# success_probability = 0.87890000
# success_probability = 0.87870000
# success_probability = 0.87880000
# success_probability = 0.87860000
# success_probability = 0.87900000
# success_probability = 0.87870000
# success_probability = 0.87910000
# success_probability = 0.87840000
# success_probability = 0.87880000
# success_probability = 0.87890000
# success_probability = 0.87910000
# success_probability = 0.87880000
# success_probability = 0.87900000
# success_probability = 0.87890000
# success_probability = 0.87890000
# success_probability = 0.87870000
# success_probability = 0.87920000
# success_probability = 0.87880000
# success_probability = 0.87880000
# success_probability = 0.87890000
# success_probability = 0.87900000
# success_probability = 0.87910000
# success_probability = 0.87870000
# success_probability = 0.87920000
# success_probability = 0.87870000
# success_probability = 0.87900000
# success_probability = 0.87890000
# success_probability = 0.87880000
# success_probability = 0.87900000
# success_probability = 0.87880000
# success_probability = 0.87910000
# success_probability = 0.87910000
# success_probability = 0.87900000
# success_probability = 0.87910000
# success_probability = 0.87920000
# success_probability = 0.87890000
# success_probability = 0.87910000
# success_probability = 0.87900000
# success_probability = 0.87900000
# success_probability = 0.87900000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87900000
# success_probability = 0.87920000
# success_probability = 0.87900000
# success_probability = 0.87910000
# success_probability = 0.87900000
# success_probability = 0.87910000
# success_probability = 0.87900000
# success_probability = 0.87920000
# success_probability = 0.87890000
# success_probability = 0.87920000
# success_probability = 0.87910000
# success_probability = 0.87910000
# success_probability = 0.87920000
# success_probability = 0.87910000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87900000
# success_probability = 0.87920000
# success_probability = 0.87910000
# success_probability = 0.87910000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87900000
# success_probability = 0.87910000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87910000
# success_probability = 0.87920000
# success_probability = 0.87910000
# success_probability = 0.87920000
# success_probability = 0.87910000
# success_probability = 0.87910000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87910000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# success_probability = 0.87920000
# Optimization Wall-Clock Time : 37.581217 s
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  568   F = 1.137398E+00    MAXCV = 0.000000E+00
#    X = 1.332798E+00   2.536895E+00   5.994247E-03   1.607585E+00   4.366270E-01
#        2.486615E+00  -3.230632E-03   1.550007E-01  -3.811097E-02  -3.250056E-01
#        4.601032E-01   2.455687E+00   2.463160E-01   9.356166E-01  -8.363562E-03
#        5.322052E-01   5.303026E-02   6.360299E-01  -5.271388E-02   2.767746E-01
#        7.697988E-02  -1.198158E-01   1.572865E+00   4.597939E-01   1.018498E-02
#        7.409878E-01   1.560820E+00   5.903314E-01  -5.346383E-02  -1.694315E-01
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.87077000
# Evaluation  2/20 | Value = 0.86813000
# Evaluation  3/20 | Value = 0.86870000
# Evaluation  4/20 | Value = 0.86983000
# Evaluation  5/20 | Value = 0.86940000
# Evaluation  6/20 | Value = 0.87041000
# Evaluation  7/20 | Value = 0.87039000
# Evaluation  8/20 | Value = 0.86745000
# Evaluation  9/20 | Value = 0.86867000
# Evaluation 10/20 | Value = 0.86777000
# Evaluation 11/20 | Value = 0.86945000
# Evaluation 12/20 | Value = 0.86833000
# Evaluation 13/20 | Value = 0.86800000
# Evaluation 14/20 | Value = 0.86955000
# Evaluation 15/20 | Value = 0.87076000
# Evaluation 16/20 | Value = 0.86775000
# Evaluation 17/20 | Value = 0.86890000
# Evaluation 18/20 | Value = 0.87061000
# Evaluation 19/20 | Value = 0.87000000
# Evaluation 20/20 | Value = 0.86994000
#
# ================================================================================
# RUN 1 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 1
# Message              : Optimization terminated successfully.
# Function Evaluations : 568
# Optimization Time    : 37.581217 s
# Final Objective Value: 1.1373976342129208
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.87920000
# Evaluated Mean        : 0.86924050
# Evaluated Std         : 0.00106574
# Evaluated Min         : 0.86745000
# Evaluated Max         : 0.87077000
#
# All Evaluated Values:
# [0.87077, 0.86813, 0.8687 , 0.86983, 0.8694 , 0.87041, 0.87039, 0.86745,
#  0.86867, 0.86777, 0.86945, 0.86833, 0.868  , 0.86955, 0.87076, 0.86775,
#  0.8689 , 0.87061, 0.87   , 0.86994]
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566, 0.6883896757,
#  0.5848087428, 0.2739643248, 0.8377858251, 0.3022293541, 0.1728462164,
#  0.8017433668, 0.3441099205, 0.4375847094, 0.152681156 , 0.2761357842]
#
# Optimal Parameters:
# [ 1.3327975058,  2.536895449 ,  0.005994247 ,  1.6075845882,  0.4366269973,
#   2.4866153413, -0.0032306324,  0.1550007382, -0.0381109727, -0.3250056303,
#   0.4601032217,  2.4556870742,  0.2463159739,  0.9356166351, -0.0083635621,
#   0.5322051623,  0.0530302565,  0.6360298991, -0.0527138809,  0.2767746196,
#   0.0769798844, -0.1198158488,  1.5728649325,  0.4597938846,  0.0101849837,
#   0.7409878114,  1.5608198618,  0.5903314018, -0.0534638289, -0.1694315386]
# ================================================================================
#
# ================================================================================
# Optimization Run 2/30
# Optimization Seed : 151
# ================================================================================
#
# Initial Parameters:
# [0.4917938425, 0.3601415032, 0.7094100488, 0.6895107167, 0.4723817514,
#  0.4790485592, 0.0068635273, 0.9044398512, 0.4337399476, 0.4736042839,
#  0.034330777 , 0.9496323674, 0.5907905652, 0.4241785512, 0.1868628067,
#  0.9840929216, 0.690221156 , 0.9039467044, 0.0207568308, 0.9969449281,
#  0.3143005034, 0.2098620446, 0.0173606056, 0.1892781313, 0.2905169378,
#  0.2743264362, 0.6422361978, 0.0963913748, 0.0696866112, 0.767331954 ]
#
# Starting COBYLA optimization...
# success_probability = 0.34710000
# success_probability = 0.34010000
# success_probability = 0.35380000
# success_probability = 0.20250000
# success_probability = 0.33870000
# success_probability = 0.26530000
# success_probability = 0.40330000
# success_probability = 0.32820000
# success_probability = 0.40380000
# success_probability = 0.42180000
# success_probability = 0.43200000
# success_probability = 0.33790000
# success_probability = 0.41740000
# success_probability = 0.30750000
# success_probability = 0.42820000
# success_probability = 0.38300000
# success_probability = 0.44780000
# success_probability = 0.29380000
# success_probability = 0.42930000
# success_probability = 0.35220000
# success_probability = 0.46510000
# success_probability = 0.39910000
# success_probability = 0.46510000
# success_probability = 0.35270000
# success_probability = 0.46510000
# success_probability = 0.51590000
# success_probability = 0.51590000
# success_probability = 0.31090000
# success_probability = 0.51590000
# success_probability = 0.44210000
# success_probability = 0.51590000
# success_probability = 0.63390000
# success_probability = 0.54320000
# success_probability = 0.62190000
# success_probability = 0.62010000
# success_probability = 0.63660000
# success_probability = 0.56820000
# success_probability = 0.62230000
# success_probability = 0.54480000
# success_probability = 0.63710000
# success_probability = 0.48550000
# success_probability = 0.62650000
# success_probability = 0.60770000
# success_probability = 0.63540000
# success_probability = 0.46330000
# success_probability = 0.59770000
# success_probability = 0.44140000
# success_probability = 0.63190000
# success_probability = 0.59900000
# success_probability = 0.60340000
# success_probability = 0.57890000
# success_probability = 0.60930000
# success_probability = 0.59210000
# success_probability = 0.50890000
# success_probability = 0.62120000
# success_probability = 0.63710000
# success_probability = 0.63690000
# success_probability = 0.63710000
# success_probability = 0.65820000
# success_probability = 0.65820000
# success_probability = 0.64440000
# success_probability = 0.65820000
# success_probability = 0.63370000
# success_probability = 0.64820000
# success_probability = 0.63420000
# success_probability = 0.62840000
# success_probability = 0.66040000
# success_probability = 0.65100000
# success_probability = 0.62210000
# success_probability = 0.65240000
# success_probability = 0.59160000
# success_probability = 0.65050000
# success_probability = 0.66340000
# success_probability = 0.65980000
# success_probability = 0.68530000
# success_probability = 0.67370000
# success_probability = 0.66160000
# success_probability = 0.68340000
# success_probability = 0.64790000
# success_probability = 0.66940000
# success_probability = 0.67120000
# success_probability = 0.68560000
# success_probability = 0.66460000
# success_probability = 0.67170000
# success_probability = 0.68100000
# success_probability = 0.68650000
# success_probability = 0.66260000
# success_probability = 0.68520000
# success_probability = 0.66120000
# success_probability = 0.68650000
# success_probability = 0.69040000
# success_probability = 0.67670000
# success_probability = 0.65620000
# success_probability = 0.66870000
# success_probability = 0.68140000
# success_probability = 0.67520000
# success_probability = 0.68010000
# success_probability = 0.69040000
# success_probability = 0.64880000
# success_probability = 0.69040000
# success_probability = 0.66420000
# success_probability = 0.66100000
# success_probability = 0.66710000
# success_probability = 0.69380000
# success_probability = 0.68190000
# success_probability = 0.69350000
# success_probability = 0.68040000
# success_probability = 0.68840000
# success_probability = 0.68270000
# success_probability = 0.69990000
# success_probability = 0.68990000
# success_probability = 0.70190000
# success_probability = 0.66370000
# success_probability = 0.70650000
# success_probability = 0.70700000
# success_probability = 0.71330000
# success_probability = 0.71400000
# success_probability = 0.71550000
# success_probability = 0.72030000
# success_probability = 0.72620000
# success_probability = 0.73040000
# success_probability = 0.72680000
# success_probability = 0.73150000
# success_probability = 0.70970000
# success_probability = 0.73020000
# success_probability = 0.73540000
# success_probability = 0.73090000
# success_probability = 0.73810000
# success_probability = 0.73420000
# success_probability = 0.74490000
# success_probability = 0.74170000
# success_probability = 0.73000000
# success_probability = 0.74360000
# success_probability = 0.74470000
# success_probability = 0.74370000
# success_probability = 0.75890000
# success_probability = 0.75480000
# success_probability = 0.75460000
# success_probability = 0.76440000
# success_probability = 0.76410000
# success_probability = 0.75680000
# success_probability = 0.76660000
# success_probability = 0.75650000
# success_probability = 0.76920000
# success_probability = 0.75780000
# success_probability = 0.76900000
# success_probability = 0.75220000
# success_probability = 0.77020000
# success_probability = 0.75840000
# success_probability = 0.76490000
# success_probability = 0.77070000
# success_probability = 0.76840000
# success_probability = 0.74900000
# success_probability = 0.77000000
# success_probability = 0.76870000
# success_probability = 0.77150000
# success_probability = 0.77020000
# success_probability = 0.76750000
# success_probability = 0.76980000
# success_probability = 0.76300000
# success_probability = 0.76810000
# success_probability = 0.76740000
# success_probability = 0.76220000
# success_probability = 0.76910000
# success_probability = 0.76350000
# success_probability = 0.76390000
# success_probability = 0.76100000
# success_probability = 0.77280000
# success_probability = 0.76720000
# success_probability = 0.77190000
# success_probability = 0.76170000
# success_probability = 0.76300000
# success_probability = 0.77750000
# success_probability = 0.77470000
# success_probability = 0.77780000
# success_probability = 0.77260000
# success_probability = 0.77950000
# success_probability = 0.77770000
# success_probability = 0.77400000
# success_probability = 0.77490000
# success_probability = 0.78480000
# success_probability = 0.77900000
# success_probability = 0.77470000
# success_probability = 0.78470000
# success_probability = 0.78010000
# success_probability = 0.78430000
# success_probability = 0.76830000
# success_probability = 0.78260000
# success_probability = 0.78350000
# success_probability = 0.78200000
# success_probability = 0.78640000
# success_probability = 0.77890000
# success_probability = 0.78720000
# success_probability = 0.79160000
# success_probability = 0.79080000
# success_probability = 0.78960000
# success_probability = 0.79180000
# success_probability = 0.78950000
# success_probability = 0.78940000
# success_probability = 0.79190000
# success_probability = 0.78040000
# success_probability = 0.79440000
# success_probability = 0.78180000
# success_probability = 0.78810000
# success_probability = 0.78270000
# success_probability = 0.78840000
# success_probability = 0.78430000
# success_probability = 0.79210000
# success_probability = 0.78670000
# success_probability = 0.79390000
# success_probability = 0.78890000
# success_probability = 0.79400000
# success_probability = 0.78990000
# success_probability = 0.79010000
# success_probability = 0.78610000
# success_probability = 0.78990000
# success_probability = 0.78480000
# success_probability = 0.79070000
# success_probability = 0.78310000
# success_probability = 0.78730000
# success_probability = 0.79390000
# success_probability = 0.78800000
# success_probability = 0.79210000
# success_probability = 0.79050000
# success_probability = 0.79320000
# success_probability = 0.78800000
# success_probability = 0.79470000
# success_probability = 0.79160000
# success_probability = 0.79700000
# success_probability = 0.79770000
# success_probability = 0.79600000
# success_probability = 0.79200000
# success_probability = 0.79780000
# success_probability = 0.79680000
# success_probability = 0.79450000
# success_probability = 0.79390000
# success_probability = 0.79490000
# success_probability = 0.79700000
# success_probability = 0.79510000
# success_probability = 0.79290000
# success_probability = 0.79250000
# success_probability = 0.79630000
# success_probability = 0.79520000
# success_probability = 0.79720000
# success_probability = 0.79610000
# success_probability = 0.79660000
# success_probability = 0.79450000
# success_probability = 0.79710000
# success_probability = 0.79410000
# success_probability = 0.79530000
# success_probability = 0.79510000
# success_probability = 0.79450000
# success_probability = 0.79560000
# success_probability = 0.79550000
# success_probability = 0.79670000
# success_probability = 0.79700000
# success_probability = 0.79790000
# success_probability = 0.79610000
# success_probability = 0.79480000
# success_probability = 0.79680000
# success_probability = 0.79540000
# success_probability = 0.79640000
# success_probability = 0.79490000
# success_probability = 0.79710000
# success_probability = 0.79660000
# success_probability = 0.79600000
# success_probability = 0.79630000
# success_probability = 0.79750000
# success_probability = 0.79620000
# success_probability = 0.79380000
# success_probability = 0.79630000
# success_probability = 0.79630000
# success_probability = 0.79660000
# success_probability = 0.79530000
# success_probability = 0.79560000
# success_probability = 0.79690000
# success_probability = 0.79600000
# success_probability = 0.79610000
# success_probability = 0.79610000
# success_probability = 0.79480000
# success_probability = 0.79610000
# success_probability = 0.79780000
# success_probability = 0.79640000
# success_probability = 0.79640000
# success_probability = 0.79580000
# success_probability = 0.79680000
# success_probability = 0.79620000
# success_probability = 0.79670000
# success_probability = 0.79650000
# success_probability = 0.79630000
# success_probability = 0.79610000
# success_probability = 0.79700000
# success_probability = 0.79630000
# success_probability = 0.79680000
# success_probability = 0.79660000
# success_probability = 0.79700000
# success_probability = 0.79690000
# success_probability = 0.79740000
# success_probability = 0.79730000
# success_probability = 0.79720000
# success_probability = 0.79700000
# success_probability = 0.79710000
# success_probability = 0.79620000
# success_probability = 0.79710000
# success_probability = 0.79670000
# success_probability = 0.79750000
# success_probability = 0.79560000
# success_probability = 0.79770000
# success_probability = 0.79690000
# success_probability = 0.79740000
# success_probability = 0.79690000
# success_probability = 0.79700000
# success_probability = 0.79630000
# success_probability = 0.79760000
# success_probability = 0.79740000
# success_probability = 0.79740000
# success_probability = 0.79780000
# success_probability = 0.79730000
# success_probability = 0.79760000
# success_probability = 0.79700000
# success_probability = 0.79760000
# success_probability = 0.79710000
# success_probability = 0.79740000
# success_probability = 0.79730000
# success_probability = 0.79750000
# success_probability = 0.79670000
# success_probability = 0.79790000
# success_probability = 0.79750000
# success_probability = 0.79730000
# success_probability = 0.79760000
# success_probability = 0.79780000
# success_probability = 0.79730000
# success_probability = 0.79730000
# success_probability = 0.79760000
# success_probability = 0.79740000
# success_probability = 0.79770000
# success_probability = 0.79790000
# success_probability = 0.79790000
# success_probability = 0.79790000
# success_probability = 0.79810000
# success_probability = 0.79790000
# success_probability = 0.79780000
# success_probability = 0.79770000
# success_probability = 0.79780000
# success_probability = 0.79780000
# success_probability = 0.79770000
# success_probability = 0.79770000
# success_probability = 0.79790000
# success_probability = 0.79800000
# success_probability = 0.79800000
# success_probability = 0.79790000
# success_probability = 0.79730000
# success_probability = 0.79810000
# success_probability = 0.79760000
# success_probability = 0.79790000
# success_probability = 0.79760000
# success_probability = 0.79800000
# success_probability = 0.79780000
# success_probability = 0.79800000
# success_probability = 0.79760000
# success_probability = 0.79800000
# success_probability = 0.79800000
# success_probability = 0.79790000
# success_probability = 0.79720000
# success_probability = 0.79750000
# success_probability = 0.79800000
# success_probability = 0.79790000
# success_probability = 0.79810000
# success_probability = 0.79780000
# success_probability = 0.79790000
# success_probability = 0.79770000
# success_probability = 0.79790000
# success_probability = 0.79740000
# success_probability = 0.79790000
# success_probability = 0.79790000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79800000
# success_probability = 0.79780000
# success_probability = 0.79800000
# success_probability = 0.79790000
# success_probability = 0.79810000
# success_probability = 0.79790000
# success_probability = 0.79800000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79800000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79800000
# success_probability = 0.79800000
# success_probability = 0.79810000
# success_probability = 0.79800000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79790000
# success_probability = 0.79800000
# success_probability = 0.79790000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79800000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79800000
# success_probability = 0.79810000
# success_probability = 0.79800000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79800000
# success_probability = 0.79810000
# success_probability = 0.79800000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79800000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# success_probability = 0.79810000
# Optimization Wall-Clock Time : 35.723200 s
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  551   F = 1.252976E+00    MAXCV = 0.000000E+00
#    X = 1.530226E+00   1.378071E+00  -7.641871E-02   8.974593E-01   1.889041E-01
#        1.671409E+00   1.827663E-01   2.762313E+00   1.379871E+00   1.177102E+00
#       -3.379721E-01   4.905150E-01   1.893623E-01   5.863144E-01   5.288573E-02
#        1.757424E+00   1.802362E-01   9.274268E-01   1.913309E-01   2.285193E+00
#        8.742840E-01   5.457959E-01   2.026952E-02   6.035228E-01   1.057834E+00
#        1.877201E-02  -8.777064E-03  -1.745086E-01   2.071439E-01   6.588668E-01
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.79391000
# Evaluation  2/20 | Value = 0.79373000
# Evaluation  3/20 | Value = 0.79423000
# Evaluation  4/20 | Value = 0.79378000
# Evaluation  5/20 | Value = 0.79513000
# Evaluation  6/20 | Value = 0.79563000
# Evaluation  7/20 | Value = 0.79448000
# Evaluation  8/20 | Value = 0.79399000
# Evaluation  9/20 | Value = 0.79254000
# Evaluation 10/20 | Value = 0.79548000
# Evaluation 11/20 | Value = 0.79535000
# Evaluation 12/20 | Value = 0.79377000
# Evaluation 13/20 | Value = 0.79541000
# Evaluation 14/20 | Value = 0.79292000
# Evaluation 15/20 | Value = 0.79477000
# Evaluation 16/20 | Value = 0.79361000
# Evaluation 17/20 | Value = 0.79449000
# Evaluation 18/20 | Value = 0.79221000
# Evaluation 19/20 | Value = 0.79408000
# Evaluation 20/20 | Value = 0.79438000
#
# ================================================================================
# RUN 2 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 1
# Message              : Optimization terminated successfully.
# Function Evaluations : 551
# Optimization Time    : 35.723200 s
# Final Objective Value: 1.252975817566721
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.79810000
# Evaluated Mean        : 0.79419450
# Evaluated Std         : 0.00092957
# Evaluated Min         : 0.79221000
# Evaluated Max         : 0.79563000
#
# All Evaluated Values:
# [0.79391, 0.79373, 0.79423, 0.79378, 0.79513, 0.79563, 0.79448, 0.79399,
#  0.79254, 0.79548, 0.79535, 0.79377, 0.79541, 0.79292, 0.79477, 0.79361,
#  0.79449, 0.79221, 0.79408, 0.79438]
#
# Initial Parameters:
# [0.4917938425, 0.3601415032, 0.7094100488, 0.6895107167, 0.4723817514,
#  0.4790485592, 0.0068635273, 0.9044398512, 0.4337399476, 0.4736042839,
#  0.034330777 , 0.9496323674, 0.5907905652, 0.4241785512, 0.1868628067,
#  0.9840929216, 0.690221156 , 0.9039467044, 0.0207568308, 0.9969449281,
#  0.3143005034, 0.2098620446, 0.0173606056, 0.1892781313, 0.2905169378,
#  0.2743264362, 0.6422361978, 0.0963913748, 0.0696866112, 0.767331954 ]
#
# Optimal Parameters:
# [ 1.53022648  ,  1.3780705179, -0.0764187061,  0.8974593007,  0.1889040589,
#   1.6714094205,  0.1827662999,  2.7623134678,  1.3798707062,  1.177102459 ,
#  -0.3379721087,  0.4905150364,  0.1893623447,  0.5863144086,  0.0528857317,
#   1.7574242965,  0.1802362123,  0.9274268457,  0.1913308988,  2.2851934995,
#   0.8742840208,  0.5457958902,  0.020269523 ,  0.6035227588,  1.0578341116,
#   0.0187720103, -0.0087770637, -0.1745085664,  0.2071439403,  0.6588667904]
# ================================================================================
#
# ================================================================================
# Optimization Run 3/30
# Optimization Seed : 152
# ================================================================================
#
# Initial Parameters:
# [0.2185327016, 0.2605845547, 0.0494520073, 0.5385992113, 0.5420706407,
#  0.7890536718, 0.9123372133, 0.3722628249, 0.3257754726, 0.6556609124,
#  0.8969863307, 0.6516960973, 0.7833870606, 0.8742393722, 0.1922236761,
#  0.610154332 , 0.9457183359, 0.8193944158, 0.2252887854, 0.5455987355,
#  0.8717491352, 0.8014303248, 0.0339990148, 0.0928109212, 0.7620745294,
#  0.7686826107, 0.119207887 , 0.1127172009, 0.4882927557, 0.3775777261]
#
# Starting COBYLA optimization...
# success_probability = 0.26050000
# success_probability = 0.28170000
# success_probability = 0.26310000
# success_probability = 0.25920000
# success_probability = 0.30140000
# success_probability = 0.27610000
# success_probability = 0.33400000
# success_probability = 0.32010000
# success_probability = 0.30450000
# success_probability = 0.31160000
# success_probability = 0.32450000
# success_probability = 0.27970000
# success_probability = 0.28440000
# success_probability = 0.28710000
# success_probability = 0.33640000
# success_probability = 0.32270000
# success_probability = 0.32440000
# success_probability = 0.31580000
# success_probability = 0.29770000
# success_probability = 0.41920000
# success_probability = 0.41130000
# success_probability = 0.36850000
# success_probability = 0.41920000
# success_probability = 0.43470000
# success_probability = 0.43470000
# success_probability = 0.42940000
# success_probability = 0.43470000
# success_probability = 0.33290000
# success_probability = 0.43470000
# success_probability = 0.40240000
# success_probability = 0.43470000
# success_probability = 0.44080000
# success_probability = 0.41930000
# success_probability = 0.44880000
# success_probability = 0.43740000
# success_probability = 0.41110000
# success_probability = 0.43090000
# success_probability = 0.42530000
# success_probability = 0.44110000
# success_probability = 0.39560000
# success_probability = 0.43840000
# success_probability = 0.41180000
# success_probability = 0.36600000
# success_probability = 0.45790000
# success_probability = 0.43540000
# success_probability = 0.45210000
# success_probability = 0.46780000
# ...
#
# Evaluated Values:
# [0.79183, 0.79204, 0.79428, 0.79293, 0.79338, 0.79461, 0.79372, 0.79324,
#  0.79177, 0.79349, 0.79538, 0.79396, 0.79458, 0.79336, 0.79495, 0.79373,
#  0.79335, 0.79192, 0.79377, 0.79454]
#
# Initial Parameters:
# [0.0683064102, 0.5061877572, 0.2800764934, 0.4917358842, 0.3376481488,
#  0.6337766115, 0.7941202296, 0.2237709719, 0.8893153608, 0.9462072178,
#  0.9270749557, 0.8979372613, 0.8865232604, 0.1112901922, 0.4404611446,
#  0.6571269562, 0.6018173982, 0.0668305069, 0.5031888045, 0.7100940384,
#  0.3646853666, 0.6647653187, 0.3408936761, 0.3312253256, 0.7714370826,
#  0.2269448353, 0.0303235797, 0.6383902153, 0.6934448951, 0.8400035435]
#
# Optimal Parameters:
# [ 1.4031839846e+00,  1.3613006328e+00,  1.3981135007e-01,
#   9.6234346882e-01,  7.3185064252e-02,  1.7876221401e+00,
#  -2.0040785447e-02,  1.0338828163e+00,  1.5778454786e+00,
#   2.0835114647e+00, -5.1157073954e-01,  2.4970527776e+00,
#   2.2239612890e-01,  5.5655903412e-01,  1.0282234881e-02,
#   1.1531269980e+00, -7.3854481991e-02,  1.4323467915e+00,
#   3.9337840986e-01,  6.2576523400e-01, -9.4185020331e-01,
#   1.6987128540e-01, -7.9974898213e-04, -3.3548055726e-01,
#   1.1244125491e+00, -9.2151161456e-02, -6.0739199521e-02,
#   7.6698586894e-02,  1.7394594887e-01,  5.5771111965e-01]
# ----------------------------------------------------------------------------------------------------
#
# Run 25
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 174
# Optimized Value   : 0.88430000
# Evaluated Mean    : 0.87576600
# Evaluated Std     : 0.00121274
# Evaluated Min     : 0.87361000
# Evaluated Max     : 0.87877000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 617
# Optimization Time : 39.204652 s
#
# Evaluated Values:
# [0.87709, 0.87731, 0.87641, 0.87496, 0.87572, 0.87601, 0.87696, 0.87476,
#  0.87495, 0.87567, 0.8763 , 0.87566, 0.87627, 0.87536, 0.87581, 0.87368,
#  0.87577, 0.87361, 0.87425, 0.87877]
#
# Initial Parameters:
# [0.920751175 , 0.8324481628, 0.9226421153, 0.4120178702, 0.112899878 ,
#  0.539662511 , 0.9690640438, 0.8958288503, 0.8463732302, 0.6837088366,
#  0.0134777936, 0.9213092468, 0.0585796685, 0.528523907 , 0.4212992395,
#  0.8064657524, 0.2081509804, 0.1492170041, 0.0586840123, 0.6381376407,
#  0.7175421339, 0.7259671078, 0.0347409726, 0.8317209152, 0.1893140181,
#  0.5873066532, 0.6508822385, 0.1541344136, 0.9950538172, 0.0392803271]
#
# Optimal Parameters:
# [ 1.6246783218e+00,  2.5864678163e+00,  6.3916328800e-02,
#   1.7177586770e+00, -2.1674682794e-01,  1.9880008597e+00,
#  -2.7517199403e-02,  1.7229914683e+00,  1.5640127423e+00,
#   1.5800300419e+00,  2.8326918026e-01,  5.0997778392e-02,
#   1.3120998482e-01,  1.0279582644e+00, -2.5781668527e-03,
#   2.3300269242e+00, -1.1017186795e-02, -1.0071463720e+00,
#   2.6693337306e-01,  1.6266000174e+00,  1.5824920308e+00,
#   1.0744932445e+00,  4.7290035875e-02,  3.0254231875e-01,
#   1.3036311714e+00,  5.4804701611e-01,  1.8731452897e-03,
#  -5.7424677112e-01,  1.9525395282e-02, -5.9256614962e-02]
# ----------------------------------------------------------------------------------------------------
#
# Run 26
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 175
# Optimized Value   : 0.83910000
# Evaluated Mean    : 0.82918500
# Evaluated Std     : 0.00092168
# Evaluated Min     : 0.82747000
# Evaluated Max     : 0.83083000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 568
# Optimization Time : 36.077664 s
#
# Evaluated Values:
# [0.82747, 0.8286 , 0.82961, 0.82857, 0.82844, 0.82949, 0.82961, 0.8297 ,
#  0.8296 , 0.82979, 0.82943, 0.8305 , 0.82924, 0.8281 , 0.82908, 0.82825,
#  0.83083, 0.82771, 0.82886, 0.83082]
#
# Initial Parameters:
# [0.5632800098, 0.5263460088, 0.074383608 , 0.0432472297, 0.1116614549,
#  0.3149336925, 0.8051899849, 0.2265811498, 0.2507577735, 0.3247400132,
#  0.7132637608, 0.7744654451, 0.9295185054, 0.8709503245, 0.9380278462,
#  0.6231528096, 0.2419077457, 0.8799737511, 0.1804762542, 0.8020908004,
#  0.3363522676, 0.2884964572, 0.5552697615, 0.8113197998, 0.1117050081,
#  0.04623727  , 0.2558624663, 0.3513980154, 0.5655624306, 0.2444933266]
#
# Optimal Parameters:
# [ 1.6526736738,  2.3822363872, -0.0025939912, -0.6959245442,  1.496548515 ,
#   1.2516188725, -0.011457603 ,  0.5109959832,  0.4926510821,  0.2685107893,
#  -0.4108120895,  1.5477708484,  0.2741307761,  0.8003784965, -0.0066861252,
#   0.6668984081,  0.0259501439,  0.7971869233,  0.0147617546,  0.2019094554,
#   0.0504021376,  0.6064288162,  1.5098320151,  0.538856077 , -0.127924626 ,
#   0.3937255315,  1.5799025399,  0.299564012 , -0.1800739841,  0.4503796942]
# ----------------------------------------------------------------------------------------------------
#
# Run 27
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 176
# Optimized Value   : 0.89110000
# Evaluated Mean    : 0.89068900
# Evaluated Std     : 0.00112279
# Evaluated Min     : 0.88803000
# Evaluated Max     : 0.89216000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 571
# Optimization Time : 36.947107 s
#
# Evaluated Values:
# [0.8905 , 0.88803, 0.89139, 0.89042, 0.88877, 0.89105, 0.88984, 0.89122,
#  0.89158, 0.89216, 0.89025, 0.89037, 0.89154, 0.88931, 0.89192, 0.89209,
#  0.89141, 0.89022, 0.89199, 0.88972]
#
# Initial Parameters:
# [0.908796571 , 0.1480812304, 0.9316217524, 0.8690627692, 0.8218723273,
#  0.3598173853, 0.8198721198, 0.1817033926, 0.2126209616, 0.6959983996,
#  0.3659168242, 0.6449720995, 0.1945739112, 0.1231941489, 0.9608135811,
#  0.9693122607, 0.6994862206, 0.3285305578, 0.5308429614, 0.0713595069,
#  0.6124682681, 0.0173357401, 0.2291752338, 0.1716368198, 0.7904109494,
#  0.6764072798, 0.8677348266, 0.5559777189, 0.6488675301, 0.9283183685]
#
# Optimal Parameters:
# [ 1.5505264913, -0.4939421775, -0.0784269143,  1.4792383887,  0.9602447834,
#   0.8129513729,  1.2202577398,  0.030223154 ,  1.5624276186,  1.8333342223,
#   0.7962247677, -0.0241630275, -0.2439124295,  0.9593519249, -0.0051651486,
#   1.642680075 ,  1.9747437843,  0.3591053158,  1.772375206 , -0.9164913783,
#   1.4274341942, -0.3905558963,  0.0307336675,  0.7568352191,  1.3198409728,
#   0.5204595984,  0.0545234917, -0.0092274662, -0.1181005571,  1.4916760115]
# ----------------------------------------------------------------------------------------------------
#
# Run 28
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 177
# Optimized Value   : 0.89610000
# Evaluated Mean    : 0.89095050
# Evaluated Std     : 0.00099567
# Evaluated Min     : 0.88958000
# Evaluated Max     : 0.89309000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 654
# Optimization Time : 42.309845 s
#
# Evaluated Values:
# [0.89035, 0.89137, 0.88967, 0.89069, 0.89064, 0.89017, 0.89155, 0.8914 ,
#  0.89221, 0.89309, 0.88958, 0.8911 , 0.89121, 0.89004, 0.89192, 0.89017,
#  0.88994, 0.89082, 0.89012, 0.89297]
#
# Initial Parameters:
# [0.4859979492, 0.3134855983, 0.5928545916, 0.5388495959, 0.8208222388,
#  0.1681699936, 0.7886708539, 0.9073399324, 0.1513191786, 0.6385598502,
#  0.0204482374, 0.441729694 , 0.1062169866, 0.3316953766, 0.9856944419,
#  0.4606017013, 0.291802071 , 0.5311775661, 0.6869978953, 0.085870002 ,
#  0.70379701  , 0.7732596263, 0.358077326 , 0.7448635381, 0.5398799816,
#  0.6518199474, 0.496504845 , 0.729372615 , 0.4775535381, 0.1132538865]
#
# Optimal Parameters:
# [ 1.4487364491e+00,  2.5038907051e+00,  1.6359081935e-02,
#   1.5454365087e+00,  1.0515822415e+00,  3.1686605376e+00,
#   3.0348500645e-03,  1.1573475336e+00,  1.5862786182e+00,
#   1.5412461762e+00,  7.4265739048e-01, -4.0740905601e-02,
#   4.6224484825e-01,  8.2176245627e-01, -9.8471618585e-03,
#   1.0708683312e+00,  1.6390308921e-03,  4.0653653972e-01,
#  -4.2669858386e-01,  2.9600722036e-02,  1.4666715570e+00,
#   6.6148926806e-01,  1.9235827641e-02,  1.1414953315e+00,
#   1.6488419656e+00, -7.4141582532e-02,  5.5729812261e-02,
#   5.0333974674e-01,  7.1361235053e-02,  2.2025675908e-01]
# ----------------------------------------------------------------------------------------------------
#
# Run 29
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 178
# Optimized Value   : 0.87700000
# Evaluated Mean    : 0.87481650
# Evaluated Std     : 0.00132614
# Evaluated Min     : 0.87294000
# Evaluated Max     : 0.87957000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 640
# Optimization Time : 41.529615 s
#
# Evaluated Values:
# [0.87496, 0.87612, 0.87547, 0.87381, 0.87379, 0.87294, 0.87462, 0.87456,
#  0.87369, 0.87408, 0.87448, 0.8749 , 0.87557, 0.87508, 0.8757 , 0.87432,
#  0.87414, 0.87446, 0.87407, 0.87957]
#
# Initial Parameters:
# [0.7608275692, 0.0464101376, 0.0032708871, 0.7605003536, 0.2769531808,
#  0.5945503444, 0.8036218146, 0.7402677744, 0.1239034672, 0.2438968692,
#  0.748428843 , 0.9205783868, 0.2357355697, 0.9391032789, 0.4081091944,
#  0.4620759117, 0.7294079941, 0.5779372506, 0.3477807167, 0.9240071009,
#  0.4847679255, 0.9369591861, 0.6895419866, 0.4903610315, 0.1782447546,
#  0.0915727898, 0.6053767128, 0.8164664622, 0.7844838565, 0.8076365567]
#
# Optimal Parameters:
# [ 1.550565106 ,  2.7847918005,  0.018871513 ,  1.6281112816, -0.2126940867,
#   1.8764952549, -0.0158726407,  1.0340332923,  1.5419027282,  1.370505328 ,
#   0.0420268233,  0.2162897872,  0.11000782  ,  1.0160730662,  0.0515453472,
#   0.4865418013, -0.0328460223,  0.6312494579,  0.6046470016,  1.6812593026,
#   1.75361092  ,  0.2516666522, -0.0311931467,  0.9678499889,  1.3808872792,
#   0.9290296076,  0.0194362642,  0.5790405915,  0.0972493142,  1.1381034101]
# ----------------------------------------------------------------------------------------------------
#
# Run 30
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 179
# Optimized Value   : 0.71960000
# Evaluated Mean    : 0.70827450
# Evaluated Std     : 0.00168969
# Evaluated Min     : 0.70596000
# Evaluated Max     : 0.71319000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 568
# Optimization Time : 36.553926 s
#
# Evaluated Values:
# [0.70781, 0.70714, 0.70634, 0.70892, 0.70979, 0.70829, 0.70803, 0.70788,
#  0.70719, 0.70628, 0.70596, 0.70622, 0.71319, 0.70974, 0.70997, 0.70681,
#  0.70846, 0.70883, 0.70973, 0.70891]
#
# Initial Parameters:
# [0.9180695286, 0.9403935557, 0.9611445873, 0.1282735573, 0.7343854482,
#  0.1418537547, 0.3206870255, 0.8783134777, 0.3925501756, 0.9542827898,
#  0.4333144504, 0.0052152104, 0.5921889116, 0.318609756 , 0.9316370681,
#  0.6026668473, 0.0078690534, 0.7991305598, 0.851774691 , 0.06652901  ,
#  0.7310172927, 0.1064287992, 0.0810809173, 0.7115609048, 0.7069595409,
#  0.496652521 , 0.9897356485, 0.1231137075, 0.6818954479, 0.6829684311]
#
# Optimal Parameters:
# [ 1.5502394861,  0.9744140662,  1.5214757074,  0.1465896835,  0.8523468661,
#   0.9482923126,  1.1470198381, -0.0127865142,  1.5143104412,  1.6570399081,
#  -1.1476290773,  0.0079451026,  0.8295725289, -0.1036332806,  1.6347976147,
#  -0.0438196161,  0.4043552762, -0.4692489823,  1.0776063846,  0.0229498533,
#   0.3405644012,  0.1701583074,  1.627264692 ,  0.8910705102,  0.2817130557,
#   0.0342617925, -0.1622419689, -0.0194628631,  0.8224725261,  0.7213437849]
# ----------------------------------------------------------------------------------------------------
#
# SUMMARY
# ====================================================================================================
#
# Original Optimization-Shot Results:
# Maximum Optimized Value : 0.90230000
# Maximum Run             : 12
# Mean Optimized Value    : 0.85239333
# Std Optimized Value     : 0.04918088
#
# High-Shot Evaluation Results:
# Best Evaluated Mean     : 0.89440400
# Best Evaluated Mean Run : 12
# Mean of Evaluated Means : 0.84497760
# Std of Evaluated Means  : 0.04990610
#
# Optimizer Statistics:
# Mean Function Evals     : 601.00
# Std Function Evals      : 59.25
# Successful Runs         : 30/30
# Failed Runs             : 0/30
# Reached MaxIter         : 0/30
#
# Computational Runtime Statistics:
# Total Wall-Clock Time          : 1208.783259 s
# Total Optimization Time        : 1151.904481 s
# Time per Complete Opt. Run     : 38.396816 s
# Std Optimization Time per Run  : 4.219484 s
#
# ====================================================================================================
# BEST RUN ACCORDING TO ORIGINAL OPTIMIZED VALUE
# ====================================================================================================
# Run             : 12
# Optimized Value : 0.90230000
# Evaluated Mean  : 0.89440400
# Evaluated Std   : 0.00106127
# Evaluated Min   : 0.89262000
# Evaluated Max   : 0.89641000
#
# Evaluated Values:
# [0.89477, 0.89324, 0.89539, 0.89427, 0.89394, 0.8941 , 0.89262, 0.89282,
#  0.89439, 0.89629, 0.895  , 0.89312, 0.89412, 0.89451, 0.89641, 0.89537,
#  0.89523, 0.89287, 0.895  , 0.89462]
#
# Initial Parameters:
# [0.4686096061, 0.7232745231, 0.2377914049, 0.2611473192, 0.5875409414,
#  0.1731145953, 0.7920365816, 0.2429085519, 0.4598110398, 0.538569559 ,
#  0.9551791717, 0.6609157227, 0.9283165557, 0.5726652914, 0.2455894569,
#  0.4432030642, 0.7417625144, 0.0493864947, 0.8549279744, 0.441836411 ,
#  0.432948119 , 0.6233500039, 0.5952390388, 0.9474075505, 0.6240703149,
#  0.9470900533, 0.5137991727, 0.8754064637, 0.2320964387, 0.7979994569]
#
# Optimal Parameters:
# [ 1.4718280147,  2.5517677944,  0.0681470727, -1.4858676602,  1.6991953326,
#   0.6254886472,  1.5231398675, -0.0589579198,  2.1430639861, -0.3394983436,
#   1.1596783614,  0.7781622967,  0.3766433437,  0.9457854481,  0.0033809054,
#   0.0627732379,  1.5072880692,  1.5630393536,  1.6619765965, -0.0427305848,
#  -0.0770005014, -0.4211073618,  1.6214835069,  0.1931881252,  0.283073454 ,
#   0.6882800872,  1.6078732801,  0.7566980715, -0.0735162693, -0.3566049053]
#
# ====================================================================================================
# BEST RUN ACCORDING TO HIGH-SHOT EVALUATED MEAN
# ====================================================================================================
# Run             : 12
# Optimized Value : 0.90230000
# Evaluated Mean  : 0.89440400
# Evaluated Std   : 0.00106127
# Evaluated Min   : 0.89262000
# Evaluated Max   : 0.89641000
#
# Evaluated Values:
# [0.89477, 0.89324, 0.89539, 0.89427, 0.89394, 0.8941 , 0.89262, 0.89282,
#  0.89439, 0.89629, 0.895  , 0.89312, 0.89412, 0.89451, 0.89641, 0.89537,
#  0.89523, 0.89287, 0.895  , 0.89462]
#
# Initial Parameters:
# [0.4686096061, 0.7232745231, 0.2377914049, 0.2611473192, 0.5875409414,
#  0.1731145953, 0.7920365816, 0.2429085519, 0.4598110398, 0.538569559 ,
#  0.9551791717, 0.6609157227, 0.9283165557, 0.5726652914, 0.2455894569,
#  0.4432030642, 0.7417625144, 0.0493864947, 0.8549279744, 0.441836411 ,
#  0.432948119 , 0.6233500039, 0.5952390388, 0.9474075505, 0.6240703149,
#  0.9470900533, 0.5137991727, 0.8754064637, 0.2320964387, 0.7979994569]
#
# Optimal Parameters:
# [ 1.4718280147,  2.5517677944,  0.0681470727, -1.4858676602,  1.6991953326,
#   0.6254886472,  1.5231398675, -0.0589579198,  2.1430639861, -0.3394983436,
#   1.1596783614,  0.7781622967,  0.3766433437,  0.9457854481,  0.0033809054,
#   0.0627732379,  1.5072880692,  1.5630393536,  1.6619765965, -0.0427305848,
#  -0.0770005014, -0.4211073618,  1.6214835069,  0.1931881252,  0.283073454 ,
#   0.6882800872,  1.6078732801,  0.7566980715, -0.0735162693, -0.3566049053]
# ====================================================================================================
#
# Report saved to:
# /Users/sungwonyun/Documents/Qiskit/Minimum Error Discrimination/Simulator Seed 150 ReRe /TT_QNN_CB_report.txt
