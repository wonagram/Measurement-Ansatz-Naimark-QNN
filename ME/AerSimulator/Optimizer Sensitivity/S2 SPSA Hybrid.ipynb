# %%
# 0,1: 00 for psi_1, 01 for psi_2 ...
# 2,3: For states
# 4,5: Ancillary qubits

# %%
from qiskit import QuantumCircuit
from numpy import sqrt

def circuit_init():
    qc = QuantumCircuit(6)
    return qc

def PREP(qc):
    desired_vector = [
        1/sqrt(3), 0, 0, 0,
        1/(4*sqrt(3)), 1/4, 1/4, sqrt(3)/4,
        1/(4*sqrt(3)), -1/4, -1/4, sqrt(3)/4,
        0, 0, 0, 0
    ]
    qc.initialize(desired_vector, [3,2,1,0])
    return qc

# %%
from qiskit.circuit.library.standard_gates import RXGate,RYGate, RZGate
from qiskit.circuit.library import MCXGate
from qiskit.circuit.library.standard_gates import XGate
from pennylane.templates.state_preparations.mottonen import compute_theta, gray_code
from numpy import array, log2

def RR_X(qc, wires, params):
    qc.append(RXGate(params[0]),[wires[0]])
    qc.append(RXGate(params[1]),[wires[1]])

def RR_Z(qc, wires, params):
    qc.append(RZGate(params[0]),[wires[0]])
    qc.append(RZGate(params[1]),[wires[1]])


def CRR_X(qc, wires, state, params):
    qc.append(RXGate(params[0]).control(1,ctrl_state = state[::-1]), [wires[0], wires[1]])  # Control: wires[0] Target: wires[1]
    qc.append(RXGate(params[1]).control(1,ctrl_state = state[::-1]), [wires[0], wires[2]])  # Control: wires[0] Target: wires[2]
    return qc

def CRR_Z(qc, wires, state, params):
    qc.append(RZGate(params[0]).control(1,ctrl_state = state[::-1]), [wires[0], wires[1]])  # Control: wires[0] Target: wires[1]
    qc.append(RZGate(params[1]).control(1,ctrl_state = state[::-1]), [wires[0], wires[2]])  # Control: wires[0] Target: wires[2]
    return qc

def CCRR_X(qc, wires, state, params):
    qc.append(RXGate(params[0]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[2]])  # Control: wires[0] wires[1]
    qc.append(RXGate(params[1]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[3]])  # Control: wires[0] wires[1]
    return qc

def CCRR_Z(qc, wires, state, params):
    qc.append(RZGate(params[0]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[2]])  # Control: wires[0] wires[1]
    qc.append(RZGate(params[1]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[3]])  # Control: wires[0] wires[1]
    return qc

def U_CCR_decom(qc,wires,params):
    # Make sure that control qubits should be increasing order
    params = array(params)
    params = compute_theta(params) #can be on/off

    num_Ucontrols = len(wires)-1
    code = gray_code(2)
    n_selections = len(code)

    control_order = [int(log2(int(code[i], 2) ^ int(code[(i + 1) % n_selections], 2))) for i in range(n_selections)]

    for i in range(n_selections):
        qc.ry(params[i],wires[2])
        qc.cx(wires[num_Ucontrols-1 - control_order[i]],wires[2])
    return qc

def U_CCcR_decom(qc,wires,params):
    # Make sure that control qubits should be increasing order
    params = array(params)
    params = compute_theta(params) #can be on/off

    num_Ucontrols = len(wires)-2
    code = gray_code(2)
    n_selections = len(code)
    control_order = [int(log2(int(code[i], 2) ^ int(code[(i + 1) % n_selections], 2))) for i in range(n_selections)]

    for i in range(n_selections):
        qc.cry(params[i],wires[2],wires[3])
        CCX(qc,[wires[num_Ucontrols-1 - control_order[i]],wires[2],wires[3]],'11')

    return qc

def CCX(qc, wires, state):
    mcx_gate = MCXGate(num_ctrl_qubits=2,ctrl_state=state[::-1])
    qc.append(mcx_gate, [wires[0], wires[1],wires[2]])
    return qc

def CCCX(qc, wires, state):
    mcx_gate = MCXGate(num_ctrl_qubits=3,ctrl_state=state[::-1])
    qc.append(mcx_gate, [wires[0], wires[1],wires[2], wires[3]])
    return qc

def CX01(qc, wires):
    qc.append(
        XGate().control(1, ctrl_state='1'),
        [wires[0], wires[1]])
    return qc

# %%
from qiskit.circuit.library.standard_gates import RYGate

from numpy import pi


def Ansatz(qc, wires, params):


    #Big made by HEA
    RR_X(qc,wires[0:2],params[0:2])
    RR_Z(qc,wires[0:2],params[2:4])
    qc.cx(wires[0],wires[1])

    #Module 1
    U_CCR_decom(qc,wires[0:3],params[4:8])
    CRR_X(qc,[wires[2],wires[0],wires[1]],'0',params[8:10])
    CRR_Z(qc,[wires[2],wires[0],wires[1]],'0',params[10:12])
    CCX(qc,[wires[0],wires[2], wires[1]],'10')
    CRR_X(qc,[wires[2],wires[0],wires[1]],'1',params[12:14])
    CRR_Z(qc,[wires[2],wires[0],wires[1]],'1',params[14:16])
    CCX(qc,[wires[0],wires[2], wires[1]],'11')

    #Module 2
    U_CCcR_decom(qc, wires[0:4],params[16:20])
    CCRR_X(qc,[wires[2],wires[3],wires[0],wires[1]],'10',params[20:22])
    CCRR_Z(qc,[wires[2],wires[3],wires[0],wires[1]],'10',params[22:24])
    CCCX(qc,[wires[0],wires[2],wires[3],wires[1]],'110')
    CCRR_X(qc,[wires[2],wires[3],wires[0],wires[1]],'11',params[24:26])
    CCRR_Z(qc,[wires[2],wires[3],wires[0],wires[1]],'11',params[26:28])
    CCCX(qc,[wires[0],wires[2],wires[3],wires[1]],'111')

    CX01(qc, [wires[3],wires[2]])
    qc.measure_all()
    return qc

# %%
from numpy.random import rand
num_params=28
params = list(range(num_params))
qc = QuantumCircuit(4)
#PREP(qc)
Ansatz(qc, [0,1,2,3] , params)
qc.draw(output='mpl', style = 'clifford')

# %%
from qiskit_aer import AerSimulator
from qiskit import transpile

from qiskit_algorithms.optimizers import SPSA
from qiskit_algorithms.utils import algorithm_globals

import numpy as np
import os
import time


# ============================================================
# Simulator
# ============================================================

aersim = AerSimulator()


# ============================================================
# Settings
# ============================================================

num_times = 30
num_shots = 10000

optimizer_name = "SPSA"
maxiter = 2000

# SPSA-specific settings
learning_rate = 0.05
perturbation = 0.1

BASE_SEED = 150

report_filename = f"{optimizer_name}_report.txt"

# ============================================================
# High-Shot Evaluation Settings
# ============================================================

evaluation_num_times = 20
evaluation_num_shots = 100000

EVALUATION_BASE_SEED = 10000

evaluation_seeds = np.array(
    [
        EVALUATION_BASE_SEED + i
        for i in range(evaluation_num_times)
    ],
    dtype=int
)


# ============================================================
# Storage
# ============================================================

final_optimized_values = []

initial_params_all_runs = []
optimal_params_all_runs = []

optimization_success_all_runs = []
optimization_status_all_runs = []
optimization_message_all_runs = []

optimization_nit_all_runs = []
optimization_nfev_all_runs = []

reached_maxiter_all_runs = []

# ------------------------------------------------------------
# Runtime Storage
# ------------------------------------------------------------

optimization_wall_times = []


# ------------------------------------------------------------
# High-Shot Evaluation Storage
# ------------------------------------------------------------

evaluation_values_all_runs = []

evaluation_mean_all_runs = []
evaluation_std_all_runs = []
evaluation_min_all_runs = []
evaluation_max_all_runs = []


# ============================================================
# Objective Function
# ============================================================

def objective_function(
    params,
    run_seed,
    shots=None,
    print_result=True
):

    if shots is None:
        shots = num_shots


    # --------------------------------------------------------
    # Construct circuit
    # --------------------------------------------------------

    qc = circuit_init()

    PREP(qc)

    Ansatz(
        qc,
        [2, 3, 4, 5],
        params
    )


    qc_reverse = qc.reverse_bits()


    # --------------------------------------------------------
    # Transpile
    # --------------------------------------------------------

    t_qc = transpile(
        qc_reverse,
        aersim,
        seed_transpiler=run_seed
    )


    # --------------------------------------------------------
    # Run simulator
    # --------------------------------------------------------

    job = aersim.run(
        t_qc,
        shots=shots,
        seed_simulator=run_seed
    )


    result = job.result()

    counts = result.get_counts()


    # --------------------------------------------------------
    # Target counts
    # --------------------------------------------------------

    tar_00 = 0
    tar_01 = 0
    tar_10 = 0


    for outcome, count in counts.items():

        if outcome[0:2] == "00":

            if outcome[4:6] == "00":

                tar_00 += count


        if outcome[0:2] == "01":

            if outcome[4:6] == "01":

                tar_01 += count


        if outcome[0:2] == "10":

            if outcome[4:6] == "10":

                tar_10 += count


    # --------------------------------------------------------
    # Success probability
    # --------------------------------------------------------

    p_suc = (
        tar_00
        + tar_01
        + tar_10
    ) / shots


    if print_result:

        print(
            f"success_probability = "
            f"{p_suc:.8f}"
        )


    # --------------------------------------------------------
    # SPSA minimizes.
    #
    # We want to maximize p_suc,
    # therefore minimize 1 / p_suc.
    # --------------------------------------------------------

    if p_suc == 0:

        return 1e10


    return 1.0 / p_suc


# ============================================================
# SPSA Callback
# ============================================================

def spsa_callback(
    nfev,
    parameters,
    value,
    stepsize,
    accepted
):

    if value > 0 and value < 1e10:

        success_probability = (
            1.0 / value
        )

    else:

        success_probability = 0.0


    print(
        f"SPSA evaluation {nfev:5d} | "
        f"p_suc = {success_probability:.8f} | "
        f"objective = {value:.8f} | "
        f"step = {stepsize:.6f} | "
        f"accepted = {accepted}"
    )


# ============================================================
# Run Optimization
# ============================================================

# Measures the complete workflow:
# optimization + final evaluations + high-shot evaluations + overhead.
total_wall_start = time.perf_counter()

for run in range(num_times):


    # ========================================================
    # Optimization Seed
    # ========================================================

    run_seed = (
        BASE_SEED + run
    )


    rng = np.random.default_rng(
        run_seed
    )


    print(
        "\n"
        + "=" * 80
    )


    print(
        f"Optimization Run "
        f"{run + 1}/{num_times}"
    )


    print(
        f"Optimization Seed : "
        f"{run_seed}"
    )


    print(
        "=" * 80
    )


    # ========================================================
    # Generate Random Initial Parameters
    # ========================================================

    initial_params = rng.random(
        num_params
    )


    # --------------------------------------------------------
    # Seed SPSA internal randomness
    # --------------------------------------------------------

    algorithm_globals.random_seed = (
        run_seed
    )


    initial_params_all_runs.append(
        initial_params.copy()
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    # ========================================================
    # Create SPSA Optimizer
    # ========================================================

    optimizer = SPSA(
        maxiter=maxiter,
        learning_rate=learning_rate,
        perturbation=perturbation,
        callback=spsa_callback
    )


    # ========================================================
    # Run SPSA Optimization
    # ========================================================

    print(
        "\nStarting SPSA optimization..."
    )


    optimization_start = time.perf_counter()

    result = optimizer.minimize(

        fun=lambda params: objective_function(
            params,
            run_seed,
            shots=num_shots,
            print_result=True
        ),

        x0=initial_params
    )

    optimization_end = time.perf_counter()

    run_optimization_wall_time = (
        optimization_end
        - optimization_start
    )

    optimization_wall_times.append(
        run_optimization_wall_time
    )

    print(
        f"Optimization Wall-Clock Time : "
        f"{run_optimization_wall_time:.6f} s"
    )


    # ========================================================
    # Optimization Status
    # ========================================================

    raw_success = getattr(
        result,
        "success",
        None
    )


    if raw_success is None:

        optimization_success = None

    else:

        optimization_success = bool(
            raw_success
        )


    optimization_status = getattr(
        result,
        "status",
        None
    )


    raw_message = getattr(
        result,
        "message",
        None
    )


    if raw_message is None:

        optimization_message = (
            "Not provided by SPSA"
        )

    else:

        optimization_message = str(
            raw_message
        )


    optimization_nit = getattr(
        result,
        "nit",
        None
    )


    optimization_nfev = getattr(
        result,
        "nfev",
        None
    )


    # ========================================================
    # Detect Maximum Iteration Limit
    # ========================================================

    reached_maxiter = False


    if optimization_nit is not None:

        if optimization_nit >= maxiter:

            reached_maxiter = True


    # ========================================================
    # Store Optimization Status
    # ========================================================

    optimization_success_all_runs.append(
        optimization_success
    )


    optimization_status_all_runs.append(
        optimization_status
    )


    optimization_message_all_runs.append(
        optimization_message
    )


    optimization_nit_all_runs.append(
        optimization_nit
    )


    optimization_nfev_all_runs.append(
        optimization_nfev
    )


    reached_maxiter_all_runs.append(
        reached_maxiter
    )


    # ========================================================
    # Optimal Parameters
    # ========================================================

    optimal_params = (
        result.x.copy()
    )


    optimal_params_all_runs.append(
        optimal_params.copy()
    )


    # ========================================================
    # Final Optimization-Shot Evaluation
    #
    # This is the original optimized value:
    #     shots = 10,000
    #     seed  = optimization run seed
    # ========================================================

    final_objective = objective_function(
        optimal_params,
        run_seed,
        shots=num_shots,
        print_result=False
    )


    if final_objective >= 1e10:

        final_value = 0.0

    else:

        final_value = (
            1.0 / final_objective
        )


    final_optimized_values.append(
        final_value
    )


    # ========================================================
    # High-Shot Evaluation
    # ========================================================

    print(
        "\n"
        + "-" * 80
    )


    print(
        "HIGH-SHOT EVALUATION OF "
        "OPTIMIZED PARAMETERS"
    )


    print(
        "-" * 80
    )


    print(
        f"Optimization Shots     : "
        f"{num_shots}"
    )


    print(
        f"Evaluation Shots       : "
        f"{evaluation_num_shots}"
    )


    print(
        f"Number of Evaluations : "
        f"{evaluation_num_times}"
    )


    print(
        "\nEvaluation Results:"
    )


    evaluation_values = []


    # --------------------------------------------------------
    # Same 20 evaluation seeds for every optimized parameter
    # set.
    #
    # Evaluation seeds themselves are NOT printed here.
    # --------------------------------------------------------

    for eval_index, eval_seed in enumerate(
        evaluation_seeds
    ):


        eval_objective = objective_function(
            optimal_params,
            int(eval_seed),
            shots=evaluation_num_shots,
            print_result=False
        )


        if eval_objective >= 1e10:

            eval_value = 0.0

        else:

            eval_value = (
                1.0 / eval_objective
            )


        evaluation_values.append(
            eval_value
        )


        print(
            f"Evaluation "
            f"{eval_index + 1:2d}/"
            f"{evaluation_num_times:2d}"
            f" | Value = "
            f"{eval_value:.8f}"
        )


    # ========================================================
    # Evaluation Statistics
    # ========================================================

    evaluation_values = np.array(
        evaluation_values,
        dtype=float
    )


    evaluation_mean = np.mean(
        evaluation_values
    )


    evaluation_std = np.std(
        evaluation_values
    )


    evaluation_min = np.min(
        evaluation_values
    )


    evaluation_max = np.max(
        evaluation_values
    )


    # ========================================================
    # Store Evaluation Results
    # ========================================================

    evaluation_values_all_runs.append(
        evaluation_values.copy()
    )


    evaluation_mean_all_runs.append(
        evaluation_mean
    )


    evaluation_std_all_runs.append(
        evaluation_std
    )


    evaluation_min_all_runs.append(
        evaluation_min
    )


    evaluation_max_all_runs.append(
        evaluation_max
    )


    # ========================================================
    # Individual Run Report
    # ========================================================

    print(
        "\n"
        + "=" * 80
    )


    print(
        f"RUN {run + 1} RESULT"
    )


    print(
        "=" * 80
    )


    print(
        f"Optimization Success : "
        f"{optimization_success}"
    )


    print(
        f"Reached MaxIter      : "
        f"{reached_maxiter}"
    )


    print(
        f"Status               : "
        f"{optimization_status}"
    )


    print(
        f"Message              : "
        f"{optimization_message}"
    )


    print(
        f"Iterations           : "
        f"{optimization_nit}"
    )


    print(
        f"Function Evaluations : "
        f"{optimization_nfev}"
    )


    print(
        f"Optimization Time    : "
        f"{run_optimization_wall_time:.6f} s"
    )


    print(
        f"Optimizer Objective  : "
        f"{result.fun}"
    )


    print(
        f"Final Objective Value: "
        f"{final_objective}"
    )


    print(
        "\n"
        + "-" * 80
    )


    print(
        "OPTIMIZED AND HIGH-SHOT "
        "EVALUATED VALUES"
    )


    print(
        "-" * 80
    )


    print(
        f"Final Optimized Value : "
        f"{final_value:.8f}"
    )


    print(
        f"Evaluated Mean        : "
        f"{evaluation_mean:.8f}"
    )


    print(
        f"Evaluated Std         : "
        f"{evaluation_std:.8f}"
    )


    print(
        f"Evaluated Min         : "
        f"{evaluation_min:.8f}"
    )


    print(
        f"Evaluated Max         : "
        f"{evaluation_max:.8f}"
    )


    print(
        "\nAll Evaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values,
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "=" * 80
    )


# ============================================================
# Runtime Statistics
# ============================================================

total_wall_end = time.perf_counter()

total_wall_time = (
    total_wall_end
    - total_wall_start
)

optimization_wall_times = np.array(
    optimization_wall_times,
    dtype=float
)

total_optimization_wall_time = np.sum(
    optimization_wall_times
)

mean_optimization_wall_time = np.mean(
    optimization_wall_times
)

std_optimization_wall_time = np.std(
    optimization_wall_times
)


# ============================================================
# Convert Results to NumPy Arrays
# ============================================================

final_optimized_values = np.array(
    final_optimized_values,
    dtype=float
)


initial_params_all_runs = np.array(
    initial_params_all_runs
)


optimal_params_all_runs = np.array(
    optimal_params_all_runs
)


evaluation_values_all_runs = np.array(
    evaluation_values_all_runs,
    dtype=float
)


evaluation_mean_all_runs = np.array(
    evaluation_mean_all_runs,
    dtype=float
)


evaluation_std_all_runs = np.array(
    evaluation_std_all_runs,
    dtype=float
)


evaluation_min_all_runs = np.array(
    evaluation_min_all_runs,
    dtype=float
)


evaluation_max_all_runs = np.array(
    evaluation_max_all_runs,
    dtype=float
)


# ============================================================
# Original Optimization Statistics
# ============================================================

maximum_value = np.max(
    final_optimized_values
)


mean_value = np.mean(
    final_optimized_values
)


std_value = np.std(
    final_optimized_values
)


maximum_run_index = np.argmax(
    final_optimized_values
)


maximum_run = (
    maximum_run_index
    + 1
)


# ============================================================
# High-Shot Evaluation Statistics
# ============================================================

maximum_evaluated_mean = np.max(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run_index = np.argmax(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run = (
    maximum_evaluated_mean_run_index
    + 1
)


mean_of_evaluated_means = np.mean(
    evaluation_mean_all_runs
)


std_of_evaluated_means = np.std(
    evaluation_mean_all_runs
)


# ============================================================
# Iteration Statistics
# ============================================================

nit_values = np.array(
    [
        nit
        for nit
        in optimization_nit_all_runs
        if nit is not None
    ],
    dtype=float
)


if len(nit_values) > 0:

    mean_nit = np.mean(
        nit_values
    )


    std_nit = np.std(
        nit_values
    )

else:

    mean_nit = np.nan
    std_nit = np.nan


# ============================================================
# Function Evaluation Statistics
# ============================================================

nfev_values = np.array(
    [
        nfev
        for nfev
        in optimization_nfev_all_runs
        if nfev is not None
    ],
    dtype=float
)


if len(nfev_values) > 0:

    mean_nfev = np.mean(
        nfev_values
    )


    std_nfev = np.std(
        nfev_values
    )

else:

    mean_nfev = np.nan
    std_nfev = np.nan


# ============================================================
# SPSA Run Statistics
# ============================================================

# SPSA may not provide a SciPy-style success flag.

num_successful_runs = sum(
    value is True
    for value in optimization_success_all_runs
)


num_failed_runs = sum(
    value is False
    for value in optimization_success_all_runs
)


num_unknown_success = sum(
    value is None
    for value in optimization_success_all_runs
)


num_reached_maxiter = sum(
    reached_maxiter_all_runs
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

best_initial_params = (
    initial_params_all_runs[
        maximum_run_index
    ]
)


best_optimal_params = (
    optimal_params_all_runs[
        maximum_run_index
    ]
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

best_evaluated_initial_params = (
    initial_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_optimal_params = (
    optimal_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_values = (
    evaluation_values_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


# ============================================================
# Print Final Report
# ============================================================

print("\n")


print(
    "=" * 100
)


print(
    "FINAL OPTIMIZATION AND "
    "HIGH-SHOT EVALUATION REPORT"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Settings
# ------------------------------------------------------------

print(
    f"Optimizer               : "
    f"{optimizer_name}"
)


print(
    f"Learning Rate           : "
    f"{learning_rate}"
)


print(
    f"Perturbation            : "
    f"{perturbation}"
)


print(
    f"Max Iteration           : "
    f"{maxiter}"
)


print(
    f"Number of Runs          : "
    f"{num_times}"
)


print(
    f"Optimization Shots      : "
    f"{num_shots}"
)


print(
    f"Optimization Base Seed  : "
    f"{BASE_SEED}"
)


print(
    f"Evaluation Shots        : "
    f"{evaluation_num_shots}"
)


print(
    f"Evaluations Per Run     : "
    f"{evaluation_num_times}"
)


print(
    f"Evaluation Base Seed    : "
    f"{EVALUATION_BASE_SEED}"
)


# Evaluation seeds printed ONCE only.
print(
    "Evaluation Seeds        : "
    + np.array2string(
        evaluation_seeds,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Results for Every Run
# ============================================================

for i in range(num_times):


    print(
        f"\nRun {i + 1:2d}"
    )


    print(
        "-" * 100
    )


    print(
        f"Optimization Seed : "
        f"{BASE_SEED + i}"
    )


    print(
        f"Optimized Value   : "
        f"{final_optimized_values[i]:.8f}"
    )


    print(
        f"Evaluated Mean    : "
        f"{evaluation_mean_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Std     : "
        f"{evaluation_std_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Min     : "
        f"{evaluation_min_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Max     : "
        f"{evaluation_max_all_runs[i]:.8f}"
    )


    print(
        f"Success           : "
        f"{optimization_success_all_runs[i]}"
    )


    print(
        f"Reached MaxIter   : "
        f"{reached_maxiter_all_runs[i]}"
    )


    print(
        f"Status            : "
        f"{optimization_status_all_runs[i]}"
    )


    print(
        f"Message           : "
        f"{optimization_message_all_runs[i]}"
    )


    print(
        f"Iterations        : "
        f"{optimization_nit_all_runs[i]}"
    )


    print(
        f"Function Evals    : "
        f"{optimization_nfev_all_runs[i]}"
    )


    print(
        f"Optimization Time : "
        f"{optimization_wall_times[i]:.6f} s"
    )


    print(
        "\nEvaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values_all_runs[i],
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "-" * 100
    )


# ============================================================
# Summary
# ============================================================

print(
    "\nSUMMARY"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Original Optimization-Shot Results
# ------------------------------------------------------------

print(
    "\nOriginal Optimization-Shot Results:"
)


print(
    f"Maximum Optimized Value : "
    f"{maximum_value:.8f}"
)


print(
    f"Maximum Run             : "
    f"{maximum_run}"
)


print(
    f"Mean Optimized Value    : "
    f"{mean_value:.8f}"
)


print(
    f"Std Optimized Value     : "
    f"{std_value:.8f}"
)


# ------------------------------------------------------------
# High-Shot Evaluation Results
# ------------------------------------------------------------

print(
    "\nHigh-Shot Evaluation Results:"
)


print(
    f"Best Evaluated Mean     : "
    f"{maximum_evaluated_mean:.8f}"
)


print(
    f"Best Evaluated Mean Run : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Mean of Evaluated Means : "
    f"{mean_of_evaluated_means:.8f}"
)


print(
    f"Std of Evaluated Means  : "
    f"{std_of_evaluated_means:.8f}"
)


# ------------------------------------------------------------
# Optimizer Statistics
# ------------------------------------------------------------

print(
    "\nOptimizer Statistics:"
)


print(
    f"Mean Iterations         : "
    f"{mean_nit:.2f}"
)


print(
    f"Std Iterations          : "
    f"{std_nit:.2f}"
)


print(
    f"Mean Function Evals     : "
    f"{mean_nfev:.2f}"
)


print(
    f"Std Function Evals      : "
    f"{std_nfev:.2f}"
)


print(
    f"Successful Runs         : "
    f"{num_successful_runs}/"
    f"{num_times}"
)


print(
    f"Failed Runs             : "
    f"{num_failed_runs}/"
    f"{num_times}"
)


print(
    f"Success Not Reported    : "
    f"{num_unknown_success}/"
    f"{num_times}"
)


print(
    f"Reached MaxIter         : "
    f"{num_reached_maxiter}/"
    f"{num_times}"
)


# ------------------------------------------------------------
# Computational Runtime Statistics
# ------------------------------------------------------------

print(
    "\nComputational Runtime Statistics:"
)

print(
    f"Total Wall-Clock Time          : "
    f"{total_wall_time:.6f} s"
)

print(
    f"Total Optimization Time        : "
    f"{total_optimization_wall_time:.6f} s"
)

print(
    f"Time per Complete Opt. Run     : "
    f"{mean_optimization_wall_time:.6f} s"
)

print(
    f"Std Optimization Time per Run  : "
    f"{std_optimization_wall_time:.6f} s"
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "ORIGINAL OPTIMIZED VALUE"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        evaluation_values_all_runs[
            maximum_run_index
        ],
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_optimal_params,
        precision=10,
        separator=", "
    )
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "HIGH-SHOT EVALUATED MEAN"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        best_evaluated_values,
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_evaluated_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_evaluated_optimal_params,
        precision=10,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Save Report to TXT
# ============================================================

with open(
    report_filename,
    "w"
) as f:


    # ========================================================
    # Header
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "FINAL OPTIMIZATION AND "
        "HIGH-SHOT EVALUATION REPORT\n"
    )


    f.write(
        "=" * 100
        + "\n\n"
    )


    # ========================================================
    # Settings
    # ========================================================

    f.write(
        f"Optimizer               : "
        f"{optimizer_name}\n"
    )


    f.write(
        f"Learning Rate           : "
        f"{learning_rate}\n"
    )


    f.write(
        f"Perturbation            : "
        f"{perturbation}\n"
    )


    f.write(
        f"Max Iteration           : "
        f"{maxiter}\n"
    )


    f.write(
        f"Number of Runs          : "
        f"{num_times}\n"
    )


    f.write(
        f"Optimization Shots      : "
        f"{num_shots}\n"
    )


    f.write(
        f"Optimization Base Seed  : "
        f"{BASE_SEED}\n"
    )


    f.write(
        f"Evaluation Shots        : "
        f"{evaluation_num_shots}\n"
    )


    f.write(
        f"Evaluations Per Run     : "
        f"{evaluation_num_times}\n"
    )


    f.write(
        f"Evaluation Base Seed    : "
        f"{EVALUATION_BASE_SEED}\n"
    )


    # Evaluation seeds saved ONCE only.
    f.write(
        "Evaluation Seeds        : "
    )


    f.write(
        np.array2string(
            evaluation_seeds,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    # ========================================================
    # Results for Every Run
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "RESULTS FOR EACH RUN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    for i in range(num_times):


        f.write(
            f"\nRun {i + 1:2d}\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


        f.write(
            f"Optimization Seed : "
            f"{BASE_SEED + i}\n"
        )


        f.write(
            f"Optimized Value   : "
            f"{final_optimized_values[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Mean    : "
            f"{evaluation_mean_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Std     : "
            f"{evaluation_std_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Min     : "
            f"{evaluation_min_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Max     : "
            f"{evaluation_max_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Success           : "
            f"{optimization_success_all_runs[i]}\n"
        )


        f.write(
            f"Reached MaxIter   : "
            f"{reached_maxiter_all_runs[i]}\n"
        )


        f.write(
            f"Status            : "
            f"{optimization_status_all_runs[i]}\n"
        )


        f.write(
            f"Message           : "
            f"{optimization_message_all_runs[i]}\n"
        )


        f.write(
            f"Iterations        : "
            f"{optimization_nit_all_runs[i]}\n"
        )


        f.write(
            f"Function Evals    : "
            f"{optimization_nfev_all_runs[i]}\n"
        )


        f.write(
            f"Optimization Time : "
            f"{optimization_wall_times[i]:.6f} s\n"
        )


        f.write(
            "\nEvaluated Values:\n"
        )


        f.write(
            np.array2string(
                evaluation_values_all_runs[i],
                precision=8,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nInitial Parameters:\n"
        )


        f.write(
            np.array2string(
                initial_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nOptimal Parameters:\n"
        )


        f.write(
            np.array2string(
                optimal_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


    # ========================================================
    # Summary
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "SUMMARY\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    # --------------------------------------------------------
    # Original Optimization-Shot Results
    # --------------------------------------------------------

    f.write(
        "\nOriginal Optimization-Shot Results:\n"
    )


    f.write(
        f"Maximum Optimized Value : "
        f"{maximum_value:.8f}\n"
    )


    f.write(
        f"Maximum Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Mean Optimized Value    : "
        f"{mean_value:.8f}\n"
    )


    f.write(
        f"Std Optimized Value     : "
        f"{std_value:.8f}\n"
    )


    # --------------------------------------------------------
    # High-Shot Evaluation Results
    # --------------------------------------------------------

    f.write(
        "\nHigh-Shot Evaluation Results:\n"
    )


    f.write(
        f"Best Evaluated Mean     : "
        f"{maximum_evaluated_mean:.8f}\n"
    )


    f.write(
        f"Best Evaluated Mean Run : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Mean of Evaluated Means : "
        f"{mean_of_evaluated_means:.8f}\n"
    )


    f.write(
        f"Std of Evaluated Means  : "
        f"{std_of_evaluated_means:.8f}\n"
    )


    # --------------------------------------------------------
    # Optimizer Statistics
    # --------------------------------------------------------

    f.write(
        "\nOptimizer Statistics:\n"
    )


    f.write(
        f"Mean Iterations         : "
        f"{mean_nit:.2f}\n"
    )


    f.write(
        f"Std Iterations          : "
        f"{std_nit:.2f}\n"
    )


    f.write(
        f"Mean Function Evals     : "
        f"{mean_nfev:.2f}\n"
    )


    f.write(
        f"Std Function Evals      : "
        f"{std_nfev:.2f}\n"
    )


    f.write(
        f"Successful Runs         : "
        f"{num_successful_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Failed Runs             : "
        f"{num_failed_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Success Not Reported    : "
        f"{num_unknown_success}/"
        f"{num_times}\n"
    )


    f.write(
        f"Reached MaxIter         : "
        f"{num_reached_maxiter}/"
        f"{num_times}\n"
    )


    # --------------------------------------------------------
    # Computational Runtime Statistics
    # --------------------------------------------------------

    f.write(
        "\nComputational Runtime Statistics:\n"
    )

    f.write(
        f"Total Wall-Clock Time          : "
        f"{total_wall_time:.6f} s\n"
    )

    f.write(
        f"Total Optimization Time        : "
        f"{total_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Time per Complete Opt. Run     : "
        f"{mean_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Std Optimization Time per Run  : "
        f"{std_optimization_wall_time:.6f} s\n"
    )


    # ========================================================
    # Best Run According to Original Optimized Value
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "ORIGINAL OPTIMIZED VALUE\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            evaluation_values_all_runs[
                maximum_run_index
            ],
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    # ========================================================
    # Best Run According to High-Shot Evaluated Mean
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "HIGH-SHOT EVALUATED MEAN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_values,
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


# ============================================================
# Report Location
# ============================================================

print(
    "\nReport saved to:"
)


print(
    os.path.abspath(
        report_filename
    )
)
# Out:
# ================================================================================
# Optimization Run 1/30
# Optimization Seed : 150
# ================================================================================
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566, 0.6883896757,
#  0.5848087428, 0.2739643248, 0.8377858251, 0.3022293541, 0.1728462164,
#  0.8017433668, 0.3441099205, 0.4375847094]
#
# Starting SPSA optimization...
# success_probability = 0.33330000
# success_probability = 0.32840000
# success_probability = 0.33150000
# SPSA evaluation     3 | p_suc = 0.33150000 | objective = 3.01659125 | step = 0.059221 | accepted = True
# success_probability = 0.32110000
# success_probability = 0.34530000
# success_probability = 0.34070000
# SPSA evaluation     6 | p_suc = 0.34070000 | objective = 2.93513355 | step = 0.288734 | accepted = True
# success_probability = 0.33950000
# success_probability = 0.34310000
# success_probability = 0.34030000
# SPSA evaluation     9 | p_suc = 0.34030000 | objective = 2.93858360 | step = 0.040885 | accepted = True
# success_probability = 0.33320000
# success_probability = 0.35020000
# success_probability = 0.34340000
# SPSA evaluation    12 | p_suc = 0.34340000 | objective = 2.91205591 | step = 0.192729 | accepted = True
# success_probability = 0.33990000
# success_probability = 0.35130000
# success_probability = 0.34430000
# SPSA evaluation    15 | p_suc = 0.34430000 | objective = 2.90444380 | step = 0.126297 | accepted = True
# success_probability = 0.35750000
# success_probability = 0.33400000
# success_probability = 0.34900000
# SPSA evaluation    18 | p_suc = 0.34900000 | objective = 2.86532951 | step = 0.260354 | accepted = True
# success_probability = 0.34040000
# success_probability = 0.36120000
# success_probability = 0.35290000
# SPSA evaluation    21 | p_suc = 0.35290000 | objective = 2.83366393 | step = 0.223792 | accepted = True
# success_probability = 0.35590000
# success_probability = 0.35560000
# success_probability = 0.35330000
# SPSA evaluation    24 | p_suc = 0.35330000 | objective = 2.83045570 | step = 0.003136 | accepted = True
# success_probability = 0.34320000
# success_probability = 0.36370000
# success_probability = 0.35740000
# SPSA evaluation    27 | p_suc = 0.35740000 | objective = 2.79798545 | step = 0.217261 | accepted = True
# success_probability = 0.36840000
# success_probability = 0.34820000
# success_probability = 0.36330000
# SPSA evaluation    30 | p_suc = 0.36330000 | objective = 2.75254611 | step = 0.208316 | accepted = True
# success_probability = 0.37810000
# success_probability = 0.35210000
# success_probability = 0.36870000
# SPSA evaluation    33 | p_suc = 0.36870000 | objective = 2.71223217 | step = 0.258357 | accepted = True
# success_probability = 0.35610000
# success_probability = 0.38390000
# success_probability = 0.37660000
# SPSA evaluation    36 | p_suc = 0.37660000 | objective = 2.65533723 | step = 0.269013 | accepted = True
# success_probability = 0.36820000
# success_probability = 0.38090000
# success_probability = 0.37820000
# SPSA evaluation    39 | p_suc = 0.37820000 | objective = 2.64410365 | step = 0.119792 | accepted = True
# success_probability = 0.38590000
# success_probability = 0.37110000
# success_probability = 0.38100000
# SPSA evaluation    42 | p_suc = 0.38100000 | objective = 2.62467192 | step = 0.136715 | accepted = True
# success_probability = 0.40020000
# success_probability = 0.36580000
# success_probability = 0.39220000
# SPSA evaluation    45 | p_suc = 0.39220000 | objective = 2.54971953 | step = 0.310854 | accepted = True
# success_probability = 0.39650000
# success_probability = 0.38240000
# success_probability = 0.39430000
# SPSA evaluation    48 | p_suc = 0.39430000 | objective = 2.53613999 | step = 0.123020 | accepted = True
# success_probability = 0.39230000
# success_probability = 0.39510000
# success_probability = 0.39500000
# SPSA evaluation    51 | p_suc = 0.39500000 | objective = 2.53164557 | step = 0.023897 | accepted = True
# success_probability = 0.37820000
# success_probability = 0.40950000
# success_probability = 0.40200000
# SPSA evaluation    54 | p_suc = 0.40200000 | objective = 2.48756219 | step = 0.267355 | accepted = True
# success_probability = 0.38200000
# success_probability = 0.41540000
# success_probability = 0.41040000
# SPSA evaluation    57 | p_suc = 0.41040000 | objective = 2.43664717 | step = 0.278443 | accepted = True
# success_probability = 0.39310000
# success_probability = 0.42460000
# success_probability = 0.41560000
# SPSA evaluation    60 | p_suc = 0.41560000 | objective = 2.40615977 | step = 0.249659 | accepted = True
# success_probability = 0.40030000
# success_probability = 0.43000000
# success_probability = 0.42400000
# SPSA evaluation    63 | p_suc = 0.42400000 | objective = 2.35849057 | step = 0.228256 | accepted = True
# success_probability = 0.41150000
# success_probability = 0.42750000
# success_probability = 0.42610000
# SPSA evaluation    66 | p_suc = 0.42610000 | objective = 2.34686693 | step = 0.120319 | accepted = True
# success_probability = 0.42560000
# success_probability = 0.41750000
# success_probability = 0.42600000
# SPSA evaluation    69 | p_suc = 0.42600000 | objective = 2.34741784 | step = 0.060304 | accepted = True
# success_probability = 0.42450000
# success_probability = 0.42140000
# success_probability = 0.42630000
# SPSA evaluation    72 | p_suc = 0.42630000 | objective = 2.34576589 | step = 0.022925 | accepted = True
# success_probability = 0.43450000
# success_probability = 0.41060000
# success_probability = 0.42870000
# SPSA evaluation    75 | p_suc = 0.42870000 | objective = 2.33263354 | step = 0.177218 | accepted = True
# success_probability = 0.41090000
# success_probability = 0.44020000
# success_probability = 0.43350000
# SPSA evaluation    78 | p_suc = 0.43350000 | objective = 2.30680507 | step = 0.214289 | accepted = True
# success_probability = 0.44850000
# success_probability = 0.41530000
# success_probability = 0.44010000
# SPSA evaluation    81 | p_suc = 0.44010000 | objective = 2.27221086 | step = 0.235794 | accepted = True
# success_probability = 0.43730000
# success_probability = 0.44200000
# success_probability = 0.44040000
# SPSA evaluation    84 | p_suc = 0.44040000 | objective = 2.27066303 | step = 0.032167 | accepted = True
# success_probability = 0.42830000
# success_probability = 0.45350000
# success_probability = 0.44520000
# SPSA evaluation    87 | p_suc = 0.44520000 | objective = 2.24618149 | step = 0.171630 | accepted = True
# success_probability = 0.43280000
# success_probability = 0.45400000
# success_probability = 0.44820000
# SPSA evaluation    90 | p_suc = 0.44820000 | objective = 2.23114681 | step = 0.142729 | accepted = True
# success_probability = 0.45930000
# success_probability = 0.43340000
# success_probability = 0.45110000
# SPSA evaluation    93 | p_suc = 0.45110000 | objective = 2.21680337 | step = 0.172121 | accepted = True
# success_probability = 0.45940000
# success_probability = 0.44490000
# success_probability = 0.45190000
# SPSA evaluation    96 | p_suc = 0.45190000 | objective = 2.21287896 | step = 0.093850 | accepted = True
# success_probability = 0.43460000
# success_probability = 0.46910000
# success_probability = 0.45810000
# SPSA evaluation    99 | p_suc = 0.45810000 | objective = 2.18292949 | step = 0.223863 | accepted = True
# success_probability = 0.47390000
# success_probability = 0.44720000
# success_probability = 0.46490000
# SPSA evaluation   102 | p_suc = 0.46490000 | objective = 2.15100022 | step = 0.166664 | accepted = True
# success_probability = 0.47190000
# success_probability = 0.45410000
# success_probability = 0.46780000
# SPSA evaluation   105 | p_suc = 0.46780000 | objective = 2.13766567 | step = 0.109885 | accepted = True
# success_probability = 0.45530000
# success_probability = 0.47880000
# success_probability = 0.47260000
# SPSA evaluation   108 | p_suc = 0.47260000 | objective = 2.11595430 | step = 0.142605 | accepted = True
# success_probability = 0.47910000
# success_probability = 0.45730000
# success_probability = 0.47410000
# SPSA evaluation   111 | p_suc = 0.47410000 | objective = 2.10925965 | step = 0.131628 | accepted = True
# success_probability = 0.48080000
# success_probability = 0.45750000
# success_probability = 0.47460000
# SPSA evaluation   114 | p_suc = 0.47460000 | objective = 2.10703751 | step = 0.140126 | accepted = True
# success_probability = 0.47880000
# success_probability = 0.46640000
# success_probability = 0.47560000
# SPSA evaluation   117 | p_suc = 0.47560000 | objective = 2.10260723 | step = 0.073456 | accepted = True
# success_probability = 0.46390000
# success_probability = 0.48360000
# success_probability = 0.47920000
# SPSA evaluation   120 | p_suc = 0.47920000 | objective = 2.08681135 | step = 0.116165 | accepted = True
# success_probability = 0.49080000
# success_probability = 0.45950000
# success_probability = 0.48290000
# SPSA evaluation   123 | p_suc = 0.48290000 | objective = 2.07082212 | step = 0.183600 | accepted = True
# success_probability = 0.49270000
# success_probability = 0.46640000
# success_probability = 0.48740000
# SPSA evaluation   126 | p_suc = 0.48740000 | objective = 2.05170291 | step = 0.151403 | accepted = True
# success_probability = 0.48880000
# success_probability = 0.47470000
# success_probability = 0.48810000
# SPSA evaluation   129 | p_suc = 0.48810000 | objective = 2.04876050 | step = 0.080387 | accepted = True
# success_probability = 0.47520000
# success_probability = 0.49540000
# success_probability = 0.49000000
# SPSA evaluation   132 | p_suc = 0.49000000 | objective = 2.04081633 | step = 0.113511 | accepted = True
# success_probability = 0.49670000
# success_probability = 0.47430000
# success_probability = 0.49130000
# SPSA evaluation   135 | p_suc = 0.49130000 | objective = 2.03541624 | step = 0.125782 | accepted = True
# success_probability = 0.47300000
# success_probability = 0.50450000
# success_probability = 0.49420000
# SPSA evaluation   138 | p_suc = 0.49420000 | objective = 2.02347228 | step = 0.174625 | accepted = True
# success_probability = 0.50350000
# success_probability = 0.48700000
# success_probability = 0.49610000
# SPSA evaluation   141 | p_suc = 0.49610000 | objective = 2.01572264 | step = 0.089017 | accepted = True
# success_probability = 0.50750000
# success_probability = 0.48350000
# success_probability = 0.49940000
# SPSA evaluation   144 | p_suc = 0.49940000 | objective = 2.00240288 | step = 0.129389 | accepted = True
# success_probability = 0.51040000
# success_probability = 0.49110000
# success_probability = 0.50280000
# SPSA evaluation   147 | p_suc = 0.50280000 | objective = 1.98886237 | step = 0.101858 | accepted = True
# success_probability = 0.50090000
# success_probability = 0.50370000
# success_probability = 0.50290000
# SPSA evaluation   150 | p_suc = 0.50290000 | objective = 1.98846689 | step = 0.014681 | accepted = True
# success_probability = 0.49570000
# success_probability = 0.50700000
# success_probability = 0.50350000
# SPSA evaluation   153 | p_suc = 0.50350000 | objective = 1.98609732 | step = 0.059480 | accepted = True
# success_probability = 0.51620000
# success_probability = 0.48890000
# success_probability = 0.50880000
# SPSA evaluation   156 | p_suc = 0.50880000 | objective = 1.96540881 | step = 0.143101 | accepted = True
# success_probability = 0.52080000
# success_probability = 0.48880000
# success_probability = 0.51310000
# SPSA evaluation   159 | p_suc = 0.51310000 | objective = 1.94893783 | step = 0.166290 | accepted = True
# success_probability = 0.52160000
# success_probability = 0.50040000
# success_probability = 0.51420000
# SPSA evaluation   162 | p_suc = 0.51420000 | objective = 1.94476857 | step = 0.107448 | accepted = True
# success_probability = 0.51730000
# success_probability = 0.50820000
# success_probability = 0.51550000
# SPSA evaluation   165 | p_suc = 0.51550000 | objective = 1.93986421 | step = 0.045791 | accepted = True
# success_probability = 0.52960000
# success_probability = 0.49890000
# success_probability = 0.51930000
# SPSA evaluation   168 | p_suc = 0.51930000 | objective = 1.92566917 | step = 0.153708 | accepted = True
# success_probability = 0.52220000
# success_probability = 0.51290000
# success_probability = 0.52030000
# SPSA evaluation   171 | p_suc = 0.52030000 | objective = 1.92196810 | step = 0.045934 | accepted = True
# success_probability = 0.50580000
# success_probability = 0.52950000
# success_probability = 0.52210000
# SPSA evaluation   174 | p_suc = 0.52210000 | objective = 1.91534189 | step = 0.117064 | accepted = True
# success_probability = 0.52780000
# success_probability = 0.51110000
# success_probability = 0.52280000
# SPSA evaluation   177 | p_suc = 0.52280000 | objective = 1.91277735 | step = 0.081896 | accepted = True
# success_probability = 0.52090000
# success_probability = 0.52390000
# success_probability = 0.52270000
# SPSA evaluation   180 | p_suc = 0.52270000 | objective = 1.91314329 | step = 0.014542 | accepted = True
# success_probability = 0.52240000
# success_probability = 0.51920000
# success_probability = 0.52300000
# SPSA evaluation   183 | p_suc = 0.52300000 | objective = 1.91204589 | step = 0.015607 | accepted = True
# success_probability = 0.52470000
# success_probability = 0.51600000
# success_probability = 0.52360000
# SPSA evaluation   186 | p_suc = 0.52360000 | objective = 1.90985485 | step = 0.042509 | accepted = True
# success_probability = 0.52290000
# success_probability = 0.51870000
# success_probability = 0.52330000
# SPSA evaluation   189 | p_suc = 0.52330000 | objective = 1.91094974 | step = 0.020485 | accepted = True
# success_probability = 0.51520000
# success_probability = 0.52690000
# success_probability = 0.52540000
# SPSA evaluation   192 | p_suc = 0.52540000 | objective = 1.90331176 | step = 0.057017 | accepted = True
# success_probability = 0.51720000
# success_probability = 0.52510000
# success_probability = 0.52560000
# SPSA evaluation   195 | p_suc = 0.52560000 | objective = 1.90258752 | step = 0.038481 | accepted = True
# success_probability = 0.51380000
# success_probability = 0.53170000
# success_probability = 0.52630000
# SPSA evaluation   198 | p_suc = 0.52630000 | objective = 1.90005700 | step = 0.086678 | accepted = True
# success_probability = 0.52770000
# success_probability = 0.52000000
# success_probability = 0.52710000
# SPSA evaluation   201 | p_suc = 0.52710000 | objective = 1.89717321 | step = 0.037121 | accepted = True
# success_probability = 0.52260000
# success_probability = 0.52850000
# success_probability = 0.52710000
# SPSA evaluation   204 | p_suc = 0.52710000 | objective = 1.89717321 | step = 0.028259 | accepted = True
# success_probability = 0.54150000
# success_probability = 0.50900000
# success_probability = 0.53040000
# SPSA evaluation   207 | p_suc = 0.53040000 | objective = 1.88536953 | step = 0.155986 | accepted = True
# success_probability = 0.52440000
# success_probability = 0.53600000
# success_probability = 0.53030000
# SPSA evaluation   210 | p_suc = 0.53030000 | objective = 1.88572506 | step = 0.054595 | accepted = True
# success_probability = 0.54600000
# success_probability = 0.51390000
# success_probability = 0.53640000
# SPSA evaluation   213 | p_suc = 0.53640000 | objective = 1.86428039 | step = 0.151340 | accepted = True
# success_probability = 0.53910000
# success_probability = 0.53090000
# success_probability = 0.53670000
# SPSA evaluation   216 | p_suc = 0.53670000 | objective = 1.86323831 | step = 0.037901 | accepted = True
# success_probability = 0.53440000
# success_probability = 0.53660000
# success_probability = 0.53660000
# SPSA evaluation   219 | p_suc = 0.53660000 | objective = 1.86358554 | step = 0.010149 | accepted = True
# success_probability = 0.55130000
# success_probability = 0.52340000
# success_probability = 0.53930000
# SPSA evaluation   222 | p_suc = 0.53930000 | objective = 1.85425552 | step = 0.127909 | accepted = True
# success_probability = 0.54370000
# success_probability = 0.53500000
# success_probability = 0.54080000
# SPSA evaluation   225 | p_suc = 0.54080000 | objective = 1.84911243 | step = 0.039566 | accepted = True
# success_probability = 0.54380000
# success_probability = 0.53460000
# success_probability = 0.54080000
# SPSA evaluation   228 | p_suc = 0.54080000 | objective = 1.84911243 | step = 0.041864 | accepted = True
# success_probability = 0.53340000
# success_probability = 0.54330000
# success_probability = 0.54140000
# SPSA evaluation   231 | p_suc = 0.54140000 | objective = 1.84706317 | step = 0.045192 | accepted = True
# success_probability = 0.54040000
# success_probability = 0.53410000
# success_probability = 0.54100000
# SPSA evaluation   234 | p_suc = 0.54100000 | objective = 1.84842884 | step = 0.028875 | accepted = True
# success_probability = 0.53700000
# success_probability = 0.53990000
# success_probability = 0.54120000
# SPSA evaluation   237 | p_suc = 0.54120000 | objective = 1.84774575 | step = 0.013232 | accepted = True
# success_probability = 0.52330000
# success_probability = 0.55550000
# success_probability = 0.54700000
# SPSA evaluation   240 | p_suc = 0.54700000 | objective = 1.82815356 | step = 0.146535 | accepted = True
# success_probability = 0.54680000
# success_probability = 0.53900000
# success_probability = 0.54650000
# SPSA evaluation   243 | p_suc = 0.54650000 | objective = 1.82982617 | step = 0.035010 | accepted = True
# success_probability = 0.54820000
# success_probability = 0.53970000
# success_probability = 0.54670000
# SPSA evaluation   246 | p_suc = 0.54670000 | objective = 1.82915676 | step = 0.038006 | accepted = True
# success_probability = 0.53520000
# success_probability = 0.55160000
# success_probability = 0.54800000
# SPSA evaluation   249 | p_suc = 0.54800000 | objective = 1.82481752 | step = 0.073489 | accepted = True
# success_probability = 0.54710000
# success_probability = 0.54230000
# success_probability = 0.54770000
# SPSA evaluation   252 | p_suc = 0.54770000 | objective = 1.82581705 | step = 0.021402 | accepted = True
# success_probability = 0.55240000
# success_probability = 0.53580000
# success_probability = 0.54890000
# SPSA evaluation   255 | p_suc = 0.54890000 | objective = 1.82182547 | step = 0.074194 | accepted = True
# success_probability = 0.53330000
# success_probability = 0.55930000
# success_probability = 0.55170000
# SPSA evaluation   258 | p_suc = 0.55170000 | objective = 1.81257930 | step = 0.115312 | accepted = True
# success_probability = 0.56250000
# success_probability = 0.53840000
# success_probability = 0.55310000
# SPSA evaluation   261 | p_suc = 0.55310000 | objective = 1.80799132 | step = 0.105271 | accepted = True
# success_probability = 0.53750000
# success_probability = 0.56250000
# success_probability = 0.55470000
# SPSA evaluation   264 | p_suc = 0.55470000 | objective = 1.80277628 | step = 0.109385 | accepted = True
# success_probability = 0.55260000
# success_probability = 0.55310000
# success_probability = 0.55470000
# SPSA evaluation   267 | p_suc = 0.55470000 | objective = 1.80277628 | step = 0.002164 | accepted = True
# success_probability = 0.54930000
# success_probability = 0.55810000
# success_probability = 0.55500000
# SPSA evaluation   270 | p_suc = 0.55500000 | objective = 1.80180180 | step = 0.037973 | accepted = True
# success_probability = 0.55220000
# success_probability = 0.55800000
# success_probability = 0.55520000
# SPSA evaluation   273 | p_suc = 0.55520000 | objective = 1.80115274 | step = 0.024901 | accepted = True
# success_probability = 0.55910000
# success_probability = 0.54780000
# success_probability = 0.55470000
# SPSA evaluation   276 | p_suc = 0.55470000 | objective = 1.80277628 | step = 0.048807 | accepted = True
# success_probability = 0.55890000
# success_probability = 0.55040000
# success_probability = 0.55580000
# SPSA evaluation   279 | p_suc = 0.55580000 | objective = 1.79920835 | step = 0.036553 | accepted = True
# success_probability = 0.55290000
# success_probability = 0.55630000
# success_probability = 0.55560000
# SPSA evaluation   282 | p_suc = 0.55560000 | objective = 1.79985601 | step = 0.014623 | accepted = True
# success_probability = 0.56080000
# success_probability = 0.54810000
# success_probability = 0.55750000
# SPSA evaluation   285 | p_suc = 0.55750000 | objective = 1.79372197 | step = 0.054658 | accepted = True
# success_probability = 0.55760000
# success_probability = 0.55870000
# success_probability = 0.55760000
# SPSA evaluation   288 | p_suc = 0.55760000 | objective = 1.79340029 | step = 0.004671 | accepted = True
# success_probability = 0.57310000
# success_probability = 0.54040000
# success_probability = 0.56210000
# SPSA evaluation   291 | p_suc = 0.56210000 | objective = 1.77904287 | step = 0.139676 | accepted = True
# success_probability = 0.55320000
# success_probability = 0.56430000
# success_probability = 0.56240000
# SPSA evaluation   294 | p_suc = 0.56240000 | objective = 1.77809388 | step = 0.047038 | accepted = True
# success_probability = 0.55860000
# success_probability = 0.55880000
# success_probability = 0.56240000
# SPSA evaluation   297 | p_suc = 0.56240000 | objective = 1.77809388 | step = 0.000848 | accepted = True
# success_probability = 0.57180000
# success_probability = 0.55110000
# success_probability = 0.56410000
# SPSA evaluation   300 | p_suc = 0.56410000 | objective = 1.77273533 | step = 0.086899 | accepted = True
# success_probability = 0.55830000
# success_probability = 0.56170000
# success_probability = 0.56450000
# SPSA evaluation   303 | p_suc = 0.56450000 | objective = 1.77147919 | step = 0.014343 | accepted = True
# success_probability = 0.54970000
# success_probability = 0.57440000
# success_probability = 0.56550000
# SPSA evaluation   306 | p_suc = 0.56550000 | objective = 1.76834660 | step = 0.103485 | accepted = True
# success_probability = 0.56350000
# success_probability = 0.56400000
# success_probability = 0.56550000
# SPSA evaluation   309 | p_suc = 0.56550000 | objective = 1.76834660 | step = 0.002081 | accepted = True
# success_probability = 0.57090000
# success_probability = 0.55820000
# success_probability = 0.56680000
# SPSA evaluation   312 | p_suc = 0.56680000 | objective = 1.76429076 | step = 0.052720 | accepted = True
# success_probability = 0.57050000
# success_probability = 0.56280000
# success_probability = 0.56860000
# SPSA evaluation   315 | p_suc = 0.56860000 | objective = 1.75870559 | step = 0.031725 | accepted = True
# success_probability = 0.56800000
# success_probability = 0.55970000
# success_probability = 0.56650000
# SPSA evaluation   318 | p_suc = 0.56650000 | objective = 1.76522507 | step = 0.034538 | accepted = True
# success_probability = 0.56710000
# success_probability = 0.56340000
# success_probability = 0.56600000
# SPSA evaluation   321 | p_suc = 0.56600000 | objective = 1.76678445 | step = 0.015319 | accepted = True
# success_probability = 0.56050000
# success_probability = 0.56500000
# success_probability = 0.56690000
# SPSA evaluation   324 | p_suc = 0.56690000 | objective = 1.76397954 | step = 0.018798 | accepted = True
# success_probability = 0.56910000
# success_probability = 0.56120000
# success_probability = 0.56660000
# SPSA evaluation   327 | p_suc = 0.56660000 | objective = 1.76491352 | step = 0.032722 | accepted = True
# success_probability = 0.56940000
# success_probability = 0.56230000
# success_probability = 0.56590000
# SPSA evaluation   330 | p_suc = 0.56590000 | objective = 1.76709666 | step = 0.029335 | accepted = True
# success_probability = 0.56780000
# success_probability = 0.56490000
# success_probability = 0.56580000
# SPSA evaluation   333 | p_suc = 0.56580000 | objective = 1.76740898 | step = 0.011961 | accepted = True
# success_probability = 0.56230000
# success_probability = 0.56640000
# success_probability = 0.56620000
# SPSA evaluation   336 | p_suc = 0.56620000 | objective = 1.76616037 | step = 0.017030 | accepted = True
# success_probability = 0.57520000
# success_probability = 0.55840000
# success_probability = 0.56890000
# SPSA evaluation   339 | p_suc = 0.56890000 | objective = 1.75777817 | step = 0.069193 | accepted = True
# success_probability = 0.57160000
# success_probability = 0.56140000
# success_probability = 0.56990000
# SPSA evaluation   342 | p_suc = 0.56990000 | objective = 1.75469381 | step = 0.042049 | accepted = True
# success_probability = 0.55090000
# success_probability = 0.58090000
# success_probability = 0.57350000
# SPSA evaluation   345 | p_suc = 0.57350000 | objective = 1.74367916 | step = 0.124013 | accepted = True
# success_probability = 0.57600000
# success_probability = 0.56680000
# success_probability = 0.57330000
# SPSA evaluation   348 | p_suc = 0.57330000 | objective = 1.74428746 | step = 0.037278 | accepted = True
# success_probability = 0.58950000
# success_probability = 0.55410000
# success_probability = 0.57730000
# SPSA evaluation   351 | p_suc = 0.57730000 | objective = 1.73220163 | step = 0.143367 | accepted = True
# success_probability = 0.58130000
# success_probability = 0.56720000
# success_probability = 0.57890000
# SPSA evaluation   354 | p_suc = 0.57890000 | objective = 1.72741406 | step = 0.056572 | accepted = True
# success_probability = 0.59170000
# success_probability = 0.56270000
# success_probability = 0.58310000
# SPSA evaluation   357 | p_suc = 0.58310000 | objective = 1.71497170 | step = 0.115223 | accepted = True
# success_probability = 0.57500000
# success_probability = 0.58120000
# success_probability = 0.58300000
# SPSA evaluation   360 | p_suc = 0.58300000 | objective = 1.71526587 | step = 0.024542 | accepted = True
# success_probability = 0.57350000
# success_probability = 0.58810000
# success_probability = 0.58400000
# SPSA evaluation   363 | p_suc = 0.58400000 | objective = 1.71232877 | step = 0.057265 | accepted = True
# success_probability = 0.57790000
# success_probability = 0.58150000
# success_probability = 0.58380000
# SPSA evaluation   366 | p_suc = 0.58380000 | objective = 1.71291538 | step = 0.014172 | accepted = True
# success_probability = 0.56560000
# success_probability = 0.59530000
# success_probability = 0.58680000
# SPSA evaluation   369 | p_suc = 0.58680000 | objective = 1.70415815 | step = 0.116689 | accepted = True
# success_probability = 0.58140000
# success_probability = 0.58270000
# success_probability = 0.58680000
# SPSA evaluation   372 | p_suc = 0.58680000 | objective = 1.70415815 | step = 0.005076 | accepted = True
# success_probability = 0.59520000
# success_probability = 0.57300000
# success_probability = 0.58840000
# SPSA evaluation   375 | p_suc = 0.58840000 | objective = 1.69952413 | step = 0.086110 | accepted = True
# success_probability = 0.57490000
# success_probability = 0.59480000
# success_probability = 0.58970000
# SPSA evaluation   378 | p_suc = 0.58970000 | objective = 1.69577751 | step = 0.076985 | accepted = True
# success_probability = 0.58920000
# success_probability = 0.58190000
# success_probability = 0.59050000
# SPSA evaluation   381 | p_suc = 0.59050000 | objective = 1.69348010 | step = 0.028166 | accepted = True
# success_probability = 0.59140000
# success_probability = 0.57900000
# success_probability = 0.59010000
# SPSA evaluation   384 | p_suc = 0.59010000 | objective = 1.69462803 | step = 0.047905 | accepted = True
# success_probability = 0.59940000
# success_probability = 0.57490000
# success_probability = 0.59160000
# SPSA evaluation   387 | p_suc = 0.59160000 | objective = 1.69033130 | step = 0.094054 | accepted = True
# success_probability = 0.59120000
# success_probability = 0.58570000
# success_probability = 0.59180000
# SPSA evaluation   390 | p_suc = 0.59180000 | objective = 1.68976005 | step = 0.021012 | accepted = True
# success_probability = 0.59840000
# success_probability = 0.58060000
# success_probability = 0.59150000
# SPSA evaluation   393 | p_suc = 0.59150000 | objective = 1.69061708 | step = 0.067775 | accepted = True
# success_probability = 0.60940000
# success_probability = 0.57190000
# success_probability = 0.59640000
# SPSA evaluation   396 | p_suc = 0.59640000 | objective = 1.67672703 | step = 0.142340 | accepted = True
# success_probability = 0.58230000
# success_probability = 0.60590000
# success_probability = 0.59850000
# SPSA evaluation   399 | p_suc = 0.59850000 | objective = 1.67084378 | step = 0.088488 | accepted = True
# success_probability = 0.59340000
# success_probability = 0.59930000
# success_probability = 0.59800000
# SPSA evaluation   402 | p_suc = 0.59800000 | objective = 1.67224080 | step = 0.021947 | accepted = True
# success_probability = 0.59760000
# success_probability = 0.59630000
# success_probability = 0.59780000
# SPSA evaluation   405 | p_suc = 0.59780000 | objective = 1.67280027 | step = 0.004826 | accepted = True
# success_probability = 0.57580000
# success_probability = 0.62000000
# success_probability = 0.60370000
# SPSA evaluation   408 | p_suc = 0.60370000 | objective = 1.65645188 | step = 0.163786 | accepted = True
# success_probability = 0.59950000
# success_probability = 0.60640000
# success_probability = 0.60430000
# SPSA evaluation   411 | p_suc = 0.60430000 | objective = 1.65480721 | step = 0.025108 | accepted = True
# success_probability = 0.60520000
# success_probability = 0.60350000
# success_probability = 0.60460000
# SPSA evaluation   414 | p_suc = 0.60460000 | objective = 1.65398611 | step = 0.006157 | accepted = True
# success_probability = 0.59340000
# success_probability = 0.60950000
# success_probability = 0.60410000
# SPSA evaluation   417 | p_suc = 0.60410000 | objective = 1.65535507 | step = 0.058888 | accepted = True
# success_probability = 0.60260000
# success_probability = 0.60400000
# success_probability = 0.60420000
# SPSA evaluation   420 | p_suc = 0.60420000 | objective = 1.65508110 | step = 0.005088 | accepted = True
# success_probability = 0.61990000
# success_probability = 0.59280000
# success_probability = 0.60810000
# SPSA evaluation   423 | p_suc = 0.60810000 | objective = 1.64446637 | step = 0.097557 | accepted = True
# success_probability = 0.61790000
# success_probability = 0.59850000
# success_probability = 0.60960000
# SPSA evaluation   426 | p_suc = 0.60960000 | objective = 1.64041995 | step = 0.069397 | accepted = True
# success_probability = 0.60870000
# success_probability = 0.60970000
# success_probability = 0.61000000
# SPSA evaluation   429 | p_suc = 0.61000000 | objective = 1.63934426 | step = 0.003565 | accepted = True
# success_probability = 0.61410000
# success_probability = 0.60970000
# success_probability = 0.61060000
# SPSA evaluation   432 | p_suc = 0.61060000 | objective = 1.63773338 | step = 0.015546 | accepted = True
# success_probability = 0.59570000
# success_probability = 0.61970000
# success_probability = 0.61180000
# SPSA evaluation   435 | p_suc = 0.61180000 | objective = 1.63452109 | step = 0.086004 | accepted = True
# success_probability = 0.59450000
# success_probability = 0.62420000
# success_probability = 0.61410000
# SPSA evaluation   438 | p_suc = 0.61410000 | objective = 1.62839928 | step = 0.105877 | accepted = True
# success_probability = 0.63590000
# success_probability = 0.59650000
# success_probability = 0.61880000
# SPSA evaluation   441 | p_suc = 0.61880000 | objective = 1.61603103 | step = 0.137409 | accepted = True
# success_probability = 0.61470000
# success_probability = 0.61970000
# success_probability = 0.61890000
# SPSA evaluation   444 | p_suc = 0.61890000 | objective = 1.61576991 | step = 0.017364 | accepted = True
# success_probability = 0.64210000
# success_probability = 0.59870000
# success_probability = 0.62710000
# SPSA evaluation   447 | p_suc = 0.62710000 | objective = 1.59464200 | step = 0.149347 | accepted = True
# success_probability = 0.63910000
# success_probability = 0.61010000
# success_probability = 0.62990000
# SPSA evaluation   450 | p_suc = 0.62990000 | objective = 1.58755358 | step = 0.098389 | accepted = True
# success_probability = 0.61250000
# success_probability = 0.64070000
# success_probability = 0.63210000
# SPSA evaluation   453 | p_suc = 0.63210000 | objective = 1.58202816 | step = 0.095062 | accepted = True
# success_probability = 0.64270000
# success_probability = 0.61310000
# success_probability = 0.63450000
# SPSA evaluation   456 | p_suc = 0.63450000 | objective = 1.57604413 | step = 0.099374 | accepted = True
# success_probability = 0.62860000
# success_probability = 0.63060000
# success_probability = 0.63450000
# SPSA evaluation   459 | p_suc = 0.63450000 | objective = 1.57604413 | step = 0.006675 | accepted = True
# success_probability = 0.63260000
# success_probability = 0.62860000
# success_probability = 0.63430000
# SPSA evaluation   462 | p_suc = 0.63430000 | objective = 1.57654107 | step = 0.013307 | accepted = True
# success_probability = 0.62660000
# success_probability = 0.63510000
# success_probability = 0.63590000
# SPSA evaluation   465 | p_suc = 0.63590000 | objective = 1.57257430 | step = 0.028256 | accepted = True
# success_probability = 0.62180000
# success_probability = 0.64090000
# success_probability = 0.63570000
# SPSA evaluation   468 | p_suc = 0.63570000 | objective = 1.57306906 | step = 0.063403 | accepted = True
# success_probability = 0.63470000
# success_probability = 0.63000000
# success_probability = 0.63580000
# SPSA evaluation   471 | p_suc = 0.63580000 | objective = 1.57282164 | step = 0.015549 | accepted = True
# success_probability = 0.64390000
# success_probability = 0.62380000
# success_probability = 0.63830000
# SPSA evaluation   474 | p_suc = 0.63830000 | objective = 1.56666144 | step = 0.066199 | accepted = True
# success_probability = 0.64350000
# success_probability = 0.62460000
# success_probability = 0.63930000
# SPSA evaluation   477 | p_suc = 0.63930000 | objective = 1.56421086 | step = 0.062206 | accepted = True
# success_probability = 0.64220000
# success_probability = 0.62760000
# success_probability = 0.64030000
# SPSA evaluation   480 | p_suc = 0.64030000 | objective = 1.56176792 | step = 0.047920 | accepted = True
# success_probability = 0.63610000
# success_probability = 0.63380000
# success_probability = 0.64010000
# SPSA evaluation   483 | p_suc = 0.64010000 | objective = 1.56225590 | step = 0.007547 | accepted = True
# success_probability = 0.64310000
# success_probability = 0.62690000
# success_probability = 0.64020000
# SPSA evaluation   486 | p_suc = 0.64020000 | objective = 1.56201187 | step = 0.053157 | accepted = True
# success_probability = 0.63970000
# success_probability = 0.63280000
# success_probability = 0.64020000
# SPSA evaluation   489 | p_suc = 0.64020000 | objective = 1.56201187 | step = 0.022549 | accepted = True
# success_probability = 0.63630000
# success_probability = 0.63210000
# success_probability = 0.64020000
# SPSA evaluation   492 | p_suc = 0.64020000 | objective = 1.56201187 | step = 0.013814 | accepted = True
# success_probability = 0.63440000
# success_probability = 0.63640000
# success_probability = 0.64030000
# SPSA evaluation   495 | p_suc = 0.64030000 | objective = 1.56176792 | step = 0.006553 | accepted = True
# success_probability = 0.63700000
# success_probability = 0.63300000
# success_probability = 0.64000000
# SPSA evaluation   498 | p_suc = 0.64000000 | objective = 1.56250000 | step = 0.013123 | accepted = True
# success_probability = 0.62640000
# success_probability = 0.64520000
# success_probability = 0.64120000
# SPSA evaluation   501 | p_suc = 0.64120000 | objective = 1.55957580 | step = 0.061536 | accepted = True
# success_probability = 0.63330000
# success_probability = 0.63990000
# success_probability = 0.64160000
# SPSA evaluation   504 | p_suc = 0.64160000 | objective = 1.55860349 | step = 0.021545 | accepted = True
# success_probability = 0.62000000
# success_probability = 0.65400000
# success_probability = 0.64440000
# SPSA evaluation   507 | p_suc = 0.64440000 | objective = 1.55183116 | step = 0.110925 | accepted = True
# success_probability = 0.62350000
# success_probability = 0.66150000
# success_probability = 0.64750000
# SPSA evaluation   510 | p_suc = 0.64750000 | objective = 1.54440154 | step = 0.121881 | accepted = True
# success_probability = 0.64280000
# success_probability = 0.64730000
# success_probability = 0.64840000
# SPSA evaluation   513 | p_suc = 0.64840000 | objective = 1.54225787 | step = 0.014307 | accepted = True
# success_probability = 0.65660000
# success_probability = 0.63500000
# success_probability = 0.65010000
# SPSA evaluation   516 | p_suc = 0.65010000 | objective = 1.53822489 | step = 0.068533 | accepted = True
# success_probability = 0.65530000
# success_probability = 0.63580000
# success_probability = 0.65090000
# SPSA evaluation   519 | p_suc = 0.65090000 | objective = 1.53633431 | step = 0.061915 | accepted = True
# success_probability = 0.63660000
# success_probability = 0.65530000
# success_probability = 0.65270000
# SPSA evaluation   522 | p_suc = 0.65270000 | objective = 1.53209744 | step = 0.059300 | accepted = True
# success_probability = 0.62420000
# success_probability = 0.67520000
# success_probability = 0.66200000
# SPSA evaluation   525 | p_suc = 0.66200000 | objective = 1.51057402 | step = 0.160078 | accepted = True
# success_probability = 0.66920000
# success_probability = 0.64540000
# success_probability = 0.66370000
# SPSA evaluation   528 | p_suc = 0.66370000 | objective = 1.50670484 | step = 0.072897 | accepted = True
# success_probability = 0.64340000
# success_probability = 0.67070000
# success_probability = 0.66640000
# SPSA evaluation   531 | p_suc = 0.66640000 | objective = 1.50060024 | step = 0.083690 | accepted = True
# success_probability = 0.67170000
# success_probability = 0.65270000
# success_probability = 0.66750000
# SPSA evaluation   534 | p_suc = 0.66750000 | objective = 1.49812734 | step = 0.057330 | accepted = True
# success_probability = 0.65740000
# success_probability = 0.66560000
# success_probability = 0.66740000
# SPSA evaluation   537 | p_suc = 0.66740000 | objective = 1.49835181 | step = 0.024791 | accepted = True
# success_probability = 0.66330000
# success_probability = 0.66100000
# success_probability = 0.66690000
# SPSA evaluation   540 | p_suc = 0.66690000 | objective = 1.49947518 | step = 0.006940 | accepted = True
# success_probability = 0.65610000
# success_probability = 0.66880000
# success_probability = 0.66790000
# SPSA evaluation   543 | p_suc = 0.66790000 | objective = 1.49723012 | step = 0.038287 | accepted = True
# success_probability = 0.63670000
# success_probability = 0.68880000
# success_probability = 0.67520000
# SPSA evaluation   546 | p_suc = 0.67520000 | objective = 1.48104265 | step = 0.157155 | accepted = True
# success_probability = 0.66980000
# success_probability = 0.66580000
# success_probability = 0.67500000
# SPSA evaluation   549 | p_suc = 0.67500000 | objective = 1.48148148 | step = 0.011866 | accepted = True
# success_probability = 0.68070000
# success_probability = 0.65770000
# success_probability = 0.67610000
# SPSA evaluation   552 | p_suc = 0.67610000 | objective = 1.47907114 | step = 0.067962 | accepted = True
# success_probability = 0.67530000
# success_probability = 0.66960000
# success_probability = 0.67590000
# SPSA evaluation   555 | p_suc = 0.67590000 | objective = 1.47950880 | step = 0.016676 | accepted = True
# success_probability = 0.66960000
# success_probability = 0.67130000
# success_probability = 0.67590000
# SPSA evaluation   558 | p_suc = 0.67590000 | objective = 1.47950880 | step = 0.005003 | accepted = True
# success_probability = 0.66850000
# success_probability = 0.67030000
# success_probability = 0.67580000
# SPSA evaluation   561 | p_suc = 0.67580000 | objective = 1.47972773 | step = 0.005314 | accepted = True
# success_probability = 0.67380000
# success_probability = 0.66400000
# success_probability = 0.67630000
# SPSA evaluation   564 | p_suc = 0.67630000 | objective = 1.47863374 | step = 0.028977 | accepted = True
# success_probability = 0.66740000
# success_probability = 0.67270000
# success_probability = 0.67600000
# SPSA evaluation   567 | p_suc = 0.67600000 | objective = 1.47928994 | step = 0.015617 | accepted = True
# success_probability = 0.67660000
# success_probability = 0.66460000
# success_probability = 0.67640000
# SPSA evaluation   570 | p_suc = 0.67640000 | objective = 1.47841514 | step = 0.035303 | accepted = True
# success_probability = 0.68690000
# success_probability = 0.66080000
# success_probability = 0.67840000
# SPSA evaluation   573 | p_suc = 0.67840000 | objective = 1.47405660 | step = 0.076067 | accepted = True
# success_probability = 0.64740000
# success_probability = 0.70010000
# success_probability = 0.68590000
# SPSA evaluation   576 | p_suc = 0.68590000 | objective = 1.45793847 | step = 0.153814 | accepted = True
# success_probability = 0.69670000
# success_probability = 0.65900000
# success_probability = 0.68900000
# SPSA evaluation   579 | p_suc = 0.68900000 | objective = 1.45137881 | step = 0.108625 | accepted = True
# success_probability = 0.66170000
# success_probability = 0.70640000
# success_probability = 0.69420000
# SPSA evaluation   582 | p_suc = 0.69420000 | objective = 1.44050706 | step = 0.126507 | accepted = True
# success_probability = 0.67610000
# success_probability = 0.69970000
# success_probability = 0.69530000
# SPSA evaluation   585 | p_suc = 0.69530000 | objective = 1.43822810 | step = 0.065995 | accepted = True
# success_probability = 0.69900000
# success_probability = 0.68000000
# success_probability = 0.69740000
# SPSA evaluation   588 | p_suc = 0.69740000 | objective = 1.43389733 | step = 0.052879 | accepted = True
# success_probability = 0.71060000
# success_probability = 0.67380000
# success_probability = 0.70100000
# SPSA evaluation   591 | p_suc = 0.70100000 | objective = 1.42653352 | step = 0.101674 | accepted = True
# success_probability = 0.70690000
# success_probability = 0.68120000
# success_probability = 0.70220000
# SPSA evaluation   594 | p_suc = 0.70220000 | objective = 1.42409570 | step = 0.070602 | accepted = True
# success_probability = 0.71490000
# success_probability = 0.67520000
# success_probability = 0.70520000
# SPSA evaluation   597 | p_suc = 0.70520000 | objective = 1.41803744 | step = 0.108801 | accepted = True
# success_probability = 0.69650000
# success_probability = 0.70160000
# success_probability = 0.70520000
# SPSA evaluation   600 | p_suc = 0.70520000 | objective = 1.41803744 | step = 0.013806 | accepted = True
# success_probability = 0.69780000
# success_probability = 0.70420000
# success_probability = 0.70570000
# SPSA evaluation   603 | p_suc = 0.70570000 | objective = 1.41703273 | step = 0.017229 | accepted = True
# success_probability = 0.71690000
# success_probability = 0.68180000
# success_probability = 0.70790000
# SPSA evaluation   606 | p_suc = 0.70790000 | objective = 1.41262890 | step = 0.094997 | accepted = True
# success_probability = 0.71310000
# success_probability = 0.69030000
# success_probability = 0.70990000
# SPSA evaluation   609 | p_suc = 0.70990000 | objective = 1.40864911 | step = 0.061272 | accepted = True
# success_probability = 0.70050000
# success_probability = 0.70520000
# success_probability = 0.71000000
# SPSA evaluation   612 | p_suc = 0.71000000 | objective = 1.40845070 | step = 0.012586 | accepted = True
# success_probability = 0.69110000
# success_probability = 0.71400000
# success_probability = 0.71150000
# SPSA evaluation   615 | p_suc = 0.71150000 | objective = 1.40548138 | step = 0.061393 | accepted = True
# success_probability = 0.69510000
# success_probability = 0.71320000
# success_probability = 0.71290000
# SPSA evaluation   618 | p_suc = 0.71290000 | objective = 1.40272128 | step = 0.048299 | accepted = True
# success_probability = 0.69740000
# success_probability = 0.71370000
# success_probability = 0.71230000
# SPSA evaluation   621 | p_suc = 0.71230000 | objective = 1.40390285 | step = 0.043322 | accepted = True
# success_probability = 0.70680000
# success_probability = 0.70530000
# success_probability = 0.71220000
# SPSA evaluation   624 | p_suc = 0.71220000 | objective = 1.40409997 | step = 0.003981 | accepted = True
# success_probability = 0.67570000
# success_probability = 0.73560000
# success_probability = 0.72020000
# SPSA evaluation   627 | p_suc = 0.72020000 | objective = 1.38850319 | step = 0.159423 | accepted = True
# success_probability = 0.71500000
# success_probability = 0.71470000
# success_probability = 0.72030000
# SPSA evaluation   630 | p_suc = 0.72030000 | objective = 1.38831043 | step = 0.000777 | accepted = True
# success_probability = 0.72240000
# success_probability = 0.69980000
# success_probability = 0.72160000
# SPSA evaluation   633 | p_suc = 0.72160000 | objective = 1.38580931 | step = 0.059139 | accepted = True
# success_probability = 0.71260000
# success_probability = 0.71980000
# success_probability = 0.72170000
# SPSA evaluation   636 | p_suc = 0.72170000 | objective = 1.38561729 | step = 0.018569 | accepted = True
# success_probability = 0.70250000
# success_probability = 0.73200000
# success_probability = 0.72350000
# SPSA evaluation   639 | p_suc = 0.72350000 | objective = 1.38217001 | step = 0.075890 | accepted = True
# success_probability = 0.72810000
# success_probability = 0.70690000
# success_probability = 0.72520000
# SPSA evaluation   642 | p_suc = 0.72520000 | objective = 1.37892995 | step = 0.054489 | accepted = True
# success_probability = 0.73960000
# success_probability = 0.69680000
# success_probability = 0.72860000
# SPSA evaluation   645 | p_suc = 0.72860000 | objective = 1.37249520 | step = 0.109865 | accepted = True
# success_probability = 0.71770000
# success_probability = 0.72860000
# success_probability = 0.72950000
# SPSA evaluation   648 | p_suc = 0.72950000 | objective = 1.37080192 | step = 0.027575 | accepted = True
# success_probability = 0.72470000
# success_probability = 0.72120000
# success_probability = 0.72960000
# SPSA evaluation   651 | p_suc = 0.72960000 | objective = 1.37061404 | step = 0.008859 | accepted = True
# success_probability = 0.72360000
# success_probability = 0.72580000
# success_probability = 0.72910000
# SPSA evaluation   654 | p_suc = 0.72910000 | objective = 1.37155397 | step = 0.005541 | accepted = True
# success_probability = 0.72290000
# success_probability = 0.72040000
# success_probability = 0.72930000
# SPSA evaluation   657 | p_suc = 0.72930000 | objective = 1.37117784 | step = 0.006350 | accepted = True
# success_probability = 0.71410000
# success_probability = 0.73320000
# success_probability = 0.73030000
# SPSA evaluation   660 | p_suc = 0.73030000 | objective = 1.36930029 | step = 0.048258 | accepted = True
# success_probability = 0.72710000
# success_probability = 0.72260000
# success_probability = 0.73080000
# SPSA evaluation   663 | p_suc = 0.73080000 | objective = 1.36836344 | step = 0.011330 | accepted = True
# success_probability = 0.70840000
# success_probability = 0.73690000
# success_probability = 0.73200000
# SPSA evaluation   666 | p_suc = 0.73200000 | objective = 1.36612022 | step = 0.072223 | accepted = True
# success_probability = 0.71730000
# success_probability = 0.73230000
# success_probability = 0.73260000
# SPSA evaluation   669 | p_suc = 0.73260000 | objective = 1.36500137 | step = 0.037776 | accepted = True
# success_probability = 0.72910000
# success_probability = 0.72580000
# success_probability = 0.73300000
# SPSA evaluation   672 | p_suc = 0.73300000 | objective = 1.36425648 | step = 0.008250 | accepted = True
# success_probability = 0.72680000
# success_probability = 0.72450000
# success_probability = 0.73280000
# SPSA evaluation   675 | p_suc = 0.73280000 | objective = 1.36462882 | step = 0.005778 | accepted = True
# success_probability = 0.72200000
# success_probability = 0.73140000
# success_probability = 0.73280000
# SPSA evaluation   678 | p_suc = 0.73280000 | objective = 1.36462882 | step = 0.023548 | accepted = True
# success_probability = 0.71580000
# success_probability = 0.73510000
# success_probability = 0.73300000
# SPSA evaluation   681 | p_suc = 0.73300000 | objective = 1.36425648 | step = 0.048522 | accepted = True
# success_probability = 0.73250000
# success_probability = 0.72610000
# success_probability = 0.73390000
# SPSA evaluation   684 | p_suc = 0.73390000 | objective = 1.36258346 | step = 0.015918 | accepted = True
# success_probability = 0.74080000
# success_probability = 0.71420000
# success_probability = 0.73660000
# SPSA evaluation   687 | p_suc = 0.73660000 | objective = 1.35758892 | step = 0.066509 | accepted = True
# success_probability = 0.71250000
# success_probability = 0.75200000
# success_probability = 0.73870000
# SPSA evaluation   690 | p_suc = 0.73870000 | objective = 1.35372952 | step = 0.097524 | accepted = True
# success_probability = 0.71820000
# success_probability = 0.75020000
# success_probability = 0.74140000
# SPSA evaluation   693 | p_suc = 0.74140000 | objective = 1.34879957 | step = 0.078568 | accepted = True
# success_probability = 0.73030000
# success_probability = 0.73800000
# success_probability = 0.74100000
# SPSA evaluation   696 | p_suc = 0.74100000 | objective = 1.34952767 | step = 0.018900 | accepted = True
# success_probability = 0.72950000
# success_probability = 0.73950000
# success_probability = 0.74160000
# SPSA evaluation   699 | p_suc = 0.74160000 | objective = 1.34843581 | step = 0.024522 | accepted = True
# success_probability = 0.74550000
# ...
# success_probability = 0.81300000
# success_probability = 0.81950000
# success_probability = 0.82420000
# SPSA evaluation  1773 | p_suc = 0.82420000 | objective = 1.21329774 | step = 0.012906 | accepted = True
# success_probability = 0.81480000
# success_probability = 0.81740000
# success_probability = 0.82430000
# SPSA evaluation  1776 | p_suc = 0.82430000 | objective = 1.21315055 | step = 0.005164 | accepted = True
# success_probability = 0.81760000
# success_probability = 0.81470000
# success_probability = 0.82440000
# SPSA evaluation  1779 | p_suc = 0.82440000 | objective = 1.21300340 | step = 0.005759 | accepted = True
# success_probability = 0.81580000
# success_probability = 0.81560000
# success_probability = 0.82440000
# SPSA evaluation  1782 | p_suc = 0.82440000 | objective = 1.21300340 | step = 0.000398 | accepted = True
# success_probability = 0.81650000
# success_probability = 0.81600000
# success_probability = 0.82430000
# SPSA evaluation  1785 | p_suc = 0.82430000 | objective = 1.21315055 | step = 0.000993 | accepted = True
# success_probability = 0.81780000
# success_probability = 0.81410000
# success_probability = 0.82420000
# SPSA evaluation  1788 | p_suc = 0.82420000 | objective = 1.21329774 | step = 0.007352 | accepted = True
# success_probability = 0.81540000
# success_probability = 0.81770000
# success_probability = 0.82400000
# SPSA evaluation  1791 | p_suc = 0.82400000 | objective = 1.21359223 | step = 0.004563 | accepted = True
# success_probability = 0.81660000
# success_probability = 0.81920000
# success_probability = 0.82370000
# SPSA evaluation  1794 | p_suc = 0.82370000 | objective = 1.21403424 | step = 0.005142 | accepted = True
# success_probability = 0.81420000
# success_probability = 0.81670000
# success_probability = 0.82390000
# SPSA evaluation  1797 | p_suc = 0.82390000 | objective = 1.21373953 | step = 0.004974 | accepted = True
# success_probability = 0.81480000
# success_probability = 0.81910000
# success_probability = 0.82400000
# SPSA evaluation  1800 | p_suc = 0.82400000 | objective = 1.21359223 | step = 0.008523 | accepted = True
# success_probability = 0.81450000
# success_probability = 0.81600000
# success_probability = 0.82390000
# SPSA evaluation  1803 | p_suc = 0.82390000 | objective = 1.21373953 | step = 0.002986 | accepted = True
# success_probability = 0.81800000
# success_probability = 0.81500000
# success_probability = 0.82400000
# SPSA evaluation  1806 | p_suc = 0.82400000 | objective = 1.21359223 | step = 0.005953 | accepted = True
# success_probability = 0.81510000
# success_probability = 0.81900000
# success_probability = 0.82410000
# SPSA evaluation  1809 | p_suc = 0.82410000 | objective = 1.21344497 | step = 0.007728 | accepted = True
# success_probability = 0.81650000
# success_probability = 0.81590000
# success_probability = 0.82410000
# SPSA evaluation  1812 | p_suc = 0.82410000 | objective = 1.21344497 | step = 0.001191 | accepted = True
# success_probability = 0.82020000
# success_probability = 0.81470000
# success_probability = 0.82410000
# SPSA evaluation  1815 | p_suc = 0.82410000 | objective = 1.21344497 | step = 0.010888 | accepted = True
# success_probability = 0.81470000
# success_probability = 0.82020000
# success_probability = 0.82460000
# SPSA evaluation  1818 | p_suc = 0.82460000 | objective = 1.21270919 | step = 0.010888 | accepted = True
# success_probability = 0.81580000
# success_probability = 0.81890000
# success_probability = 0.82420000
# SPSA evaluation  1821 | p_suc = 0.82420000 | objective = 1.21329774 | step = 0.006139 | accepted = True
# success_probability = 0.81520000
# success_probability = 0.81840000
# success_probability = 0.82400000
# SPSA evaluation  1824 | p_suc = 0.82400000 | objective = 1.21359223 | step = 0.006345 | accepted = True
# success_probability = 0.81480000
# success_probability = 0.82130000
# success_probability = 0.82450000
# SPSA evaluation  1827 | p_suc = 0.82450000 | objective = 1.21285628 | step = 0.012849 | accepted = True
# success_probability = 0.82110000
# success_probability = 0.81530000
# success_probability = 0.82450000
# SPSA evaluation  1830 | p_suc = 0.82450000 | objective = 1.21285628 | step = 0.011461 | accepted = True
# success_probability = 0.81650000
# success_probability = 0.81910000
# success_probability = 0.82430000
# SPSA evaluation  1833 | p_suc = 0.82430000 | objective = 1.21315055 | step = 0.005143 | accepted = True
# success_probability = 0.81250000
# success_probability = 0.82050000
# success_probability = 0.82490000
# SPSA evaluation  1836 | p_suc = 0.82490000 | objective = 1.21226815 | step = 0.015875 | accepted = True
# success_probability = 0.81590000
# success_probability = 0.81970000
# success_probability = 0.82530000
# SPSA evaluation  1839 | p_suc = 0.82530000 | objective = 1.21168060 | step = 0.007516 | accepted = True
# success_probability = 0.81600000
# success_probability = 0.82070000
# success_probability = 0.82530000
# SPSA evaluation  1842 | p_suc = 0.82530000 | objective = 1.21168060 | step = 0.009284 | accepted = True
# success_probability = 0.81790000
# success_probability = 0.81280000
# success_probability = 0.82510000
# SPSA evaluation  1845 | p_suc = 0.82510000 | objective = 1.21197431 | step = 0.010149 | accepted = True
# success_probability = 0.81890000
# success_probability = 0.81470000
# success_probability = 0.82490000
# SPSA evaluation  1848 | p_suc = 0.82490000 | objective = 1.21226815 | step = 0.008328 | accepted = True
# success_probability = 0.82070000
# success_probability = 0.81370000
# success_probability = 0.82540000
# SPSA evaluation  1851 | p_suc = 0.82540000 | objective = 1.21153380 | step = 0.013867 | accepted = True
# success_probability = 0.81870000
# success_probability = 0.81680000
# success_probability = 0.82540000
# SPSA evaluation  1854 | p_suc = 0.82540000 | objective = 1.21153380 | step = 0.003759 | accepted = True
# success_probability = 0.81820000
# success_probability = 0.81550000
# success_probability = 0.82560000
# SPSA evaluation  1857 | p_suc = 0.82560000 | objective = 1.21124031 | step = 0.005353 | accepted = True
# success_probability = 0.81440000
# success_probability = 0.82210000
# success_probability = 0.82540000
# SPSA evaluation  1860 | p_suc = 0.82540000 | objective = 1.21153380 | step = 0.015214 | accepted = True
# success_probability = 0.81820000
# success_probability = 0.81750000
# success_probability = 0.82560000
# SPSA evaluation  1863 | p_suc = 0.82560000 | objective = 1.21124031 | step = 0.001384 | accepted = True
# success_probability = 0.81600000
# success_probability = 0.81920000
# success_probability = 0.82550000
# SPSA evaluation  1866 | p_suc = 0.82550000 | objective = 1.21138704 | step = 0.006333 | accepted = True
# success_probability = 0.82080000
# success_probability = 0.81510000
# success_probability = 0.82560000
# SPSA evaluation  1869 | p_suc = 0.82560000 | objective = 1.21124031 | step = 0.011271 | accepted = True
# success_probability = 0.81350000
# success_probability = 0.81980000
# success_probability = 0.82550000
# SPSA evaluation  1872 | p_suc = 0.82550000 | objective = 1.21138704 | step = 0.012497 | accepted = True
# success_probability = 0.81790000
# success_probability = 0.81900000
# success_probability = 0.82550000
# SPSA evaluation  1875 | p_suc = 0.82550000 | objective = 1.21138704 | step = 0.002172 | accepted = True
# success_probability = 0.82090000
# success_probability = 0.81670000
# success_probability = 0.82540000
# SPSA evaluation  1878 | p_suc = 0.82540000 | objective = 1.21153380 | step = 0.008287 | accepted = True
# success_probability = 0.81440000
# success_probability = 0.82020000
# success_probability = 0.82580000
# SPSA evaluation  1881 | p_suc = 0.82580000 | objective = 1.21094696 | step = 0.011487 | accepted = True
# success_probability = 0.82080000
# success_probability = 0.81230000
# success_probability = 0.82560000
# SPSA evaluation  1884 | p_suc = 0.82560000 | objective = 1.21124031 | step = 0.016865 | accepted = True
# success_probability = 0.81840000
# success_probability = 0.81840000
# success_probability = 0.82560000
# SPSA evaluation  1887 | p_suc = 0.82560000 | objective = 1.21124031 | step = 0.000000 | accepted = True
# success_probability = 0.81610000
# success_probability = 0.81970000
# success_probability = 0.82550000
# SPSA evaluation  1890 | p_suc = 0.82550000 | objective = 1.21138704 | step = 0.007119 | accepted = True
# success_probability = 0.81890000
# success_probability = 0.81760000
# success_probability = 0.82540000
# SPSA evaluation  1893 | p_suc = 0.82540000 | objective = 1.21153380 | step = 0.002569 | accepted = True
# success_probability = 0.82130000
# success_probability = 0.81640000
# success_probability = 0.82560000
# SPSA evaluation  1896 | p_suc = 0.82560000 | objective = 1.21124031 | step = 0.009667 | accepted = True
# success_probability = 0.82160000
# success_probability = 0.81240000
# success_probability = 0.82530000
# SPSA evaluation  1899 | p_suc = 0.82530000 | objective = 1.21168060 | step = 0.018234 | accepted = True
# success_probability = 0.82110000
# success_probability = 0.81690000
# success_probability = 0.82550000
# SPSA evaluation  1902 | p_suc = 0.82550000 | objective = 1.21138704 | step = 0.008283 | accepted = True
# success_probability = 0.81620000
# success_probability = 0.81850000
# success_probability = 0.82520000
# SPSA evaluation  1905 | p_suc = 0.82520000 | objective = 1.21182744 | step = 0.004554 | accepted = True
# success_probability = 0.81360000
# success_probability = 0.82500000
# success_probability = 0.82590000
# SPSA evaluation  1908 | p_suc = 0.82590000 | objective = 1.21080034 | step = 0.022468 | accepted = True
# success_probability = 0.81740000
# success_probability = 0.82260000
# success_probability = 0.82580000
# SPSA evaluation  1911 | p_suc = 0.82580000 | objective = 1.21094696 | step = 0.010231 | accepted = True
# success_probability = 0.81680000
# success_probability = 0.81990000
# success_probability = 0.82590000
# SPSA evaluation  1914 | p_suc = 0.82590000 | objective = 1.21080034 | step = 0.006124 | accepted = True
# success_probability = 0.81510000
# success_probability = 0.82270000
# success_probability = 0.82580000
# SPSA evaluation  1917 | p_suc = 0.82580000 | objective = 1.21094696 | step = 0.014993 | accepted = True
# success_probability = 0.81130000
# success_probability = 0.82090000
# success_probability = 0.82580000
# SPSA evaluation  1920 | p_suc = 0.82580000 | objective = 1.21094696 | step = 0.019069 | accepted = True
# success_probability = 0.81820000
# success_probability = 0.82160000
# success_probability = 0.82600000
# SPSA evaluation  1923 | p_suc = 0.82600000 | objective = 1.21065375 | step = 0.006691 | accepted = True
# success_probability = 0.81490000
# success_probability = 0.82040000
# success_probability = 0.82610000
# SPSA evaluation  1926 | p_suc = 0.82610000 | objective = 1.21050720 | step = 0.010883 | accepted = True
# success_probability = 0.82090000
# success_probability = 0.81310000
# success_probability = 0.82630000
# SPSA evaluation  1929 | p_suc = 0.82630000 | objective = 1.21021421 | step = 0.015459 | accepted = True
# success_probability = 0.81510000
# success_probability = 0.82570000
# success_probability = 0.82640000
# SPSA evaluation  1932 | p_suc = 0.82640000 | objective = 1.21006776 | step = 0.020835 | accepted = True
# success_probability = 0.82050000
# success_probability = 0.81720000
# success_probability = 0.82650000
# SPSA evaluation  1935 | p_suc = 0.82650000 | objective = 1.20992136 | step = 0.006511 | accepted = True
# success_probability = 0.81620000
# success_probability = 0.82040000
# success_probability = 0.82640000
# SPSA evaluation  1938 | p_suc = 0.82640000 | objective = 1.21006776 | step = 0.008297 | accepted = True
# success_probability = 0.82000000
# success_probability = 0.81740000
# success_probability = 0.82650000
# SPSA evaluation  1941 | p_suc = 0.82650000 | objective = 1.20992136 | step = 0.005131 | accepted = True
# success_probability = 0.82070000
# success_probability = 0.81370000
# success_probability = 0.82670000
# SPSA evaluation  1944 | p_suc = 0.82670000 | objective = 1.20962864 | step = 0.013867 | accepted = True
# success_probability = 0.82070000
# success_probability = 0.81680000
# success_probability = 0.82650000
# SPSA evaluation  1947 | p_suc = 0.82650000 | objective = 1.20992136 | step = 0.007696 | accepted = True
# success_probability = 0.81940000
# success_probability = 0.82070000
# success_probability = 0.82660000
# SPSA evaluation  1950 | p_suc = 0.82660000 | objective = 1.20977498 | step = 0.002557 | accepted = True
# success_probability = 0.81940000
# success_probability = 0.81940000
# success_probability = 0.82660000
# SPSA evaluation  1953 | p_suc = 0.82660000 | objective = 1.20977498 | step = 0.000000 | accepted = True
# success_probability = 0.82160000
# success_probability = 0.81460000
# success_probability = 0.82660000
# SPSA evaluation  1956 | p_suc = 0.82660000 | objective = 1.20977498 | step = 0.013836 | accepted = True
# success_probability = 0.81860000
# success_probability = 0.82040000
# success_probability = 0.82680000
# SPSA evaluation  1959 | p_suc = 0.82680000 | objective = 1.20948234 | step = 0.003546 | accepted = True
# success_probability = 0.82240000
# success_probability = 0.81610000
# success_probability = 0.82730000
# SPSA evaluation  1962 | p_suc = 0.82730000 | objective = 1.20875136 | step = 0.012417 | accepted = True
# success_probability = 0.82250000
# success_probability = 0.81560000
# success_probability = 0.82700000
# SPSA evaluation  1965 | p_suc = 0.82700000 | objective = 1.20918984 | step = 0.013607 | accepted = True
# success_probability = 0.81760000
# success_probability = 0.82200000
# success_probability = 0.82730000
# SPSA evaluation  1968 | p_suc = 0.82730000 | objective = 1.20875136 | step = 0.008661 | accepted = True
# success_probability = 0.82670000
# success_probability = 0.81570000
# success_probability = 0.82670000
# SPSA evaluation  1971 | p_suc = 0.82670000 | objective = 1.20962864 | step = 0.021579 | accepted = True
# success_probability = 0.82150000
# success_probability = 0.81730000
# success_probability = 0.82730000
# SPSA evaluation  1974 | p_suc = 0.82730000 | objective = 1.20875136 | step = 0.008275 | accepted = True
# success_probability = 0.81330000
# success_probability = 0.82070000
# success_probability = 0.82760000
# SPSA evaluation  1977 | p_suc = 0.82760000 | objective = 1.20831319 | step = 0.014666 | accepted = True
# success_probability = 0.81800000
# success_probability = 0.82280000
# success_probability = 0.82750000
# SPSA evaluation  1980 | p_suc = 0.82750000 | objective = 1.20845921 | step = 0.009434 | accepted = True
# success_probability = 0.82910000
# success_probability = 0.81720000
# success_probability = 0.82820000
# SPSA evaluation  1983 | p_suc = 0.82820000 | objective = 1.20743782 | step = 0.023234 | accepted = True
# success_probability = 0.81600000
# success_probability = 0.82360000
# success_probability = 0.82790000
# SPSA evaluation  1986 | p_suc = 0.82790000 | objective = 1.20787535 | step = 0.014960 | accepted = True
# success_probability = 0.81510000
# success_probability = 0.82290000
# success_probability = 0.82790000
# SPSA evaluation  1989 | p_suc = 0.82790000 | objective = 1.20787535 | step = 0.015384 | accepted = True
# success_probability = 0.82190000
# success_probability = 0.81740000
# success_probability = 0.82800000
# SPSA evaluation  1992 | p_suc = 0.82800000 | objective = 1.20772947 | step = 0.008861 | accepted = True
# success_probability = 0.81970000
# success_probability = 0.82200000
# success_probability = 0.82800000
# SPSA evaluation  1995 | p_suc = 0.82800000 | objective = 1.20772947 | step = 0.004516 | accepted = True
# success_probability = 0.81780000
# success_probability = 0.82330000
# success_probability = 0.82830000
# SPSA evaluation  1998 | p_suc = 0.82830000 | objective = 1.20729204 | step = 0.010806 | accepted = True
# success_probability = 0.82270000
# success_probability = 0.81680000
# success_probability = 0.82820000
# SPSA evaluation  2001 | p_suc = 0.82820000 | objective = 1.20743782 | step = 0.011615 | accepted = True
# success_probability = 0.82260000
# success_probability = 0.81590000
# success_probability = 0.82780000
# SPSA evaluation  2004 | p_suc = 0.82780000 | objective = 1.20802126 | step = 0.013206 | accepted = True
# success_probability = 0.82220000
# success_probability = 0.81970000
