# %%
# 0,1: 00 for psi_1, 01 for psi_2 ...
# 2,3: For states
# 4,5: Ancillary qubits

# %%
from qiskit import QuantumCircuit
from numpy import sqrt

def circuit_init():
    qc = QuantumCircuit(6)
    return qc

def PREP(qc):
    desired_vector = [
        1/sqrt(3), 0, 0, 0,
        1/(4*sqrt(3)), 1/4, 1/4, sqrt(3)/4,
        1/(4*sqrt(3)), -1/4, -1/4, sqrt(3)/4,
        0, 0, 0, 0
    ]
    qc.initialize(desired_vector, [3,2,1,0])
    return qc

# %%
from qiskit.circuit.library.standard_gates import RXGate,RYGate, RZGate
from qiskit.circuit.library import MCXGate
from qiskit.circuit.library.standard_gates import XGate
from pennylane.templates.state_preparations.mottonen import compute_theta, gray_code
from numpy import array, log2

def RR_X(qc, wires, params):
    qc.append(RXGate(params[0]),[wires[0]])
    qc.append(RXGate(params[1]),[wires[1]])

def RR_Z(qc, wires, params):
    qc.append(RZGate(params[0]),[wires[0]])
    qc.append(RZGate(params[1]),[wires[1]])


def CRR_X(qc, wires, state, params):
    qc.append(RXGate(params[0]).control(1,ctrl_state = state[::-1]), [wires[0], wires[1]])  # Control: wires[0] Target: wires[1]
    qc.append(RXGate(params[1]).control(1,ctrl_state = state[::-1]), [wires[0], wires[2]])  # Control: wires[0] Target: wires[2]
    return qc

def CRR_Z(qc, wires, state, params):
    qc.append(RZGate(params[0]).control(1,ctrl_state = state[::-1]), [wires[0], wires[1]])  # Control: wires[0] Target: wires[1]
    qc.append(RZGate(params[1]).control(1,ctrl_state = state[::-1]), [wires[0], wires[2]])  # Control: wires[0] Target: wires[2]
    return qc

def CCRR_X(qc, wires, state, params):
    qc.append(RXGate(params[0]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[2]])  # Control: wires[0] wires[1]
    qc.append(RXGate(params[1]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[3]])  # Control: wires[0] wires[1]
    return qc

def CCRR_Z(qc, wires, state, params):
    qc.append(RZGate(params[0]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[2]])  # Control: wires[0] wires[1]
    qc.append(RZGate(params[1]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[3]])  # Control: wires[0] wires[1]
    return qc

def U_CCR_decom(qc,wires,params):
    # Make sure that control qubits should be increasing order
    params = array(params)
    params = compute_theta(params) #can be on/off

    num_Ucontrols = len(wires)-1
    code = gray_code(2)
    n_selections = len(code)

    control_order = [int(log2(int(code[i], 2) ^ int(code[(i + 1) % n_selections], 2))) for i in range(n_selections)]

    for i in range(n_selections):
        qc.ry(params[i],wires[2])
        qc.cx(wires[num_Ucontrols-1 - control_order[i]],wires[2])
    return qc

def U_CCcR_decom(qc,wires,params):
    # Make sure that control qubits should be increasing order
    params = array(params)
    params = compute_theta(params) #can be on/off

    num_Ucontrols = len(wires)-2
    code = gray_code(2)
    n_selections = len(code)
    control_order = [int(log2(int(code[i], 2) ^ int(code[(i + 1) % n_selections], 2))) for i in range(n_selections)]

    for i in range(n_selections):
        qc.cry(params[i],wires[2],wires[3])
        CCX(qc,[wires[num_Ucontrols-1 - control_order[i]],wires[2],wires[3]],'11')

    return qc

def CCX(qc, wires, state):
    mcx_gate = MCXGate(num_ctrl_qubits=2,ctrl_state=state[::-1])
    qc.append(mcx_gate, [wires[0], wires[1],wires[2]])
    return qc

def CCCX(qc, wires, state):
    mcx_gate = MCXGate(num_ctrl_qubits=3,ctrl_state=state[::-1])
    qc.append(mcx_gate, [wires[0], wires[1],wires[2], wires[3]])
    return qc

def CX01(qc, wires):
    qc.append(
        XGate().control(1, ctrl_state='1'),
        [wires[0], wires[1]])
    return qc

# %%
from qiskit.circuit.library.standard_gates import RYGate

from numpy import pi


def Ansatz(qc, wires, params):


    #Big made by HEA
    RR_X(qc,wires[0:2],params[0:2])
    RR_Z(qc,wires[0:2],params[2:4])
    qc.cx(wires[0],wires[1])

    #Module 1
    U_CCR_decom(qc,wires[0:3],params[4:8])
    CRR_X(qc,[wires[2],wires[0],wires[1]],'0',params[8:10])
    CRR_Z(qc,[wires[2],wires[0],wires[1]],'0',params[10:12])
    CCX(qc,[wires[0],wires[2], wires[1]],'10')
    CRR_X(qc,[wires[2],wires[0],wires[1]],'1',params[12:14])
    CRR_Z(qc,[wires[2],wires[0],wires[1]],'1',params[14:16])
    CCX(qc,[wires[0],wires[2], wires[1]],'11')

    #Module 2
    U_CCcR_decom(qc, wires[0:4],params[16:20])
    CCRR_X(qc,[wires[2],wires[3],wires[0],wires[1]],'10',params[20:22])
    CCRR_Z(qc,[wires[2],wires[3],wires[0],wires[1]],'10',params[22:24])
    CCCX(qc,[wires[0],wires[2],wires[3],wires[1]],'110')
    CCRR_X(qc,[wires[2],wires[3],wires[0],wires[1]],'11',params[24:26])
    CCRR_Z(qc,[wires[2],wires[3],wires[0],wires[1]],'11',params[26:28])
    CCCX(qc,[wires[0],wires[2],wires[3],wires[1]],'111')

    CX01(qc, [wires[3],wires[2]])
    qc.measure_all()
    return qc

# %%
from numpy.random import rand
num_params=28
params = list(range(num_params))
qc = QuantumCircuit(4)
#PREP(qc)
Ansatz(qc, [0,1,2,3] , params)
qc.draw(output='mpl', style = 'clifford')

# %%
from qiskit_aer import AerSimulator
from qiskit import transpile
from scipy.optimize import minimize

import numpy as np
import os
import time


# ============================================================
# Simulator
# ============================================================

aersim = AerSimulator()


# ============================================================
# Settings
# ============================================================

num_times = 30
num_shots = 10000

optimizer_name = "BFGS"

maxiter = 70
gtol = 1e-3
eps = 1e-2

BASE_SEED = 150

optimizer_filename = optimizer_name.replace(
    "-",
    "_"
)

report_filename = f"{optimizer_filename}_report.txt"


# ============================================================
# High-Shot Evaluation Settings
# ============================================================

evaluation_num_times = 20
evaluation_num_shots = 100000

EVALUATION_BASE_SEED = 10000

evaluation_seeds = np.array(
    [
        EVALUATION_BASE_SEED + i
        for i in range(evaluation_num_times)
    ],
    dtype=int
)


# ============================================================
# Storage
# ============================================================

final_optimized_values = []

initial_params_all_runs = []
optimal_params_all_runs = []

optimization_success_all_runs = []
optimization_status_all_runs = []
optimization_message_all_runs = []

optimization_nit_all_runs = []
optimization_nfev_all_runs = []
optimization_njev_all_runs = []

reached_maxiter_all_runs = []

# ------------------------------------------------------------
# Runtime Storage
# ------------------------------------------------------------

optimization_wall_times = []


# ------------------------------------------------------------
# High-Shot Evaluation Storage
# ------------------------------------------------------------

evaluation_values_all_runs = []

evaluation_mean_all_runs = []
evaluation_std_all_runs = []
evaluation_min_all_runs = []
evaluation_max_all_runs = []


# ============================================================
# Objective Function
# ============================================================

def objective_function(
    params,
    run_seed,
    shots=None,
    print_result=True
):

    if shots is None:
        shots = num_shots


    # --------------------------------------------------------
    # Build circuit
    # --------------------------------------------------------

    qc = circuit_init()

    PREP(qc)

    Ansatz(
        qc,
        [2, 3, 4, 5],
        params
    )


    # --------------------------------------------------------
    # Reverse bit ordering
    # --------------------------------------------------------

    qc_reverse = qc.reverse_bits()


    # --------------------------------------------------------
    # Transpile
    # --------------------------------------------------------

    t_qc = transpile(
        qc_reverse,
        aersim,
        seed_transpiler=run_seed
    )


    # --------------------------------------------------------
    # Run simulator
    # --------------------------------------------------------

    job = aersim.run(
        t_qc,
        shots=shots,
        seed_simulator=run_seed
    )


    result = job.result()

    counts = result.get_counts()


    # --------------------------------------------------------
    # Count successful outcomes
    # --------------------------------------------------------

    tar_00 = 0
    tar_01 = 0
    tar_10 = 0


    for outcome, count in counts.items():

        # Target 00
        if outcome[0:2] == "00":

            if outcome[4:6] == "00":

                tar_00 += count


        # Target 01
        if outcome[0:2] == "01":

            if outcome[4:6] == "01":

                tar_01 += count


        # Target 10
        if outcome[0:2] == "10":

            if outcome[4:6] == "10":

                tar_10 += count


    # --------------------------------------------------------
    # Success probability
    # --------------------------------------------------------

    p_suc = (
        tar_00
        + tar_01
        + tar_10
    ) / shots


    if print_result:

        print(
            f"success_probability = "
            f"{p_suc:.8f}"
        )


    # --------------------------------------------------------
    # BFGS minimizes.
    #
    # We want to maximize p_suc,
    # therefore minimize 1 / p_suc.
    # --------------------------------------------------------

    if p_suc == 0:

        return 1e10


    return 1.0 / p_suc


# ============================================================
# Run Optimization
# ============================================================

# Measures the complete workflow:
# optimization + final evaluations + high-shot evaluations + overhead.
total_wall_start = time.perf_counter()

for run in range(num_times):


    # ========================================================
    # Optimization Seed
    # ========================================================

    run_seed = (
        BASE_SEED + run
    )


    rng = np.random.default_rng(
        run_seed
    )


    print(
        "\n"
        + "=" * 80
    )


    print(
        f"Optimization Run "
        f"{run + 1}/{num_times}"
    )


    print(
        f"Optimization Seed : "
        f"{run_seed}"
    )


    print(
        "=" * 80
    )


    # ========================================================
    # Generate Random Initial Parameters
    # ========================================================

    initial_params = rng.random(
        num_params
    )


    initial_params_all_runs.append(
        initial_params.copy()
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    # ========================================================
    # Run BFGS Optimization
    # ========================================================

    print(
        "\nStarting BFGS optimization..."
    )


    optimization_start = time.perf_counter()

    result = minimize(

        fun=lambda params: objective_function(
            params,
            run_seed,
            shots=num_shots,
            print_result=True
        ),

        x0=initial_params,

        method=optimizer_name,

        options={
            "maxiter": maxiter,
            "gtol": gtol,
            "eps": eps,
            "disp": True
        }
    )

    optimization_end = time.perf_counter()

    run_optimization_wall_time = (
        optimization_end
        - optimization_start
    )

    optimization_wall_times.append(
        run_optimization_wall_time
    )

    print(
        f"Optimization Wall-Clock Time : "
        f"{run_optimization_wall_time:.6f} s"
    )


    # ========================================================
    # Optimization Status
    # ========================================================

    optimization_success = bool(
        result.success
    )


    optimization_status = getattr(
        result,
        "status",
        None
    )


    optimization_message = str(
        getattr(
            result,
            "message",
            "No message returned"
        )
    )


    optimization_nit = getattr(
        result,
        "nit",
        None
    )


    optimization_nfev = getattr(
        result,
        "nfev",
        None
    )


    optimization_njev = getattr(
        result,
        "njev",
        None
    )


    # ========================================================
    # Detect Maximum Iteration Limit
    # ========================================================

    message_lower = (
        optimization_message.lower()
    )


    reached_maxiter = (

        "maximum number"
        in message_lower

        or "maximum iteration"
        in message_lower

        or "maximum iterations"
        in message_lower

        or "maxiter"
        in message_lower
    )


    if optimization_nit is not None:

        if optimization_nit >= maxiter:

            reached_maxiter = True


    # ========================================================
    # Store Optimization Status
    # ========================================================

    optimization_success_all_runs.append(
        optimization_success
    )


    optimization_status_all_runs.append(
        optimization_status
    )


    optimization_message_all_runs.append(
        optimization_message
    )


    optimization_nit_all_runs.append(
        optimization_nit
    )


    optimization_nfev_all_runs.append(
        optimization_nfev
    )


    optimization_njev_all_runs.append(
        optimization_njev
    )


    reached_maxiter_all_runs.append(
        reached_maxiter
    )


    # ========================================================
    # Optimal Parameters
    # ========================================================

    optimal_params = (
        result.x.copy()
    )


    optimal_params_all_runs.append(
        optimal_params.copy()
    )


    # ========================================================
    # Final Optimization-Shot Evaluation
    # ========================================================

    final_objective = objective_function(
        optimal_params,
        run_seed,
        shots=num_shots,
        print_result=False
    )


    if final_objective >= 1e10:

        final_value = 0.0

    else:

        final_value = (
            1.0 / final_objective
        )


    final_optimized_values.append(
        final_value
    )


    # ========================================================
    # High-Shot Evaluation
    # ========================================================

    print(
        "\n"
        + "-" * 80
    )


    print(
        "HIGH-SHOT EVALUATION OF "
        "OPTIMIZED PARAMETERS"
    )


    print(
        "-" * 80
    )


    print(
        f"Optimization Shots     : "
        f"{num_shots}"
    )


    print(
        f"Evaluation Shots       : "
        f"{evaluation_num_shots}"
    )


    print(
        f"Number of Evaluations : "
        f"{evaluation_num_times}"
    )


    print(
        "\nEvaluation Results:"
    )


    evaluation_values = []


    for eval_index, eval_seed in enumerate(
        evaluation_seeds
    ):


        eval_objective = objective_function(
            optimal_params,
            int(eval_seed),
            shots=evaluation_num_shots,
            print_result=False
        )


        if eval_objective >= 1e10:

            eval_value = 0.0

        else:

            eval_value = (
                1.0 / eval_objective
            )


        evaluation_values.append(
            eval_value
        )


        print(
            f"Evaluation "
            f"{eval_index + 1:2d}/"
            f"{evaluation_num_times:2d}"
            f" | Value = "
            f"{eval_value:.8f}"
        )


    # ========================================================
    # Evaluation Statistics
    # ========================================================

    evaluation_values = np.array(
        evaluation_values,
        dtype=float
    )


    evaluation_mean = np.mean(
        evaluation_values
    )


    evaluation_std = np.std(
        evaluation_values
    )


    evaluation_min = np.min(
        evaluation_values
    )


    evaluation_max = np.max(
        evaluation_values
    )


    # ========================================================
    # Store Evaluation Results
    # ========================================================

    evaluation_values_all_runs.append(
        evaluation_values.copy()
    )


    evaluation_mean_all_runs.append(
        evaluation_mean
    )


    evaluation_std_all_runs.append(
        evaluation_std
    )


    evaluation_min_all_runs.append(
        evaluation_min
    )


    evaluation_max_all_runs.append(
        evaluation_max
    )


    # ========================================================
    # Individual Run Report
    # ========================================================

    print(
        "\n"
        + "=" * 80
    )


    print(
        f"RUN {run + 1} RESULT"
    )


    print(
        "=" * 80
    )


    print(
        f"Optimization Success : "
        f"{optimization_success}"
    )


    print(
        f"Reached MaxIter      : "
        f"{reached_maxiter}"
    )


    print(
        f"Status               : "
        f"{optimization_status}"
    )


    print(
        f"Message              : "
        f"{optimization_message}"
    )


    print(
        f"Iterations           : "
        f"{optimization_nit}"
    )


    print(
        f"Function Evaluations : "
        f"{optimization_nfev}"
    )


    print(
        f"Gradient Evaluations : "
        f"{optimization_njev}"
    )


    print(
        f"Optimization Time    : "
        f"{run_optimization_wall_time:.6f} s"
    )


    print(
        f"Final Objective Value: "
        f"{result.fun}"
    )


    print(
        "\n"
        + "-" * 80
    )


    print(
        "OPTIMIZED AND HIGH-SHOT "
        "EVALUATED VALUES"
    )


    print(
        "-" * 80
    )


    print(
        f"Final Optimized Value : "
        f"{final_value:.8f}"
    )


    print(
        f"Evaluated Mean        : "
        f"{evaluation_mean:.8f}"
    )


    print(
        f"Evaluated Std         : "
        f"{evaluation_std:.8f}"
    )


    print(
        f"Evaluated Min         : "
        f"{evaluation_min:.8f}"
    )


    print(
        f"Evaluated Max         : "
        f"{evaluation_max:.8f}"
    )


    print(
        "\nAll Evaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values,
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "=" * 80
    )


# ============================================================
# Runtime Statistics
# ============================================================

total_wall_end = time.perf_counter()

total_wall_time = (
    total_wall_end
    - total_wall_start
)

optimization_wall_times = np.array(
    optimization_wall_times,
    dtype=float
)

total_optimization_wall_time = np.sum(
    optimization_wall_times
)

mean_optimization_wall_time = np.mean(
    optimization_wall_times
)

std_optimization_wall_time = np.std(
    optimization_wall_times
)


# ============================================================
# Convert Results to NumPy Arrays
# ============================================================

final_optimized_values = np.array(
    final_optimized_values,
    dtype=float
)


initial_params_all_runs = np.array(
    initial_params_all_runs
)


optimal_params_all_runs = np.array(
    optimal_params_all_runs
)


evaluation_values_all_runs = np.array(
    evaluation_values_all_runs,
    dtype=float
)


evaluation_mean_all_runs = np.array(
    evaluation_mean_all_runs,
    dtype=float
)


evaluation_std_all_runs = np.array(
    evaluation_std_all_runs,
    dtype=float
)


evaluation_min_all_runs = np.array(
    evaluation_min_all_runs,
    dtype=float
)


evaluation_max_all_runs = np.array(
    evaluation_max_all_runs,
    dtype=float
)


# ============================================================
# Original Optimization Statistics
# ============================================================

maximum_value = np.max(
    final_optimized_values
)


mean_value = np.mean(
    final_optimized_values
)


std_value = np.std(
    final_optimized_values
)


maximum_run_index = np.argmax(
    final_optimized_values
)


maximum_run = (
    maximum_run_index
    + 1
)


# ============================================================
# High-Shot Evaluation Statistics
# ============================================================

maximum_evaluated_mean = np.max(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run_index = np.argmax(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run = (
    maximum_evaluated_mean_run_index
    + 1
)


mean_of_evaluated_means = np.mean(
    evaluation_mean_all_runs
)


std_of_evaluated_means = np.std(
    evaluation_mean_all_runs
)


# ============================================================
# BFGS Iteration Statistics
# ============================================================

nit_values = np.array(
    [
        nit
        for nit
        in optimization_nit_all_runs
        if nit is not None
    ],
    dtype=float
)


if len(nit_values) > 0:

    mean_nit = np.mean(
        nit_values
    )


    std_nit = np.std(
        nit_values
    )

else:

    mean_nit = np.nan
    std_nit = np.nan


# ============================================================
# Function Evaluation Statistics
# ============================================================

nfev_values = np.array(
    [
        nfev
        for nfev
        in optimization_nfev_all_runs
        if nfev is not None
    ],
    dtype=float
)


if len(nfev_values) > 0:

    mean_nfev = np.mean(
        nfev_values
    )


    std_nfev = np.std(
        nfev_values
    )

else:

    mean_nfev = np.nan
    std_nfev = np.nan


# ============================================================
# Gradient Evaluation Statistics
# ============================================================

njev_values = np.array(
    [
        njev
        for njev
        in optimization_njev_all_runs
        if njev is not None
    ],
    dtype=float
)


if len(njev_values) > 0:

    mean_njev = np.mean(
        njev_values
    )


    std_njev = np.std(
        njev_values
    )

else:

    mean_njev = np.nan
    std_njev = np.nan


# ============================================================
# Optimization Success Statistics
# ============================================================

num_successful_runs = sum(
    optimization_success_all_runs
)


num_failed_runs = (
    num_times
    - num_successful_runs
)


num_reached_maxiter = sum(
    reached_maxiter_all_runs
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

best_initial_params = (
    initial_params_all_runs[
        maximum_run_index
    ]
)


best_optimal_params = (
    optimal_params_all_runs[
        maximum_run_index
    ]
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

best_evaluated_initial_params = (
    initial_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_optimal_params = (
    optimal_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_values = (
    evaluation_values_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


# ============================================================
# Print Final Report
# ============================================================

print("\n")


print(
    "=" * 100
)


print(
    "FINAL OPTIMIZATION AND "
    "HIGH-SHOT EVALUATION REPORT"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Settings
# ------------------------------------------------------------

print(
    f"Optimizer               : "
    f"{optimizer_name}"
)


print(
    f"Gradient Tolerance      : "
    f"{gtol}"
)


print(
    f"Finite-Difference Step  : "
    f"{eps}"
)


print(
    f"Max Iteration           : "
    f"{maxiter}"
)


print(
    f"Number of Runs          : "
    f"{num_times}"
)


print(
    f"Optimization Shots      : "
    f"{num_shots}"
)


print(
    f"Optimization Base Seed  : "
    f"{BASE_SEED}"
)


print(
    f"Evaluation Shots        : "
    f"{evaluation_num_shots}"
)


print(
    f"Evaluations Per Run     : "
    f"{evaluation_num_times}"
)


print(
    f"Evaluation Base Seed    : "
    f"{EVALUATION_BASE_SEED}"
)


# Evaluation seeds printed ONCE only.
print(
    "Evaluation Seeds        : "
    + np.array2string(
        evaluation_seeds,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Results for Every Run
# ============================================================

for i in range(num_times):


    print(
        f"\nRun {i + 1:2d}"
    )


    print(
        "-" * 100
    )


    print(
        f"Optimization Seed : "
        f"{BASE_SEED + i}"
    )


    print(
        f"Optimized Value   : "
        f"{final_optimized_values[i]:.8f}"
    )


    print(
        f"Evaluated Mean    : "
        f"{evaluation_mean_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Std     : "
        f"{evaluation_std_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Min     : "
        f"{evaluation_min_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Max     : "
        f"{evaluation_max_all_runs[i]:.8f}"
    )


    print(
        f"Success           : "
        f"{optimization_success_all_runs[i]}"
    )


    print(
        f"Reached MaxIter   : "
        f"{reached_maxiter_all_runs[i]}"
    )


    print(
        f"Status            : "
        f"{optimization_status_all_runs[i]}"
    )


    print(
        f"Message           : "
        f"{optimization_message_all_runs[i]}"
    )


    print(
        f"Iterations        : "
        f"{optimization_nit_all_runs[i]}"
    )


    print(
        f"Function Evals    : "
        f"{optimization_nfev_all_runs[i]}"
    )


    print(
        f"Gradient Evals    : "
        f"{optimization_njev_all_runs[i]}"
    )


    print(
        f"Optimization Time : "
        f"{optimization_wall_times[i]:.6f} s"
    )


    print(
        "\nEvaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values_all_runs[i],
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "-" * 100
    )


# ============================================================
# Summary
# ============================================================

print(
    "\nSUMMARY"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Original Optimization-Shot Results
# ------------------------------------------------------------

print(
    "\nOriginal Optimization-Shot Results:"
)


print(
    f"Maximum Optimized Value : "
    f"{maximum_value:.8f}"
)


print(
    f"Maximum Run             : "
    f"{maximum_run}"
)


print(
    f"Mean Optimized Value    : "
    f"{mean_value:.8f}"
)


print(
    f"Std Optimized Value     : "
    f"{std_value:.8f}"
)


# ------------------------------------------------------------
# High-Shot Evaluation Results
# ------------------------------------------------------------

print(
    "\nHigh-Shot Evaluation Results:"
)


print(
    f"Best Evaluated Mean     : "
    f"{maximum_evaluated_mean:.8f}"
)


print(
    f"Best Evaluated Mean Run : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Mean of Evaluated Means : "
    f"{mean_of_evaluated_means:.8f}"
)


print(
    f"Std of Evaluated Means  : "
    f"{std_of_evaluated_means:.8f}"
)


# ------------------------------------------------------------
# Optimizer Statistics
# ------------------------------------------------------------

print(
    "\nOptimizer Statistics:"
)


print(
    f"Mean Iterations         : "
    f"{mean_nit:.2f}"
)


print(
    f"Std Iterations          : "
    f"{std_nit:.2f}"
)


print(
    f"Mean Function Evals     : "
    f"{mean_nfev:.2f}"
)


print(
    f"Std Function Evals      : "
    f"{std_nfev:.2f}"
)


print(
    f"Mean Gradient Evals     : "
    f"{mean_njev:.2f}"
)


print(
    f"Std Gradient Evals      : "
    f"{std_njev:.2f}"
)


print(
    f"Successful Runs         : "
    f"{num_successful_runs}/"
    f"{num_times}"
)


print(
    f"Failed Runs             : "
    f"{num_failed_runs}/"
    f"{num_times}"
)


print(
    f"Reached MaxIter         : "
    f"{num_reached_maxiter}/"
    f"{num_times}"
)


# ------------------------------------------------------------
# Computational Runtime Statistics
# ------------------------------------------------------------

print(
    "\nComputational Runtime Statistics:"
)

print(
    f"Total Wall-Clock Time          : "
    f"{total_wall_time:.6f} s"
)

print(
    f"Total Optimization Time        : "
    f"{total_optimization_wall_time:.6f} s"
)

print(
    f"Time per Complete Opt. Run     : "
    f"{mean_optimization_wall_time:.6f} s"
)

print(
    f"Std Optimization Time per Run  : "
    f"{std_optimization_wall_time:.6f} s"
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "ORIGINAL OPTIMIZED VALUE"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        evaluation_values_all_runs[
            maximum_run_index
        ],
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_optimal_params,
        precision=10,
        separator=", "
    )
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "HIGH-SHOT EVALUATED MEAN"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        best_evaluated_values,
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_evaluated_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_evaluated_optimal_params,
        precision=10,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Save Report to TXT
# ============================================================

with open(
    report_filename,
    "w"
) as f:


    # ========================================================
    # Header
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "FINAL OPTIMIZATION AND "
        "HIGH-SHOT EVALUATION REPORT\n"
    )


    f.write(
        "=" * 100
        + "\n\n"
    )


    # ========================================================
    # Settings
    # ========================================================

    f.write(
        f"Optimizer               : "
        f"{optimizer_name}\n"
    )


    f.write(
        f"Gradient Tolerance      : "
        f"{gtol}\n"
    )


    f.write(
        f"Finite-Difference Step  : "
        f"{eps}\n"
    )


    f.write(
        f"Max Iteration           : "
        f"{maxiter}\n"
    )


    f.write(
        f"Number of Runs          : "
        f"{num_times}\n"
    )


    f.write(
        f"Optimization Shots      : "
        f"{num_shots}\n"
    )


    f.write(
        f"Optimization Base Seed  : "
        f"{BASE_SEED}\n"
    )


    f.write(
        f"Evaluation Shots        : "
        f"{evaluation_num_shots}\n"
    )


    f.write(
        f"Evaluations Per Run     : "
        f"{evaluation_num_times}\n"
    )


    f.write(
        f"Evaluation Base Seed    : "
        f"{EVALUATION_BASE_SEED}\n"
    )


    # Evaluation seeds saved ONCE only.
    f.write(
        "Evaluation Seeds        : "
    )


    f.write(
        np.array2string(
            evaluation_seeds,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    # ========================================================
    # Results for Every Run
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "RESULTS FOR EACH RUN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    for i in range(num_times):


        f.write(
            f"\nRun {i + 1:2d}\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


        f.write(
            f"Optimization Seed : "
            f"{BASE_SEED + i}\n"
        )


        f.write(
            f"Optimized Value   : "
            f"{final_optimized_values[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Mean    : "
            f"{evaluation_mean_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Std     : "
            f"{evaluation_std_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Min     : "
            f"{evaluation_min_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Max     : "
            f"{evaluation_max_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Success           : "
            f"{optimization_success_all_runs[i]}\n"
        )


        f.write(
            f"Reached MaxIter   : "
            f"{reached_maxiter_all_runs[i]}\n"
        )


        f.write(
            f"Status            : "
            f"{optimization_status_all_runs[i]}\n"
        )


        f.write(
            f"Message           : "
            f"{optimization_message_all_runs[i]}\n"
        )


        f.write(
            f"Iterations        : "
            f"{optimization_nit_all_runs[i]}\n"
        )


        f.write(
            f"Function Evals    : "
            f"{optimization_nfev_all_runs[i]}\n"
        )


        f.write(
            f"Gradient Evals    : "
            f"{optimization_njev_all_runs[i]}\n"
        )


        f.write(
            f"Optimization Time : "
            f"{optimization_wall_times[i]:.6f} s\n"
        )


        f.write(
            "\nEvaluated Values:\n"
        )


        f.write(
            np.array2string(
                evaluation_values_all_runs[i],
                precision=8,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nInitial Parameters:\n"
        )


        f.write(
            np.array2string(
                initial_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nOptimal Parameters:\n"
        )


        f.write(
            np.array2string(
                optimal_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


    # ========================================================
    # Summary
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "SUMMARY\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    # --------------------------------------------------------
    # Original Optimization-Shot Results
    # --------------------------------------------------------

    f.write(
        "\nOriginal Optimization-Shot Results:\n"
    )


    f.write(
        f"Maximum Optimized Value : "
        f"{maximum_value:.8f}\n"
    )


    f.write(
        f"Maximum Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Mean Optimized Value    : "
        f"{mean_value:.8f}\n"
    )


    f.write(
        f"Std Optimized Value     : "
        f"{std_value:.8f}\n"
    )


    # --------------------------------------------------------
    # High-Shot Evaluation Results
    # --------------------------------------------------------

    f.write(
        "\nHigh-Shot Evaluation Results:\n"
    )


    f.write(
        f"Best Evaluated Mean     : "
        f"{maximum_evaluated_mean:.8f}\n"
    )


    f.write(
        f"Best Evaluated Mean Run : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Mean of Evaluated Means : "
        f"{mean_of_evaluated_means:.8f}\n"
    )


    f.write(
        f"Std of Evaluated Means  : "
        f"{std_of_evaluated_means:.8f}\n"
    )


    # --------------------------------------------------------
    # Optimizer Statistics
    # --------------------------------------------------------

    f.write(
        "\nOptimizer Statistics:\n"
    )


    f.write(
        f"Mean Iterations         : "
        f"{mean_nit:.2f}\n"
    )


    f.write(
        f"Std Iterations          : "
        f"{std_nit:.2f}\n"
    )


    f.write(
        f"Mean Function Evals     : "
        f"{mean_nfev:.2f}\n"
    )


    f.write(
        f"Std Function Evals      : "
        f"{std_nfev:.2f}\n"
    )


    f.write(
        f"Mean Gradient Evals     : "
        f"{mean_njev:.2f}\n"
    )


    f.write(
        f"Std Gradient Evals      : "
        f"{std_njev:.2f}\n"
    )


    f.write(
        f"Successful Runs         : "
        f"{num_successful_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Failed Runs             : "
        f"{num_failed_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Reached MaxIter         : "
        f"{num_reached_maxiter}/"
        f"{num_times}\n"
    )


    # --------------------------------------------------------
    # Computational Runtime Statistics
    # --------------------------------------------------------

    f.write(
        "\nComputational Runtime Statistics:\n"
    )

    f.write(
        f"Total Wall-Clock Time          : "
        f"{total_wall_time:.6f} s\n"
    )

    f.write(
        f"Total Optimization Time        : "
        f"{total_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Time per Complete Opt. Run     : "
        f"{mean_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Std Optimization Time per Run  : "
        f"{std_optimization_wall_time:.6f} s\n"
    )


    # ========================================================
    # Best Run According to Original Optimized Value
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "ORIGINAL OPTIMIZED VALUE\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            evaluation_values_all_runs[
                maximum_run_index
            ],
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    # ========================================================
    # Best Run According to High-Shot Evaluated Mean
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "HIGH-SHOT EVALUATED MEAN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_values,
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


# ============================================================
# Report Location
# ============================================================

print(
    "\nReport saved to:"
)


print(
    os.path.abspath(
        report_filename
    )
)
# Out:
# ================================================================================
# Optimization Run 1/30
# Optimization Seed : 150
# ================================================================================
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566, 0.6883896757,
#  0.5848087428, 0.2739643248, 0.8377858251, 0.3022293541, 0.1728462164,
#  0.8017433668, 0.3441099205, 0.4375847094]
#
# Starting BFGS optimization...
# success_probability = 0.33170000
# success_probability = 0.33160000
# success_probability = 0.33050000
# success_probability = 0.33140000
# success_probability = 0.33150000
# success_probability = 0.33050000
# success_probability = 0.33150000
# success_probability = 0.33260000
# success_probability = 0.33170000
# success_probability = 0.33140000
# success_probability = 0.33070000
# success_probability = 0.33170000
# success_probability = 0.33170000
# success_probability = 0.33190000
# success_probability = 0.33160000
# success_probability = 0.33180000
# success_probability = 0.33180000
# success_probability = 0.33160000
# success_probability = 0.33170000
# success_probability = 0.33170000
# success_probability = 0.33160000
# success_probability = 0.33170000
# success_probability = 0.33160000
# success_probability = 0.33170000
# success_probability = 0.33170000
# success_probability = 0.33170000
# success_probability = 0.33170000
# success_probability = 0.33170000
# success_probability = 0.33170000
# success_probability = 0.40540000
# success_probability = 0.40530000
# success_probability = 0.40470000
# success_probability = 0.40530000
# success_probability = 0.40500000
# success_probability = 0.40500000
# success_probability = 0.40550000
# success_probability = 0.40630000
# success_probability = 0.40540000
# success_probability = 0.40470000
# success_probability = 0.40490000
# success_probability = 0.40540000
# success_probability = 0.40540000
# success_probability = 0.40530000
# success_probability = 0.40550000
# success_probability = 0.40550000
# success_probability = 0.40530000
# success_probability = 0.40530000
# success_probability = 0.40540000
# success_probability = 0.40560000
# success_probability = 0.40550000
# success_probability = 0.40550000
# success_probability = 0.40550000
# success_probability = 0.40540000
# success_probability = 0.40540000
# success_probability = 0.40540000
# success_probability = 0.40560000
# success_probability = 0.40540000
# success_probability = 0.40540000
# success_probability = 0.47760000
# success_probability = 0.47700000
# success_probability = 0.47670000
# success_probability = 0.47670000
# success_probability = 0.47720000
# success_probability = 0.47760000
# success_probability = 0.47740000
# success_probability = 0.47840000
# success_probability = 0.47710000
# success_probability = 0.47750000
# success_probability = 0.47680000
# success_probability = 0.47760000
# success_probability = 0.47760000
# success_probability = 0.47750000
# success_probability = 0.47760000
# success_probability = 0.47740000
# success_probability = 0.47740000
# success_probability = 0.47760000
# success_probability = 0.47740000
# success_probability = 0.47780000
# success_probability = 0.47780000
# success_probability = 0.47720000
# success_probability = 0.47750000
# success_probability = 0.47760000
# success_probability = 0.47760000
# success_probability = 0.47750000
# success_probability = 0.47760000
# success_probability = 0.47760000
# success_probability = 0.47760000
# success_probability = 0.50520000
# success_probability = 0.50500000
# success_probability = 0.50490000
# success_probability = 0.50520000
# success_probability = 0.50510000
# success_probability = 0.50510000
# success_probability = 0.50540000
# success_probability = 0.50600000
# success_probability = 0.50520000
# success_probability = 0.50480000
# success_probability = 0.50450000
# success_probability = 0.50520000
# success_probability = 0.50520000
# success_probability = 0.50530000
# success_probability = 0.50530000
# success_probability = 0.50550000
# success_probability = 0.50520000
# success_probability = 0.50520000
# success_probability = 0.50510000
# success_probability = 0.50550000
# success_probability = 0.50510000
# success_probability = 0.50530000
# success_probability = 0.50500000
# success_probability = 0.50520000
# success_probability = 0.50520000
# success_probability = 0.50520000
# success_probability = 0.50540000
# success_probability = 0.50520000
# success_probability = 0.50520000
# success_probability = 0.50650000
# success_probability = 0.50650000
# success_probability = 0.50750000
# success_probability = 0.50650000
# success_probability = 0.50620000
# success_probability = 0.50700000
# success_probability = 0.50660000
# success_probability = 0.50650000
# success_probability = 0.50670000
# success_probability = 0.50620000
# success_probability = 0.50660000
# success_probability = 0.50650000
# success_probability = 0.50650000
# success_probability = 0.50660000
# success_probability = 0.50660000
# success_probability = 0.50650000
# success_probability = 0.50660000
# success_probability = 0.50650000
# success_probability = 0.50640000
# success_probability = 0.50630000
# success_probability = 0.50600000
# success_probability = 0.50680000
# success_probability = 0.50650000
# success_probability = 0.50650000
# success_probability = 0.50650000
# success_probability = 0.50650000
# success_probability = 0.50640000
# success_probability = 0.50650000
# success_probability = 0.50650000
# success_probability = 0.50800000
# success_probability = 0.50850000
# success_probability = 0.50980000
# success_probability = 0.50850000
# success_probability = 0.50790000
# success_probability = 0.50890000
# success_probability = 0.50890000
# success_probability = 0.50870000
# success_probability = 0.50830000
# success_probability = 0.50800000
# success_probability = 0.50840000
# success_probability = 0.50800000
# success_probability = 0.50800000
# success_probability = 0.50840000
# success_probability = 0.50790000
# success_probability = 0.50810000
# success_probability = 0.50830000
# success_probability = 0.50860000
# success_probability = 0.50820000
# success_probability = 0.50820000
# success_probability = 0.50770000
# success_probability = 0.50810000
# success_probability = 0.50790000
# success_probability = 0.50800000
# success_probability = 0.50800000
# success_probability = 0.50820000
# success_probability = 0.50790000
# success_probability = 0.50800000
# success_probability = 0.50800000
# success_probability = 0.51290000
# success_probability = 0.51270000
# success_probability = 0.51460000
# success_probability = 0.51230000
# success_probability = 0.51250000
# success_probability = 0.51330000
# success_probability = 0.51340000
# success_probability = 0.51300000
# success_probability = 0.51240000
# success_probability = 0.51250000
# success_probability = 0.51380000
# success_probability = 0.51290000
# success_probability = 0.51290000
# success_probability = 0.51330000
# success_probability = 0.51260000
# success_probability = 0.51280000
# success_probability = 0.51300000
# success_probability = 0.51290000
# success_probability = 0.51290000
# success_probability = 0.51300000
# success_probability = 0.51280000
# success_probability = 0.51320000
# success_probability = 0.51260000
# success_probability = 0.51290000
# success_probability = 0.51290000
# success_probability = 0.51290000
# success_probability = 0.51280000
# success_probability = 0.51290000
# success_probability = 0.51290000
# success_probability = 0.52600000
# success_probability = 0.52670000
# success_probability = 0.52700000
# success_probability = 0.52620000
# success_probability = 0.52600000
# success_probability = 0.52600000
# success_probability = 0.52670000
# success_probability = 0.52610000
# success_probability = 0.52550000
# success_probability = 0.52660000
# success_probability = 0.52670000
# success_probability = 0.52600000
# success_probability = 0.52600000
# success_probability = 0.52630000
# success_probability = 0.52600000
# success_probability = 0.52590000
# success_probability = 0.52580000
# success_probability = 0.52590000
# success_probability = 0.52590000
# success_probability = 0.52610000
# success_probability = 0.52600000
# success_probability = 0.52580000
# success_probability = 0.52590000
# success_probability = 0.52600000
# success_probability = 0.52600000
# success_probability = 0.52580000
# success_probability = 0.52600000
# success_probability = 0.52600000
# success_probability = 0.52600000
# success_probability = 0.54350000
# success_probability = 0.54410000
# success_probability = 0.54410000
# success_probability = 0.54330000
# success_probability = 0.54380000
# success_probability = 0.54360000
# success_probability = 0.54410000
# success_probability = 0.54290000
# success_probability = 0.54390000
# success_probability = 0.54300000
# success_probability = 0.54350000
# success_probability = 0.54350000
# success_probability = 0.54350000
# success_probability = 0.54390000
# success_probability = 0.54410000
# success_probability = 0.54370000
# success_probability = 0.54380000
# success_probability = 0.54340000
# success_probability = 0.54360000
# success_probability = 0.54380000
# success_probability = 0.54360000
# success_probability = 0.54390000
# success_probability = 0.54390000
# success_probability = 0.54350000
# success_probability = 0.54350000
# success_probability = 0.54340000
# success_probability = 0.54350000
# success_probability = 0.54350000
# success_probability = 0.54350000
# success_probability = 0.55460000
# success_probability = 0.55420000
# success_probability = 0.55410000
# success_probability = 0.55400000
# success_probability = 0.55450000
# success_probability = 0.55470000
# success_probability = 0.55460000
# success_probability = 0.55460000
# success_probability = 0.55480000
# success_probability = 0.55440000
# success_probability = 0.55510000
# success_probability = 0.55460000
# success_probability = 0.55460000
# success_probability = 0.55470000
# success_probability = 0.55500000
# success_probability = 0.55470000
# success_probability = 0.55490000
# success_probability = 0.55460000
# success_probability = 0.55440000
# success_probability = 0.55540000
# success_probability = 0.55460000
# success_probability = 0.55480000
# success_probability = 0.55450000
# success_probability = 0.55460000
# success_probability = 0.55460000
# success_probability = 0.55460000
# success_probability = 0.55470000
# success_probability = 0.55460000
# success_probability = 0.55460000
# success_probability = 0.56530000
# success_probability = 0.56580000
# success_probability = 0.56560000
# success_probability = 0.56490000
# success_probability = 0.56600000
# success_probability = 0.56490000
# success_probability = 0.56580000
# success_probability = 0.56510000
# success_probability = 0.56560000
# success_probability = 0.56610000
# success_probability = 0.56510000
# success_probability = 0.56530000
# success_probability = 0.56530000
# success_probability = 0.56500000
# success_probability = 0.56530000
# success_probability = 0.56530000
# success_probability = 0.56540000
# success_probability = 0.56530000
# success_probability = 0.56540000
# success_probability = 0.56600000
# success_probability = 0.56550000
# success_probability = 0.56530000
# success_probability = 0.56520000
# success_probability = 0.56530000
# success_probability = 0.56530000
# success_probability = 0.56530000
# success_probability = 0.56530000
# success_probability = 0.56530000
# success_probability = 0.56530000
# success_probability = 0.57200000
# success_probability = 0.57210000
# success_probability = 0.57200000
# success_probability = 0.57220000
# success_probability = 0.57230000
# success_probability = 0.57160000
# success_probability = 0.57260000
# success_probability = 0.57210000
# success_probability = 0.57160000
# success_probability = 0.57180000
# success_probability = 0.57230000
# success_probability = 0.57200000
# success_probability = 0.57200000
# success_probability = 0.57260000
# success_probability = 0.57220000
# success_probability = 0.57210000
# success_probability = 0.57230000
# success_probability = 0.57210000
# success_probability = 0.57200000
# success_probability = 0.57230000
# success_probability = 0.57190000
# success_probability = 0.57190000
# success_probability = 0.57200000
# success_probability = 0.57200000
# success_probability = 0.57200000
# success_probability = 0.57200000
# success_probability = 0.57200000
# success_probability = 0.57200000
# success_probability = 0.57200000
# success_probability = 0.57830000
# success_probability = 0.57840000
# success_probability = 0.57780000
# success_probability = 0.57870000
# success_probability = 0.57820000
# success_probability = 0.57810000
# success_probability = 0.57830000
# success_probability = 0.57870000
# success_probability = 0.57790000
# success_probability = 0.57840000
# success_probability = 0.57900000
# success_probability = 0.57830000
# success_probability = 0.57830000
# success_probability = 0.57820000
# success_probability = 0.57810000
# success_probability = 0.57860000
# success_probability = 0.57820000
# success_probability = 0.57830000
# success_probability = 0.57820000
# success_probability = 0.57840000
# success_probability = 0.57820000
# success_probability = 0.57840000
# success_probability = 0.57850000
# success_probability = 0.57830000
# success_probability = 0.57830000
# success_probability = 0.57820000
# success_probability = 0.57820000
# success_probability = 0.57830000
# success_probability = 0.57830000
# success_probability = 0.58560000
# success_probability = 0.58650000
# success_probability = 0.58540000
# success_probability = 0.58560000
# success_probability = 0.58620000
# success_probability = 0.58540000
# success_probability = 0.58600000
# success_probability = 0.58560000
# success_probability = 0.58520000
# success_probability = 0.58510000
# success_probability = 0.58600000
# success_probability = 0.58560000
# success_probability = 0.58560000
# success_probability = 0.58570000
# success_probability = 0.58590000
# success_probability = 0.58540000
# success_probability = 0.58540000
# success_probability = 0.58580000
# success_probability = 0.58580000
# success_probability = 0.58570000
# success_probability = 0.58560000
# success_probability = 0.58530000
# success_probability = 0.58510000
# success_probability = 0.58560000
# success_probability = 0.58560000
# success_probability = 0.58560000
# success_probability = 0.58560000
# success_probability = 0.58560000
# success_probability = 0.58560000
# success_probability = 0.59340000
# success_probability = 0.59340000
# success_probability = 0.59330000
# success_probability = 0.59310000
# success_probability = 0.59320000
# success_probability = 0.59330000
# success_probability = 0.59350000
# success_probability = 0.59330000
# success_probability = 0.59320000
# success_probability = 0.59330000
# success_probability = 0.59320000
# success_probability = 0.59340000
# success_probability = 0.59340000
# success_probability = 0.59310000
# success_probability = 0.59340000
# success_probability = 0.59330000
# success_probability = 0.59310000
# success_probability = 0.59340000
# success_probability = 0.59320000
# success_probability = 0.59370000
# success_probability = 0.59350000
# success_probability = 0.59320000
# success_probability = 0.59330000
# success_probability = 0.59340000
# success_probability = 0.59340000
# success_probability = 0.59330000
# success_probability = 0.59340000
# success_probability = 0.59340000
# success_probability = 0.59340000
# success_probability = 0.60190000
# success_probability = 0.60210000
# success_probability = 0.60190000
# success_probability = 0.60250000
# success_probability = 0.60190000
# success_probability = 0.60240000
# success_probability = 0.60220000
# success_probability = 0.60150000
# success_probability = 0.60200000
# success_probability = 0.60190000
# success_probability = 0.60160000
# success_probability = 0.60190000
# success_probability = 0.60190000
# success_probability = 0.60210000
# success_probability = 0.60170000
# success_probability = 0.60220000
# success_probability = 0.60150000
# success_probability = 0.60190000
# success_probability = 0.60190000
# success_probability = 0.60200000
# success_probability = 0.60170000
# success_probability = 0.60190000
# success_probability = 0.60170000
# success_probability = 0.60190000
# success_probability = 0.60190000
# success_probability = 0.60190000
# success_probability = 0.60190000
# success_probability = 0.60190000
# success_probability = 0.60190000
# success_probability = 0.61790000
# success_probability = 0.61800000
# success_probability = 0.61770000
# success_probability = 0.61820000
# success_probability = 0.61790000
# success_probability = 0.61790000
# success_probability = 0.61810000
# success_probability = 0.61790000
# success_probability = 0.61720000
# success_probability = 0.61820000
# success_probability = 0.61810000
# success_probability = 0.61790000
# success_probability = 0.61790000
# success_probability = 0.61840000
# success_probability = 0.61790000
# success_probability = 0.61790000
# success_probability = 0.61790000
# success_probability = 0.61810000
# success_probability = 0.61770000
# success_probability = 0.61800000
# success_probability = 0.61770000
# success_probability = 0.61780000
# success_probability = 0.61780000
# success_probability = 0.61790000
# success_probability = 0.61790000
# success_probability = 0.61790000
# success_probability = 0.61780000
# success_probability = 0.61790000
# success_probability = 0.61790000
# success_probability = 0.65010000
# success_probability = 0.64960000
# success_probability = 0.64970000
# success_probability = 0.64920000
# success_probability = 0.65000000
# success_probability = 0.64980000
# success_probability = 0.65010000
# success_probability = 0.65040000
# success_probability = 0.64930000
# success_probability = 0.64950000
# success_probability = 0.64960000
# success_probability = 0.65010000
# success_probability = 0.65010000
# success_probability = 0.64980000
# success_probability = 0.65030000
# success_probability = 0.64960000
# success_probability = 0.65010000
# success_probability = 0.65000000
# success_probability = 0.65010000
# success_probability = 0.65030000
# success_probability = 0.64990000
# success_probability = 0.65020000
# success_probability = 0.64990000
# success_probability = 0.65010000
# success_probability = 0.65010000
# success_probability = 0.65010000
# success_probability = 0.65010000
# success_probability = 0.65010000
# success_probability = 0.65010000
# success_probability = 0.66540000
# success_probability = 0.66520000
# success_probability = 0.66610000
# success_probability = 0.66530000
# success_probability = 0.66530000
# success_probability = 0.66580000
# success_probability = 0.66600000
# success_probability = 0.66610000
# success_probability = 0.66400000
# success_probability = 0.66540000
# success_probability = 0.66520000
# success_probability = 0.66540000
# success_probability = 0.66540000
# success_probability = 0.66590000
# success_probability = 0.66630000
# success_probability = 0.66560000
# success_probability = 0.66530000
# success_probability = 0.66570000
# success_probability = 0.66550000
# success_probability = 0.66550000
# success_probability = 0.66600000
# success_probability = 0.66560000
# success_probability = 0.66550000
# success_probability = 0.66540000
# success_probability = 0.66540000
# success_probability = 0.66550000
# success_probability = 0.66540000
# success_probability = 0.66540000
# success_probability = 0.66540000
# success_probability = 0.63320000
# success_probability = 0.63270000
# success_probability = 0.63430000
# success_probability = 0.63340000
# success_probability = 0.63240000
# success_probability = 0.63350000
# success_probability = 0.63330000
# success_probability = 0.63390000
# success_probability = 0.63270000
# success_probability = 0.63320000
# success_probability = 0.63330000
# success_probability = 0.63320000
# success_probability = 0.63320000
# success_probability = 0.63340000
# success_probability = 0.63350000
# success_probability = 0.63340000
# success_probability = 0.63300000
# success_probability = 0.63350000
# success_probability = 0.63340000
# success_probability = 0.63270000
# success_probability = 0.63340000
# success_probability = 0.63290000
# success_probability = 0.63340000
# success_probability = 0.63320000
# success_probability = 0.63320000
# success_probability = 0.63310000
# success_probability = 0.63320000
# success_probability = 0.63320000
# success_probability = 0.63320000
# success_probability = 0.66250000
# success_probability = 0.66240000
# success_probability = 0.66350000
# success_probability = 0.66230000
# success_probability = 0.66230000
# success_probability = 0.66270000
# success_probability = 0.66290000
# success_probability = 0.66370000
# success_probability = 0.66140000
# success_probability = 0.66230000
# success_probability = 0.66270000
# success_probability = 0.66250000
# success_probability = 0.66250000
# success_probability = 0.66280000
# success_probability = 0.66270000
# success_probability = 0.66250000
# success_probability = 0.66210000
# success_probability = 0.66260000
# success_probability = 0.66260000
# success_probability = 0.66200000
# success_probability = 0.66280000
# success_probability = 0.66230000
# success_probability = 0.66230000
# success_probability = 0.66250000
# success_probability = 0.66250000
# success_probability = 0.66270000
# success_probability = 0.66260000
# success_probability = 0.66250000
# success_probability = 0.66250000
# success_probability = 0.66530000
# success_probability = 0.66500000
# success_probability = 0.66620000
# success_probability = 0.66520000
# success_probability = 0.66520000
# success_probability = 0.66530000
# success_probability = 0.66490000
# success_probability = 0.66620000
# success_probability = 0.66430000
# success_probability = 0.66540000
# success_probability = 0.66550000
# success_probability = 0.66530000
# success_probability = 0.66530000
# success_probability = 0.66520000
# success_probability = 0.66560000
# success_probability = 0.66520000
# success_probability = 0.66520000
# success_probability = 0.66540000
# success_probability = 0.66570000
# success_probability = 0.66500000
# success_probability = 0.66580000
# success_probability = 0.66520000
# success_probability = 0.66510000
# success_probability = 0.66530000
# success_probability = 0.66530000
# success_probability = 0.66540000
# success_probability = 0.66540000
# success_probability = 0.66530000
# success_probability = 0.66530000
# success_probability = 0.66550000
# success_probability = 0.66530000
# success_probability = 0.66620000
# success_probability = 0.66550000
# success_probability = 0.66550000
# success_probability = 0.66590000
# success_probability = 0.66540000
# success_probability = 0.66600000
# success_probability = 0.66430000
# success_probability = 0.66540000
# success_probability = 0.66540000
# success_probability = 0.66550000
# success_probability = 0.66550000
# success_probability = 0.66590000
# success_probability = 0.66600000
# success_probability = 0.66550000
# success_probability = 0.66560000
# success_probability = 0.66580000
# success_probability = 0.66560000
# success_probability = 0.66550000
# success_probability = 0.66570000
# success_probability = 0.66570000
# success_probability = 0.66570000
# success_probability = 0.66550000
# success_probability = 0.66550000
# success_probability = 0.66550000
# success_probability = 0.66550000
# success_probability = 0.66550000
# success_probability = 0.66550000
# success_probability = 0.66560000
# success_probability = 0.66550000
# success_probability = 0.66640000
# success_probability = 0.66590000
# success_probability = 0.66550000
# success_probability = 0.66650000
# success_probability = 0.66560000
# success_probability = 0.66620000
# success_probability = 0.66430000
# success_probability = 0.66550000
# success_probability = 0.66570000
# success_probability = 0.66560000
# success_probability = 0.66560000
# success_probability = 0.66600000
# success_probability = 0.66630000
# success_probability = 0.66580000
# success_probability = 0.66570000
# success_probability = 0.66590000
# success_probability = 0.66580000
# success_probability = 0.66570000
# success_probability = 0.66610000
# success_probability = 0.66580000
# success_probability = 0.66580000
# success_probability = 0.66560000
# success_probability = 0.66560000
# success_probability = 0.66570000
# success_probability = 0.66560000
# success_probability = 0.66560000
# success_probability = 0.66560000
# success_probability = 0.66620000
# success_probability = 0.66590000
# success_probability = 0.66760000
# success_probability = 0.66610000
# success_probability = 0.66600000
# success_probability = 0.66690000
# success_probability = 0.66640000
# success_probability = 0.66700000
# success_probability = 0.66500000
# success_probability = 0.66640000
# success_probability = 0.66650000
# success_probability = 0.66620000
# success_probability = 0.66620000
# success_probability = 0.66650000
# success_probability = 0.66670000
# success_probability = 0.66620000
# success_probability = 0.66620000
# success_probability = 0.66640000
# success_probability = 0.66650000
# success_probability = 0.66620000
# success_probability = 0.66670000
# success_probability = 0.66610000
# success_probability = 0.66620000
# success_probability = 0.66620000
# success_probability = 0.66620000
# success_probability = 0.66630000
# success_probability = 0.66630000
# success_probability = 0.66620000
# success_probability = 0.66620000
# success_probability = 0.66890000
# success_probability = 0.66910000
# success_probability = 0.67040000
# success_probability = 0.66840000
# success_probability = 0.66860000
# success_probability = 0.66920000
# success_probability = 0.66890000
# success_probability = 0.66990000
# success_probability = 0.66810000
# success_probability = 0.66920000
# success_probability = 0.66910000
# success_probability = 0.66890000
# success_probability = 0.66890000
# success_probability = 0.66920000
# success_probability = 0.66890000
# success_probability = 0.66810000
# success_probability = 0.66890000
# success_probability = 0.66910000
# success_probability = 0.66890000
# success_probability = 0.66880000
# success_probability = 0.66910000
# success_probability = 0.66870000
# success_probability = 0.66900000
# success_probability = 0.66890000
# success_probability = 0.66890000
# success_probability = 0.66900000
# success_probability = 0.66890000
# success_probability = 0.66890000
# success_probability = 0.66890000
# success_probability = 0.67950000
# success_probability = 0.67890000
# success_probability = 0.68060000
# success_probability = 0.67960000
# success_probability = 0.67910000
# success_probability = 0.68010000
# success_probability = 0.67960000
# success_probability = 0.68000000
# success_probability = 0.67850000
# success_probability = 0.67970000
# success_probability = 0.67910000
# success_probability = 0.67950000
# success_probability = 0.67950000
# success_probability = 0.68000000
# success_probability = 0.68040000
# success_probability = 0.67930000
# success_probability = 0.67930000
# success_probability = 0.67990000
# success_probability = 0.67980000
# success_probability = 0.67920000
# success_probability = 0.67990000
# success_probability = 0.67920000
# success_probability = 0.67950000
# success_probability = 0.67950000
# success_probability = 0.67950000
# success_probability = 0.67940000
# success_probability = 0.67930000
# success_probability = 0.67950000
# success_probability = 0.67950000
# success_probability = 0.71140000
# success_probability = 0.71180000
# success_probability = 0.71300000
# success_probability = 0.71200000
# success_probability = 0.71110000
# success_probability = 0.71140000
# success_probability = 0.71270000
# success_probability = 0.71270000
# success_probability = 0.71110000
# success_probability = 0.71200000
# success_probability = 0.71180000
# success_probability = 0.71140000
# success_probability = 0.71140000
# success_probability = 0.71170000
# success_probability = 0.71220000
# success_probability = 0.71150000
# success_probability = 0.71150000
# success_probability = 0.71150000
# success_probability = 0.71170000
# success_probability = 0.71070000
# success_probability = 0.71200000
# success_probability = 0.71130000
# success_probability = 0.71160000
# success_probability = 0.71140000
# success_probability = 0.71140000
# success_probability = 0.71160000
# success_probability = 0.71160000
# success_probability = 0.71140000
# success_probability = 0.71140000
# success_probability = 0.74020000
# success_probability = 0.74010000
# success_probability = 0.74030000
# success_probability = 0.74050000
# success_probability = 0.73980000
# success_probability = 0.73970000
# success_probability = 0.74080000
# success_probability = 0.74000000
# success_probability = 0.74000000
# success_probability = 0.73950000
# success_probability = 0.74000000
# success_probability = 0.74020000
# success_probability = 0.74020000
# success_probability = 0.74020000
# success_probability = 0.74000000
# success_probability = 0.74000000
# success_probability = 0.73990000
# success_probability = 0.74040000
# success_probability = 0.74090000
# success_probability = 0.74010000
# success_probability = 0.74110000
# success_probability = 0.74010000
# success_probability = 0.74010000
# success_probability = 0.74020000
# success_probability = 0.74020000
# success_probability = 0.74020000
# success_probability = 0.74030000
# success_probability = 0.74020000
# success_probability = 0.74020000
# success_probability = 0.75170000
# success_probability = 0.75190000
# success_probability = 0.75120000
# success_probability = 0.75220000
# success_probability = 0.75050000
# success_probability = 0.75130000
# success_probability = 0.75220000
# success_probability = 0.75260000
# success_probability = 0.75090000
# success_probability = 0.75200000
# success_probability = 0.75180000
# success_probability = 0.75170000
# success_probability = 0.75170000
# success_probability = 0.75230000
# success_probability = 0.75240000
# success_probability = 0.75190000
# success_probability = 0.75210000
# success_probability = 0.75190000
# success_probability = 0.75170000
# success_probability = 0.75170000
# success_probability = 0.75180000
# success_probability = 0.75160000
# success_probability = 0.75220000
# success_probability = 0.75170000
# success_probability = 0.75170000
# success_probability = 0.75170000
# success_probability = 0.75160000
# success_probability = 0.75170000
# success_probability = 0.75170000
# success_probability = 0.76210000
# success_probability = 0.76220000
# success_probability = 0.76200000
# success_probability = 0.76230000
# success_probability = 0.76160000
# success_probability = 0.76230000
# success_probability = 0.76250000
# success_probability = 0.76220000
# success_probability = 0.76180000
# success_probability = 0.76210000
# success_probability = 0.76180000
# success_probability = 0.76210000
# success_probability = 0.76210000
# success_probability = 0.76210000
# success_probability = 0.76270000
# success_probability = 0.76220000
# success_probability = 0.76260000
# success_probability = 0.76270000
# success_probability = 0.76210000
# success_probability = 0.76240000
# success_probability = 0.76230000
# success_probability = 0.76250000
# success_probability = 0.76190000
# success_probability = 0.76210000
# success_probability = 0.76210000
# success_probability = 0.76210000
# success_probability = 0.76210000
# success_probability = 0.76210000
# success_probability = 0.76210000
# success_probability = 0.77140000
# success_probability = 0.77050000
# success_probability = 0.77080000
# success_probability = 0.77150000
# success_probability = 0.77090000
# success_probability = 0.77040000
# success_probability = 0.77160000
# success_probability = 0.77100000
# success_probability = 0.77030000
# success_probability = 0.77180000
# success_probability = 0.77170000
# success_probability = 0.77140000
# success_probability = 0.77140000
# success_probability = 0.77120000
# success_probability = 0.77130000
# success_probability = 0.77130000
# success_probability = 0.77100000
# success_probability = 0.77140000
# success_probability = 0.77140000
# success_probability = 0.77120000
# success_probability = 0.77180000
# success_probability = 0.77080000
# success_probability = 0.77110000
# success_probability = 0.77140000
# success_probability = 0.77140000
# success_probability = 0.77140000
# success_probability = 0.77170000
# success_probability = 0.77140000
# success_probability = 0.77140000
# success_probability = 0.78050000
# success_probability = 0.78040000
# success_probability = 0.78030000
# success_probability = 0.78060000
# success_probability = 0.78040000
# success_probability = 0.77990000
# success_probability = 0.78110000
# success_probability = 0.78090000
# success_probability = 0.77990000
# success_probability = 0.78100000
# success_probability = 0.78090000
# success_probability = 0.78050000
# success_probability = 0.78050000
# success_probability = 0.78020000
# success_probability = 0.78140000
# success_probability = 0.78050000
# success_probability = 0.78040000
# success_probability = 0.78030000
# success_probability = 0.78040000
# success_probability = 0.78040000
# success_probability = 0.78040000
# success_probability = 0.78050000
# success_probability = 0.78030000
# success_probability = 0.78050000
# success_probability = 0.78050000
# success_probability = 0.78050000
# success_probability = 0.78040000
# success_probability = 0.78050000
# success_probability = 0.78050000
# success_probability = 0.78750000
# success_probability = 0.78700000
# success_probability = 0.78720000
# success_probability = 0.78780000
# success_probability = 0.78700000
# success_probability = 0.78710000
# success_probability = 0.78760000
# success_probability = 0.78790000
# success_probability = 0.78700000
# success_probability = 0.78780000
# success_probability = 0.78790000
# success_probability = 0.78750000
# success_probability = 0.78750000
# success_probability = 0.78780000
# success_probability = 0.78740000
# success_probability = 0.78770000
# success_probability = 0.78710000
# success_probability = 0.78750000
# success_probability = 0.78750000
# success_probability = 0.78730000
# success_probability = 0.78760000
# success_probability = 0.78730000
# success_probability = 0.78740000
# success_probability = 0.78750000
# success_probability = 0.78750000
# success_probability = 0.78750000
# success_probability = 0.78760000
# success_probability = 0.78750000
# success_probability = 0.78750000
# success_probability = 0.79220000
# success_probability = 0.79180000
# success_probability = 0.79220000
# success_probability = 0.79210000
# success_probability = 0.79200000
# success_probability = 0.79210000
# success_probability = 0.79370000
# success_probability = 0.79260000
# success_probability = 0.79150000
# success_probability = 0.79150000
# success_probability = 0.79240000
# success_probability = 0.79220000
# success_probability = 0.79220000
# success_probability = 0.79230000
# success_probability = 0.79230000
# success_probability = 0.79230000
# success_probability = 0.79210000
# success_probability = 0.79210000
# success_probability = 0.79200000
# success_probability = 0.79180000
# success_probability = 0.79250000
# success_probability = 0.79210000
# success_probability = 0.79230000
# success_probability = 0.79220000
# success_probability = 0.79220000
# success_probability = 0.79220000
# success_probability = 0.79220000
# success_probability = 0.79220000
# success_probability = 0.79220000
# success_probability = 0.79590000
# success_probability = 0.79530000
# success_probability = 0.79580000
# success_probability = 0.79590000
# success_probability = 0.79580000
# success_probability = 0.79600000
# success_probability = 0.79650000
# success_probability = 0.79590000
# success_probability = 0.79420000
# success_probability = 0.79510000
# success_probability = 0.79610000
# success_probability = 0.79590000
# success_probability = 0.79590000
# success_probability = 0.79620000
# success_probability = 0.79600000
# success_probability = 0.79640000
# success_probability = 0.79580000
# success_probability = 0.79610000
# success_probability = 0.79580000
# success_probability = 0.79600000
# success_probability = 0.79600000
# success_probability = 0.79580000
# success_probability = 0.79620000
# success_probability = 0.79590000
# success_probability = 0.79590000
# success_probability = 0.79600000
# success_probability = 0.79600000
# success_probability = 0.79590000
# success_probability = 0.79590000
# success_probability = 0.79980000
# success_probability = 0.79900000
# success_probability = 0.79970000
# success_probability = 0.80000000
# success_probability = 0.79950000
# success_probability = 0.79950000
# success_probability = 0.80060000
# success_probability = 0.79980000
# success_probability = 0.79900000
# success_probability = 0.79990000
# success_probability = 0.80030000
# success_probability = 0.79980000
# success_probability = 0.79980000
# success_probability = 0.80000000
# success_probability = 0.79980000
# success_probability = 0.79970000
# success_probability = 0.79980000
# success_probability = 0.80020000
# success_probability = 0.79990000
# success_probability = 0.79980000
# success_probability = 0.79960000
# success_probability = 0.79980000
# success_probability = 0.79970000
# success_probability = 0.79980000
# success_probability = 0.79980000
# success_probability = 0.79980000
# success_probability = 0.79960000
# success_probability = 0.79980000
# success_probability = 0.79980000
# success_probability = 0.80520000
# success_probability = 0.80480000
# success_probability = 0.80530000
# success_probability = 0.80530000
# success_probability = 0.80510000
# success_probability = 0.80500000
# success_probability = 0.80490000
# success_probability = 0.80530000
# success_probability = 0.80360000
# success_probability = 0.80460000
# success_probability = 0.80470000
# success_probability = 0.80520000
# success_probability = 0.80520000
# success_probability = 0.80530000
# success_probability = 0.80540000
# success_probability = 0.80500000
# success_probability = 0.80500000
# success_probability = 0.80530000
# success_probability = 0.80510000
# success_probability = 0.80510000
# success_probability = 0.80520000
# success_probability = 0.80520000
# success_probability = 0.80510000
# success_probability = 0.80520000
# success_probability = 0.80520000
# success_probability = 0.80520000
# success_probability = 0.80520000
# success_probability = 0.80520000
# success_probability = 0.80520000
# success_probability = 0.80900000
# success_probability = 0.80860000
# success_probability = 0.80910000
# success_probability = 0.80930000
# success_probability = 0.80920000
# success_probability = 0.80910000
# success_probability = 0.80970000
# success_probability = 0.80870000
# success_probability = 0.80830000
# success_probability = 0.80890000
# success_probability = 0.80910000
# success_probability = 0.80900000
# success_probability = 0.80900000
# success_probability = 0.80920000
# success_probability = 0.80920000
# success_probability = 0.80910000
# success_probability = 0.80900000
# success_probability = 0.80920000
# success_probability = 0.80900000
# success_probability = 0.80930000
# success_probability = 0.80900000
# success_probability = 0.80930000
# success_probability = 0.80910000
# success_probability = 0.80900000
# success_probability = 0.80900000
# success_probability = 0.80900000
# success_probability = 0.80900000
# success_probability = 0.80900000
# success_probability = 0.80900000
# success_probability = 0.81140000
# success_probability = 0.81050000
# success_probability = 0.81130000
# success_probability = 0.81120000
# success_probability = 0.81100000
# success_probability = 0.81090000
# success_probability = 0.81220000
# success_probability = 0.81160000
# success_probability = 0.81080000
# success_probability = 0.81220000
# success_probability = 0.81220000
# success_probability = 0.81140000
# success_probability = 0.81140000
# success_probability = 0.81200000
# success_probability = 0.81220000
# success_probability = 0.81120000
# success_probability = 0.81070000
# success_probability = 0.81150000
# success_probability = 0.81120000
# success_probability = 0.81130000
# success_probability = 0.81160000
# success_probability = 0.81100000
# success_probability = 0.81100000
# success_probability = 0.81140000
# success_probability = 0.81140000
# success_probability = 0.81140000
# success_probability = 0.81150000
# success_probability = 0.81140000
# success_probability = 0.81140000
# success_probability = 0.81400000
# success_probability = 0.81340000
# success_probability = 0.81380000
# success_probability = 0.81400000
# success_probability = 0.81420000
# success_probability = 0.81410000
# success_probability = 0.81400000
# success_probability = 0.81410000
# success_probability = 0.81280000
# success_probability = 0.81450000
# success_probability = 0.81420000
# success_probability = 0.81400000
# success_probability = 0.81400000
# success_probability = 0.81500000
# success_probability = 0.81460000
# success_probability = 0.81440000
# success_probability = 0.81430000
# success_probability = 0.81400000
# success_probability = 0.81400000
# success_probability = 0.81440000
# success_probability = 0.81400000
# success_probability = 0.81390000
# success_probability = 0.81390000
# success_probability = 0.81400000
# success_probability = 0.81400000
# success_probability = 0.81400000
# success_probability = 0.81410000
# success_probability = 0.81400000
# success_probability = 0.81400000
# success_probability = 0.81820000
# success_probability = 0.81830000
# success_probability = 0.81800000
# success_probability = 0.81800000
# success_probability = 0.81810000
# success_probability = 0.81830000
# success_probability = 0.81870000
# success_probability = 0.81840000
# success_probability = 0.81750000
# success_probability = 0.81850000
# success_probability = 0.81840000
# success_probability = 0.81820000
# success_probability = 0.81820000
# success_probability = 0.81870000
# success_probability = 0.81860000
# success_probability = 0.81820000
# success_probability = 0.81830000
# success_probability = 0.81840000
# success_probability = 0.81820000
# success_probability = 0.81830000
# success_probability = 0.81860000
# success_probability = 0.81860000
# success_probability = 0.81830000
# success_probability = 0.81820000
# success_probability = 0.81820000
# success_probability = 0.81830000
# success_probability = 0.81810000
# success_probability = 0.81820000
# success_probability = 0.81820000
# success_probability = 0.82580000
# success_probability = 0.82550000
# success_probability = 0.82550000
# success_probability = 0.82580000
# success_probability = 0.82590000
# success_probability = 0.82550000
# success_probability = 0.82610000
# success_probability = 0.82660000
# success_probability = 0.82490000
# success_probability = 0.82530000
# success_probability = 0.82560000
# success_probability = 0.82580000
# success_probability = 0.82580000
# success_probability = 0.82620000
# success_probability = 0.82630000
# success_probability = 0.82560000
# success_probability = 0.82590000
# success_probability = 0.82580000
# success_probability = 0.82570000
# success_probability = 0.82550000
# success_probability = 0.82590000
# success_probability = 0.82600000
# success_probability = 0.82530000
# success_probability = 0.82580000
# success_probability = 0.82580000
# success_probability = 0.82570000
# success_probability = 0.82580000
# success_probability = 0.82580000
# success_probability = 0.82580000
# success_probability = 0.83160000
# success_probability = 0.83140000
# success_probability = 0.83050000
# success_probability = 0.83140000
# success_probability = 0.83080000
# success_probability = 0.83110000
# success_probability = 0.83170000
# success_probability = 0.83190000
# success_probability = 0.83050000
# success_probability = 0.83170000
# success_probability = 0.83150000
# success_probability = 0.83160000
# success_probability = 0.83160000
# success_probability = 0.83180000
# success_probability = 0.83210000
# success_probability = 0.83120000
# success_probability = 0.83130000
# success_probability = 0.83180000
# success_probability = 0.83130000
# success_probability = 0.83190000
# success_probability = 0.83160000
# success_probability = 0.83160000
# success_probability = 0.83140000
# success_probability = 0.83160000
# success_probability = 0.83160000
# success_probability = 0.83160000
# success_probability = 0.83170000
# success_probability = 0.83160000
# success_probability = 0.83160000
# success_probability = 0.81130000
# success_probability = 0.81210000
# success_probability = 0.81080000
# success_probability = 0.81130000
# success_probability = 0.81030000
# success_probability = 0.81090000
# success_probability = 0.81140000
# success_probability = 0.81150000
# success_probability = 0.81100000
# success_probability = 0.81160000
# success_probability = 0.81140000
# success_probability = 0.81130000
# success_probability = 0.81130000
# success_probability = 0.81160000
# success_probability = 0.81190000
# success_probability = 0.81120000
# success_probability = 0.81100000
# success_probability = 0.81160000
# success_probability = 0.81110000
# success_probability = 0.81170000
# success_probability = 0.81170000
# success_probability = 0.81120000
# success_probability = 0.81170000
# success_probability = 0.81130000
# success_probability = 0.81130000
# success_probability = 0.81120000
# success_probability = 0.81130000
# success_probability = 0.81130000
# success_probability = 0.81130000
# success_probability = 0.82890000
# success_probability = 0.82910000
# success_probability = 0.82740000
# success_probability = 0.82860000
# success_probability = 0.82790000
# success_probability = 0.82860000
# success_probability = 0.82910000
# success_probability = 0.82950000
# success_probability = 0.82800000
# success_probability = 0.82890000
# success_probability = 0.82830000
# success_probability = 0.82890000
# success_probability = 0.82890000
# success_probability = 0.82910000
# success_probability = 0.82900000
# success_probability = 0.82860000
# success_probability = 0.82850000
# success_probability = 0.82880000
# success_probability = 0.82890000
# success_probability = 0.82900000
# success_probability = 0.82960000
# success_probability = 0.82870000
# success_probability = 0.82880000
# success_probability = 0.82890000
# success_probability = 0.82890000
# success_probability = 0.82880000
# success_probability = 0.82850000
# success_probability = 0.82890000
# success_probability = 0.82890000
# success_probability = 0.83130000
# success_probability = 0.83180000
# success_probability = 0.83020000
# success_probability = 0.83180000
# success_probability = 0.83080000
# success_probability = 0.83060000
# success_probability = 0.83170000
# success_probability = 0.83140000
# success_probability = 0.83040000
# success_probability = 0.83130000
# success_probability = 0.83160000
# success_probability = 0.83130000
# success_probability = 0.83130000
# success_probability = 0.83200000
# success_probability = 0.83180000
# success_probability = 0.83150000
# success_probability = 0.83150000
# success_probability = 0.83130000
# success_probability = 0.83120000
# success_probability = 0.83190000
# success_probability = 0.83160000
# success_probability = 0.83100000
# success_probability = 0.83170000
# success_probability = 0.83130000
# success_probability = 0.83130000
# success_probability = 0.83130000
# success_probability = 0.83120000
# success_probability = 0.83130000
# success_probability = 0.83130000
# success_probability = 0.83180000
# success_probability = 0.83180000
# success_probability = 0.83050000
# success_probability = 0.83190000
# success_probability = 0.83120000
# success_probability = 0.83150000
# success_probability = 0.83170000
# success_probability = 0.83170000
# success_probability = 0.83020000
# success_probability = 0.83160000
# success_probability = 0.83190000
# success_probability = 0.83180000
# success_probability = 0.83180000
# success_probability = 0.83180000
# success_probability = 0.83170000
# success_probability = 0.83140000
# success_probability = 0.83160000
# success_probability = 0.83200000
# success_probability = 0.83150000
# success_probability = 0.83230000
# success_probability = 0.83210000
# success_probability = 0.83190000
# success_probability = 0.83170000
# success_probability = 0.83180000
# success_probability = 0.83180000
# success_probability = 0.83180000
# success_probability = 0.83170000
# success_probability = 0.83180000
# success_probability = 0.83180000
# success_probability = 0.83140000
# success_probability = 0.83190000
# success_probability = 0.83050000
# success_probability = 0.83140000
# success_probability = 0.83090000
# success_probability = 0.83070000
# success_probability = 0.83210000
# success_probability = 0.83140000
# success_probability = 0.83030000
# success_probability = 0.83150000
# success_probability = 0.83140000
# success_probability = 0.83140000
# success_probability = 0.83140000
# success_probability = 0.83210000
# success_probability = 0.83180000
# success_probability = 0.83150000
# success_probability = 0.83170000
# success_probability = 0.83160000
# success_probability = 0.83140000
# success_probability = 0.83210000
# success_probability = 0.83180000
# success_probability = 0.83110000
# success_probability = 0.83170000
# success_probability = 0.83140000
# success_probability = 0.83140000
# success_probability = 0.83170000
# success_probability = 0.83140000
# success_probability = 0.83140000
# success_probability = 0.83140000
# success_probability = 0.83160000
# success_probability = 0.83180000
# success_probability = 0.83080000
# success_probability = 0.83160000
# success_probability = 0.83110000
# success_probability = 0.83130000
# success_probability = 0.83210000
# success_probability = 0.83170000
# success_probability = 0.83040000
# success_probability = 0.83150000
# success_probability = 0.83180000
# success_probability = 0.83160000
# success_probability = 0.83160000
# ...
# Evaluated Min     : 0.94003000
# Evaluated Max     : 0.94004000
# Success           : False
# Reached MaxIter   : False
# Status            : 2
# Message           : Desired error not necessarily achieved due to precision loss.
# Iterations        : 56
# Function Evals    : 3637
# Gradient Evals    : 125
# Optimization Time : 434.019307 s
#
# Evaluated Values:
# [0.94003, 0.94003, 0.94003, 0.94003, 0.94004, 0.94004, 0.94004, 0.94004,
#  0.94004, 0.94004, 0.94004, 0.94004, 0.94004, 0.94004, 0.94004, 0.94004,
#  0.94004, 0.94004, 0.94004, 0.94004]
#
# Initial Parameters:
# [0.0683064102, 0.5061877572, 0.2800764934, 0.4917358842, 0.3376481488,
#  0.6337766115, 0.7941202296, 0.2237709719, 0.8893153608, 0.9462072178,
#  0.9270749557, 0.8979372613, 0.8865232604, 0.1112901922, 0.4404611446,
#  0.6571269562, 0.6018173982, 0.0668305069, 0.5031888045, 0.7100940384,
#  0.3646853666, 0.6647653187, 0.3408936761, 0.3312253256, 0.7714370826,
#  0.2269448353, 0.0303235797, 0.6383902153]
#
# Optimal Parameters:
# [-0.0296081866, -0.0467764209, -0.075194521 , -1.6481921139,  0.0325726432,
#   3.0550218468,  3.2890220498,  2.9077203161,  4.7343876065,  1.068749938 ,
#   0.9270749557,  0.8979372613,  2.2695976338,  1.5399610588,  1.4861345964,
#   0.9786968719,  3.1107804755, -0.1595273106,  2.6946127225, -0.3667311639,
#   0.0975523467,  1.3687354045,  0.3408936761,  0.3312253256,  0.8380792337,
#  -1.4013302014,  0.0303235797,  0.6383902153]
# ----------------------------------------------------------------------------------------------------
#
# Run 25
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 174
# Optimized Value   : 0.53700000
# Evaluated Mean    : 0.52869400
# Evaluated Std     : 0.00001319
# Evaluated Min     : 0.52866000
# Evaluated Max     : 0.52871000
# Success           : False
# Reached MaxIter   : False
# Status            : 2
# Message           : Desired error not necessarily achieved due to precision loss.
# Iterations        : 13
# Function Evals    : 1636
# Gradient Evals    : 56
# Optimization Time : 193.246054 s
#
# Evaluated Values:
# [0.5287 , 0.52871, 0.52871, 0.5287 , 0.52871, 0.5287 , 0.52869, 0.5287 ,
#  0.5287 , 0.5287 , 0.5287 , 0.5287 , 0.5287 , 0.5287 , 0.52869, 0.52868,
#  0.52868, 0.52868, 0.52867, 0.52866]
#
# Initial Parameters:
# [0.920751175 , 0.8324481628, 0.9226421153, 0.4120178702, 0.112899878 ,
#  0.539662511 , 0.9690640438, 0.8958288503, 0.8463732302, 0.6837088366,
#  0.0134777936, 0.9213092468, 0.0585796685, 0.528523907 , 0.4212992395,
#  0.8064657524, 0.2081509804, 0.1492170041, 0.0586840123, 0.6381376407,
#  0.7175421339, 0.7259671078, 0.0347409726, 0.8317209152, 0.1893140181,
#  0.5873066532, 0.6508822385, 0.1541344136]
#
# Optimal Parameters:
# [-0.0213064598,  0.1448959437,  0.4402897539,  0.8851555377, -0.1367689337,
#  -0.280216471 ,  3.3173847165,  0.7517091293,  0.5935844618,  0.1528596265,
#   0.0134777936,  0.9213092468, -0.0916110736,  0.0404407852,  0.6471628492,
#   0.6347850508,  0.2081509804,  0.061021689 , -0.0295113028, -0.2936118371,
#   0.7759064208,  0.6904144946,  0.0347409726,  0.8317209152,  0.1893140181,
#   0.5873066532,  0.6508822385,  0.1541344136]
# ----------------------------------------------------------------------------------------------------
#
# Run 26
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 175
# Optimized Value   : 0.54680000
# Evaluated Mean    : 0.54603650
# Evaluated Std     : 0.00000792
# Evaluated Min     : 0.54602000
# Evaluated Max     : 0.54605000
# Success           : False
# Reached MaxIter   : False
# Status            : 2
# Message           : Desired error not necessarily achieved due to precision loss.
# Iterations        : 15
# Function Evals    : 2042
# Gradient Evals    : 70
# Optimization Time : 244.542936 s
#
# Evaluated Values:
# [0.54602, 0.54603, 0.54604, 0.54604, 0.54605, 0.54605, 0.54604, 0.54604,
#  0.54603, 0.54603, 0.54603, 0.54604, 0.54605, 0.54604, 0.54604, 0.54603,
#  0.54603, 0.54603, 0.54603, 0.54604]
#
# Initial Parameters:
# [0.5632800098, 0.5263460088, 0.074383608 , 0.0432472297, 0.1116614549,
#  0.3149336925, 0.8051899849, 0.2265811498, 0.2507577735, 0.3247400132,
#  0.7132637608, 0.7744654451, 0.9295185054, 0.8709503245, 0.9380278462,
#  0.6231528096, 0.2419077457, 0.8799737511, 0.1804762542, 0.8020908004,
#  0.3363522676, 0.2884964572, 0.5552697615, 0.8113197998, 0.1117050081,
#  0.04623727  , 0.2558624663, 0.3513980154]
#
# Optimal Parameters:
# [ 0.1359561068, -0.2330157082,  0.9626657222,  0.1747428412,  0.1553934144,
#   0.8123305022,  3.6092779746,  1.4394600068,  1.6899400459,  3.2425364097,
#   0.7132637608,  0.7744654451,  1.1387922252,  1.7188377128,  1.0006971762,
#   1.0044655322,  0.3102411218,  0.7504947953,  0.7129723471,  0.232590575 ,
#   0.0791671047,  1.2534614468,  0.5552697615,  0.8113197998,  0.1431839839,
#  -0.1364185494,  0.2558624663,  0.3513980154]
# ----------------------------------------------------------------------------------------------------
#
# Run 27
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 176
# Optimized Value   : 0.56610000
# Evaluated Mean    : 0.55887050
# Evaluated Std     : 0.00000921
# Evaluated Min     : 0.55885000
# Evaluated Max     : 0.55889000
# Success           : False
# Reached MaxIter   : False
# Status            : 2
# Message           : Desired error not necessarily achieved due to precision loss.
# Iterations        : 11
# Function Evals    : 2681
# Gradient Evals    : 92
# Optimization Time : 319.814093 s
#
# Evaluated Values:
# [0.55885, 0.55886, 0.55887, 0.55887, 0.55888, 0.55887, 0.55886, 0.55886,
#  0.55886, 0.55887, 0.55887, 0.55887, 0.55887, 0.55888, 0.55888, 0.55889,
#  0.55888, 0.55887, 0.55887, 0.55888]
#
# Initial Parameters:
# [0.908796571 , 0.1480812304, 0.9316217524, 0.8690627692, 0.8218723273,
#  0.3598173853, 0.8198721198, 0.1817033926, 0.2126209616, 0.6959983996,
#  0.3659168242, 0.6449720995, 0.1945739112, 0.1231941489, 0.9608135811,
#  0.9693122607, 0.6994862206, 0.3285305578, 0.5308429614, 0.0713595069,
#  0.6124682681, 0.0173357401, 0.2291752338, 0.1716368198, 0.7904109494,
#  0.6764072798, 0.8677348266, 0.5559777189]
#
# Optimal Parameters:
# [ 1.5168103547, -0.4039139784,  1.1437502663,  0.8447123277,  0.1886310954,
#   2.939847387 ,  2.9388321778,  0.2610588253,  1.7629276973,  1.1302952114,
#   0.3659168242,  0.6449720995, -0.2071078977, -0.155556933 ,  0.7976427267,
#   1.0436307197,  0.7766984854,  1.0692460726,  0.5276997897, -0.4037996636,
#   0.8647377832,  0.5442073169,  0.2291752338,  0.1716368198,  0.6958429696,
#   0.6837717722,  0.8677348266,  0.5559777189]
# ----------------------------------------------------------------------------------------------------
#
# Run 28
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 177
# Optimized Value   : 0.56020000
# Evaluated Mean    : 0.55299500
# Evaluated Std     : 0.00001565
# Evaluated Min     : 0.55296000
# Evaluated Max     : 0.55302000
# Success           : False
# Reached MaxIter   : False
# Status            : 2
# Message           : Desired error not necessarily achieved due to precision loss.
# Iterations        : 10
# Function Evals    : 1810
# Gradient Evals    : 62
# Optimization Time : 216.726948 s
#
# Evaluated Values:
# [0.55298, 0.55298, 0.55299, 0.55299, 0.553  , 0.553  , 0.553  , 0.55301,
#  0.55301, 0.55301, 0.55301, 0.55302, 0.55301, 0.55301, 0.553  , 0.55299,
#  0.55298, 0.55298, 0.55297, 0.55296]
#
# Initial Parameters:
# [0.4859979492, 0.3134855983, 0.5928545916, 0.5388495959, 0.8208222388,
#  0.1681699936, 0.7886708539, 0.9073399324, 0.1513191786, 0.6385598502,
#  0.0204482374, 0.441729694 , 0.1062169866, 0.3316953766, 0.9856944419,
#  0.4606017013, 0.291802071 , 0.5311775661, 0.6869978953, 0.085870002 ,
#  0.70379701  , 0.7732596263, 0.358077326 , 0.7448635381, 0.5398799816,
#  0.6518199474, 0.496504845 , 0.729372615 ]
#
# Optimal Parameters:
# [ 0.0415700313,  0.3038604005,  0.763945915 , -0.1578505131, -0.0925123516,
#   0.9166583699,  3.4996630665,  1.4922112745, -0.7637364266,  0.577970705 ,
#   0.0204482374,  0.441729694 ,  0.2114413604,  0.2857881865,  0.9702318994,
#   0.5349190629,  0.2492060685,  0.5317542873,  0.4135968247,  0.0431454113,
#   0.7303462116,  0.987876031 ,  0.358077326 ,  0.7448635381,  0.5398799816,
#   0.6518199474,  0.496504845 ,  0.729372615 ]
# ----------------------------------------------------------------------------------------------------
#
# Run 29
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 178
# Optimized Value   : 0.49150000
# Evaluated Mean    : 0.48363100
# Evaluated Std     : 0.00001513
# Evaluated Min     : 0.48360000
# Evaluated Max     : 0.48365000
# Success           : False
# Reached MaxIter   : False
# Status            : 2
# Message           : Desired error not necessarily achieved due to precision loss.
# Iterations        : 8
# Function Evals    : 1634
# Gradient Evals    : 56
# Optimization Time : 194.983721 s
#
# Evaluated Values:
# [0.48363, 0.48364, 0.48365, 0.48365, 0.48365, 0.48364, 0.48364, 0.48364,
#  0.48364, 0.48364, 0.48364, 0.48364, 0.48363, 0.48363, 0.48362, 0.48361,
#  0.48361, 0.48361, 0.48361, 0.4836 ]
#
# Initial Parameters:
# [0.7608275692, 0.0464101376, 0.0032708871, 0.7605003536, 0.2769531808,
#  0.5945503444, 0.8036218146, 0.7402677744, 0.1239034672, 0.2438968692,
#  0.748428843 , 0.9205783868, 0.2357355697, 0.9391032789, 0.4081091944,
#  0.4620759117, 0.7294079941, 0.5779372506, 0.3477807167, 0.9240071009,
#  0.4847679255, 0.9369591861, 0.6895419866, 0.4903610315, 0.1782447546,
#  0.0915727898, 0.6053767128, 0.8164664622]
#
# Optimal Parameters:
# [ 0.9114236473, -0.1616297029, -0.1377835705, -0.1220746661, -0.4817774926,
#   0.1506611799,  3.2162017982,  0.7508669477, -0.5821413523, -0.5482331259,
#   0.748428843 ,  0.9205783868, -0.0404572845,  0.2667315006,  0.2717380765,
#   0.3859197282,  0.7161176428,  0.5779372506,  0.3299156197,  0.5534048504,
#  -0.2554438264,  0.3383769687,  0.6895419866,  0.4903610315,  0.1782447546,
#   0.0915727898,  0.6053767128,  0.8164664622]
# ----------------------------------------------------------------------------------------------------
#
# Run 30
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 179
# Optimized Value   : 0.46960000
# Evaluated Mean    : 0.45199500
# Evaluated Std     : 0.00001245
# Evaluated Min     : 0.45197000
# Evaluated Max     : 0.45202000
# Success           : False
# Reached MaxIter   : False
# Status            : 2
# Message           : Desired error not necessarily achieved due to precision loss.
# Iterations        : 20
# Function Evals    : 3522
# Gradient Evals    : 121
# Optimization Time : 422.866479 s
#
# Evaluated Values:
# [0.45197, 0.45198, 0.45199, 0.45199, 0.452  , 0.45199, 0.45199, 0.45199,
#  0.45199, 0.45199, 0.45199, 0.452  , 0.45201, 0.45202, 0.45202, 0.45201,
#  0.452  , 0.452  , 0.45199, 0.45198]
#
# Initial Parameters:
# [0.9180695286, 0.9403935557, 0.9611445873, 0.1282735573, 0.7343854482,
#  0.1418537547, 0.3206870255, 0.8783134777, 0.3925501756, 0.9542827898,
#  0.4333144504, 0.0052152104, 0.5921889116, 0.318609756 , 0.9316370681,
#  0.6026668473, 0.0078690534, 0.7991305598, 0.851774691 , 0.06652901  ,
#  0.7310172927, 0.1064287992, 0.0810809173, 0.7115609048, 0.7069595409,
#  0.496652521 , 0.9897356485, 0.1231137075]
#
# Optimal Parameters:
# [ 0.1328028281,  1.7054698017,  0.5697566421, -0.3327437965,  0.1435245456,
#  -0.1770066198,  2.6231996644,  0.5966082638,  1.4289665087,  0.3320763969,
#   0.4333144504,  0.0052152104,  1.4263086866,  0.730576727 ,  1.325462981 ,
#  -0.3161210531,  0.4959804941,  0.3802370194, -0.1479257983, -0.3858445495,
#   2.261282006 , -0.2928056195,  0.0810809173,  0.7115609048,  0.4601785783,
#   0.496652521 ,  0.9897356485,  0.1231137075]
# ----------------------------------------------------------------------------------------------------
#
# SUMMARY
# ====================================================================================================
#
# Original Optimization-Shot Results:
# Maximum Optimized Value : 0.94470000
# Maximum Run             : 17
# Mean Optimized Value    : 0.60771333
# Std Optimized Value     : 0.16324775
#
# High-Shot Evaluation Results:
# Best Evaluated Mean     : 0.94127800
# Best Evaluated Mean Run : 17
# Mean of Evaluated Means : 0.59965693
# Std of Evaluated Means  : 0.16408006
#
# Optimizer Statistics:
# Mean Iterations         : 19.87
# Std Iterations          : 14.57
# Mean Function Evals     : 2359.10
# Std Function Evals      : 879.59
# Mean Gradient Evals     : 80.93
# Std Gradient Evals      : 30.32
# Successful Runs         : 0/30
# Failed Runs             : 30/30
# Reached MaxIter         : 0/30
#
# Computational Runtime Statistics:
# Total Wall-Clock Time          : 8821.403234 s
# Total Optimization Time        : 8451.436132 s
# Time per Complete Opt. Run     : 281.714538 s
# Std Optimization Time per Run  : 105.124864 s
#
# ====================================================================================================
# BEST RUN ACCORDING TO ORIGINAL OPTIMIZED VALUE
# ====================================================================================================
# Run             : 17
# Optimized Value : 0.94470000
# Evaluated Mean  : 0.94127800
# Evaluated Std   : 0.00000400
# Evaluated Min   : 0.94127000
# Evaluated Max   : 0.94128000
#
# Evaluated Values:
# [0.94127, 0.94127, 0.94127, 0.94127, 0.94128, 0.94128, 0.94128, 0.94128,
#  0.94128, 0.94128, 0.94128, 0.94128, 0.94128, 0.94128, 0.94128, 0.94128,
#  0.94128, 0.94128, 0.94128, 0.94128]
#
# Initial Parameters:
# [0.7162412684, 0.1693989446, 0.7052765596, 0.2312009266, 0.9423502042,
#  0.6728407104, 0.4350288739, 0.1490473433, 0.3371571605, 0.9369448933,
#  0.3373395547, 0.961351198 , 0.4707410022, 0.7024076892, 0.9419588348,
#  0.0183954332, 0.0077587191, 0.4818001667, 0.7262090741, 0.616799371 ,
#  0.6107607858, 0.4676317986, 0.0873035913, 0.3932966427, 0.2402358413,
#  0.6880719084, 0.6456336481, 0.6554428034]
#
# Optimal Parameters:
# [ 3.0974069897, -0.0409225593, -0.038345319 , -1.6033313309, -3.2131400304,
#   3.2100835291,  3.2761058932, -0.0165183155,  0.721696819 ,  0.1442460961,
#   0.3373395547,  0.961351198 ,  0.7537903298,  1.6613885583,  2.6787154176,
#   0.2747475512, -3.1851657325, -0.0884585819,  2.4276117894,  0.3641969212,
#   2.3221794054, -0.2498960722,  0.0873035913,  0.3932966427, -0.1589720256,
#   1.0676448509,  0.6456336481,  0.6554428034]
#
# ====================================================================================================
# BEST RUN ACCORDING TO HIGH-SHOT EVALUATED MEAN
# ====================================================================================================
# Run             : 17
# Optimized Value : 0.94470000
# Evaluated Mean  : 0.94127800
# Evaluated Std   : 0.00000400
# Evaluated Min   : 0.94127000
# Evaluated Max   : 0.94128000
#
# Evaluated Values:
# [0.94127, 0.94127, 0.94127, 0.94127, 0.94128, 0.94128, 0.94128, 0.94128,
#  0.94128, 0.94128, 0.94128, 0.94128, 0.94128, 0.94128, 0.94128, 0.94128,
#  0.94128, 0.94128, 0.94128, 0.94128]
#
# Initial Parameters:
# [0.7162412684, 0.1693989446, 0.7052765596, 0.2312009266, 0.9423502042,
#  0.6728407104, 0.4350288739, 0.1490473433, 0.3371571605, 0.9369448933,
#  0.3373395547, 0.961351198 , 0.4707410022, 0.7024076892, 0.9419588348,
#  0.0183954332, 0.0077587191, 0.4818001667, 0.7262090741, 0.616799371 ,
#  0.6107607858, 0.4676317986, 0.0873035913, 0.3932966427, 0.2402358413,
#  0.6880719084, 0.6456336481, 0.6554428034]
#
# Optimal Parameters:
# [ 3.0974069897, -0.0409225593, -0.038345319 , -1.6033313309, -3.2131400304,
#   3.2100835291,  3.2761058932, -0.0165183155,  0.721696819 ,  0.1442460961,
#   0.3373395547,  0.961351198 ,  0.7537903298,  1.6613885583,  2.6787154176,
#   0.2747475512, -3.1851657325, -0.0884585819,  2.4276117894,  0.3641969212,
#   2.3221794054, -0.2498960722,  0.0873035913,  0.3932966427, -0.1589720256,
#   1.0676448509,  0.6456336481,  0.6554428034]
# ====================================================================================================
#
# Report saved to:
# /Users/sungwonyun/Documents/Qiskit/Minimum Error Discrimination/Opitmizer Sensitivity Test/BFGS_report.txt
