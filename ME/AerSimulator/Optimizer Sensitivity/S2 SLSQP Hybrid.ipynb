# %%
# 0,1: 00 for psi_1, 01 for psi_2 ...
# 2,3: For states
# 4,5: Ancillary qubits

# %%
from qiskit import QuantumCircuit
from numpy import sqrt

def circuit_init():
    qc = QuantumCircuit(6)
    return qc

def PREP(qc):
    desired_vector = [
        1/sqrt(3), 0, 0, 0,
        1/(4*sqrt(3)), 1/4, 1/4, sqrt(3)/4,
        1/(4*sqrt(3)), -1/4, -1/4, sqrt(3)/4,
        0, 0, 0, 0
    ]
    qc.initialize(desired_vector, [3,2,1,0])
    return qc

# %%
from qiskit.circuit.library.standard_gates import RXGate,RYGate, RZGate
from qiskit.circuit.library import MCXGate
from qiskit.circuit.library.standard_gates import XGate
from pennylane.templates.state_preparations.mottonen import compute_theta, gray_code
from numpy import array, log2

def RR_X(qc, wires, params):
    qc.append(RXGate(params[0]),[wires[0]])
    qc.append(RXGate(params[1]),[wires[1]])

def RR_Z(qc, wires, params):
    qc.append(RZGate(params[0]),[wires[0]])
    qc.append(RZGate(params[1]),[wires[1]])


def CRR_X(qc, wires, state, params):
    qc.append(RXGate(params[0]).control(1,ctrl_state = state[::-1]), [wires[0], wires[1]])  # Control: wires[0] Target: wires[1]
    qc.append(RXGate(params[1]).control(1,ctrl_state = state[::-1]), [wires[0], wires[2]])  # Control: wires[0] Target: wires[2]
    return qc

def CRR_Z(qc, wires, state, params):
    qc.append(RZGate(params[0]).control(1,ctrl_state = state[::-1]), [wires[0], wires[1]])  # Control: wires[0] Target: wires[1]
    qc.append(RZGate(params[1]).control(1,ctrl_state = state[::-1]), [wires[0], wires[2]])  # Control: wires[0] Target: wires[2]
    return qc

def CCRR_X(qc, wires, state, params):
    qc.append(RXGate(params[0]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[2]])  # Control: wires[0] wires[1]
    qc.append(RXGate(params[1]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[3]])  # Control: wires[0] wires[1]
    return qc

def CCRR_Z(qc, wires, state, params):
    qc.append(RZGate(params[0]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[2]])  # Control: wires[0] wires[1]
    qc.append(RZGate(params[1]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[3]])  # Control: wires[0] wires[1]
    return qc

def U_CCR_decom(qc,wires,params):
    # Make sure that control qubits should be increasing order
    params = array(params)
    params = compute_theta(params) #can be on/off

    num_Ucontrols = len(wires)-1
    code = gray_code(2)
    n_selections = len(code)

    control_order = [int(log2(int(code[i], 2) ^ int(code[(i + 1) % n_selections], 2))) for i in range(n_selections)]

    for i in range(n_selections):
        qc.ry(params[i],wires[2])
        qc.cx(wires[num_Ucontrols-1 - control_order[i]],wires[2])
    return qc

def U_CCcR_decom(qc,wires,params):
    # Make sure that control qubits should be increasing order
    params = array(params)
    params = compute_theta(params) #can be on/off

    num_Ucontrols = len(wires)-2
    code = gray_code(2)
    n_selections = len(code)
    control_order = [int(log2(int(code[i], 2) ^ int(code[(i + 1) % n_selections], 2))) for i in range(n_selections)]

    for i in range(n_selections):
        qc.cry(params[i],wires[2],wires[3])
        CCX(qc,[wires[num_Ucontrols-1 - control_order[i]],wires[2],wires[3]],'11')

    return qc

def CCX(qc, wires, state):
    mcx_gate = MCXGate(num_ctrl_qubits=2,ctrl_state=state[::-1])
    qc.append(mcx_gate, [wires[0], wires[1],wires[2]])
    return qc

def CCCX(qc, wires, state):
    mcx_gate = MCXGate(num_ctrl_qubits=3,ctrl_state=state[::-1])
    qc.append(mcx_gate, [wires[0], wires[1],wires[2], wires[3]])
    return qc

def CX01(qc, wires):
    qc.append(
        XGate().control(1, ctrl_state='1'),
        [wires[0], wires[1]])
    return qc

# %%
from qiskit.circuit.library.standard_gates import RYGate

from numpy import pi


def Ansatz(qc, wires, params):


    #Big made by HEA
    RR_X(qc,wires[0:2],params[0:2])
    RR_Z(qc,wires[0:2],params[2:4])
    qc.cx(wires[0],wires[1])

    #Module 1
    U_CCR_decom(qc,wires[0:3],params[4:8])
    CRR_X(qc,[wires[2],wires[0],wires[1]],'0',params[8:10])
    CRR_Z(qc,[wires[2],wires[0],wires[1]],'0',params[10:12])
    CCX(qc,[wires[0],wires[2], wires[1]],'10')
    CRR_X(qc,[wires[2],wires[0],wires[1]],'1',params[12:14])
    CRR_Z(qc,[wires[2],wires[0],wires[1]],'1',params[14:16])
    CCX(qc,[wires[0],wires[2], wires[1]],'11')

    #Module 2
    U_CCcR_decom(qc, wires[0:4],params[16:20])
    CCRR_X(qc,[wires[2],wires[3],wires[0],wires[1]],'10',params[20:22])
    CCRR_Z(qc,[wires[2],wires[3],wires[0],wires[1]],'10',params[22:24])
    CCCX(qc,[wires[0],wires[2],wires[3],wires[1]],'110')
    CCRR_X(qc,[wires[2],wires[3],wires[0],wires[1]],'11',params[24:26])
    CCRR_Z(qc,[wires[2],wires[3],wires[0],wires[1]],'11',params[26:28])
    CCCX(qc,[wires[0],wires[2],wires[3],wires[1]],'111')

    CX01(qc, [wires[3],wires[2]])
    qc.measure_all()
    return qc

# %%
from numpy.random import rand
num_params=28
params = list(range(num_params))
qc = QuantumCircuit(4)
#PREP(qc)
Ansatz(qc, [0,1,2,3] , params)
qc.draw(output='mpl', style = 'clifford')

# %%
from qiskit_aer import AerSimulator
from qiskit import transpile
from scipy.optimize import minimize

import numpy as np
import os
import time


# ============================================================
# Simulator
# ============================================================

aersim = AerSimulator()


# ============================================================
# Settings
# ============================================================

num_times = 30
num_shots = 10000

optimizer_name = "SLSQP"

maxiter = 70

# SLSQP convergence tolerance
ftol = 1e-6
eps = 1e-2

BASE_SEED = 150

report_filename = f"{optimizer_name}_report.txt"

# ============================================================
# High-Shot Evaluation Settings
# ============================================================

evaluation_num_times = 20
evaluation_num_shots = 100000

EVALUATION_BASE_SEED = 10000

evaluation_seeds = np.array(
    [
        EVALUATION_BASE_SEED + i
        for i in range(evaluation_num_times)
    ],
    dtype=int
)


# ============================================================
# Storage
# ============================================================

final_optimized_values = []

initial_params_all_runs = []
optimal_params_all_runs = []

optimization_success_all_runs = []
optimization_status_all_runs = []
optimization_message_all_runs = []

optimization_nit_all_runs = []
optimization_nfev_all_runs = []
optimization_njev_all_runs = []

reached_maxiter_all_runs = []

# ------------------------------------------------------------
# Runtime Storage
# ------------------------------------------------------------

optimization_wall_times = []


# ------------------------------------------------------------
# High-Shot Evaluation Storage
# ------------------------------------------------------------

evaluation_values_all_runs = []

evaluation_mean_all_runs = []
evaluation_std_all_runs = []
evaluation_min_all_runs = []
evaluation_max_all_runs = []


# ============================================================
# Objective Function
# ============================================================

def objective_function(
    params,
    run_seed,
    shots=None,
    print_result=True
):

    if shots is None:
        shots = num_shots


    # --------------------------------------------------------
    # Build circuit
    # --------------------------------------------------------

    qc = circuit_init()

    PREP(qc)

    Ansatz(
        qc,
        [2, 3, 4, 5],
        params
    )


    # --------------------------------------------------------
    # Reverse bit ordering
    # --------------------------------------------------------

    qc_reverse = qc.reverse_bits()


    # --------------------------------------------------------
    # Transpile
    # --------------------------------------------------------

    t_qc = transpile(
        qc_reverse,
        aersim,
        seed_transpiler=run_seed
    )


    # --------------------------------------------------------
    # Run simulator
    # --------------------------------------------------------

    job = aersim.run(
        t_qc,
        shots=shots,
        seed_simulator=run_seed
    )


    result = job.result()

    counts = result.get_counts()


    # --------------------------------------------------------
    # Count successful outcomes
    # --------------------------------------------------------

    tar_00 = 0
    tar_01 = 0
    tar_10 = 0


    for outcome, count in counts.items():

        # Target 00
        if outcome[0:2] == "00":

            if outcome[4:6] == "00":

                tar_00 += count


        # Target 01
        if outcome[0:2] == "01":

            if outcome[4:6] == "01":

                tar_01 += count


        # Target 10
        if outcome[0:2] == "10":

            if outcome[4:6] == "10":

                tar_10 += count


    # --------------------------------------------------------
    # Success probability
    # --------------------------------------------------------

    p_suc = (
        tar_00
        + tar_01
        + tar_10
    ) / shots


    if print_result:

        print(
            f"success_probability = "
            f"{p_suc:.8f}"
        )


    # --------------------------------------------------------
    # SLSQP minimizes.
    #
    # We want to maximize p_suc,
    # therefore minimize 1 / p_suc.
    # --------------------------------------------------------

    if p_suc == 0:

        return 1e10


    return 1.0 / p_suc


# ============================================================
# Run Optimization
# ============================================================

# Measures the complete workflow:
# optimization + final evaluations + high-shot evaluations + overhead.
total_wall_start = time.perf_counter()

for run in range(num_times):


    # ========================================================
    # Optimization Seed
    # ========================================================

    run_seed = (
        BASE_SEED + run
    )


    rng = np.random.default_rng(
        run_seed
    )


    print(
        "\n"
        + "=" * 80
    )


    print(
        f"Optimization Run "
        f"{run + 1}/{num_times}"
    )


    print(
        f"Optimization Seed : "
        f"{run_seed}"
    )


    print(
        "=" * 80
    )


    # ========================================================
    # Generate Random Initial Parameters
    # ========================================================

    initial_params = rng.random(
        num_params
    )


    initial_params_all_runs.append(
        initial_params.copy()
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    # ========================================================
    # Run SLSQP Optimization
    # ========================================================

    print(
        "\nStarting SLSQP optimization..."
    )


    optimization_start = time.perf_counter()

    result = minimize(

        fun=lambda params: objective_function(
            params,
            run_seed,
            shots=num_shots,
            print_result=True
        ),

        x0=initial_params,

        method=optimizer_name,

        options={
            "maxiter": maxiter,
            "ftol": ftol,
            "eps": eps,
            "disp": True
        }
    )

    optimization_end = time.perf_counter()

    run_optimization_wall_time = (
        optimization_end
        - optimization_start
    )

    optimization_wall_times.append(
        run_optimization_wall_time
    )

    print(
        f"Optimization Wall-Clock Time : "
        f"{run_optimization_wall_time:.6f} s"
    )


    # ========================================================
    # Optimization Status
    # ========================================================

    optimization_success = bool(
        result.success
    )


    optimization_status = getattr(
        result,
        "status",
        None
    )


    optimization_message = str(
        getattr(
            result,
            "message",
            "No message returned"
        )
    )


    optimization_nit = getattr(
        result,
        "nit",
        None
    )


    optimization_nfev = getattr(
        result,
        "nfev",
        None
    )


    optimization_njev = getattr(
        result,
        "njev",
        None
    )


    # ========================================================
    # Detect Maximum Iteration Limit
    # ========================================================

    message_lower = (
        optimization_message.lower()
    )


    reached_maxiter = (

        "maximum number"
        in message_lower

        or "maximum iteration"
        in message_lower

        or "maximum iterations"
        in message_lower

        or "iteration limit"
        in message_lower

        or "maxiter"
        in message_lower
    )


    if optimization_nit is not None:

        if optimization_nit >= maxiter:

            reached_maxiter = True


    # ========================================================
    # Store Optimization Status
    # ========================================================

    optimization_success_all_runs.append(
        optimization_success
    )


    optimization_status_all_runs.append(
        optimization_status
    )


    optimization_message_all_runs.append(
        optimization_message
    )


    optimization_nit_all_runs.append(
        optimization_nit
    )


    optimization_nfev_all_runs.append(
        optimization_nfev
    )


    optimization_njev_all_runs.append(
        optimization_njev
    )


    reached_maxiter_all_runs.append(
        reached_maxiter
    )


    # ========================================================
    # Optimal Parameters
    # ========================================================

    optimal_params = (
        result.x.copy()
    )


    optimal_params_all_runs.append(
        optimal_params.copy()
    )


    # ========================================================
    # Final Optimization-Shot Evaluation
    #
    # Uses:
    #   shots = 10,000
    #   seed  = optimization run seed
    # ========================================================

    final_objective = objective_function(
        optimal_params,
        run_seed,
        shots=num_shots,
        print_result=False
    )


    if final_objective >= 1e10:

        final_value = 0.0

    else:

        final_value = (
            1.0 / final_objective
        )


    final_optimized_values.append(
        final_value
    )


    # ========================================================
    # High-Shot Evaluation
    # ========================================================

    print(
        "\n"
        + "-" * 80
    )


    print(
        "HIGH-SHOT EVALUATION OF "
        "OPTIMIZED PARAMETERS"
    )


    print(
        "-" * 80
    )


    print(
        f"Optimization Shots     : "
        f"{num_shots}"
    )


    print(
        f"Evaluation Shots       : "
        f"{evaluation_num_shots}"
    )


    print(
        f"Number of Evaluations : "
        f"{evaluation_num_times}"
    )


    print(
        "\nEvaluation Results:"
    )


    evaluation_values = []


    # --------------------------------------------------------
    # The same 20 evaluation seeds are used for every
    # optimized parameter set.
    #
    # Seed values themselves are not printed here.
    # --------------------------------------------------------

    for eval_index, eval_seed in enumerate(
        evaluation_seeds
    ):


        eval_objective = objective_function(
            optimal_params,
            int(eval_seed),
            shots=evaluation_num_shots,
            print_result=False
        )


        if eval_objective >= 1e10:

            eval_value = 0.0

        else:

            eval_value = (
                1.0 / eval_objective
            )


        evaluation_values.append(
            eval_value
        )


        print(
            f"Evaluation "
            f"{eval_index + 1:2d}/"
            f"{evaluation_num_times:2d}"
            f" | Value = "
            f"{eval_value:.8f}"
        )


    # ========================================================
    # Evaluation Statistics
    # ========================================================

    evaluation_values = np.array(
        evaluation_values,
        dtype=float
    )


    evaluation_mean = np.mean(
        evaluation_values
    )


    evaluation_std = np.std(
        evaluation_values
    )


    evaluation_min = np.min(
        evaluation_values
    )


    evaluation_max = np.max(
        evaluation_values
    )


    # ========================================================
    # Store Evaluation Results
    # ========================================================

    evaluation_values_all_runs.append(
        evaluation_values.copy()
    )


    evaluation_mean_all_runs.append(
        evaluation_mean
    )


    evaluation_std_all_runs.append(
        evaluation_std
    )


    evaluation_min_all_runs.append(
        evaluation_min
    )


    evaluation_max_all_runs.append(
        evaluation_max
    )


    # ========================================================
    # Individual Run Report
    # ========================================================

    print(
        "\n"
        + "=" * 80
    )


    print(
        f"RUN {run + 1} RESULT"
    )


    print(
        "=" * 80
    )


    print(
        f"Optimization Success : "
        f"{optimization_success}"
    )


    print(
        f"Reached MaxIter      : "
        f"{reached_maxiter}"
    )


    print(
        f"Status               : "
        f"{optimization_status}"
    )


    print(
        f"Message              : "
        f"{optimization_message}"
    )


    print(
        f"Iterations           : "
        f"{optimization_nit}"
    )


    print(
        f"Function Evaluations : "
        f"{optimization_nfev}"
    )


    print(
        f"Gradient Evaluations : "
        f"{optimization_njev}"
    )


    print(
        f"Optimization Time    : "
        f"{run_optimization_wall_time:.6f} s"
    )


    print(
        f"Final Objective Value: "
        f"{result.fun}"
    )


    print(
        "\n"
        + "-" * 80
    )


    print(
        "OPTIMIZED AND HIGH-SHOT "
        "EVALUATED VALUES"
    )


    print(
        "-" * 80
    )


    print(
        f"Final Optimized Value : "
        f"{final_value:.8f}"
    )


    print(
        f"Evaluated Mean        : "
        f"{evaluation_mean:.8f}"
    )


    print(
        f"Evaluated Std         : "
        f"{evaluation_std:.8f}"
    )


    print(
        f"Evaluated Min         : "
        f"{evaluation_min:.8f}"
    )


    print(
        f"Evaluated Max         : "
        f"{evaluation_max:.8f}"
    )


    print(
        "\nAll Evaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values,
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "=" * 80
    )


# ============================================================
# Runtime Statistics
# ============================================================

total_wall_end = time.perf_counter()

total_wall_time = (
    total_wall_end
    - total_wall_start
)

optimization_wall_times = np.array(
    optimization_wall_times,
    dtype=float
)

total_optimization_wall_time = np.sum(
    optimization_wall_times
)

mean_optimization_wall_time = np.mean(
    optimization_wall_times
)

std_optimization_wall_time = np.std(
    optimization_wall_times
)


# ============================================================
# Convert Results to NumPy Arrays
# ============================================================

final_optimized_values = np.array(
    final_optimized_values,
    dtype=float
)


initial_params_all_runs = np.array(
    initial_params_all_runs
)


optimal_params_all_runs = np.array(
    optimal_params_all_runs
)


evaluation_values_all_runs = np.array(
    evaluation_values_all_runs,
    dtype=float
)


evaluation_mean_all_runs = np.array(
    evaluation_mean_all_runs,
    dtype=float
)


evaluation_std_all_runs = np.array(
    evaluation_std_all_runs,
    dtype=float
)


evaluation_min_all_runs = np.array(
    evaluation_min_all_runs,
    dtype=float
)


evaluation_max_all_runs = np.array(
    evaluation_max_all_runs,
    dtype=float
)


# ============================================================
# Original Optimization Statistics
# ============================================================

maximum_value = np.max(
    final_optimized_values
)


mean_value = np.mean(
    final_optimized_values
)


std_value = np.std(
    final_optimized_values
)


maximum_run_index = np.argmax(
    final_optimized_values
)


maximum_run = (
    maximum_run_index
    + 1
)


# ============================================================
# High-Shot Evaluation Statistics
# ============================================================

maximum_evaluated_mean = np.max(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run_index = np.argmax(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run = (
    maximum_evaluated_mean_run_index
    + 1
)


mean_of_evaluated_means = np.mean(
    evaluation_mean_all_runs
)


std_of_evaluated_means = np.std(
    evaluation_mean_all_runs
)


# ============================================================
# Iteration Statistics
# ============================================================

nit_values = np.array(
    [
        nit
        for nit
        in optimization_nit_all_runs
        if nit is not None
    ],
    dtype=float
)


if len(nit_values) > 0:

    mean_nit = np.mean(
        nit_values
    )


    std_nit = np.std(
        nit_values
    )

else:

    mean_nit = np.nan
    std_nit = np.nan


# ============================================================
# Function Evaluation Statistics
# ============================================================

nfev_values = np.array(
    [
        nfev
        for nfev
        in optimization_nfev_all_runs
        if nfev is not None
    ],
    dtype=float
)


if len(nfev_values) > 0:

    mean_nfev = np.mean(
        nfev_values
    )


    std_nfev = np.std(
        nfev_values
    )

else:

    mean_nfev = np.nan
    std_nfev = np.nan


# ============================================================
# Gradient Evaluation Statistics
# ============================================================

njev_values = np.array(
    [
        njev
        for njev
        in optimization_njev_all_runs
        if njev is not None
    ],
    dtype=float
)


if len(njev_values) > 0:

    mean_njev = np.mean(
        njev_values
    )


    std_njev = np.std(
        njev_values
    )

else:

    mean_njev = np.nan
    std_njev = np.nan


# ============================================================
# Optimization Success Statistics
# ============================================================

num_successful_runs = sum(
    optimization_success_all_runs
)


num_failed_runs = (
    num_times
    - num_successful_runs
)


num_reached_maxiter = sum(
    reached_maxiter_all_runs
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

best_initial_params = (
    initial_params_all_runs[
        maximum_run_index
    ]
)


best_optimal_params = (
    optimal_params_all_runs[
        maximum_run_index
    ]
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

best_evaluated_initial_params = (
    initial_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_optimal_params = (
    optimal_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_values = (
    evaluation_values_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


# ============================================================
# Print Final Report
# ============================================================

print("\n")


print(
    "=" * 100
)


print(
    "FINAL OPTIMIZATION AND "
    "HIGH-SHOT EVALUATION REPORT"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Settings
# ------------------------------------------------------------

print(
    f"Optimizer               : "
    f"{optimizer_name}"
)


print(
    f"f Tolerance             : "
    f"{ftol}"
)


print(
    f"Max Iteration           : "
    f"{maxiter}"
)


print(
    f"Number of Runs          : "
    f"{num_times}"
)


print(
    f"Optimization Shots      : "
    f"{num_shots}"
)


print(
    f"Optimization Base Seed  : "
    f"{BASE_SEED}"
)


print(
    f"Evaluation Shots        : "
    f"{evaluation_num_shots}"
)


print(
    f"Evaluations Per Run     : "
    f"{evaluation_num_times}"
)


print(
    f"Evaluation Base Seed    : "
    f"{EVALUATION_BASE_SEED}"
)


# Evaluation seeds printed ONCE only.
print(
    "Evaluation Seeds        : "
    + np.array2string(
        evaluation_seeds,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Results for Every Run
# ============================================================

for i in range(num_times):


    print(
        f"\nRun {i + 1:2d}"
    )


    print(
        "-" * 100
    )


    print(
        f"Optimization Seed : "
        f"{BASE_SEED + i}"
    )


    print(
        f"Optimized Value   : "
        f"{final_optimized_values[i]:.8f}"
    )


    print(
        f"Evaluated Mean    : "
        f"{evaluation_mean_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Std     : "
        f"{evaluation_std_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Min     : "
        f"{evaluation_min_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Max     : "
        f"{evaluation_max_all_runs[i]:.8f}"
    )


    print(
        f"Success           : "
        f"{optimization_success_all_runs[i]}"
    )


    print(
        f"Reached MaxIter   : "
        f"{reached_maxiter_all_runs[i]}"
    )


    print(
        f"Status            : "
        f"{optimization_status_all_runs[i]}"
    )


    print(
        f"Message           : "
        f"{optimization_message_all_runs[i]}"
    )


    print(
        f"Iterations        : "
        f"{optimization_nit_all_runs[i]}"
    )


    print(
        f"Function Evals    : "
        f"{optimization_nfev_all_runs[i]}"
    )


    print(
        f"Gradient Evals    : "
        f"{optimization_njev_all_runs[i]}"
    )


    print(
        f"Optimization Time : "
        f"{optimization_wall_times[i]:.6f} s"
    )


    print(
        "\nEvaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values_all_runs[i],
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "-" * 100
    )


# ============================================================
# Summary
# ============================================================

print(
    "\nSUMMARY"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Original Optimization-Shot Results
# ------------------------------------------------------------

print(
    "\nOriginal Optimization-Shot Results:"
)


print(
    f"Maximum Optimized Value : "
    f"{maximum_value:.8f}"
)


print(
    f"Maximum Run             : "
    f"{maximum_run}"
)


print(
    f"Mean Optimized Value    : "
    f"{mean_value:.8f}"
)


print(
    f"Std Optimized Value     : "
    f"{std_value:.8f}"
)


# ------------------------------------------------------------
# High-Shot Evaluation Results
# ------------------------------------------------------------

print(
    "\nHigh-Shot Evaluation Results:"
)


print(
    f"Best Evaluated Mean     : "
    f"{maximum_evaluated_mean:.8f}"
)


print(
    f"Best Evaluated Mean Run : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Mean of Evaluated Means : "
    f"{mean_of_evaluated_means:.8f}"
)


print(
    f"Std of Evaluated Means  : "
    f"{std_of_evaluated_means:.8f}"
)


# ------------------------------------------------------------
# Optimizer Statistics
# ------------------------------------------------------------

print(
    "\nOptimizer Statistics:"
)


print(
    f"Mean Iterations         : "
    f"{mean_nit:.2f}"
)


print(
    f"Std Iterations          : "
    f"{std_nit:.2f}"
)


print(
    f"Mean Function Evals     : "
    f"{mean_nfev:.2f}"
)


print(
    f"Std Function Evals      : "
    f"{std_nfev:.2f}"
)


print(
    f"Mean Gradient Evals     : "
    f"{mean_njev:.2f}"
)


print(
    f"Std Gradient Evals      : "
    f"{std_njev:.2f}"
)


print(
    f"Successful Runs         : "
    f"{num_successful_runs}/"
    f"{num_times}"
)


print(
    f"Failed Runs             : "
    f"{num_failed_runs}/"
    f"{num_times}"
)


print(
    f"Reached MaxIter         : "
    f"{num_reached_maxiter}/"
    f"{num_times}"
)


# ------------------------------------------------------------
# Computational Runtime Statistics
# ------------------------------------------------------------

print(
    "\nComputational Runtime Statistics:"
)

print(
    f"Total Wall-Clock Time          : "
    f"{total_wall_time:.6f} s"
)

print(
    f"Total Optimization Time        : "
    f"{total_optimization_wall_time:.6f} s"
)

print(
    f"Time per Complete Opt. Run     : "
    f"{mean_optimization_wall_time:.6f} s"
)

print(
    f"Std Optimization Time per Run  : "
    f"{std_optimization_wall_time:.6f} s"
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "ORIGINAL OPTIMIZED VALUE"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        evaluation_values_all_runs[
            maximum_run_index
        ],
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_optimal_params,
        precision=10,
        separator=", "
    )
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "HIGH-SHOT EVALUATED MEAN"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        best_evaluated_values,
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_evaluated_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_evaluated_optimal_params,
        precision=10,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Save Report to TXT
# ============================================================

with open(
    report_filename,
    "w"
) as f:


    # ========================================================
    # Header
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "FINAL OPTIMIZATION AND "
        "HIGH-SHOT EVALUATION REPORT\n"
    )


    f.write(
        "=" * 100
        + "\n\n"
    )


    # ========================================================
    # Settings
    # ========================================================

    f.write(
        f"Optimizer               : "
        f"{optimizer_name}\n"
    )


    f.write(
        f"f Tolerance             : "
        f"{ftol}\n"
    )


    f.write(
        f"Max Iteration           : "
        f"{maxiter}\n"
    )


    f.write(
        f"Number of Runs          : "
        f"{num_times}\n"
    )


    f.write(
        f"Optimization Shots      : "
        f"{num_shots}\n"
    )


    f.write(
        f"Optimization Base Seed  : "
        f"{BASE_SEED}\n"
    )


    f.write(
        f"Evaluation Shots        : "
        f"{evaluation_num_shots}\n"
    )


    f.write(
        f"Evaluations Per Run     : "
        f"{evaluation_num_times}\n"
    )


    f.write(
        f"Evaluation Base Seed    : "
        f"{EVALUATION_BASE_SEED}\n"
    )


    # Evaluation seeds saved ONCE only.
    f.write(
        "Evaluation Seeds        : "
    )


    f.write(
        np.array2string(
            evaluation_seeds,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    # ========================================================
    # Results for Every Run
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "RESULTS FOR EACH RUN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    for i in range(num_times):


        f.write(
            f"\nRun {i + 1:2d}\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


        f.write(
            f"Optimization Seed : "
            f"{BASE_SEED + i}\n"
        )


        f.write(
            f"Optimized Value   : "
            f"{final_optimized_values[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Mean    : "
            f"{evaluation_mean_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Std     : "
            f"{evaluation_std_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Min     : "
            f"{evaluation_min_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Max     : "
            f"{evaluation_max_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Success           : "
            f"{optimization_success_all_runs[i]}\n"
        )


        f.write(
            f"Reached MaxIter   : "
            f"{reached_maxiter_all_runs[i]}\n"
        )


        f.write(
            f"Status            : "
            f"{optimization_status_all_runs[i]}\n"
        )


        f.write(
            f"Message           : "
            f"{optimization_message_all_runs[i]}\n"
        )


        f.write(
            f"Iterations        : "
            f"{optimization_nit_all_runs[i]}\n"
        )


        f.write(
            f"Function Evals    : "
            f"{optimization_nfev_all_runs[i]}\n"
        )


        f.write(
            f"Gradient Evals    : "
            f"{optimization_njev_all_runs[i]}\n"
        )


        f.write(
            f"Optimization Time : "
            f"{optimization_wall_times[i]:.6f} s\n"
        )


        f.write(
            "\nEvaluated Values:\n"
        )


        f.write(
            np.array2string(
                evaluation_values_all_runs[i],
                precision=8,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nInitial Parameters:\n"
        )


        f.write(
            np.array2string(
                initial_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nOptimal Parameters:\n"
        )


        f.write(
            np.array2string(
                optimal_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


    # ========================================================
    # Summary
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "SUMMARY\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    # --------------------------------------------------------
    # Original Optimization-Shot Results
    # --------------------------------------------------------

    f.write(
        "\nOriginal Optimization-Shot Results:\n"
    )


    f.write(
        f"Maximum Optimized Value : "
        f"{maximum_value:.8f}\n"
    )


    f.write(
        f"Maximum Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Mean Optimized Value    : "
        f"{mean_value:.8f}\n"
    )


    f.write(
        f"Std Optimized Value     : "
        f"{std_value:.8f}\n"
    )


    # --------------------------------------------------------
    # High-Shot Evaluation Results
    # --------------------------------------------------------

    f.write(
        "\nHigh-Shot Evaluation Results:\n"
    )


    f.write(
        f"Best Evaluated Mean     : "
        f"{maximum_evaluated_mean:.8f}\n"
    )


    f.write(
        f"Best Evaluated Mean Run : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Mean of Evaluated Means : "
        f"{mean_of_evaluated_means:.8f}\n"
    )


    f.write(
        f"Std of Evaluated Means  : "
        f"{std_of_evaluated_means:.8f}\n"
    )


    # --------------------------------------------------------
    # Optimizer Statistics
    # --------------------------------------------------------

    f.write(
        "\nOptimizer Statistics:\n"
    )


    f.write(
        f"Mean Iterations         : "
        f"{mean_nit:.2f}\n"
    )


    f.write(
        f"Std Iterations          : "
        f"{std_nit:.2f}\n"
    )


    f.write(
        f"Mean Function Evals     : "
        f"{mean_nfev:.2f}\n"
    )


    f.write(
        f"Std Function Evals      : "
        f"{std_nfev:.2f}\n"
    )


    f.write(
        f"Mean Gradient Evals     : "
        f"{mean_njev:.2f}\n"
    )


    f.write(
        f"Std Gradient Evals      : "
        f"{std_njev:.2f}\n"
    )


    f.write(
        f"Successful Runs         : "
        f"{num_successful_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Failed Runs             : "
        f"{num_failed_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Reached MaxIter         : "
        f"{num_reached_maxiter}/"
        f"{num_times}\n"
    )


    # --------------------------------------------------------
    # Computational Runtime Statistics
    # --------------------------------------------------------

    f.write(
        "\nComputational Runtime Statistics:\n"
    )

    f.write(
        f"Total Wall-Clock Time          : "
        f"{total_wall_time:.6f} s\n"
    )

    f.write(
        f"Total Optimization Time        : "
        f"{total_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Time per Complete Opt. Run     : "
        f"{mean_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Std Optimization Time per Run  : "
        f"{std_optimization_wall_time:.6f} s\n"
    )


    # ========================================================
    # Best Run According to Original Optimized Value
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "ORIGINAL OPTIMIZED VALUE\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            evaluation_values_all_runs[
                maximum_run_index
            ],
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    # ========================================================
    # Best Run According to High-Shot Evaluated Mean
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "HIGH-SHOT EVALUATED MEAN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_values,
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


# ============================================================
# Report Location
# ============================================================

print(
    "\nReport saved to:"
)


print(
    os.path.abspath(
        report_filename
    )
)
# Out:
# ================================================================================
# Optimization Run 1/30
# Optimization Seed : 150
# ================================================================================
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566, 0.6883896757,
#  0.5848087428, 0.2739643248, 0.8377858251, 0.3022293541, 0.1728462164,
#  0.8017433668, 0.3441099205, 0.4375847094]
#
# Starting SLSQP optimization...
# success_probability = 0.33170000
# success_probability = 0.33160000
# success_probability = 0.33050000
# success_probability = 0.33140000
# success_probability = 0.33150000
# success_probability = 0.33050000
# success_probability = 0.33150000
# success_probability = 0.33260000
# success_probability = 0.33170000
# success_probability = 0.33140000
# success_probability = 0.33070000
# success_probability = 0.33170000
# success_probability = 0.33170000
# success_probability = 0.33190000
# success_probability = 0.33160000
# success_probability = 0.33180000
# success_probability = 0.33180000
# success_probability = 0.33160000
# success_probability = 0.33170000
# success_probability = 0.33170000
# success_probability = 0.33160000
# success_probability = 0.33170000
# success_probability = 0.33160000
# success_probability = 0.33170000
# success_probability = 0.33170000
# success_probability = 0.33170000
# success_probability = 0.33170000
# success_probability = 0.33170000
# success_probability = 0.33170000
# success_probability = 0.43000000
# success_probability = 0.43030000
# success_probability = 0.43100000
# success_probability = 0.43000000
# success_probability = 0.43000000
# success_probability = 0.43110000
# success_probability = 0.43050000
# success_probability = 0.43110000
# success_probability = 0.43020000
# success_probability = 0.43040000
# success_probability = 0.43060000
# success_probability = 0.43000000
# success_probability = 0.43000000
# success_probability = 0.43010000
# success_probability = 0.43010000
# success_probability = 0.43000000
# success_probability = 0.43000000
# success_probability = 0.43000000
# success_probability = 0.43000000
# success_probability = 0.43000000
# success_probability = 0.43020000
# success_probability = 0.43000000
# success_probability = 0.43020000
# success_probability = 0.43000000
# success_probability = 0.43000000
# success_probability = 0.43000000
# success_probability = 0.43000000
# success_probability = 0.43000000
# success_probability = 0.43000000
# success_probability = 0.49930000
# success_probability = 0.49920000
# success_probability = 0.49940000
# success_probability = 0.49950000
# success_probability = 0.49940000
# success_probability = 0.49960000
# success_probability = 0.49950000
# success_probability = 0.50000000
# success_probability = 0.49940000
# success_probability = 0.49970000
# success_probability = 0.49990000
# success_probability = 0.49930000
# success_probability = 0.49930000
# success_probability = 0.49940000
# success_probability = 0.49930000
# success_probability = 0.49930000
# success_probability = 0.49940000
# success_probability = 0.49910000
# success_probability = 0.49910000
# success_probability = 0.49920000
# success_probability = 0.49920000
# success_probability = 0.49930000
# success_probability = 0.49930000
# success_probability = 0.49930000
# success_probability = 0.49930000
# success_probability = 0.49920000
# success_probability = 0.49950000
# success_probability = 0.49930000
# success_probability = 0.49930000
# success_probability = 0.54030000
# success_probability = 0.54030000
# success_probability = 0.54030000
# success_probability = 0.54030000
# success_probability = 0.54010000
# success_probability = 0.54020000
# success_probability = 0.54010000
# success_probability = 0.53980000
# success_probability = 0.54040000
# success_probability = 0.54090000
# success_probability = 0.54020000
# success_probability = 0.54030000
# success_probability = 0.54030000
# success_probability = 0.54010000
# success_probability = 0.54060000
# success_probability = 0.53980000
# success_probability = 0.53990000
# success_probability = 0.54030000
# success_probability = 0.54020000
# success_probability = 0.54050000
# success_probability = 0.54000000
# success_probability = 0.53990000
# success_probability = 0.54030000
# success_probability = 0.54030000
# success_probability = 0.54030000
# success_probability = 0.54020000
# success_probability = 0.54040000
# success_probability = 0.54030000
# success_probability = 0.54030000
# success_probability = 0.53960000
# success_probability = 0.54030000
# success_probability = 0.54080000
# success_probability = 0.54120000
# success_probability = 0.54120000
# success_probability = 0.54080000
# success_probability = 0.54050000
# success_probability = 0.54110000
# success_probability = 0.54120000
# success_probability = 0.54110000
# success_probability = 0.54140000
# success_probability = 0.54100000
# success_probability = 0.54110000
# success_probability = 0.54080000
# success_probability = 0.54120000
# success_probability = 0.54120000
# success_probability = 0.54100000
# success_probability = 0.54120000
# success_probability = 0.54140000
# success_probability = 0.54130000
# success_probability = 0.54110000
# success_probability = 0.54110000
# success_probability = 0.54140000
# success_probability = 0.54130000
# success_probability = 0.54120000
# success_probability = 0.54110000
# success_probability = 0.54120000
# success_probability = 0.54120000
# success_probability = 0.54120000
# success_probability = 0.54120000
# success_probability = 0.54120000
# success_probability = 0.54120000
# success_probability = 0.54010000
# success_probability = 0.53890000
# success_probability = 0.54100000
# success_probability = 0.54040000
# success_probability = 0.54070000
# success_probability = 0.54110000
# success_probability = 0.54120000
# success_probability = 0.54120000
# success_probability = 0.54120000
# success_probability = 0.54120000
# success_probability = 0.54120000
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.8477457501847745
#             Iterations: 5
#             Function evaluations: 159
#             Gradient evaluations: 5
# Optimization Wall-Clock Time : 19.337638 s
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.52871000
# Evaluation  2/20 | Value = 0.52871000
# Evaluation  3/20 | Value = 0.52872000
# Evaluation  4/20 | Value = 0.52872000
# Evaluation  5/20 | Value = 0.52873000
# Evaluation  6/20 | Value = 0.52873000
# Evaluation  7/20 | Value = 0.52872000
# Evaluation  8/20 | Value = 0.52873000
# Evaluation  9/20 | Value = 0.52873000
# Evaluation 10/20 | Value = 0.52873000
# Evaluation 11/20 | Value = 0.52873000
# Evaluation 12/20 | Value = 0.52873000
# Evaluation 13/20 | Value = 0.52873000
# Evaluation 14/20 | Value = 0.52874000
# Evaluation 15/20 | Value = 0.52873000
# Evaluation 16/20 | Value = 0.52872000
# Evaluation 17/20 | Value = 0.52872000
# Evaluation 18/20 | Value = 0.52872000
# Evaluation 19/20 | Value = 0.52872000
# Evaluation 20/20 | Value = 0.52871000
#
# ================================================================================
# RUN 1 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 0
# Message              : Optimization terminated successfully
# Iterations           : 5
# Function Evaluations : 159
# Gradient Evaluations : 5
# Optimization Time    : 19.337638 s
# Final Objective Value: 1.8477457501847745
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.54120000
# Evaluated Mean        : 0.52872400
# Evaluated Std         : 0.00000800
# Evaluated Min         : 0.52871000
# Evaluated Max         : 0.52874000
#
# All Evaluated Values:
# [0.52871, 0.52871, 0.52872, 0.52872, 0.52873, 0.52873, 0.52872, 0.52873,
#  0.52873, 0.52873, 0.52873, 0.52873, 0.52873, 0.52874, 0.52873, 0.52872,
#  0.52872, 0.52872, 0.52872, 0.52871]
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566, 0.6883896757,
#  0.5848087428, 0.2739643248, 0.8377858251, 0.3022293541, 0.1728462164,
#  0.8017433668, 0.3441099205, 0.4375847094]
#
# Optimal Parameters:
# [-0.0187250477,  0.1238594252,  0.5645384581,  0.1601752254,  0.0481760787,
#   0.8716368924,  2.8111376361,  0.2731822513,  0.4346269315, -0.1645498096,
#   0.5940727125,  0.6105506387,  1.2487113637,  0.6861661108,  0.4733848298,
#   0.9555539165,  0.2506979951,  0.4530352744,  0.9205706673,  0.6035542689,
#   0.5704022193,  0.2610312596,  0.8377858251,  0.3022293541,  0.1081338909,
#   0.9274936462,  0.3441099205,  0.4375847094]
# ================================================================================
#
# ================================================================================
# Optimization Run 2/30
# Optimization Seed : 151
# ================================================================================
#
# Initial Parameters:
# [0.4917938425, 0.3601415032, 0.7094100488, 0.6895107167, 0.4723817514,
#  0.4790485592, 0.0068635273, 0.9044398512, 0.4337399476, 0.4736042839,
#  0.034330777 , 0.9496323674, 0.5907905652, 0.4241785512, 0.1868628067,
#  0.9840929216, 0.690221156 , 0.9039467044, 0.0207568308, 0.9969449281,
#  0.3143005034, 0.2098620446, 0.0173606056, 0.1892781313, 0.2905169378,
#  0.2743264362, 0.6422361978, 0.0963913748]
#
# Starting SLSQP optimization...
# success_probability = 0.34040000
# success_probability = 0.34020000
# success_probability = 0.33980000
# success_probability = 0.34080000
# success_probability = 0.34070000
# success_probability = 0.33950000
# success_probability = 0.34090000
# success_probability = 0.34040000
# success_probability = 0.34040000
# success_probability = 0.34000000
# success_probability = 0.33970000
# success_probability = 0.34040000
# success_probability = 0.34040000
# success_probability = 0.34040000
# success_probability = 0.34030000
# success_probability = 0.34040000
# success_probability = 0.34040000
# success_probability = 0.34040000
# success_probability = 0.34030000
# success_probability = 0.34040000
# success_probability = 0.34040000
# success_probability = 0.34030000
# success_probability = 0.34030000
# success_probability = 0.34040000
# success_probability = 0.34040000
# success_probability = 0.34040000
# success_probability = 0.34040000
# success_probability = 0.34040000
# success_probability = 0.34040000
# success_probability = 0.35080000
# success_probability = 0.35200000
# success_probability = 0.35230000
# success_probability = 0.35180000
# success_probability = 0.35220000
# success_probability = 0.35210000
# success_probability = 0.35200000
# success_probability = 0.35230000
# success_probability = 0.35200000
# success_probability = 0.35260000
# success_probability = 0.35270000
# success_probability = 0.35190000
# success_probability = 0.35200000
# success_probability = 0.35200000
# success_probability = 0.35200000
# success_probability = 0.35200000
# success_probability = 0.35200000
# success_probability = 0.35200000
# success_probability = 0.35200000
# success_probability = 0.35200000
# success_probability = 0.35200000
# success_probability = 0.35200000
# success_probability = 0.35200000
# success_probability = 0.35200000
# success_probability = 0.35200000
# success_probability = 0.35200000
# success_probability = 0.35190000
# success_probability = 0.35200000
# success_probability = 0.35200000
# success_probability = 0.35200000
# success_probability = 0.37420000
# success_probability = 0.37400000
# success_probability = 0.37410000
# success_probability = 0.37440000
# success_probability = 0.37400000
# success_probability = 0.37450000
# success_probability = 0.37440000
# success_probability = 0.37410000
# success_probability = 0.37420000
# success_probability = 0.37500000
# success_probability = 0.37440000
# success_probability = 0.37420000
# success_probability = 0.37420000
# success_probability = 0.37400000
# success_probability = 0.37400000
# success_probability = 0.37420000
# success_probability = 0.37410000
# success_probability = 0.37410000
# success_probability = 0.37420000
# success_probability = 0.37410000
# success_probability = 0.37410000
# success_probability = 0.37410000
# success_probability = 0.37420000
# success_probability = 0.37420000
# success_probability = 0.37420000
# success_probability = 0.37420000
# success_probability = 0.37420000
# success_probability = 0.37420000
# success_probability = 0.37420000
# success_probability = 0.37680000
# success_probability = 0.38170000
# success_probability = 0.38140000
# success_probability = 0.38190000
# success_probability = 0.38200000
# success_probability = 0.38200000
# success_probability = 0.38260000
# success_probability = 0.38190000
# success_probability = 0.38160000
# success_probability = 0.38240000
# success_probability = 0.38210000
# success_probability = 0.38160000
# success_probability = 0.38170000
# success_probability = 0.38170000
# success_probability = 0.38170000
# success_probability = 0.38190000
# success_probability = 0.38170000
# success_probability = 0.38170000
# success_probability = 0.38160000
# success_probability = 0.38180000
# success_probability = 0.38170000
# success_probability = 0.38170000
# success_probability = 0.38200000
# success_probability = 0.38190000
# success_probability = 0.38170000
# success_probability = 0.38170000
# success_probability = 0.38170000
# success_probability = 0.38170000
# success_probability = 0.38170000
# success_probability = 0.38170000
# success_probability = 0.31210000
# success_probability = 0.35370000
# success_probability = 0.38910000
# success_probability = 0.38820000
# success_probability = 0.38760000
# success_probability = 0.38890000
# success_probability = 0.38770000
# success_probability = 0.38780000
# success_probability = 0.38830000
# success_probability = 0.38810000
# success_probability = 0.38790000
# success_probability = 0.38800000
# success_probability = 0.38850000
# success_probability = 0.38790000
# success_probability = 0.38820000
# success_probability = 0.38820000
# success_probability = 0.38800000
# success_probability = 0.38800000
# success_probability = 0.38810000
# success_probability = 0.38820000
# success_probability = 0.38820000
# success_probability = 0.38800000
# success_probability = 0.38820000
# success_probability = 0.38820000
# success_probability = 0.38810000
# success_probability = 0.38810000
# success_probability = 0.38820000
# success_probability = 0.38820000
# success_probability = 0.38820000
# success_probability = 0.38820000
# success_probability = 0.38820000
# success_probability = 0.38820000
# success_probability = 0.41750000
# success_probability = 0.41660000
# success_probability = 0.41770000
# success_probability = 0.41760000
# success_probability = 0.41690000
# success_probability = 0.41770000
# success_probability = 0.41740000
# success_probability = 0.41710000
# success_probability = 0.41760000
# success_probability = 0.41690000
# success_probability = 0.41730000
# success_probability = 0.41750000
# success_probability = 0.41750000
# success_probability = 0.41760000
# success_probability = 0.41780000
# success_probability = 0.41750000
# success_probability = 0.41750000
# success_probability = 0.41740000
# success_probability = 0.41750000
# success_probability = 0.41740000
# success_probability = 0.41750000
# success_probability = 0.41750000
# success_probability = 0.41760000
# success_probability = 0.41750000
# success_probability = 0.41750000
# success_probability = 0.41750000
# success_probability = 0.41740000
# success_probability = 0.41750000
# success_probability = 0.41750000
# success_probability = 0.39270000
# success_probability = 0.43240000
# success_probability = 0.43270000
# success_probability = 0.43240000
# success_probability = 0.43210000
# success_probability = 0.43240000
# success_probability = 0.43270000
# success_probability = 0.43250000
# success_probability = 0.43170000
# success_probability = 0.43250000
# success_probability = 0.43200000
# success_probability = 0.43240000
# success_probability = 0.43240000
# success_probability = 0.43240000
# success_probability = 0.43220000
# success_probability = 0.43230000
# success_probability = 0.43240000
# success_probability = 0.43230000
# success_probability = 0.43240000
# success_probability = 0.43250000
# success_probability = 0.43240000
# success_probability = 0.43240000
# success_probability = 0.43220000
# success_probability = 0.43240000
# success_probability = 0.43240000
# success_probability = 0.43240000
# success_probability = 0.43250000
# success_probability = 0.43240000
# success_probability = 0.43240000
# success_probability = 0.43240000
# success_probability = 0.46380000
# success_probability = 0.46470000
# success_probability = 0.46330000
# success_probability = 0.46390000
# success_probability = 0.46390000
# success_probability = 0.46380000
# success_probability = 0.46430000
# success_probability = 0.46290000
# success_probability = 0.46400000
# success_probability = 0.46370000
# success_probability = 0.46300000
# success_probability = 0.46380000
# success_probability = 0.46380000
# success_probability = 0.46380000
# success_probability = 0.46390000
# success_probability = 0.46370000
# success_probability = 0.46380000
# success_probability = 0.46380000
# success_probability = 0.46370000
# success_probability = 0.46380000
# success_probability = 0.46350000
# success_probability = 0.46390000
# success_probability = 0.46390000
# success_probability = 0.46380000
# success_probability = 0.46380000
# success_probability = 0.46390000
# success_probability = 0.46380000
# success_probability = 0.46380000
# success_probability = 0.46380000
# success_probability = 0.26820000
# success_probability = 0.46740000
# success_probability = 0.50640000
# success_probability = 0.50770000
# success_probability = 0.50690000
# success_probability = 0.50610000
# success_probability = 0.50590000
# success_probability = 0.50540000
# success_probability = 0.50660000
# success_probability = 0.50590000
# success_probability = 0.50590000
# success_probability = 0.50630000
# success_probability = 0.50660000
# success_probability = 0.50640000
# success_probability = 0.50640000
# success_probability = 0.50650000
# success_probability = 0.50650000
# success_probability = 0.50640000
# success_probability = 0.50660000
# success_probability = 0.50650000
# success_probability = 0.50600000
# success_probability = 0.50610000
# success_probability = 0.50630000
# success_probability = 0.50630000
# success_probability = 0.50600000
# success_probability = 0.50640000
# success_probability = 0.50640000
# success_probability = 0.50640000
# success_probability = 0.50640000
# success_probability = 0.50640000
# success_probability = 0.50640000
# success_probability = 0.57550000
# success_probability = 0.57590000
# success_probability = 0.57530000
# success_probability = 0.57560000
# success_probability = 0.57510000
# success_probability = 0.57480000
# success_probability = 0.57550000
# success_probability = 0.57540000
# success_probability = 0.57510000
# success_probability = 0.57510000
# success_probability = 0.57530000
# success_probability = 0.57550000
# success_probability = 0.57550000
# success_probability = 0.57600000
# success_probability = 0.57580000
# success_probability = 0.57540000
# success_probability = 0.57570000
# success_probability = 0.57550000
# success_probability = 0.57530000
# success_probability = 0.57520000
# success_probability = 0.57500000
# success_probability = 0.57540000
# success_probability = 0.57580000
# success_probability = 0.57550000
# success_probability = 0.57550000
# success_probability = 0.57550000
# success_probability = 0.57560000
# success_probability = 0.57550000
# success_probability = 0.57550000
# success_probability = 0.60110000
# success_probability = 0.60130000
# success_probability = 0.60140000
# success_probability = 0.60090000
# success_probability = 0.60100000
# success_probability = 0.60090000
# success_probability = 0.60150000
# success_probability = 0.60130000
# success_probability = 0.60150000
# success_probability = 0.60100000
# success_probability = 0.60110000
# success_probability = 0.60110000
# success_probability = 0.60110000
# success_probability = 0.60170000
# success_probability = 0.60110000
# success_probability = 0.60100000
# success_probability = 0.60140000
# success_probability = 0.60110000
# success_probability = 0.60130000
# success_probability = 0.60120000
# success_probability = 0.60120000
# success_probability = 0.60140000
# success_probability = 0.60090000
# success_probability = 0.60110000
# success_probability = 0.60110000
# success_probability = 0.60110000
# success_probability = 0.60110000
# success_probability = 0.60110000
# success_probability = 0.60110000
# success_probability = 0.61020000
# success_probability = 0.61060000
# success_probability = 0.61050000
# success_probability = 0.61060000
# success_probability = 0.61010000
# success_probability = 0.60990000
# success_probability = 0.61020000
# success_probability = 0.61050000
# success_probability = 0.61070000
# success_probability = 0.61050000
# success_probability = 0.61050000
# success_probability = 0.61020000
# success_probability = 0.61020000
# success_probability = 0.60980000
# success_probability = 0.61000000
# success_probability = 0.61050000
# success_probability = 0.61050000
# success_probability = 0.61020000
# success_probability = 0.61040000
# success_probability = 0.61010000
# success_probability = 0.61040000
# success_probability = 0.61020000
# success_probability = 0.61000000
# success_probability = 0.61020000
# success_probability = 0.61020000
# success_probability = 0.61020000
# success_probability = 0.61020000
# success_probability = 0.61020000
# success_probability = 0.61020000
# success_probability = 0.61170000
# success_probability = 0.61670000
# success_probability = 0.61640000
# success_probability = 0.61670000
# success_probability = 0.61700000
# success_probability = 0.61700000
# success_probability = 0.61590000
# success_probability = 0.61680000
# success_probability = 0.61720000
# success_probability = 0.61670000
# success_probability = 0.61690000
# success_probability = 0.61720000
# success_probability = 0.61670000
# success_probability = 0.61670000
# success_probability = 0.61640000
# success_probability = 0.61640000
# success_probability = 0.61700000
# success_probability = 0.61660000
# success_probability = 0.61670000
# success_probability = 0.61710000
# success_probability = 0.61660000
# success_probability = 0.61700000
# success_probability = 0.61710000
# success_probability = 0.61640000
# success_probability = 0.61670000
# success_probability = 0.61670000
# success_probability = 0.61670000
# success_probability = 0.61680000
# success_probability = 0.61670000
# success_probability = 0.61670000
# success_probability = 0.31330000
# success_probability = 0.19090000
# success_probability = 0.27090000
# success_probability = 0.57020000
# success_probability = 0.61130000
# success_probability = 0.61710000
# success_probability = 0.61800000
# success_probability = 0.61770000
# success_probability = 0.61780000
# success_probability = 0.61840000
# success_probability = 0.61850000
# success_probability = 0.61760000
# success_probability = 0.61800000
# success_probability = 0.61760000
# success_probability = 0.61820000
# success_probability = 0.61820000
# success_probability = 0.61850000
# success_probability = 0.61800000
# success_probability = 0.61800000
# success_probability = 0.61870000
# success_probability = 0.61820000
# success_probability = 0.61820000
# success_probability = 0.61830000
# success_probability = 0.61800000
# success_probability = 0.61810000
# success_probability = 0.61830000
# success_probability = 0.61770000
# success_probability = 0.61820000
# success_probability = 0.61860000
# success_probability = 0.61800000
# success_probability = 0.61800000
# success_probability = 0.61810000
# success_probability = 0.61810000
# success_probability = 0.61800000
# success_probability = 0.61800000
# success_probability = 0.51730000
# success_probability = 0.61090000
# success_probability = 0.61740000
# success_probability = 0.61760000
# success_probability = 0.61850000
# success_probability = 0.61780000
# success_probability = 0.61780000
# success_probability = 0.61800000
# success_probability = 0.61810000
# success_probability = 0.61800000
# success_probability = 0.61810000
# success_probability = 0.61830000
# success_probability = 0.61810000
# success_probability = 0.61820000
# success_probability = 0.61830000
# success_probability = 0.61850000
# success_probability = 0.61850000
# success_probability = 0.61850000
# success_probability = 0.61830000
# success_probability = 0.61840000
# success_probability = 0.61830000
# success_probability = 0.61840000
# success_probability = 0.61860000
# success_probability = 0.61830000
# success_probability = 0.61830000
# success_probability = 0.61830000
# success_probability = 0.61840000
# success_probability = 0.61850000
# success_probability = 0.61850000
# success_probability = 0.61850000
# success_probability = 0.61850000
# success_probability = 0.61850000
# success_probability = 0.61850000
# success_probability = 0.62580000
# success_probability = 0.62570000
# success_probability = 0.62580000
# success_probability = 0.62580000
# success_probability = 0.62610000
# success_probability = 0.62540000
# success_probability = 0.62600000
# success_probability = 0.62570000
# success_probability = 0.62560000
# success_probability = 0.62560000
# success_probability = 0.62630000
# success_probability = 0.62580000
# success_probability = 0.62580000
# success_probability = 0.62620000
# success_probability = 0.62560000
# success_probability = 0.62580000
# success_probability = 0.62580000
# success_probability = 0.62580000
# success_probability = 0.62600000
# success_probability = 0.62570000
# success_probability = 0.62540000
# success_probability = 0.62650000
# success_probability = 0.62550000
# success_probability = 0.62580000
# success_probability = 0.62580000
# success_probability = 0.62590000
# success_probability = 0.62590000
# success_probability = 0.62580000
# success_probability = 0.62580000
# success_probability = 0.52870000
# success_probability = 0.62700000
# success_probability = 0.62990000
# success_probability = 0.62910000
# success_probability = 0.63000000
# success_probability = 0.63000000
# success_probability = 0.62970000
# success_probability = 0.62980000
# success_probability = 0.62980000
# success_probability = 0.62970000
# success_probability = 0.62980000
# success_probability = 0.62940000
# success_probability = 0.62970000
# success_probability = 0.62990000
# success_probability = 0.62990000
# success_probability = 0.62960000
# success_probability = 0.63030000
# success_probability = 0.63030000
# success_probability = 0.62950000
# success_probability = 0.62990000
# success_probability = 0.63040000
# success_probability = 0.62980000
# success_probability = 0.63020000
# success_probability = 0.63000000
# success_probability = 0.63090000
# success_probability = 0.62990000
# success_probability = 0.62990000
# success_probability = 0.63000000
# success_probability = 0.62990000
# success_probability = 0.62990000
# success_probability = 0.62990000
# success_probability = 0.63420000
# success_probability = 0.63350000
# success_probability = 0.63450000
# success_probability = 0.63460000
# success_probability = 0.63400000
# success_probability = 0.63430000
# success_probability = 0.63440000
# success_probability = 0.63410000
# success_probability = 0.63410000
# success_probability = 0.63430000
# success_probability = 0.63420000
# success_probability = 0.63420000
# success_probability = 0.63420000
# success_probability = 0.63460000
# success_probability = 0.63450000
# success_probability = 0.63420000
# success_probability = 0.63430000
# success_probability = 0.63420000
# success_probability = 0.63400000
# success_probability = 0.63410000
# success_probability = 0.63390000
# success_probability = 0.63450000
# success_probability = 0.63430000
# success_probability = 0.63420000
# success_probability = 0.63420000
# success_probability = 0.63420000
# success_probability = 0.63430000
# success_probability = 0.63420000
# success_probability = 0.63420000
# success_probability = 0.63910000
# success_probability = 0.63890000
# success_probability = 0.63900000
# success_probability = 0.63880000
# success_probability = 0.63880000
# success_probability = 0.63960000
# success_probability = 0.63900000
# success_probability = 0.63930000
# success_probability = 0.63930000
# success_probability = 0.63890000
# success_probability = 0.63890000
# success_probability = 0.63910000
# success_probability = 0.63910000
# success_probability = 0.63890000
# success_probability = 0.63930000
# success_probability = 0.63910000
# success_probability = 0.63910000
# success_probability = 0.63920000
# success_probability = 0.63870000
# success_probability = 0.63910000
# success_probability = 0.63940000
# success_probability = 0.63900000
# success_probability = 0.63940000
# success_probability = 0.63910000
# success_probability = 0.63910000
# success_probability = 0.63920000
# success_probability = 0.63930000
# success_probability = 0.63910000
# success_probability = 0.63910000
# success_probability = 0.64470000
# success_probability = 0.64510000
# success_probability = 0.64450000
# success_probability = 0.64480000
# success_probability = 0.64470000
# success_probability = 0.64500000
# success_probability = 0.64540000
# success_probability = 0.64480000
# success_probability = 0.64530000
# success_probability = 0.64460000
# success_probability = 0.64480000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64500000
# success_probability = 0.64430000
# success_probability = 0.64480000
# success_probability = 0.64460000
# success_probability = 0.64470000
# success_probability = 0.64500000
# success_probability = 0.64490000
# success_probability = 0.64460000
# success_probability = 0.64460000
# success_probability = 0.64400000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64450000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64370000
# success_probability = 0.64540000
# success_probability = 0.64450000
# success_probability = 0.64510000
# success_probability = 0.64530000
# success_probability = 0.64550000
# success_probability = 0.64540000
# success_probability = 0.64530000
# success_probability = 0.64500000
# success_probability = 0.64510000
# success_probability = 0.64500000
# success_probability = 0.64500000
# success_probability = 0.64510000
# success_probability = 0.64530000
# success_probability = 0.64510000
# success_probability = 0.64510000
# success_probability = 0.64480000
# success_probability = 0.64550000
# success_probability = 0.64520000
# success_probability = 0.64560000
# success_probability = 0.64520000
# success_probability = 0.64500000
# success_probability = 0.64460000
# success_probability = 0.64490000
# success_probability = 0.64540000
# success_probability = 0.64510000
# success_probability = 0.64510000
# success_probability = 0.64510000
# success_probability = 0.64510000
# success_probability = 0.64500000
# success_probability = 0.64510000
# success_probability = 0.64510000
# success_probability = 0.64580000
# success_probability = 0.64600000
# success_probability = 0.64560000
# success_probability = 0.64560000
# success_probability = 0.64600000
# success_probability = 0.64580000
# success_probability = 0.64580000
# success_probability = 0.64600000
# success_probability = 0.64580000
# success_probability = 0.64570000
# success_probability = 0.64570000
# success_probability = 0.64580000
# success_probability = 0.64580000
# success_probability = 0.64520000
# success_probability = 0.64590000
# success_probability = 0.64570000
# success_probability = 0.64570000
# success_probability = 0.64580000
# success_probability = 0.64540000
# success_probability = 0.64570000
# success_probability = 0.64550000
# success_probability = 0.64580000
# success_probability = 0.64580000
# success_probability = 0.64580000
# success_probability = 0.64580000
# success_probability = 0.64580000
# success_probability = 0.64560000
# success_probability = 0.64580000
# success_probability = 0.64580000
# success_probability = 0.62090000
# success_probability = 0.64540000
# success_probability = 0.64640000
# success_probability = 0.64650000
# success_probability = 0.64690000
# success_probability = 0.64660000
# success_probability = 0.64640000
# success_probability = 0.64670000
# success_probability = 0.64630000
# success_probability = 0.64660000
# success_probability = 0.64640000
# success_probability = 0.64630000
# success_probability = 0.64650000
# success_probability = 0.64650000
# success_probability = 0.64650000
# success_probability = 0.64650000
# success_probability = 0.64670000
# success_probability = 0.64690000
# success_probability = 0.64650000
# success_probability = 0.64650000
# success_probability = 0.64640000
# success_probability = 0.64640000
# success_probability = 0.64620000
# success_probability = 0.64640000
# success_probability = 0.64680000
# success_probability = 0.64720000
# success_probability = 0.64650000
# success_probability = 0.64650000
# success_probability = 0.64640000
# success_probability = 0.64640000
# success_probability = 0.64650000
# success_probability = 0.64650000
# success_probability = 0.64890000
# success_probability = 0.64890000
# success_probability = 0.64940000
# success_probability = 0.64900000
# success_probability = 0.64900000
# success_probability = 0.64910000
# success_probability = 0.64880000
# success_probability = 0.64900000
# success_probability = 0.64910000
# success_probability = 0.64880000
# success_probability = 0.64870000
# success_probability = 0.64890000
# success_probability = 0.64890000
# success_probability = 0.64880000
# success_probability = 0.64920000
# success_probability = 0.64900000
# success_probability = 0.64910000
# success_probability = 0.64890000
# success_probability = 0.64910000
# success_probability = 0.64890000
# success_probability = 0.64870000
# success_probability = 0.64910000
# success_probability = 0.64890000
# success_probability = 0.64890000
# success_probability = 0.64890000
# success_probability = 0.64900000
# success_probability = 0.64890000
# success_probability = 0.64890000
# success_probability = 0.64890000
# success_probability = 0.64930000
# success_probability = 0.65040000
# success_probability = 0.65000000
# success_probability = 0.65060000
# success_probability = 0.65050000
# success_probability = 0.64970000
# success_probability = 0.65030000
# success_probability = 0.65090000
# success_probability = 0.65040000
# success_probability = 0.65090000
# success_probability = 0.65030000
# success_probability = 0.65050000
# success_probability = 0.65040000
# success_probability = 0.65040000
# success_probability = 0.65010000
# success_probability = 0.65050000
# success_probability = 0.65040000
# success_probability = 0.65030000
# success_probability = 0.65040000
# success_probability = 0.65050000
# success_probability = 0.65010000
# success_probability = 0.65030000
# success_probability = 0.65040000
# success_probability = 0.65050000
# success_probability = 0.65040000
# success_probability = 0.65040000
# success_probability = 0.65040000
# success_probability = 0.65030000
# success_probability = 0.65040000
# success_probability = 0.65040000
# success_probability = 0.52200000
# success_probability = 0.43890000
# success_probability = 0.43520000
# success_probability = 0.41360000
# success_probability = 0.40880000
# success_probability = 0.64410000
# success_probability = 0.64900000
# success_probability = 0.64990000
# success_probability = 0.65120000
# success_probability = 0.65070000
# success_probability = 0.65130000
# success_probability = 0.65120000
# success_probability = 0.65060000
# success_probability = 0.65120000
# success_probability = 0.65110000
# success_probability = 0.65060000
# success_probability = 0.65120000
# success_probability = 0.65120000
# success_probability = 0.65130000
# success_probability = 0.65120000
# success_probability = 0.65120000
# success_probability = 0.65170000
# success_probability = 0.65150000
# success_probability = 0.65140000
# success_probability = 0.65110000
# success_probability = 0.65130000
# success_probability = 0.65110000
# success_probability = 0.65050000
# success_probability = 0.65120000
# success_probability = 0.65130000
# success_probability = 0.65100000
# success_probability = 0.65120000
# success_probability = 0.65120000
# success_probability = 0.65120000
# success_probability = 0.65110000
# success_probability = 0.65120000
# success_probability = 0.65120000
# success_probability = 0.64220000
# success_probability = 0.64880000
# success_probability = 0.65060000
# success_probability = 0.65120000
# success_probability = 0.65150000
# success_probability = 0.65070000
# success_probability = 0.65150000
# success_probability = 0.65130000
# success_probability = 0.65090000
# success_probability = 0.65130000
# success_probability = 0.65120000
# success_probability = 0.65090000
# success_probability = 0.65090000
# success_probability = 0.65150000
# success_probability = 0.65130000
# success_probability = 0.65150000
# success_probability = 0.65150000
# success_probability = 0.65140000
# success_probability = 0.65160000
# success_probability = 0.65170000
# success_probability = 0.65130000
# success_probability = 0.65160000
# success_probability = 0.65140000
# success_probability = 0.65060000
# success_probability = 0.65110000
# success_probability = 0.65170000
# success_probability = 0.65100000
# success_probability = 0.65150000
# success_probability = 0.65150000
# success_probability = 0.65160000
# success_probability = 0.65150000
# success_probability = 0.65150000
# success_probability = 0.65150000
# success_probability = 0.49620000
# success_probability = 0.49220000
# success_probability = 0.45890000
# success_probability = 0.33350000
# success_probability = 0.40760000
# success_probability = 0.63240000
# success_probability = 0.64780000
# success_probability = 0.64950000
# success_probability = 0.65110000
# success_probability = 0.65120000
# success_probability = 0.65140000
# success_probability = 0.65080000
# success_probability = 0.65140000
# success_probability = 0.65140000
# success_probability = 0.65080000
# success_probability = 0.65110000
# success_probability = 0.65120000
# success_probability = 0.65090000
# success_probability = 0.65070000
# success_probability = 0.65150000
# success_probability = 0.65130000
# success_probability = 0.65140000
# success_probability = 0.65140000
# success_probability = 0.65140000
# success_probability = 0.65150000
# success_probability = 0.65160000
# success_probability = 0.65140000
# success_probability = 0.65150000
# success_probability = 0.65130000
# success_probability = 0.65070000
# success_probability = 0.65110000
# success_probability = 0.65160000
# success_probability = 0.65090000
# success_probability = 0.65140000
# success_probability = 0.65140000
# success_probability = 0.65150000
# success_probability = 0.65150000
# success_probability = 0.65140000
# success_probability = 0.65140000
# success_probability = 0.64950000
# success_probability = 0.65040000
# success_probability = 0.65140000
# success_probability = 0.65150000
# success_probability = 0.65090000
# success_probability = 0.65150000
# success_probability = 0.65090000
# success_probability = 0.65090000
# success_probability = 0.65130000
# success_probability = 0.65130000
# success_probability = 0.65110000
# success_probability = 0.65150000
# success_probability = 0.65170000
# success_probability = 0.65140000
# success_probability = 0.65150000
# success_probability = 0.65150000
# success_probability = 0.65130000
# success_probability = 0.65150000
# success_probability = 0.65150000
# success_probability = 0.65120000
# success_probability = 0.65150000
# success_probability = 0.65170000
# success_probability = 0.65090000
# success_probability = 0.65150000
# success_probability = 0.65150000
# success_probability = 0.65090000
# success_probability = 0.65150000
# success_probability = 0.65150000
# success_probability = 0.65150000
# success_probability = 0.65150000
# success_probability = 0.65150000
# success_probability = 0.65150000
# success_probability = 0.65590000
# success_probability = 0.65560000
# success_probability = 0.65550000
# success_probability = 0.65560000
# success_probability = 0.65580000
# success_probability = 0.65510000
# success_probability = 0.65550000
# success_probability = 0.65510000
# success_probability = 0.65540000
# success_probability = 0.65590000
# success_probability = 0.65580000
# success_probability = 0.65590000
# success_probability = 0.65590000
# success_probability = 0.65540000
# success_probability = 0.65570000
# success_probability = 0.65570000
# success_probability = 0.65580000
# success_probability = 0.65590000
# success_probability = 0.65610000
# success_probability = 0.65560000
# success_probability = 0.65590000
# success_probability = 0.65570000
# success_probability = 0.65560000
# success_probability = 0.65590000
# success_probability = 0.65590000
# success_probability = 0.65590000
# success_probability = 0.65590000
# success_probability = 0.65590000
# success_probability = 0.65590000
# success_probability = 0.65720000
# success_probability = 0.65730000
# success_probability = 0.65760000
# success_probability = 0.65730000
# success_probability = 0.65730000
# success_probability = 0.65730000
# success_probability = 0.65690000
# success_probability = 0.65720000
# success_probability = 0.65740000
# success_probability = 0.65720000
# success_probability = 0.65690000
# success_probability = 0.65720000
# success_probability = 0.65720000
# success_probability = 0.65740000
# success_probability = 0.65770000
# success_probability = 0.65720000
# success_probability = 0.65740000
# success_probability = 0.65720000
# success_probability = 0.65730000
# success_probability = 0.65720000
# success_probability = 0.65720000
# success_probability = 0.65740000
# success_probability = 0.65750000
# success_probability = 0.65720000
# success_probability = 0.65720000
# success_probability = 0.65720000
# success_probability = 0.65720000
# success_probability = 0.65720000
# success_probability = 0.65720000
# success_probability = 0.65760000
# success_probability = 0.65700000
# success_probability = 0.65730000
# success_probability = 0.65780000
# success_probability = 0.65740000
# success_probability = 0.65750000
# success_probability = 0.65730000
# success_probability = 0.65750000
# success_probability = 0.65770000
# success_probability = 0.65760000
# success_probability = 0.65790000
# success_probability = 0.65770000
# success_probability = 0.65780000
# success_probability = 0.65780000
# success_probability = 0.65780000
# success_probability = 0.65780000
# success_probability = 0.65720000
# success_probability = 0.65770000
# success_probability = 0.65770000
# success_probability = 0.65780000
# success_probability = 0.65770000
# success_probability = 0.65790000
# success_probability = 0.65740000
# success_probability = 0.65790000
# success_probability = 0.65790000
# success_probability = 0.65810000
# success_probability = 0.65780000
# success_probability = 0.65780000
# success_probability = 0.65760000
# success_probability = 0.65790000
# success_probability = 0.65780000
# success_probability = 0.65780000
# success_probability = 0.65740000
# success_probability = 0.65790000
# success_probability = 0.65760000
# success_probability = 0.65760000
# success_probability = 0.65770000
# success_probability = 0.65760000
# success_probability = 0.65780000
# success_probability = 0.65780000
# success_probability = 0.65780000
# success_probability = 0.65780000
# success_probability = 0.65780000
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1.5202189115232592
#             Iterations: 32
#             Function evaluations: 995
#             Gradient evaluations: 32
# Optimization Wall-Clock Time : 119.500039 s
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.65468000
# Evaluation  2/20 | Value = 0.65469000
# Evaluation  3/20 | Value = 0.65470000
# Evaluation  4/20 | Value = 0.65470000
# Evaluation  5/20 | Value = 0.65471000
# Evaluation  6/20 | Value = 0.65470000
# Evaluation  7/20 | Value = 0.65469000
# Evaluation  8/20 | Value = 0.65470000
# Evaluation  9/20 | Value = 0.65470000
# Evaluation 10/20 | Value = 0.65469000
# Evaluation 11/20 | Value = 0.65469000
# Evaluation 12/20 | Value = 0.65470000
# Evaluation 13/20 | Value = 0.65470000
# Evaluation 14/20 | Value = 0.65470000
# Evaluation 15/20 | Value = 0.65469000
# Evaluation 16/20 | Value = 0.65468000
# Evaluation 17/20 | Value = 0.65468000
# Evaluation 18/20 | Value = 0.65468000
# Evaluation 19/20 | Value = 0.65469000
# Evaluation 20/20 | Value = 0.65469000
#
# ================================================================================
# RUN 2 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 0
# Message              : Optimization terminated successfully
# Iterations           : 32
# Function Evaluations : 995
# Gradient Evaluations : 32
# Optimization Time    : 119.500039 s
# Final Objective Value: 1.5202189115232592
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.65780000
# Evaluated Mean        : 0.65469300
# Evaluated Std         : 0.00000843
# Evaluated Min         : 0.65468000
# Evaluated Max         : 0.65471000
#
# All Evaluated Values:
# [0.65468, 0.65469, 0.6547 , 0.6547 , 0.65471, 0.6547 , 0.65469, 0.6547 ,
#  0.6547 , 0.65469, 0.65469, 0.6547 , 0.6547 , 0.6547 , 0.65469, 0.65468,
#  0.65468, 0.65468, 0.65469, 0.65469]
#
# Initial Parameters:
# [0.4917938425, 0.3601415032, 0.7094100488, 0.6895107167, 0.4723817514,
#  0.4790485592, 0.0068635273, 0.9044398512, 0.4337399476, 0.4736042839,
#  0.034330777 , 0.9496323674, 0.5907905652, 0.4241785512, 0.1868628067,
#  0.9840929216, 0.690221156 , 0.9039467044, 0.0207568308, 0.9969449281,
#  0.3143005034, 0.2098620446, 0.0173606056, 0.1892781313, 0.2905169378,
#  0.2743264362, 0.6422361978, 0.0963913748]
#
# Optimal Parameters:
# [ 0.0609120019,  0.0829865951,  0.8822858859, -0.6021024558,  0.0594937972,
#   3.1212406834, -3.2407517042,  2.6963039008,  1.0366069942, -1.1685721205,
#   0.034330777 ,  0.9496323674,  0.1640954266,  0.5054147064,  0.3842309807,
#   1.1210879633,  0.3614942737,  0.9163587275, -0.9424574318, -0.0201868047,
#  -0.0146727022,  0.0861617151,  0.0173606056,  0.1892781313,  0.6208296882,
#   0.1958107028,  0.6422361978,  0.0963913748]
# ================================================================================
#
# ================================================================================
# Optimization Run 3/30
# Optimization Seed : 152
# ================================================================================
#
# Initial Parameters:
# [0.2185327016, 0.2605845547, 0.0494520073, 0.5385992113, 0.5420706407,
#  0.7890536718, 0.9123372133, 0.3722628249, 0.3257754726, 0.6556609124,
#  0.8969863307, 0.6516960973, 0.7833870606, 0.8742393722, 0.1922236761,
#  0.610154332 , 0.9457183359, 0.8193944158, 0.2252887854, 0.5455987355,
#  0.8717491352, 0.8014303248, 0.0339990148, 0.0928109212, 0.7620745294,
#  0.7686826107, 0.119207887 , 0.1127172009]
#
# Starting SLSQP optimization...
# success_probability = 0.35840000
# success_probability = 0.35820000
# success_probability = 0.35730000
# success_probability = 0.35840000
# success_probability = 0.35870000
# success_probability = 0.35750000
# success_probability = 0.35870000
# success_probability = 0.35930000
# success_probability = 0.35860000
# success_probability = 0.35880000
# success_probability = 0.35790000
# success_probability = 0.35840000
# success_probability = 0.35840000
# success_probability = 0.35840000
# success_probability = 0.35840000
# success_probability = 0.35850000
# success_probability = 0.35820000
# success_probability = 0.35860000
# success_probability = 0.35850000
# success_probability = 0.35840000
# success_probability = 0.35850000
# success_probability = 0.35820000
# success_probability = 0.35840000
# success_probability = 0.35840000
# success_probability = 0.35840000
# success_probability = 0.35840000
# success_probability = 0.35840000
# success_probability = 0.35840000
# success_probability = 0.35840000
# success_probability = 0.45240000
# success_probability = 0.45220000
# success_probability = 0.45310000
# success_probability = 0.45220000
# success_probability = 0.45210000
# success_probability = 0.45260000
# success_probability = 0.45250000
# success_probability = 0.45310000
# success_probability = 0.45300000
# ...
# Optimization Seed : 173
# Optimized Value   : 0.51050000
# Evaluated Mean    : 0.50160000
# Evaluated Std     : 0.00000837
# Evaluated Min     : 0.50159000
# Evaluated Max     : 0.50161000
# Success           : True
# Reached MaxIter   : False
# Status            : 0
# Message           : Optimization terminated successfully
# Iterations        : 4
# Function Evals    : 127
# Gradient Evals    : 4
# Optimization Time : 15.784579 s
#
# Evaluated Values:
# [0.50159, 0.50159, 0.5016 , 0.5016 , 0.5016 , 0.5016 , 0.50161, 0.50161,
#  0.50161, 0.50161, 0.50161, 0.50161, 0.50161, 0.5016 , 0.5016 , 0.50159,
#  0.50159, 0.50159, 0.50159, 0.50159]
#
# Initial Parameters:
# [0.0683064102, 0.5061877572, 0.2800764934, 0.4917358842, 0.3376481488,
#  0.6337766115, 0.7941202296, 0.2237709719, 0.8893153608, 0.9462072178,
#  0.9270749557, 0.8979372613, 0.8865232604, 0.1112901922, 0.4404611446,
#  0.6571269562, 0.6018173982, 0.0668305069, 0.5031888045, 0.7100940384,
#  0.3646853666, 0.6647653187, 0.3408936761, 0.3312253256, 0.7714370826,
#  0.2269448353, 0.0303235797, 0.6383902153]
#
# Optimal Parameters:
# [ 0.6251554398,  0.2759567859,  0.2830019996, -1.8664958431, -0.0163507895,
#   0.9332999708,  3.710629752 ,  0.1815037732,  1.7091114718, -0.0538163486,
#   0.9270749557,  0.8979372613,  0.7564337885, -0.6639714405,  0.2255998571,
#   1.0022361057,  0.9013532573,  0.2815903854,  0.5031888045,  0.7037895466,
#  -0.5832703037,  0.2772595307,  0.3408936761,  0.3312253256,  0.7714370826,
#   0.2269448353,  0.0303235797,  0.6383902153]
# ----------------------------------------------------------------------------------------------------
#
# Run 25
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 174
# Optimized Value   : 0.56790000
# Evaluated Mean    : 0.56186100
# Evaluated Std     : 0.00001221
# Evaluated Min     : 0.56184000
# Evaluated Max     : 0.56188000
# Success           : True
# Reached MaxIter   : False
# Status            : 0
# Message           : Optimization terminated successfully
# Iterations        : 9
# Function Evals    : 278
# Gradient Evals    : 9
# Optimization Time : 35.128884 s
#
# Evaluated Values:
# [0.56184, 0.56184, 0.56185, 0.56186, 0.56187, 0.56187, 0.56187, 0.56188,
#  0.56188, 0.56187, 0.56187, 0.56187, 0.56187, 0.56187, 0.56186, 0.56185,
#  0.56185, 0.56185, 0.56185, 0.56185]
#
# Initial Parameters:
# [0.920751175 , 0.8324481628, 0.9226421153, 0.4120178702, 0.112899878 ,
#  0.539662511 , 0.9690640438, 0.8958288503, 0.8463732302, 0.6837088366,
#  0.0134777936, 0.9213092468, 0.0585796685, 0.528523907 , 0.4212992395,
#  0.8064657524, 0.2081509804, 0.1492170041, 0.0586840123, 0.6381376407,
#  0.7175421339, 0.7259671078, 0.0347409726, 0.8317209152, 0.1893140181,
#  0.5873066532, 0.6508822385, 0.1541344136]
#
# Optimal Parameters:
# [-0.0435902029, -0.3372839227, -0.1832584673,  0.3751782226, -0.008994103 ,
#   1.1074612646,  2.8985031576,  1.5328131149, -0.4889970572, -0.3851948658,
#   0.0134777936,  0.9213092468, -0.2779259061,  0.3667629104,  0.4835205379,
#   1.7194379199,  0.1939166005,  0.0109624309, -0.0266358065, -0.5168501361,
#   1.2588193673,  0.9941285253,  0.0347409726,  0.8317209152,  0.1182285792,
#   0.5162212143,  0.6508822385,  0.1541344136]
# ----------------------------------------------------------------------------------------------------
#
# Run 26
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 175
# Optimized Value   : 0.37130000
# Evaluated Mean    : 0.36024450
# Evaluated Std     : 0.00001161
# Evaluated Min     : 0.36023000
# Evaluated Max     : 0.36027000
# Success           : True
# Reached MaxIter   : False
# Status            : 0
# Message           : Optimization terminated successfully
# Iterations        : 2
# Function Evals    : 72
# Gradient Evals    : 2
# Optimization Time : 8.948794 s
#
# Evaluated Values:
# [0.36023, 0.36024, 0.36024, 0.36023, 0.36024, 0.36023, 0.36023, 0.36024,
#  0.36025, 0.36024, 0.36025, 0.36026, 0.36026, 0.36027, 0.36026, 0.36025,
#  0.36025, 0.36025, 0.36024, 0.36023]
#
# Initial Parameters:
# [0.5632800098, 0.5263460088, 0.074383608 , 0.0432472297, 0.1116614549,
#  0.3149336925, 0.8051899849, 0.2265811498, 0.2507577735, 0.3247400132,
#  0.7132637608, 0.7744654451, 0.9295185054, 0.8709503245, 0.9380278462,
#  0.6231528096, 0.2419077457, 0.8799737511, 0.1804762542, 0.8020908004,
#  0.3363522676, 0.2884964572, 0.5552697615, 0.8113197998, 0.1117050081,
#  0.04623727  , 0.2558624663, 0.3513980154]
#
# Optimal Parameters:
# [0.5447005966, 0.45252839  , 0.0834295598, 0.024786027 , 0.0379028777,
#  0.3240387496, 0.8328736192, 0.2265516528, 0.2596853233, 0.2693847744,
#  0.7132637608, 0.7744654451, 0.9294890085, 0.8709503245, 0.9380278462,
#  0.6231528096, 0.2419077457, 0.8799737511, 0.1804762542, 0.8020908004,
#  0.3363227706, 0.2884964572, 0.5552697615, 0.8113197998, 0.1117050081,
#  0.04623727  , 0.2558624663, 0.3513980154]
# ----------------------------------------------------------------------------------------------------
#
# Run 27
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 176
# Optimized Value   : 0.60160000
# Evaluated Mean    : 0.58538700
# Evaluated Std     : 0.00001308
# Evaluated Min     : 0.58536000
# Evaluated Max     : 0.58541000
# Success           : True
# Reached MaxIter   : False
# Status            : 0
# Message           : Optimization terminated successfully
# Iterations        : 13
# Function Evals    : 400
# Gradient Evals    : 13
# Optimization Time : 49.719885 s
#
# Evaluated Values:
# [0.58536, 0.58537, 0.58538, 0.58538, 0.58538, 0.58537, 0.58537, 0.58538,
#  0.58539, 0.5854 , 0.5854 , 0.5854 , 0.5854 , 0.58541, 0.5854 , 0.5854 ,
#  0.58539, 0.58539, 0.58539, 0.58538]
#
# Initial Parameters:
# [0.908796571 , 0.1480812304, 0.9316217524, 0.8690627692, 0.8218723273,
#  0.3598173853, 0.8198721198, 0.1817033926, 0.2126209616, 0.6959983996,
#  0.3659168242, 0.6449720995, 0.1945739112, 0.1231941489, 0.9608135811,
#  0.9693122607, 0.6994862206, 0.3285305578, 0.5308429614, 0.0713595069,
#  0.6124682681, 0.0173357401, 0.2291752338, 0.1716368198, 0.7904109494,
#  0.6764072798, 0.8677348266, 0.5559777189]
#
# Optimal Parameters:
# [-0.0540778658, -0.0710761646,  1.0816046118,  1.7049616353, -0.1125089821,
#   2.0657142209,  2.9793860943,  0.7859128644, -0.7811613899,  0.5194575573,
#   0.3659168242,  0.6449720995,  0.3951712998,  1.3399398494,  0.9098237099,
#   1.6674294411,  0.9049050918,  0.1515217566,  0.69200592  ,  0.2099890365,
#   0.1028439701,  0.4624432844,  0.2291752338,  0.1716368198,  0.7890899046,
#   0.6856800976,  0.8677348266,  0.5559777189]
# ----------------------------------------------------------------------------------------------------
#
# Run 28
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 177
# Optimized Value   : 0.86490000
# Evaluated Mean    : 0.85770800
# Evaluated Std     : 0.00000400
# Evaluated Min     : 0.85770000
# Evaluated Max     : 0.85771000
# Success           : True
# Reached MaxIter   : False
# Status            : 0
# Message           : Optimization terminated successfully
# Iterations        : 38
# Function Evals    : 1148
# Gradient Evals    : 38
# Optimization Time : 143.158949 s
#
# Evaluated Values:
# [0.8577 , 0.8577 , 0.8577 , 0.8577 , 0.85771, 0.85771, 0.85771, 0.85771,
#  0.85771, 0.85771, 0.85771, 0.85771, 0.85771, 0.85771, 0.85771, 0.85771,
#  0.85771, 0.85771, 0.85771, 0.85771]
#
# Initial Parameters:
# [0.4859979492, 0.3134855983, 0.5928545916, 0.5388495959, 0.8208222388,
#  0.1681699936, 0.7886708539, 0.9073399324, 0.1513191786, 0.6385598502,
#  0.0204482374, 0.441729694 , 0.1062169866, 0.3316953766, 0.9856944419,
#  0.4606017013, 0.291802071 , 0.5311775661, 0.6869978953, 0.085870002 ,
#  0.70379701  , 0.7732596263, 0.358077326 , 0.7448635381, 0.5398799816,
#  0.6518199474, 0.496504845 , 0.729372615 ]
#
# Optimal Parameters:
# [-4.6372738575e-02, -1.5228720679e-04, -1.2492053622e+00,
#   1.6141411075e+00, -3.3766314931e-01,  3.5615730641e+00,
#   3.2155924185e+00,  3.2965614546e+00, -2.7974909797e-01,
#   1.1410682225e+00,  2.0448237372e-02,  4.4172969397e-01,
#  -2.6489881319e-01, -1.5221641500e+00,  8.7566679843e-01,
#  -2.2778227465e-01,  2.8494401549e+00,  2.2357988867e-01,
#  -2.4135930053e-02, -2.9466248704e+00, -7.9020147479e-01,
#   1.4307485088e+00,  3.5807732598e-01,  7.4486353812e-01,
#   8.8368528480e-01,  1.5461119321e+00,  4.9650484503e-01,
#   7.2937261495e-01]
# ----------------------------------------------------------------------------------------------------
#
# Run 29
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 178
# Optimized Value   : 0.54230000
# Evaluated Mean    : 0.53238150
# Evaluated Std     : 0.00001014
# Evaluated Min     : 0.53236000
# Evaluated Max     : 0.53240000
# Success           : True
# Reached MaxIter   : False
# Status            : 0
# Message           : Optimization terminated successfully
# Iterations        : 7
# Function Evals    : 214
# Gradient Evals    : 7
# Optimization Time : 26.660268 s
#
# Evaluated Values:
# [0.53237, 0.53238, 0.53239, 0.53238, 0.53239, 0.53238, 0.53237, 0.53237,
#  0.53238, 0.53239, 0.5324 , 0.5324 , 0.53239, 0.53239, 0.53238, 0.53238,
#  0.53238, 0.53238, 0.53237, 0.53236]
#
# Initial Parameters:
# [0.7608275692, 0.0464101376, 0.0032708871, 0.7605003536, 0.2769531808,
#  0.5945503444, 0.8036218146, 0.7402677744, 0.1239034672, 0.2438968692,
#  0.748428843 , 0.9205783868, 0.2357355697, 0.9391032789, 0.4081091944,
#  0.4620759117, 0.7294079941, 0.5779372506, 0.3477807167, 0.9240071009,
#  0.4847679255, 0.9369591861, 0.6895419866, 0.4903610315, 0.1782447546,
#  0.0915727898, 0.6053767128, 0.8164664622]
#
# Optimal Parameters:
# [-0.2999511374, -0.20300952  , -0.3275883145,  0.8504086982,  0.0448109473,
#   0.2241343543,  2.924510547 ,  1.12469812  ,  0.3993893474, -0.3853583172,
#   0.748428843 ,  0.9205783868,  0.116211363 ,  0.9639918531,  0.4255536329,
#   0.1216502052,  0.6349657787,  0.672342137 ,  0.2988067631,  0.0744440876,
#   0.0966275623,  0.929407394 ,  0.6895419866,  0.4903610315,  0.272649641 ,
#   0.1859776762,  0.6053767128,  0.8164664622]
# ----------------------------------------------------------------------------------------------------
#
# Run 30
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 179
# Optimized Value   : 0.62580000
# Evaluated Mean    : 0.61175600
# Evaluated Std     : 0.00001200
# Evaluated Min     : 0.61173000
# Evaluated Max     : 0.61177000
# Success           : True
# Reached MaxIter   : False
# Status            : 0
# Message           : Optimization terminated successfully
# Iterations        : 17
# Function Evals    : 525
# Gradient Evals    : 17
# Optimization Time : 67.633623 s
#
# Evaluated Values:
# [0.61175, 0.61175, 0.61176, 0.61176, 0.61177, 0.61177, 0.61176, 0.61177,
#  0.61177, 0.61177, 0.61177, 0.61176, 0.61176, 0.61175, 0.61174, 0.61173,
#  0.61174, 0.61174, 0.61175, 0.61175]
#
# Initial Parameters:
# [0.9180695286, 0.9403935557, 0.9611445873, 0.1282735573, 0.7343854482,
#  0.1418537547, 0.3206870255, 0.8783134777, 0.3925501756, 0.9542827898,
#  0.4333144504, 0.0052152104, 0.5921889116, 0.318609756 , 0.9316370681,
#  0.6026668473, 0.0078690534, 0.7991305598, 0.851774691 , 0.06652901  ,
#  0.7310172927, 0.1064287992, 0.0810809173, 0.7115609048, 0.7069595409,
#  0.496652521 , 0.9897356485, 0.1231137075]
#
# Optimal Parameters:
# [ 0.3071643739,  0.0157133437, -1.0322529649,  0.3797942145,  0.1565821005,
#   2.3446993256,  2.9593690149,  4.3090246771,  1.0081318106, -0.8682727275,
#   0.4333144504,  0.0052152104,  0.8430293884,  0.1040101484,  0.5722095438,
#  -0.0417732006,  0.3144533831,  0.9314008175,  1.0322275081,  0.3515949373,
#   0.5606998536, -0.1396650937,  0.0810809173,  0.7115609048,  0.6705684616,
#   0.2886327511,  0.9897356485,  0.1231137075]
# ----------------------------------------------------------------------------------------------------
#
# SUMMARY
# ====================================================================================================
#
# Original Optimization-Shot Results:
# Maximum Optimized Value : 0.95100000
# Maximum Run             : 17
# Mean Optimized Value    : 0.69900333
# Std Optimized Value     : 0.18589063
#
# High-Shot Evaluation Results:
# Best Evaluated Mean     : 0.94836800
# Best Evaluated Mean Run : 17
# Mean of Evaluated Means : 0.69149120
# Std of Evaluated Means  : 0.18902976
#
# Optimizer Statistics:
# Mean Iterations         : 19.60
# Std Iterations          : 13.65
# Mean Function Evals     : 599.07
# Std Function Evals      : 409.19
# Mean Gradient Evals     : 19.60
# Std Gradient Evals      : 13.65
# Successful Runs         : 30/30
# Failed Runs             : 0/30
# Reached MaxIter         : 0/30
#
# Computational Runtime Statistics:
# Total Wall-Clock Time          : 2561.514829 s
# Total Optimization Time        : 2188.096072 s
# Time per Complete Opt. Run     : 72.936536 s
# Std Optimization Time per Run  : 49.731012 s
#
# ====================================================================================================
# BEST RUN ACCORDING TO ORIGINAL OPTIMIZED VALUE
# ====================================================================================================
# Run             : 17
# Optimized Value : 0.95100000
# Evaluated Mean  : 0.94836800
# Evaluated Std   : 0.00000400
# Evaluated Min   : 0.94836000
# Evaluated Max   : 0.94837000
#
# Evaluated Values:
# [0.94836, 0.94836, 0.94836, 0.94836, 0.94837, 0.94837, 0.94837, 0.94837,
#  0.94837, 0.94837, 0.94837, 0.94837, 0.94837, 0.94837, 0.94837, 0.94837,
#  0.94837, 0.94837, 0.94837, 0.94837]
#
# Initial Parameters:
# [0.7162412684, 0.1693989446, 0.7052765596, 0.2312009266, 0.9423502042,
#  0.6728407104, 0.4350288739, 0.1490473433, 0.3371571605, 0.9369448933,
#  0.3373395547, 0.961351198 , 0.4707410022, 0.7024076892, 0.9419588348,
#  0.0183954332, 0.0077587191, 0.4818001667, 0.7262090741, 0.616799371 ,
#  0.6107607858, 0.4676317986, 0.0873035913, 0.3932966427, 0.2402358413,
#  0.6880719084, 0.6456336481, 0.6554428034]
#
# Optimal Parameters:
# [-0.0265277349,  0.076697111 ,  0.1099626998,  1.5719526344,  0.0597262526,
#   3.0496879248,  3.1546077133,  3.1883906521,  0.2495756081,  0.2371084641,
#   0.3373395547,  0.961351198 ,  0.7114085268,  1.5707330047,  0.3992515657,
#   0.1363697275, -3.3046986038, -0.0450746915,  3.1287640429,  0.0609962697,
#   1.0465328569,  1.134441263 ,  0.0873035913,  0.3932966427,  0.1277552814,
#   1.2933513366,  0.6456336481,  0.6554428034]
#
# ====================================================================================================
# BEST RUN ACCORDING TO HIGH-SHOT EVALUATED MEAN
# ====================================================================================================
# Run             : 17
# Optimized Value : 0.95100000
# Evaluated Mean  : 0.94836800
# Evaluated Std   : 0.00000400
# Evaluated Min   : 0.94836000
# Evaluated Max   : 0.94837000
#
# Evaluated Values:
# [0.94836, 0.94836, 0.94836, 0.94836, 0.94837, 0.94837, 0.94837, 0.94837,
#  0.94837, 0.94837, 0.94837, 0.94837, 0.94837, 0.94837, 0.94837, 0.94837,
#  0.94837, 0.94837, 0.94837, 0.94837]
#
# Initial Parameters:
# [0.7162412684, 0.1693989446, 0.7052765596, 0.2312009266, 0.9423502042,
#  0.6728407104, 0.4350288739, 0.1490473433, 0.3371571605, 0.9369448933,
#  0.3373395547, 0.961351198 , 0.4707410022, 0.7024076892, 0.9419588348,
#  0.0183954332, 0.0077587191, 0.4818001667, 0.7262090741, 0.616799371 ,
#  0.6107607858, 0.4676317986, 0.0873035913, 0.3932966427, 0.2402358413,
#  0.6880719084, 0.6456336481, 0.6554428034]
#
# Optimal Parameters:
# [-0.0265277349,  0.076697111 ,  0.1099626998,  1.5719526344,  0.0597262526,
#   3.0496879248,  3.1546077133,  3.1883906521,  0.2495756081,  0.2371084641,
#   0.3373395547,  0.961351198 ,  0.7114085268,  1.5707330047,  0.3992515657,
#   0.1363697275, -3.3046986038, -0.0450746915,  3.1287640429,  0.0609962697,
#   1.0465328569,  1.134441263 ,  0.0873035913,  0.3932966427,  0.1277552814,
#   1.2933513366,  0.6456336481,  0.6554428034]
# ====================================================================================================
#
# Report saved to:
# /Users/sungwonyun/Documents/Qiskit/Minimum Error Discrimination/Opitmizer Sensitivity Test/SLSQP_report.txt
