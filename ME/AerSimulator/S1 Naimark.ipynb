# %%
# 0,1: 00 for psi_1, 01 for psi_2 ...
# 2: For states
# 3,4: Ancillary qubits

# when theta = 32.56... 
# psi_1 = |0> 
# psi_2 = sqrt(2/3)|0> + sqrt(1/3)|1>
# psi_3 = sqrt(2/3)|0> - sqrt(1/3)|1>

# %%
from qiskit import QuantumCircuit
from numpy import sqrt

def circuit_init():
    qc = QuantumCircuit(5)
    return qc

def PREP(qc):
    desired_vector = [sqrt(1/3), 0, sqrt(2)/3, 1/3, sqrt(2)/3, -1/3, 0, 0]
    qc.initialize(desired_vector, [2,1,0])
    return qc

def CX01(qc, wires):
    qc.append(XGate().control(1, ctrl_state='1'),[wires[0], wires[1]])
    return qc

# %%
from qiskit.circuit.library.standard_gates import RYGate
from qiskit.circuit.library import UGate
from qiskit.circuit.library.standard_gates import XGate
from numpy import pi
 
def Ansatz(qc, wires, params):
    qc.u(params[0], params[1], params[2], wires[0])

    # set RYGate
    CRY1_1=RYGate(params[3],label='θ1_1').control(1,ctrl_state='0')
    CRY2_1=RYGate(params[4],label='θ2_1').control(1,ctrl_state='1')
    CRY1_2=RYGate(params[5],label='θ1_2').control(2,ctrl_state='10')
    CRY2_2=RYGate(params[6],label='θ2_2').control(2)

    # set VGate
    V1_1 = UGate(params[7],params[8],params[9],label = 'V1_1').control(1,ctrl_state='0')
    V2_1 = UGate(params[10],params[11],params[12],label = 'V2_1').control(1,ctrl_state='1')
    V1_2 = UGate(params[13],params[14],params[15],label = 'V1_2').control(2,ctrl_state='10')
    V2_2 = UGate(params[16],params[17],params[18],label = 'V2_2').control(2)

    # module 1
    qc.append(CRY1_1, [wires[0], wires[1]])
    qc.append(CRY2_1, [wires[0], wires[1]])
    qc.append(V1_1, [wires[1], wires[0]])
    qc.append(V2_1, [wires[1], wires[0]])
    #qc.cx(wires[2], wires[1])
    qc.append(CRY1_2, [wires[0], wires[1], wires[2]])
    qc.append(CRY2_2, [wires[0], wires[1], wires[2]])
    qc.append(V1_2, [wires[2], wires[1], wires[0]])
    qc.append(V2_2, [wires[2], wires[1], wires[0]])

    CX01(qc, [wires[2],wires[1]])
    
    qc.measure_all()
    return qc

# %%
from numpy.random import rand

num_params= 19
params = list(range(num_params))
num_shots=10000

qc = circuit_init()
PREP(qc)
Ansatz(qc, [2,3,4] , params)

qc.draw(output='mpl', style = 'clifford') 
#qc_reversed=qc.reverse_bits()
#qc_reversed.draw(output='mpl',style = 'clifford')

# %%
from qiskit_aer import AerSimulator
from qiskit import transpile
from scipy.optimize import minimize

import numpy as np
import os
import time


# ============================================================
# Simulator
# ============================================================

aersim = AerSimulator()


# ============================================================
# Settings
# ============================================================

num_times = 30
num_shots = 10000

optimizer_name = "COBYLA"
tol_value = 1e-8
maxiter = 1000

BASE_SEED = 150

report_filename = (
    "Sym_Nymark_report.txt"
)


# ============================================================
# High-Shot Evaluation Settings
# ============================================================

evaluation_num_times = 20
evaluation_num_shots = 100000

EVALUATION_BASE_SEED = 10000

evaluation_seeds = np.array(
    [
        EVALUATION_BASE_SEED + i
        for i in range(evaluation_num_times)
    ],
    dtype=int
)


# ============================================================
# Storage
# ============================================================

final_optimized_values = []

initial_params_all_runs = []
optimal_params_all_runs = []

optimization_success_all_runs = []
optimization_status_all_runs = []
optimization_message_all_runs = []
optimization_nfev_all_runs = []
reached_maxiter_all_runs = []


# ------------------------------------------------------------
# Runtime Storage
# ------------------------------------------------------------

optimization_wall_times = []


# ------------------------------------------------------------
# High-Shot Evaluation Storage
# ------------------------------------------------------------

evaluation_values_all_runs = []

evaluation_mean_all_runs = []
evaluation_std_all_runs = []
evaluation_min_all_runs = []
evaluation_max_all_runs = []


# ============================================================
# Objective Function
# ============================================================

def objective_function(
    params,
    run_seed,
    shots=None,
    print_result=True
):

    if shots is None:
        shots = num_shots


    # --------------------------------------------------------
    # Construct circuit
    # --------------------------------------------------------

    qc = circuit_init()

    PREP(qc)

    Ansatz(
        qc,
        [2, 3, 4],
        params
    )


    qc_reverse = qc.reverse_bits()


    # --------------------------------------------------------
    # Transpile
    # --------------------------------------------------------

    t_qc = transpile(
        qc_reverse,
        aersim,
        seed_transpiler=run_seed
    )


    # --------------------------------------------------------
    # Run simulation
    # --------------------------------------------------------

    job = aersim.run(
        t_qc,
        shots=shots,
        seed_simulator=run_seed
    )


    result = job.result()

    counts = result.get_counts()


    # --------------------------------------------------------
    # Target counts
    # --------------------------------------------------------

    tar_00 = 0
    tar_01 = 0
    tar_10 = 0


    for outcome, count in counts.items():

        if outcome[0:2] == "00":

            if outcome[3:5] == "00":

                tar_00 += count


        if outcome[0:2] == "01":

            if outcome[3:5] == "01":

                tar_01 += count


        if outcome[0:2] == "10":

            if outcome[3:5] == "10":

                tar_10 += count


    # --------------------------------------------------------
    # Success probability
    # --------------------------------------------------------

    p_suc = (
        tar_00
        + tar_01
        + tar_10
    ) / shots


    if print_result:

        print(
            f"success_probability = "
            f"{p_suc:.8f}"
        )


    # --------------------------------------------------------
    # Avoid division by zero
    # --------------------------------------------------------

    if p_suc == 0:

        return 1e10


    # --------------------------------------------------------
    # COBYLA minimizes.
    #
    # Minimizing 1 / p_suc maximizes p_suc.
    # --------------------------------------------------------

    return 1.0 / p_suc


# ============================================================
# Run Optimization
# ============================================================

total_wall_start = time.perf_counter()

for run in range(num_times):


    # ========================================================
    # Optimization Seed
    # ========================================================

    run_seed = (
        BASE_SEED + run
    )


    rng = np.random.default_rng(
        run_seed
    )


    print(
        "\n"
        + "=" * 80
    )


    print(
        f"Optimization Run "
        f"{run + 1}/{num_times}"
    )


    print(
        f"Optimization Seed : "
        f"{run_seed}"
    )


    print(
        "=" * 80
    )


    # ========================================================
    # Generate Random Initial Parameters
    # ========================================================

    initial_params = rng.random(
        num_params
    )


    initial_params_all_runs.append(
        initial_params.copy()
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    # ========================================================
    # Run COBYLA Optimization
    # ========================================================

    print(
        "\nStarting COBYLA optimization..."
    )


    optimization_start = time.perf_counter()

    result = minimize(

        fun=lambda params: objective_function(
            params,
            run_seed,
            shots=num_shots,
            print_result=True
        ),

        x0=initial_params,

        method=optimizer_name,

        options={
            "maxiter": maxiter,
            "disp": True,
            "tol": tol_value
        }
    )

    optimization_end = time.perf_counter()

    run_optimization_wall_time = (
        optimization_end
        - optimization_start
    )

    optimization_wall_times.append(
        run_optimization_wall_time
    )


    # ========================================================
    # Optimization Status
    # ========================================================

    optimization_success = bool(
        result.success
    )


    optimization_status = getattr(
        result,
        "status",
        None
    )


    optimization_message = str(
        getattr(
            result,
            "message",
            "No message returned"
        )
    )


    optimization_nfev = getattr(
        result,
        "nfev",
        None
    )


    # ========================================================
    # Detect Maximum Function Evaluations
    # ========================================================

    message_lower = (
        optimization_message.lower()
    )


    reached_maxiter = (

        "maximum number"
        in message_lower

        or "maximum function"
        in message_lower

        or "maxiter"
        in message_lower

        or "maxfun"
        in message_lower

        or "maximum iterations"
        in message_lower

        or "maximum evaluations"
        in message_lower
    )


    if optimization_nfev is not None:

        if optimization_nfev >= maxiter:

            reached_maxiter = True


    # ========================================================
    # Store Optimization Status
    # ========================================================

    optimization_success_all_runs.append(
        optimization_success
    )


    optimization_status_all_runs.append(
        optimization_status
    )


    optimization_message_all_runs.append(
        optimization_message
    )


    optimization_nfev_all_runs.append(
        optimization_nfev
    )


    reached_maxiter_all_runs.append(
        reached_maxiter
    )


    # ========================================================
    # Optimal Parameters
    # ========================================================

    optimal_params = (
        result.x.copy()
    )


    optimal_params_all_runs.append(
        optimal_params.copy()
    )


    # ========================================================
    # Final Optimization-Shot Evaluation
    # ========================================================

    final_objective = objective_function(
        optimal_params,
        run_seed,
        shots=num_shots,
        print_result=False
    )


    if final_objective >= 1e10:

        final_value = 0.0

    else:

        final_value = (
            1.0 / final_objective
        )


    final_optimized_values.append(
        final_value
    )


    # ========================================================
    # High-Shot Evaluation
    # ========================================================

    print(
        "\n"
        + "-" * 80
    )


    print(
        "HIGH-SHOT EVALUATION OF "
        "OPTIMIZED PARAMETERS"
    )


    print(
        "-" * 80
    )


    print(
        f"Optimization Shots     : "
        f"{num_shots}"
    )


    print(
        f"Evaluation Shots       : "
        f"{evaluation_num_shots}"
    )


    print(
        f"Number of Evaluations : "
        f"{evaluation_num_times}"
    )


    print(
        "\nEvaluation Results:"
    )


    evaluation_values = []


    for eval_index, eval_seed in enumerate(
        evaluation_seeds
    ):


        eval_objective = objective_function(
            optimal_params,
            int(eval_seed),
            shots=evaluation_num_shots,
            print_result=False
        )


        if eval_objective >= 1e10:

            eval_value = 0.0

        else:

            eval_value = (
                1.0 / eval_objective
            )


        evaluation_values.append(
            eval_value
        )


        print(
            f"Evaluation "
            f"{eval_index + 1:2d}/"
            f"{evaluation_num_times:2d}"
            f" | Value = "
            f"{eval_value:.8f}"
        )


    # ========================================================
    # Evaluation Statistics
    # ========================================================

    evaluation_values = np.array(
        evaluation_values,
        dtype=float
    )


    evaluation_mean = np.mean(
        evaluation_values
    )


    evaluation_std = np.std(
        evaluation_values
    )


    evaluation_min = np.min(
        evaluation_values
    )


    evaluation_max = np.max(
        evaluation_values
    )


    # ========================================================
    # Store Evaluation Results
    # ========================================================

    evaluation_values_all_runs.append(
        evaluation_values.copy()
    )


    evaluation_mean_all_runs.append(
        evaluation_mean
    )


    evaluation_std_all_runs.append(
        evaluation_std
    )


    evaluation_min_all_runs.append(
        evaluation_min
    )


    evaluation_max_all_runs.append(
        evaluation_max
    )


    # ========================================================
    # Individual Run Report
    # ========================================================

    print(
        "\n"
        + "=" * 80
    )


    print(
        f"RUN {run + 1} RESULT"
    )


    print(
        "=" * 80
    )


    print(
        f"Optimization Success : "
        f"{optimization_success}"
    )


    print(
        f"Reached MaxIter      : "
        f"{reached_maxiter}"
    )


    print(
        f"Status               : "
        f"{optimization_status}"
    )


    print(
        f"Message              : "
        f"{optimization_message}"
    )


    print(
        f"Function Evaluations : "
        f"{optimization_nfev}"
    )


    print(
        f"Optimization Time    : "
        f"{run_optimization_wall_time:.6f} s"
    )


    print(
        f"Final Objective Value: "
        f"{result.fun}"
    )


    print(
        "\n"
        + "-" * 80
    )


    print(
        "OPTIMIZED AND HIGH-SHOT "
        "EVALUATED VALUES"
    )


    print(
        "-" * 80
    )


    print(
        f"Final Optimized Value : "
        f"{final_value:.8f}"
    )


    print(
        f"Evaluated Mean        : "
        f"{evaluation_mean:.8f}"
    )


    print(
        f"Evaluated Std         : "
        f"{evaluation_std:.8f}"
    )


    print(
        f"Evaluated Min         : "
        f"{evaluation_min:.8f}"
    )


    print(
        f"Evaluated Max         : "
        f"{evaluation_max:.8f}"
    )


    print(
        "\nAll Evaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values,
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "=" * 80
    )


# ============================================================
# Runtime Statistics
# ============================================================

total_wall_end = time.perf_counter()

total_wall_time = (
    total_wall_end
    - total_wall_start
)

optimization_wall_times = np.array(
    optimization_wall_times,
    dtype=float
)

total_optimization_wall_time = np.sum(
    optimization_wall_times
)

mean_optimization_wall_time = np.mean(
    optimization_wall_times
)

std_optimization_wall_time = np.std(
    optimization_wall_times
)


# ============================================================
# Convert Results to NumPy Arrays
# ============================================================

final_optimized_values = np.array(
    final_optimized_values,
    dtype=float
)


initial_params_all_runs = np.array(
    initial_params_all_runs
)


optimal_params_all_runs = np.array(
    optimal_params_all_runs
)


evaluation_values_all_runs = np.array(
    evaluation_values_all_runs,
    dtype=float
)


evaluation_mean_all_runs = np.array(
    evaluation_mean_all_runs,
    dtype=float
)


evaluation_std_all_runs = np.array(
    evaluation_std_all_runs,
    dtype=float
)


evaluation_min_all_runs = np.array(
    evaluation_min_all_runs,
    dtype=float
)


evaluation_max_all_runs = np.array(
    evaluation_max_all_runs,
    dtype=float
)


# ============================================================
# Original Optimization Statistics
# ============================================================

maximum_value = np.max(
    final_optimized_values
)


mean_value = np.mean(
    final_optimized_values
)


std_value = np.std(
    final_optimized_values
)


maximum_run_index = np.argmax(
    final_optimized_values
)


maximum_run = (
    maximum_run_index + 1
)


# ============================================================
# High-Shot Evaluation Statistics
# ============================================================

maximum_evaluated_mean = np.max(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run_index = np.argmax(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run = (
    maximum_evaluated_mean_run_index
    + 1
)


mean_of_evaluated_means = np.mean(
    evaluation_mean_all_runs
)


std_of_evaluated_means = np.std(
    evaluation_mean_all_runs
)


# ============================================================
# Function Evaluation Statistics
# ============================================================

nfev_values = np.array(
    [
        nfev
        for nfev
        in optimization_nfev_all_runs
        if nfev is not None
    ],
    dtype=float
)


if len(nfev_values) > 0:

    mean_nfev = np.mean(
        nfev_values
    )


    std_nfev = np.std(
        nfev_values
    )

else:

    mean_nfev = np.nan
    std_nfev = np.nan


# ============================================================
# Optimization Success Statistics
# ============================================================

num_successful_runs = sum(
    optimization_success_all_runs
)


num_failed_runs = (
    num_times
    - num_successful_runs
)


num_reached_maxiter = sum(
    reached_maxiter_all_runs
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

best_initial_params = (
    initial_params_all_runs[
        maximum_run_index
    ]
)


best_optimal_params = (
    optimal_params_all_runs[
        maximum_run_index
    ]
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

best_evaluated_initial_params = (
    initial_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_optimal_params = (
    optimal_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_values = (
    evaluation_values_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


# ============================================================
# Print Final Report
# ============================================================

print("\n")


print(
    "=" * 100
)


print(
    "FINAL OPTIMIZATION AND "
    "HIGH-SHOT EVALUATION REPORT"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Settings
# ------------------------------------------------------------

print(
    f"Optimizer               : "
    f"{optimizer_name}"
)


print(
    f"Tolerance               : "
    f"{tol_value}"
)


print(
    f"Max Iteration           : "
    f"{maxiter}"
)


print(
    f"Number of Runs          : "
    f"{num_times}"
)


print(
    f"Optimization Shots      : "
    f"{num_shots}"
)


print(
    f"Optimization Base Seed  : "
    f"{BASE_SEED}"
)


print(
    f"Evaluation Shots        : "
    f"{evaluation_num_shots}"
)


print(
    f"Evaluations Per Run     : "
    f"{evaluation_num_times}"
)


print(
    f"Evaluation Base Seed    : "
    f"{EVALUATION_BASE_SEED}"
)


# Evaluation seeds are printed only once.
print(
    "Evaluation Seeds        : "
    + np.array2string(
        evaluation_seeds,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Results for Every Run
# ============================================================

for i in range(num_times):


    print(
        f"\nRun {i + 1:2d}"
    )


    print(
        "-" * 100
    )


    print(
        f"Optimization Seed : "
        f"{BASE_SEED + i}"
    )


    print(
        f"Optimized Value   : "
        f"{final_optimized_values[i]:.8f}"
    )


    print(
        f"Evaluated Mean    : "
        f"{evaluation_mean_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Std     : "
        f"{evaluation_std_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Min     : "
        f"{evaluation_min_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Max     : "
        f"{evaluation_max_all_runs[i]:.8f}"
    )


    print(
        f"Success           : "
        f"{optimization_success_all_runs[i]}"
    )


    print(
        f"Reached MaxIter   : "
        f"{reached_maxiter_all_runs[i]}"
    )


    print(
        f"Status            : "
        f"{optimization_status_all_runs[i]}"
    )


    print(
        f"Message           : "
        f"{optimization_message_all_runs[i]}"
    )


    print(
        f"Function Evals    : "
        f"{optimization_nfev_all_runs[i]}"
    )


    print(
        f"Optimization Time : "
        f"{optimization_wall_times[i]:.6f} s"
    )


    print(
        "\nEvaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values_all_runs[i],
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "-" * 100
    )


# ============================================================
# Summary
# ============================================================

print(
    "\nSUMMARY"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Original Optimization Results
# ------------------------------------------------------------

print(
    "\nOriginal Optimization-Shot Results:"
)


print(
    f"Maximum Optimized Value : "
    f"{maximum_value:.8f}"
)


print(
    f"Maximum Run             : "
    f"{maximum_run}"
)


print(
    f"Mean Optimized Value    : "
    f"{mean_value:.8f}"
)


print(
    f"Std Optimized Value     : "
    f"{std_value:.8f}"
)


# ------------------------------------------------------------
# High-Shot Evaluation Results
# ------------------------------------------------------------

print(
    "\nHigh-Shot Evaluation Results:"
)


print(
    f"Best Evaluated Mean     : "
    f"{maximum_evaluated_mean:.8f}"
)


print(
    f"Best Evaluated Mean Run : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Mean of Evaluated Means : "
    f"{mean_of_evaluated_means:.8f}"
)


print(
    f"Std of Evaluated Means  : "
    f"{std_of_evaluated_means:.8f}"
)


# ------------------------------------------------------------
# Optimizer Statistics
# ------------------------------------------------------------

print(
    "\nOptimizer Statistics:"
)


print(
    f"Mean Function Evals     : "
    f"{mean_nfev:.2f}"
)


print(
    f"Std Function Evals      : "
    f"{std_nfev:.2f}"
)


print(
    f"Successful Runs         : "
    f"{num_successful_runs}/"
    f"{num_times}"
)


print(
    f"Failed Runs             : "
    f"{num_failed_runs}/"
    f"{num_times}"
)


print(
    f"Reached MaxIter         : "
    f"{num_reached_maxiter}/"
    f"{num_times}"
)


# ------------------------------------------------------------
# Computational Runtime Statistics
# ------------------------------------------------------------

print(
    "\nComputational Runtime Statistics:"
)

print(
    f"Total Wall-Clock Time          : "
    f"{total_wall_time:.6f} s"
)

print(
    f"Total Optimization Time        : "
    f"{total_optimization_wall_time:.6f} s"
)

print(
    f"Time per Complete Opt. Run     : "
    f"{mean_optimization_wall_time:.6f} s"
)

print(
    f"Std Optimization Time per Run  : "
    f"{std_optimization_wall_time:.6f} s"
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "ORIGINAL OPTIMIZED VALUE"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        evaluation_values_all_runs[
            maximum_run_index
        ],
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_optimal_params,
        precision=10,
        separator=", "
    )
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "HIGH-SHOT EVALUATED MEAN"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        best_evaluated_values,
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_evaluated_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_evaluated_optimal_params,
        precision=10,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Save Report to TXT
# ============================================================

with open(
    report_filename,
    "w"
) as f:


    # ========================================================
    # Header
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "FINAL OPTIMIZATION AND "
        "HIGH-SHOT EVALUATION REPORT\n"
    )


    f.write(
        "=" * 100
        + "\n\n"
    )


    # ========================================================
    # Settings
    # ========================================================

    f.write(
        f"Optimizer               : "
        f"{optimizer_name}\n"
    )


    f.write(
        f"Tolerance               : "
        f"{tol_value}\n"
    )


    f.write(
        f"Max Iteration           : "
        f"{maxiter}\n"
    )


    f.write(
        f"Number of Runs          : "
        f"{num_times}\n"
    )


    f.write(
        f"Optimization Shots      : "
        f"{num_shots}\n"
    )


    f.write(
        f"Optimization Base Seed  : "
        f"{BASE_SEED}\n"
    )


    f.write(
        f"Evaluation Shots        : "
        f"{evaluation_num_shots}\n"
    )


    f.write(
        f"Evaluations Per Run     : "
        f"{evaluation_num_times}\n"
    )


    f.write(
        f"Evaluation Base Seed    : "
        f"{EVALUATION_BASE_SEED}\n"
    )


    # Evaluation seeds are saved only once.
    f.write(
        "Evaluation Seeds        : "
    )


    f.write(
        np.array2string(
            evaluation_seeds,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    # ========================================================
    # Results for Every Run
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "RESULTS FOR EACH RUN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    for i in range(num_times):


        f.write(
            f"\nRun {i + 1:2d}\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


        f.write(
            f"Optimization Seed : "
            f"{BASE_SEED + i}\n"
        )


        f.write(
            f"Optimized Value   : "
            f"{final_optimized_values[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Mean    : "
            f"{evaluation_mean_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Std     : "
            f"{evaluation_std_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Min     : "
            f"{evaluation_min_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Max     : "
            f"{evaluation_max_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Success           : "
            f"{optimization_success_all_runs[i]}\n"
        )


        f.write(
            f"Reached MaxIter   : "
            f"{reached_maxiter_all_runs[i]}\n"
        )


        f.write(
            f"Status            : "
            f"{optimization_status_all_runs[i]}\n"
        )


        f.write(
            f"Message           : "
            f"{optimization_message_all_runs[i]}\n"
        )


        f.write(
            f"Function Evals    : "
            f"{optimization_nfev_all_runs[i]}\n"
        )


        f.write(
            f"Optimization Time : "
            f"{optimization_wall_times[i]:.6f} s\n"
        )


        f.write(
            "\nEvaluated Values:\n"
        )


        f.write(
            np.array2string(
                evaluation_values_all_runs[i],
                precision=8,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nInitial Parameters:\n"
        )


        f.write(
            np.array2string(
                initial_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nOptimal Parameters:\n"
        )


        f.write(
            np.array2string(
                optimal_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


    # ========================================================
    # Summary
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "SUMMARY\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    # --------------------------------------------------------
    # Original Optimization Results
    # --------------------------------------------------------

    f.write(
        "\nOriginal Optimization-Shot Results:\n"
    )


    f.write(
        f"Maximum Optimized Value : "
        f"{maximum_value:.8f}\n"
    )


    f.write(
        f"Maximum Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Mean Optimized Value    : "
        f"{mean_value:.8f}\n"
    )


    f.write(
        f"Std Optimized Value     : "
        f"{std_value:.8f}\n"
    )


    # --------------------------------------------------------
    # High-Shot Evaluation Results
    # --------------------------------------------------------

    f.write(
        "\nHigh-Shot Evaluation Results:\n"
    )


    f.write(
        f"Best Evaluated Mean     : "
        f"{maximum_evaluated_mean:.8f}\n"
    )


    f.write(
        f"Best Evaluated Mean Run : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Mean of Evaluated Means : "
        f"{mean_of_evaluated_means:.8f}\n"
    )


    f.write(
        f"Std of Evaluated Means  : "
        f"{std_of_evaluated_means:.8f}\n"
    )


    # --------------------------------------------------------
    # Optimizer Statistics
    # --------------------------------------------------------

    f.write(
        "\nOptimizer Statistics:\n"
    )


    f.write(
        f"Mean Function Evals     : "
        f"{mean_nfev:.2f}\n"
    )


    f.write(
        f"Std Function Evals      : "
        f"{std_nfev:.2f}\n"
    )


    f.write(
        f"Successful Runs         : "
        f"{num_successful_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Failed Runs             : "
        f"{num_failed_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Reached MaxIter         : "
        f"{num_reached_maxiter}/"
        f"{num_times}\n"
    )


    # --------------------------------------------------------
    # Computational Runtime Statistics
    # --------------------------------------------------------

    f.write(
        "\nComputational Runtime Statistics:\n"
    )

    f.write(
        f"Total Wall-Clock Time          : "
        f"{total_wall_time:.6f} s\n"
    )

    f.write(
        f"Total Optimization Time        : "
        f"{total_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Time per Complete Opt. Run     : "
        f"{mean_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Std Optimization Time per Run  : "
        f"{std_optimization_wall_time:.6f} s\n"
    )


    # ========================================================
    # Best Run According to Original Optimized Value
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "ORIGINAL OPTIMIZED VALUE\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            evaluation_values_all_runs[
                maximum_run_index
            ],
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    # ========================================================
    # Best Run According to High-Shot Evaluated Mean
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "HIGH-SHOT EVALUATED MEAN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_values,
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


# ============================================================
# Report Location
# ============================================================

print(
    "\nReport saved to:"
)


print(
    os.path.abspath(
        report_filename
    )
)
# Out:
# ================================================================================
# Optimization Run 1/30
# Optimization Seed : 150
# ================================================================================
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566]
#
# Starting COBYLA optimization...
# success_probability = 0.34070000
# success_probability = 0.32910000
# success_probability = 0.34080000
# success_probability = 0.34100000
# success_probability = 0.30570000
# success_probability = 0.38930000
# success_probability = 0.39060000
# success_probability = 0.39130000
# success_probability = 0.38940000
# success_probability = 0.39130000
# success_probability = 0.39210000
# success_probability = 0.39230000
# success_probability = 0.39180000
# success_probability = 0.39550000
# success_probability = 0.39440000
# success_probability = 0.39550000
# success_probability = 0.39560000
# success_probability = 0.39530000
# success_probability = 0.39560000
# success_probability = 0.39450000
# success_probability = 0.42310000
# success_probability = 0.43180000
# success_probability = 0.42400000
# success_probability = 0.43270000
# success_probability = 0.43750000
# success_probability = 0.46180000
# success_probability = 0.45880000
# success_probability = 0.46340000
# success_probability = 0.47540000
# success_probability = 0.49650000
# success_probability = 0.49660000
# success_probability = 0.49660000
# success_probability = 0.50340000
# success_probability = 0.49870000
# success_probability = 0.49760000
# success_probability = 0.50080000
# success_probability = 0.50760000
# success_probability = 0.50340000
# success_probability = 0.50290000
# success_probability = 0.50760000
# success_probability = 0.47910000
# success_probability = 0.51110000
# success_probability = 0.45900000
# success_probability = 0.51420000
# success_probability = 0.47400000
# success_probability = 0.51090000
# success_probability = 0.44180000
# success_probability = 0.51440000
# success_probability = 0.49920000
# success_probability = 0.50440000
# success_probability = 0.50200000
# success_probability = 0.47430000
# success_probability = 0.51390000
# success_probability = 0.51520000
# success_probability = 0.51570000
# success_probability = 0.51430000
# success_probability = 0.51620000
# success_probability = 0.51500000
# success_probability = 0.51420000
# success_probability = 0.51340000
# success_probability = 0.50770000
# success_probability = 0.50420000
# success_probability = 0.50150000
# success_probability = 0.51750000
# success_probability = 0.51100000
# success_probability = 0.51740000
# success_probability = 0.51480000
# success_probability = 0.51780000
# success_probability = 0.51450000
# success_probability = 0.51910000
# success_probability = 0.51600000
# success_probability = 0.52160000
# success_probability = 0.51960000
# success_probability = 0.51940000
# success_probability = 0.50660000
# success_probability = 0.51930000
# success_probability = 0.52100000
# success_probability = 0.52110000
# success_probability = 0.52090000
# success_probability = 0.52110000
# success_probability = 0.52070000
# success_probability = 0.51910000
# success_probability = 0.51870000
# success_probability = 0.52510000
# success_probability = 0.52650000
# success_probability = 0.52420000
# success_probability = 0.52790000
# success_probability = 0.52340000
# success_probability = 0.52800000
# success_probability = 0.52810000
# success_probability = 0.52810000
# success_probability = 0.52670000
# success_probability = 0.52790000
# success_probability = 0.52880000
# success_probability = 0.52960000
# success_probability = 0.52950000
# success_probability = 0.52940000
# success_probability = 0.52670000
# success_probability = 0.52840000
# success_probability = 0.52880000
# success_probability = 0.52770000
# success_probability = 0.52920000
# success_probability = 0.53000000
# success_probability = 0.52710000
# success_probability = 0.53080000
# success_probability = 0.52650000
# success_probability = 0.52690000
# success_probability = 0.53190000
# success_probability = 0.53040000
# success_probability = 0.53130000
# success_probability = 0.53100000
# success_probability = 0.53350000
# success_probability = 0.53270000
# success_probability = 0.53290000
# success_probability = 0.53200000
# success_probability = 0.52970000
# success_probability = 0.53380000
# success_probability = 0.53430000
# success_probability = 0.53230000
# success_probability = 0.53460000
# success_probability = 0.53170000
# success_probability = 0.53350000
# success_probability = 0.53300000
# success_probability = 0.53450000
# success_probability = 0.53390000
# success_probability = 0.53420000
# success_probability = 0.53250000
# success_probability = 0.53430000
# success_probability = 0.53350000
# success_probability = 0.53310000
# success_probability = 0.53480000
# success_probability = 0.53220000
# success_probability = 0.53290000
# success_probability = 0.53450000
# success_probability = 0.53430000
# success_probability = 0.53090000
# success_probability = 0.53430000
# success_probability = 0.53370000
# success_probability = 0.53340000
# success_probability = 0.53310000
# success_probability = 0.53450000
# success_probability = 0.53320000
# success_probability = 0.53400000
# success_probability = 0.53410000
# success_probability = 0.53410000
# success_probability = 0.53280000
# success_probability = 0.53340000
# success_probability = 0.53270000
# success_probability = 0.53410000
# success_probability = 0.53230000
# success_probability = 0.53360000
# success_probability = 0.53280000
# success_probability = 0.53440000
# success_probability = 0.53200000
# success_probability = 0.53290000
# success_probability = 0.53390000
# success_probability = 0.53400000
# success_probability = 0.53390000
# success_probability = 0.53450000
# success_probability = 0.53420000
# success_probability = 0.53430000
# success_probability = 0.53380000
# success_probability = 0.53440000
# success_probability = 0.53460000
# success_probability = 0.53460000
# success_probability = 0.53430000
# success_probability = 0.53440000
# success_probability = 0.53450000
# success_probability = 0.53450000
# success_probability = 0.53480000
# success_probability = 0.53410000
# success_probability = 0.53470000
# success_probability = 0.53480000
# success_probability = 0.53420000
# success_probability = 0.53470000
# success_probability = 0.53430000
# success_probability = 0.53400000
# success_probability = 0.53450000
# success_probability = 0.53440000
# success_probability = 0.53470000
# success_probability = 0.53460000
# success_probability = 0.53430000
# success_probability = 0.53470000
# success_probability = 0.53460000
# success_probability = 0.53480000
# success_probability = 0.53460000
# success_probability = 0.53460000
# success_probability = 0.53480000
# success_probability = 0.53460000
# success_probability = 0.53480000
# success_probability = 0.53450000
# success_probability = 0.53460000
# success_probability = 0.53450000
# success_probability = 0.53480000
# success_probability = 0.53470000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53470000
# success_probability = 0.53480000
# success_probability = 0.53460000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
# success_probability = 0.53480000
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  313   F = 1.869858E+00    MAXCV = 0.000000E+00
#    X =-8.887809E-01   2.996863E+00   3.080553E+00   1.287324E-02   3.117161E+00
#        3.108582E+00   2.943719E+00  -9.809162E-01   6.433417E-04   1.088544E+00
#        2.274951E+00   8.462865E-01   1.515827E+00   3.712547E-01  -2.606035E-01
#        2.383322E+00   3.126741E-01  -2.335366E-01   1.838492E+00
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.52601000
# Evaluation  2/20 | Value = 0.52183000
# Evaluation  3/20 | Value = 0.52479000
# Evaluation  4/20 | Value = 0.52615000
# Evaluation  5/20 | Value = 0.52520000
# Evaluation  6/20 | Value = 0.52558000
# Evaluation  7/20 | Value = 0.52484000
# Evaluation  8/20 | Value = 0.52170000
# Evaluation  9/20 | Value = 0.52299000
# Evaluation 10/20 | Value = 0.52448000
# Evaluation 11/20 | Value = 0.52524000
# Evaluation 12/20 | Value = 0.52401000
# Evaluation 13/20 | Value = 0.52791000
# Evaluation 14/20 | Value = 0.52311000
# Evaluation 15/20 | Value = 0.52644000
# Evaluation 16/20 | Value = 0.52309000
# Evaluation 17/20 | Value = 0.52508000
# Evaluation 18/20 | Value = 0.52554000
# Evaluation 19/20 | Value = 0.52509000
# Evaluation 20/20 | Value = 0.52418000
#
# ================================================================================
# RUN 1 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 1
# Message              : Optimization terminated successfully.
# Function Evaluations : 313
# Optimization Time    : 27.242744 s
# Final Objective Value: 1.869857890800299
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.53480000
# Evaluated Mean        : 0.52466300
# Evaluated Std         : 0.00150905
# Evaluated Min         : 0.52170000
# Evaluated Max         : 0.52791000
#
# All Evaluated Values:
# [0.52601, 0.52183, 0.52479, 0.52615, 0.5252 , 0.52558, 0.52484, 0.5217 ,
#  0.52299, 0.52448, 0.52524, 0.52401, 0.52791, 0.52311, 0.52644, 0.52309,
#  0.52508, 0.52554, 0.52509, 0.52418]
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566]
#
# Optimal Parameters:
# [-8.8878090467e-01,  2.9968626243e+00,  3.0805528801e+00,
#   1.2873239909e-02,  3.1171612725e+00,  3.1085820772e+00,
#   2.9437193104e+00, -9.8091618528e-01,  6.4334167385e-04,
#   1.0885437839e+00,  2.2749511916e+00,  8.4628645005e-01,
#   1.5158266486e+00,  3.7125474769e-01, -2.6060353195e-01,
#   2.3833217404e+00,  3.1267411709e-01, -2.3353655297e-01,
#   1.8384919834e+00]
# ================================================================================
#
# ================================================================================
# Optimization Run 2/30
# Optimization Seed : 151
# ================================================================================
#
# Initial Parameters:
# [0.4917938425, 0.3601415032, 0.7094100488, 0.6895107167, 0.4723817514,
#  0.4790485592, 0.0068635273, 0.9044398512, 0.4337399476, 0.4736042839,
#  0.034330777 , 0.9496323674, 0.5907905652, 0.4241785512, 0.1868628067,
#  0.9840929216, 0.690221156 , 0.9039467044, 0.0207568308]
#
# Starting COBYLA optimization...
# success_probability = 0.33220000
# success_probability = 0.33420000
# success_probability = 0.33890000
# success_probability = 0.33380000
# success_probability = 0.38430000
# success_probability = 0.34080000
# success_probability = 0.33360000
# success_probability = 0.38690000
# success_probability = 0.38540000
# success_probability = 0.38690000
# success_probability = 0.38530000
# success_probability = 0.37640000
# success_probability = 0.38470000
# success_probability = 0.38510000
# success_probability = 0.38280000
# success_probability = 0.38690000
# success_probability = 0.38600000
# success_probability = 0.38730000
# success_probability = 0.38730000
# success_probability = 0.38630000
# success_probability = 0.43460000
# success_probability = 0.45670000
# success_probability = 0.47190000
# success_probability = 0.48900000
# success_probability = 0.44590000
# success_probability = 0.45550000
# success_probability = 0.48880000
# success_probability = 0.48590000
# success_probability = 0.48810000
# success_probability = 0.49130000
# success_probability = 0.48980000
# success_probability = 0.50860000
# success_probability = 0.50140000
# success_probability = 0.50740000
# success_probability = 0.50360000
# success_probability = 0.50780000
# success_probability = 0.50890000
# success_probability = 0.51110000
# success_probability = 0.51280000
# success_probability = 0.51280000
# success_probability = 0.48080000
# success_probability = 0.50350000
# success_probability = 0.50110000
# success_probability = 0.52390000
# success_probability = 0.49400000
# success_probability = 0.52010000
# success_probability = 0.49990000
# success_probability = 0.52960000
# success_probability = 0.52030000
# success_probability = 0.53290000
# success_probability = 0.53290000
# success_probability = 0.52270000
# success_probability = 0.52800000
# success_probability = 0.53150000
# success_probability = 0.53680000
# success_probability = 0.53080000
# success_probability = 0.53850000
# success_probability = 0.52880000
# success_probability = 0.53490000
# success_probability = 0.53390000
# success_probability = 0.53650000
# success_probability = 0.53080000
# success_probability = 0.53150000
# success_probability = 0.53290000
# success_probability = 0.53710000
# success_probability = 0.52230000
# success_probability = 0.53500000
# success_probability = 0.53520000
# success_probability = 0.52690000
# success_probability = 0.53890000
# success_probability = 0.54220000
# success_probability = 0.53720000
# success_probability = 0.54630000
# success_probability = 0.54370000
# success_probability = 0.54260000
# success_probability = 0.54610000
# success_probability = 0.54790000
# success_probability = 0.54960000
# success_probability = 0.54490000
# success_probability = 0.54970000
# success_probability = 0.54990000
# success_probability = 0.55410000
# success_probability = 0.55410000
# success_probability = 0.55290000
# success_probability = 0.54580000
# success_probability = 0.55530000
# success_probability = 0.55760000
# success_probability = 0.55650000
# success_probability = 0.55280000
# success_probability = 0.55780000
# success_probability = 0.55970000
# success_probability = 0.56400000
# success_probability = 0.57010000
# success_probability = 0.56440000
# success_probability = 0.56640000
# success_probability = 0.57250000
# success_probability = 0.57510000
# success_probability = 0.57210000
# success_probability = 0.57390000
# success_probability = 0.57750000
# success_probability = 0.57890000
# success_probability = 0.58840000
# success_probability = 0.58420000
# success_probability = 0.58890000
# success_probability = 0.59140000
# success_probability = 0.59150000
# success_probability = 0.59490000
# success_probability = 0.59170000
# success_probability = 0.59610000
# success_probability = 0.59740000
# success_probability = 0.59390000
# success_probability = 0.59650000
# success_probability = 0.59340000
# success_probability = 0.60100000
# success_probability = 0.60280000
# success_probability = 0.60730000
# success_probability = 0.59550000
# success_probability = 0.60790000
# success_probability = 0.60950000
# success_probability = 0.61070000
# success_probability = 0.60570000
# success_probability = 0.60840000
# success_probability = 0.60450000
# success_probability = 0.60970000
# success_probability = 0.60240000
# success_probability = 0.60870000
# success_probability = 0.60700000
# success_probability = 0.61030000
# success_probability = 0.60050000
# success_probability = 0.61190000
# success_probability = 0.61090000
# success_probability = 0.61260000
# success_probability = 0.61010000
# success_probability = 0.61060000
# success_probability = 0.60630000
# success_probability = 0.61080000
# success_probability = 0.60910000
# success_probability = 0.61520000
# success_probability = 0.61590000
# success_probability = 0.61450000
# success_probability = 0.61510000
# success_probability = 0.61590000
# success_probability = 0.61250000
# success_probability = 0.61340000
# success_probability = 0.61460000
# success_probability = 0.61570000
# success_probability = 0.61140000
# success_probability = 0.61470000
# success_probability = 0.61210000
# success_probability = 0.61370000
# success_probability = 0.61370000
# success_probability = 0.61420000
# success_probability = 0.61470000
# success_probability = 0.61450000
# success_probability = 0.61280000
# success_probability = 0.61420000
# success_probability = 0.61570000
# success_probability = 0.61550000
# success_probability = 0.61420000
# success_probability = 0.61590000
# success_probability = 0.61510000
# success_probability = 0.61500000
# success_probability = 0.61470000
# success_probability = 0.61500000
# success_probability = 0.61490000
# success_probability = 0.61600000
# success_probability = 0.61470000
# success_probability = 0.61520000
# success_probability = 0.61540000
# success_probability = 0.61570000
# success_probability = 0.61540000
# success_probability = 0.61460000
# success_probability = 0.61550000
# success_probability = 0.61490000
# success_probability = 0.61550000
# success_probability = 0.61510000
# success_probability = 0.61510000
# success_probability = 0.61530000
# success_probability = 0.61610000
# success_probability = 0.61580000
# success_probability = 0.61530000
# success_probability = 0.61560000
# success_probability = 0.61550000
# success_probability = 0.61530000
# success_probability = 0.61530000
# success_probability = 0.61480000
# success_probability = 0.61500000
# success_probability = 0.61570000
# success_probability = 0.61590000
# success_probability = 0.61580000
# success_probability = 0.61530000
# success_probability = 0.61590000
# success_probability = 0.61510000
# success_probability = 0.61590000
# success_probability = 0.61510000
# success_probability = 0.61590000
# success_probability = 0.61550000
# success_probability = 0.61590000
# success_probability = 0.61560000
# success_probability = 0.61590000
# success_probability = 0.61620000
# success_probability = 0.61570000
# success_probability = 0.61600000
# success_probability = 0.61620000
# success_probability = 0.61520000
# success_probability = 0.61620000
# success_probability = 0.61590000
# success_probability = 0.61540000
# success_probability = 0.61580000
# success_probability = 0.61590000
# success_probability = 0.61610000
# success_probability = 0.61600000
# success_probability = 0.61600000
# success_probability = 0.61580000
# success_probability = 0.61630000
# success_probability = 0.61600000
# success_probability = 0.61590000
# success_probability = 0.61620000
# success_probability = 0.61620000
# success_probability = 0.61630000
# success_probability = 0.61620000
# success_probability = 0.61570000
# success_probability = 0.61620000
# success_probability = 0.61620000
# success_probability = 0.61620000
# success_probability = 0.61630000
# success_probability = 0.61600000
# success_probability = 0.61630000
# success_probability = 0.61620000
# success_probability = 0.61630000
# success_probability = 0.61610000
# success_probability = 0.61620000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61620000
# success_probability = 0.61630000
# success_probability = 0.61620000
# success_probability = 0.61620000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61620000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61620000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61620000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
# success_probability = 0.61630000
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  352   F = 1.622586E+00    MAXCV = 0.000000E+00
#    X = 2.565608E+00   1.638143E+00  -1.536320E-01   3.056709E+00  -1.741058E+00
#       -5.695580E-02   2.962484E+00   2.014246E+00  -7.826300E-02   8.550260E-01
#       -1.021220E+00   1.051279E+00   1.197893E+00   1.288901E-01  -1.426109E-01
#        9.867928E-01   1.440585E+00   3.491693E-01   4.238196E-01
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.61187000
# Evaluation  2/20 | Value = 0.61174000
# Evaluation  3/20 | Value = 0.60985000
# Evaluation  4/20 | Value = 0.61043000
# Evaluation  5/20 | Value = 0.61321000
# Evaluation  6/20 | Value = 0.61200000
# Evaluation  7/20 | Value = 0.61043000
# Evaluation  8/20 | Value = 0.61240000
# Evaluation  9/20 | Value = 0.61326000
# Evaluation 10/20 | Value = 0.61243000
# Evaluation 11/20 | Value = 0.60926000
# Evaluation 12/20 | Value = 0.61014000
# Evaluation 13/20 | Value = 0.61309000
# Evaluation 14/20 | Value = 0.60965000
# Evaluation 15/20 | Value = 0.61170000
# Evaluation 16/20 | Value = 0.60993000
# Evaluation 17/20 | Value = 0.60953000
# Evaluation 18/20 | Value = 0.61051000
# Evaluation 19/20 | Value = 0.60991000
# Evaluation 20/20 | Value = 0.61188000
#
# ================================================================================
# RUN 2 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 1
# Message              : Optimization terminated successfully.
# Function Evaluations : 352
# Optimization Time    : 21.667716 s
# Final Objective Value: 1.6225864027259453
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.61630000
# Evaluated Mean        : 0.61116100
# Evaluated Std         : 0.00129829
# Evaluated Min         : 0.60926000
# Evaluated Max         : 0.61326000
#
# All Evaluated Values:
# [0.61187, 0.61174, 0.60985, 0.61043, 0.61321, 0.612  , 0.61043, 0.6124 ,
#  0.61326, 0.61243, 0.60926, 0.61014, 0.61309, 0.60965, 0.6117 , 0.60993,
#  0.60953, 0.61051, 0.60991, 0.61188]
#
# Initial Parameters:
# [0.4917938425, 0.3601415032, 0.7094100488, 0.6895107167, 0.4723817514,
#  0.4790485592, 0.0068635273, 0.9044398512, 0.4337399476, 0.4736042839,
#  0.034330777 , 0.9496323674, 0.5907905652, 0.4241785512, 0.1868628067,
#  0.9840929216, 0.690221156 , 0.9039467044, 0.0207568308]
#
# Optimal Parameters:
# [ 2.5656077836,  1.6381427921, -0.153632015 ,  3.056709365 , -1.7410583049,
#  -0.0569558033,  2.9624835112,  2.014245799 , -0.0782630016,  0.8550259632,
#  -1.0212197941,  1.0512789982,  1.1978932408,  0.1288900646, -0.1426108901,
#   0.9867927805,  1.4405850173,  0.3491692662,  0.4238196225]
# ================================================================================
#
# ================================================================================
# Optimization Run 3/30
# Optimization Seed : 152
# ================================================================================
#
# Initial Parameters:
# [0.2185327016, 0.2605845547, 0.0494520073, 0.5385992113, 0.5420706407,
#  0.7890536718, 0.9123372133, 0.3722628249, 0.3257754726, 0.6556609124,
#  0.8969863307, 0.6516960973, 0.7833870606, 0.8742393722, 0.1922236761,
#  0.610154332 , 0.9457183359, 0.8193944158, 0.2252887854]
#
# Starting COBYLA optimization...
# success_probability = 0.33420000
# success_probability = 0.33350000
# success_probability = 0.33160000
# success_probability = 0.33420000
# success_probability = 0.30290000
# success_probability = 0.37120000
# success_probability = 0.36360000
# success_probability = 0.39140000
# success_probability = 0.38820000
# success_probability = 0.39140000
# success_probability = 0.38970000
# success_probability = 0.38520000
# success_probability = 0.39280000
# success_probability = 0.36990000
# success_probability = 0.39150000
# success_probability = 0.39280000
# success_probability = 0.39470000
# success_probability = 0.39030000
# success_probability = 0.39470000
# success_probability = 0.39440000
# success_probability = 0.41890000
# success_probability = 0.47990000
# success_probability = 0.44930000
# success_probability = 0.43920000
# success_probability = 0.49690000
# success_probability = 0.49520000
# success_probability = 0.44340000
# success_probability = 0.46910000
# success_probability = 0.44640000
# success_probability = 0.51230000
# success_probability = 0.50820000
# success_probability = 0.51370000
# success_probability = 0.51590000
# success_probability = 0.51590000
# success_probability = 0.51640000
# success_probability = 0.51640000
# success_probability = 0.51870000
# success_probability = 0.52010000
# success_probability = 0.53550000
# success_probability = 0.53590000
# success_probability = 0.54750000
# success_probability = 0.50560000
# success_probability = 0.50460000
# success_probability = 0.53560000
# success_probability = 0.53740000
# success_probability = 0.54190000
# success_probability = 0.53440000
# success_probability = 0.53060000
# success_probability = 0.50250000
# success_probability = 0.52520000
# success_probability = 0.53780000
# success_probability = 0.54660000
# success_probability = 0.46070000
# success_probability = 0.55010000
# success_probability = 0.46330000
# success_probability = 0.55010000
# success_probability = 0.54340000
# success_probability = 0.55640000
# success_probability = 0.54990000
# success_probability = 0.55290000
# success_probability = 0.53800000
# success_probability = 0.54780000
# success_probability = 0.56750000
# success_probability = 0.56390000
# success_probability = 0.56750000
# success_probability = 0.56980000
# success_probability = 0.56910000
# success_probability = 0.57420000
# success_probability = 0.56100000
# success_probability = 0.57750000
# success_probability = 0.55110000
# success_probability = 0.59750000
# success_probability = 0.59060000
# success_probability = 0.62480000
# success_probability = 0.60030000
# success_probability = 0.61890000
# success_probability = 0.62590000
# success_probability = 0.62640000
# success_probability = 0.62390000
# success_probability = 0.62600000
# success_probability = 0.62100000
# success_probability = 0.62600000
# success_probability = 0.61210000
# success_probability = 0.62640000
# success_probability = 0.59690000
# success_probability = 0.62980000
# success_probability = 0.61110000
# success_probability = 0.62580000
# success_probability = 0.62140000
# success_probability = 0.62110000
# success_probability = 0.62770000
# success_probability = 0.62360000
# success_probability = 0.61760000
# success_probability = 0.62900000
# success_probability = 0.60650000
# success_probability = 0.62310000
# success_probability = 0.62800000
# success_probability = 0.62500000
# success_probability = 0.62850000
# success_probability = 0.62350000
# success_probability = 0.62530000
# success_probability = 0.63030000
# success_probability = 0.63110000
# success_probability = 0.63070000
# success_probability = 0.62960000
# success_probability = 0.62850000
# success_probability = 0.63480000
# success_probability = 0.63280000
# success_probability = 0.63440000
# success_probability = 0.63570000
# success_probability = 0.63660000
# success_probability = 0.63680000
# success_probability = 0.63730000
# success_probability = 0.64080000
# success_probability = 0.63840000
# success_probability = 0.64010000
# success_probability = 0.63580000
# success_probability = 0.63720000
# success_probability = 0.64080000
# success_probability = 0.64030000
# success_probability = 0.63990000
# success_probability = 0.64070000
# success_probability = 0.63930000
# success_probability = 0.63930000
# success_probability = 0.63900000
# success_probability = 0.63850000
# success_probability = 0.63720000
# success_probability = 0.64060000
# success_probability = 0.63860000
# success_probability = 0.64030000
# success_probability = 0.64110000
# success_probability = 0.64020000
# success_probability = 0.64150000
# success_probability = 0.64180000
# success_probability = 0.64020000
# success_probability = 0.63940000
# success_probability = 0.64160000
# success_probability = 0.64250000
# success_probability = 0.64070000
# success_probability = 0.64170000
# success_probability = 0.64190000
# success_probability = 0.64210000
# success_probability = 0.64260000
# success_probability = 0.64110000
# success_probability = 0.63820000
# success_probability = 0.64210000
# success_probability = 0.64100000
# success_probability = 0.64170000
# success_probability = 0.64250000
# success_probability = 0.64190000
# success_probability = 0.63910000
# success_probability = 0.64210000
# success_probability = 0.64400000
# success_probability = 0.64370000
# success_probability = 0.64350000
# success_probability = 0.64390000
# success_probability = 0.64310000
# success_probability = 0.64230000
# success_probability = 0.64430000
# success_probability = 0.64380000
# success_probability = 0.64390000
# success_probability = 0.64260000
# success_probability = 0.64390000
# success_probability = 0.64270000
# success_probability = 0.64340000
# success_probability = 0.64400000
# success_probability = 0.64360000
# success_probability = 0.64260000
# success_probability = 0.64400000
# success_probability = 0.64280000
# success_probability = 0.64420000
# success_probability = 0.64270000
# success_probability = 0.64310000
# success_probability = 0.64350000
# success_probability = 0.64420000
# success_probability = 0.64400000
# success_probability = 0.64420000
# success_probability = 0.64370000
# success_probability = 0.64390000
# success_probability = 0.64330000
# success_probability = 0.64400000
# success_probability = 0.64410000
# success_probability = 0.64440000
# success_probability = 0.64430000
# success_probability = 0.64340000
# success_probability = 0.64410000
# success_probability = 0.64380000
# success_probability = 0.64400000
# success_probability = 0.64350000
# success_probability = 0.64420000
# success_probability = 0.64380000
# success_probability = 0.64420000
# success_probability = 0.64410000
# success_probability = 0.64450000
# success_probability = 0.64390000
# success_probability = 0.64440000
# success_probability = 0.64450000
# success_probability = 0.64440000
# success_probability = 0.64420000
# success_probability = 0.64420000
# success_probability = 0.64460000
# success_probability = 0.64410000
# success_probability = 0.64430000
# success_probability = 0.64440000
# success_probability = 0.64440000
# success_probability = 0.64440000
# success_probability = 0.64450000
# success_probability = 0.64430000
# success_probability = 0.64410000
# success_probability = 0.64440000
# success_probability = 0.64470000
# success_probability = 0.64430000
# success_probability = 0.64460000
# success_probability = 0.64460000
# success_probability = 0.64460000
# success_probability = 0.64420000
# success_probability = 0.64450000
# success_probability = 0.64460000
# success_probability = 0.64460000
# success_probability = 0.64450000
# success_probability = 0.64470000
# success_probability = 0.64440000
# success_probability = 0.64450000
# success_probability = 0.64460000
# success_probability = 0.64450000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64460000
# success_probability = 0.64450000
# success_probability = 0.64440000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64460000
# success_probability = 0.64460000
# success_probability = 0.64460000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64460000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64460000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64460000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64460000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
# success_probability = 0.64470000
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  347   F = 1.551109E+00    MAXCV = 0.000000E+00
#    X = 8.565478E-01   4.121064E-01  -2.309937E-01   2.641388E+00   3.175720E+00
#       -1.193351E-01   3.108021E+00   1.656836E+00  -1.259079E-01   9.044748E-01
#        6.946142E-01  -3.899142E-01  -1.302902E-01   1.375260E+00   1.204394E-01
#        1.863280E+00   1.069933E+00   3.332907E-01   6.621053E-01
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.63927000
# Evaluation  2/20 | Value = 0.64232000
# Evaluation  3/20 | Value = 0.64020000
# Evaluation  4/20 | Value = 0.64157000
# Evaluation  5/20 | Value = 0.63953000
# Evaluation  6/20 | Value = 0.63628000
# Evaluation  7/20 | Value = 0.63897000
# Evaluation  8/20 | Value = 0.64139000
# Evaluation  9/20 | Value = 0.64180000
# Evaluation 10/20 | Value = 0.64130000
# Evaluation 11/20 | Value = 0.64028000
# Evaluation 12/20 | Value = 0.64055000
# Evaluation 13/20 | Value = 0.63965000
# Evaluation 14/20 | Value = 0.64046000
# Evaluation 15/20 | Value = 0.63819000
# Evaluation 16/20 | Value = 0.63848000
# Evaluation 17/20 | Value = 0.63877000
# Evaluation 18/20 | Value = 0.64115000
# Evaluation 19/20 | Value = 0.63943000
# Evaluation 20/20 | Value = 0.64225000
#
# ================================================================================
# RUN 3 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 1
# Message              : Optimization terminated successfully.
# Function Evaluations : 347
# Optimization Time    : 23.385774 s
# Final Objective Value: 1.5511090429657204
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.64470000
# Evaluated Mean        : 0.64009200
# Evaluated Std         : 0.00149595
# Evaluated Min         : 0.63628000
# Evaluated Max         : 0.64232000
#
# All Evaluated Values:
# [0.63927, 0.64232, 0.6402 , 0.64157, 0.63953, 0.63628, 0.63897, 0.64139,
#  0.6418 , 0.6413 , 0.64028, 0.64055, 0.63965, 0.64046, 0.63819, 0.63848,
#  0.63877, 0.64115, 0.63943, 0.64225]
#
# Initial Parameters:
# [0.2185327016, 0.2605845547, 0.0494520073, 0.5385992113, 0.5420706407,
#  0.7890536718, 0.9123372133, 0.3722628249, 0.3257754726, 0.6556609124,
#  0.8969863307, 0.6516960973, 0.7833870606, 0.8742393722, 0.1922236761,
#  0.610154332 , 0.9457183359, 0.8193944158, 0.2252887854]
#
# Optimal Parameters:
# [ 0.856547767 ,  0.4121064415, -0.230993682 ,  2.6413875602,  3.1757196783,
#  -0.1193351292,  3.108020614 ,  1.6568355584, -0.1259078959,  0.9044748376,
#   0.6946142   , -0.3899142482, -0.1302902173,  1.375260262 ,  0.1204394313,
#   1.8632796226,  1.0699326442,  0.3332907264,  0.6621053354]
# ================================================================================
#
# ================================================================================
# Optimization Run 4/30
# Optimization Seed : 153
# ================================================================================
#
# Initial Parameters:
# [0.9351787748, 0.5440484715, 0.1109812758, 0.8565970763, 0.3821572142,
#  0.9499039298, 0.3855507108, 0.5811580834, 0.920415456 , 0.0082027188,
#  0.9726734037, 0.2335279912, 0.0796605772, 0.8396870049, 0.3792427994,
#  0.8424622263, 0.3825950036, 0.0886091157, 0.8842851536]
#
# Starting COBYLA optimization...
# success_probability = 0.32600000
# success_probability = 0.34570000
# success_probability = 0.35050000
# success_probability = 0.34560000
# success_probability = 0.41170000
# success_probability = 0.35250000
# success_probability = 0.34220000
# success_probability = 0.39850000
# success_probability = 0.41430000
# success_probability = 0.41430000
# success_probability = 0.41100000
# success_probability = 0.43000000
# success_probability = 0.42820000
# success_probability = 0.42560000
# success_probability = 0.43120000
# success_probability = 0.43120000
# success_probability = 0.43390000
# success_probability = 0.43340000
# success_probability = 0.43390000
# success_probability = 0.43320000
# success_probability = 0.49580000
# success_probability = 0.49880000
# success_probability = 0.49420000
# success_probability = 0.44660000
# success_probability = 0.50330000
# success_probability = 0.42000000
# success_probability = 0.50090000
# success_probability = 0.48540000
# success_probability = 0.50220000
# success_probability = 0.50670000
# success_probability = 0.50150000
# success_probability = 0.48950000
# success_probability = 0.49980000
# success_probability = 0.49650000
# success_probability = 0.50330000
# success_probability = 0.50760000
# success_probability = 0.50760000
# success_probability = 0.50350000
# success_probability = 0.50740000
# success_probability = 0.50330000
# success_probability = 0.49950000
# success_probability = 0.49890000
# success_probability = 0.51150000
# success_probability = 0.45500000
# success_probability = 0.50960000
# success_probability = 0.43890000
# success_probability = 0.51460000
# success_probability = 0.50930000
# success_probability = 0.50650000
# success_probability = 0.50320000
# success_probability = 0.50880000
# success_probability = 0.51230000
# success_probability = 0.51300000
# success_probability = 0.51360000
# success_probability = 0.51280000
# success_probability = 0.51100000
# success_probability = 0.51730000
# success_probability = 0.51750000
# success_probability = 0.51010000
# success_probability = 0.51740000
# success_probability = 0.49090000
# success_probability = 0.52310000
# success_probability = 0.51440000
# success_probability = 0.52230000
# success_probability = 0.51760000
# success_probability = 0.52320000
# success_probability = 0.50820000
# success_probability = 0.52340000
# success_probability = 0.51550000
# success_probability = 0.52470000
# success_probability = 0.52930000
# success_probability = 0.52550000
# success_probability = 0.51350000
# success_probability = 0.52270000
# success_probability = 0.52970000
# success_probability = 0.53260000
# success_probability = 0.51930000
# success_probability = 0.52810000
# success_probability = 0.52700000
# success_probability = 0.53090000
# success_probability = 0.52940000
# success_probability = 0.52780000
# success_probability = 0.53120000
# success_probability = 0.52870000
# success_probability = 0.53170000
# success_probability = 0.52580000
# ...
# Evaluated Max     : 0.63797000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 369
# Optimization Time : 23.246086 s
#
# Evaluated Values:
# [0.63289, 0.63611, 0.63574, 0.63729, 0.63457, 0.63323, 0.6345 , 0.63651,
#  0.6378 , 0.63649, 0.63797, 0.63599, 0.63292, 0.63704, 0.63409, 0.63488,
#  0.63477, 0.6345 , 0.63541, 0.63645]
#
# Initial Parameters:
# [0.1024943338, 0.7590156346, 0.5423988438, 0.2717202027, 0.821423202 ,
#  0.5490770792, 0.3929539844, 0.4443998034, 0.8931920339, 0.6002576055,
#  0.2288338735, 0.7955796738, 0.5437449364, 0.3068613245, 0.2044913485,
#  0.8968288433, 0.6989656495, 0.9796459926, 0.9642069447]
#
# Optimal Parameters:
# [ 0.1622535703,  0.9921312831,  2.4833042243,  2.1993751932,  3.1774821158,
#   3.1798634204,  0.0423102742,  2.6165256169,  0.8176036887,  0.3829290295,
#   1.4434003354,  0.9066026486, -0.3648734636,  2.1205531418,  0.2866779977,
#   1.9203375623,  1.8201461452,  1.1455231873,  1.8788927324]
# ----------------------------------------------------------------------------------------------------
#
# Run 23
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 172
# Optimized Value   : 0.53300000
# Evaluated Mean    : 0.52330750
# Evaluated Std     : 0.00178910
# Evaluated Min     : 0.51958000
# Evaluated Max     : 0.52671000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 307
# Optimization Time : 19.392196 s
#
# Evaluated Values:
# [0.52282, 0.52424, 0.52176, 0.5238 , 0.52345, 0.52671, 0.52648, 0.52212,
#  0.52127, 0.52308, 0.52149, 0.52225, 0.51958, 0.52403, 0.52612, 0.52396,
#  0.5251 , 0.52183, 0.52266, 0.5234 ]
#
# Initial Parameters:
# [0.1702293838, 0.9230877777, 0.5877290957, 0.306458957 , 0.4751153524,
#  0.3697992575, 0.4214819696, 0.5618192319, 0.161492304 , 0.8493918532,
#  0.0143050224, 0.3930636181, 0.7191759106, 0.2969669963, 0.7611493365,
#  0.0896341489, 0.847170193 , 0.8567125443, 0.2548602455]
#
# Optimal Parameters:
# [-0.9746269218,  2.3247955069,  0.1728278346,  0.0143925424,  3.0592855247,
#   0.3203655651,  0.0032936931,  0.5131361973,  0.0528870027,  0.8469546378,
#   0.0866607812,  0.251379947 ,  2.8121767426, -0.5191761676, -0.9361853427,
#   0.3955975464,  2.1310168488,  1.1996735773,  0.4275710798]
# ----------------------------------------------------------------------------------------------------
#
# Run 24
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 173
# Optimized Value   : 0.52630000
# Evaluated Mean    : 0.52200100
# Evaluated Std     : 0.00135199
# Evaluated Min     : 0.51896000
# Evaluated Max     : 0.52379000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 281
# Optimization Time : 17.649798 s
#
# Evaluated Values:
# [0.52038, 0.52261, 0.5219 , 0.5234 , 0.52327, 0.52245, 0.52377, 0.52186,
#  0.52219, 0.52235, 0.52183, 0.52126, 0.51896, 0.52215, 0.52357, 0.52065,
#  0.52379, 0.51957, 0.52076, 0.5233 ]
#
# Initial Parameters:
# [0.0683064102, 0.5061877572, 0.2800764934, 0.4917358842, 0.3376481488,
#  0.6337766115, 0.7941202296, 0.2237709719, 0.8893153608, 0.9462072178,
#  0.9270749557, 0.8979372613, 0.8865232604, 0.1112901922, 0.4404611446,
#  0.6571269562, 0.6018173982, 0.0668305069, 0.5031888045]
#
# Optimal Parameters:
# [ 2.0631910827,  0.5209227842,  0.0807034436,  3.1637148597, -0.3420893847,
#  -0.0213483995,  1.3433366692, -0.1365507119,  0.4476299098,  0.4634454447,
#   0.2863445767,  0.6999332119, -0.08489784  ,  0.7450173004, -0.1000464416,
#   0.110821732 ,  0.2551605489, -0.3228701074,  0.4356597145]
# ----------------------------------------------------------------------------------------------------
#
# Run 25
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 174
# Optimized Value   : 0.65100000
# Evaluated Mean    : 0.64459250
# Evaluated Std     : 0.00152698
# Evaluated Min     : 0.64078000
# Evaluated Max     : 0.64728000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 353
# Optimization Time : 22.430684 s
#
# Evaluated Values:
# [0.64354, 0.64685, 0.64482, 0.64422, 0.64417, 0.64078, 0.64353, 0.64588,
#  0.64728, 0.64614, 0.64555, 0.64458, 0.64359, 0.64458, 0.6441 , 0.64441,
#  0.64232, 0.64556, 0.64347, 0.64648]
#
# Initial Parameters:
# [0.920751175 , 0.8324481628, 0.9226421153, 0.4120178702, 0.112899878 ,
#  0.539662511 , 0.9690640438, 0.8958288503, 0.8463732302, 0.6837088366,
#  0.0134777936, 0.9213092468, 0.0585796685, 0.528523907 , 0.4212992395,
#  0.8064657524, 0.2081509804, 0.1492170041, 0.0586840123]
#
# Optimal Parameters:
# [ 2.059769271 ,  0.6733106098,  0.1099078574,  3.2884781559,  2.9188330185,
#  -0.0084592578,  3.0915391308,  1.658906874 ,  0.210746228 ,  0.3976676115,
#  -0.4893625589,  0.4843703866, -0.4303490743,  0.5939069264, -0.4125762665,
#   0.3034673419, -0.5761403594, -0.1262782529,  1.2377854977]
# ----------------------------------------------------------------------------------------------------
#
# Run 26
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 175
# Optimized Value   : 0.64800000
# Evaluated Mean    : 0.64103900
# Evaluated Std     : 0.00179263
# Evaluated Min     : 0.63761000
# Evaluated Max     : 0.64478000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 317
# Optimization Time : 20.241144 s
#
# Evaluated Values:
# [0.64195, 0.64342, 0.63996, 0.64258, 0.63941, 0.63761, 0.6386 , 0.64251,
#  0.64478, 0.64237, 0.64296, 0.64098, 0.64038, 0.64101, 0.63898, 0.6408 ,
#  0.63915, 0.64164, 0.63952, 0.64217]
#
# Initial Parameters:
# [0.5632800098, 0.5263460088, 0.074383608 , 0.0432472297, 0.1116614549,
#  0.3149336925, 0.8051899849, 0.2265811498, 0.2507577735, 0.3247400132,
#  0.7132637608, 0.7744654451, 0.9295185054, 0.8709503245, 0.9380278462,
#  0.6231528096, 0.2419077457, 0.8799737511, 0.1804762542]
#
# Optimal Parameters:
# [ 6.5779567690e-01,  2.0611513839e+00,  5.8277346546e-01,
#  -2.5678970573e+00,  3.1616491280e+00,  2.1551009146e-03,
#   3.1314876116e+00, -2.8448909940e-01,  1.4801343731e-01,
#   1.5039000484e+00,  1.0117714277e+00,  2.9910658604e+00,
#   3.5238601899e-01,  9.0176555670e-01,  8.0888797569e-01,
#  -1.8343384981e-01,  8.3979143977e-01,  5.4519274914e-01,
#  -6.8751103322e-01]
# ----------------------------------------------------------------------------------------------------
#
# Run 27
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 176
# Optimized Value   : 0.53190000
# Evaluated Mean    : 0.52488200
# Evaluated Std     : 0.00138327
# Evaluated Min     : 0.52173000
# Evaluated Max     : 0.52715000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 308
# Optimization Time : 19.875900 s
#
# Evaluated Values:
# [0.52282, 0.52608, 0.52619, 0.52498, 0.52472, 0.52561, 0.52684, 0.52389,
#  0.52381, 0.52338, 0.52487, 0.52538, 0.52173, 0.52405, 0.52527, 0.52354,
#  0.52715, 0.52471, 0.52627, 0.52635]
#
# Initial Parameters:
# [0.908796571 , 0.1480812304, 0.9316217524, 0.8690627692, 0.8218723273,
#  0.3598173853, 0.8198721198, 0.1817033926, 0.2126209616, 0.6959983996,
#  0.3659168242, 0.6449720995, 0.1945739112, 0.1231941489, 0.9608135811,
#  0.9693122607, 0.6994862206, 0.3285305578, 0.5308429614]
#
# Optimal Parameters:
# [ 2.2313283787e+00,  5.4908319105e-02,  1.1153005276e-02,
#   3.1343396132e+00, -4.8411055487e-02, -8.8015059100e-02,
#   2.4471443446e-01, -3.7000750447e-01, -3.0964762249e-01,
#   1.5365984116e-01, -2.1307563114e-01,  6.2480457405e-01,
#   1.3435300526e-01,  3.0422433833e-02,  5.2603605245e-01,
#   3.1829272664e-01,  1.8636069178e-01, -1.1969522912e-01,
#   4.5613862464e-04]
# ----------------------------------------------------------------------------------------------------
#
# Run 28
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 177
# Optimized Value   : 0.53510000
# Evaluated Mean    : 0.52262850
# Evaluated Std     : 0.00167292
# Evaluated Min     : 0.51998000
# Evaluated Max     : 0.52635000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 307
# Optimization Time : 19.494079 s
#
# Evaluated Values:
# [0.52242, 0.52212, 0.52165, 0.52366, 0.52428, 0.52635, 0.52539, 0.52171,
#  0.52128, 0.52288, 0.52   , 0.52081, 0.51998, 0.52295, 0.52517, 0.5221 ,
#  0.52364, 0.52169, 0.52177, 0.52272]
#
# Initial Parameters:
# [0.4859979492, 0.3134855983, 0.5928545916, 0.5388495959, 0.8208222388,
#  0.1681699936, 0.7886708539, 0.9073399324, 0.1513191786, 0.6385598502,
#  0.0204482374, 0.441729694 , 0.1062169866, 0.3316953766, 0.9856944419,
#  0.4606017013, 0.291802071 , 0.5311775661, 0.6869978953]
#
# Optimal Parameters:
# [-0.9328518303, -0.1107946133,  0.0467122665, -0.133788982 ,  3.0862089404,
#  -0.1976991027, -0.1727263153,  0.6017942549,  0.2177381316,  2.1371115605,
#  -0.519052848 ,  0.1577577551,  0.1441026452, -0.3751642197, -0.493898482 ,
#   0.5423419879,  1.0992991133,  0.4891248638,  0.2755875156]
# ----------------------------------------------------------------------------------------------------
#
# Run 29
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 178
# Optimized Value   : 0.52230000
# Evaluated Mean    : 0.52471100
# Evaluated Std     : 0.00111226
# Evaluated Min     : 0.52160000
# Evaluated Max     : 0.52641000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 302
# Optimization Time : 19.396336 s
#
# Evaluated Values:
# [0.52343, 0.52608, 0.52567, 0.52494, 0.52499, 0.52551, 0.52514, 0.52375,
#  0.52427, 0.52323, 0.52494, 0.52476, 0.5216 , 0.52448, 0.52528, 0.52391,
#  0.52641, 0.52442, 0.52529, 0.52612]
#
# Initial Parameters:
# [0.7608275692, 0.0464101376, 0.0032708871, 0.7605003536, 0.2769531808,
#  0.5945503444, 0.8036218146, 0.7402677744, 0.1239034672, 0.2438968692,
#  0.748428843 , 0.9205783868, 0.2357355697, 0.9391032789, 0.4081091944,
#  0.4620759117, 0.7294079941, 0.5779372506, 0.3477807167]
#
# Optimal Parameters:
# [ 2.2052303026, -0.1934533569, -0.0653251137,  3.1601934137,  0.0174887431,
#   0.1117663413, -0.0973111682,  0.4279965676,  0.0737464135,  1.1804957829,
#   0.8030296018,  1.9862136756,  0.3554037286,  0.9158845124,  0.3666289107,
#   1.7261802513,  0.2742566137,  0.3757347929,  0.4361576125]
# ----------------------------------------------------------------------------------------------------
#
# Run 30
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 179
# Optimized Value   : 0.63830000
# Evaluated Mean    : 0.63216200
# Evaluated Std     : 0.00199067
# Evaluated Min     : 0.62851000
# Evaluated Max     : 0.63761000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 356
# Optimization Time : 22.605785 s
#
# Evaluated Values:
# [0.63207, 0.63242, 0.63279, 0.63345, 0.6305 , 0.62851, 0.63058, 0.63345,
#  0.63761, 0.6324 , 0.63464, 0.63271, 0.63195, 0.63287, 0.63102, 0.63016,
#  0.62994, 0.63265, 0.6296 , 0.63392]
#
# Initial Parameters:
# [0.9180695286, 0.9403935557, 0.9611445873, 0.1282735573, 0.7343854482,
#  0.1418537547, 0.3206870255, 0.8783134777, 0.3925501756, 0.9542827898,
#  0.4333144504, 0.0052152104, 0.5921889116, 0.318609756 , 0.9316370681,
#  0.6026668473, 0.0078690534, 0.7991305598, 0.851774691 ]
#
# Optimal Parameters:
# [ 0.1367096995,  1.7273604769,  2.7491164456,  2.1342833571,  3.3169469277,
#   3.1324270735, -0.0172571156,  1.650282879 ,  0.4802030477,  2.1588646161,
#   1.4173324311, -0.2712203066, -1.3082962037,  2.4115367262,  0.6976366042,
#   1.3793320221,  0.4953855889, -0.0255275543,  2.3916942674]
# ----------------------------------------------------------------------------------------------------
#
# SUMMARY
# ====================================================================================================
#
# Original Optimization-Shot Results:
# Maximum Optimized Value : 0.65170000
# Maximum Run             : 5
# Mean Optimized Value    : 0.58185000
# Std Optimized Value     : 0.05648031
#
# High-Shot Evaluation Results:
# Best Evaluated Mean     : 0.64720950
# Best Evaluated Mean Run : 7
# Mean of Evaluated Means : 0.57592913
# Std of Evaluated Means  : 0.05681794
#
# Optimizer Statistics:
# Mean Function Evals     : 325.80
# Std Function Evals      : 24.56
# Successful Runs         : 30/30
# Failed Runs             : 0/30
# Reached MaxIter         : 0/30
#
# Computational Runtime Statistics:
# Total Wall-Clock Time          : 681.035814 s
# Total Optimization Time        : 627.950892 s
# Time per Complete Opt. Run     : 20.931696 s
# Std Optimization Time per Run  : 2.207160 s
#
# ====================================================================================================
# BEST RUN ACCORDING TO ORIGINAL OPTIMIZED VALUE
# ====================================================================================================
# Run             : 5
# Optimized Value : 0.65170000
# Evaluated Mean  : 0.64417000
# Evaluated Std   : 0.00153620
# Evaluated Min   : 0.64022000
# Evaluated Max   : 0.64668000
#
# Evaluated Values:
# [0.64447, 0.64668, 0.64403, 0.64483, 0.64364, 0.64022, 0.64296, 0.64624,
#  0.64665, 0.64463, 0.64457, 0.64385, 0.64405, 0.64506, 0.64274, 0.64307,
#  0.64246, 0.64413, 0.64301, 0.64611]
#
# Initial Parameters:
# [5.8384665481e-01, 6.5946990870e-01, 2.0436564271e-01, 1.9927804559e-01,
#  9.0725040275e-01, 7.9017806975e-02, 5.2590823150e-01, 8.7554377694e-01,
#  8.9650510022e-01, 2.2082502361e-01, 4.0495615065e-01, 9.8067066750e-01,
#  8.5452932017e-01, 4.4663598739e-01, 6.5407987005e-04, 8.5217217448e-01,
#  7.4417491421e-01, 2.3555563654e-01, 9.1502735789e-01]
#
# Optimal Parameters:
# [ 0.4535553219,  0.0717057189,  1.2120398812, -2.8351252566,  3.1306327685,
#   0.0335787306,  3.2896738489,  2.4855418911,  0.9323201762, -0.2462033054,
#   1.3944320906,  1.7124281283,  1.8099670833,  0.3171586607,  0.2805912472,
#   0.5228785917,  1.8189366765,  0.5586997869,  0.4477568397]
#
# ====================================================================================================
# BEST RUN ACCORDING TO HIGH-SHOT EVALUATED MEAN
# ====================================================================================================
# Run             : 7
# Optimized Value : 0.64670000
# Evaluated Mean  : 0.64720950
# Evaluated Std   : 0.00171398
# Evaluated Min   : 0.64281000
# Evaluated Max   : 0.65006000
#
# Evaluated Values:
# [0.6475 , 0.65006, 0.6479 , 0.64809, 0.64604, 0.64281, 0.6453 , 0.64935,
#  0.64948, 0.64774, 0.64843, 0.64777, 0.64677, 0.6478 , 0.64513, 0.64757,
#  0.64537, 0.64702, 0.64551, 0.64855]
#
# Initial Parameters:
# [0.1387201042, 0.0044612871, 0.097293735 , 0.073305076 , 0.255743526 ,
#  0.7555888478, 0.9324239664, 0.7351450903, 0.2183979342, 0.0855301053,
#  0.9549357801, 0.4225010377, 0.1258504647, 0.8729334808, 0.2668126481,
#  0.7949307894, 0.381014832 , 0.4219666286, 0.1535488672]
#
# Optimal Parameters:
# [ 1.6140713918e+00, -6.3346363929e-02,  4.2595188022e-03,
#   3.1700936213e+00,  3.0718850544e+00,  2.4128838963e-03,
#   3.1572660967e+00,  1.2258806443e+00,  5.5339308809e-01,
#   5.4535832967e-01, -4.6109654477e-02,  1.8637711250e+00,
#  -1.4256371561e-01,  1.9235457023e+00,  4.6085214063e-01,
#   1.4615766227e+00,  9.7707965853e-01,  5.1848417748e-01,
#   1.0428978464e+00]
# ====================================================================================================
#
# Report saved to:
# /Users/sungwonyun/Documents/Qiskit/Minimum Error Discrimination/Simulator Seed 150 ReRe /Sym_Nymark_report.txt
