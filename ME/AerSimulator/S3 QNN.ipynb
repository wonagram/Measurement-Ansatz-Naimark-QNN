# %%
# 0,1: 00 for psi_1, 01 for psi_2 ...
# 2,3,4: For states
# 5,6: Ancillary qubits

# %%
from qiskit import QuantumCircuit
from numpy import sqrt, array


def circuit_init():
    qc = QuantumCircuit(7)
    return qc
    
def PREP(qc):

    desired_vector = [
        1 / sqrt(3), 0, 0, 0, 0, 0, 0, 0,
        -1 / (8 * sqrt(3)), -1 / 8, -1 / 8, -sqrt(3) / 8,
        -1 / 8, -sqrt(3) / 8, -sqrt(3) / 8, -3 / 8,
        -1 / (8 * sqrt(3)), 1 / 8, 1 / 8, -sqrt(3) / 8,
        1 / 8, -sqrt(3) / 8, -sqrt(3) / 8, 3 / 8,
        0, 0, 0, 0, 0, 0, 0, 0
    ]
    
    qc.initialize(desired_vector, [4, 3, 2, 1, 0])
    return qc

# %%
def Ansatz(qc, wires, num_layers, params):

    for i in range(num_layers):
        qc.barrier()

        offset = 10 * i
        qc.rx(params[offset + 0], wires[0])
        qc.rz(params[offset + 1], wires[0])

        qc.rx(params[offset + 2], wires[1])
        qc.rz(params[offset + 3], wires[1])

        qc.rx(params[offset + 4], wires[2])
        qc.rz(params[offset + 5], wires[2])

        qc.rx(params[offset + 6], wires[3])
        qc.rz(params[offset + 7], wires[3])

        qc.rx(params[offset + 8], wires[4])
        qc.rz(params[offset + 9], wires[4])

        qc.cx(wires[0], wires[1])
        qc.cx(wires[1], wires[2])
        qc.cx(wires[2], wires[3])
        qc.cx(wires[3], wires[4])

    qc.measure_all()

    return qc

# %%
from numpy.random import rand
num_layers=3
num_params= 10*num_layers
params = list(range(num_params))
num_shots=10000

qc = circuit_init()
qc = PREP(qc)
Ansatz(qc, [2,3,4,5,6] , num_layers, params)

qc.draw(output='mpl', fold = False, style = 'clifford') 
#qc_reversed=qc.reverse_bits()
#qc_reversed.draw(output='mpl',style = 'clifford')

# %%
# q_00: priori probability of psi_00
# p_00: Tr[M_00 psi_00]
# p_suc = q_00 p_00 + q_01 p_01 + q_10 p_10 = sum_i (tot_i/num_shots)(tar_i/tot_i) = 1/num_shots sum_i tar_i

# %%
from qiskit_aer import AerSimulator
from qiskit import transpile
from scipy.optimize import minimize

import numpy as np
import os
import time


# ============================================================
# Simulator
# ============================================================

aersim = AerSimulator()


# ============================================================
# Settings
# ============================================================

num_times = 30
num_shots = 10000

optimizer_name = "COBYLA"
tol_value = 1e-8
maxiter = 1000

BASE_SEED = 150

num_layers = 3

report_filename = (
    "TT_QNN_report.txt"
)


# ============================================================
# High-Shot Evaluation Settings
# ============================================================

evaluation_num_times = 20
evaluation_num_shots = 100000

EVALUATION_BASE_SEED = 10000

evaluation_seeds = np.array(
    [
        EVALUATION_BASE_SEED + i
        for i in range(evaluation_num_times)
    ],
    dtype=int
)


# ============================================================
# Storage
# ============================================================

final_optimized_values = []

initial_params_all_runs = []
optimal_params_all_runs = []

optimization_success_all_runs = []
optimization_status_all_runs = []
optimization_message_all_runs = []
optimization_nfev_all_runs = []
reached_maxiter_all_runs = []

# ------------------------------------------------------------
# Runtime Storage
# ------------------------------------------------------------

optimization_wall_times = []


# ------------------------------------------------------------
# High-Shot Evaluation Storage
# ------------------------------------------------------------

evaluation_values_all_runs = []

evaluation_mean_all_runs = []
evaluation_std_all_runs = []
evaluation_min_all_runs = []
evaluation_max_all_runs = []


# ============================================================
# Objective Function
# ============================================================

def objective_function(
    params,
    run_seed,
    shots=None,
    print_result=True
):

    if shots is None:
        shots = num_shots


    # --------------------------------------------------------
    # Construct circuit
    # --------------------------------------------------------

    qc = circuit_init()

    PREP(qc)

    Ansatz(
        qc,
        wires=[2, 3, 4, 5, 6],
        num_layers=num_layers,
        params=params
    )


    qc_reverse = qc.reverse_bits()


    # --------------------------------------------------------
    # Transpile
    # --------------------------------------------------------

    t_qc = transpile(
        qc_reverse,
        aersim,
        seed_transpiler=run_seed
    )


    # --------------------------------------------------------
    # Run simulator
    # --------------------------------------------------------

    job = aersim.run(
        t_qc,
        shots=shots,
        seed_simulator=run_seed
    )


    result = job.result()

    counts = result.get_counts()


    # --------------------------------------------------------
    # Target counts
    # --------------------------------------------------------

    tar_00 = 0
    tar_01 = 0
    tar_10 = 0


    for outcome, count in counts.items():

        if outcome[0:2] == "00":

            if outcome[5:7] == "00":

                tar_00 += count


        if outcome[0:2] == "01":

            if outcome[5:7] == "01":

                tar_01 += count


        if outcome[0:2] == "10":

            if outcome[5:7] == "10":

                tar_10 += count


    # --------------------------------------------------------
    # Success probability
    # --------------------------------------------------------

    p_suc = (
        tar_00
        + tar_01
        + tar_10
    ) / shots


    if print_result:

        print(
            f"success_probability = "
            f"{p_suc:.8f}"
        )


    # --------------------------------------------------------
    # Avoid division by zero
    # --------------------------------------------------------

    if p_suc == 0:

        return 1e10


    # --------------------------------------------------------
    # COBYLA minimizes.
    #
    # Minimizing 1 / p_suc maximizes p_suc.
    # --------------------------------------------------------

    return 1.0 / p_suc


# ============================================================
# Run Optimization
# ============================================================

# Measures the complete workflow:
# optimization + final evaluations + high-shot evaluations + overhead.
total_wall_start = time.perf_counter()

for run in range(num_times):


    # ========================================================
    # Optimization Seed
    # ========================================================

    run_seed = (
        BASE_SEED + run
    )


    rng = np.random.default_rng(
        run_seed
    )


    print(
        "\n"
        + "=" * 80
    )


    print(
        f"Optimization Run "
        f"{run + 1}/{num_times}"
    )


    print(
        f"Optimization Seed : "
        f"{run_seed}"
    )


    print(
        "=" * 80
    )


    # ========================================================
    # Generate Random Initial Parameters
    # ========================================================

    initial_params = rng.random(
        num_params
    )


    initial_params_all_runs.append(
        initial_params.copy()
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    # ========================================================
    # Run COBYLA Optimization
    # ========================================================

    print(
        "\nStarting COBYLA optimization..."
    )


    optimization_start = time.perf_counter()

    result = minimize(

        fun=lambda params: objective_function(
            params,
            run_seed,
            shots=num_shots,
            print_result=True
        ),

        x0=initial_params,

        method=optimizer_name,

        options={
            "maxiter": maxiter,
            "disp": True,
            "tol": tol_value
        }
    )

    optimization_end = time.perf_counter()

    run_optimization_wall_time = (
        optimization_end
        - optimization_start
    )

    optimization_wall_times.append(
        run_optimization_wall_time
    )

    print(
        f"Optimization Wall-Clock Time : "
        f"{run_optimization_wall_time:.6f} s"
    )


    # ========================================================
    # Optimization Status
    # ========================================================

    optimization_success = bool(
        result.success
    )


    optimization_status = getattr(
        result,
        "status",
        None
    )


    optimization_message = str(
        getattr(
            result,
            "message",
            "No message returned"
        )
    )


    optimization_nfev = getattr(
        result,
        "nfev",
        None
    )


    # ========================================================
    # Detect Maximum Function Evaluations
    # ========================================================

    message_lower = (
        optimization_message.lower()
    )


    reached_maxiter = (

        "maximum number"
        in message_lower

        or "maximum function"
        in message_lower

        or "maxiter"
        in message_lower

        or "maxfun"
        in message_lower

        or "maximum iterations"
        in message_lower

        or "maximum evaluations"
        in message_lower
    )


    if optimization_nfev is not None:

        if optimization_nfev >= maxiter:

            reached_maxiter = True


    # ========================================================
    # Store Optimization Status
    # ========================================================

    optimization_success_all_runs.append(
        optimization_success
    )


    optimization_status_all_runs.append(
        optimization_status
    )


    optimization_message_all_runs.append(
        optimization_message
    )


    optimization_nfev_all_runs.append(
        optimization_nfev
    )


    reached_maxiter_all_runs.append(
        reached_maxiter
    )


    # ========================================================
    # Optimal Parameters
    # ========================================================

    optimal_params = (
        result.x.copy()
    )


    optimal_params_all_runs.append(
        optimal_params.copy()
    )


    # ========================================================
    # Final Optimization-Shot Evaluation
    # ========================================================

    final_objective = objective_function(
        optimal_params,
        run_seed,
        shots=num_shots,
        print_result=False
    )


    if final_objective >= 1e10:

        final_value = 0.0

    else:

        final_value = (
            1.0 / final_objective
        )


    final_optimized_values.append(
        final_value
    )


    # ========================================================
    # High-Shot Evaluation
    # ========================================================

    print(
        "\n"
        + "-" * 80
    )


    print(
        "HIGH-SHOT EVALUATION OF "
        "OPTIMIZED PARAMETERS"
    )


    print(
        "-" * 80
    )


    print(
        f"Optimization Shots     : "
        f"{num_shots}"
    )


    print(
        f"Evaluation Shots       : "
        f"{evaluation_num_shots}"
    )


    print(
        f"Number of Evaluations : "
        f"{evaluation_num_times}"
    )


    print(
        "\nEvaluation Results:"
    )


    evaluation_values = []


    for eval_index, eval_seed in enumerate(
        evaluation_seeds
    ):


        eval_objective = objective_function(
            optimal_params,
            int(eval_seed),
            shots=evaluation_num_shots,
            print_result=False
        )


        if eval_objective >= 1e10:

            eval_value = 0.0

        else:

            eval_value = (
                1.0 / eval_objective
            )


        evaluation_values.append(
            eval_value
        )


        print(
            f"Evaluation "
            f"{eval_index + 1:2d}/"
            f"{evaluation_num_times:2d}"
            f" | Value = "
            f"{eval_value:.8f}"
        )


    # ========================================================
    # Evaluation Statistics
    # ========================================================

    evaluation_values = np.array(
        evaluation_values,
        dtype=float
    )


    evaluation_mean = np.mean(
        evaluation_values
    )


    evaluation_std = np.std(
        evaluation_values
    )


    evaluation_min = np.min(
        evaluation_values
    )


    evaluation_max = np.max(
        evaluation_values
    )


    # ========================================================
    # Store Evaluation Results
    # ========================================================

    evaluation_values_all_runs.append(
        evaluation_values.copy()
    )


    evaluation_mean_all_runs.append(
        evaluation_mean
    )


    evaluation_std_all_runs.append(
        evaluation_std
    )


    evaluation_min_all_runs.append(
        evaluation_min
    )


    evaluation_max_all_runs.append(
        evaluation_max
    )


    # ========================================================
    # Individual Run Report
    # ========================================================

    print(
        "\n"
        + "=" * 80
    )


    print(
        f"RUN {run + 1} RESULT"
    )


    print(
        "=" * 80
    )


    print(
        f"Optimization Success : "
        f"{optimization_success}"
    )


    print(
        f"Reached MaxIter      : "
        f"{reached_maxiter}"
    )


    print(
        f"Status               : "
        f"{optimization_status}"
    )


    print(
        f"Message              : "
        f"{optimization_message}"
    )


    print(
        f"Function Evaluations : "
        f"{optimization_nfev}"
    )


    print(
        f"Optimization Time    : "
        f"{run_optimization_wall_time:.6f} s"
    )


    print(
        f"Final Objective Value: "
        f"{result.fun}"
    )


    print(
        "\n"
        + "-" * 80
    )


    print(
        "OPTIMIZED AND HIGH-SHOT "
        "EVALUATED VALUES"
    )


    print(
        "-" * 80
    )


    print(
        f"Final Optimized Value : "
        f"{final_value:.8f}"
    )


    print(
        f"Evaluated Mean        : "
        f"{evaluation_mean:.8f}"
    )


    print(
        f"Evaluated Std         : "
        f"{evaluation_std:.8f}"
    )


    print(
        f"Evaluated Min         : "
        f"{evaluation_min:.8f}"
    )


    print(
        f"Evaluated Max         : "
        f"{evaluation_max:.8f}"
    )


    print(
        "\nAll Evaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values,
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "=" * 80
    )


# ============================================================
# Runtime Statistics
# ============================================================

total_wall_end = time.perf_counter()

total_wall_time = (
    total_wall_end
    - total_wall_start
)

optimization_wall_times = np.array(
    optimization_wall_times,
    dtype=float
)

total_optimization_wall_time = np.sum(
    optimization_wall_times
)

mean_optimization_wall_time = np.mean(
    optimization_wall_times
)

std_optimization_wall_time = np.std(
    optimization_wall_times
)


# ============================================================
# Convert Results to NumPy Arrays
# ============================================================

final_optimized_values = np.array(
    final_optimized_values,
    dtype=float
)


initial_params_all_runs = np.array(
    initial_params_all_runs
)


optimal_params_all_runs = np.array(
    optimal_params_all_runs
)


evaluation_values_all_runs = np.array(
    evaluation_values_all_runs,
    dtype=float
)


evaluation_mean_all_runs = np.array(
    evaluation_mean_all_runs,
    dtype=float
)


evaluation_std_all_runs = np.array(
    evaluation_std_all_runs,
    dtype=float
)


evaluation_min_all_runs = np.array(
    evaluation_min_all_runs,
    dtype=float
)


evaluation_max_all_runs = np.array(
    evaluation_max_all_runs,
    dtype=float
)


# ============================================================
# Original Optimization Statistics
# ============================================================

maximum_value = np.max(
    final_optimized_values
)


mean_value = np.mean(
    final_optimized_values
)


std_value = np.std(
    final_optimized_values
)


maximum_run_index = np.argmax(
    final_optimized_values
)


maximum_run = (
    maximum_run_index + 1
)


# ============================================================
# High-Shot Evaluation Statistics
# ============================================================

maximum_evaluated_mean = np.max(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run_index = np.argmax(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run = (
    maximum_evaluated_mean_run_index
    + 1
)


mean_of_evaluated_means = np.mean(
    evaluation_mean_all_runs
)


std_of_evaluated_means = np.std(
    evaluation_mean_all_runs
)


# ============================================================
# Function Evaluation Statistics
# ============================================================

nfev_values = np.array(
    [
        nfev
        for nfev
        in optimization_nfev_all_runs
        if nfev is not None
    ],
    dtype=float
)


if len(nfev_values) > 0:

    mean_nfev = np.mean(
        nfev_values
    )


    std_nfev = np.std(
        nfev_values
    )

else:

    mean_nfev = np.nan
    std_nfev = np.nan


# ============================================================
# Optimization Success Statistics
# ============================================================

num_successful_runs = sum(
    optimization_success_all_runs
)


num_failed_runs = (
    num_times
    - num_successful_runs
)


num_reached_maxiter = sum(
    reached_maxiter_all_runs
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

best_initial_params = (
    initial_params_all_runs[
        maximum_run_index
    ]
)


best_optimal_params = (
    optimal_params_all_runs[
        maximum_run_index
    ]
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

best_evaluated_initial_params = (
    initial_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_optimal_params = (
    optimal_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_values = (
    evaluation_values_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


# ============================================================
# Print Final Report
# ============================================================

print("\n")


print(
    "=" * 100
)


print(
    "FINAL OPTIMIZATION AND "
    "HIGH-SHOT EVALUATION REPORT"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Settings
# ------------------------------------------------------------

print(
    f"Optimizer               : "
    f"{optimizer_name}"
)


print(
    f"Tolerance               : "
    f"{tol_value}"
)


print(
    f"Max Iteration           : "
    f"{maxiter}"
)


print(
    f"Number of Runs          : "
    f"{num_times}"
)


print(
    f"Number of Layers        : "
    f"{num_layers}"
)


print(
    f"Optimization Shots      : "
    f"{num_shots}"
)


print(
    f"Optimization Base Seed  : "
    f"{BASE_SEED}"
)


print(
    f"Evaluation Shots        : "
    f"{evaluation_num_shots}"
)


print(
    f"Evaluations Per Run     : "
    f"{evaluation_num_times}"
)


print(
    f"Evaluation Base Seed    : "
    f"{EVALUATION_BASE_SEED}"
)


# Evaluation seeds are printed only once.
print(
    "Evaluation Seeds        : "
    + np.array2string(
        evaluation_seeds,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Results for Every Run
# ============================================================

for i in range(num_times):


    print(
        f"\nRun {i + 1:2d}"
    )


    print(
        "-" * 100
    )


    print(
        f"Optimization Seed : "
        f"{BASE_SEED + i}"
    )


    print(
        f"Optimized Value   : "
        f"{final_optimized_values[i]:.8f}"
    )


    print(
        f"Evaluated Mean    : "
        f"{evaluation_mean_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Std     : "
        f"{evaluation_std_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Min     : "
        f"{evaluation_min_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Max     : "
        f"{evaluation_max_all_runs[i]:.8f}"
    )


    print(
        f"Success           : "
        f"{optimization_success_all_runs[i]}"
    )


    print(
        f"Reached MaxIter   : "
        f"{reached_maxiter_all_runs[i]}"
    )


    print(
        f"Status            : "
        f"{optimization_status_all_runs[i]}"
    )


    print(
        f"Message           : "
        f"{optimization_message_all_runs[i]}"
    )


    print(
        f"Function Evals    : "
        f"{optimization_nfev_all_runs[i]}"
    )


    print(
        f"Optimization Time : "
        f"{optimization_wall_times[i]:.6f} s"
    )


    print(
        "\nEvaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values_all_runs[i],
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "-" * 100
    )


# ============================================================
# Summary
# ============================================================

print(
    "\nSUMMARY"
)


print(
    "=" * 100
)


print(
    "\nOriginal Optimization-Shot Results:"
)


print(
    f"Maximum Optimized Value : "
    f"{maximum_value:.8f}"
)


print(
    f"Maximum Run             : "
    f"{maximum_run}"
)


print(
    f"Mean Optimized Value    : "
    f"{mean_value:.8f}"
)


print(
    f"Std Optimized Value     : "
    f"{std_value:.8f}"
)


print(
    "\nHigh-Shot Evaluation Results:"
)


print(
    f"Best Evaluated Mean     : "
    f"{maximum_evaluated_mean:.8f}"
)


print(
    f"Best Evaluated Mean Run : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Mean of Evaluated Means : "
    f"{mean_of_evaluated_means:.8f}"
)


print(
    f"Std of Evaluated Means  : "
    f"{std_of_evaluated_means:.8f}"
)


print(
    "\nOptimizer Statistics:"
)


print(
    f"Mean Function Evals     : "
    f"{mean_nfev:.2f}"
)


print(
    f"Std Function Evals      : "
    f"{std_nfev:.2f}"
)


print(
    f"Successful Runs         : "
    f"{num_successful_runs}/"
    f"{num_times}"
)


print(
    f"Failed Runs             : "
    f"{num_failed_runs}/"
    f"{num_times}"
)


print(
    f"Reached MaxIter         : "
    f"{num_reached_maxiter}/"
    f"{num_times}"
)


# ------------------------------------------------------------
# Computational Runtime Statistics
# ------------------------------------------------------------

print(
    "\nComputational Runtime Statistics:"
)

print(
    f"Total Wall-Clock Time          : "
    f"{total_wall_time:.6f} s"
)

print(
    f"Total Optimization Time        : "
    f"{total_optimization_wall_time:.6f} s"
)

print(
    f"Time per Complete Opt. Run     : "
    f"{mean_optimization_wall_time:.6f} s"
)

print(
    f"Std Optimization Time per Run  : "
    f"{std_optimization_wall_time:.6f} s"
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "ORIGINAL OPTIMIZED VALUE"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        evaluation_values_all_runs[
            maximum_run_index
        ],
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_optimal_params,
        precision=10,
        separator=", "
    )
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "HIGH-SHOT EVALUATED MEAN"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        best_evaluated_values,
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_evaluated_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_evaluated_optimal_params,
        precision=10,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Save Report to TXT
# ============================================================

with open(
    report_filename,
    "w"
) as f:


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "FINAL OPTIMIZATION AND "
        "HIGH-SHOT EVALUATION REPORT\n"
    )


    f.write(
        "=" * 100
        + "\n\n"
    )


    # ========================================================
    # Settings
    # ========================================================

    f.write(
        f"Optimizer               : "
        f"{optimizer_name}\n"
    )


    f.write(
        f"Tolerance               : "
        f"{tol_value}\n"
    )


    f.write(
        f"Max Iteration           : "
        f"{maxiter}\n"
    )


    f.write(
        f"Number of Runs          : "
        f"{num_times}\n"
    )


    f.write(
        f"Number of Layers        : "
        f"{num_layers}\n"
    )


    f.write(
        f"Optimization Shots      : "
        f"{num_shots}\n"
    )


    f.write(
        f"Optimization Base Seed  : "
        f"{BASE_SEED}\n"
    )


    f.write(
        f"Evaluation Shots        : "
        f"{evaluation_num_shots}\n"
    )


    f.write(
        f"Evaluations Per Run     : "
        f"{evaluation_num_times}\n"
    )


    f.write(
        f"Evaluation Base Seed    : "
        f"{EVALUATION_BASE_SEED}\n"
    )


    # Evaluation seeds are saved only once.
    f.write(
        "Evaluation Seeds        : "
    )


    f.write(
        np.array2string(
            evaluation_seeds,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    # ========================================================
    # Results for Every Run
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "RESULTS FOR EACH RUN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    for i in range(num_times):


        f.write(
            f"\nRun {i + 1:2d}\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


        f.write(
            f"Optimization Seed : "
            f"{BASE_SEED + i}\n"
        )


        f.write(
            f"Optimized Value   : "
            f"{final_optimized_values[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Mean    : "
            f"{evaluation_mean_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Std     : "
            f"{evaluation_std_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Min     : "
            f"{evaluation_min_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Max     : "
            f"{evaluation_max_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Success           : "
            f"{optimization_success_all_runs[i]}\n"
        )


        f.write(
            f"Reached MaxIter   : "
            f"{reached_maxiter_all_runs[i]}\n"
        )


        f.write(
            f"Status            : "
            f"{optimization_status_all_runs[i]}\n"
        )


        f.write(
            f"Message           : "
            f"{optimization_message_all_runs[i]}\n"
        )


        f.write(
            f"Function Evals    : "
            f"{optimization_nfev_all_runs[i]}\n"
        )


        f.write(
            f"Optimization Time : "
            f"{optimization_wall_times[i]:.6f} s\n"
        )


        f.write(
            "\nEvaluated Values:\n"
        )


        f.write(
            np.array2string(
                evaluation_values_all_runs[i],
                precision=8,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nInitial Parameters:\n"
        )


        f.write(
            np.array2string(
                initial_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nOptimal Parameters:\n"
        )


        f.write(
            np.array2string(
                optimal_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


    # ========================================================
    # Summary
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "SUMMARY\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "\nOriginal Optimization-Shot Results:\n"
    )


    f.write(
        f"Maximum Optimized Value : "
        f"{maximum_value:.8f}\n"
    )


    f.write(
        f"Maximum Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Mean Optimized Value    : "
        f"{mean_value:.8f}\n"
    )


    f.write(
        f"Std Optimized Value     : "
        f"{std_value:.8f}\n"
    )


    f.write(
        "\nHigh-Shot Evaluation Results:\n"
    )


    f.write(
        f"Best Evaluated Mean     : "
        f"{maximum_evaluated_mean:.8f}\n"
    )


    f.write(
        f"Best Evaluated Mean Run : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Mean of Evaluated Means : "
        f"{mean_of_evaluated_means:.8f}\n"
    )


    f.write(
        f"Std of Evaluated Means  : "
        f"{std_of_evaluated_means:.8f}\n"
    )


    f.write(
        "\nOptimizer Statistics:\n"
    )


    f.write(
        f"Mean Function Evals     : "
        f"{mean_nfev:.2f}\n"
    )


    f.write(
        f"Std Function Evals      : "
        f"{std_nfev:.2f}\n"
    )


    f.write(
        f"Successful Runs         : "
        f"{num_successful_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Failed Runs             : "
        f"{num_failed_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Reached MaxIter         : "
        f"{num_reached_maxiter}/"
        f"{num_times}\n"
    )


    # --------------------------------------------------------
    # Computational Runtime Statistics
    # --------------------------------------------------------

    f.write(
        "\nComputational Runtime Statistics:\n"
    )

    f.write(
        f"Total Wall-Clock Time          : "
        f"{total_wall_time:.6f} s\n"
    )

    f.write(
        f"Total Optimization Time        : "
        f"{total_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Time per Complete Opt. Run     : "
        f"{mean_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Std Optimization Time per Run  : "
        f"{std_optimization_wall_time:.6f} s\n"
    )


    # ========================================================
    # Best Original Optimization Run
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "ORIGINAL OPTIMIZED VALUE\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            evaluation_values_all_runs[
                maximum_run_index
            ],
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    # ========================================================
    # Best High-Shot Evaluated Run
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "HIGH-SHOT EVALUATED MEAN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_values,
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


# ============================================================
# Report Location
# ============================================================

print(
    "\nReport saved to:"
)


print(
    os.path.abspath(
        report_filename
    )
)
# Out:
# ================================================================================
# Optimization Run 1/30
# Optimization Seed : 150
# ================================================================================
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566, 0.6883896757,
#  0.5848087428, 0.2739643248, 0.8377858251, 0.3022293541, 0.1728462164,
#  0.8017433668, 0.3441099205, 0.4375847094, 0.152681156 , 0.2761357842]
#
# Starting COBYLA optimization...
# success_probability = 0.28710000
# success_probability = 0.29340000
# success_probability = 0.30570000
# success_probability = 0.31520000
# success_probability = 0.29520000
# success_probability = 0.28840000
# success_probability = 0.28780000
# success_probability = 0.31650000
# success_probability = 0.27570000
# success_probability = 0.30630000
# success_probability = 0.31020000
# success_probability = 0.30360000
# success_probability = 0.30220000
# success_probability = 0.31250000
# success_probability = 0.34550000
# success_probability = 0.30030000
# success_probability = 0.31080000
# success_probability = 0.28760000
# success_probability = 0.34590000
# success_probability = 0.32840000
# success_probability = 0.33300000
# success_probability = 0.28740000
# success_probability = 0.34590000
# success_probability = 0.36010000
# success_probability = 0.36010000
# success_probability = 0.28750000
# success_probability = 0.36010000
# success_probability = 0.32080000
# success_probability = 0.36010000
# success_probability = 0.35350000
# success_probability = 0.36010000
# success_probability = 0.33500000
# success_probability = 0.36020000
# success_probability = 0.32770000
# success_probability = 0.35400000
# success_probability = 0.34620000
# success_probability = 0.34140000
# success_probability = 0.35500000
# success_probability = 0.35290000
# success_probability = 0.36870000
# success_probability = 0.37330000
# success_probability = 0.36730000
# success_probability = 0.37800000
# success_probability = 0.39000000
# success_probability = 0.40520000
# success_probability = 0.42760000
# success_probability = 0.42180000
# success_probability = 0.41460000
# success_probability = 0.41880000
# success_probability = 0.42730000
# success_probability = 0.41110000
# success_probability = 0.44060000
# success_probability = 0.45830000
# success_probability = 0.46130000
# success_probability = 0.46920000
# success_probability = 0.46920000
# success_probability = 0.45790000
# success_probability = 0.46720000
# success_probability = 0.47430000
# success_probability = 0.47580000
# success_probability = 0.47950000
# success_probability = 0.47770000
# success_probability = 0.49150000
# success_probability = 0.49300000
# success_probability = 0.44290000
# success_probability = 0.49960000
# success_probability = 0.51800000
# success_probability = 0.52680000
# success_probability = 0.56890000
# success_probability = 0.58010000
# success_probability = 0.57360000
# success_probability = 0.59870000
# success_probability = 0.58220000
# success_probability = 0.58840000
# success_probability = 0.58630000
# success_probability = 0.59160000
# success_probability = 0.59560000
# success_probability = 0.61750000
# success_probability = 0.59990000
# success_probability = 0.59570000
# success_probability = 0.59700000
# success_probability = 0.61990000
# success_probability = 0.61340000
# success_probability = 0.62180000
# success_probability = 0.61010000
# success_probability = 0.61240000
# success_probability = 0.59600000
# success_probability = 0.62180000
# success_probability = 0.61300000
# success_probability = 0.60380000
# success_probability = 0.61130000
# success_probability = 0.63430000
# success_probability = 0.65180000
# success_probability = 0.65580000
# success_probability = 0.66350000
# success_probability = 0.66830000
# success_probability = 0.66810000
# success_probability = 0.67180000
# success_probability = 0.64880000
# success_probability = 0.66780000
# success_probability = 0.64090000
# success_probability = 0.67800000
# success_probability = 0.65160000
# success_probability = 0.68140000
# success_probability = 0.66090000
# success_probability = 0.67290000
# success_probability = 0.69790000
# success_probability = 0.69010000
# success_probability = 0.66770000
# success_probability = 0.69530000
# success_probability = 0.66690000
# success_probability = 0.69900000
# success_probability = 0.65420000
# success_probability = 0.68990000
# success_probability = 0.69620000
# success_probability = 0.68370000
# success_probability = 0.65670000
# success_probability = 0.70360000
# success_probability = 0.70220000
# success_probability = 0.70130000
# success_probability = 0.63320000
# success_probability = 0.70360000
# success_probability = 0.67630000
# success_probability = 0.69450000
# success_probability = 0.67840000
# success_probability = 0.69540000
# success_probability = 0.67750000
# success_probability = 0.70150000
# success_probability = 0.69610000
# success_probability = 0.70150000
# success_probability = 0.69560000
# success_probability = 0.69980000
# success_probability = 0.70370000
# success_probability = 0.70290000
# success_probability = 0.70170000
# success_probability = 0.70630000
# success_probability = 0.69770000
# success_probability = 0.71150000
# success_probability = 0.71120000
# success_probability = 0.70650000
# success_probability = 0.70910000
# success_probability = 0.71100000
# success_probability = 0.70760000
# success_probability = 0.70880000
# success_probability = 0.70900000
# success_probability = 0.70060000
# success_probability = 0.70730000
# success_probability = 0.71340000
# success_probability = 0.71000000
# success_probability = 0.71020000
# success_probability = 0.70700000
# success_probability = 0.70230000
# success_probability = 0.71020000
# success_probability = 0.69430000
# success_probability = 0.70420000
# success_probability = 0.70760000
# success_probability = 0.71320000
# success_probability = 0.71020000
# success_probability = 0.70640000
# success_probability = 0.71070000
# success_probability = 0.71340000
# success_probability = 0.70320000
# success_probability = 0.70200000
# success_probability = 0.71810000
# success_probability = 0.71550000
# success_probability = 0.71940000
# success_probability = 0.71750000
# success_probability = 0.71960000
# success_probability = 0.71700000
# success_probability = 0.71660000
# success_probability = 0.71720000
# success_probability = 0.71690000
# success_probability = 0.71800000
# success_probability = 0.71410000
# success_probability = 0.72080000
# success_probability = 0.71940000
# success_probability = 0.72190000
# success_probability = 0.72200000
# success_probability = 0.71920000
# success_probability = 0.72040000
# success_probability = 0.72010000
# success_probability = 0.72130000
# success_probability = 0.71890000
# success_probability = 0.72290000
# success_probability = 0.72510000
# success_probability = 0.72610000
# success_probability = 0.72270000
# success_probability = 0.72490000
# success_probability = 0.72770000
# success_probability = 0.72600000
# success_probability = 0.71800000
# success_probability = 0.72770000
# success_probability = 0.72830000
# success_probability = 0.72830000
# success_probability = 0.72390000
# success_probability = 0.72790000
# success_probability = 0.72590000
# success_probability = 0.72850000
# success_probability = 0.72630000
# success_probability = 0.72790000
# success_probability = 0.71940000
# success_probability = 0.72800000
# success_probability = 0.72040000
# success_probability = 0.72800000
# success_probability = 0.72430000
# success_probability = 0.72520000
# success_probability = 0.72250000
# success_probability = 0.72390000
# success_probability = 0.72530000
# success_probability = 0.72590000
# success_probability = 0.72520000
# success_probability = 0.72890000
# success_probability = 0.72380000
# success_probability = 0.72640000
# success_probability = 0.72540000
# success_probability = 0.72620000
# success_probability = 0.72660000
# success_probability = 0.72610000
# success_probability = 0.73010000
# success_probability = 0.72520000
# success_probability = 0.72820000
# success_probability = 0.72780000
# success_probability = 0.73020000
# success_probability = 0.72740000
# success_probability = 0.73130000
# success_probability = 0.72830000
# success_probability = 0.72990000
# success_probability = 0.72970000
# success_probability = 0.73070000
# success_probability = 0.73030000
# success_probability = 0.73030000
# success_probability = 0.73050000
# success_probability = 0.73050000
# success_probability = 0.72950000
# success_probability = 0.72950000
# success_probability = 0.73030000
# success_probability = 0.73090000
# success_probability = 0.73090000
# success_probability = 0.73010000
# success_probability = 0.72700000
# success_probability = 0.73090000
# success_probability = 0.72680000
# success_probability = 0.72990000
# success_probability = 0.72940000
# success_probability = 0.73010000
# success_probability = 0.72920000
# success_probability = 0.73040000
# success_probability = 0.73230000
# success_probability = 0.73180000
# success_probability = 0.73150000
# success_probability = 0.73150000
# success_probability = 0.72870000
# success_probability = 0.73120000
# success_probability = 0.72900000
# success_probability = 0.73090000
# success_probability = 0.72980000
# success_probability = 0.73050000
# success_probability = 0.73230000
# success_probability = 0.73180000
# success_probability = 0.73230000
# success_probability = 0.73110000
# success_probability = 0.73150000
# success_probability = 0.73140000
# success_probability = 0.73200000
# success_probability = 0.73160000
# success_probability = 0.73120000
# success_probability = 0.73140000
# success_probability = 0.73130000
# success_probability = 0.73040000
# success_probability = 0.73170000
# success_probability = 0.73230000
# success_probability = 0.73230000
# success_probability = 0.73020000
# success_probability = 0.73170000
# success_probability = 0.73180000
# success_probability = 0.73170000
# success_probability = 0.73150000
# success_probability = 0.73200000
# success_probability = 0.73120000
# success_probability = 0.73240000
# success_probability = 0.73130000
# success_probability = 0.73240000
# success_probability = 0.73180000
# success_probability = 0.73190000
# success_probability = 0.73210000
# success_probability = 0.73150000
# success_probability = 0.73200000
# success_probability = 0.73280000
# success_probability = 0.73260000
# success_probability = 0.73150000
# success_probability = 0.73180000
# success_probability = 0.73220000
# success_probability = 0.73260000
# success_probability = 0.73220000
# success_probability = 0.73170000
# success_probability = 0.73280000
# success_probability = 0.73320000
# success_probability = 0.73280000
# success_probability = 0.73280000
# success_probability = 0.73240000
# success_probability = 0.73300000
# success_probability = 0.73290000
# success_probability = 0.73230000
# success_probability = 0.73270000
# success_probability = 0.73250000
# success_probability = 0.73270000
# success_probability = 0.73250000
# success_probability = 0.73360000
# success_probability = 0.73190000
# success_probability = 0.73300000
# success_probability = 0.73220000
# success_probability = 0.73270000
# success_probability = 0.73190000
# success_probability = 0.73180000
# success_probability = 0.73170000
# success_probability = 0.73300000
# success_probability = 0.73240000
# success_probability = 0.73290000
# success_probability = 0.73230000
# success_probability = 0.73330000
# success_probability = 0.73330000
# success_probability = 0.73320000
# success_probability = 0.73270000
# success_probability = 0.73290000
# success_probability = 0.73210000
# success_probability = 0.73270000
# success_probability = 0.73310000
# success_probability = 0.73250000
# success_probability = 0.73330000
# success_probability = 0.73240000
# success_probability = 0.73310000
# success_probability = 0.73220000
# success_probability = 0.73320000
# success_probability = 0.73300000
# success_probability = 0.73380000
# success_probability = 0.73320000
# success_probability = 0.73350000
# success_probability = 0.73340000
# success_probability = 0.73320000
# success_probability = 0.73370000
# success_probability = 0.73310000
# success_probability = 0.73370000
# success_probability = 0.73340000
# success_probability = 0.73350000
# success_probability = 0.73380000
# success_probability = 0.73320000
# success_probability = 0.73350000
# success_probability = 0.73370000
# success_probability = 0.73320000
# success_probability = 0.73380000
# success_probability = 0.73360000
# success_probability = 0.73370000
# success_probability = 0.73350000
# success_probability = 0.73330000
# success_probability = 0.73390000
# success_probability = 0.73350000
# success_probability = 0.73330000
# success_probability = 0.73360000
# success_probability = 0.73320000
# success_probability = 0.73360000
# success_probability = 0.73360000
# success_probability = 0.73380000
# success_probability = 0.73300000
# success_probability = 0.73340000
# success_probability = 0.73330000
# success_probability = 0.73350000
# success_probability = 0.73360000
# success_probability = 0.73330000
# success_probability = 0.73380000
# success_probability = 0.73400000
# success_probability = 0.73380000
# success_probability = 0.73350000
# success_probability = 0.73370000
# success_probability = 0.73370000
# success_probability = 0.73370000
# success_probability = 0.73350000
# success_probability = 0.73360000
# success_probability = 0.73360000
# success_probability = 0.73390000
# success_probability = 0.73330000
# success_probability = 0.73380000
# success_probability = 0.73330000
# success_probability = 0.73380000
# success_probability = 0.73330000
# success_probability = 0.73400000
# success_probability = 0.73340000
# success_probability = 0.73390000
# success_probability = 0.73360000
# success_probability = 0.73380000
# success_probability = 0.73360000
# success_probability = 0.73400000
# success_probability = 0.73370000
# success_probability = 0.73360000
# success_probability = 0.73380000
# success_probability = 0.73390000
# success_probability = 0.73390000
# success_probability = 0.73360000
# success_probability = 0.73400000
# success_probability = 0.73390000
# success_probability = 0.73390000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73390000
# success_probability = 0.73400000
# success_probability = 0.73390000
# success_probability = 0.73390000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73380000
# success_probability = 0.73390000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73390000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73390000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73390000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73390000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# success_probability = 0.73400000
# Optimization Wall-Clock Time : 35.076057 s
#
#    Normal return from subroutine COBYLA
#
#    NFVALS =  573   F = 1.362398E+00    MAXCV = 0.000000E+00
#    X = 3.179531E+00   1.507271E+00   2.057520E+00   3.884467E-01   1.048677E+00
#        1.877111E+00   1.506211E+00   1.214596E-01   1.398132E+00   6.771829E-02
#        1.170040E+00   8.238913E-01   1.758932E+00   2.682324E+00   1.831620E-02
#        5.872067E-01  -7.919842E-02   2.285681E+00   1.467165E+00   5.851664E-01
#       -6.328836E-02   3.404170E-01   1.463439E+00   5.421422E-01   3.620944E-02
#        6.448059E-01  -9.207583E-02   8.056526E-01   2.292142E-01   7.399869E-01
#
# --------------------------------------------------------------------------------
# HIGH-SHOT EVALUATION OF OPTIMIZED PARAMETERS
# --------------------------------------------------------------------------------
# Optimization Shots     : 10000
# Evaluation Shots       : 100000
# Number of Evaluations : 20
#
# Evaluation Results:
# Evaluation  1/20 | Value = 0.71624000
# Evaluation  2/20 | Value = 0.71943000
# Evaluation  3/20 | Value = 0.71634000
# Evaluation  4/20 | Value = 0.71758000
# Evaluation  5/20 | Value = 0.71686000
# Evaluation  6/20 | Value = 0.71645000
# Evaluation  7/20 | Value = 0.71750000
# Evaluation  8/20 | Value = 0.71894000
# Evaluation  9/20 | Value = 0.71958000
# Evaluation 10/20 | Value = 0.71844000
# Evaluation 11/20 | Value = 0.71952000
# Evaluation 12/20 | Value = 0.71674000
# Evaluation 13/20 | Value = 0.71409000
# Evaluation 14/20 | Value = 0.71986000
# Evaluation 15/20 | Value = 0.71730000
# Evaluation 16/20 | Value = 0.71878000
# Evaluation 17/20 | Value = 0.71894000
# Evaluation 18/20 | Value = 0.71592000
# Evaluation 19/20 | Value = 0.71808000
# Evaluation 20/20 | Value = 0.72071000
#
# ================================================================================
# RUN 1 RESULT
# ================================================================================
# Optimization Success : True
# Reached MaxIter      : False
# Status               : 1
# Message              : Optimization terminated successfully.
# Function Evaluations : 573
# Optimization Time    : 35.076057 s
# Final Objective Value: 1.3623978201634879
#
# --------------------------------------------------------------------------------
# OPTIMIZED AND HIGH-SHOT EVALUATED VALUES
# --------------------------------------------------------------------------------
# Final Optimized Value : 0.73400000
# Evaluated Mean        : 0.71786500
# Evaluated Std         : 0.00160531
# Evaluated Min         : 0.71409000
# Evaluated Max         : 0.72071000
#
# All Evaluated Values:
# [0.71624, 0.71943, 0.71634, 0.71758, 0.71686, 0.71645, 0.7175 , 0.71894,
#  0.71958, 0.71844, 0.71952, 0.71674, 0.71409, 0.71986, 0.7173 , 0.71878,
#  0.71894, 0.71592, 0.71808, 0.72071]
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566, 0.6883896757,
#  0.5848087428, 0.2739643248, 0.8377858251, 0.3022293541, 0.1728462164,
#  0.8017433668, 0.3441099205, 0.4375847094, 0.152681156 , 0.2761357842]
#
# Optimal Parameters:
# [ 3.1795307981,  1.5072710529,  2.0575201123,  0.3884466585,  1.0486772675,
#   1.8771106495,  1.5062112798,  0.1214596099,  1.3981317762,  0.0677182947,
#   1.1700401082,  0.8238912615,  1.7589320907,  2.6823236096,  0.0183162006,
#   0.5872066558, -0.0791984173,  2.2856810083,  1.4671646294,  0.5851664301,
#  -0.0632883583,  0.340417002 ,  1.4634388934,  0.5421421634,  0.0362094402,
#   0.6448058699, -0.0920758315,  0.8056525993,  0.2292141651,  0.7399868565]
# ================================================================================
#
# ================================================================================
# Optimization Run 2/30
# Optimization Seed : 151
# ================================================================================
#
# Initial Parameters:
# [0.4917938425, 0.3601415032, 0.7094100488, 0.6895107167, 0.4723817514,
#  0.4790485592, 0.0068635273, 0.9044398512, 0.4337399476, 0.4736042839,
#  0.034330777 , 0.9496323674, 0.5907905652, 0.4241785512, 0.1868628067,
#  0.9840929216, 0.690221156 , 0.9039467044, 0.0207568308, 0.9969449281,
#  0.3143005034, 0.2098620446, 0.0173606056, 0.1892781313, 0.2905169378,
#  0.2743264362, 0.6422361978, 0.0963913748, 0.0696866112, 0.767331954 ]
#
# Starting COBYLA optimization...
# success_probability = 0.33940000
# success_probability = 0.26170000
# success_probability = 0.34890000
# success_probability = 0.35630000
# success_probability = 0.32760000
# success_probability = 0.30560000
# success_probability = 0.36690000
# success_probability = 0.31880000
# success_probability = 0.36690000
# success_probability = 0.27540000
# success_probability = 0.36310000
# success_probability = 0.30460000
# success_probability = 0.37320000
# success_probability = 0.33200000
# success_probability = 0.37270000
# success_probability = 0.33600000
# success_probability = 0.37990000
# success_probability = 0.31720000
# success_probability = 0.37850000
# success_probability = 0.30250000
# success_probability = 0.36850000
# success_probability = 0.32620000
# success_probability = 0.37990000
# success_probability = 0.37790000
# success_probability = 0.37990000
# success_probability = 0.34040000
# success_probability = 0.37990000
# success_probability = 0.31290000
# success_probability = 0.37990000
# success_probability = 0.31630000
# success_probability = 0.37990000
# success_probability = 0.40530000
# success_probability = 0.40400000
# success_probability = 0.33640000
# success_probability = 0.41490000
# success_probability = 0.31950000
# success_probability = 0.41620000
# success_probability = 0.43570000
# success_probability = 0.42580000
# success_probability = 0.45800000
# success_probability = 0.45390000
# success_probability = 0.39060000
# success_probability = 0.44670000
# success_probability = 0.41550000
# success_probability = 0.45810000
# success_probability = 0.44190000
# success_probability = 0.46000000
# success_probability = 0.37550000
# success_probability = 0.45720000
# success_probability = 0.42200000
# success_probability = 0.43860000
# success_probability = 0.38790000
# success_probability = 0.44490000
# success_probability = 0.34620000
# success_probability = 0.46050000
# success_probability = 0.42960000
# success_probability = 0.43590000
# success_probability = 0.42370000
# success_probability = 0.45880000
# success_probability = 0.40460000
# success_probability = 0.46050000
# success_probability = 0.41300000
# success_probability = 0.46050000
# success_probability = 0.42490000
# success_probability = 0.46050000
# success_probability = 0.42500000
# success_probability = 0.44300000
# success_probability = 0.42880000
# success_probability = 0.45740000
# success_probability = 0.45880000
# success_probability = 0.45790000
# success_probability = 0.46420000
# success_probability = 0.43580000
# success_probability = 0.46310000
# success_probability = 0.47740000
# success_probability = 0.46330000
# success_probability = 0.44490000
# success_probability = 0.47350000
# success_probability = 0.45370000
# success_probability = 0.47180000
# success_probability = 0.48030000
# success_probability = 0.48330000
# success_probability = 0.46850000
# success_probability = 0.48100000
# success_probability = 0.47590000
# success_probability = 0.48870000
# success_probability = 0.46960000
# success_probability = 0.48880000
# success_probability = 0.47900000
# success_probability = 0.48840000
# success_probability = 0.47550000
# success_probability = 0.48700000
# success_probability = 0.47850000
# success_probability = 0.48880000
# success_probability = 0.48400000
# success_probability = 0.48560000
# success_probability = 0.47040000
# success_probability = 0.49160000
# success_probability = 0.48790000
# success_probability = 0.50210000
# success_probability = 0.48480000
# success_probability = 0.50070000
# success_probability = 0.50370000
# success_probability = 0.50370000
# success_probability = 0.50110000
# success_probability = 0.50370000
# success_probability = 0.49050000
# success_probability = 0.49870000
# success_probability = 0.49920000
# success_probability = 0.49880000
# success_probability = 0.48530000
# success_probability = 0.50690000
# success_probability = 0.51710000
# success_probability = 0.51430000
# success_probability = 0.51860000
# success_probability = 0.52540000
# success_probability = 0.52250000
# success_probability = 0.52450000
# success_probability = 0.53210000
# success_probability = 0.53430000
# success_probability = 0.53820000
# success_probability = 0.54370000
# success_probability = 0.52120000
# success_probability = 0.54140000
# success_probability = 0.52630000
# success_probability = 0.54440000
# success_probability = 0.53840000
# success_probability = 0.54660000
# success_probability = 0.54050000
# success_probability = 0.54310000
# success_probability = 0.54030000
# success_probability = 0.54300000
# success_probability = 0.55700000
# success_probability = 0.56820000
# success_probability = 0.56760000
# success_probability = 0.57370000
# success_probability = 0.57500000
# success_probability = 0.58050000
# success_probability = 0.57410000
# success_probability = 0.60360000
# success_probability = 0.60740000
# success_probability = 0.60740000
# success_probability = 0.60630000
# success_probability = 0.60040000
# success_probability = 0.60540000
# success_probability = 0.61180000
# success_probability = 0.62200000
# success_probability = 0.61670000
# success_probability = 0.62630000
# success_probability = 0.61960000
# success_probability = 0.64750000
# success_probability = 0.64530000
# success_probability = 0.64740000
# success_probability = 0.65100000
# success_probability = 0.65300000
# success_probability = 0.65880000
# success_probability = 0.66460000
# success_probability = 0.67910000
# success_probability = 0.67830000
# success_probability = 0.67740000
# success_probability = 0.67730000
# success_probability = 0.68140000
# success_probability = 0.68570000
# success_probability = 0.67410000
# success_probability = 0.68410000
# success_probability = 0.68020000
# success_probability = 0.68700000
# success_probability = 0.68350000
# success_probability = 0.68460000
# success_probability = 0.69040000
# success_probability = 0.69620000
# success_probability = 0.69360000
# success_probability = 0.69090000
# success_probability = 0.68780000
# success_probability = 0.69100000
# success_probability = 0.70160000
# success_probability = 0.70030000
# success_probability = 0.69220000
# success_probability = 0.69790000
# success_probability = 0.70660000
# success_probability = 0.70430000
# success_probability = 0.69790000
# success_probability = 0.70000000
# success_probability = 0.70750000
# success_probability = 0.70990000
# success_probability = 0.70240000
# success_probability = 0.71220000
# success_probability = 0.71170000
# success_probability = 0.70700000
# success_probability = 0.69990000
# success_probability = 0.71200000
# success_probability = 0.71510000
# success_probability = 0.71790000
# success_probability = 0.71760000
# success_probability = 0.71920000
# success_probability = 0.71850000
# success_probability = 0.71400000
# success_probability = 0.71300000
# success_probability = 0.72010000
# success_probability = 0.72150000
# success_probability = 0.71470000
# success_probability = 0.71700000
# success_probability = 0.72540000
# success_probability = 0.72750000
# success_probability = 0.72730000
# success_probability = 0.71530000
# success_probability = 0.73210000
# success_probability = 0.73000000
# success_probability = 0.72900000
# success_probability = 0.72740000
# success_probability = 0.73260000
# success_probability = 0.72840000
# success_probability = 0.73580000
# success_probability = 0.73110000
# success_probability = 0.73320000
# success_probability = 0.73760000
# success_probability = 0.73640000
# success_probability = 0.73230000
# success_probability = 0.73920000
# success_probability = 0.72550000
# success_probability = 0.73260000
# success_probability = 0.72960000
# success_probability = 0.73580000
# success_probability = 0.73270000
# success_probability = 0.73520000
# success_probability = 0.74590000
# success_probability = 0.74650000
# success_probability = 0.74440000
# success_probability = 0.74680000
# success_probability = 0.74130000
# success_probability = 0.74830000
# success_probability = 0.73720000
# success_probability = 0.74790000
# success_probability = 0.73780000
# success_probability = 0.74960000
# success_probability = 0.74730000
# success_probability = 0.74980000
# success_probability = 0.75130000
# success_probability = 0.74490000
# success_probability = 0.74620000
# success_probability = 0.75470000
# success_probability = 0.75400000
# success_probability = 0.75110000
# success_probability = 0.74810000
# success_probability = 0.74750000
# success_probability = 0.74350000
# success_probability = 0.75770000
# success_probability = 0.75500000
# success_probability = 0.75690000
# success_probability = 0.74550000
# success_probability = 0.75530000
# success_probability = 0.75740000
# success_probability = 0.75730000
# success_probability = 0.74090000
# success_probability = 0.75650000
# success_probability = 0.75310000
# success_probability = 0.75700000
# success_probability = 0.75660000
# success_probability = 0.75590000
# success_probability = 0.75730000
# success_probability = 0.75860000
# success_probability = 0.75800000
# success_probability = 0.76290000
# success_probability = 0.76570000
# success_probability = 0.76750000
# success_probability = 0.77020000
# success_probability = 0.76820000
# success_probability = 0.76600000
# success_probability = 0.76690000
# success_probability = 0.77080000
# success_probability = 0.77120000
# success_probability = 0.77170000
# success_probability = 0.76920000
# success_probability = 0.77380000
# success_probability = 0.77170000
# success_probability = 0.77420000
# success_probability = 0.77770000
# success_probability = 0.77510000
# success_probability = 0.77510000
# success_probability = 0.77500000
# success_probability = 0.78100000
# success_probability = 0.78090000
# success_probability = 0.77860000
# success_probability = 0.78230000
# success_probability = 0.78040000
# success_probability = 0.78450000
# success_probability = 0.78220000
# success_probability = 0.78450000
# success_probability = 0.78490000
# success_probability = 0.78680000
# success_probability = 0.78630000
# success_probability = 0.78510000
# success_probability = 0.78570000
# success_probability = 0.78870000
# success_probability = 0.78920000
# success_probability = 0.78640000
# success_probability = 0.78980000
# success_probability = 0.78780000
# success_probability = 0.78930000
# success_probability = 0.79360000
# success_probability = 0.79460000
# success_probability = 0.79270000
# success_probability = 0.79450000
# success_probability = 0.78920000
# success_probability = 0.79600000
# success_probability = 0.79600000
# success_probability = 0.79200000
# success_probability = 0.79350000
# success_probability = 0.79820000
# success_probability = 0.79590000
# success_probability = 0.79950000
# success_probability = 0.79620000
# success_probability = 0.80400000
# success_probability = 0.80300000
# success_probability = 0.80110000
# success_probability = 0.80410000
# success_probability = 0.80420000
# success_probability = 0.80300000
# success_probability = 0.80200000
# success_probability = 0.80020000
# success_probability = 0.80100000
# success_probability = 0.80410000
# success_probability = 0.80330000
# success_probability = 0.80370000
# success_probability = 0.80490000
# success_probability = 0.80630000
# success_probability = 0.80600000
# success_probability = 0.80660000
# success_probability = 0.80670000
# success_probability = 0.80420000
# success_probability = 0.80620000
# success_probability = 0.80480000
# success_probability = 0.80810000
# success_probability = 0.80880000
# success_probability = 0.80630000
# success_probability = 0.80830000
# success_probability = 0.80720000
# success_probability = 0.80400000
# success_probability = 0.80990000
# success_probability = 0.81020000
# success_probability = 0.81050000
# success_probability = 0.80790000
# success_probability = 0.81080000
# success_probability = 0.80760000
# success_probability = 0.80960000
# success_probability = 0.80900000
# success_probability = 0.81100000
# success_probability = 0.81220000
# success_probability = 0.81050000
# success_probability = 0.81240000
# success_probability = 0.81440000
# success_probability = 0.81040000
# success_probability = 0.81180000
# success_probability = 0.81120000
# success_probability = 0.81380000
# success_probability = 0.81350000
# success_probability = 0.81390000
# success_probability = 0.81290000
# success_probability = 0.81330000
# success_probability = 0.81500000
# success_probability = 0.81470000
# success_probability = 0.81400000
# success_probability = 0.81310000
# success_probability = 0.81100000
# success_probability = 0.81460000
# success_probability = 0.81420000
# success_probability = 0.81480000
# success_probability = 0.81410000
# success_probability = 0.81600000
# success_probability = 0.81170000
# success_probability = 0.81430000
# success_probability = 0.81340000
# success_probability = 0.81380000
# success_probability = 0.81820000
# success_probability = 0.81800000
# success_probability = 0.81810000
# success_probability = 0.81670000
# success_probability = 0.81820000
# success_probability = 0.81900000
# success_probability = 0.81620000
# success_probability = 0.81890000
# success_probability = 0.81770000
# success_probability = 0.81810000
# success_probability = 0.81860000
# success_probability = 0.81670000
# success_probability = 0.81740000
# success_probability = 0.81940000
# success_probability = 0.81650000
# success_probability = 0.81910000
# success_probability = 0.81930000
# success_probability = 0.81820000
# success_probability = 0.81930000
# success_probability = 0.81980000
# success_probability = 0.81990000
# success_probability = 0.81980000
# success_probability = 0.81900000
# success_probability = 0.82000000
# success_probability = 0.81880000
# success_probability = 0.81940000
# success_probability = 0.81920000
# success_probability = 0.82010000
# success_probability = 0.82100000
# success_probability = 0.81980000
# success_probability = 0.81950000
# success_probability = 0.81700000
# success_probability = 0.81960000
# success_probability = 0.82100000
# success_probability = 0.82030000
# success_probability = 0.82090000
# success_probability = 0.82080000
# success_probability = 0.82110000
# success_probability = 0.82130000
# success_probability = 0.82240000
# success_probability = 0.82180000
# success_probability = 0.82160000
# success_probability = 0.82210000
# success_probability = 0.82010000
# success_probability = 0.82240000
# success_probability = 0.82120000
# success_probability = 0.82180000
# success_probability = 0.82190000
# success_probability = 0.82130000
# success_probability = 0.82050000
# success_probability = 0.82270000
# success_probability = 0.82260000
# success_probability = 0.82170000
# success_probability = 0.82320000
# success_probability = 0.82360000
# success_probability = 0.82080000
# success_probability = 0.82240000
# success_probability = 0.82270000
# success_probability = 0.82230000
# success_probability = 0.82160000
# success_probability = 0.82330000
# success_probability = 0.82330000
# success_probability = 0.82360000
# success_probability = 0.82290000
# success_probability = 0.82310000
# success_probability = 0.82250000
# success_probability = 0.82290000
# success_probability = 0.82340000
# success_probability = 0.82340000
# success_probability = 0.82290000
# success_probability = 0.82290000
# success_probability = 0.82290000
# success_probability = 0.82230000
# success_probability = 0.82320000
# success_probability = 0.82340000
# success_probability = 0.82350000
# success_probability = 0.82300000
# success_probability = 0.82370000
# success_probability = 0.82320000
# success_probability = 0.82300000
# success_probability = 0.82260000
# success_probability = 0.82360000
# success_probability = 0.82360000
# success_probability = 0.82360000
# success_probability = 0.82260000
# success_probability = 0.82330000
# success_probability = 0.82350000
# success_probability = 0.82330000
# success_probability = 0.82310000
# success_probability = 0.82380000
# success_probability = 0.82380000
# success_probability = 0.82350000
# success_probability = 0.82380000
# success_probability = 0.82300000
# success_probability = 0.82400000
# success_probability = 0.82330000
# success_probability = 0.82360000
# success_probability = 0.82370000
# success_probability = 0.82410000
# success_probability = 0.82340000
# success_probability = 0.82340000
# success_probability = 0.82380000
# success_probability = 0.82400000
# success_probability = 0.82380000
# success_probability = 0.82420000
# success_probability = 0.82340000
# success_probability = 0.82370000
# success_probability = 0.82350000
# success_probability = 0.82390000
# success_probability = 0.82380000
# success_probability = 0.82400000
# success_probability = 0.82370000
# success_probability = 0.82410000
# success_probability = 0.82340000
# success_probability = 0.82330000
# success_probability = 0.82420000
# success_probability = 0.82370000
# success_probability = 0.82360000
# success_probability = 0.82360000
# success_probability = 0.82400000
# success_probability = 0.82380000
# success_probability = 0.82380000
# success_probability = 0.82360000
# success_probability = 0.82410000
# success_probability = 0.82350000
# success_probability = 0.82380000
# success_probability = 0.82350000
# success_probability = 0.82380000
# success_probability = 0.82340000
# success_probability = 0.82430000
# success_probability = 0.82350000
# success_probability = 0.82440000
# success_probability = 0.82400000
# success_probability = 0.82400000
# success_probability = 0.82380000
# success_probability = 0.82410000
# success_probability = 0.82410000
# success_probability = 0.82420000
# success_probability = 0.82410000
# success_probability = 0.82420000
# success_probability = 0.82410000
# success_probability = 0.82420000
# success_probability = 0.82410000
# success_probability = 0.82390000
# success_probability = 0.82430000
# success_probability = 0.82410000
# success_probability = 0.82430000
# success_probability = 0.82410000
# success_probability = 0.82420000
# success_probability = 0.82370000
# success_probability = 0.82440000
# success_probability = 0.82350000
# success_probability = 0.82420000
# success_probability = 0.82420000
# success_probability = 0.82410000
# success_probability = 0.82420000
# success_probability = 0.82400000
# success_probability = 0.82420000
# success_probability = 0.82430000
# success_probability = 0.82410000
# success_probability = 0.82400000
# success_probability = 0.82430000
# success_probability = 0.82420000
# success_probability = 0.82420000
# success_probability = 0.82440000
# success_probability = 0.82420000
# success_probability = 0.82450000
# success_probability = 0.82400000
# success_probability = 0.82430000
# success_probability = 0.82420000
# success_probability = 0.82430000
# success_probability = 0.82450000
# success_probability = 0.82440000
# success_probability = 0.82420000
# success_probability = 0.82420000
# success_probability = 0.82460000
# success_probability = 0.82430000
# success_probability = 0.82430000
# success_probability = 0.82420000
# success_probability = 0.82430000
# success_probability = 0.82460000
# success_probability = 0.82440000
# success_probability = 0.82410000
# success_probability = 0.82440000
# success_probability = 0.82430000
# success_probability = 0.82420000
# success_probability = 0.82440000
# success_probability = 0.82430000
# success_probability = 0.82420000
# success_probability = 0.82440000
# success_probability = 0.82420000
# success_probability = 0.82440000
# success_probability = 0.82430000
# success_probability = 0.82430000
# success_probability = 0.82430000
# success_probability = 0.82420000
# success_probability = 0.82430000
# success_probability = 0.82440000
# success_probability = 0.82450000
# success_probability = 0.82420000
# success_probability = 0.82430000
# success_probability = 0.82420000
# success_probability = 0.82430000
# success_probability = 0.82440000
# success_probability = 0.82460000
# success_probability = 0.82430000
# success_probability = 0.82430000
# success_probability = 0.82450000
# success_probability = 0.82420000
# success_probability = 0.82440000
# success_probability = 0.82430000
# success_probability = 0.82450000
# success_probability = 0.82420000
# success_probability = 0.82440000
# success_probability = 0.82460000
# success_probability = 0.82450000
# success_probability = 0.82440000
# success_probability = 0.82430000
# success_probability = 0.82440000
# success_probability = 0.82440000
# success_probability = 0.82440000
# success_probability = 0.82440000
# success_probability = 0.82430000
# success_probability = 0.82460000
# success_probability = 0.82440000
# success_probability = 0.82440000
# success_probability = 0.82450000
# success_probability = 0.82460000
# success_probability = 0.82450000
# success_probability = 0.82450000
# success_probability = 0.82430000
# success_probability = 0.82460000
# success_probability = 0.82430000
# success_probability = 0.82430000
# success_probability = 0.82460000
# success_probability = 0.82450000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82450000
# success_probability = 0.82440000
# success_probability = 0.82460000
# success_probability = 0.82450000
# success_probability = 0.82450000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82450000
# success_probability = 0.82450000
# success_probability = 0.82460000
# success_probability = 0.82450000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82450000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82450000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# success_probability = 0.82460000
# ...
#
# Evaluated Values:
# [0.81113, 0.81082, 0.81362, 0.81312, 0.81178, 0.81254, 0.81298, 0.81186,
#  0.81236, 0.81153, 0.8114 , 0.81415, 0.8122 , 0.81233, 0.81169, 0.81277,
#  0.81196, 0.81362, 0.81273, 0.81422]
#
# Initial Parameters:
# [0.0683064102, 0.5061877572, 0.2800764934, 0.4917358842, 0.3376481488,
#  0.6337766115, 0.7941202296, 0.2237709719, 0.8893153608, 0.9462072178,
#  0.9270749557, 0.8979372613, 0.8865232604, 0.1112901922, 0.4404611446,
#  0.6571269562, 0.6018173982, 0.0668305069, 0.5031888045, 0.7100940384,
#  0.3646853666, 0.6647653187, 0.3408936761, 0.3312253256, 0.7714370826,
#  0.2269448353, 0.0303235797, 0.6383902153, 0.6934448951, 0.8400035435]
#
# Optimal Parameters:
# [-1.4594000845,  1.3708074362,  0.0441073659, -1.1952681937, -0.1319460094,
#   1.7541948323,  0.1931578786, -0.49270969  ,  1.4796978915,  1.5128808785,
#   0.0916183612,  0.3054608192, -0.2012228407,  0.4744033887,  0.0018624644,
#   0.2425154807, -0.1677692991, -1.0927921032, -0.7049039329,  1.4986882833,
#   1.123170449 ,  0.3288581096,  0.037526058 ,  0.3830952855,  1.1589528908,
#   0.3793906979, -0.041472823 ,  1.1566809368,  1.6078034506, -0.2694893163]
# ----------------------------------------------------------------------------------------------------
#
# Run 25
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 174
# Optimized Value   : 0.90950000
# Evaluated Mean    : 0.90401950
# Evaluated Std     : 0.00080657
# Evaluated Min     : 0.90247000
# Evaluated Max     : 0.90562000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 678
# Optimization Time : 43.168902 s
#
# Evaluated Values:
# [0.9044 , 0.90298, 0.90562, 0.90315, 0.90296, 0.90439, 0.90361, 0.90492,
#  0.90406, 0.90247, 0.90368, 0.90483, 0.90413, 0.90365, 0.90469, 0.9047 ,
#  0.90317, 0.90511, 0.90375, 0.90412]
#
# Initial Parameters:
# [0.920751175 , 0.8324481628, 0.9226421153, 0.4120178702, 0.112899878 ,
#  0.539662511 , 0.9690640438, 0.8958288503, 0.8463732302, 0.6837088366,
#  0.0134777936, 0.9213092468, 0.0585796685, 0.528523907 , 0.4212992395,
#  0.8064657524, 0.2081509804, 0.1492170041, 0.0586840123, 0.6381376407,
#  0.7175421339, 0.7259671078, 0.0347409726, 0.8317209152, 0.1893140181,
#  0.5873066532, 0.6508822385, 0.1541344136, 0.9950538172, 0.0392803271]
#
# Optimal Parameters:
# [-1.4018493450e+00,  2.9492174876e+00,  1.0922639818e-03,
#  -1.6993675959e+00,  1.8790767860e-01, -5.2876097325e-02,
#  -1.0673702703e-02,  1.5706522411e+00,  1.5748770911e+00,
#   1.6102129051e+00, -4.8140116435e-01,  2.5851145096e+00,
#   3.4710665799e-01,  8.4066550863e-01, -9.9098879799e-02,
#   2.2017306804e+00,  4.3003562730e-03, -6.5986663930e-01,
#   2.1000223571e-01,  1.5681659966e+00,  1.5252441009e+00,
#   5.8015601442e-01,  1.6573172215e-02,  8.3509806177e-01,
#   1.5041998340e+00,  5.5003893384e-01, -2.6915583910e-02,
#  -2.9372064710e-02,  1.5796115058e+00,  3.9346379309e-01]
# ----------------------------------------------------------------------------------------------------
#
# Run 26
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 175
# Optimized Value   : 0.75320000
# Evaluated Mean    : 0.74400200
# Evaluated Std     : 0.00172103
# Evaluated Min     : 0.74103000
# Evaluated Max     : 0.74711000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 561
# Optimization Time : 35.644630 s
#
# Evaluated Values:
# [0.74264, 0.74448, 0.74509, 0.74453, 0.74339, 0.74211, 0.74133, 0.74435,
#  0.74711, 0.74625, 0.74503, 0.74523, 0.74298, 0.7445 , 0.74103, 0.74626,
#  0.7419 , 0.74567, 0.74184, 0.74432]
#
# Initial Parameters:
# [0.5632800098, 0.5263460088, 0.074383608 , 0.0432472297, 0.1116614549,
#  0.3149336925, 0.8051899849, 0.2265811498, 0.2507577735, 0.3247400132,
#  0.7132637608, 0.7744654451, 0.9295185054, 0.8709503245, 0.9380278462,
#  0.6231528096, 0.2419077457, 0.8799737511, 0.1804762542, 0.8020908004,
#  0.3363522676, 0.2884964572, 0.5552697615, 0.8113197998, 0.1117050081,
#  0.04623727  , 0.2558624663, 0.3513980154, 0.5655624306, 0.2444933266]
#
# Optimal Parameters:
# [ 1.1230522618,  1.4319905124,  0.5681091962, -0.0852155816,  0.217744572 ,
#  -1.4441960263, -0.0133630816,  0.0741157117,  0.0324859292,  0.6776285102,
#   1.555802298 ,  0.5014864597,  0.9088376338,  2.517801096 ,  0.0162675628,
#   1.2104665009, -0.0808862298,  0.5645998538, -0.0729869566,  0.7499789199,
#   0.1661664774,  0.7595812026,  1.5572446386,  0.7495239024,  0.0391644655,
#   0.2132530662,  1.5387115512,  1.0821700535,  0.0154217271,  0.2756726078]
# ----------------------------------------------------------------------------------------------------
#
# Run 27
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 176
# Optimized Value   : 0.87040000
# Evaluated Mean    : 0.86723900
# Evaluated Std     : 0.00112979
# Evaluated Min     : 0.86562000
# Evaluated Max     : 0.86952000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 608
# Optimization Time : 38.301876 s
#
# Evaluated Values:
# [0.8673 , 0.86562, 0.86673, 0.86846, 0.86644, 0.86635, 0.86952, 0.86668,
#  0.86683, 0.86593, 0.86616, 0.8674 , 0.86678, 0.86734, 0.86938, 0.86601,
#  0.86789, 0.8677 , 0.86699, 0.86927]
#
# Initial Parameters:
# [0.908796571 , 0.1480812304, 0.9316217524, 0.8690627692, 0.8218723273,
#  0.3598173853, 0.8198721198, 0.1817033926, 0.2126209616, 0.6959983996,
#  0.3659168242, 0.6449720995, 0.1945739112, 0.1231941489, 0.9608135811,
#  0.9693122607, 0.6994862206, 0.3285305578, 0.5308429614, 0.0713595069,
#  0.6124682681, 0.0173357401, 0.2291752338, 0.1716368198, 0.7904109494,
#  0.6764072798, 0.8677348266, 0.5559777189, 0.6488675301, 0.9283183685]
#
# Optimal Parameters:
# [ 1.2621322486,  1.1813001205,  3.0535934414,  1.3981556979, -0.847053419 ,
#   0.0849183797,  0.7456788535, -0.0518123017, -1.5308292364,  1.6119784153,
#   0.1336754009,  2.7386813709,  0.6311383828,  0.7444235431, -0.0404303251,
#   1.9838419114,  0.7441541927, -0.2986016619,  0.6714641899,  1.5371407415,
#   1.3426781863, -0.2195750294, -0.0061535989,  0.1501334707,  1.4879456976,
#   0.8049655188, -0.0167308625,  0.5571564577,  1.5636467955,  1.2252971282]
# ----------------------------------------------------------------------------------------------------
#
# Run 28
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 177
# Optimized Value   : 0.56860000
# Evaluated Mean    : 0.56035900
# Evaluated Std     : 0.00137090
# Evaluated Min     : 0.55752000
# Evaluated Max     : 0.56301000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 590
# Optimization Time : 37.902213 s
#
# Evaluated Values:
# [0.55897, 0.55938, 0.56003, 0.562  , 0.5606 , 0.56164, 0.55997, 0.56052,
#  0.56139, 0.56007, 0.5629 , 0.5603 , 0.55752, 0.56301, 0.55952, 0.56157,
#  0.56043, 0.55876, 0.55972, 0.55888]
#
# Initial Parameters:
# [0.4859979492, 0.3134855983, 0.5928545916, 0.5388495959, 0.8208222388,
#  0.1681699936, 0.7886708539, 0.9073399324, 0.1513191786, 0.6385598502,
#  0.0204482374, 0.441729694 , 0.1062169866, 0.3316953766, 0.9856944419,
#  0.4606017013, 0.291802071 , 0.5311775661, 0.6869978953, 0.085870002 ,
#  0.70379701  , 0.7732596263, 0.358077326 , 0.7448635381, 0.5398799816,
#  0.6518199474, 0.496504845 , 0.729372615 , 0.4775535381, 0.1132538865]
#
# Optimal Parameters:
# [-0.4020700131,  1.3502128324,  1.4697827894,  1.3667019952,  0.1182069571,
#   1.4481716912,  0.0584938367,  2.1247542466, -0.1197632696,  2.2245647937,
#   1.1452225305,  0.1942517037, -0.9499680082,  1.3183585058, -0.0058628508,
#   0.1085220665,  0.010181462 ,  0.837232554 ,  0.6942033744, -0.0078239048,
#   0.1198349106,  1.6377894492,  0.1757168688,  1.0508780435,  0.0024131174,
#   0.9497964276,  0.2141013902,  0.3674014704, -0.7391984304, -0.5382272028]
# ----------------------------------------------------------------------------------------------------
#
# Run 29
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 178
# Optimized Value   : 0.73260000
# Evaluated Mean    : 0.72921600
# Evaluated Std     : 0.00123279
# Evaluated Min     : 0.72604000
# Evaluated Max     : 0.73161000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 557
# Optimization Time : 35.460610 s
#
# Evaluated Values:
# [0.72888, 0.72943, 0.72982, 0.72977, 0.72771, 0.72604, 0.7303 , 0.73054,
#  0.73058, 0.72823, 0.729  , 0.72976, 0.72896, 0.7287 , 0.72986, 0.72856,
#  0.7281 , 0.73045, 0.72802, 0.73161]
#
# Initial Parameters:
# [0.7608275692, 0.0464101376, 0.0032708871, 0.7605003536, 0.2769531808,
#  0.5945503444, 0.8036218146, 0.7402677744, 0.1239034672, 0.2438968692,
#  0.748428843 , 0.9205783868, 0.2357355697, 0.9391032789, 0.4081091944,
#  0.4620759117, 0.7294079941, 0.5779372506, 0.3477807167, 0.9240071009,
#  0.4847679255, 0.9369591861, 0.6895419866, 0.4903610315, 0.1782447546,
#  0.0915727898, 0.6053767128, 0.8164664622, 0.7844838565, 0.8076365567]
#
# Optimal Parameters:
# [ 0.5703612314,  1.5020416566,  0.790890338 ,  2.6319372737,  0.0890267306,
#   1.5649030922,  0.3713458733,  0.3676656825,  0.3038158504,  0.685456    ,
#   1.409217475 ,  1.8329537476,  0.9716941681,  2.6838094243, -0.0152876729,
#  -0.1420287082,  0.0255472438, -0.1478761048,  2.203093019 ,  0.0991002877,
#   0.1664845565,  0.9599429609,  1.5495112822,  0.3352772052, -0.1302241643,
#   0.1705513594,  1.2259330708,  1.0390491648,  0.6831631853,  1.0036346561]
# ----------------------------------------------------------------------------------------------------
#
# Run 30
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 179
# Optimized Value   : 0.68960000
# Evaluated Mean    : 0.68803600
# Evaluated Std     : 0.00112377
# Evaluated Min     : 0.68574000
# Evaluated Max     : 0.69056000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 539
# Optimization Time : 33.895787 s
#
# Evaluated Values:
# [0.68676, 0.68574, 0.68783, 0.69045, 0.68822, 0.68803, 0.68832, 0.68718,
#  0.68799, 0.69056, 0.68934, 0.68771, 0.68756, 0.68885, 0.68715, 0.68876,
#  0.68731, 0.68785, 0.68721, 0.6879 ]
#
# Initial Parameters:
# [0.9180695286, 0.9403935557, 0.9611445873, 0.1282735573, 0.7343854482,
#  0.1418537547, 0.3206870255, 0.8783134777, 0.3925501756, 0.9542827898,
#  0.4333144504, 0.0052152104, 0.5921889116, 0.318609756 , 0.9316370681,
#  0.6026668473, 0.0078690534, 0.7991305598, 0.851774691 , 0.06652901  ,
#  0.7310172927, 0.1064287992, 0.0810809173, 0.7115609048, 0.7069595409,
#  0.496652521 , 0.9897356485, 0.1231137075, 0.6818954479, 0.6829684311]
#
# Optimal Parameters:
# [ 0.5602037978,  2.2494682839,  1.7000418918,  0.0723746416,  0.2972563869,
#  -0.4272729705, -0.030226348 ,  2.3004633328,  0.351294517 ,  2.3383655922,
#   0.306709498 ,  1.2478916103,  1.5952785515,  1.1729800099,  1.5487751654,
#  -0.0102616666,  1.5793412832,  1.1871507307,  0.216029424 ,  1.4631217733,
#   1.0542483831, -0.5861770347,  0.0281086741,  0.8512219787,  1.5973771431,
#   0.5396889953,  1.8395400523,  0.3806266499,  1.6378190091,  0.7164986278]
# ----------------------------------------------------------------------------------------------------
#
# SUMMARY
# ====================================================================================================
#
# Original Optimization-Shot Results:
# Maximum Optimized Value : 0.90950000
# Maximum Run             : 25
# Mean Optimized Value    : 0.69582667
# Std Optimized Value     : 0.13347450
#
# High-Shot Evaluation Results:
# Best Evaluated Mean     : 0.90401950
# Best Evaluated Mean Run : 25
# Mean of Evaluated Means : 0.68806412
# Std of Evaluated Means  : 0.13491882
#
# Optimizer Statistics:
# Mean Function Evals     : 606.03
# Std Function Evals      : 57.10
# Successful Runs         : 30/30
# Failed Runs             : 0/30
# Reached MaxIter         : 0/30
#
# Computational Runtime Statistics:
# Total Wall-Clock Time          : 1169.298702 s
# Total Optimization Time        : 1113.631081 s
# Time per Complete Opt. Run     : 37.121036 s
# Std Optimization Time per Run  : 3.501296 s
#
# ====================================================================================================
# BEST RUN ACCORDING TO ORIGINAL OPTIMIZED VALUE
# ====================================================================================================
# Run             : 25
# Optimized Value : 0.90950000
# Evaluated Mean  : 0.90401950
# Evaluated Std   : 0.00080657
# Evaluated Min   : 0.90247000
# Evaluated Max   : 0.90562000
#
# Evaluated Values:
# [0.9044 , 0.90298, 0.90562, 0.90315, 0.90296, 0.90439, 0.90361, 0.90492,
#  0.90406, 0.90247, 0.90368, 0.90483, 0.90413, 0.90365, 0.90469, 0.9047 ,
#  0.90317, 0.90511, 0.90375, 0.90412]
#
# Initial Parameters:
# [0.920751175 , 0.8324481628, 0.9226421153, 0.4120178702, 0.112899878 ,
#  0.539662511 , 0.9690640438, 0.8958288503, 0.8463732302, 0.6837088366,
#  0.0134777936, 0.9213092468, 0.0585796685, 0.528523907 , 0.4212992395,
#  0.8064657524, 0.2081509804, 0.1492170041, 0.0586840123, 0.6381376407,
#  0.7175421339, 0.7259671078, 0.0347409726, 0.8317209152, 0.1893140181,
#  0.5873066532, 0.6508822385, 0.1541344136, 0.9950538172, 0.0392803271]
#
# Optimal Parameters:
# [-1.4018493450e+00,  2.9492174876e+00,  1.0922639818e-03,
#  -1.6993675959e+00,  1.8790767860e-01, -5.2876097325e-02,
#  -1.0673702703e-02,  1.5706522411e+00,  1.5748770911e+00,
#   1.6102129051e+00, -4.8140116435e-01,  2.5851145096e+00,
#   3.4710665799e-01,  8.4066550863e-01, -9.9098879799e-02,
#   2.2017306804e+00,  4.3003562730e-03, -6.5986663930e-01,
#   2.1000223571e-01,  1.5681659966e+00,  1.5252441009e+00,
#   5.8015601442e-01,  1.6573172215e-02,  8.3509806177e-01,
#   1.5041998340e+00,  5.5003893384e-01, -2.6915583910e-02,
#  -2.9372064710e-02,  1.5796115058e+00,  3.9346379309e-01]
#
# ====================================================================================================
# BEST RUN ACCORDING TO HIGH-SHOT EVALUATED MEAN
# ====================================================================================================
# Run             : 25
# Optimized Value : 0.90950000
# Evaluated Mean  : 0.90401950
# Evaluated Std   : 0.00080657
# Evaluated Min   : 0.90247000
# Evaluated Max   : 0.90562000
#
# Evaluated Values:
# [0.9044 , 0.90298, 0.90562, 0.90315, 0.90296, 0.90439, 0.90361, 0.90492,
#  0.90406, 0.90247, 0.90368, 0.90483, 0.90413, 0.90365, 0.90469, 0.9047 ,
#  0.90317, 0.90511, 0.90375, 0.90412]
#
# Initial Parameters:
# [0.920751175 , 0.8324481628, 0.9226421153, 0.4120178702, 0.112899878 ,
#  0.539662511 , 0.9690640438, 0.8958288503, 0.8463732302, 0.6837088366,
#  0.0134777936, 0.9213092468, 0.0585796685, 0.528523907 , 0.4212992395,
#  0.8064657524, 0.2081509804, 0.1492170041, 0.0586840123, 0.6381376407,
#  0.7175421339, 0.7259671078, 0.0347409726, 0.8317209152, 0.1893140181,
#  0.5873066532, 0.6508822385, 0.1541344136, 0.9950538172, 0.0392803271]
#
# Optimal Parameters:
# [-1.4018493450e+00,  2.9492174876e+00,  1.0922639818e-03,
#  -1.6993675959e+00,  1.8790767860e-01, -5.2876097325e-02,
#  -1.0673702703e-02,  1.5706522411e+00,  1.5748770911e+00,
#   1.6102129051e+00, -4.8140116435e-01,  2.5851145096e+00,
#   3.4710665799e-01,  8.4066550863e-01, -9.9098879799e-02,
#   2.2017306804e+00,  4.3003562730e-03, -6.5986663930e-01,
#   2.1000223571e-01,  1.5681659966e+00,  1.5252441009e+00,
#   5.8015601442e-01,  1.6573172215e-02,  8.3509806177e-01,
#   1.5041998340e+00,  5.5003893384e-01, -2.6915583910e-02,
#  -2.9372064710e-02,  1.5796115058e+00,  3.9346379309e-01]
# ====================================================================================================
#
# Report saved to:
# /Users/sungwonyun/Documents/Qiskit/Minimum Error Discrimination/Simulator Seed 150 ReRe /TT_QNN_report.txt
