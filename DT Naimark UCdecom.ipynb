# %%
# 0,1: 00 for psi_1, 01 for psi_2 ...
# 2,3: For states
# 4,5: Ancillary qubits

# %%
from qiskit import QuantumCircuit
from numpy import sqrt

def circuit_init():
    qc = QuantumCircuit(6)
    return qc

def PREP(qc):
    desired_vector = [
        1/sqrt(3), 0, 0, 0, 
        1/(4*sqrt(3)), 1/4, 1/4, sqrt(3)/4, 
        1/(4*sqrt(3)), -1/4, -1/4, sqrt(3)/4, 
        0, 0, 0, 0
    ]
    qc.initialize(desired_vector, [3,2,1,0])
    return qc

# %%
from qiskit.circuit.library.standard_gates import RXGate,RYGate, RZGate
from qiskit.circuit.library import U3Gate
from qiskit.circuit.library import MCXGate
from qiskit.circuit.library.standard_gates import XGate
from pennylane.templates.state_preparations.mottonen import compute_theta, gray_code
from numpy import array, log2


def UU(qc, wires, params):
    qc.append(U3Gate(params[0],params[1],params[2]),[wires[0]])
    qc.append(U3Gate(params[3],params[4],params[5]),[wires[1]])


def RR_Z(qc, wires, params):
    qc.append(RZGate(params[0]),[wires[0]])
    qc.append(RZGate(params[1]),[wires[1]])

def CUU(qc,wires, params, state='1'):
    qc.append(U3Gate(params[0],params[1],params[2]).control(1,ctrl_state = state[::-1]), [wires[0], wires[1]])  # Control: wires[0] Target: wires[1]
    qc.append(U3Gate(params[3],params[4],params[5]).control(1,ctrl_state = state[::-1]), [wires[0], wires[2]])  # Control: wires[0] Target: wires[2]
    return qc

def CRR_Z(qc,wires, params, state='1'):
    qc.append(RZGate(params[0]).control(1,ctrl_state = state[::-1]), [wires[0], wires[1]])  # Control: wires[0] Target: wires[1]
    qc.append(RZGate(params[1]).control(1,ctrl_state = state[::-1]), [wires[0], wires[2]])  # Control: wires[0] Target: wires[2]
    return qc

def CR_Y(qc, wires, params, state = '1'):
    qc.append(RYGate(params[0]).control(1,ctrl_state = state[::-1]), [wires[0], wires[1]])  # Control: wires[0] Target: wires[1]


def CCUU(qc,wires, params, state='11'):
    qc.append(U3Gate(params[0],params[1],params[2]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[2]])  # Control: wires[0] wires[1]
    qc.append(U3Gate(params[3],params[4],params[5]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[3]])  # Control: wires[0] wires[1]

def CCRR_Z(qc, wires, params, state = '11'):
    qc.append(RZGate(params[0]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[2]])  # Control: wires[0] wires[1]
    qc.append(RZGate(params[1]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[3]])  # Control: wires[0] wires[1]
    return qc
    

def CCR_Y(qc, wires, params, state = '11'):
    qc.append(RYGate(params[0]).control(2, ctrl_state = state[::-1]), [wires[0], wires[1],wires[2]])  # Control: wires[0] wires[1]
    return qc

def U_CCR_decom(qc,wires,params):
    # Make sure that control qubits should be increasing order
    params = array(params)
    params = compute_theta(params) #can be on/off

    num_Ucontrols = len(wires)-1
    code = gray_code(2)
    n_selections = len(code)
    control_order = [int(log2(int(code[i], 2) ^ int(code[(i + 1) % n_selections], 2))) for i in range(n_selections)]

    for i in range(n_selections):
        qc.ry(params[i],wires[2])
        qc.cx(wires[num_Ucontrols-1 - control_order[i]],wires[2])
    
    return qc

def U_CCcR_decom(qc,wires,params):
    # Make sure that control qubits should be increasing order
    params = array(params)
    params = compute_theta(params) #can be on/off

    num_Ucontrols = len(wires)-2
    code = gray_code(2)
    n_selections = len(code)
    control_order = [int(log2(int(code[i], 2) ^ int(code[(i + 1) % n_selections], 2))) for i in range(n_selections)]

    for i in range(n_selections):
        qc.cry(params[i],wires[2],wires[3])
        CCX(qc,[wires[num_Ucontrols-1 - control_order[i]],wires[2],wires[3]],'11')
    
    return qc

def CCX(qc, wires, state = '11'):
    mcx_gate = MCXGate(num_ctrl_qubits=2,ctrl_state=state[::-1])
    qc.append(mcx_gate, [wires[0], wires[1],wires[2]])
    return qc

def CCCX(qc, wires, state = '111'):
    mcx_gate = MCXGate(num_ctrl_qubits=3,ctrl_state=state[::-1])
    qc.append(mcx_gate, [wires[0], wires[1],wires[2], wires[3]])
    return qc

def CX01(qc, wires):
    qc.append(XGate().control(1, ctrl_state='1'),[wires[0], wires[1]])
    return qc

# %%
from qiskit.circuit.library.standard_gates import RYGate

from numpy import pi 
def Ansatz(qc, wires, params):


    UU(qc,wires[0:2],params[0:6])
    qc.cx(wires[1],wires[0])
    RR_Z(qc,wires[0:2],params[6:8])
    qc.cx(wires[0],wires[1])
    qc.ry(params[8],wires[1])
    qc.cx(wires[1],wires[0])
    UU(qc,wires[0:2],params[9:15])

    qc.barrier()
    #Module 1
    U_CCR_decom(qc,wires[0:3],params[15:19])

    CUU(qc,[wires[2],wires[0],wires[1]],params[19:25],'0')
    CCX(qc,[wires[1],wires[2], wires[0]],'10')
    CRR_Z(qc,[wires[2],wires[0],wires[1]],params[25:27],'0')
    CCX(qc,[wires[0],wires[2], wires[1]],'10')
    CR_Y(qc,[wires[2], wires[1]],[params[27]],'0')
    CCX(qc,[wires[1],wires[2], wires[0]],'10')
    CUU(qc,[wires[2],wires[0],wires[1]],params[28:34],'0')
    
    CUU(qc,[wires[2],wires[0],wires[1]],params[34:40],'1')
    CCX(qc,[wires[1],wires[2], wires[0]],'11')
    CRR_Z(qc,[wires[2],wires[0],wires[1]],params[40:42],'1')
    CCX(qc,[wires[0],wires[2], wires[1]],'11')
    CR_Y(qc,[wires[2], wires[1]],[params[42]],'1')
    CCX(qc,[wires[1],wires[2], wires[0]],'11')
    CUU(qc,[wires[2],wires[0],wires[1]],params[43:49],'1')

    qc.barrier()
    #Module 2
    U_CCcR_decom(qc, wires[0:4],params[49:53])
    CCUU(qc,[wires[2],wires[3],wires[0],wires[1]],params[53:59],'10')
    CCCX(qc,[wires[1],wires[2],wires[3],wires[0]],'110')
    CCRR_Z(qc,[wires[2],wires[3],wires[0],wires[1]], params[59:61], '10')
    CCCX(qc,[wires[0],wires[2],wires[3],wires[1]],'110')
    CCR_Y(qc,[wires[2],wires[3],wires[1]],[params[61]],'10')
    CCCX(qc,[wires[1],wires[2],wires[3],wires[0]],'110')
    CCUU(qc,[wires[2],wires[3],wires[0],wires[1]],params[62:68],'10')
    
    CCUU(qc,[wires[2],wires[3],wires[0],wires[1]],params[68:74],'11')
    CCCX(qc,[wires[1],wires[2],wires[3],wires[0]],'111')
    CCRR_Z(qc,[wires[2],wires[3],wires[0],wires[1]], params[74:76], '11')
    CCCX(qc,[wires[0],wires[2],wires[3],wires[1]],'111')
    CCR_Y(qc,[wires[2],wires[3],wires[1]],[params[76]],'11')
    CCCX(qc,[wires[1],wires[2],wires[3],wires[0]],'111')
    CCUU(qc,[wires[2],wires[3],wires[0],wires[1]],params[77:83],'11')
    
    CX01(qc, [wires[3],wires[2]])
    qc.measure_all()
    return qc

# %%
from numpy.random import rand
num_params=83
params = list(range(num_params))
qc = QuantumCircuit(4)
#PREP(qc)
Ansatz(qc, [0,1,2,3] , params)
qc.draw(output='mpl', style = 'clifford')

# %%
from qiskit_aer import AerSimulator
from qiskit import transpile
from scipy.optimize import minimize

import numpy as np
import os
import time


# ============================================================
# Simulator
# ============================================================

aersim = AerSimulator()


# ============================================================
# Settings
# ============================================================

num_times = 30
num_shots = 10000

optimizer_name = "COBYLA"
tol_value = 1e-8
maxiter = 2000

BASE_SEED = 150

report_filename = (
    "DT_Nymark_report.txt"
)


# ============================================================
# High-Shot Evaluation Settings
# ============================================================

evaluation_num_times = 20
evaluation_num_shots = 100000

EVALUATION_BASE_SEED = 10000

evaluation_seeds = np.array(
    [
        EVALUATION_BASE_SEED + i
        for i in range(evaluation_num_times)
    ],
    dtype=int
)


# ============================================================
# Storage
# ============================================================

final_optimized_values = []

initial_params_all_runs = []
optimal_params_all_runs = []

optimization_success_all_runs = []
optimization_status_all_runs = []
optimization_message_all_runs = []
optimization_nfev_all_runs = []
reached_maxiter_all_runs = []

# ------------------------------------------------------------
# Runtime Storage
# ------------------------------------------------------------

optimization_wall_times = []


# ------------------------------------------------------------
# High-Shot Evaluation Storage
# ------------------------------------------------------------

evaluation_values_all_runs = []

evaluation_mean_all_runs = []
evaluation_std_all_runs = []
evaluation_min_all_runs = []
evaluation_max_all_runs = []


# ============================================================
# Objective Function
# ============================================================

def objective_function(
    params,
    run_seed,
    shots=None,
    print_result=True
):

    if shots is None:
        shots = num_shots


    # --------------------------------------------------------
    # Construct circuit
    # --------------------------------------------------------

    qc = circuit_init()

    PREP(qc)

    Ansatz(
        qc,
        [2, 3, 4, 5],
        params
    )


    qc_reverse = qc.reverse_bits()


    # --------------------------------------------------------
    # Transpile
    # --------------------------------------------------------

    t_qc = transpile(
        qc_reverse,
        aersim,
        seed_transpiler=run_seed
    )


    # --------------------------------------------------------
    # Run simulation
    # --------------------------------------------------------

    job = aersim.run(
        t_qc,
        shots=shots,
        seed_simulator=run_seed
    )


    result = job.result()

    counts = result.get_counts()


    # --------------------------------------------------------
    # Target counts
    # --------------------------------------------------------

    tar_00 = 0
    tar_01 = 0
    tar_10 = 0


    for outcome, count in counts.items():

        if outcome[0:2] == "00":

            if outcome[4:6] == "00":

                tar_00 += count


        if outcome[0:2] == "01":

            if outcome[4:6] == "01":

                tar_01 += count


        if outcome[0:2] == "10":

            if outcome[4:6] == "10":

                tar_10 += count


    # --------------------------------------------------------
    # Success probability
    # --------------------------------------------------------

    p_suc = (
        tar_00
        + tar_01
        + tar_10
    ) / shots


    if print_result:

        print(
            f"success_probability = "
            f"{p_suc:.8f}"
        )


    # --------------------------------------------------------
    # Avoid division by zero
    # --------------------------------------------------------

    if p_suc == 0:

        return 1e10


    # --------------------------------------------------------
    # COBYLA minimizes.
    #
    # Minimizing 1 / p_suc maximizes p_suc.
    # --------------------------------------------------------

    return 1.0 / p_suc


# ============================================================
# Run Optimization
# ============================================================

# Total wall-clock timer for the complete workflow
total_wall_start = time.perf_counter()

for run in range(num_times):


    # ========================================================
    # Optimization Seed
    # ========================================================

    run_seed = (
        BASE_SEED + run
    )


    rng = np.random.default_rng(
        run_seed
    )


    print(
        "\n"
        + "=" * 80
    )


    print(
        f"Optimization Run "
        f"{run + 1}/{num_times}"
    )


    print(
        f"Optimization Seed : "
        f"{run_seed}"
    )


    print(
        "=" * 80
    )


    # ========================================================
    # Generate Random Initial Parameters
    # ========================================================

    initial_params = rng.random(
        num_params
    )


    initial_params_all_runs.append(
        initial_params.copy()
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    # ========================================================
    # Run COBYLA Optimization
    # ========================================================

    print(
        "\nStarting COBYLA optimization..."
    )


    optimization_start = time.perf_counter()

    result = minimize(

        fun=lambda params: objective_function(
            params,
            run_seed,
            shots=num_shots,
            print_result=True
        ),

        x0=initial_params,

        method=optimizer_name,

        options={
            "maxiter": maxiter,
            "disp": True,
            "tol": tol_value
        }
    )

    optimization_end = time.perf_counter()

    run_optimization_wall_time = (
        optimization_end
        - optimization_start
    )

    optimization_wall_times.append(
        run_optimization_wall_time
    )

    print(
        f"Optimization Wall-Clock Time : "
        f"{run_optimization_wall_time:.6f} s"
    )


    # ========================================================
    # Optimization Status
    # ========================================================

    optimization_success = bool(
        result.success
    )


    optimization_status = getattr(
        result,
        "status",
        None
    )


    optimization_message = str(
        getattr(
            result,
            "message",
            "No message returned"
        )
    )


    optimization_nfev = getattr(
        result,
        "nfev",
        None
    )


    # ========================================================
    # Detect Maximum Function Evaluations
    # ========================================================

    message_lower = (
        optimization_message.lower()
    )


    reached_maxiter = (

        "maximum number"
        in message_lower

        or "maximum function"
        in message_lower

        or "maxiter"
        in message_lower

        or "maxfun"
        in message_lower

        or "maximum iterations"
        in message_lower

        or "maximum evaluations"
        in message_lower
    )


    if optimization_nfev is not None:

        if optimization_nfev >= maxiter:

            reached_maxiter = True


    # ========================================================
    # Store Optimization Status
    # ========================================================

    optimization_success_all_runs.append(
        optimization_success
    )


    optimization_status_all_runs.append(
        optimization_status
    )


    optimization_message_all_runs.append(
        optimization_message
    )


    optimization_nfev_all_runs.append(
        optimization_nfev
    )


    reached_maxiter_all_runs.append(
        reached_maxiter
    )


    # ========================================================
    # Optimal Parameters
    # ========================================================

    optimal_params = (
        result.x.copy()
    )


    optimal_params_all_runs.append(
        optimal_params.copy()
    )


    # ========================================================
    # Final Optimization-Shot Evaluation
    # ========================================================

    final_objective = objective_function(
        optimal_params,
        run_seed,
        shots=num_shots,
        print_result=False
    )


    if final_objective >= 1e10:

        final_value = 0.0

    else:

        final_value = (
            1.0 / final_objective
        )


    final_optimized_values.append(
        final_value
    )


    # ========================================================
    # High-Shot Evaluation
    # ========================================================

    print(
        "\n"
        + "-" * 80
    )


    print(
        "HIGH-SHOT EVALUATION OF "
        "OPTIMIZED PARAMETERS"
    )


    print(
        "-" * 80
    )


    print(
        f"Optimization Shots     : "
        f"{num_shots}"
    )


    print(
        f"Evaluation Shots       : "
        f"{evaluation_num_shots}"
    )


    print(
        f"Number of Evaluations : "
        f"{evaluation_num_times}"
    )


    print(
        "\nEvaluation Results:"
    )


    evaluation_values = []


    for eval_index, eval_seed in enumerate(
        evaluation_seeds
    ):


        eval_objective = objective_function(
            optimal_params,
            int(eval_seed),
            shots=evaluation_num_shots,
            print_result=False
        )


        if eval_objective >= 1e10:

            eval_value = 0.0

        else:

            eval_value = (
                1.0 / eval_objective
            )


        evaluation_values.append(
            eval_value
        )


        print(
            f"Evaluation "
            f"{eval_index + 1:2d}/"
            f"{evaluation_num_times:2d}"
            f" | Value = "
            f"{eval_value:.8f}"
        )


    # ========================================================
    # Evaluation Statistics
    # ========================================================

    evaluation_values = np.array(
        evaluation_values,
        dtype=float
    )


    evaluation_mean = np.mean(
        evaluation_values
    )


    evaluation_std = np.std(
        evaluation_values
    )


    evaluation_min = np.min(
        evaluation_values
    )


    evaluation_max = np.max(
        evaluation_values
    )


    # ========================================================
    # Store Evaluation Results
    # ========================================================

    evaluation_values_all_runs.append(
        evaluation_values.copy()
    )


    evaluation_mean_all_runs.append(
        evaluation_mean
    )


    evaluation_std_all_runs.append(
        evaluation_std
    )


    evaluation_min_all_runs.append(
        evaluation_min
    )


    evaluation_max_all_runs.append(
        evaluation_max
    )


    # ========================================================
    # Individual Run Report
    # ========================================================

    print(
        "\n"
        + "=" * 80
    )


    print(
        f"RUN {run + 1} RESULT"
    )


    print(
        "=" * 80
    )


    print(
        f"Optimization Success : "
        f"{optimization_success}"
    )


    print(
        f"Reached MaxIter      : "
        f"{reached_maxiter}"
    )


    print(
        f"Status               : "
        f"{optimization_status}"
    )


    print(
        f"Message              : "
        f"{optimization_message}"
    )


    print(
        f"Function Evaluations : "
        f"{optimization_nfev}"
    )


    print(
        f"Optimization Time    : "
        f"{run_optimization_wall_time:.6f} s"
    )


    print(
        f"Final Objective Value: "
        f"{result.fun}"
    )


    print(
        "\n"
        + "-" * 80
    )


    print(
        "OPTIMIZED AND HIGH-SHOT "
        "EVALUATED VALUES"
    )


    print(
        "-" * 80
    )


    print(
        f"Final Optimized Value : "
        f"{final_value:.8f}"
    )


    print(
        f"Evaluated Mean        : "
        f"{evaluation_mean:.8f}"
    )


    print(
        f"Evaluated Std         : "
        f"{evaluation_std:.8f}"
    )


    print(
        f"Evaluated Min         : "
        f"{evaluation_min:.8f}"
    )


    print(
        f"Evaluated Max         : "
        f"{evaluation_max:.8f}"
    )


    print(
        "\nAll Evaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values,
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params,
            precision=10,
            separator=", "
        )
    )


    print(
        "=" * 80
    )


# ============================================================
# Runtime Statistics
# ============================================================

total_wall_end = time.perf_counter()

total_wall_time = (
    total_wall_end
    - total_wall_start
)

optimization_wall_times = np.array(
    optimization_wall_times,
    dtype=float
)

total_optimization_wall_time = np.sum(
    optimization_wall_times
)

mean_optimization_wall_time = np.mean(
    optimization_wall_times
)

std_optimization_wall_time = np.std(
    optimization_wall_times
)


# ============================================================
# Convert Results to NumPy Arrays
# ============================================================

final_optimized_values = np.array(
    final_optimized_values,
    dtype=float
)


initial_params_all_runs = np.array(
    initial_params_all_runs
)


optimal_params_all_runs = np.array(
    optimal_params_all_runs
)


evaluation_values_all_runs = np.array(
    evaluation_values_all_runs,
    dtype=float
)


evaluation_mean_all_runs = np.array(
    evaluation_mean_all_runs,
    dtype=float
)


evaluation_std_all_runs = np.array(
    evaluation_std_all_runs,
    dtype=float
)


evaluation_min_all_runs = np.array(
    evaluation_min_all_runs,
    dtype=float
)


evaluation_max_all_runs = np.array(
    evaluation_max_all_runs,
    dtype=float
)


# ============================================================
# Original Optimization Statistics
# ============================================================

maximum_value = np.max(
    final_optimized_values
)


mean_value = np.mean(
    final_optimized_values
)


std_value = np.std(
    final_optimized_values
)


maximum_run_index = np.argmax(
    final_optimized_values
)


maximum_run = (
    maximum_run_index + 1
)


# ============================================================
# High-Shot Evaluation Statistics
# ============================================================

maximum_evaluated_mean = np.max(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run_index = np.argmax(
    evaluation_mean_all_runs
)


maximum_evaluated_mean_run = (
    maximum_evaluated_mean_run_index
    + 1
)


mean_of_evaluated_means = np.mean(
    evaluation_mean_all_runs
)


std_of_evaluated_means = np.std(
    evaluation_mean_all_runs
)


# ============================================================
# Function Evaluation Statistics
# ============================================================

nfev_values = np.array(
    [
        nfev
        for nfev
        in optimization_nfev_all_runs
        if nfev is not None
    ],
    dtype=float
)


if len(nfev_values) > 0:

    mean_nfev = np.mean(
        nfev_values
    )


    std_nfev = np.std(
        nfev_values
    )

else:

    mean_nfev = np.nan
    std_nfev = np.nan


# ============================================================
# Optimization Success Statistics
# ============================================================

num_successful_runs = sum(
    optimization_success_all_runs
)


num_failed_runs = (
    num_times
    - num_successful_runs
)


num_reached_maxiter = sum(
    reached_maxiter_all_runs
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

best_initial_params = (
    initial_params_all_runs[
        maximum_run_index
    ]
)


best_optimal_params = (
    optimal_params_all_runs[
        maximum_run_index
    ]
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

best_evaluated_initial_params = (
    initial_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_optimal_params = (
    optimal_params_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


best_evaluated_values = (
    evaluation_values_all_runs[
        maximum_evaluated_mean_run_index
    ]
)


# ============================================================
# Print Final Report
# ============================================================

print("\n")


print(
    "=" * 100
)


print(
    "FINAL OPTIMIZATION AND "
    "HIGH-SHOT EVALUATION REPORT"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Settings
# ------------------------------------------------------------

print(
    f"Optimizer               : "
    f"{optimizer_name}"
)


print(
    f"Tolerance               : "
    f"{tol_value}"
)


print(
    f"Max Iteration           : "
    f"{maxiter}"
)


print(
    f"Number of Runs          : "
    f"{num_times}"
)


print(
    f"Optimization Shots      : "
    f"{num_shots}"
)


print(
    f"Optimization Base Seed  : "
    f"{BASE_SEED}"
)


print(
    f"Evaluation Shots        : "
    f"{evaluation_num_shots}"
)


print(
    f"Evaluations Per Run     : "
    f"{evaluation_num_times}"
)


print(
    f"Evaluation Base Seed    : "
    f"{EVALUATION_BASE_SEED}"
)


# Evaluation seeds are printed only once.
print(
    "Evaluation Seeds        : "
    + np.array2string(
        evaluation_seeds,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Results for Every Run
# ============================================================

for i in range(num_times):


    print(
        f"\nRun {i + 1:2d}"
    )


    print(
        "-" * 100
    )


    print(
        f"Optimization Seed : "
        f"{BASE_SEED + i}"
    )


    print(
        f"Optimized Value   : "
        f"{final_optimized_values[i]:.8f}"
    )


    print(
        f"Evaluated Mean    : "
        f"{evaluation_mean_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Std     : "
        f"{evaluation_std_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Min     : "
        f"{evaluation_min_all_runs[i]:.8f}"
    )


    print(
        f"Evaluated Max     : "
        f"{evaluation_max_all_runs[i]:.8f}"
    )


    print(
        f"Success           : "
        f"{optimization_success_all_runs[i]}"
    )


    print(
        f"Reached MaxIter   : "
        f"{reached_maxiter_all_runs[i]}"
    )


    print(
        f"Status            : "
        f"{optimization_status_all_runs[i]}"
    )


    print(
        f"Message           : "
        f"{optimization_message_all_runs[i]}"
    )


    print(
        f"Function Evals    : "
        f"{optimization_nfev_all_runs[i]}"
    )


    print(
        "\nEvaluated Values:"
    )


    print(
        np.array2string(
            evaluation_values_all_runs[i],
            precision=8,
            separator=", "
        )
    )


    print(
        "\nInitial Parameters:"
    )


    print(
        np.array2string(
            initial_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "\nOptimal Parameters:"
    )


    print(
        np.array2string(
            optimal_params_all_runs[i],
            precision=10,
            separator=", "
        )
    )


    print(
        "-" * 100
    )


# ============================================================
# Summary
# ============================================================

print(
    "\nSUMMARY"
)


print(
    "=" * 100
)


# ------------------------------------------------------------
# Original Optimization Results
# ------------------------------------------------------------

print(
    "\nOriginal Optimization-Shot Results:"
)


print(
    f"Maximum Optimized Value : "
    f"{maximum_value:.8f}"
)


print(
    f"Maximum Run             : "
    f"{maximum_run}"
)


print(
    f"Mean Optimized Value    : "
    f"{mean_value:.8f}"
)


print(
    f"Std Optimized Value     : "
    f"{std_value:.8f}"
)


# ------------------------------------------------------------
# High-Shot Evaluation Results
# ------------------------------------------------------------

print(
    "\nHigh-Shot Evaluation Results:"
)


print(
    f"Best Evaluated Mean     : "
    f"{maximum_evaluated_mean:.8f}"
)


print(
    f"Best Evaluated Mean Run : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Mean of Evaluated Means : "
    f"{mean_of_evaluated_means:.8f}"
)


print(
    f"Std of Evaluated Means  : "
    f"{std_of_evaluated_means:.8f}"
)


# ------------------------------------------------------------
# Optimizer Statistics
# ------------------------------------------------------------

print(
    "\nOptimizer Statistics:"
)


print(
    f"Mean Function Evals     : "
    f"{mean_nfev:.2f}"
)


print(
    f"Std Function Evals      : "
    f"{std_nfev:.2f}"
)


print(
    f"Successful Runs         : "
    f"{num_successful_runs}/"
    f"{num_times}"
)


print(
    f"Failed Runs             : "
    f"{num_failed_runs}/"
    f"{num_times}"
)


print(
    f"Reached MaxIter         : "
    f"{num_reached_maxiter}/"
    f"{num_times}"
)


# ------------------------------------------------------------
# Computational Runtime Statistics
# ------------------------------------------------------------

print(
    "\nComputational Runtime Statistics:"
)

print(
    f"Total Wall-Clock Time          : "
    f"{total_wall_time:.6f} s"
)

print(
    f"Total Optimization Time        : "
    f"{total_optimization_wall_time:.6f} s"
)

print(
    f"Time per Complete Opt. Run     : "
    f"{mean_optimization_wall_time:.6f} s"
)

print(
    f"Std Optimization Time per Run  : "
    f"{std_optimization_wall_time:.6f} s"
)


# ============================================================
# Best Run According to Original Optimized Value
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "ORIGINAL OPTIMIZED VALUE"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        evaluation_values_all_runs[
            maximum_run_index
        ],
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_optimal_params,
        precision=10,
        separator=", "
    )
)


# ============================================================
# Best Run According to High-Shot Evaluated Mean
# ============================================================

print(
    "\n"
    + "=" * 100
)


print(
    "BEST RUN ACCORDING TO "
    "HIGH-SHOT EVALUATED MEAN"
)


print(
    "=" * 100
)


print(
    f"Run             : "
    f"{maximum_evaluated_mean_run}"
)


print(
    f"Optimized Value : "
    f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Mean  : "
    f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Std   : "
    f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Min   : "
    f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    f"Evaluated Max   : "
    f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}"
)


print(
    "\nEvaluated Values:"
)


print(
    np.array2string(
        best_evaluated_values,
        precision=8,
        separator=", "
    )
)


print(
    "\nInitial Parameters:"
)


print(
    np.array2string(
        best_evaluated_initial_params,
        precision=10,
        separator=", "
    )
)


print(
    "\nOptimal Parameters:"
)


print(
    np.array2string(
        best_evaluated_optimal_params,
        precision=10,
        separator=", "
    )
)


print(
    "=" * 100
)


# ============================================================
# Save Report to TXT
# ============================================================

with open(
    report_filename,
    "w"
) as f:


    # ========================================================
    # Header
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "FINAL OPTIMIZATION AND "
        "HIGH-SHOT EVALUATION REPORT\n"
    )


    f.write(
        "=" * 100
        + "\n\n"
    )


    # ========================================================
    # Settings
    # ========================================================

    f.write(
        f"Optimizer               : "
        f"{optimizer_name}\n"
    )


    f.write(
        f"Tolerance               : "
        f"{tol_value}\n"
    )


    f.write(
        f"Max Iteration           : "
        f"{maxiter}\n"
    )


    f.write(
        f"Number of Runs          : "
        f"{num_times}\n"
    )


    f.write(
        f"Optimization Shots      : "
        f"{num_shots}\n"
    )


    f.write(
        f"Optimization Base Seed  : "
        f"{BASE_SEED}\n"
    )


    f.write(
        f"Evaluation Shots        : "
        f"{evaluation_num_shots}\n"
    )


    f.write(
        f"Evaluations Per Run     : "
        f"{evaluation_num_times}\n"
    )


    f.write(
        f"Evaluation Base Seed    : "
        f"{EVALUATION_BASE_SEED}\n"
    )


    # Evaluation seeds are saved only once.
    f.write(
        "Evaluation Seeds        : "
    )


    f.write(
        np.array2string(
            evaluation_seeds,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    # ========================================================
    # Results for Every Run
    # ========================================================

    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "RESULTS FOR EACH RUN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    for i in range(num_times):


        f.write(
            f"\nRun {i + 1:2d}\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


        f.write(
            f"Optimization Seed : "
            f"{BASE_SEED + i}\n"
        )


        f.write(
            f"Optimized Value   : "
            f"{final_optimized_values[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Mean    : "
            f"{evaluation_mean_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Std     : "
            f"{evaluation_std_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Min     : "
            f"{evaluation_min_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Evaluated Max     : "
            f"{evaluation_max_all_runs[i]:.8f}\n"
        )


        f.write(
            f"Success           : "
            f"{optimization_success_all_runs[i]}\n"
        )


        f.write(
            f"Reached MaxIter   : "
            f"{reached_maxiter_all_runs[i]}\n"
        )


        f.write(
            f"Status            : "
            f"{optimization_status_all_runs[i]}\n"
        )


        f.write(
            f"Message           : "
            f"{optimization_message_all_runs[i]}\n"
        )


        f.write(
            f"Function Evals    : "
            f"{optimization_nfev_all_runs[i]}\n"
        )


        f.write(
            f"Optimization Time : "
            f"{optimization_wall_times[i]:.6f} s\n"
        )


        f.write(
            "\nEvaluated Values:\n"
        )


        f.write(
            np.array2string(
                evaluation_values_all_runs[i],
                precision=8,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nInitial Parameters:\n"
        )


        f.write(
            np.array2string(
                initial_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "\nOptimal Parameters:\n"
        )


        f.write(
            np.array2string(
                optimal_params_all_runs[i],
                precision=10,
                separator=", "
            )
        )


        f.write(
            "\n"
        )


        f.write(
            "-" * 100
            + "\n"
        )


    # ========================================================
    # Summary
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "SUMMARY\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    # --------------------------------------------------------
    # Original Optimization Results
    # --------------------------------------------------------

    f.write(
        "\nOriginal Optimization-Shot Results:\n"
    )


    f.write(
        f"Maximum Optimized Value : "
        f"{maximum_value:.8f}\n"
    )


    f.write(
        f"Maximum Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Mean Optimized Value    : "
        f"{mean_value:.8f}\n"
    )


    f.write(
        f"Std Optimized Value     : "
        f"{std_value:.8f}\n"
    )


    # --------------------------------------------------------
    # High-Shot Evaluation Results
    # --------------------------------------------------------

    f.write(
        "\nHigh-Shot Evaluation Results:\n"
    )


    f.write(
        f"Best Evaluated Mean     : "
        f"{maximum_evaluated_mean:.8f}\n"
    )


    f.write(
        f"Best Evaluated Mean Run : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Mean of Evaluated Means : "
        f"{mean_of_evaluated_means:.8f}\n"
    )


    f.write(
        f"Std of Evaluated Means  : "
        f"{std_of_evaluated_means:.8f}\n"
    )


    # --------------------------------------------------------
    # Optimizer Statistics
    # --------------------------------------------------------

    f.write(
        "\nOptimizer Statistics:\n"
    )


    f.write(
        f"Mean Function Evals     : "
        f"{mean_nfev:.2f}\n"
    )


    f.write(
        f"Std Function Evals      : "
        f"{std_nfev:.2f}\n"
    )


    f.write(
        f"Successful Runs         : "
        f"{num_successful_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Failed Runs             : "
        f"{num_failed_runs}/"
        f"{num_times}\n"
    )


    f.write(
        f"Reached MaxIter         : "
        f"{num_reached_maxiter}/"
        f"{num_times}\n"
    )


    # --------------------------------------------------------
    # Computational Runtime Statistics
    # --------------------------------------------------------

    f.write(
        "\nComputational Runtime Statistics:\n"
    )

    f.write(
        f"Total Wall-Clock Time          : "
        f"{total_wall_time:.6f} s\n"
    )

    f.write(
        f"Total Optimization Time        : "
        f"{total_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Time per Complete Opt. Run     : "
        f"{mean_optimization_wall_time:.6f} s\n"
    )

    f.write(
        f"Std Optimization Time per Run  : "
        f"{std_optimization_wall_time:.6f} s\n"
    )


    # ========================================================
    # Best Run According to Original Optimized Value
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "ORIGINAL OPTIMIZED VALUE\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            evaluation_values_all_runs[
                maximum_run_index
            ],
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    # ========================================================
    # Best Run According to High-Shot Evaluated Mean
    # ========================================================

    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        "BEST RUN ACCORDING TO "
        "HIGH-SHOT EVALUATED MEAN\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


    f.write(
        f"Run             : "
        f"{maximum_evaluated_mean_run}\n"
    )


    f.write(
        f"Optimized Value : "
        f"{final_optimized_values[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Mean  : "
        f"{evaluation_mean_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Std   : "
        f"{evaluation_std_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Min   : "
        f"{evaluation_min_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        f"Evaluated Max   : "
        f"{evaluation_max_all_runs[maximum_evaluated_mean_run_index]:.8f}\n"
    )


    f.write(
        "\nEvaluated Values:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_values,
            precision=8,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "\nInitial Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_initial_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n\n"
    )


    f.write(
        "Optimal Parameters:\n"
    )


    f.write(
        np.array2string(
            best_evaluated_optimal_params,
            precision=10,
            separator=", "
        )
    )


    f.write(
        "\n"
    )


    f.write(
        "=" * 100
        + "\n"
    )


# ============================================================
# Report Location
# ============================================================

print(
    "\nReport saved to:"
)


print(
    os.path.abspath(
        report_filename
    )
)
# Out:
# ================================================================================
# Optimization Run 1/30
# Optimization Seed : 150
# ================================================================================
#
# Initial Parameters:
# [0.0048220441, 0.9307870177, 0.784582211 , 0.3343249593, 0.6862689177,
#  0.7322625609, 0.8246472415, 0.1074544391, 0.3089916869, 0.3129434404,
#  0.5940727125, 0.6105506387, 0.9165420506, 0.7388171743, 0.3774708002,
#  0.7949533184, 0.4869354822, 0.5788914075, 0.9744748566, 0.6883896757,
#  0.5848087428, 0.2739643248, 0.8377858251, 0.3022293541, 0.1728462164,
#  0.8017433668, 0.3441099205, 0.4375847094, 0.152681156 , 0.2761357842,
#  0.5638672039, 0.8646746614, 0.0827886029, 0.9748236223, 0.9228236344,
#  0.4073736921, 0.7807688858, 0.6465955762, 0.2254609107, 0.8244806881,
#  0.3453562772, 0.5685671364, 0.6863696968, 0.2470087963, 0.8753744063,
#  0.1559330851, 0.6952022537, 0.165220456 , 0.4809662579, 0.5220324731,
#  0.574713288 , 0.8415277736, 0.4884155772, 0.9164990051, 0.1245572572,
#  0.4537852901, 0.9589130366, 0.6706482599, 0.7928513073, 0.7638068903,
#  0.4694302963, 0.2684748849, 0.4532232777, 0.2527348132, 0.9472151713,
#  0.0497407763, 0.4375196366, 0.7683879889, 0.1666323995, 0.8244444092,
#  0.8696022625, 0.4459329328, 0.1604106422, 0.4198495714, 0.4522866548,
#  0.8544544785, 0.7439885668, 0.0297657672, 0.1861739127, 0.7383720961,
#  0.8817988526, 0.653643534 , 0.2525396458]
#
# Starting COBYLA optimization...
# success_probability = 0.32080000
# success_probability = 0.32090000
# success_probability = 0.32660000
# success_probability = 0.33340000
# success_probability = 0.32120000
# success_probability = 0.34090000
# success_probability = 0.34110000
# success_probability = 0.33870000
# success_probability = 0.33860000
# success_probability = 0.32550000
# success_probability = 0.35080000
# success_probability = 0.35090000
# success_probability = 0.34620000
# success_probability = 0.34210000
# success_probability = 0.35230000
# success_probability = 0.34950000
# success_probability = 0.25200000
# success_probability = 0.36090000
# success_probability = 0.32460000
# success_probability = 0.49190000
# success_probability = 0.49390000
# success_probability = 0.48250000
# success_probability = 0.49240000
# success_probability = 0.49150000
# success_probability = 0.48940000
# success_probability = 0.49220000
# success_probability = 0.48200000
# success_probability = 0.48940000
# success_probability = 0.48730000
# success_probability = 0.49030000
# success_probability = 0.49390000
# success_probability = 0.49340000
# success_probability = 0.49210000
# success_probability = 0.49390000
# success_probability = 0.48830000
# success_probability = 0.48100000
# success_probability = 0.49710000
# success_probability = 0.50340000
# success_probability = 0.50090000
# success_probability = 0.49370000
# success_probability = 0.49850000
# success_probability = 0.48980000
# success_probability = 0.49370000
# success_probability = 0.50240000
# success_probability = 0.49540000
# success_probability = 0.49850000
# success_probability = 0.49790000
# success_probability = 0.49040000
# success_probability = 0.49990000
# success_probability = 0.50210000
# success_probability = 0.50100000
# success_probability = 0.48150000
# success_probability = 0.51750000
# success_probability = 0.47580000
# success_probability = 0.51460000
# success_probability = 0.51700000
# success_probability = 0.51470000
# success_probability = 0.51370000
# success_probability = 0.51700000
# success_probability = 0.51380000
# success_probability = 0.51300000
# success_probability = 0.51700000
# success_probability = 0.51580000
# success_probability = 0.51550000
# success_probability = 0.51750000
# success_probability = 0.51640000
# success_probability = 0.52060000
# success_probability = 0.52060000
# success_probability = 0.51490000
# success_probability = 0.51950000
# success_probability = 0.52220000
# success_probability = 0.52060000
# success_probability = 0.51840000
# success_probability = 0.52350000
# success_probability = 0.52140000
# success_probability = 0.52210000
# success_probability = 0.52360000
# success_probability = 0.52160000
# success_probability = 0.52420000
# success_probability = 0.52420000
# success_probability = 0.52050000
# success_probability = 0.52030000
# success_probability = 0.52420000
# success_probability = 0.52380000
# success_probability = 0.61260000
# success_probability = 0.64350000
# success_probability = 0.59630000
# success_probability = 0.61160000
# success_probability = 0.63450000
# success_probability = 0.60950000
# success_probability = 0.62370000
# success_probability = 0.58650000
# success_probability = 0.63200000
# success_probability = 0.57870000
# success_probability = 0.65070000
# success_probability = 0.53690000
# success_probability = 0.62210000
# success_probability = 0.62370000
# success_probability = 0.64630000
# success_probability = 0.57460000
# success_probability = 0.64930000
# success_probability = 0.61380000
# success_probability = 0.62110000
# success_probability = 0.64230000
# success_probability = 0.64920000
# success_probability = 0.60950000
# success_probability = 0.64950000
# success_probability = 0.64730000
# success_probability = 0.64890000
# success_probability = 0.64670000
# success_probability = 0.65010000
# success_probability = 0.64480000
# success_probability = 0.64860000
# success_probability = 0.64940000
# success_probability = 0.64880000
# success_probability = 0.64350000
# success_probability = 0.64740000
# success_probability = 0.64880000
# success_probability = 0.64840000
# success_probability = 0.64300000
# success_probability = 0.65070000
# success_probability = 0.63470000
# success_probability = 0.64570000
# success_probability = 0.62630000
# success_probability = 0.64950000
# success_probability = 0.62410000
# success_probability = 0.65580000
# success_probability = 0.64930000
# success_probability = 0.65000000
# success_probability = 0.64200000
# success_probability = 0.65530000
# success_probability = 0.65400000
# success_probability = 0.65180000
# success_probability = 0.64520000
# success_probability = 0.64760000
# success_probability = 0.64590000
# success_probability = 0.63530000
# success_probability = 0.58850000
# success_probability = 0.64470000
# success_probability = 0.62650000
# success_probability = 0.65290000
# success_probability = 0.65090000
# success_probability = 0.65410000
# success_probability = 0.65380000
# success_probability = 0.65500000
# success_probability = 0.65220000
# success_probability = 0.65450000
# success_probability = 0.65510000
# success_probability = 0.65380000
# success_probability = 0.65450000
# success_probability = 0.65580000
# success_probability = 0.65500000
# success_probability = 0.65110000
# success_probability = 0.65650000
# success_probability = 0.65650000
# success_probability = 0.65600000
# success_probability = 0.65580000
# success_probability = 0.65570000
# success_probability = 0.65550000
# success_probability = 0.65720000
# success_probability = 0.65630000
# success_probability = 0.65860000
# success_probability = 0.65810000
# success_probability = 0.65570000
# success_probability = 0.65770000
# success_probability = 0.65490000
# success_probability = 0.65720000
# success_probability = 0.64180000
# success_probability = 0.65860000
# success_probability = 0.62930000
# success_probability = 0.62480000
# success_probability = 0.67180000
# success_probability = 0.65550000
# success_probability = 0.54560000
# success_probability = 0.65770000
# success_probability = 0.65970000
# success_probability = 0.64230000
# success_probability = 0.65230000
# success_probability = 0.64950000
# success_probability = 0.65290000
# success_probability = 0.67560000
# success_probability = 0.65140000
# success_probability = 0.67780000
# success_probability = 0.65040000
# success_probability = 0.67580000
# success_probability = 0.64200000
# success_probability = 0.67420000
# success_probability = 0.63500000
# success_probability = 0.67850000
# success_probability = 0.67670000
# success_probability = 0.67900000
# success_probability = 0.67620000
# success_probability = 0.67620000
# success_probability = 0.66030000
# success_probability = 0.67580000
# success_probability = 0.67820000
# success_probability = 0.67860000
# success_probability = 0.68310000
# success_probability = 0.67940000
# success_probability = 0.68100000
# success_probability = 0.68260000
# success_probability = 0.68000000
# success_probability = 0.67710000
# success_probability = 0.57810000
# success_probability = 0.66150000
# success_probability = 0.68970000
# success_probability = 0.71780000
# success_probability = 0.62640000
# success_probability = 0.67520000
# success_probability = 0.68860000
# success_probability = 0.69950000
# success_probability = 0.66080000
# success_probability = 0.70440000
# success_probability = 0.70090000
# success_probability = 0.71390000
# success_probability = 0.72260000
# success_probability = 0.71910000
# success_probability = 0.71950000
# success_probability = 0.69280000
# success_probability = 0.71770000
# success_probability = 0.72140000
# success_probability = 0.71640000
# success_probability = 0.72280000
# success_probability = 0.72170000
# success_probability = 0.72280000
# success_probability = 0.68000000
# success_probability = 0.72090000
# success_probability = 0.70590000
# success_probability = 0.71210000
# success_probability = 0.72750000
# success_probability = 0.72810000
# success_probability = 0.72770000
# success_probability = 0.72830000
# success_probability = 0.72990000
# success_probability = 0.72550000
# success_probability = 0.72780000
# success_probability = 0.72990000
# success_probability = 0.73110000
# success_probability = 0.73170000
# success_probability = 0.72710000
# success_probability = 0.73250000
# success_probability = 0.73190000
# success_probability = 0.73250000
# success_probability = 0.72930000
# success_probability = 0.73240000
# success_probability = 0.71080000
# success_probability = 0.73140000
# success_probability = 0.72140000
# success_probability = 0.73070000
# success_probability = 0.62400000
# success_probability = 0.72920000
# success_probability = 0.64180000
# success_probability = 0.72690000
# success_probability = 0.64760000
# success_probability = 0.72900000
# success_probability = 0.69870000
# success_probability = 0.73160000
# success_probability = 0.72240000
# success_probability = 0.73250000
# success_probability = 0.71140000
# success_probability = 0.71260000
# success_probability = 0.68820000
# success_probability = 0.71170000
# success_probability = 0.67060000
# success_probability = 0.70250000
# success_probability = 0.64870000
# success_probability = 0.70640000
# success_probability = 0.68140000
# success_probability = 0.72930000
# success_probability = 0.72340000
# success_probability = 0.72590000
# success_probability = 0.71090000
# success_probability = 0.72130000
# success_probability = 0.71650000
# success_probability = 0.72560000
# success_probability = 0.72750000
# success_probability = 0.73170000
# success_probability = 0.58640000
# success_probability = 0.72890000
# success_probability = 0.64470000
# success_probability = 0.72090000
# success_probability = 0.72800000
# success_probability = 0.72810000
# success_probability = 0.72770000
# success_probability = 0.73000000
# success_probability = 0.73030000
# success_probability = 0.73150000
# success_probability = 0.72840000
# success_probability = 0.72810000
# success_probability = 0.69150000
# success_probability = 0.71000000
# success_probability = 0.63790000
# success_probability = 0.73830000
# success_probability = 0.70670000
# success_probability = 0.73000000
# success_probability = 0.65100000
# success_probability = 0.73190000
# success_probability = 0.70330000
# success_probability = 0.73880000
# success_probability = 0.69610000
# success_probability = 0.73450000
# success_probability = 0.74770000
# success_probability = 0.74790000
# success_probability = 0.72030000
# success_probability = 0.75340000
# success_probability = 0.75080000
# success_probability = 0.74640000
# success_probability = 0.69690000
# success_probability = 0.74850000
# success_probability = 0.73290000
# success_probability = 0.74480000
# success_probability = 0.74680000
# success_probability = 0.75290000
# success_probability = 0.75320000
# success_probability = 0.75340000
# success_probability = 0.73030000
# success_probability = 0.75470000
# success_probability = 0.74860000
# success_probability = 0.75470000
# success_probability = 0.75260000
# success_probability = 0.74950000
# success_probability = 0.74050000
# success_probability = 0.75110000
# success_probability = 0.58890000
# success_probability = 0.75260000
# success_probability = 0.64610000
# success_probability = 0.70790000
# success_probability = 0.75470000
# success_probability = 0.76070000
# success_probability = 0.76190000
# success_probability = 0.76820000
# success_probability = 0.75130000
# success_probability = 0.74320000
# success_probability = 0.77370000
# success_probability = 0.77360000
# success_probability = 0.76950000
# success_probability = 0.75970000
# success_probability = 0.76590000
# success_probability = 0.77940000
# success_probability = 0.77220000
# success_probability = 0.78310000
# success_probability = 0.78160000
# success_probability = 0.78250000
# success_probability = 0.78470000
# success_probability = 0.78840000
# success_probability = 0.78820000
# success_probability = 0.79050000
# success_probability = 0.78910000
# success_probability = 0.78580000
# success_probability = 0.79180000
# success_probability = 0.78500000
# success_probability = 0.79250000
# success_probability = 0.75400000
# success_probability = 0.78170000
# success_probability = 0.77760000
# success_probability = 0.78940000
# success_probability = 0.77290000
# success_probability = 0.80020000
# success_probability = 0.77750000
# success_probability = 0.78650000
# success_probability = 0.78360000
# success_probability = 0.79220000
# success_probability = 0.75610000
# success_probability = 0.80130000
# success_probability = 0.79400000
# success_probability = 0.80030000
# success_probability = 0.79770000
# success_probability = 0.79840000
# success_probability = 0.79720000
# success_probability = 0.79730000
# success_probability = 0.79000000
# success_probability = 0.79620000
# success_probability = 0.79500000
# success_probability = 0.79880000
# success_probability = 0.79850000
# success_probability = 0.79970000
# success_probability = 0.79490000
# success_probability = 0.80120000
# success_probability = 0.79750000
# success_probability = 0.80080000
# success_probability = 0.79650000
# success_probability = 0.80130000
# success_probability = 0.78730000
# success_probability = 0.80220000
# success_probability = 0.79660000
# success_probability = 0.80100000
# success_probability = 0.80140000
# success_probability = 0.80230000
# success_probability = 0.80880000
# success_probability = 0.81340000
# success_probability = 0.85190000
# success_probability = 0.84330000
# success_probability = 0.85180000
# success_probability = 0.84630000
# success_probability = 0.85070000
# success_probability = 0.85180000
# success_probability = 0.85230000
# success_probability = 0.85880000
# success_probability = 0.85500000
# success_probability = 0.85460000
# success_probability = 0.84740000
# success_probability = 0.85510000
# success_probability = 0.84900000
# success_probability = 0.84720000
# success_probability = 0.84950000
# success_probability = 0.85070000
# success_probability = 0.85730000
# success_probability = 0.85670000
# success_probability = 0.85670000
# success_probability = 0.85420000
# success_probability = 0.85530000
# success_probability = 0.84930000
# success_probability = 0.85880000
# success_probability = 0.74690000
# success_probability = 0.85200000
# success_probability = 0.84000000
# success_probability = 0.86300000
# success_probability = 0.84510000
# success_probability = 0.85070000
# success_probability = 0.86210000
# success_probability = 0.86480000
# success_probability = 0.86780000
# success_probability = 0.86830000
# success_probability = 0.84570000
# success_probability = 0.87370000
# success_probability = 0.83660000
# success_probability = 0.87510000
# success_probability = 0.86350000
# success_probability = 0.87610000
# success_probability = 0.86860000
# success_probability = 0.87720000
# success_probability = 0.87760000
# success_probability = 0.87940000
# success_probability = 0.86720000
# success_probability = 0.87300000
# success_probability = 0.87850000
# success_probability = 0.87210000
# success_probability = 0.86330000
# success_probability = 0.88000000
# success_probability = 0.87250000
# success_probability = 0.87970000
# success_probability = 0.87290000
# success_probability = 0.88070000
# success_probability = 0.84820000
# success_probability = 0.88010000
# success_probability = 0.87130000
# success_probability = 0.87710000
# success_probability = 0.88080000
# success_probability = 0.87920000
# success_probability = 0.88150000
# success_probability = 0.88300000
# success_probability = 0.88140000
# success_probability = 0.88320000
# success_probability = 0.88270000
# success_probability = 0.87860000
# success_probability = 0.87050000
# success_probability = 0.87680000
# success_probability = 0.86690000
# success_probability = 0.87280000
# success_probability = 0.86040000
# success_probability = 0.87920000
# success_probability = 0.88220000
# success_probability = 0.88360000
# success_probability = 0.88560000
# success_probability = 0.88400000
# success_probability = 0.88410000
# success_probability = 0.88540000
# success_probability = 0.88770000
# success_probability = 0.88770000
# success_probability = 0.88060000
# success_probability = 0.88130000
# success_probability = 0.87310000
# success_probability = 0.86060000
# success_probability = 0.85230000
# success_probability = 0.88120000
# success_probability = 0.84410000
# success_probability = 0.87370000
# success_probability = 0.84870000
# success_probability = 0.88410000
# success_probability = 0.85160000
# success_probability = 0.88750000
# success_probability = 0.85640000
# success_probability = 0.87900000
# success_probability = 0.88490000
# success_probability = 0.88590000
# success_probability = 0.88560000
# success_probability = 0.88690000
# success_probability = 0.89030000
# success_probability = 0.89340000
# success_probability = 0.89630000
# success_probability = 0.89610000
# success_probability = 0.89680000
# success_probability = 0.90170000
# success_probability = 0.90040000
# success_probability = 0.90130000
# success_probability = 0.90040000
# success_probability = 0.90170000
# success_probability = 0.89130000
# success_probability = 0.90250000
# success_probability = 0.90450000
# success_probability = 0.90450000
# success_probability = 0.90180000
# success_probability = 0.90550000
# success_probability = 0.88850000
# success_probability = 0.89490000
# success_probability = 0.90320000
# success_probability = 0.89620000
# success_probability = 0.88270000
# success_probability = 0.90580000
# success_probability = 0.87900000
# success_probability = 0.91020000
# success_probability = 0.91320000
# success_probability = 0.91250000
# success_probability = 0.89540000
# success_probability = 0.91120000
# success_probability = 0.91710000
# success_probability = 0.91580000
# success_probability = 0.92730000
# success_probability = 0.92640000
# success_probability = 0.92260000
# success_probability = 0.92590000
# success_probability = 0.89810000
# success_probability = 0.91980000
# success_probability = 0.91250000
# success_probability = 0.92340000
# success_probability = 0.92480000
# success_probability = 0.92650000
# success_probability = 0.92870000
# success_probability = 0.92850000
# success_probability = 0.92960000
# success_probability = 0.92800000
# success_probability = 0.92430000
# success_probability = 0.92730000
# success_probability = 0.92880000
# success_probability = 0.92890000
# success_probability = 0.89340000
# success_probability = 0.92530000
# success_probability = 0.92500000
# success_probability = 0.92540000
# success_probability = 0.90530000
# success_probability = 0.92780000
# success_probability = 0.92620000
# success_probability = 0.92920000
# success_probability = 0.91070000
# success_probability = 0.92890000
# success_probability = 0.92480000
# success_probability = 0.92750000
# success_probability = 0.91510000
# success_probability = 0.92880000
# success_probability = 0.86680000
# success_probability = 0.92660000
# success_probability = 0.91240000
# success_probability = 0.92730000
# success_probability = 0.89320000
# success_probability = 0.92900000
# success_probability = 0.89810000
# success_probability = 0.92300000
# success_probability = 0.91620000
# success_probability = 0.92960000
# success_probability = 0.92180000
# success_probability = 0.92790000
# success_probability = 0.88190000
# success_probability = 0.92250000
# success_probability = 0.90120000
# success_probability = 0.92420000
# success_probability = 0.91580000
# success_probability = 0.92720000
# success_probability = 0.91450000
# success_probability = 0.92960000
# success_probability = 0.93100000
# success_probability = 0.93270000
# success_probability = 0.92940000
# success_probability = 0.93020000
# success_probability = 0.91720000
# success_probability = 0.93260000
# success_probability = 0.92240000
# success_probability = 0.93170000
# success_probability = 0.91910000
# success_probability = 0.93090000
# success_probability = 0.93050000
# success_probability = 0.92750000
# success_probability = 0.92760000
# success_probability = 0.93310000
# success_probability = 0.93180000
# success_probability = 0.93100000
# success_probability = 0.91300000
# success_probability = 0.92950000
# success_probability = 0.93600000
# success_probability = 0.93600000
# success_probability = 0.92990000
# success_probability = 0.93030000
# success_probability = 0.90860000
# success_probability = 0.93540000
# success_probability = 0.91650000
# success_probability = 0.93110000
# success_probability = 0.90920000
# success_probability = 0.93090000
# success_probability = 0.93070000
# success_probability = 0.93580000
# success_probability = 0.93150000
# success_probability = 0.93640000
# success_probability = 0.90930000
# success_probability = 0.93080000
# success_probability = 0.92490000
# success_probability = 0.93540000
# success_probability = 0.93150000
# success_probability = 0.93450000
# success_probability = 0.92880000
# success_probability = 0.93470000
# success_probability = 0.87680000
# success_probability = 0.93390000
# success_probability = 0.88800000
# success_probability = 0.93800000
# success_probability = 0.90090000
# success_probability = 0.93660000
# success_probability = 0.91170000
# success_probability = 0.94050000
# success_probability = 0.91160000
# success_probability = 0.93720000
# success_probability = 0.91930000
# success_probability = 0.93700000
# success_probability = 0.92700000
# success_probability = 0.93010000
# success_probability = 0.93770000
# success_probability = 0.94130000
# success_probability = 0.92130000
# success_probability = 0.93170000
# success_probability = 0.92350000
# success_probability = 0.93710000
# success_probability = 0.92410000
# success_probability = 0.94260000
# success_probability = 0.93670000
# success_probability = 0.93400000
# success_probability = 0.94470000
# success_probability = 0.93760000
# success_probability = 0.94280000
# success_probability = 0.94330000
# success_probability = 0.93460000
# success_probability = 0.93570000
# success_probability = 0.94060000
# success_probability = 0.94770000
# success_probability = 0.94770000
# success_probability = 0.94540000
# success_probability = 0.94940000
# success_probability = 0.94920000
# success_probability = 0.94680000
# success_probability = 0.95170000
# success_probability = 0.95210000
# success_probability = 0.95130000
# success_probability = 0.94480000
# success_probability = 0.95270000
# success_probability = 0.94780000
# success_probability = 0.95080000
# success_probability = 0.94670000
# success_probability = 0.94580000
# success_probability = 0.94930000
# success_probability = 0.95040000
# success_probability = 0.94380000
# success_probability = 0.94770000
# success_probability = 0.94210000
# success_probability = 0.95500000
# success_probability = 0.92880000
# success_probability = 0.95610000
# success_probability = 0.94330000
# success_probability = 0.95150000
# success_probability = 0.95170000
# success_probability = 0.95430000
# success_probability = 0.94980000
# success_probability = 0.95390000
# success_probability = 0.95220000
# success_probability = 0.95340000
# success_probability = 0.92950000
# success_probability = 0.95400000
# success_probability = 0.92460000
# success_probability = 0.94890000
# success_probability = 0.91910000
# success_probability = 0.93800000
# success_probability = 0.91200000
# success_probability = 0.94930000
# success_probability = 0.91350000
# success_probability = 0.94920000
# success_probability = 0.93510000
# success_probability = 0.94990000
# success_probability = 0.94170000
# success_probability = 0.94950000
# success_probability = 0.94340000
# success_probability = 0.95210000
# success_probability = 0.93090000
# success_probability = 0.95420000
# success_probability = 0.93440000
# success_probability = 0.95790000
# success_probability = 0.94510000
# success_probability = 0.95400000
# success_probability = 0.94280000
# success_probability = 0.95360000
# success_probability = 0.94860000
# success_probability = 0.95450000
# success_probability = 0.94370000
# success_probability = 0.95510000
# success_probability = 0.94540000
# success_probability = 0.95070000
# success_probability = 0.93530000
# success_probability = 0.95730000
# success_probability = 0.94780000
# success_probability = 0.95210000
# success_probability = 0.95250000
# success_probability = 0.95580000
# success_probability = 0.95220000
# success_probability = 0.95800000
# success_probability = 0.93120000
# success_probability = 0.94940000
# success_probability = 0.93600000
# success_probability = 0.94810000
# success_probability = 0.93110000
# success_probability = 0.95320000
# success_probability = 0.93850000
# success_probability = 0.95280000
# success_probability = 0.94230000
# success_probability = 0.95290000
# success_probability = 0.94450000
# success_probability = 0.94960000
# success_probability = 0.95510000
# success_probability = 0.95180000
# success_probability = 0.93920000
# success_probability = 0.95430000
# success_probability = 0.95030000
# success_probability = 0.95600000
# success_probability = 0.94720000
# success_probability = 0.94840000
# success_probability = 0.95400000
# success_probability = 0.95540000
# success_probability = 0.95560000
# success_probability = 0.95470000
# success_probability = 0.95390000
# success_probability = 0.95290000
# success_probability = 0.95560000
# success_probability = 0.95470000
# success_probability = 0.95290000
# success_probability = 0.95470000
# success_probability = 0.95540000
# success_probability = 0.95330000
# success_probability = 0.95500000
# success_probability = 0.95320000
# success_probability = 0.95660000
# success_probability = 0.95310000
# success_probability = 0.95200000
# success_probability = 0.94790000
# success_probability = 0.95480000
# success_probability = 0.95090000
# success_probability = 0.95160000
# success_probability = 0.95730000
# success_probability = 0.95620000
# success_probability = 0.94790000
# success_probability = 0.95700000
# success_probability = 0.95460000
# success_probability = 0.95710000
# success_probability = 0.94770000
# success_probability = 0.95450000
# success_probability = 0.94400000
# success_probability = 0.95730000
# success_probability = 0.95660000
# success_probability = 0.95420000
# success_probability = 0.95200000
# success_probability = 0.95460000
# success_probability = 0.95460000
# success_probability = 0.95610000
# success_probability = 0.95340000
# success_probability = 0.95410000
# success_probability = 0.94770000
# success_probability = 0.95430000
# success_probability = 0.95050000
# success_probability = 0.95240000
# success_probability = 0.94980000
# success_probability = 0.95500000
# success_probability = 0.95600000
# success_probability = 0.95560000
# success_probability = 0.95690000
# success_probability = 0.95580000
# success_probability = 0.95640000
# success_probability = 0.95360000
# success_probability = 0.95710000
# success_probability = 0.95530000
# success_probability = 0.95730000
# success_probability = 0.95380000
# success_probability = 0.95620000
# success_probability = 0.95270000
# success_probability = 0.95770000
# success_probability = 0.95460000
# success_probability = 0.95590000
# success_probability = 0.95310000
# success_probability = 0.95940000
# success_probability = 0.95670000
# success_probability = 0.95700000
# success_probability = 0.95520000
# success_probability = 0.95510000
# success_probability = 0.95740000
# success_probability = 0.95630000
# success_probability = 0.95580000
# success_probability = 0.95710000
# success_probability = 0.95700000
# success_probability = 0.95770000
# success_probability = 0.95690000
# success_probability = 0.95720000
# success_probability = 0.95650000
# success_probability = 0.95600000
# success_probability = 0.95540000
# success_probability = 0.95700000
# success_probability = 0.95920000
# success_probability = 0.95680000
# success_probability = 0.95840000
# success_probability = 0.95810000
# success_probability = 0.95840000
# success_probability = 0.95590000
# success_probability = 0.95770000
# success_probability = 0.95620000
# success_probability = 0.95790000
# success_probability = 0.95780000
# success_probability = 0.95840000
# success_probability = 0.95800000
# success_probability = 0.95710000
# success_probability = 0.95590000
# success_probability = 0.95780000
# success_probability = 0.95620000
# success_probability = 0.95730000
# success_probability = 0.95710000
# success_probability = 0.95800000
# success_probability = 0.95650000
# success_probability = 0.95860000
# success_probability = 0.95720000
# success_probability = 0.95730000
# success_probability = 0.95810000
# success_probability = 0.95680000
# success_probability = 0.95800000
# success_probability = 0.95810000
# success_probability = 0.95870000
# success_probability = 0.95670000
# success_probability = 0.95840000
# success_probability = 0.95670000
# success_probability = 0.95670000
# success_probability = 0.95840000
# success_probability = 0.95510000
# success_probability = 0.95730000
# success_probability = 0.95680000
# success_probability = 0.95920000
# success_probability = 0.95690000
# success_probability = 0.95760000
# success_probability = 0.95700000
# success_probability = 0.95710000
# success_probability = 0.95750000
# success_probability = 0.95790000
# success_probability = 0.95670000
# success_probability = 0.95840000
# success_probability = 0.95610000
# success_probability = 0.95730000
# success_probability = 0.95750000
# success_probability = 0.95850000
# success_probability = 0.95740000
# success_probability = 0.95810000
# success_probability = 0.95630000
# success_probability = 0.95710000
# success_probability = 0.95670000
# success_probability = 0.95720000
# success_probability = 0.95660000
# success_probability = 0.95810000
# success_probability = 0.95570000
# success_probability = 0.95920000
# success_probability = 0.95820000
# success_probability = 0.95750000
# success_probability = 0.95860000
# success_probability = 0.95900000
# success_probability = 0.95760000
# success_probability = 0.95900000
# success_probability = 0.95920000
# success_probability = 0.95770000
# success_probability = 0.95820000
# success_probability = 0.95920000
# success_probability = 0.95770000
# success_probability = 0.95820000
# success_probability = 0.95800000
# success_probability = 0.95890000
# success_probability = 0.95700000
# success_probability = 0.95830000
# success_probability = 0.95740000
# success_probability = 0.95870000
# success_probability = 0.95900000
# success_probability = 0.95880000
# success_probability = 0.95950000
# success_probability = 0.95800000
# success_probability = 0.95870000
# success_probability = 0.95880000
# success_probability = 0.95890000
# success_probability = 0.95780000
# success_probability = 0.95910000
# success_probability = 0.95920000
# success_probability = 0.95890000
# success_probability = 0.95880000
# success_probability = 0.95900000
# success_probability = 0.95820000
# success_probability = 0.95820000
# success_probability = 0.95790000
# success_probability = 0.95860000
# success_probability = 0.95900000
# success_probability = 0.95850000
# success_probability = 0.95880000
# success_probability = 0.95800000
# success_probability = 0.95900000
# success_probability = 0.95900000
# success_probability = 0.95760000
# success_probability = 0.95920000
# success_probability = 0.95810000
# success_probability = 0.95850000
# success_probability = 0.95840000
# success_probability = 0.95870000
# success_probability = 0.95870000
# success_probability = 0.95860000
# success_probability = 0.95800000
# success_probability = 0.95830000
# success_probability = 0.95890000
# success_probability = 0.95930000
# success_probability = 0.95830000
# success_probability = 0.95880000
# success_probability = 0.95920000
# success_probability = 0.95890000
# success_probability = 0.95880000
# success_probability = 0.95900000
# success_probability = 0.95960000
# success_probability = 0.95860000
# success_probability = 0.95950000
# success_probability = 0.95860000
# success_probability = 0.95920000
# success_probability = 0.95900000
# success_probability = 0.95930000
# success_probability = 0.95940000
# success_probability = 0.95910000
# success_probability = 0.95960000
# success_probability = 0.95950000
# success_probability = 0.95890000
# success_probability = 0.95950000
# success_probability = 0.95950000
# success_probability = 0.95910000
# success_probability = 0.95880000
# success_probability = 0.95920000
# success_probability = 0.95900000
# success_probability = 0.95930000
# success_probability = 0.95950000
# success_probability = 0.95970000
# success_probability = 0.95930000
# success_probability = 0.95920000
# success_probability = 0.95880000
# success_probability = 0.95950000
# success_probability = 0.95950000
# success_probability = 0.95960000
# success_probability = 0.95920000
# success_probability = 0.95940000
# success_probability = 0.95930000
# success_probability = 0.95980000
# success_probability = 0.95910000
# success_probability = 0.95980000
# success_probability = 0.95900000
# success_probability = 0.95990000
# success_probability = 0.95900000
# success_probability = 0.95950000
# success_probability = 0.95920000
# success_probability = 0.95950000
# success_probability = 0.95910000
# success_probability = 0.96010000
# success_probability = 0.95990000
# success_probability = 0.95980000
# success_probability = 0.95930000
# success_probability = 0.95990000
# success_probability = 0.95940000
# success_probability = 0.95990000
# success_probability = 0.95940000
# success_probability = 0.95960000
# success_probability = 0.95900000
# success_probability = 0.95990000
# success_probability = 0.95920000
# success_probability = 0.95950000
# success_probability = 0.95950000
# success_probability = 0.95960000
# success_probability = 0.95890000
# success_probability = 0.95940000
# success_probability = 0.95870000
# success_probability = 0.95990000
# success_probability = 0.95880000
# success_probability = 0.95900000
# success_probability = 0.95930000
# success_probability = 0.96000000
# success_probability = 0.95980000
# success_probability = 0.95970000
# success_probability = 0.95920000
# success_probability = 0.95910000
# success_probability = 0.95940000
# success_probability = 0.95920000
# success_probability = 0.95890000
# success_probability = 0.95900000
# success_probability = 0.95920000
# success_probability = 0.96000000
# success_probability = 0.95980000
# success_probability = 0.95960000
# success_probability = 0.95980000
# success_probability = 0.95960000
# success_probability = 0.95980000
# success_probability = 0.95970000
# success_probability = 0.96000000
# success_probability = 0.95960000
# success_probability = 0.96010000
# success_probability = 0.95960000
# success_probability = 0.95980000
# success_probability = 0.95910000
# success_probability = 0.95980000
# success_probability = 0.96010000
# success_probability = 0.96000000
# success_probability = 0.96000000
# success_probability = 0.95980000
# success_probability = 0.95950000
# success_probability = 0.96010000
# success_probability = 0.95960000
# success_probability = 0.95960000
# success_probability = 0.95970000
# success_probability = 0.95970000
# success_probability = 0.95970000
# success_probability = 0.95980000
# success_probability = 0.95940000
# success_probability = 0.95960000
# success_probability = 0.96000000
# success_probability = 0.95970000
# success_probability = 0.95990000
# success_probability = 0.95980000
# success_probability = 0.96000000
# success_probability = 0.95990000
# success_probability = 0.95940000
# success_probability = 0.95960000
# success_probability = 0.95940000
# success_probability = 0.96000000
# success_probability = 0.95970000
# success_probability = 0.95990000
# success_probability = 0.95970000
# success_probability = 0.95990000
# success_probability = 0.95930000
# success_probability = 0.95980000
# success_probability = 0.96000000
# success_probability = 0.95970000
# success_probability = 0.95990000
# success_probability = 0.96010000
# success_probability = 0.96000000
# success_probability = 0.96010000
# success_probability = 0.96030000
# success_probability = 0.96010000
# success_probability = 0.95980000
# success_probability = 0.96030000
# success_probability = 0.95990000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96010000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96010000
# success_probability = 0.96010000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96000000
# success_probability = 0.95990000
# success_probability = 0.96000000
# success_probability = 0.96020000
# success_probability = 0.96000000
# success_probability = 0.96010000
# success_probability = 0.96020000
# success_probability = 0.96010000
# success_probability = 0.96010000
# success_probability = 0.96020000
# success_probability = 0.96010000
# success_probability = 0.96010000
# success_probability = 0.96000000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96000000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96010000
# success_probability = 0.96030000
# success_probability = 0.95990000
# success_probability = 0.96030000
# success_probability = 0.95990000
# success_probability = 0.96030000
# success_probability = 0.96010000
# success_probability = 0.96020000
# success_probability = 0.96000000
# success_probability = 0.96020000
# success_probability = 0.96010000
# success_probability = 0.96000000
# success_probability = 0.96010000
# success_probability = 0.96030000
# success_probability = 0.96000000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96010000
# success_probability = 0.96000000
# success_probability = 0.96010000
# success_probability = 0.96030000
# success_probability = 0.96010000
# success_probability = 0.96030000
# success_probability = 0.96010000
# success_probability = 0.96030000
# success_probability = 0.96010000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96010000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96020000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# success_probability = 0.96030000
# ...
#  0.6518199474, 0.496504845 , 0.729372615 , 0.4775535381, 0.1132538865,
#  0.3171287194, 0.6974759726, 0.9708775987, 0.4451800101, 0.6758017747,
#  0.6194900998, 0.1012538026, 0.7686771015, 0.1224097253, 0.0527568807,
#  0.4050062492, 0.0100490169, 0.6647206668, 0.5495225155, 0.9583006172,
#  0.2762205387, 0.1931722249, 0.1168164697, 0.9519431293, 0.7602497712,
#  0.1196059678, 0.02310011  , 0.8821256137, 0.2014686398, 0.1903080952,
#  0.362067198 , 0.8426962885, 0.1403006233, 0.1569124757, 0.1111713195,
#  0.9187651897, 0.7512801886, 0.5301748522, 0.1317426314, 0.6921360823,
#  0.7958142338, 0.8327416496, 0.4427424773, 0.9748631191, 0.213811372 ,
#  0.6624780307, 0.3662789169, 0.0385273203, 0.6558371557, 0.7797766622,
#  0.5486165526, 0.8667103446, 0.568045883 , 0.2290704352, 0.1394365961,
#  0.7964815329, 0.982999422 , 0.4252657299]
#
# Optimal Parameters:
# [-0.2219207797,  0.1596905843,  0.6568093259, -0.4375337599,  1.4316058356,
#   0.1867555892,  0.5268149404,  0.6500341537, -0.4030566558, -0.3652059708,
#   0.4286411537,  0.7798713019, -0.3437594947,  0.7702433716,  2.1907331101,
#  -0.0709508199,  2.7711155115,  3.4142857686,  3.2491293868, -1.004710408 ,
#   2.0022698279,  0.7971842143,  1.219917257 ,  0.4445996505,  0.4924048339,
#   0.6957052505, -1.2592399011,  1.0400928806,  2.052701235 ,  0.0721731353,
#  -0.1636716879,  0.4297778749,  1.0341868562,  0.3370977474,  2.3074528048,
#   0.5947126646,  1.4252271186,  2.7567790218, -0.123426265 , -0.1696860534,
#   1.1094538983, -0.2925181202,  1.9943743998,  1.1996184105,  0.7783833662,
#   0.3156872294, -0.12300395  ,  0.0435801732,  0.580837453 ,  3.114313795 ,
#  -0.1032817244,  0.8903042216,  3.131362778 ,  0.7341754306,  1.1374911922,
#   1.1968702791,  1.5469756207,  0.7956322955,  0.2143644407,  0.1845736606,
#   1.3817078257,  0.6957127487,  1.4208455154,  0.0647550115,  0.1004439627,
#   0.6500992965,  0.4348097257,  0.7626845008,  0.7351155454, -0.4619301097,
#   1.0949115107,  0.5460778468, -0.847944377 ,  1.5860345246,  1.3812686758,
#  -0.1640027179,  1.8667939201,  1.0556514325,  0.1945610589,  0.20669695  ,
#   0.8373725833,  1.202508729 ,  0.5561256405]
# ----------------------------------------------------------------------------------------------------
#
# Run 29
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 178
# Optimized Value   : 0.97020000
# Evaluated Mean    : 0.96488950
# Evaluated Std     : 0.00072392
# Evaluated Min     : 0.96354000
# Evaluated Max     : 0.96607000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 1722
#
# Evaluated Values:
# [0.96454, 0.96461, 0.96456, 0.96571, 0.96427, 0.96547, 0.96595, 0.96467,
#  0.96354, 0.96409, 0.96542, 0.96505, 0.96424, 0.96546, 0.96556, 0.9644 ,
#  0.96607, 0.96419, 0.96413, 0.96586]
#
# Initial Parameters:
# [0.7608275692, 0.0464101376, 0.0032708871, 0.7605003536, 0.2769531808,
#  0.5945503444, 0.8036218146, 0.7402677744, 0.1239034672, 0.2438968692,
#  0.748428843 , 0.9205783868, 0.2357355697, 0.9391032789, 0.4081091944,
#  0.4620759117, 0.7294079941, 0.5779372506, 0.3477807167, 0.9240071009,
#  0.4847679255, 0.9369591861, 0.6895419866, 0.4903610315, 0.1782447546,
#  0.0915727898, 0.6053767128, 0.8164664622, 0.7844838565, 0.8076365567,
#  0.3786127878, 0.4749924312, 0.1239156448, 0.2275737853, 0.6876209816,
#  0.7743270047, 0.4786391045, 0.7675538616, 0.7245921163, 0.9591018277,
#  0.4288484364, 0.2218635615, 0.3048422465, 0.4536455377, 0.5066066802,
#  0.3874690718, 0.9072326738, 0.6676705454, 0.4837890293, 0.3620150368,
#  0.3227239258, 0.1903899749, 0.4097574303, 0.2441153488, 0.115563853 ,
#  0.0781657966, 0.2518107663, 0.8801837987, 0.3918907749, 0.2473111974,
#  0.1614564923, 0.7175855681, 0.1598583196, 0.664328631 , 0.9104760626,
#  0.0971491354, 0.6029039781, 0.0713788606, 0.4155950638, 0.9710570273,
#  0.6021034329, 0.2574229341, 0.8676281711, 0.4637558266, 0.4469683577,
#  0.184157682 , 0.2665326606, 0.6041048967, 0.0871891986, 0.5576150718,
#  0.775864039 , 0.4162019333, 0.8611011259]
#
# Optimal Parameters:
# [ 0.0282687459,  1.2980352472,  0.3446917772,  1.5312252448,  0.5251518599,
#  -0.0563740822,  1.5138493202,  1.0677364023,  0.5928400814,  1.0140451302,
#   1.8808885564,  0.2014473021,  0.9564492278,  1.514552884 , -0.0310318803,
#   0.0067094371,  3.1974232992,  0.4010087339,  3.0220811641,  2.1491989657,
#   2.1930754898,  1.3333274728, -0.0450387894,  0.2019631266,  0.2322093984,
#   0.0041757173,  0.5691701078,  0.9258478852,  1.0767614207,  1.1812029198,
#   0.2071159783,  0.671525532 ,  0.5828578443,  0.6672049988,  0.8791839438,
#   0.4120574452,  1.0268248456,  0.3814718511,  0.4496574088,  1.6857940712,
#   0.3019436739,  0.8150841584, -0.075048126 ,  0.4018322958,  0.3040626074,
#   1.7395957867,  0.2086044132, -0.2218045946,  1.1509379406,  0.1584383279,
#   1.1856618565, -0.0797609024,  3.1479856334,  1.3026079974, -0.33016016  ,
#  -0.7632224879,  0.9427524278,  0.2585971527,  0.4311152374,  1.1530602486,
#   0.0104697129,  0.9959619965,  1.5515833081,  0.5117751896, -0.0895568064,
#   2.0218838591,  0.4537958797,  0.0057961328,  1.5291860393,  1.9349794846,
#   0.5181655307,  0.3904673054,  0.1970213004, -0.0964976969,  1.0924749305,
#  -0.2647126129,  1.5506429561,  0.5346502201,  0.2014334326,  0.7173739998,
#   0.567601884 ,  0.2994904527,  2.7704791979]
# ----------------------------------------------------------------------------------------------------
#
# Run 30
# ----------------------------------------------------------------------------------------------------
# Optimization Seed : 179
# Optimized Value   : 0.62740000
# Evaluated Mean    : 0.62364850
# Evaluated Std     : 0.00151397
# Evaluated Min     : 0.62053000
# Evaluated Max     : 0.62641000
# Success           : True
# Reached MaxIter   : False
# Status            : 1
# Message           : Optimization terminated successfully.
# Function Evals    : 1263
#
# Evaluated Values:
# [0.62347, 0.62465, 0.6226 , 0.62415, 0.62488, 0.62609, 0.6244 , 0.62345,
#  0.62296, 0.62555, 0.62198, 0.62374, 0.62071, 0.62321, 0.62435, 0.62236,
#  0.62641, 0.62053, 0.62401, 0.62347]
#
# Initial Parameters:
# [0.9180695286, 0.9403935557, 0.9611445873, 0.1282735573, 0.7343854482,
#  0.1418537547, 0.3206870255, 0.8783134777, 0.3925501756, 0.9542827898,
#  0.4333144504, 0.0052152104, 0.5921889116, 0.318609756 , 0.9316370681,
#  0.6026668473, 0.0078690534, 0.7991305598, 0.851774691 , 0.06652901  ,
#  0.7310172927, 0.1064287992, 0.0810809173, 0.7115609048, 0.7069595409,
#  0.496652521 , 0.9897356485, 0.1231137075, 0.6818954479, 0.6829684311,
#  0.6297061464, 0.4286822178, 0.2197024243, 0.0834353681, 0.9077417659,
#  0.0972222206, 0.061382995 , 0.8279569226, 0.1578310648, 0.0841288554,
#  0.4172996827, 0.7066178285, 0.6364755314, 0.8297559874, 0.3496650027,
#  0.8342151076, 0.380898976 , 0.4686856659, 0.2478629526, 0.2083816805,
#  0.6907081716, 0.5840401998, 0.2448348262, 0.703362514 , 0.0087485208,
#  0.9115934208, 0.0920837192, 0.9668733452, 0.881263467 , 0.8161583376,
#  0.9708130872, 0.1303500549, 0.4036945116, 0.6522566273, 0.6359234131,
#  0.4831190558, 0.3116499934, 0.727724005 , 0.0521833069, 0.7172717036,
#  0.9428815129, 0.0681871225, 0.4163408869, 0.5632919726, 0.0053311238,
#  0.2980786748, 0.4540301237, 0.3438448494, 0.8933085981, 0.8259414868,
#  0.0761022159, 0.3835538967, 0.8864307775]
#
# Optimal Parameters:
# [ 1.3103140782,  2.0157568337,  0.7383101296, -0.51061113  ,  1.9991613507,
#   0.0751102476,  0.1801779735,  1.4468466245,  0.0655893366, -0.1037301331,
#   0.4164761415, -0.188312239 ,  0.7252096811,  0.9794695214,  0.4173796424,
#   0.1734039982,  0.2197380585,  2.9039566269,  3.2128767884,  1.1887160925,
#   1.6909438647,  0.0355477482,  1.0897400986,  0.6957931083,  0.6631728744,
#   0.1647852835,  0.9741055989,  0.4256773267,  1.4338362992,  0.6869506938,
#   0.5635466416,  0.359920682 ,  0.2228260027, -0.3567715331,  1.9529214072,
#   1.157092695 , -0.3854789544,  1.0965148314,  0.3207908802,  0.6379974814,
#   0.3198111095,  0.5205790483,  0.4616508644,  1.4991851754,  0.2663928948,
#   0.7537870905,  0.3271480316,  0.3613403849,  0.1881528873, -0.1007137283,
#   0.1471497786,  0.4867025621,  0.1580102202,  0.5846039889, -0.070086048 ,
#   0.8632035254, -0.4061400101,  0.86613242  ,  0.7598955798,  0.6810381457,
#   0.8696069544, -0.3239784374,  0.6076760198,  0.5460882885,  0.5221885834,
#   0.395052736 ,  0.2812542379,  0.9837043135,  0.8974747046,  0.7283256572,
#   1.9107259642,  0.058112078 ,  1.4128940645,  0.5467846919,  1.014616348 ,
#   0.3451922875,  0.3499577695,  0.2965352768,  0.892095024 ,  0.8056045253,
#   0.006735694 ,  0.3824099583,  0.8851291094]
# ----------------------------------------------------------------------------------------------------
#
# SUMMARY
# ====================================================================================================
#
# Original Optimization-Shot Results:
# Maximum Optimized Value : 0.97020000
# Maximum Run             : 29
# Mean Optimized Value    : 0.87390000
# Std Optimized Value     : 0.12527768
#
# High-Shot Evaluation Results:
# Best Evaluated Mean     : 0.96488950
# Best Evaluated Mean Run : 29
# Mean of Evaluated Means : 0.86587510
# Std of Evaluated Means  : 0.12491922
#
# Optimizer Statistics:
# Mean Function Evals     : 1593.60
# Std Function Evals      : 185.31
# Successful Runs         : 30/30
# Failed Runs             : 0/30
# Reached MaxIter         : 0/30
#
# Computational Runtime Statistics:
# Total Wall-Clock Time          : 3769.689285 s
# Total Optimization Time        : 3706.990869 s
# Time per Complete Opt. Run     : 123.566362 s
# Std Optimization Time per Run  : 14.077722 s
#
# ====================================================================================================
# BEST RUN ACCORDING TO ORIGINAL OPTIMIZED VALUE
# ====================================================================================================
# Run             : 29
# Optimized Value : 0.97020000
# Evaluated Mean  : 0.96488950
# Evaluated Std   : 0.00072392
# Evaluated Min   : 0.96354000
# Evaluated Max   : 0.96607000
#
# Evaluated Values:
# [0.96454, 0.96461, 0.96456, 0.96571, 0.96427, 0.96547, 0.96595, 0.96467,
#  0.96354, 0.96409, 0.96542, 0.96505, 0.96424, 0.96546, 0.96556, 0.9644 ,
#  0.96607, 0.96419, 0.96413, 0.96586]
#
# Initial Parameters:
# [0.7608275692, 0.0464101376, 0.0032708871, 0.7605003536, 0.2769531808,
#  0.5945503444, 0.8036218146, 0.7402677744, 0.1239034672, 0.2438968692,
#  0.748428843 , 0.9205783868, 0.2357355697, 0.9391032789, 0.4081091944,
#  0.4620759117, 0.7294079941, 0.5779372506, 0.3477807167, 0.9240071009,
#  0.4847679255, 0.9369591861, 0.6895419866, 0.4903610315, 0.1782447546,
#  0.0915727898, 0.6053767128, 0.8164664622, 0.7844838565, 0.8076365567,
#  0.3786127878, 0.4749924312, 0.1239156448, 0.2275737853, 0.6876209816,
#  0.7743270047, 0.4786391045, 0.7675538616, 0.7245921163, 0.9591018277,
#  0.4288484364, 0.2218635615, 0.3048422465, 0.4536455377, 0.5066066802,
#  0.3874690718, 0.9072326738, 0.6676705454, 0.4837890293, 0.3620150368,
#  0.3227239258, 0.1903899749, 0.4097574303, 0.2441153488, 0.115563853 ,
#  0.0781657966, 0.2518107663, 0.8801837987, 0.3918907749, 0.2473111974,
#  0.1614564923, 0.7175855681, 0.1598583196, 0.664328631 , 0.9104760626,
#  0.0971491354, 0.6029039781, 0.0713788606, 0.4155950638, 0.9710570273,
#  0.6021034329, 0.2574229341, 0.8676281711, 0.4637558266, 0.4469683577,
#  0.184157682 , 0.2665326606, 0.6041048967, 0.0871891986, 0.5576150718,
#  0.775864039 , 0.4162019333, 0.8611011259]
#
# Optimal Parameters:
# [ 0.0282687459,  1.2980352472,  0.3446917772,  1.5312252448,  0.5251518599,
#  -0.0563740822,  1.5138493202,  1.0677364023,  0.5928400814,  1.0140451302,
#   1.8808885564,  0.2014473021,  0.9564492278,  1.514552884 , -0.0310318803,
#   0.0067094371,  3.1974232992,  0.4010087339,  3.0220811641,  2.1491989657,
#   2.1930754898,  1.3333274728, -0.0450387894,  0.2019631266,  0.2322093984,
#   0.0041757173,  0.5691701078,  0.9258478852,  1.0767614207,  1.1812029198,
#   0.2071159783,  0.671525532 ,  0.5828578443,  0.6672049988,  0.8791839438,
#   0.4120574452,  1.0268248456,  0.3814718511,  0.4496574088,  1.6857940712,
#   0.3019436739,  0.8150841584, -0.075048126 ,  0.4018322958,  0.3040626074,
#   1.7395957867,  0.2086044132, -0.2218045946,  1.1509379406,  0.1584383279,
#   1.1856618565, -0.0797609024,  3.1479856334,  1.3026079974, -0.33016016  ,
#  -0.7632224879,  0.9427524278,  0.2585971527,  0.4311152374,  1.1530602486,
#   0.0104697129,  0.9959619965,  1.5515833081,  0.5117751896, -0.0895568064,
#   2.0218838591,  0.4537958797,  0.0057961328,  1.5291860393,  1.9349794846,
#   0.5181655307,  0.3904673054,  0.1970213004, -0.0964976969,  1.0924749305,
#  -0.2647126129,  1.5506429561,  0.5346502201,  0.2014334326,  0.7173739998,
#   0.567601884 ,  0.2994904527,  2.7704791979]
#
# ====================================================================================================
# BEST RUN ACCORDING TO HIGH-SHOT EVALUATED MEAN
# ====================================================================================================
# Run             : 29
# Optimized Value : 0.97020000
# Evaluated Mean  : 0.96488950
# Evaluated Std   : 0.00072392
# Evaluated Min   : 0.96354000
# Evaluated Max   : 0.96607000
#
# Evaluated Values:
# [0.96454, 0.96461, 0.96456, 0.96571, 0.96427, 0.96547, 0.96595, 0.96467,
#  0.96354, 0.96409, 0.96542, 0.96505, 0.96424, 0.96546, 0.96556, 0.9644 ,
#  0.96607, 0.96419, 0.96413, 0.96586]
#
# Initial Parameters:
# [0.7608275692, 0.0464101376, 0.0032708871, 0.7605003536, 0.2769531808,
#  0.5945503444, 0.8036218146, 0.7402677744, 0.1239034672, 0.2438968692,
#  0.748428843 , 0.9205783868, 0.2357355697, 0.9391032789, 0.4081091944,
#  0.4620759117, 0.7294079941, 0.5779372506, 0.3477807167, 0.9240071009,
#  0.4847679255, 0.9369591861, 0.6895419866, 0.4903610315, 0.1782447546,
#  0.0915727898, 0.6053767128, 0.8164664622, 0.7844838565, 0.8076365567,
#  0.3786127878, 0.4749924312, 0.1239156448, 0.2275737853, 0.6876209816,
#  0.7743270047, 0.4786391045, 0.7675538616, 0.7245921163, 0.9591018277,
#  0.4288484364, 0.2218635615, 0.3048422465, 0.4536455377, 0.5066066802,
#  0.3874690718, 0.9072326738, 0.6676705454, 0.4837890293, 0.3620150368,
#  0.3227239258, 0.1903899749, 0.4097574303, 0.2441153488, 0.115563853 ,
#  0.0781657966, 0.2518107663, 0.8801837987, 0.3918907749, 0.2473111974,
#  0.1614564923, 0.7175855681, 0.1598583196, 0.664328631 , 0.9104760626,
#  0.0971491354, 0.6029039781, 0.0713788606, 0.4155950638, 0.9710570273,
#  0.6021034329, 0.2574229341, 0.8676281711, 0.4637558266, 0.4469683577,
#  0.184157682 , 0.2665326606, 0.6041048967, 0.0871891986, 0.5576150718,
#  0.775864039 , 0.4162019333, 0.8611011259]
#
# Optimal Parameters:
# [ 0.0282687459,  1.2980352472,  0.3446917772,  1.5312252448,  0.5251518599,
#  -0.0563740822,  1.5138493202,  1.0677364023,  0.5928400814,  1.0140451302,
#   1.8808885564,  0.2014473021,  0.9564492278,  1.514552884 , -0.0310318803,
#   0.0067094371,  3.1974232992,  0.4010087339,  3.0220811641,  2.1491989657,
#   2.1930754898,  1.3333274728, -0.0450387894,  0.2019631266,  0.2322093984,
#   0.0041757173,  0.5691701078,  0.9258478852,  1.0767614207,  1.1812029198,
#   0.2071159783,  0.671525532 ,  0.5828578443,  0.6672049988,  0.8791839438,
#   0.4120574452,  1.0268248456,  0.3814718511,  0.4496574088,  1.6857940712,
#   0.3019436739,  0.8150841584, -0.075048126 ,  0.4018322958,  0.3040626074,
#   1.7395957867,  0.2086044132, -0.2218045946,  1.1509379406,  0.1584383279,
#   1.1856618565, -0.0797609024,  3.1479856334,  1.3026079974, -0.33016016  ,
#  -0.7632224879,  0.9427524278,  0.2585971527,  0.4311152374,  1.1530602486,
#   0.0104697129,  0.9959619965,  1.5515833081,  0.5117751896, -0.0895568064,
#   2.0218838591,  0.4537958797,  0.0057961328,  1.5291860393,  1.9349794846,
#   0.5181655307,  0.3904673054,  0.1970213004, -0.0964976969,  1.0924749305,
#  -0.2647126129,  1.5506429561,  0.5346502201,  0.2014334326,  0.7173739998,
#   0.567601884 ,  0.2994904527,  2.7704791979]
# ====================================================================================================
#
# Report saved to:
# /Users/sungwonyun/Documents/Qiskit/Minimum Error Discrimination/Simulator Seed 150 ReRe /DT_Nymark_report.txt
